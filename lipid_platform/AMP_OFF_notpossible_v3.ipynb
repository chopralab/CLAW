# %%
import pandas as pd

# %%
OzOFF_database_path="lipid_database/OzOFF_database/Database_OzOFF.parquet"
OzON_database_path = "lipid_database/OzON_databases/OzON_Possible_Database_0.parquet"
df_OFF = pd.read_parquet(OzOFF_database_path)
df_ON = pd.read_parquet(OzON_database_path)
df_OFF
# Out:
#            Lipid  Parent_Ion  Product_Ion Class Chain_length
# 0    FA(d2-16:0)       425.4          183    FA           16
# 1        FA(5:0)       269.3          183    FA            5
# 2        FA(5:1)       267.3          183    FA            5
# 3        FA(5:2)       265.3          183    FA            5
# 4        FA(5:3)       263.3          183    FA            5
# ..           ...         ...          ...   ...          ...
# 153     FA(30:1)       617.3          183    FA           30
# 154     FA(30:2)       615.3          183    FA           30
# 155     FA(30:3)       613.3          183    FA           30
# 156     FA(30:4)       611.3          183    FA           30
# 157     FA(30:5)       609.3          183    FA           30
#
# [158 rows x 5 columns]

# %%
df_ON
# Out:
#                       Lipid  Parent_Ion  Product_Ion  Species Class  \
# 0                   FA(5:0)       269.3        183.0      5:0    FA
# 1                   FA(6:0)       283.3        183.0      6:0    FA
# 2            FA(6:1)_<>_n-2       269.2        183.0      6:1    FA
# 3            FA(6:1)_<>_n-3       255.2        183.0      6:1    FA
# 4            FA(6:1)_<>_n-4       241.2        183.0      6:1    FA
# ...                     ...         ...          ...      ...   ...
# 6531  FA(30:6)_<BBFFF>_n-26       265.5        183.0     30:6    FA
# 6532  FA(30:6)_<FFFFF>_n-27       255.5        183.0     30:6    FA
# 6533  FA(30:6)_<BFFFF>_n-27       253.5        183.0     30:6    FA
# 6534  FA(30:6)_<FFFFF>_n-28       241.5        183.0     30:6    FA
# 6535            FA(d2-16:0)       425.4        183.0  d2-16:0    FA
#
#      DB Location  FA mass  [FA+AMP]+
# 0           None    102.2      281.3
# 1           None    116.2      295.3
# 2             <>    114.1      281.2
# 3             <>    114.1      281.2
# 4             <>    114.1      281.2
# ...          ...      ...        ...
# 6531     <BBFFF>    440.4      607.5
# 6532     <FFFFF>    440.4      607.5
# 6533     <BFFFF>    440.4      607.5
# 6534     <FFFFF>    440.4      607.5
# 6535        None    258.3      437.4
#
# [6536 rows x 8 columns]

# %% [markdown]
# # OFF

# %% [markdown]
# # 1 - mzml parser

# %%
# Submit the SLURM job for mzml_parser_1.sh
# !sbatch core/backend/mzml_parser_1_AMP_OFF.sh
# Out:
# Submitted batch job 19982060

# %%
df = pd.read_parquet('Projects/AMP/mzml_parsed/OFF/df_mzml_parser_1_OFF.parquet')
df
# Out:
#         Lipid  Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0        None       227.1        183.0        0.011583        40.920002
# 1        None       227.1        183.0        0.024483        40.820004
# 2        None       227.1        183.0        0.037383        40.760002
# 3        None       227.1        183.0        0.050317        40.740002
# 4        None       227.1        183.0        0.063233        40.740002
# ...       ...         ...          ...             ...              ...
# 4796605  None       533.5        183.0       29.949033        42.920002
# 4796606  None       533.5        183.0       29.961967        43.360004
# 4796607  None       533.5        183.0       29.974883        50.240002
# 4796608  None       533.5        183.0       29.987800        41.440002
# 4796609  None       533.5        183.0       30.000717        41.560001
#
#                                                  Sample_ID      Transition
# 0                      11162023_Blank-AMP_2x_MRMs_O3off_01  227.1 -> 183.0
# 1                      11162023_Blank-AMP_2x_MRMs_O3off_01  227.1 -> 183.0
# 2                      11162023_Blank-AMP_2x_MRMs_O3off_01  227.1 -> 183.0
# 3                      11162023_Blank-AMP_2x_MRMs_O3off_01  227.1 -> 183.0
# 4                      11162023_Blank-AMP_2x_MRMs_O3off_01  227.1 -> 183.0
# ...                                                    ...             ...
# 4796605  11192023_5xFAD-m2-hippo-FAD257_AMP_2x_0.05uMd2...  533.5 -> 183.0
# 4796606  11192023_5xFAD-m2-hippo-FAD257_AMP_2x_0.05uMd2...  533.5 -> 183.0
# 4796607  11192023_5xFAD-m2-hippo-FAD257_AMP_2x_0.05uMd2...  533.5 -> 183.0
# 4796608  11192023_5xFAD-m2-hippo-FAD257_AMP_2x_0.05uMd2...  533.5 -> 183.0
# 4796609  11192023_5xFAD-m2-hippo-FAD257_AMP_2x_0.05uMd2...  533.5 -> 183.0
#
# [4796610 rows x 7 columns]

# %%
transitions = pd.read_parquet('Projects/AMP/mzml_parsed/OFF/df_transition_summed_1_OFF.parquet')
transitions
# Out:
#       Parent_Ion  Product_Ion      Intensity      Transition  \
# 0          227.1        183.0  141907.550026  227.1 -> 183.0
# 1          241.1        183.0  101898.667385  241.1 -> 183.0
# 2          255.2        183.0  191667.253429  255.2 -> 183.0
# 3          269.1        183.0  174145.792530  269.1 -> 183.0
# 4          283.2        183.0  684325.971741  283.2 -> 183.0
# ...          ...          ...            ...             ...
# 2250       507.4        183.0  625977.444618  507.4 -> 183.0
# 2251       521.4        183.0  173889.252361  521.4 -> 183.0
# 2252       533.4        183.0  135267.409386  533.4 -> 183.0
# 2253       535.4        183.0  224620.855759  535.4 -> 183.0
# 2254       533.5        183.0   97392.426933  533.5 -> 183.0
#
#                                               Sample_ID
# 0                   11162023_Blank-AMP_2x_MRMs_O3off_01
# 1                   11162023_Blank-AMP_2x_MRMs_O3off_01
# 2                   11162023_Blank-AMP_2x_MRMs_O3off_01
# 3                   11162023_Blank-AMP_2x_MRMs_O3off_01
# 4                   11162023_Blank-AMP_2x_MRMs_O3off_01
# ...                                                 ...
# 2250  11192023_5xFAD-m2-hippo-FAD257_AMP_2x_0.05uMd2...
# 2251  11192023_5xFAD-m2-hippo-FAD257_AMP_2x_0.05uMd2...
# 2252  11192023_5xFAD-m2-hippo-FAD257_AMP_2x_0.05uMd2...
# 2253  11192023_5xFAD-m2-hippo-FAD257_AMP_2x_0.05uMd2...
# 2254  11192023_5xFAD-m2-hippo-FAD257_AMP_2x_0.05uMd2...
#
# [2255 rows x 5 columns]

# %% [markdown]
# # 2 - sample name

# %%
# Submit the SLURM job for !sbatch core/backend/sample_2.sh
# !sbatch core/backend/sample_2_AMP_OFF.sh
# Out:
# Submitted batch job 19982077

# %%
df = pd.read_parquet('Projects/AMP/samples/OFF/df_sample_2_hippo_5xFAD_m1_FAD231.parquet')
df
# Out:
#        Lipid  Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0       None       227.1        183.0        0.011583        41.320004
# 1       None       227.1        183.0        0.024483        41.440002
# 2       None       227.1        183.0        0.037383        41.380001
# 3       None       227.1        183.0        0.050317        41.360004
# 4       None       227.1        183.0        0.063233        41.380001
# ...      ...         ...          ...             ...              ...
# 127706  None       533.5        183.0       29.949017        42.580002
# 127707  None       533.5        183.0       29.961950        42.660004
# 127708  None       533.5        183.0       29.974867        40.940002
# 127709  None       533.5        183.0       29.987783        41.240002
# 127710  None       533.5        183.0       30.000700        41.320004
#
#                                                 Sample_ID      Transition  \
# 0       11192023_5xFAD-m1-hippo-FAD231_AMP_2x_0.05uMd2...  227.1 -> 183.0
# 1       11192023_5xFAD-m1-hippo-FAD231_AMP_2x_0.05uMd2...  227.1 -> 183.0
# 2       11192023_5xFAD-m1-hippo-FAD231_AMP_2x_0.05uMd2...  227.1 -> 183.0
# 3       11192023_5xFAD-m1-hippo-FAD231_AMP_2x_0.05uMd2...  227.1 -> 183.0
# 4       11192023_5xFAD-m1-hippo-FAD231_AMP_2x_0.05uMd2...  227.1 -> 183.0
# ...                                                   ...             ...
# 127706  11192023_5xFAD-m1-hippo-FAD231_AMP_2x_0.05uMd2...  533.5 -> 183.0
# 127707  11192023_5xFAD-m1-hippo-FAD231_AMP_2x_0.05uMd2...  533.5 -> 183.0
# 127708  11192023_5xFAD-m1-hippo-FAD231_AMP_2x_0.05uMd2...  533.5 -> 183.0
# 127709  11192023_5xFAD-m1-hippo-FAD231_AMP_2x_0.05uMd2...  533.5 -> 183.0
# 127710  11192023_5xFAD-m1-hippo-FAD231_AMP_2x_0.05uMd2...  533.5 -> 183.0
#
#                        Sample   STD  STD_RT_OFF
# 0       hippo_5xFAD_m1_FAD231  None    7.899767
# 1       hippo_5xFAD_m1_FAD231  None    7.899767
# 2       hippo_5xFAD_m1_FAD231  None    7.899767
# 3       hippo_5xFAD_m1_FAD231  None    7.899767
# 4       hippo_5xFAD_m1_FAD231  None    7.899767
# ...                       ...   ...         ...
# 127706  hippo_5xFAD_m1_FAD231  None    7.899767
# 127707  hippo_5xFAD_m1_FAD231  None    7.899767
# 127708  hippo_5xFAD_m1_FAD231  None    7.899767
# 127709  hippo_5xFAD_m1_FAD231  None    7.899767
# 127710  hippo_5xFAD_m1_FAD231  None    7.899767
#
# [127711 rows x 10 columns]

# %% [markdown]
# # 3 - Match lipids NOT POSSIBLE

# %% [markdown]
# count # of files and set this number in the .sh file

# %%
input_dir = 'Projects/AMP/samples/OFF/'
import glob; num_files = len(glob.glob('Projects/AMP/samples/OFF/*.parquet'))
num_files
# Out:
# 47

# %%
# Submit the SLURM job for !sbatch core/backend/match_3.sh
# !sbatch core/backend/not_possible/match_3_AMP_OFF_notpossible.sh
# Out:
# Submitted batch job 20174785

# %%
import pandas as pd
df = pd.read_parquet('Projects/AMP/match/OFF/notpossible/df_match_3_hippo_WT_m1_FAD245.parquet')
print(df['Lipid'].unique())
print(df['Lipid'].unique())

df
# Out:
# [''
#  'FA(6:1)_<>_n-4 | FA(6:2)_<F>_n-4 | FA(6:3)_<FF>_n-4 | FA(6:4)_<FFF>_n-4 | FA(7:1)_<>_n-5 | FA(7:2)_<F>_n-5 | FA(7:3)_<FF>_n-5 | FA(7:4)_<FFF>_n-5 | FA(7:5)_<FFFF>_n-5 | FA(8:1)_<>_n-6 | FA(8:2)_<F>_n-6 | FA(8:3)_<FF>_n-6 | FA(8:4)_<FFF>_n-6 | FA(8:5)_<FFFF>_n-6 | FA(8:6)_<FFFFF>_n-6 | FA(9:1)_<>_n-7 | FA(9:2)_<F>_n-7 | FA(9:3)_<FF>_n-7 | FA(9:4)_<FFF>_n-7 | FA(9:5)_<FFFF>_n-7 | FA(9:6)_<FFFFF>_n-7 | FA(10:1)_<>_n-8 | FA(10:2)_<F>_n-8 | FA(10:3)_<FF>_n-8 | FA(10:4)_<FFF>_n-8 | FA(10:5)_<FFFF>_n-8 | FA(10:6)_<FFFFF>_n-8 | FA(11:1)_<>_n-9 | FA(11:2)_<F>_n-9 | FA(11:3)_<FF>_n-9 | FA(11:4)_<FFF>_n-9 | FA(11:5)_<FFFF>_n-9 | FA(11:6)_<FFFFF>_n-9 | FA(12:1)_<>_n-10 | FA(12:2)_<F>_n-10 | FA(12:3)_<FF>_n-10 | FA(12:4)_<FFF>_n-10 | FA(12:5)_<FFFF>_n-10 | FA(12:6)_<FFFFF>_n-10 | FA(13:1)_<>_n-11 | FA(13:2)_<F>_n-11 | FA(13:3)_<FF>_n-11 | FA(13:4)_<FFF>_n-11 | FA(13:5)_<FFFF>_n-11 | FA(13:6)_<FFFFF>_n-11 | FA(14:1)_<>_n-12 | FA(14:2)_<F>_n-12 | FA(14:3)_<FF>_n-12 | FA(14:4)_<FFF>_n-12 | FA(14:5)_<FFFF>_n-12 | FA(14:6)_<FFFFF>_n-12 | FA(15:1)_<>_n-13 | FA(15:2)_<F>_n-13 | FA(15:3)_<FF>_n-13 | FA(15:4)_<FFF>_n-13 | FA(15:5)_<FFFF>_n-13 | FA(15:6)_<FFFFF>_n-13 | FA(16:1)_<>_n-14 | FA(16:2)_<F>_n-14 | FA(16:3)_<FF>_n-14 | FA(16:4)_<FFF>_n-14 | FA(16:5)_<FFFF>_n-14 | FA(16:6)_<FFFFF>_n-14 | FA(17:1)_<>_n-15 | FA(17:2)_<F>_n-15 | FA(17:3)_<FF>_n-15 | FA(17:4)_<FFF>_n-15 | FA(17:5)_<FFFF>_n-15 | FA(17:6)_<FFFFF>_n-15 | FA(18:1)_<>_n-16 | FA(18:2)_<F>_n-16 | FA(18:3)_<FF>_n-16 | FA(18:4)_<FFF>_n-16 | FA(18:5)_<FFFF>_n-16 | FA(18:6)_<FFFFF>_n-16 | FA(19:1)_<>_n-17 | FA(19:2)_<F>_n-17 | FA(19:3)_<FF>_n-17 | FA(19:4)_<FFF>_n-17 | FA(19:5)_<FFFF>_n-17 | FA(19:6)_<FFFFF>_n-17 | FA(20:1)_<>_n-18 | FA(20:2)_<F>_n-18 | FA(20:3)_<FF>_n-18 | FA(20:4)_<FFF>_n-18 | FA(20:5)_<FFFF>_n-18 | FA(20:6)_<FFFFF>_n-18'
#  'FA(6:1)_<>_n-3 | FA(6:2)_<F>_n-3 | FA(6:3)_<FF>_n-3 | FA(7:1)_<>_n-4 | FA(7:2)_<F>_n-4 | FA(7:3)_<FF>_n-4 | FA(7:4)_<FFF>_n-4 | FA(8:1)_<>_n-5 | FA(8:2)_<F>_n-5 | FA(8:3)_<FF>_n-5 | FA(8:4)_<FFF>_n-5 | FA(8:5)_<FFFF>_n-5 | FA(9:1)_<>_n-6 | FA(9:2)_<F>_n-6 | FA(9:3)_<FF>_n-6 | FA(9:4)_<FFF>_n-6 | FA(9:5)_<FFFF>_n-6 | FA(9:6)_<FFFFF>_n-6 | FA(10:1)_<>_n-7 | FA(10:2)_<F>_n-7 | FA(10:3)_<FF>_n-7 | FA(10:4)_<FFF>_n-7 | FA(10:5)_<FFFF>_n-7 | FA(10:6)_<FFFFF>_n-7 | FA(11:1)_<>_n-8 | FA(11:2)_<F>_n-8 | FA(11:3)_<FF>_n-8 | FA(11:4)_<FFF>_n-8 | FA(11:5)_<FFFF>_n-8 | FA(11:6)_<FFFFF>_n-8 | FA(12:1)_<>_n-9 | FA(12:2)_<F>_n-9 | FA(12:3)_<FF>_n-9 | FA(12:4)_<FFF>_n-9 | FA(12:5)_<FFFF>_n-9 | FA(12:6)_<FFFFF>_n-9 | FA(13:1)_<>_n-10 | FA(13:2)_<F>_n-10 | FA(13:3)_<FF>_n-10 | FA(13:4)_<FFF>_n-10 | FA(13:5)_<FFFF>_n-10 | FA(13:6)_<FFFFF>_n-10 | FA(14:1)_<>_n-11 | FA(14:2)_<F>_n-11 | FA(14:3)_<FF>_n-11 | FA(14:4)_<FFF>_n-11 | FA(14:5)_<FFFF>_n-11 | FA(14:6)_<FFFFF>_n-11 | FA(15:1)_<>_n-12 | FA(15:2)_<F>_n-12 | FA(15:3)_<FF>_n-12 | FA(15:4)_<FFF>_n-12 | FA(15:5)_<FFFF>_n-12 | FA(15:6)_<FFFFF>_n-12 | FA(16:1)_<>_n-13 | FA(16:2)_<F>_n-13 | FA(16:3)_<FF>_n-13 | FA(16:4)_<FFF>_n-13 | FA(16:5)_<FFFF>_n-13 | FA(16:6)_<FFFFF>_n-13 | FA(17:1)_<>_n-14 | FA(17:2)_<F>_n-14 | FA(17:3)_<FF>_n-14 | FA(17:4)_<FFF>_n-14 | FA(17:5)_<FFFF>_n-14 | FA(17:6)_<FFFFF>_n-14 | FA(18:1)_<>_n-15 | FA(18:2)_<F>_n-15 | FA(18:3)_<FF>_n-15 | FA(18:4)_<FFF>_n-15 | FA(18:5)_<FFFF>_n-15 | FA(18:6)_<FFFFF>_n-15 | FA(19:1)_<>_n-16 | FA(19:2)_<F>_n-16 | FA(19:3)_<FF>_n-16 | FA(19:4)_<FFF>_n-16 | FA(19:5)_<FFFF>_n-16 | FA(19:6)_<FFFFF>_n-16 | FA(20:1)_<>_n-17 | FA(20:2)_<F>_n-17 | FA(20:3)_<FF>_n-17 | FA(20:4)_<FFF>_n-17 | FA(20:5)_<FFFF>_n-17 | FA(20:6)_<FFFFF>_n-17 | FA(21:1)_<>_n-18 | FA(21:2)_<F>_n-18 | FA(21:3)_<FF>_n-18 | FA(21:4)_<FFF>_n-18 | FA(21:5)_<FFFF>_n-18 | FA(21:6)_<FFFFF>_n-18 | FA(22:1)_<>_n-19 | FA(22:2)_<F>_n-19 | FA(22:3)_<FF>_n-19 | FA(22:4)_<FFF>_n-19 | FA(22:5)_<FFFF>_n-19 | FA(22:6)_<FFFFF>_n-19 | FA(23:1)_<>_n-20 | FA(23:2)_<F>_n-20 | FA(23:3)_<FF>_n-20 | FA(23:4)_<FFF>_n-20 | FA(23:5)_<FFFF>_n-20 | FA(23:6)_<FFFFF>_n-20 | FA(24:1)_<>_n-21 | FA(24:2)_<F>_n-21 | FA(24:3)_<FF>_n-21 | FA(24:4)_<FFF>_n-21 | FA(24:5)_<FFFF>_n-21 | FA(24:6)_<FFFFF>_n-21 | FA(25:1)_<>_n-22 | FA(25:2)_<F>_n-22 | FA(25:3)_<FF>_n-22 | FA(25:4)_<FFF>_n-22 | FA(25:5)_<FFFF>_n-22 | FA(25:6)_<FFFFF>_n-22 | FA(26:1)_<>_n-23 | FA(26:2)_<F>_n-23 | FA(26:3)_<FF>_n-23 | FA(26:4)_<FFF>_n-23 | FA(26:5)_<FFFF>_n-23 | FA(26:6)_<FFFFF>_n-23 | FA(27:1)_<>_n-24 | FA(27:2)_<F>_n-24 | FA(27:3)_<FF>_n-24 | FA(27:4)_<FFF>_n-24 | FA(27:5)_<FFFF>_n-24 | FA(27:6)_<FFFFF>_n-24'
#  'FA(5:0) | FA(6:1)_<>_n-2 | FA(6:2)_<F>_n-2 | FA(7:1)_<>_n-3 | FA(7:2)_<F>_n-3 | FA(7:3)_<FF>_n-3 | FA(8:1)_<>_n-4 | FA(8:2)_<F>_n-4 | FA(8:3)_<FF>_n-4 | FA(8:4)_<FFF>_n-4 | FA(9:1)_<>_n-5 | FA(9:2)_<F>_n-5 | FA(9:3)_<FF>_n-5 | FA(9:4)_<FFF>_n-5 | FA(9:5)_<FFFF>_n-5 | FA(10:1)_<>_n-6 | FA(10:2)_<F>_n-6 | FA(10:3)_<FF>_n-6 | FA(10:4)_<FFF>_n-6 | FA(10:5)_<FFFF>_n-6 | FA(10:6)_<FFFFF>_n-6 | FA(11:1)_<>_n-7 | FA(11:2)_<F>_n-7 | FA(11:3)_<FF>_n-7 | FA(11:4)_<FFF>_n-7 | FA(11:5)_<FFFF>_n-7 | FA(11:6)_<FFFFF>_n-7 | FA(12:1)_<>_n-8 | FA(12:2)_<F>_n-8 | FA(12:3)_<FF>_n-8 | FA(12:4)_<FFF>_n-8 | FA(12:5)_<FFFF>_n-8 | FA(12:6)_<FFFFF>_n-8 | FA(13:1)_<>_n-9 | FA(13:2)_<F>_n-9 | FA(13:3)_<FF>_n-9 | FA(13:4)_<FFF>_n-9 | FA(13:5)_<FFFF>_n-9 | FA(13:6)_<FFFFF>_n-9 | FA(14:1)_<>_n-10 | FA(14:2)_<F>_n-10 | FA(14:3)_<FF>_n-10 | FA(14:4)_<FFF>_n-10 | FA(14:5)_<FFFF>_n-10 | FA(14:6)_<FFFFF>_n-10 | FA(15:1)_<>_n-11 | FA(15:2)_<F>_n-11 | FA(15:3)_<FF>_n-11 | FA(15:4)_<FFF>_n-11 | FA(15:5)_<FFFF>_n-11 | FA(15:6)_<FFFFF>_n-11 | FA(16:1)_<>_n-12 | FA(16:2)_<F>_n-12 | FA(16:3)_<FF>_n-12 | FA(16:4)_<FFF>_n-12 | FA(16:5)_<FFFF>_n-12 | FA(16:6)_<FFFFF>_n-12 | FA(17:1)_<>_n-13 | FA(17:2)_<F>_n-13 | FA(17:3)_<FF>_n-13 | FA(17:4)_<FFF>_n-13 | FA(17:5)_<FFFF>_n-13 | FA(17:6)_<FFFFF>_n-13 | FA(18:1)_<>_n-14 | FA(18:2)_<F>_n-14 | FA(18:3)_<FF>_n-14 | FA(18:4)_<FFF>_n-14 | FA(18:5)_<FFFF>_n-14 | FA(18:6)_<FFFFF>_n-14 | FA(19:1)_<>_n-15 | FA(19:2)_<F>_n-15 | FA(19:3)_<FF>_n-15 | FA(19:4)_<FFF>_n-15 | FA(19:5)_<FFFF>_n-15 | FA(19:6)_<FFFFF>_n-15 | FA(20:1)_<>_n-16 | FA(20:2)_<F>_n-16 | FA(20:3)_<FF>_n-16 | FA(20:4)_<FFF>_n-16 | FA(20:5)_<FFFF>_n-16 | FA(20:6)_<FFFFF>_n-16 | FA(21:1)_<>_n-17 | FA(21:2)_<F>_n-17 | FA(21:3)_<FF>_n-17 | FA(21:4)_<FFF>_n-17 | FA(21:5)_<FFFF>_n-17 | FA(21:6)_<FFFFF>_n-17 | FA(22:1)_<>_n-18 | FA(22:2)_<F>_n-18 | FA(22:3)_<FF>_n-18 | FA(22:4)_<FFF>_n-18 | FA(22:5)_<FFFF>_n-18 | FA(22:6)_<FFFFF>_n-18 | FA(23:1)_<>_n-19 | FA(23:2)_<F>_n-19 | FA(23:3)_<FF>_n-19 | FA(23:4)_<FFF>_n-19 | FA(23:5)_<FFFF>_n-19 | FA(23:6)_<FFFFF>_n-19 | FA(24:1)_<>_n-20 | FA(24:2)_<F>_n-20 | FA(24:3)_<FF>_n-20 | FA(24:4)_<FFF>_n-20 | FA(24:5)_<FFFF>_n-20 | FA(24:6)_<FFFFF>_n-20 | FA(25:1)_<>_n-21 | FA(25:2)_<F>_n-21 | FA(25:3)_<FF>_n-21 | FA(25:4)_<FFF>_n-21 | FA(25:5)_<FFFF>_n-21 | FA(25:6)_<FFFFF>_n-21 | FA(26:1)_<>_n-22 | FA(26:2)_<F>_n-22 | FA(26:3)_<FF>_n-22 | FA(26:4)_<FFF>_n-22 | FA(26:5)_<FFFF>_n-22 | FA(26:6)_<FFFFF>_n-22 | FA(27:1)_<>_n-23 | FA(27:2)_<F>_n-23 | FA(27:3)_<FF>_n-23 | FA(27:4)_<FFF>_n-23 | FA(27:5)_<FFFF>_n-23 | FA(27:6)_<FFFFF>_n-23'
#  'FA(6:0) | FA(7:1)_<>_n-2 | FA(7:2)_<F>_n-2 | FA(8:1)_<>_n-3 | FA(8:2)_<F>_n-3 | FA(8:3)_<FF>_n-3 | FA(9:1)_<>_n-4 | FA(9:2)_<F>_n-4 | FA(9:3)_<FF>_n-4 | FA(9:4)_<FFF>_n-4 | FA(10:1)_<>_n-5 | FA(10:2)_<F>_n-5 | FA(10:3)_<FF>_n-5 | FA(10:4)_<FFF>_n-5 | FA(10:5)_<FFFF>_n-5 | FA(11:1)_<>_n-6 | FA(11:2)_<F>_n-6 | FA(11:3)_<FF>_n-6 | FA(11:4)_<FFF>_n-6 | FA(11:5)_<FFFF>_n-6 | FA(11:6)_<FFFFF>_n-6 | FA(12:1)_<>_n-7 | FA(12:2)_<F>_n-7 | FA(12:3)_<FF>_n-7 | FA(12:4)_<FFF>_n-7 | FA(12:5)_<FFFF>_n-7 | FA(12:6)_<FFFFF>_n-7 | FA(13:1)_<>_n-8 | FA(13:2)_<F>_n-8 | FA(13:3)_<FF>_n-8 | FA(13:4)_<FFF>_n-8 | FA(13:5)_<FFFF>_n-8 | FA(13:6)_<FFFFF>_n-8 | FA(14:1)_<>_n-9 | FA(14:2)_<F>_n-9 | FA(14:3)_<FF>_n-9 | FA(14:4)_<FFF>_n-9 | FA(14:5)_<FFFF>_n-9 | FA(14:6)_<FFFFF>_n-9 | FA(15:1)_<>_n-10 | FA(15:2)_<F>_n-10 | FA(15:3)_<FF>_n-10 | FA(15:4)_<FFF>_n-10 | FA(15:5)_<FFFF>_n-10 | FA(15:6)_<FFFFF>_n-10 | FA(16:1)_<>_n-11 | FA(16:2)_<F>_n-11 | FA(16:3)_<FF>_n-11 | FA(16:4)_<FFF>_n-11 | FA(16:5)_<FFFF>_n-11 | FA(16:6)_<FFFFF>_n-11 | FA(17:1)_<>_n-12 | FA(17:2)_<F>_n-12 | FA(17:3)_<FF>_n-12 | FA(17:4)_<FFF>_n-12 | FA(17:5)_<FFFF>_n-12 | FA(17:6)_<FFFFF>_n-12 | FA(18:1)_<>_n-13 | FA(18:2)_<F>_n-13 | FA(18:3)_<FF>_n-13 | FA(18:4)_<FFF>_n-13 | FA(18:5)_<FFFF>_n-13 | FA(18:6)_<FFFFF>_n-13 | FA(19:1)_<>_n-14 | FA(19:2)_<F>_n-14 | FA(19:3)_<FF>_n-14 | FA(19:4)_<FFF>_n-14 | FA(19:5)_<FFFF>_n-14 | FA(19:6)_<FFFFF>_n-14 | FA(20:1)_<>_n-15 | FA(20:2)_<F>_n-15 | FA(20:3)_<FF>_n-15 | FA(20:4)_<FFF>_n-15 | FA(20:5)_<FFFF>_n-15 | FA(20:6)_<FFFFF>_n-15 | FA(21:1)_<>_n-16 | FA(21:2)_<F>_n-16 | FA(21:3)_<FF>_n-16 | FA(21:4)_<FFF>_n-16 | FA(21:5)_<FFFF>_n-16 | FA(21:6)_<FFFFF>_n-16 | FA(22:1)_<>_n-17 | FA(22:2)_<F>_n-17 | FA(22:3)_<FF>_n-17 | FA(22:4)_<FFF>_n-17 | FA(22:5)_<FFFF>_n-17 | FA(22:6)_<FFFFF>_n-17 | FA(23:1)_<>_n-18 | FA(23:2)_<F>_n-18 | FA(23:3)_<FF>_n-18 | FA(23:4)_<FFF>_n-18 | FA(23:5)_<FFFF>_n-18 | FA(23:6)_<FFFFF>_n-18 | FA(24:1)_<>_n-19 | FA(24:2)_<F>_n-19 | FA(24:3)_<FF>_n-19 | FA(24:4)_<FFF>_n-19 | FA(24:5)_<FFFF>_n-19 | FA(24:6)_<FFFFF>_n-19 | FA(25:1)_<>_n-20 | FA(25:2)_<F>_n-20 | FA(25:3)_<FF>_n-20 | FA(25:4)_<FFF>_n-20 | FA(25:5)_<FFFF>_n-20 | FA(25:6)_<FFFFF>_n-20 | FA(26:1)_<>_n-21 | FA(26:2)_<F>_n-21 | FA(26:3)_<FF>_n-21 | FA(26:4)_<FFF>_n-21 | FA(26:5)_<FFFF>_n-21 | FA(26:6)_<FFFFF>_n-21 | FA(27:1)_<>_n-22 | FA(27:2)_<F>_n-22 | FA(27:3)_<FF>_n-22 | FA(27:4)_<FFF>_n-22 | FA(27:5)_<FFFF>_n-22 | FA(27:6)_<FFFFF>_n-22'
#  'FA(7:0) | FA(8:1)_<>_n-2 | FA(8:2)_<F>_n-2 | FA(9:1)_<>_n-3 | FA(9:2)_<F>_n-3 | FA(9:3)_<FF>_n-3 | FA(10:1)_<>_n-4 | FA(10:2)_<F>_n-4 | FA(10:3)_<FF>_n-4 | FA(10:4)_<FFF>_n-4 | FA(11:1)_<>_n-5 | FA(11:2)_<F>_n-5 | FA(11:3)_<FF>_n-5 | FA(11:4)_<FFF>_n-5 | FA(11:5)_<FFFF>_n-5 | FA(12:1)_<>_n-6 | FA(12:2)_<F>_n-6 | FA(12:3)_<FF>_n-6 | FA(12:4)_<FFF>_n-6 | FA(12:5)_<FFFF>_n-6 | FA(12:6)_<FFFFF>_n-6 | FA(13:1)_<>_n-7 | FA(13:2)_<F>_n-7 | FA(13:3)_<FF>_n-7 | FA(13:4)_<FFF>_n-7 | FA(13:5)_<FFFF>_n-7 | FA(13:6)_<FFFFF>_n-7 | FA(14:1)_<>_n-8 | FA(14:2)_<F>_n-8 | FA(14:3)_<FF>_n-8 | FA(14:4)_<FFF>_n-8 | FA(14:5)_<FFFF>_n-8 | FA(14:6)_<FFFFF>_n-8 | FA(15:1)_<>_n-9 | FA(15:2)_<F>_n-9 | FA(15:3)_<FF>_n-9 | FA(15:4)_<FFF>_n-9 | FA(15:5)_<FFFF>_n-9 | FA(15:6)_<FFFFF>_n-9 | FA(16:1)_<>_n-10 | FA(16:2)_<F>_n-10 | FA(16:3)_<FF>_n-10 | FA(16:4)_<FFF>_n-10 | FA(16:5)_<FFFF>_n-10 | FA(16:6)_<FFFFF>_n-10 | FA(17:1)_<>_n-11 | FA(17:2)_<F>_n-11 | FA(17:3)_<FF>_n-11 | FA(17:4)_<FFF>_n-11 | FA(17:5)_<FFFF>_n-11 | FA(17:6)_<FFFFF>_n-11 | FA(18:1)_<>_n-12 | FA(18:2)_<F>_n-12 | FA(18:3)_<FF>_n-12 | FA(18:4)_<FFF>_n-12 | FA(18:5)_<FFFF>_n-12 | FA(18:6)_<FFFFF>_n-12 | FA(19:1)_<>_n-13 | FA(19:2)_<F>_n-13 | FA(19:3)_<FF>_n-13 | FA(19:4)_<FFF>_n-13 | FA(19:5)_<FFFF>_n-13 | FA(19:6)_<FFFFF>_n-13 | FA(20:1)_<>_n-14 | FA(20:2)_<F>_n-14 | FA(20:3)_<FF>_n-14 | FA(20:4)_<FFF>_n-14 | FA(20:5)_<FFFF>_n-14 | FA(20:6)_<FFFFF>_n-14 | FA(21:1)_<>_n-15 | FA(21:2)_<F>_n-15 | FA(21:3)_<FF>_n-15 | FA(21:4)_<FFF>_n-15 | FA(21:5)_<FFFF>_n-15 | FA(21:6)_<FFFFF>_n-15 | FA(22:1)_<>_n-16 | FA(22:2)_<F>_n-16 | FA(22:3)_<FF>_n-16 | FA(22:4)_<FFF>_n-16 | FA(22:5)_<FFFF>_n-16 | FA(22:6)_<FFFFF>_n-16 | FA(23:1)_<>_n-17 | FA(23:2)_<F>_n-17 | FA(23:3)_<FF>_n-17 | FA(23:4)_<FFF>_n-17 | FA(23:5)_<FFFF>_n-17 | FA(23:6)_<FFFFF>_n-17 | FA(24:1)_<>_n-18 | FA(24:2)_<F>_n-18 | FA(24:3)_<FF>_n-18 | FA(24:4)_<FFF>_n-18 | FA(24:5)_<FFFF>_n-18 | FA(24:6)_<FFFFF>_n-18 | FA(25:1)_<>_n-19 | FA(25:2)_<F>_n-19 | FA(25:3)_<FF>_n-19 | FA(25:4)_<FFF>_n-19 | FA(25:5)_<FFFF>_n-19 | FA(25:6)_<FFFFF>_n-19 | FA(26:1)_<>_n-20 | FA(26:2)_<F>_n-20 | FA(26:3)_<FF>_n-20 | FA(26:4)_<FFF>_n-20 | FA(26:5)_<FFFF>_n-20 | FA(26:6)_<FFFFF>_n-20 | FA(27:1)_<>_n-21 | FA(27:2)_<F>_n-21 | FA(27:3)_<FF>_n-21 | FA(27:4)_<FFF>_n-21 | FA(27:5)_<FFFF>_n-21 | FA(27:6)_<FFFFF>_n-21'
#  'FA(9:2)_<B>_n-2 | FA(9:3)_<BF>_n-2 | FA(10:2)_<B>_n-3 | FA(10:3)_<BF>_n-3 | FA(10:4)_<BFF>_n-3 | FA(11:2)_<B>_n-4 | FA(11:3)_<BF>_n-4 | FA(11:4)_<BFF>_n-4 | FA(11:5)_<BFFF>_n-4 | FA(12:2)_<B>_n-5 | FA(12:3)_<BF>_n-5 | FA(12:4)_<BFF>_n-5 | FA(12:5)_<BFFF>_n-5 | FA(12:6)_<BFFFF>_n-5 | FA(13:2)_<B>_n-6 | FA(13:3)_<BF>_n-6 | FA(13:4)_<BFF>_n-6 | FA(13:5)_<BFFF>_n-6 | FA(13:6)_<BFFFF>_n-6 | FA(14:2)_<B>_n-7 | FA(14:3)_<BF>_n-7 | FA(14:4)_<BFF>_n-7 | FA(14:5)_<BFFF>_n-7 | FA(14:6)_<BFFFF>_n-7 | FA(15:2)_<B>_n-8 | FA(15:3)_<BF>_n-8 | FA(15:4)_<BFF>_n-8 | FA(15:5)_<BFFF>_n-8 | FA(15:6)_<BFFFF>_n-8 | FA(16:2)_<B>_n-9 | FA(16:3)_<BF>_n-9 | FA(16:4)_<BFF>_n-9 | FA(16:5)_<BFFF>_n-9 | FA(16:6)_<BFFFF>_n-9 | FA(17:2)_<B>_n-10 | FA(17:3)_<BF>_n-10 | FA(17:4)_<BFF>_n-10 | FA(17:5)_<BFFF>_n-10 | FA(17:6)_<BFFFF>_n-10 | FA(18:2)_<B>_n-11 | FA(18:3)_<BF>_n-11 | FA(18:4)_<BFF>_n-11 | FA(18:5)_<BFFF>_n-11 | FA(18:6)_<BFFFF>_n-11 | FA(19:2)_<B>_n-12 | FA(19:3)_<BF>_n-12 | FA(19:4)_<BFF>_n-12 | FA(19:5)_<BFFF>_n-12 | FA(19:6)_<BFFFF>_n-12 | FA(20:2)_<B>_n-13 | FA(20:3)_<BF>_n-13 | FA(20:4)_<BFF>_n-13 | FA(20:5)_<BFFF>_n-13 | FA(20:6)_<BFFFF>_n-13 | FA(21:2)_<B>_n-14 | FA(21:3)_<BF>_n-14 | FA(21:4)_<BFF>_n-14 | FA(21:5)_<BFFF>_n-14 | FA(21:6)_<BFFFF>_n-14 | FA(22:2)_<B>_n-15 | FA(22:3)_<BF>_n-15 | FA(22:4)_<BFF>_n-15 | FA(22:5)_<BFFF>_n-15 | FA(22:6)_<BFFFF>_n-15 | FA(23:2)_<B>_n-16 | FA(23:3)_<BF>_n-16 | FA(23:4)_<BFF>_n-16 | FA(23:5)_<BFFF>_n-16 | FA(23:6)_<BFFFF>_n-16 | FA(24:2)_<B>_n-17 | FA(24:3)_<BF>_n-17 | FA(24:4)_<BFF>_n-17 | FA(24:5)_<BFFF>_n-17 | FA(24:6)_<BFFFF>_n-17 | FA(25:2)_<B>_n-18 | FA(25:3)_<BF>_n-18 | FA(25:4)_<BFF>_n-18 | FA(25:5)_<BFFF>_n-18 | FA(25:6)_<BFFFF>_n-18 | FA(26:2)_<B>_n-19 | FA(26:3)_<BF>_n-19 | FA(26:4)_<BFF>_n-19 | FA(26:5)_<BFFF>_n-19 | FA(26:6)_<BFFFF>_n-19 | FA(27:2)_<B>_n-20 | FA(27:3)_<BF>_n-20 | FA(27:4)_<BFF>_n-20 | FA(27:5)_<BFFF>_n-20 | FA(27:6)_<BFFFF>_n-20'
#  'FA(8:0) | FA(9:1)_<>_n-2 | FA(9:2)_<F>_n-2 | FA(10:1)_<>_n-3 | FA(10:2)_<F>_n-3 | FA(10:3)_<FF>_n-3 | FA(11:1)_<>_n-4 | FA(11:2)_<F>_n-4 | FA(11:3)_<FF>_n-4 | FA(11:4)_<FFF>_n-4 | FA(12:1)_<>_n-5 | FA(12:2)_<F>_n-5 | FA(12:3)_<FF>_n-5 | FA(12:4)_<FFF>_n-5 | FA(12:5)_<FFFF>_n-5 | FA(13:1)_<>_n-6 | FA(13:2)_<F>_n-6 | FA(13:3)_<FF>_n-6 | FA(13:4)_<FFF>_n-6 | FA(13:5)_<FFFF>_n-6 | FA(13:6)_<FFFFF>_n-6 | FA(14:1)_<>_n-7 | FA(14:2)_<F>_n-7 | FA(14:3)_<FF>_n-7 | FA(14:4)_<FFF>_n-7 | FA(14:5)_<FFFF>_n-7 | FA(14:6)_<FFFFF>_n-7 | FA(15:1)_<>_n-8 | FA(15:2)_<F>_n-8 | FA(15:3)_<FF>_n-8 | FA(15:4)_<FFF>_n-8 | FA(15:5)_<FFFF>_n-8 | FA(15:6)_<FFFFF>_n-8 | FA(16:1)_<>_n-9 | FA(16:2)_<F>_n-9 | FA(16:3)_<FF>_n-9 | FA(16:4)_<FFF>_n-9 | FA(16:5)_<FFFF>_n-9 | FA(16:6)_<FFFFF>_n-9 | FA(17:1)_<>_n-10 | FA(17:2)_<F>_n-10 | FA(17:3)_<FF>_n-10 | FA(17:4)_<FFF>_n-10 | FA(17:5)_<FFFF>_n-10 | FA(17:6)_<FFFFF>_n-10 | FA(18:1)_<>_n-11 | FA(18:2)_<F>_n-11 | FA(18:3)_<FF>_n-11 | FA(18:4)_<FFF>_n-11 | FA(18:5)_<FFFF>_n-11 | FA(18:6)_<FFFFF>_n-11 | FA(19:1)_<>_n-12 | FA(19:2)_<F>_n-12 | FA(19:3)_<FF>_n-12 | FA(19:4)_<FFF>_n-12 | FA(19:5)_<FFFF>_n-12 | FA(19:6)_<FFFFF>_n-12 | FA(20:1)_<>_n-13 | FA(20:2)_<F>_n-13 | FA(20:3)_<FF>_n-13 | FA(20:4)_<FFF>_n-13 | FA(20:5)_<FFFF>_n-13 | FA(20:6)_<FFFFF>_n-13 | FA(21:1)_<>_n-14 | FA(21:2)_<F>_n-14 | FA(21:3)_<FF>_n-14 | FA(21:4)_<FFF>_n-14 | FA(21:5)_<FFFF>_n-14 | FA(21:6)_<FFFFF>_n-14 | FA(22:1)_<>_n-15 | FA(22:2)_<F>_n-15 | FA(22:3)_<FF>_n-15 | FA(22:4)_<FFF>_n-15 | FA(22:5)_<FFFF>_n-15 | FA(22:6)_<FFFFF>_n-15 | FA(23:1)_<>_n-16 | FA(23:2)_<F>_n-16 | FA(23:3)_<FF>_n-16 | FA(23:4)_<FFF>_n-16 | FA(23:5)_<FFFF>_n-16 | FA(23:6)_<FFFFF>_n-16 | FA(24:1)_<>_n-17 | FA(24:2)_<F>_n-17 | FA(24:3)_<FF>_n-17 | FA(24:4)_<FFF>_n-17 | FA(24:5)_<FFFF>_n-17 | FA(24:6)_<FFFFF>_n-17 | FA(25:1)_<>_n-18 | FA(25:2)_<F>_n-18 | FA(25:3)_<FF>_n-18 | FA(25:4)_<FFF>_n-18 | FA(25:5)_<FFFF>_n-18 | FA(25:6)_<FFFFF>_n-18 | FA(26:1)_<>_n-19 | FA(26:2)_<F>_n-19 | FA(26:3)_<FF>_n-19 | FA(26:4)_<FFF>_n-19 | FA(26:5)_<FFFF>_n-19 | FA(26:6)_<FFFFF>_n-19 | FA(27:1)_<>_n-20 | FA(27:2)_<F>_n-20 | FA(27:3)_<FF>_n-20 | FA(27:4)_<FFF>_n-20 | FA(27:5)_<FFFF>_n-20 | FA(27:6)_<FFFFF>_n-20 | FA(28:1)_<>_n-21 | FA(28:2)_<F>_n-21 | FA(28:3)_<FF>_n-21 | FA(28:4)_<FFF>_n-21 | FA(28:5)_<FFFF>_n-21 | FA(28:6)_<FFFFF>_n-21 | FA(29:1)_<>_n-22 | FA(29:2)_<F>_n-22 | FA(29:3)_<FF>_n-22 | FA(29:4)_<FFF>_n-22 | FA(29:5)_<FFFF>_n-22 | FA(29:6)_<FFFFF>_n-22 | FA(30:1)_<>_n-23 | FA(30:2)_<F>_n-23 | FA(30:3)_<FF>_n-23 | FA(30:4)_<FFF>_n-23 | FA(30:5)_<FFFF>_n-23 | FA(30:6)_<FFFFF>_n-23'
#  'FA(10:2)_<B>_n-2 | FA(10:3)_<BF>_n-2 | FA(11:2)_<B>_n-3 | FA(11:3)_<BF>_n-3 | FA(11:4)_<BFF>_n-3 | FA(12:2)_<B>_n-4 | FA(12:3)_<BF>_n-4 | FA(12:4)_<BFF>_n-4 | FA(12:5)_<BFFF>_n-4 | FA(13:2)_<B>_n-5 | FA(13:3)_<BF>_n-5 | FA(13:4)_<BFF>_n-5 | FA(13:5)_<BFFF>_n-5 | FA(13:6)_<BFFFF>_n-5 | FA(14:2)_<B>_n-6 | FA(14:3)_<BF>_n-6 | FA(14:4)_<BFF>_n-6 | FA(14:5)_<BFFF>_n-6 | FA(14:6)_<BFFFF>_n-6 | FA(15:2)_<B>_n-7 | FA(15:3)_<BF>_n-7 | FA(15:4)_<BFF>_n-7 | FA(15:5)_<BFFF>_n-7 | FA(15:6)_<BFFFF>_n-7 | FA(16:2)_<B>_n-8 | FA(16:3)_<BF>_n-8 | FA(16:4)_<BFF>_n-8 | FA(16:5)_<BFFF>_n-8 | FA(16:6)_<BFFFF>_n-8 | FA(17:2)_<B>_n-9 | FA(17:3)_<BF>_n-9 | FA(17:4)_<BFF>_n-9 | FA(17:5)_<BFFF>_n-9 | FA(17:6)_<BFFFF>_n-9 | FA(18:2)_<B>_n-10 | FA(18:3)_<BF>_n-10 | FA(18:4)_<BFF>_n-10 | FA(18:5)_<BFFF>_n-10 | FA(18:6)_<BFFFF>_n-10 | FA(19:2)_<B>_n-11 | FA(19:3)_<BF>_n-11 | FA(19:4)_<BFF>_n-11 | FA(19:5)_<BFFF>_n-11 | FA(19:6)_<BFFFF>_n-11 | FA(20:2)_<B>_n-12 | FA(20:3)_<BF>_n-12 | FA(20:4)_<BFF>_n-12 | FA(20:5)_<BFFF>_n-12 | FA(20:6)_<BFFFF>_n-12 | FA(21:2)_<B>_n-13 | FA(21:3)_<BF>_n-13 | FA(21:4)_<BFF>_n-13 | FA(21:5)_<BFFF>_n-13 | FA(21:6)_<BFFFF>_n-13 | FA(22:2)_<B>_n-14 | FA(22:3)_<BF>_n-14 | FA(22:4)_<BFF>_n-14 | FA(22:5)_<BFFF>_n-14 | FA(22:6)_<BFFFF>_n-14 | FA(23:2)_<B>_n-15 | FA(23:3)_<BF>_n-15 | FA(23:4)_<BFF>_n-15 | FA(23:5)_<BFFF>_n-15 | FA(23:6)_<BFFFF>_n-15 | FA(24:2)_<B>_n-16 | FA(24:3)_<BF>_n-16 | FA(24:4)_<BFF>_n-16 | FA(24:5)_<BFFF>_n-16 | FA(24:6)_<BFFFF>_n-16 | FA(25:2)_<B>_n-17 | FA(25:3)_<BF>_n-17 | FA(25:4)_<BFF>_n-17 | FA(25:5)_<BFFF>_n-17 | FA(25:6)_<BFFFF>_n-17 | FA(26:2)_<B>_n-18 | FA(26:3)_<BF>_n-18 | FA(26:4)_<BFF>_n-18 | FA(26:5)_<BFFF>_n-18 | FA(26:6)_<BFFFF>_n-18 | FA(27:2)_<B>_n-19 | FA(27:3)_<BF>_n-19 | FA(27:4)_<BFF>_n-19 | FA(27:5)_<BFFF>_n-19 | FA(27:6)_<BFFFF>_n-19'
#  'FA(9:0) | FA(10:1)_<>_n-2 | FA(10:2)_<F>_n-2 | FA(11:1)_<>_n-3 | FA(11:2)_<F>_n-3 | FA(11:3)_<FF>_n-3 | FA(12:1)_<>_n-4 | FA(12:2)_<F>_n-4 | FA(12:3)_<FF>_n-4 | FA(12:4)_<FFF>_n-4 | FA(13:1)_<>_n-5 | FA(13:2)_<F>_n-5 | FA(13:3)_<FF>_n-5 | FA(13:4)_<FFF>_n-5 | FA(13:5)_<FFFF>_n-5 | FA(14:1)_<>_n-6 | FA(14:2)_<F>_n-6 | FA(14:3)_<FF>_n-6 | FA(14:4)_<FFF>_n-6 | FA(14:5)_<FFFF>_n-6 | FA(14:6)_<FFFFF>_n-6 | FA(15:1)_<>_n-7 | FA(15:2)_<F>_n-7 | FA(15:3)_<FF>_n-7 | FA(15:4)_<FFF>_n-7 | FA(15:5)_<FFFF>_n-7 | FA(15:6)_<FFFFF>_n-7 | FA(16:1)_<>_n-8 | FA(16:2)_<F>_n-8 | FA(16:3)_<FF>_n-8 | FA(16:4)_<FFF>_n-8 | FA(16:5)_<FFFF>_n-8 | FA(16:6)_<FFFFF>_n-8 | FA(17:1)_<>_n-9 | FA(17:2)_<F>_n-9 | FA(17:3)_<FF>_n-9 | FA(17:4)_<FFF>_n-9 | FA(17:5)_<FFFF>_n-9 | FA(17:6)_<FFFFF>_n-9 | FA(18:1)_<>_n-10 | FA(18:2)_<F>_n-10 | FA(18:3)_<FF>_n-10 | FA(18:4)_<FFF>_n-10 | FA(18:5)_<FFFF>_n-10 | FA(18:6)_<FFFFF>_n-10 | FA(19:1)_<>_n-11 | FA(19:2)_<F>_n-11 | FA(19:3)_<FF>_n-11 | FA(19:4)_<FFF>_n-11 | FA(19:5)_<FFFF>_n-11 | FA(19:6)_<FFFFF>_n-11 | FA(20:1)_<>_n-12 | FA(20:2)_<F>_n-12 | FA(20:3)_<FF>_n-12 | FA(20:4)_<FFF>_n-12 | FA(20:5)_<FFFF>_n-12 | FA(20:6)_<FFFFF>_n-12 | FA(21:1)_<>_n-13 | FA(21:2)_<F>_n-13 | FA(21:3)_<FF>_n-13 | FA(21:4)_<FFF>_n-13 | FA(21:5)_<FFFF>_n-13 | FA(21:6)_<FFFFF>_n-13 | FA(22:1)_<>_n-14 | FA(22:2)_<F>_n-14 | FA(22:3)_<FF>_n-14 | FA(22:4)_<FFF>_n-14 | FA(22:5)_<FFFF>_n-14 | FA(22:6)_<FFFFF>_n-14 | FA(23:1)_<>_n-15 | FA(23:2)_<F>_n-15 | FA(23:3)_<FF>_n-15 | FA(23:4)_<FFF>_n-15 | FA(23:5)_<FFFF>_n-15 | FA(23:6)_<FFFFF>_n-15 | FA(24:1)_<>_n-16 | FA(24:2)_<F>_n-16 | FA(24:3)_<FF>_n-16 | FA(24:4)_<FFF>_n-16 | FA(24:5)_<FFFF>_n-16 | FA(24:6)_<FFFFF>_n-16 | FA(25:1)_<>_n-17 | FA(25:2)_<F>_n-17 | FA(25:3)_<FF>_n-17 | FA(25:4)_<FFF>_n-17 | FA(25:5)_<FFFF>_n-17 | FA(25:6)_<FFFFF>_n-17 | FA(26:1)_<>_n-18 | FA(26:2)_<F>_n-18 | FA(26:3)_<FF>_n-18 | FA(26:4)_<FFF>_n-18 | FA(26:5)_<FFFF>_n-18 | FA(26:6)_<FFFFF>_n-18 | FA(27:1)_<>_n-19 | FA(27:2)_<F>_n-19 | FA(27:3)_<FF>_n-19 | FA(27:4)_<FFF>_n-19 | FA(27:5)_<FFFF>_n-19 | FA(27:6)_<FFFFF>_n-19'
#  'FA(11:2)_<B>_n-2 | FA(11:3)_<BF>_n-2 | FA(12:2)_<B>_n-3 | FA(12:3)_<BF>_n-3 | FA(12:4)_<BFF>_n-3 | FA(13:2)_<B>_n-4 | FA(13:3)_<BF>_n-4 | FA(13:4)_<BFF>_n-4 | FA(13:5)_<BFFF>_n-4 | FA(14:2)_<B>_n-5 | FA(14:3)_<BF>_n-5 | FA(14:4)_<BFF>_n-5 | FA(14:5)_<BFFF>_n-5 | FA(14:6)_<BFFFF>_n-5 | FA(15:2)_<B>_n-6 | FA(15:3)_<BF>_n-6 | FA(15:4)_<BFF>_n-6 | FA(15:5)_<BFFF>_n-6 | FA(15:6)_<BFFFF>_n-6 | FA(16:2)_<B>_n-7 | FA(16:3)_<BF>_n-7 | FA(16:4)_<BFF>_n-7 | FA(16:5)_<BFFF>_n-7 | FA(16:6)_<BFFFF>_n-7 | FA(17:2)_<B>_n-8 | FA(17:3)_<BF>_n-8 | FA(17:4)_<BFF>_n-8 | FA(17:5)_<BFFF>_n-8 | FA(17:6)_<BFFFF>_n-8 | FA(18:2)_<B>_n-9 | FA(18:3)_<BF>_n-9 | FA(18:4)_<BFF>_n-9 | FA(18:5)_<BFFF>_n-9 | FA(18:6)_<BFFFF>_n-9 | FA(19:2)_<B>_n-10 | FA(19:3)_<BF>_n-10 | FA(19:4)_<BFF>_n-10 | FA(19:5)_<BFFF>_n-10 | FA(19:6)_<BFFFF>_n-10 | FA(20:2)_<B>_n-11 | FA(20:3)_<BF>_n-11 | FA(20:4)_<BFF>_n-11 | FA(20:5)_<BFFF>_n-11 | FA(20:6)_<BFFFF>_n-11 | FA(21:2)_<B>_n-12 | FA(21:3)_<BF>_n-12 | FA(21:4)_<BFF>_n-12 | FA(21:5)_<BFFF>_n-12 | FA(21:6)_<BFFFF>_n-12 | FA(22:2)_<B>_n-13 | FA(22:3)_<BF>_n-13 | FA(22:4)_<BFF>_n-13 | FA(22:5)_<BFFF>_n-13 | FA(22:6)_<BFFFF>_n-13 | FA(23:2)_<B>_n-14 | FA(23:3)_<BF>_n-14 | FA(23:4)_<BFF>_n-14 | FA(23:5)_<BFFF>_n-14 | FA(23:6)_<BFFFF>_n-14 | FA(24:2)_<B>_n-15 | FA(24:3)_<BF>_n-15 | FA(24:4)_<BFF>_n-15 | FA(24:5)_<BFFF>_n-15 | FA(24:6)_<BFFFF>_n-15 | FA(25:2)_<B>_n-16 | FA(25:3)_<BF>_n-16 | FA(25:4)_<BFF>_n-16 | FA(25:5)_<BFFF>_n-16 | FA(25:6)_<BFFFF>_n-16 | FA(26:2)_<B>_n-17 | FA(26:3)_<BF>_n-17 | FA(26:4)_<BFF>_n-17 | FA(26:5)_<BFFF>_n-17 | FA(26:6)_<BFFFF>_n-17 | FA(27:2)_<B>_n-18 | FA(27:3)_<BF>_n-18 | FA(27:4)_<BFF>_n-18 | FA(27:5)_<BFFF>_n-18 | FA(27:6)_<BFFFF>_n-18'
#  'FA(10:0) | FA(11:1)_<>_n-2 | FA(11:2)_<F>_n-2 | FA(12:1)_<>_n-3 | FA(12:2)_<F>_n-3 | FA(12:3)_<FF>_n-3 | FA(13:1)_<>_n-4 | FA(13:2)_<F>_n-4 | FA(13:3)_<FF>_n-4 | FA(13:4)_<FFF>_n-4 | FA(14:1)_<>_n-5 | FA(14:2)_<F>_n-5 | FA(14:3)_<FF>_n-5 | FA(14:4)_<FFF>_n-5 | FA(14:5)_<FFFF>_n-5 | FA(15:1)_<>_n-6 | FA(15:2)_<F>_n-6 | FA(15:3)_<FF>_n-6 | FA(15:4)_<FFF>_n-6 | FA(15:5)_<FFFF>_n-6 | FA(15:6)_<FFFFF>_n-6 | FA(16:1)_<>_n-7 | FA(16:2)_<F>_n-7 | FA(16:3)_<FF>_n-7 | FA(16:4)_<FFF>_n-7 | FA(16:5)_<FFFF>_n-7 | FA(16:6)_<FFFFF>_n-7 | FA(17:1)_<>_n-8 | FA(17:2)_<F>_n-8 | FA(17:3)_<FF>_n-8 | FA(17:4)_<FFF>_n-8 | FA(17:5)_<FFFF>_n-8 | FA(17:6)_<FFFFF>_n-8 | FA(18:1)_<>_n-9 | FA(18:2)_<F>_n-9 | FA(18:3)_<FF>_n-9 | FA(18:4)_<FFF>_n-9 | FA(18:5)_<FFFF>_n-9 | FA(18:6)_<FFFFF>_n-9 | FA(19:1)_<>_n-10 | FA(19:2)_<F>_n-10 | FA(19:3)_<FF>_n-10 | FA(19:4)_<FFF>_n-10 | FA(19:5)_<FFFF>_n-10 | FA(19:6)_<FFFFF>_n-10 | FA(20:1)_<>_n-11 | FA(20:2)_<F>_n-11 | FA(20:3)_<FF>_n-11 | FA(20:4)_<FFF>_n-11 | FA(20:5)_<FFFF>_n-11 | FA(20:6)_<FFFFF>_n-11 | FA(21:1)_<>_n-12 | FA(21:2)_<F>_n-12 | FA(21:3)_<FF>_n-12 | FA(21:4)_<FFF>_n-12 | FA(21:5)_<FFFF>_n-12 | FA(21:6)_<FFFFF>_n-12 | FA(22:1)_<>_n-13 | FA(22:2)_<F>_n-13 | FA(22:3)_<FF>_n-13 | FA(22:4)_<FFF>_n-13 | FA(22:5)_<FFFF>_n-13 | FA(22:6)_<FFFFF>_n-13 | FA(23:1)_<>_n-14 | FA(23:2)_<F>_n-14 | FA(23:3)_<FF>_n-14 | FA(23:4)_<FFF>_n-14 | FA(23:5)_<FFFF>_n-14 | FA(23:6)_<FFFFF>_n-14 | FA(24:1)_<>_n-15 | FA(24:2)_<F>_n-15 | FA(24:3)_<FF>_n-15 | FA(24:4)_<FFF>_n-15 | FA(24:5)_<FFFF>_n-15 | FA(24:6)_<FFFFF>_n-15 | FA(25:1)_<>_n-16 | FA(25:2)_<F>_n-16 | FA(25:3)_<FF>_n-16 | FA(25:4)_<FFF>_n-16 | FA(25:5)_<FFFF>_n-16 | FA(25:6)_<FFFFF>_n-16 | FA(26:1)_<>_n-17 | FA(26:2)_<F>_n-17 | FA(26:3)_<FF>_n-17 | FA(26:4)_<FFF>_n-17 | FA(26:5)_<FFFF>_n-17 | FA(26:6)_<FFFFF>_n-17 | FA(27:1)_<>_n-18 | FA(27:2)_<F>_n-18 | FA(27:3)_<FF>_n-18 | FA(27:4)_<FFF>_n-18 | FA(27:5)_<FFFF>_n-18 | FA(27:6)_<FFFFF>_n-18 | FA(28:1)_<>_n-19 | FA(28:2)_<F>_n-19 | FA(28:3)_<FF>_n-19 | FA(28:4)_<FFF>_n-19 | FA(28:5)_<FFFF>_n-19 | FA(28:6)_<FFFFF>_n-19 | FA(29:1)_<>_n-20 | FA(29:2)_<F>_n-20 | FA(29:3)_<FF>_n-20 | FA(29:4)_<FFF>_n-20 | FA(29:5)_<FFFF>_n-20 | FA(29:6)_<FFFFF>_n-20 | FA(30:1)_<>_n-21 | FA(30:2)_<F>_n-21 | FA(30:3)_<FF>_n-21 | FA(30:4)_<FFF>_n-21 | FA(30:5)_<FFFF>_n-21 | FA(30:6)_<FFFFF>_n-21'
#  'FA(12:3)_<BB>_n-2 | FA(12:4)_<BBF>_n-2 | FA(13:3)_<BB>_n-3 | FA(13:4)_<BBF>_n-3 | FA(13:5)_<BBFF>_n-3 | FA(14:3)_<BB>_n-4 | FA(14:4)_<BBF>_n-4 | FA(14:5)_<BBFF>_n-4 | FA(14:6)_<BBFFF>_n-4 | FA(15:3)_<BB>_n-5 | FA(15:4)_<BBF>_n-5 | FA(15:5)_<BBFF>_n-5 | FA(15:6)_<BBFFF>_n-5 | FA(16:3)_<BB>_n-6 | FA(16:4)_<BBF>_n-6 | FA(16:5)_<BBFF>_n-6 | FA(16:6)_<BBFFF>_n-6 | FA(17:3)_<BB>_n-7 | FA(17:4)_<BBF>_n-7 | FA(17:5)_<BBFF>_n-7 | FA(17:6)_<BBFFF>_n-7 | FA(18:3)_<BB>_n-8 | FA(18:4)_<BBF>_n-8 | FA(18:5)_<BBFF>_n-8 | FA(18:6)_<BBFFF>_n-8 | FA(19:3)_<BB>_n-9 | FA(19:4)_<BBF>_n-9 | FA(19:5)_<BBFF>_n-9 | FA(19:6)_<BBFFF>_n-9 | FA(20:3)_<BB>_n-10 | FA(20:4)_<BBF>_n-10 | FA(20:5)_<BBFF>_n-10 | FA(20:6)_<BBFFF>_n-10 | FA(21:3)_<BB>_n-11 | FA(21:4)_<BBF>_n-11 | FA(21:5)_<BBFF>_n-11 | FA(21:6)_<BBFFF>_n-11 | FA(22:3)_<BB>_n-12 | FA(22:4)_<BBF>_n-12 | FA(22:5)_<BBFF>_n-12 | FA(22:6)_<BBFFF>_n-12 | FA(23:3)_<BB>_n-13 | FA(23:4)_<BBF>_n-13 | FA(23:5)_<BBFF>_n-13 | FA(23:6)_<BBFFF>_n-13 | FA(24:3)_<BB>_n-14 | FA(24:4)_<BBF>_n-14 | FA(24:5)_<BBFF>_n-14 | FA(24:6)_<BBFFF>_n-14 | FA(25:3)_<BB>_n-15 | FA(25:4)_<BBF>_n-15 | FA(25:5)_<BBFF>_n-15 | FA(25:6)_<BBFFF>_n-15 | FA(26:3)_<BB>_n-16 | FA(26:4)_<BBF>_n-16 | FA(26:5)_<BBFF>_n-16 | FA(26:6)_<BBFFF>_n-16 | FA(27:3)_<BB>_n-17 | FA(27:4)_<BBF>_n-17 | FA(27:5)_<BBFF>_n-17 | FA(27:6)_<BBFFF>_n-17'
#  'FA(11:0) | FA(12:1)_<>_n-2 | FA(12:2)_<F>_n-2 | FA(13:1)_<>_n-3 | FA(13:2)_<F>_n-3 | FA(13:3)_<FF>_n-3 | FA(14:1)_<>_n-4 | FA(14:2)_<F>_n-4 | FA(14:3)_<FF>_n-4 | FA(14:4)_<FFF>_n-4 | FA(15:1)_<>_n-5 | FA(15:2)_<F>_n-5 | FA(15:3)_<FF>_n-5 | FA(15:4)_<FFF>_n-5 | FA(15:5)_<FFFF>_n-5 | FA(16:1)_<>_n-6 | FA(16:2)_<F>_n-6 | FA(16:3)_<FF>_n-6 | FA(16:4)_<FFF>_n-6 | FA(16:5)_<FFFF>_n-6 | FA(16:6)_<FFFFF>_n-6 | FA(17:1)_<>_n-7 | FA(17:2)_<F>_n-7 | FA(17:3)_<FF>_n-7 | FA(17:4)_<FFF>_n-7 | FA(17:5)_<FFFF>_n-7 | FA(17:6)_<FFFFF>_n-7 | FA(18:1)_<>_n-8 | FA(18:2)_<F>_n-8 | FA(18:3)_<FF>_n-8 | FA(18:4)_<FFF>_n-8 | FA(18:5)_<FFFF>_n-8 | FA(18:6)_<FFFFF>_n-8 | FA(19:1)_<>_n-9 | FA(19:2)_<F>_n-9 | FA(19:3)_<FF>_n-9 | FA(19:4)_<FFF>_n-9 | FA(19:5)_<FFFF>_n-9 | FA(19:6)_<FFFFF>_n-9 | FA(20:1)_<>_n-10 | FA(20:2)_<F>_n-10 | FA(20:3)_<FF>_n-10 | FA(20:4)_<FFF>_n-10 | FA(20:5)_<FFFF>_n-10 | FA(20:6)_<FFFFF>_n-10 | FA(21:1)_<>_n-11 | FA(21:2)_<F>_n-11 | FA(21:3)_<FF>_n-11 | FA(21:4)_<FFF>_n-11 | FA(21:5)_<FFFF>_n-11 | FA(21:6)_<FFFFF>_n-11 | FA(22:1)_<>_n-12 | FA(22:2)_<F>_n-12 | FA(22:3)_<FF>_n-12 | FA(22:4)_<FFF>_n-12 | FA(22:5)_<FFFF>_n-12 | FA(22:6)_<FFFFF>_n-12 | FA(23:1)_<>_n-13 | FA(23:2)_<F>_n-13 | FA(23:3)_<FF>_n-13 | FA(23:4)_<FFF>_n-13 | FA(23:5)_<FFFF>_n-13 | FA(23:6)_<FFFFF>_n-13 | FA(24:1)_<>_n-14 | FA(24:2)_<F>_n-14 | FA(24:3)_<FF>_n-14 | FA(24:4)_<FFF>_n-14 | FA(24:5)_<FFFF>_n-14 | FA(24:6)_<FFFFF>_n-14 | FA(25:1)_<>_n-15 | FA(25:2)_<F>_n-15 | FA(25:3)_<FF>_n-15 | FA(25:4)_<FFF>_n-15 | FA(25:5)_<FFFF>_n-15 | FA(25:6)_<FFFFF>_n-15 | FA(26:1)_<>_n-16 | FA(26:2)_<F>_n-16 | FA(26:3)_<FF>_n-16 | FA(26:4)_<FFF>_n-16 | FA(26:5)_<FFFF>_n-16 | FA(26:6)_<FFFFF>_n-16 | FA(27:1)_<>_n-17 | FA(27:2)_<F>_n-17 | FA(27:3)_<FF>_n-17 | FA(27:4)_<FFF>_n-17 | FA(27:5)_<FFFF>_n-17 | FA(27:6)_<FFFFF>_n-17 | FA(28:1)_<>_n-18 | FA(28:2)_<F>_n-18 | FA(28:3)_<FF>_n-18 | FA(28:4)_<FFF>_n-18 | FA(28:5)_<FFFF>_n-18 | FA(28:6)_<FFFFF>_n-18 | FA(29:1)_<>_n-19 | FA(29:2)_<F>_n-19 | FA(29:3)_<FF>_n-19 | FA(29:4)_<FFF>_n-19 | FA(29:5)_<FFFF>_n-19 | FA(29:6)_<FFFFF>_n-19 | FA(30:1)_<>_n-20 | FA(30:2)_<F>_n-20 | FA(30:3)_<FF>_n-20 | FA(30:4)_<FFF>_n-20 | FA(30:5)_<FFFF>_n-20 | FA(30:6)_<FFFFF>_n-20'
#  'FA(13:3)_<BB>_n-2 | FA(13:4)_<BBF>_n-2 | FA(14:3)_<BB>_n-3 | FA(14:4)_<BBF>_n-3 | FA(14:5)_<BBFF>_n-3 | FA(15:3)_<BB>_n-4 | FA(15:4)_<BBF>_n-4 | FA(15:5)_<BBFF>_n-4 | FA(15:6)_<BBFFF>_n-4 | FA(16:3)_<BB>_n-5 | FA(16:4)_<BBF>_n-5 | FA(16:5)_<BBFF>_n-5 | FA(16:6)_<BBFFF>_n-5 | FA(17:3)_<BB>_n-6 | FA(17:4)_<BBF>_n-6 | FA(17:5)_<BBFF>_n-6 | FA(17:6)_<BBFFF>_n-6 | FA(18:3)_<BB>_n-7 | FA(18:4)_<BBF>_n-7 | FA(18:5)_<BBFF>_n-7 | FA(18:6)_<BBFFF>_n-7 | FA(19:3)_<BB>_n-8 | FA(19:4)_<BBF>_n-8 | FA(19:5)_<BBFF>_n-8 | FA(19:6)_<BBFFF>_n-8 | FA(20:3)_<BB>_n-9 | FA(20:4)_<BBF>_n-9 | FA(20:5)_<BBFF>_n-9 | FA(20:6)_<BBFFF>_n-9 | FA(21:3)_<BB>_n-10 | FA(21:4)_<BBF>_n-10 | FA(21:5)_<BBFF>_n-10 | FA(21:6)_<BBFFF>_n-10 | FA(22:3)_<BB>_n-11 | FA(22:4)_<BBF>_n-11 | FA(22:5)_<BBFF>_n-11 | FA(22:6)_<BBFFF>_n-11 | FA(23:3)_<BB>_n-12 | FA(23:4)_<BBF>_n-12 | FA(23:5)_<BBFF>_n-12 | FA(23:6)_<BBFFF>_n-12 | FA(24:3)_<BB>_n-13 | FA(24:4)_<BBF>_n-13 | FA(24:5)_<BBFF>_n-13 | FA(24:6)_<BBFFF>_n-13 | FA(25:3)_<BB>_n-14 | FA(25:4)_<BBF>_n-14 | FA(25:5)_<BBFF>_n-14 | FA(25:6)_<BBFFF>_n-14 | FA(26:3)_<BB>_n-15 | FA(26:4)_<BBF>_n-15 | FA(26:5)_<BBFF>_n-15 | FA(26:6)_<BBFFF>_n-15 | FA(27:3)_<BB>_n-16 | FA(27:4)_<BBF>_n-16 | FA(27:5)_<BBFF>_n-16 | FA(27:6)_<BBFFF>_n-16 | FA(28:3)_<BB>_n-17 | FA(28:4)_<BBF>_n-17 | FA(28:5)_<BBFF>_n-17 | FA(28:6)_<BBFFF>_n-17 | FA(29:3)_<BB>_n-18 | FA(29:4)_<BBF>_n-18 | FA(29:5)_<BBFF>_n-18 | FA(29:6)_<BBFFF>_n-18 | FA(30:3)_<BB>_n-19 | FA(30:4)_<BBF>_n-19 | FA(30:5)_<BBFF>_n-19 | FA(30:6)_<BBFFF>_n-19'
#  'FA(13:2)_<B>_n-2 | FA(13:3)_<BF>_n-2 | FA(14:2)_<B>_n-3 | FA(14:3)_<BF>_n-3 | FA(14:4)_<BFF>_n-3 | FA(15:2)_<B>_n-4 | FA(15:3)_<BF>_n-4 | FA(15:4)_<BFF>_n-4 | FA(15:5)_<BFFF>_n-4 | FA(16:2)_<B>_n-5 | FA(16:3)_<BF>_n-5 | FA(16:4)_<BFF>_n-5 | FA(16:5)_<BFFF>_n-5 | FA(16:6)_<BFFFF>_n-5 | FA(17:2)_<B>_n-6 | FA(17:3)_<BF>_n-6 | FA(17:4)_<BFF>_n-6 | FA(17:5)_<BFFF>_n-6 | FA(17:6)_<BFFFF>_n-6 | FA(18:2)_<B>_n-7 | FA(18:3)_<BF>_n-7 | FA(18:4)_<BFF>_n-7 | FA(18:5)_<BFFF>_n-7 | FA(18:6)_<BFFFF>_n-7 | FA(19:2)_<B>_n-8 | FA(19:3)_<BF>_n-8 | FA(19:4)_<BFF>_n-8 | FA(19:5)_<BFFF>_n-8 | FA(19:6)_<BFFFF>_n-8 | FA(20:2)_<B>_n-9 | FA(20:3)_<BF>_n-9 | FA(20:4)_<BFF>_n-9 | FA(20:5)_<BFFF>_n-9 | FA(20:6)_<BFFFF>_n-9 | FA(21:2)_<B>_n-10 | FA(21:3)_<BF>_n-10 | FA(21:4)_<BFF>_n-10 | FA(21:5)_<BFFF>_n-10 | FA(21:6)_<BFFFF>_n-10 | FA(22:2)_<B>_n-11 | FA(22:3)_<BF>_n-11 | FA(22:4)_<BFF>_n-11 | FA(22:5)_<BFFF>_n-11 | FA(22:6)_<BFFFF>_n-11 | FA(23:2)_<B>_n-12 | FA(23:3)_<BF>_n-12 | FA(23:4)_<BFF>_n-12 | FA(23:5)_<BFFF>_n-12 | FA(23:6)_<BFFFF>_n-12 | FA(24:2)_<B>_n-13 | FA(24:3)_<BF>_n-13 | FA(24:4)_<BFF>_n-13 | FA(24:5)_<BFFF>_n-13 | FA(24:6)_<BFFFF>_n-13 | FA(25:2)_<B>_n-14 | FA(25:3)_<BF>_n-14 | FA(25:4)_<BFF>_n-14 | FA(25:5)_<BFFF>_n-14 | FA(25:6)_<BFFFF>_n-14 | FA(26:2)_<B>_n-15 | FA(26:3)_<BF>_n-15 | FA(26:4)_<BFF>_n-15 | FA(26:5)_<BFFF>_n-15 | FA(26:6)_<BFFFF>_n-15 | FA(27:2)_<B>_n-16 | FA(27:3)_<BF>_n-16 | FA(27:4)_<BFF>_n-16 | FA(27:5)_<BFFF>_n-16 | FA(27:6)_<BFFFF>_n-16'
#  'FA(12:0) | FA(13:1)_<>_n-2 | FA(13:2)_<F>_n-2 | FA(14:1)_<>_n-3 | FA(14:2)_<F>_n-3 | FA(14:3)_<FF>_n-3 | FA(15:1)_<>_n-4 | FA(15:2)_<F>_n-4 | FA(15:3)_<FF>_n-4 | FA(15:4)_<FFF>_n-4 | FA(16:1)_<>_n-5 | FA(16:2)_<F>_n-5 | FA(16:3)_<FF>_n-5 | FA(16:4)_<FFF>_n-5 | FA(16:5)_<FFFF>_n-5 | FA(17:1)_<>_n-6 | FA(17:2)_<F>_n-6 | FA(17:3)_<FF>_n-6 | FA(17:4)_<FFF>_n-6 | FA(17:5)_<FFFF>_n-6 | FA(17:6)_<FFFFF>_n-6 | FA(18:1)_<>_n-7 | FA(18:2)_<F>_n-7 | FA(18:3)_<FF>_n-7 | FA(18:4)_<FFF>_n-7 | FA(18:5)_<FFFF>_n-7 | FA(18:6)_<FFFFF>_n-7 | FA(19:1)_<>_n-8 | FA(19:2)_<F>_n-8 | FA(19:3)_<FF>_n-8 | FA(19:4)_<FFF>_n-8 | FA(19:5)_<FFFF>_n-8 | FA(19:6)_<FFFFF>_n-8 | FA(20:1)_<>_n-9 | FA(20:2)_<F>_n-9 | FA(20:3)_<FF>_n-9 | FA(20:4)_<FFF>_n-9 | FA(20:5)_<FFFF>_n-9 | FA(20:6)_<FFFFF>_n-9 | FA(21:1)_<>_n-10 | FA(21:2)_<F>_n-10 | FA(21:3)_<FF>_n-10 | FA(21:4)_<FFF>_n-10 | FA(21:5)_<FFFF>_n-10 | FA(21:6)_<FFFFF>_n-10 | FA(22:1)_<>_n-11 | FA(22:2)_<F>_n-11 | FA(22:3)_<FF>_n-11 | FA(22:4)_<FFF>_n-11 | FA(22:5)_<FFFF>_n-11 | FA(22:6)_<FFFFF>_n-11 | FA(23:1)_<>_n-12 | FA(23:2)_<F>_n-12 | FA(23:3)_<FF>_n-12 | FA(23:4)_<FFF>_n-12 | FA(23:5)_<FFFF>_n-12 | FA(23:6)_<FFFFF>_n-12 | FA(24:1)_<>_n-13 | FA(24:2)_<F>_n-13 | FA(24:3)_<FF>_n-13 | FA(24:4)_<FFF>_n-13 | FA(24:5)_<FFFF>_n-13 | FA(24:6)_<FFFFF>_n-13 | FA(25:1)_<>_n-14 | FA(25:2)_<F>_n-14 | FA(25:3)_<FF>_n-14 | FA(25:4)_<FFF>_n-14 | FA(25:5)_<FFFF>_n-14 | FA(25:6)_<FFFFF>_n-14 | FA(26:1)_<>_n-15 | FA(26:2)_<F>_n-15 | FA(26:3)_<FF>_n-15 | FA(26:4)_<FFF>_n-15 | FA(26:5)_<FFFF>_n-15 | FA(26:6)_<FFFFF>_n-15 | FA(27:1)_<>_n-16 | FA(27:2)_<F>_n-16 | FA(27:3)_<FF>_n-16 | FA(27:4)_<FFF>_n-16 | FA(27:5)_<FFFF>_n-16 | FA(27:6)_<FFFFF>_n-16 | FA(28:1)_<>_n-17 | FA(28:2)_<F>_n-17 | FA(28:3)_<FF>_n-17 | FA(28:4)_<FFF>_n-17 | FA(28:5)_<FFFF>_n-17 | FA(28:6)_<FFFFF>_n-17 | FA(29:1)_<>_n-18 | FA(29:2)_<F>_n-18 | FA(29:3)_<FF>_n-18 | FA(29:4)_<FFF>_n-18 | FA(29:5)_<FFFF>_n-18 | FA(29:6)_<FFFFF>_n-18 | FA(30:1)_<>_n-19 | FA(30:2)_<F>_n-19 | FA(30:3)_<FF>_n-19 | FA(30:4)_<FFF>_n-19 | FA(30:5)_<FFFF>_n-19 | FA(30:6)_<FFFFF>_n-19'
#  'FA(14:3)_<BB>_n-2 | FA(14:4)_<BBF>_n-2 | FA(15:3)_<BB>_n-3 | FA(15:4)_<BBF>_n-3 | FA(15:5)_<BBFF>_n-3 | FA(16:3)_<BB>_n-4 | FA(16:4)_<BBF>_n-4 | FA(16:5)_<BBFF>_n-4 | FA(16:6)_<BBFFF>_n-4 | FA(17:3)_<BB>_n-5 | FA(17:4)_<BBF>_n-5 | FA(17:5)_<BBFF>_n-5 | FA(17:6)_<BBFFF>_n-5 | FA(18:3)_<BB>_n-6 | FA(18:4)_<BBF>_n-6 | FA(18:5)_<BBFF>_n-6 | FA(18:6)_<BBFFF>_n-6 | FA(19:3)_<BB>_n-7 | FA(19:4)_<BBF>_n-7 | FA(19:5)_<BBFF>_n-7 | FA(19:6)_<BBFFF>_n-7 | FA(20:3)_<BB>_n-8 | FA(20:4)_<BBF>_n-8 | FA(20:5)_<BBFF>_n-8 | FA(20:6)_<BBFFF>_n-8 | FA(21:3)_<BB>_n-9 | FA(21:4)_<BBF>_n-9 | FA(21:5)_<BBFF>_n-9 | FA(21:6)_<BBFFF>_n-9 | FA(22:3)_<BB>_n-10 | FA(22:4)_<BBF>_n-10 | FA(22:5)_<BBFF>_n-10 | FA(22:6)_<BBFFF>_n-10 | FA(23:3)_<BB>_n-11 | FA(23:4)_<BBF>_n-11 | FA(23:5)_<BBFF>_n-11 | FA(23:6)_<BBFFF>_n-11 | FA(24:3)_<BB>_n-12 | FA(24:4)_<BBF>_n-12 | FA(24:5)_<BBFF>_n-12 | FA(24:6)_<BBFFF>_n-12 | FA(25:3)_<BB>_n-13 | FA(25:4)_<BBF>_n-13 | FA(25:5)_<BBFF>_n-13 | FA(25:6)_<BBFFF>_n-13 | FA(26:3)_<BB>_n-14 | FA(26:4)_<BBF>_n-14 | FA(26:5)_<BBFF>_n-14 | FA(26:6)_<BBFFF>_n-14 | FA(27:3)_<BB>_n-15 | FA(27:4)_<BBF>_n-15 | FA(27:5)_<BBFF>_n-15 | FA(27:6)_<BBFFF>_n-15'
#  'FA(14:2)_<B>_n-2 | FA(14:3)_<BF>_n-2 | FA(15:2)_<B>_n-3 | FA(15:3)_<BF>_n-3 | FA(15:4)_<BFF>_n-3 | FA(16:2)_<B>_n-4 | FA(16:3)_<BF>_n-4 | FA(16:4)_<BFF>_n-4 | FA(16:5)_<BFFF>_n-4 | FA(17:2)_<B>_n-5 | FA(17:3)_<BF>_n-5 | FA(17:4)_<BFF>_n-5 | FA(17:5)_<BFFF>_n-5 | FA(17:6)_<BFFFF>_n-5 | FA(18:2)_<B>_n-6 | FA(18:3)_<BF>_n-6 | FA(18:4)_<BFF>_n-6 | FA(18:5)_<BFFF>_n-6 | FA(18:6)_<BFFFF>_n-6 | FA(19:2)_<B>_n-7 | FA(19:3)_<BF>_n-7 | FA(19:4)_<BFF>_n-7 | FA(19:5)_<BFFF>_n-7 | FA(19:6)_<BFFFF>_n-7 | FA(20:2)_<B>_n-8 | FA(20:3)_<BF>_n-8 | FA(20:4)_<BFF>_n-8 | FA(20:5)_<BFFF>_n-8 | FA(20:6)_<BFFFF>_n-8 | FA(21:2)_<B>_n-9 | FA(21:3)_<BF>_n-9 | FA(21:4)_<BFF>_n-9 | FA(21:5)_<BFFF>_n-9 | FA(21:6)_<BFFFF>_n-9 | FA(22:2)_<B>_n-10 | FA(22:3)_<BF>_n-10 | FA(22:4)_<BFF>_n-10 | FA(22:5)_<BFFF>_n-10 | FA(22:6)_<BFFFF>_n-10 | FA(23:2)_<B>_n-11 | FA(23:3)_<BF>_n-11 | FA(23:4)_<BFF>_n-11 | FA(23:5)_<BFFF>_n-11 | FA(23:6)_<BFFFF>_n-11 | FA(24:2)_<B>_n-12 | FA(24:3)_<BF>_n-12 | FA(24:4)_<BFF>_n-12 | FA(24:5)_<BFFF>_n-12 | FA(24:6)_<BFFFF>_n-12 | FA(25:2)_<B>_n-13 | FA(25:3)_<BF>_n-13 | FA(25:4)_<BFF>_n-13 | FA(25:5)_<BFFF>_n-13 | FA(25:6)_<BFFFF>_n-13 | FA(26:2)_<B>_n-14 | FA(26:3)_<BF>_n-14 | FA(26:4)_<BFF>_n-14 | FA(26:5)_<BFFF>_n-14 | FA(26:6)_<BFFFF>_n-14 | FA(27:2)_<B>_n-15 | FA(27:3)_<BF>_n-15 | FA(27:4)_<BFF>_n-15 | FA(27:5)_<BFFF>_n-15 | FA(27:6)_<BFFFF>_n-15 | FA(28:2)_<B>_n-16 | FA(28:3)_<BF>_n-16 | FA(28:4)_<BFF>_n-16 | FA(28:5)_<BFFF>_n-16 | FA(28:6)_<BFFFF>_n-16 | FA(29:2)_<B>_n-17 | FA(29:3)_<BF>_n-17 | FA(29:4)_<BFF>_n-17 | FA(29:5)_<BFFF>_n-17 | FA(29:6)_<BFFFF>_n-17 | FA(30:2)_<B>_n-18 | FA(30:3)_<BF>_n-18 | FA(30:4)_<BFF>_n-18 | FA(30:5)_<BFFF>_n-18 | FA(30:6)_<BFFFF>_n-18'
#  'FA(13:0) | FA(14:1)_<>_n-2 | FA(14:2)_<F>_n-2 | FA(15:1)_<>_n-3 | FA(15:2)_<F>_n-3 | FA(15:3)_<FF>_n-3 | FA(16:1)_<>_n-4 | FA(16:2)_<F>_n-4 | FA(16:3)_<FF>_n-4 | FA(16:4)_<FFF>_n-4 | FA(17:1)_<>_n-5 | FA(17:2)_<F>_n-5 | FA(17:3)_<FF>_n-5 | FA(17:4)_<FFF>_n-5 | FA(17:5)_<FFFF>_n-5 | FA(18:1)_<>_n-6 | FA(18:2)_<F>_n-6 | FA(18:3)_<FF>_n-6 | FA(18:4)_<FFF>_n-6 | FA(18:5)_<FFFF>_n-6 | FA(18:6)_<FFFFF>_n-6 | FA(19:1)_<>_n-7 | FA(19:2)_<F>_n-7 | FA(19:3)_<FF>_n-7 | FA(19:4)_<FFF>_n-7 | FA(19:5)_<FFFF>_n-7 | FA(19:6)_<FFFFF>_n-7 | FA(20:1)_<>_n-8 | FA(20:2)_<F>_n-8 | FA(20:3)_<FF>_n-8 | FA(20:4)_<FFF>_n-8 | FA(20:5)_<FFFF>_n-8 | FA(20:6)_<FFFFF>_n-8 | FA(21:1)_<>_n-9 | FA(21:2)_<F>_n-9 | FA(21:3)_<FF>_n-9 | FA(21:4)_<FFF>_n-9 | FA(21:5)_<FFFF>_n-9 | FA(21:6)_<FFFFF>_n-9 | FA(22:1)_<>_n-10 | FA(22:2)_<F>_n-10 | FA(22:3)_<FF>_n-10 | FA(22:4)_<FFF>_n-10 | FA(22:5)_<FFFF>_n-10 | FA(22:6)_<FFFFF>_n-10 | FA(23:1)_<>_n-11 | FA(23:2)_<F>_n-11 | FA(23:3)_<FF>_n-11 | FA(23:4)_<FFF>_n-11 | FA(23:5)_<FFFF>_n-11 | FA(23:6)_<FFFFF>_n-11 | FA(24:1)_<>_n-12 | FA(24:2)_<F>_n-12 | FA(24:3)_<FF>_n-12 | FA(24:4)_<FFF>_n-12 | FA(24:5)_<FFFF>_n-12 | FA(24:6)_<FFFFF>_n-12 | FA(25:1)_<>_n-13 | FA(25:2)_<F>_n-13 | FA(25:3)_<FF>_n-13 | FA(25:4)_<FFF>_n-13 | FA(25:5)_<FFFF>_n-13 | FA(25:6)_<FFFFF>_n-13 | FA(26:1)_<>_n-14 | FA(26:2)_<F>_n-14 | FA(26:3)_<FF>_n-14 | FA(26:4)_<FFF>_n-14 | FA(26:5)_<FFFF>_n-14 | FA(26:6)_<FFFFF>_n-14 | FA(27:1)_<>_n-15 | FA(27:2)_<F>_n-15 | FA(27:3)_<FF>_n-15 | FA(27:4)_<FFF>_n-15 | FA(27:5)_<FFFF>_n-15 | FA(27:6)_<FFFFF>_n-15 | FA(28:1)_<>_n-16 | FA(28:2)_<F>_n-16 | FA(28:3)_<FF>_n-16 | FA(28:4)_<FFF>_n-16 | FA(28:5)_<FFFF>_n-16 | FA(28:6)_<FFFFF>_n-16 | FA(29:1)_<>_n-17 | FA(29:2)_<F>_n-17 | FA(29:3)_<FF>_n-17 | FA(29:4)_<FFF>_n-17 | FA(29:5)_<FFFF>_n-17 | FA(29:6)_<FFFFF>_n-17 | FA(30:1)_<>_n-18 | FA(30:2)_<F>_n-18 | FA(30:3)_<FF>_n-18 | FA(30:4)_<FFF>_n-18 | FA(30:5)_<FFFF>_n-18 | FA(30:6)_<FFFFF>_n-18'
#  'FA(15:4)_<BBB>_n-2 | FA(15:5)_<BBBF>_n-2 | FA(16:4)_<BBB>_n-3 | FA(16:5)_<BBBF>_n-3 | FA(16:6)_<BBBFF>_n-3 | FA(17:4)_<BBB>_n-4 | FA(17:5)_<BBBF>_n-4 | FA(17:6)_<BBBFF>_n-4 | FA(18:4)_<BBB>_n-5 | FA(18:5)_<BBBF>_n-5 | FA(18:6)_<BBBFF>_n-5 | FA(19:4)_<BBB>_n-6 | FA(19:5)_<BBBF>_n-6 | FA(19:6)_<BBBFF>_n-6 | FA(20:4)_<BBB>_n-7 | FA(20:5)_<BBBF>_n-7 | FA(20:6)_<BBBFF>_n-7 | FA(21:4)_<BBB>_n-8 | FA(21:5)_<BBBF>_n-8 | FA(21:6)_<BBBFF>_n-8 | FA(22:4)_<BBB>_n-9 | FA(22:5)_<BBBF>_n-9 | FA(22:6)_<BBBFF>_n-9 | FA(23:4)_<BBB>_n-10 | FA(23:5)_<BBBF>_n-10 | FA(23:6)_<BBBFF>_n-10 | FA(24:4)_<BBB>_n-11 | FA(24:5)_<BBBF>_n-11 | FA(24:6)_<BBBFF>_n-11 | FA(25:4)_<BBB>_n-12 | FA(25:5)_<BBBF>_n-12 | FA(25:6)_<BBBFF>_n-12 | FA(26:4)_<BBB>_n-13 | FA(26:5)_<BBBF>_n-13 | FA(26:6)_<BBBFF>_n-13 | FA(27:4)_<BBB>_n-14 | FA(27:5)_<BBBF>_n-14 | FA(27:6)_<BBBFF>_n-14 | FA(28:4)_<BBB>_n-15 | FA(28:5)_<BBBF>_n-15 | FA(28:6)_<BBBFF>_n-15 | FA(29:4)_<BBB>_n-16 | FA(29:5)_<BBBF>_n-16 | FA(29:6)_<BBBFF>_n-16 | FA(30:4)_<BBB>_n-17 | FA(30:5)_<BBBF>_n-17 | FA(30:6)_<BBBFF>_n-17'
#  'FA(15:2)_<B>_n-2 | FA(15:3)_<BF>_n-2 | FA(16:2)_<B>_n-3 | FA(16:3)_<BF>_n-3 | FA(16:4)_<BFF>_n-3 | FA(17:2)_<B>_n-4 | FA(17:3)_<BF>_n-4 | FA(17:4)_<BFF>_n-4 | FA(17:5)_<BFFF>_n-4 | FA(18:2)_<B>_n-5 | FA(18:3)_<BF>_n-5 | FA(18:4)_<BFF>_n-5 | FA(18:5)_<BFFF>_n-5 | FA(18:6)_<BFFFF>_n-5 | FA(19:2)_<B>_n-6 | FA(19:3)_<BF>_n-6 | FA(19:4)_<BFF>_n-6 | FA(19:5)_<BFFF>_n-6 | FA(19:6)_<BFFFF>_n-6 | FA(20:2)_<B>_n-7 | FA(20:3)_<BF>_n-7 | FA(20:4)_<BFF>_n-7 | FA(20:5)_<BFFF>_n-7 | FA(20:6)_<BFFFF>_n-7 | FA(21:2)_<B>_n-8 | FA(21:3)_<BF>_n-8 | FA(21:4)_<BFF>_n-8 | FA(21:5)_<BFFF>_n-8 | FA(21:6)_<BFFFF>_n-8 | FA(22:2)_<B>_n-9 | FA(22:3)_<BF>_n-9 | FA(22:4)_<BFF>_n-9 | FA(22:5)_<BFFF>_n-9 | FA(22:6)_<BFFFF>_n-9 | FA(23:2)_<B>_n-10 | FA(23:3)_<BF>_n-10 | FA(23:4)_<BFF>_n-10 | FA(23:5)_<BFFF>_n-10 | FA(23:6)_<BFFFF>_n-10 | FA(24:2)_<B>_n-11 | FA(24:3)_<BF>_n-11 | FA(24:4)_<BFF>_n-11 | FA(24:5)_<BFFF>_n-11 | FA(24:6)_<BFFFF>_n-11 | FA(25:2)_<B>_n-12 | FA(25:3)_<BF>_n-12 | FA(25:4)_<BFF>_n-12 | FA(25:5)_<BFFF>_n-12 | FA(25:6)_<BFFFF>_n-12 | FA(26:2)_<B>_n-13 | FA(26:3)_<BF>_n-13 | FA(26:4)_<BFF>_n-13 | FA(26:5)_<BFFF>_n-13 | FA(26:6)_<BFFFF>_n-13 | FA(27:2)_<B>_n-14 | FA(27:3)_<BF>_n-14 | FA(27:4)_<BFF>_n-14 | FA(27:5)_<BFFF>_n-14 | FA(27:6)_<BFFFF>_n-14 | FA(28:2)_<B>_n-15 | FA(28:3)_<BF>_n-15 | FA(28:4)_<BFF>_n-15 | FA(28:5)_<BFFF>_n-15 | FA(28:6)_<BFFFF>_n-15 | FA(29:2)_<B>_n-16 | FA(29:3)_<BF>_n-16 | FA(29:4)_<BFF>_n-16 | FA(29:5)_<BFFF>_n-16 | FA(29:6)_<BFFFF>_n-16 | FA(30:2)_<B>_n-17 | FA(30:3)_<BF>_n-17 | FA(30:4)_<BFF>_n-17 | FA(30:5)_<BFFF>_n-17 | FA(30:6)_<BFFFF>_n-17'
#  'FA(14:0) | FA(15:1)_<>_n-2 | FA(15:2)_<F>_n-2 | FA(16:1)_<>_n-3 | FA(16:2)_<F>_n-3 | FA(16:3)_<FF>_n-3 | FA(17:1)_<>_n-4 | FA(17:2)_<F>_n-4 | FA(17:3)_<FF>_n-4 | FA(17:4)_<FFF>_n-4 | FA(18:1)_<>_n-5 | FA(18:2)_<F>_n-5 | FA(18:3)_<FF>_n-5 | FA(18:4)_<FFF>_n-5 | FA(18:5)_<FFFF>_n-5 | FA(19:1)_<>_n-6 | FA(19:2)_<F>_n-6 | FA(19:3)_<FF>_n-6 | FA(19:4)_<FFF>_n-6 | FA(19:5)_<FFFF>_n-6 | FA(19:6)_<FFFFF>_n-6 | FA(20:1)_<>_n-7 | FA(20:2)_<F>_n-7 | FA(20:3)_<FF>_n-7 | FA(20:4)_<FFF>_n-7 | FA(20:5)_<FFFF>_n-7 | FA(20:6)_<FFFFF>_n-7 | FA(21:1)_<>_n-8 | FA(21:2)_<F>_n-8 | FA(21:3)_<FF>_n-8 | FA(21:4)_<FFF>_n-8 | FA(21:5)_<FFFF>_n-8 | FA(21:6)_<FFFFF>_n-8 | FA(22:1)_<>_n-9 | FA(22:2)_<F>_n-9 | FA(22:3)_<FF>_n-9 | FA(22:4)_<FFF>_n-9 | FA(22:5)_<FFFF>_n-9 | FA(22:6)_<FFFFF>_n-9 | FA(23:1)_<>_n-10 | FA(23:2)_<F>_n-10 | FA(23:3)_<FF>_n-10 | FA(23:4)_<FFF>_n-10 | FA(23:5)_<FFFF>_n-10 | FA(23:6)_<FFFFF>_n-10 | FA(24:1)_<>_n-11 | FA(24:2)_<F>_n-11 | FA(24:3)_<FF>_n-11 | FA(24:4)_<FFF>_n-11 | FA(24:5)_<FFFF>_n-11 | FA(24:6)_<FFFFF>_n-11 | FA(25:1)_<>_n-12 | FA(25:2)_<F>_n-12 | FA(25:3)_<FF>_n-12 | FA(25:4)_<FFF>_n-12 | FA(25:5)_<FFFF>_n-12 | FA(25:6)_<FFFFF>_n-12 | FA(26:1)_<>_n-13 | FA(26:2)_<F>_n-13 | FA(26:3)_<FF>_n-13 | FA(26:4)_<FFF>_n-13 | FA(26:5)_<FFFF>_n-13 | FA(26:6)_<FFFFF>_n-13 | FA(27:1)_<>_n-14 | FA(27:2)_<F>_n-14 | FA(27:3)_<FF>_n-14 | FA(27:4)_<FFF>_n-14 | FA(27:5)_<FFFF>_n-14 | FA(27:6)_<FFFFF>_n-14 | FA(28:1)_<>_n-15 | FA(28:2)_<F>_n-15 | FA(28:3)_<FF>_n-15 | FA(28:4)_<FFF>_n-15 | FA(28:5)_<FFFF>_n-15 | FA(28:6)_<FFFFF>_n-15 | FA(29:1)_<>_n-16 | FA(29:2)_<F>_n-16 | FA(29:3)_<FF>_n-16 | FA(29:4)_<FFF>_n-16 | FA(29:5)_<FFFF>_n-16 | FA(29:6)_<FFFFF>_n-16 | FA(30:1)_<>_n-17 | FA(30:2)_<F>_n-17 | FA(30:3)_<FF>_n-17 | FA(30:4)_<FFF>_n-17 | FA(30:5)_<FFFF>_n-17 | FA(30:6)_<FFFFF>_n-17'
#  'FA(16:4)_<BBB>_n-2 | FA(16:5)_<BBBF>_n-2 | FA(17:4)_<BBB>_n-3 | FA(17:5)_<BBBF>_n-3 | FA(17:6)_<BBBFF>_n-3 | FA(18:4)_<BBB>_n-4 | FA(18:5)_<BBBF>_n-4 | FA(18:6)_<BBBFF>_n-4 | FA(19:4)_<BBB>_n-5 | FA(19:5)_<BBBF>_n-5 | FA(19:6)_<BBBFF>_n-5 | FA(20:4)_<BBB>_n-6 | FA(20:5)_<BBBF>_n-6 | FA(20:6)_<BBBFF>_n-6 | FA(21:4)_<BBB>_n-7 | FA(21:5)_<BBBF>_n-7 | FA(21:6)_<BBBFF>_n-7 | FA(22:4)_<BBB>_n-8 | FA(22:5)_<BBBF>_n-8 | FA(22:6)_<BBBFF>_n-8 | FA(23:4)_<BBB>_n-9 | FA(23:5)_<BBBF>_n-9 | FA(23:6)_<BBBFF>_n-9 | FA(24:4)_<BBB>_n-10 | FA(24:5)_<BBBF>_n-10 | FA(24:6)_<BBBFF>_n-10 | FA(25:4)_<BBB>_n-11 | FA(25:5)_<BBBF>_n-11 | FA(25:6)_<BBBFF>_n-11 | FA(26:4)_<BBB>_n-12 | FA(26:5)_<BBBF>_n-12 | FA(26:6)_<BBBFF>_n-12 | FA(27:4)_<BBB>_n-13 | FA(27:5)_<BBBF>_n-13 | FA(27:6)_<BBBFF>_n-13'
#  'FA(16:3)_<BB>_n-2 | FA(16:4)_<BBF>_n-2 | FA(17:3)_<BB>_n-3 | FA(17:4)_<BBF>_n-3 | FA(17:5)_<BBFF>_n-3 | FA(18:3)_<BB>_n-4 | FA(18:4)_<BBF>_n-4 | FA(18:5)_<BBFF>_n-4 | FA(18:6)_<BBFFF>_n-4 | FA(19:3)_<BB>_n-5 | FA(19:4)_<BBF>_n-5 | FA(19:5)_<BBFF>_n-5 | FA(19:6)_<BBFFF>_n-5 | FA(20:3)_<BB>_n-6 | FA(20:4)_<BBF>_n-6 | FA(20:5)_<BBFF>_n-6 | FA(20:6)_<BBFFF>_n-6 | FA(21:3)_<BB>_n-7 | FA(21:4)_<BBF>_n-7 | FA(21:5)_<BBFF>_n-7 | FA(21:6)_<BBFFF>_n-7 | FA(22:3)_<BB>_n-8 | FA(22:4)_<BBF>_n-8 | FA(22:5)_<BBFF>_n-8 | FA(22:6)_<BBFFF>_n-8 | FA(23:3)_<BB>_n-9 | FA(23:4)_<BBF>_n-9 | FA(23:5)_<BBFF>_n-9 | FA(23:6)_<BBFFF>_n-9 | FA(24:3)_<BB>_n-10 | FA(24:4)_<BBF>_n-10 | FA(24:5)_<BBFF>_n-10 | FA(24:6)_<BBFFF>_n-10 | FA(25:3)_<BB>_n-11 | FA(25:4)_<BBF>_n-11 | FA(25:5)_<BBFF>_n-11 | FA(25:6)_<BBFFF>_n-11 | FA(26:3)_<BB>_n-12 | FA(26:4)_<BBF>_n-12 | FA(26:5)_<BBFF>_n-12 | FA(26:6)_<BBFFF>_n-12 | FA(27:3)_<BB>_n-13 | FA(27:4)_<BBF>_n-13 | FA(27:5)_<BBFF>_n-13 | FA(27:6)_<BBFFF>_n-13'
#  'FA(16:2)_<B>_n-2 | FA(16:3)_<BF>_n-2 | FA(17:2)_<B>_n-3 | FA(17:3)_<BF>_n-3 | FA(17:4)_<BFF>_n-3 | FA(18:2)_<B>_n-4 | FA(18:3)_<BF>_n-4 | FA(18:4)_<BFF>_n-4 | FA(18:5)_<BFFF>_n-4 | FA(19:2)_<B>_n-5 | FA(19:3)_<BF>_n-5 | FA(19:4)_<BFF>_n-5 | FA(19:5)_<BFFF>_n-5 | FA(19:6)_<BFFFF>_n-5 | FA(20:2)_<B>_n-6 | FA(20:3)_<BF>_n-6 | FA(20:4)_<BFF>_n-6 | FA(20:5)_<BFFF>_n-6 | FA(20:6)_<BFFFF>_n-6 | FA(21:2)_<B>_n-7 | FA(21:3)_<BF>_n-7 | FA(21:4)_<BFF>_n-7 | FA(21:5)_<BFFF>_n-7 | FA(21:6)_<BFFFF>_n-7 | FA(22:2)_<B>_n-8 | FA(22:3)_<BF>_n-8 | FA(22:4)_<BFF>_n-8 | FA(22:5)_<BFFF>_n-8 | FA(22:6)_<BFFFF>_n-8 | FA(23:2)_<B>_n-9 | FA(23:3)_<BF>_n-9 | FA(23:4)_<BFF>_n-9 | FA(23:5)_<BFFF>_n-9 | FA(23:6)_<BFFFF>_n-9 | FA(24:2)_<B>_n-10 | FA(24:3)_<BF>_n-10 | FA(24:4)_<BFF>_n-10 | FA(24:5)_<BFFF>_n-10 | FA(24:6)_<BFFFF>_n-10 | FA(25:2)_<B>_n-11 | FA(25:3)_<BF>_n-11 | FA(25:4)_<BFF>_n-11 | FA(25:5)_<BFFF>_n-11 | FA(25:6)_<BFFFF>_n-11 | FA(26:2)_<B>_n-12 | FA(26:3)_<BF>_n-12 | FA(26:4)_<BFF>_n-12 | FA(26:5)_<BFFF>_n-12 | FA(26:6)_<BFFFF>_n-12 | FA(27:2)_<B>_n-13 | FA(27:3)_<BF>_n-13 | FA(27:4)_<BFF>_n-13 | FA(27:5)_<BFFF>_n-13 | FA(27:6)_<BFFFF>_n-13 | FA(28:2)_<B>_n-14 | FA(28:3)_<BF>_n-14 | FA(28:4)_<BFF>_n-14 | FA(28:5)_<BFFF>_n-14 | FA(28:6)_<BFFFF>_n-14 | FA(29:2)_<B>_n-15 | FA(29:3)_<BF>_n-15 | FA(29:4)_<BFF>_n-15 | FA(29:5)_<BFFF>_n-15 | FA(29:6)_<BFFFF>_n-15 | FA(30:2)_<B>_n-16 | FA(30:3)_<BF>_n-16 | FA(30:4)_<BFF>_n-16 | FA(30:5)_<BFFF>_n-16 | FA(30:6)_<BFFFF>_n-16'
#  'FA(15:0) | FA(16:1)_<>_n-2 | FA(16:2)_<F>_n-2 | FA(17:1)_<>_n-3 | FA(17:2)_<F>_n-3 | FA(17:3)_<FF>_n-3 | FA(18:1)_<>_n-4 | FA(18:2)_<F>_n-4 | FA(18:3)_<FF>_n-4 | FA(18:4)_<FFF>_n-4 | FA(19:1)_<>_n-5 | FA(19:2)_<F>_n-5 | FA(19:3)_<FF>_n-5 | FA(19:4)_<FFF>_n-5 | FA(19:5)_<FFFF>_n-5 | FA(20:1)_<>_n-6 | FA(20:2)_<F>_n-6 | FA(20:3)_<FF>_n-6 | FA(20:4)_<FFF>_n-6 | FA(20:5)_<FFFF>_n-6 | FA(20:6)_<FFFFF>_n-6 | FA(21:1)_<>_n-7 | FA(21:2)_<F>_n-7 | FA(21:3)_<FF>_n-7 | FA(21:4)_<FFF>_n-7 | FA(21:5)_<FFFF>_n-7 | FA(21:6)_<FFFFF>_n-7 | FA(22:1)_<>_n-8 | FA(22:2)_<F>_n-8 | FA(22:3)_<FF>_n-8 | FA(22:4)_<FFF>_n-8 | FA(22:5)_<FFFF>_n-8 | FA(22:6)_<FFFFF>_n-8 | FA(23:1)_<>_n-9 | FA(23:2)_<F>_n-9 | FA(23:3)_<FF>_n-9 | FA(23:4)_<FFF>_n-9 | FA(23:5)_<FFFF>_n-9 | FA(23:6)_<FFFFF>_n-9 | FA(24:1)_<>_n-10 | FA(24:2)_<F>_n-10 | FA(24:3)_<FF>_n-10 | FA(24:4)_<FFF>_n-10 | FA(24:5)_<FFFF>_n-10 | FA(24:6)_<FFFFF>_n-10 | FA(25:1)_<>_n-11 | FA(25:2)_<F>_n-11 | FA(25:3)_<FF>_n-11 | FA(25:4)_<FFF>_n-11 | FA(25:5)_<FFFF>_n-11 | FA(25:6)_<FFFFF>_n-11 | FA(26:1)_<>_n-12 | FA(26:2)_<F>_n-12 | FA(26:3)_<FF>_n-12 | FA(26:4)_<FFF>_n-12 | FA(26:5)_<FFFF>_n-12 | FA(26:6)_<FFFFF>_n-12 | FA(27:1)_<>_n-13 | FA(27:2)_<F>_n-13 | FA(27:3)_<FF>_n-13 | FA(27:4)_<FFF>_n-13 | FA(27:5)_<FFFF>_n-13 | FA(27:6)_<FFFFF>_n-13 | FA(28:1)_<>_n-14 | FA(28:2)_<F>_n-14 | FA(28:3)_<FF>_n-14 | FA(28:4)_<FFF>_n-14 | FA(28:5)_<FFFF>_n-14 | FA(28:6)_<FFFFF>_n-14 | FA(29:1)_<>_n-15 | FA(29:2)_<F>_n-15 | FA(29:3)_<FF>_n-15 | FA(29:4)_<FFF>_n-15 | FA(29:5)_<FFFF>_n-15 | FA(29:6)_<FFFFF>_n-15 | FA(30:1)_<>_n-16 | FA(30:2)_<F>_n-16 | FA(30:3)_<FF>_n-16 | FA(30:4)_<FFF>_n-16 | FA(30:5)_<FFFF>_n-16 | FA(30:6)_<FFFFF>_n-16'
# ...
#  'FA(18:0) | FA(19:1)_<>_n-2 | FA(19:2)_<F>_n-2 | FA(20:1)_<>_n-3 | FA(20:2)_<F>_n-3 | FA(20:3)_<FF>_n-3 | FA(21:1)_<>_n-4 | FA(21:2)_<F>_n-4 | FA(21:3)_<FF>_n-4 | FA(21:4)_<FFF>_n-4 | FA(22:1)_<>_n-5 | FA(22:2)_<F>_n-5 | FA(22:3)_<FF>_n-5 | FA(22:4)_<FFF>_n-5 | FA(22:5)_<FFFF>_n-5 | FA(23:1)_<>_n-6 | FA(23:2)_<F>_n-6 | FA(23:3)_<FF>_n-6 | FA(23:4)_<FFF>_n-6 | FA(23:5)_<FFFF>_n-6 | FA(23:6)_<FFFFF>_n-6 | FA(24:1)_<>_n-7 | FA(24:2)_<F>_n-7 | FA(24:3)_<FF>_n-7 | FA(24:4)_<FFF>_n-7 | FA(24:5)_<FFFF>_n-7 | FA(24:6)_<FFFFF>_n-7 | FA(25:1)_<>_n-8 | FA(25:2)_<F>_n-8 | FA(25:3)_<FF>_n-8 | FA(25:4)_<FFF>_n-8 | FA(25:5)_<FFFF>_n-8 | FA(25:6)_<FFFFF>_n-8 | FA(26:1)_<>_n-9 | FA(26:2)_<F>_n-9 | FA(26:3)_<FF>_n-9 | FA(26:4)_<FFF>_n-9 | FA(26:5)_<FFFF>_n-9 | FA(26:6)_<FFFFF>_n-9 | FA(27:1)_<>_n-10 | FA(27:2)_<F>_n-10 | FA(27:3)_<FF>_n-10 | FA(27:4)_<FFF>_n-10 | FA(27:5)_<FFFF>_n-10 | FA(27:6)_<FFFFF>_n-10 | FA(28:1)_<>_n-11 | FA(28:2)_<F>_n-11 | FA(28:3)_<FF>_n-11 | FA(28:4)_<FFF>_n-11 | FA(28:5)_<FFFF>_n-11 | FA(28:6)_<FFFFF>_n-11 | FA(29:1)_<>_n-12 | FA(29:2)_<F>_n-12 | FA(29:3)_<FF>_n-12 | FA(29:4)_<FFF>_n-12 | FA(29:5)_<FFFF>_n-12 | FA(29:6)_<FFFFF>_n-12 | FA(30:1)_<>_n-13 | FA(30:2)_<F>_n-13 | FA(30:3)_<FF>_n-13 | FA(30:4)_<FFF>_n-13 | FA(30:5)_<FFFF>_n-13 | FA(30:6)_<FFFFF>_n-13'
#  'FA(19:0) | FA(20:1)_<>_n-2 | FA(20:2)_<F>_n-2 | FA(21:1)_<>_n-3 | FA(21:2)_<F>_n-3 | FA(21:3)_<FF>_n-3 | FA(22:1)_<>_n-4 | FA(22:2)_<F>_n-4 | FA(22:3)_<FF>_n-4 | FA(22:4)_<FFF>_n-4 | FA(23:1)_<>_n-5 | FA(23:2)_<F>_n-5 | FA(23:3)_<FF>_n-5 | FA(23:4)_<FFF>_n-5 | FA(23:5)_<FFFF>_n-5 | FA(24:1)_<>_n-6 | FA(24:2)_<F>_n-6 | FA(24:3)_<FF>_n-6 | FA(24:4)_<FFF>_n-6 | FA(24:5)_<FFFF>_n-6 | FA(24:6)_<FFFFF>_n-6 | FA(25:1)_<>_n-7 | FA(25:2)_<F>_n-7 | FA(25:3)_<FF>_n-7 | FA(25:4)_<FFF>_n-7 | FA(25:5)_<FFFF>_n-7 | FA(25:6)_<FFFFF>_n-7 | FA(26:1)_<>_n-8 | FA(26:2)_<F>_n-8 | FA(26:3)_<FF>_n-8 | FA(26:4)_<FFF>_n-8 | FA(26:5)_<FFFF>_n-8 | FA(26:6)_<FFFFF>_n-8 | FA(27:1)_<>_n-9 | FA(27:2)_<F>_n-9 | FA(27:3)_<FF>_n-9 | FA(27:4)_<FFF>_n-9 | FA(27:5)_<FFFF>_n-9 | FA(27:6)_<FFFFF>_n-9 | FA(28:1)_<>_n-10 | FA(28:2)_<F>_n-10 | FA(28:3)_<FF>_n-10 | FA(28:4)_<FFF>_n-10 | FA(28:5)_<FFFF>_n-10 | FA(28:6)_<FFFFF>_n-10 | FA(29:1)_<>_n-11 | FA(29:2)_<F>_n-11 | FA(29:3)_<FF>_n-11 | FA(29:4)_<FFF>_n-11 | FA(29:5)_<FFFF>_n-11 | FA(29:6)_<FFFFF>_n-11 | FA(30:1)_<>_n-12 | FA(30:2)_<F>_n-12 | FA(30:3)_<FF>_n-12 | FA(30:4)_<FFF>_n-12 | FA(30:5)_<FFFF>_n-12 | FA(30:6)_<FFFFF>_n-12'
#  'FA(21:6)_<BBBBB>_n-2 | FA(22:6)_<BBBBB>_n-3 | FA(23:6)_<BBBBB>_n-4 | FA(24:6)_<BBBBB>_n-5 | FA(25:6)_<BBBBB>_n-6 | FA(26:6)_<BBBBB>_n-7 | FA(27:6)_<BBBBB>_n-8 | FA(28:6)_<BBBBB>_n-9 | FA(29:6)_<BBBBB>_n-10 | FA(30:6)_<BBBBB>_n-11'
#  'FA(21:5)_<BBBB>_n-2 | FA(21:6)_<BBBBF>_n-2 | FA(22:5)_<BBBB>_n-3 | FA(22:6)_<BBBBF>_n-3 | FA(23:5)_<BBBB>_n-4 | FA(23:6)_<BBBBF>_n-4 | FA(24:5)_<BBBB>_n-5 | FA(24:6)_<BBBBF>_n-5 | FA(25:5)_<BBBB>_n-6 | FA(25:6)_<BBBBF>_n-6 | FA(26:5)_<BBBB>_n-7 | FA(26:6)_<BBBBF>_n-7 | FA(27:5)_<BBBB>_n-8 | FA(27:6)_<BBBBF>_n-8 | FA(28:5)_<BBBB>_n-9 | FA(28:6)_<BBBBF>_n-9 | FA(29:5)_<BBBB>_n-10 | FA(29:6)_<BBBBF>_n-10 | FA(30:5)_<BBBB>_n-11 | FA(30:6)_<BBBBF>_n-11'
#  'FA(21:4)_<BBB>_n-2 | FA(21:5)_<BBBF>_n-2 | FA(22:4)_<BBB>_n-3 | FA(22:5)_<BBBF>_n-3 | FA(22:6)_<BBBFF>_n-3 | FA(23:4)_<BBB>_n-4 | FA(23:5)_<BBBF>_n-4 | FA(23:6)_<BBBFF>_n-4 | FA(24:4)_<BBB>_n-5 | FA(24:5)_<BBBF>_n-5 | FA(24:6)_<BBBFF>_n-5 | FA(25:4)_<BBB>_n-6 | FA(25:5)_<BBBF>_n-6 | FA(25:6)_<BBBFF>_n-6 | FA(26:4)_<BBB>_n-7 | FA(26:5)_<BBBF>_n-7 | FA(26:6)_<BBBFF>_n-7 | FA(27:4)_<BBB>_n-8 | FA(27:5)_<BBBF>_n-8 | FA(27:6)_<BBBFF>_n-8 | FA(28:4)_<BBB>_n-9 | FA(28:5)_<BBBF>_n-9 | FA(28:6)_<BBBFF>_n-9 | FA(29:4)_<BBB>_n-10 | FA(29:5)_<BBBF>_n-10 | FA(29:6)_<BBBFF>_n-10 | FA(30:4)_<BBB>_n-11 | FA(30:5)_<BBBF>_n-11 | FA(30:6)_<BBBFF>_n-11'
#  'FA(21:3)_<BB>_n-2 | FA(21:4)_<BBF>_n-2 | FA(22:3)_<BB>_n-3 | FA(22:4)_<BBF>_n-3 | FA(22:5)_<BBFF>_n-3 | FA(23:3)_<BB>_n-4 | FA(23:4)_<BBF>_n-4 | FA(23:5)_<BBFF>_n-4 | FA(23:6)_<BBFFF>_n-4 | FA(24:3)_<BB>_n-5 | FA(24:4)_<BBF>_n-5 | FA(24:5)_<BBFF>_n-5 | FA(24:6)_<BBFFF>_n-5 | FA(25:3)_<BB>_n-6 | FA(25:4)_<BBF>_n-6 | FA(25:5)_<BBFF>_n-6 | FA(25:6)_<BBFFF>_n-6 | FA(26:3)_<BB>_n-7 | FA(26:4)_<BBF>_n-7 | FA(26:5)_<BBFF>_n-7 | FA(26:6)_<BBFFF>_n-7 | FA(27:3)_<BB>_n-8 | FA(27:4)_<BBF>_n-8 | FA(27:5)_<BBFF>_n-8 | FA(27:6)_<BBFFF>_n-8 | FA(28:3)_<BB>_n-9 | FA(28:4)_<BBF>_n-9 | FA(28:5)_<BBFF>_n-9 | FA(28:6)_<BBFFF>_n-9 | FA(29:3)_<BB>_n-10 | FA(29:4)_<BBF>_n-10 | FA(29:5)_<BBFF>_n-10 | FA(29:6)_<BBFFF>_n-10 | FA(30:3)_<BB>_n-11 | FA(30:4)_<BBF>_n-11 | FA(30:5)_<BBFF>_n-11 | FA(30:6)_<BBFFF>_n-11'
#  'FA(21:2)_<B>_n-2 | FA(21:3)_<BF>_n-2 | FA(22:2)_<B>_n-3 | FA(22:3)_<BF>_n-3 | FA(22:4)_<BFF>_n-3 | FA(23:2)_<B>_n-4 | FA(23:3)_<BF>_n-4 | FA(23:4)_<BFF>_n-4 | FA(23:5)_<BFFF>_n-4 | FA(24:2)_<B>_n-5 | FA(24:3)_<BF>_n-5 | FA(24:4)_<BFF>_n-5 | FA(24:5)_<BFFF>_n-5 | FA(24:6)_<BFFFF>_n-5 | FA(25:2)_<B>_n-6 | FA(25:3)_<BF>_n-6 | FA(25:4)_<BFF>_n-6 | FA(25:5)_<BFFF>_n-6 | FA(25:6)_<BFFFF>_n-6 | FA(26:2)_<B>_n-7 | FA(26:3)_<BF>_n-7 | FA(26:4)_<BFF>_n-7 | FA(26:5)_<BFFF>_n-7 | FA(26:6)_<BFFFF>_n-7 | FA(27:2)_<B>_n-8 | FA(27:3)_<BF>_n-8 | FA(27:4)_<BFF>_n-8 | FA(27:5)_<BFFF>_n-8 | FA(27:6)_<BFFFF>_n-8 | FA(28:2)_<B>_n-9 | FA(28:3)_<BF>_n-9 | FA(28:4)_<BFF>_n-9 | FA(28:5)_<BFFF>_n-9 | FA(28:6)_<BFFFF>_n-9 | FA(29:2)_<B>_n-10 | FA(29:3)_<BF>_n-10 | FA(29:4)_<BFF>_n-10 | FA(29:5)_<BFFF>_n-10 | FA(29:6)_<BFFFF>_n-10 | FA(30:2)_<B>_n-11 | FA(30:3)_<BF>_n-11 | FA(30:4)_<BFF>_n-11 | FA(30:5)_<BFFF>_n-11 | FA(30:6)_<BFFFF>_n-11'
#  'FA(20:0) | FA(21:1)_<>_n-2 | FA(21:2)_<F>_n-2 | FA(22:1)_<>_n-3 | FA(22:2)_<F>_n-3 | FA(22:3)_<FF>_n-3 | FA(23:1)_<>_n-4 | FA(23:2)_<F>_n-4 | FA(23:3)_<FF>_n-4 | FA(23:4)_<FFF>_n-4 | FA(24:1)_<>_n-5 | FA(24:2)_<F>_n-5 | FA(24:3)_<FF>_n-5 | FA(24:4)_<FFF>_n-5 | FA(24:5)_<FFFF>_n-5 | FA(25:1)_<>_n-6 | FA(25:2)_<F>_n-6 | FA(25:3)_<FF>_n-6 | FA(25:4)_<FFF>_n-6 | FA(25:5)_<FFFF>_n-6 | FA(25:6)_<FFFFF>_n-6 | FA(26:1)_<>_n-7 | FA(26:2)_<F>_n-7 | FA(26:3)_<FF>_n-7 | FA(26:4)_<FFF>_n-7 | FA(26:5)_<FFFF>_n-7 | FA(26:6)_<FFFFF>_n-7 | FA(27:1)_<>_n-8 | FA(27:2)_<F>_n-8 | FA(27:3)_<FF>_n-8 | FA(27:4)_<FFF>_n-8 | FA(27:5)_<FFFF>_n-8 | FA(27:6)_<FFFFF>_n-8 | FA(28:1)_<>_n-9 | FA(28:2)_<F>_n-9 | FA(28:3)_<FF>_n-9 | FA(28:4)_<FFF>_n-9 | FA(28:5)_<FFFF>_n-9 | FA(28:6)_<FFFFF>_n-9 | FA(29:1)_<>_n-10 | FA(29:2)_<F>_n-10 | FA(29:3)_<FF>_n-10 | FA(29:4)_<FFF>_n-10 | FA(29:5)_<FFFF>_n-10 | FA(29:6)_<FFFFF>_n-10 | FA(30:1)_<>_n-11 | FA(30:2)_<F>_n-11 | FA(30:3)_<FF>_n-11 | FA(30:4)_<FFF>_n-11 | FA(30:5)_<FFFF>_n-11 | FA(30:6)_<FFFFF>_n-11'
#  'FA(21:0) | FA(22:1)_<>_n-2 | FA(22:2)_<F>_n-2 | FA(23:1)_<>_n-3 | FA(23:2)_<F>_n-3 | FA(23:3)_<FF>_n-3 | FA(24:1)_<>_n-4 | FA(24:2)_<F>_n-4 | FA(24:3)_<FF>_n-4 | FA(24:4)_<FFF>_n-4 | FA(25:1)_<>_n-5 | FA(25:2)_<F>_n-5 | FA(25:3)_<FF>_n-5 | FA(25:4)_<FFF>_n-5 | FA(25:5)_<FFFF>_n-5 | FA(26:1)_<>_n-6 | FA(26:2)_<F>_n-6 | FA(26:3)_<FF>_n-6 | FA(26:4)_<FFF>_n-6 | FA(26:5)_<FFFF>_n-6 | FA(26:6)_<FFFFF>_n-6 | FA(27:1)_<>_n-7 | FA(27:2)_<F>_n-7 | FA(27:3)_<FF>_n-7 | FA(27:4)_<FFF>_n-7 | FA(27:5)_<FFFF>_n-7 | FA(27:6)_<FFFFF>_n-7 | FA(28:1)_<>_n-8 | FA(28:2)_<F>_n-8 | FA(28:3)_<FF>_n-8 | FA(28:4)_<FFF>_n-8 | FA(28:5)_<FFFF>_n-8 | FA(28:6)_<FFFFF>_n-8 | FA(29:1)_<>_n-9 | FA(29:2)_<F>_n-9 | FA(29:3)_<FF>_n-9 | FA(29:4)_<FFF>_n-9 | FA(29:5)_<FFFF>_n-9 | FA(29:6)_<FFFFF>_n-9 | FA(30:1)_<>_n-10 | FA(30:2)_<F>_n-10 | FA(30:3)_<FF>_n-10 | FA(30:4)_<FFF>_n-10 | FA(30:5)_<FFFF>_n-10 | FA(30:6)_<FFFFF>_n-10'
#  'FA(23:3)_<BB>_n-2 | FA(23:4)_<BBF>_n-2 | FA(24:3)_<BB>_n-3 | FA(24:4)_<BBF>_n-3 | FA(24:5)_<BBFF>_n-3 | FA(25:3)_<BB>_n-4 | FA(25:4)_<BBF>_n-4 | FA(25:5)_<BBFF>_n-4 | FA(25:6)_<BBFFF>_n-4 | FA(26:3)_<BB>_n-5 | FA(26:4)_<BBF>_n-5 | FA(26:5)_<BBFF>_n-5 | FA(26:6)_<BBFFF>_n-5 | FA(27:3)_<BB>_n-6 | FA(27:4)_<BBF>_n-6 | FA(27:5)_<BBFF>_n-6 | FA(27:6)_<BBFFF>_n-6 | FA(28:3)_<BB>_n-7 | FA(28:4)_<BBF>_n-7 | FA(28:5)_<BBFF>_n-7 | FA(28:6)_<BBFFF>_n-7 | FA(29:3)_<BB>_n-8 | FA(29:4)_<BBF>_n-8 | FA(29:5)_<BBFF>_n-8 | FA(29:6)_<BBFFF>_n-8 | FA(30:3)_<BB>_n-9 | FA(30:4)_<BBF>_n-9 | FA(30:5)_<BBFF>_n-9 | FA(30:6)_<BBFFF>_n-9'
#  'FA(23:2)_<B>_n-2 | FA(23:3)_<BF>_n-2 | FA(24:2)_<B>_n-3 | FA(24:3)_<BF>_n-3 | FA(24:4)_<BFF>_n-3 | FA(25:2)_<B>_n-4 | FA(25:3)_<BF>_n-4 | FA(25:4)_<BFF>_n-4 | FA(25:5)_<BFFF>_n-4 | FA(26:2)_<B>_n-5 | FA(26:3)_<BF>_n-5 | FA(26:4)_<BFF>_n-5 | FA(26:5)_<BFFF>_n-5 | FA(26:6)_<BFFFF>_n-5 | FA(27:2)_<B>_n-6 | FA(27:3)_<BF>_n-6 | FA(27:4)_<BFF>_n-6 | FA(27:5)_<BFFF>_n-6 | FA(27:6)_<BFFFF>_n-6 | FA(28:2)_<B>_n-7 | FA(28:3)_<BF>_n-7 | FA(28:4)_<BFF>_n-7 | FA(28:5)_<BFFF>_n-7 | FA(28:6)_<BFFFF>_n-7 | FA(29:2)_<B>_n-8 | FA(29:3)_<BF>_n-8 | FA(29:4)_<BFF>_n-8 | FA(29:5)_<BFFF>_n-8 | FA(29:6)_<BFFFF>_n-8 | FA(30:2)_<B>_n-9 | FA(30:3)_<BF>_n-9 | FA(30:4)_<BFF>_n-9 | FA(30:5)_<BFFF>_n-9 | FA(30:6)_<BFFFF>_n-9'
#  'FA(22:0) | FA(23:1)_<>_n-2 | FA(23:2)_<F>_n-2 | FA(24:1)_<>_n-3 | FA(24:2)_<F>_n-3 | FA(24:3)_<FF>_n-3 | FA(25:1)_<>_n-4 | FA(25:2)_<F>_n-4 | FA(25:3)_<FF>_n-4 | FA(25:4)_<FFF>_n-4 | FA(26:1)_<>_n-5 | FA(26:2)_<F>_n-5 | FA(26:3)_<FF>_n-5 | FA(26:4)_<FFF>_n-5 | FA(26:5)_<FFFF>_n-5 | FA(27:1)_<>_n-6 | FA(27:2)_<F>_n-6 | FA(27:3)_<FF>_n-6 | FA(27:4)_<FFF>_n-6 | FA(27:5)_<FFFF>_n-6 | FA(27:6)_<FFFFF>_n-6 | FA(28:1)_<>_n-7 | FA(28:2)_<F>_n-7 | FA(28:3)_<FF>_n-7 | FA(28:4)_<FFF>_n-7 | FA(28:5)_<FFFF>_n-7 | FA(28:6)_<FFFFF>_n-7 | FA(29:1)_<>_n-8 | FA(29:2)_<F>_n-8 | FA(29:3)_<FF>_n-8 | FA(29:4)_<FFF>_n-8 | FA(29:5)_<FFFF>_n-8 | FA(29:6)_<FFFFF>_n-8 | FA(30:1)_<>_n-9 | FA(30:2)_<F>_n-9 | FA(30:3)_<FF>_n-9 | FA(30:4)_<FFF>_n-9 | FA(30:5)_<FFFF>_n-9 | FA(30:6)_<FFFFF>_n-9'
#  'FA(23:0) | FA(24:1)_<>_n-2 | FA(24:2)_<F>_n-2 | FA(25:1)_<>_n-3 | FA(25:2)_<F>_n-3 | FA(25:3)_<FF>_n-3 | FA(26:1)_<>_n-4 | FA(26:2)_<F>_n-4 | FA(26:3)_<FF>_n-4 | FA(26:4)_<FFF>_n-4 | FA(27:1)_<>_n-5 | FA(27:2)_<F>_n-5 | FA(27:3)_<FF>_n-5 | FA(27:4)_<FFF>_n-5 | FA(27:5)_<FFFF>_n-5 | FA(28:1)_<>_n-6 | FA(28:2)_<F>_n-6 | FA(28:3)_<FF>_n-6 | FA(28:4)_<FFF>_n-6 | FA(28:5)_<FFFF>_n-6 | FA(28:6)_<FFFFF>_n-6 | FA(29:1)_<>_n-7 | FA(29:2)_<F>_n-7 | FA(29:3)_<FF>_n-7 | FA(29:4)_<FFF>_n-7 | FA(29:5)_<FFFF>_n-7 | FA(29:6)_<FFFFF>_n-7 | FA(30:1)_<>_n-8 | FA(30:2)_<F>_n-8 | FA(30:3)_<FF>_n-8 | FA(30:4)_<FFF>_n-8 | FA(30:5)_<FFFF>_n-8 | FA(30:6)_<FFFFF>_n-8'
#  'FA(25:2)_<B>_n-2 | FA(25:3)_<BF>_n-2 | FA(26:2)_<B>_n-3 | FA(26:3)_<BF>_n-3 | FA(26:4)_<BFF>_n-3 | FA(27:2)_<B>_n-4 | FA(27:3)_<BF>_n-4 | FA(27:4)_<BFF>_n-4 | FA(27:5)_<BFFF>_n-4 | FA(28:2)_<B>_n-5 | FA(28:3)_<BF>_n-5 | FA(28:4)_<BFF>_n-5 | FA(28:5)_<BFFF>_n-5 | FA(28:6)_<BFFFF>_n-5 | FA(29:2)_<B>_n-6 | FA(29:3)_<BF>_n-6 | FA(29:4)_<BFF>_n-6 | FA(29:5)_<BFFF>_n-6 | FA(29:6)_<BFFFF>_n-6 | FA(30:2)_<B>_n-7 | FA(30:3)_<BF>_n-7 | FA(30:4)_<BFF>_n-7 | FA(30:5)_<BFFF>_n-7 | FA(30:6)_<BFFFF>_n-7'
#  'FA(24:0) | FA(25:1)_<>_n-2 | FA(25:2)_<F>_n-2 | FA(26:1)_<>_n-3 | FA(26:2)_<F>_n-3 | FA(26:3)_<FF>_n-3 | FA(27:1)_<>_n-4 | FA(27:2)_<F>_n-4 | FA(27:3)_<FF>_n-4 | FA(27:4)_<FFF>_n-4 | FA(28:1)_<>_n-5 | FA(28:2)_<F>_n-5 | FA(28:3)_<FF>_n-5 | FA(28:4)_<FFF>_n-5 | FA(28:5)_<FFFF>_n-5 | FA(29:1)_<>_n-6 | FA(29:2)_<F>_n-6 | FA(29:3)_<FF>_n-6 | FA(29:4)_<FFF>_n-6 | FA(29:5)_<FFFF>_n-6 | FA(29:6)_<FFFFF>_n-6 | FA(30:1)_<>_n-7 | FA(30:2)_<F>_n-7 | FA(30:3)_<FF>_n-7 | FA(30:4)_<FFF>_n-7 | FA(30:5)_<FFFF>_n-7 | FA(30:6)_<FFFFF>_n-7']
#                                                     Lipid  Parent_Ion  \
# 0                                                               227.1
# 1                                                               227.1
# 2                                                               227.1
# 3                                                               227.1
# 4                                                               227.1
# ...                                                   ...         ...
# 127706  FA(25:2)_<B>_n-2 | FA(25:3)_<BF>_n-2 | FA(26:2...       533.5
# 127707  FA(25:2)_<B>_n-2 | FA(25:3)_<BF>_n-2 | FA(26:2...       533.5
# 127708  FA(25:2)_<B>_n-2 | FA(25:3)_<BF>_n-2 | FA(26:2...       533.5
# 127709  FA(25:2)_<B>_n-2 | FA(25:3)_<BF>_n-2 | FA(26:2...       533.5
# 127710  FA(25:2)_<B>_n-2 | FA(25:3)_<BF>_n-2 | FA(26:2...       533.5
#
#         Product_Ion  Retention_Time  OzESI_Intensity  \
# 0             183.0        0.011583             41.0
# 1             183.0        0.024483             41.0
# 2             183.0        0.037383             41.0
# 3             183.0        0.050317             41.0
# 4             183.0        0.063233             41.0
# ...             ...             ...              ...
# 127706        183.0       29.949050             41.0
# 127707        183.0       29.961967             41.0
# 127708        183.0       29.974883             41.0
# 127709        183.0       29.987800             41.0
# 127710        183.0       30.000733             41.0
#
#                                                 Sample_ID      Transition  \
# 0       11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  227.1 -> 183.0
# 1       11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  227.1 -> 183.0
# 2       11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  227.1 -> 183.0
# 3       11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  227.1 -> 183.0
# 4       11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  227.1 -> 183.0
# ...                                                   ...             ...
# 127706  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  533.5 -> 183.0
# 127707  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  533.5 -> 183.0
# 127708  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  533.5 -> 183.0
# 127709  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  533.5 -> 183.0
# 127710  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  533.5 -> 183.0
#
#                     Sample   STD  STD_RT_OFF  \
# 0       hippo_WT_m1_FAD245  None    7.899783
# 1       hippo_WT_m1_FAD245  None    7.899783
# 2       hippo_WT_m1_FAD245  None    7.899783
# 3       hippo_WT_m1_FAD245  None    7.899783
# 4       hippo_WT_m1_FAD245  None    7.899783
# ...                    ...   ...         ...
# 127706  hippo_WT_m1_FAD245  None    7.899783
# 127707  hippo_WT_m1_FAD245  None    7.899783
# 127708  hippo_WT_m1_FAD245  None    7.899783
# 127709  hippo_WT_m1_FAD245  None    7.899783
# 127710  hippo_WT_m1_FAD245  None    7.899783
#
#                                                     Class
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 127706  FA | FA | FA | FA | FA | FA | FA | FA | FA | F...
# 127707  FA | FA | FA | FA | FA | FA | FA | FA | FA | F...
# 127708  FA | FA | FA | FA | FA | FA | FA | FA | FA | F...
# 127709  FA | FA | FA | FA | FA | FA | FA | FA | FA | F...
# 127710  FA | FA | FA | FA | FA | FA | FA | FA | FA | F...
#
# [127711 rows x 11 columns]

# %% [markdown]
# # 4 - group

# %%
# !sbatch core/backend/not_possible/group_4_AMP_OFF_notpossible.sh
# Out:
# Submitted batch job 20384319

# %%
import pandas as pd

# Load the parquet file
df_before = pd.read_parquet('Projects/AMP/group/OFF/notpossible/df_group_4_hippo_WT_m1_FAD245_OFF.parquet')

# # Filter out the rows where Lipid is 'FA(24:1)' and Parent_Ion is 533.5
# filtered_df = df_before[~((df_before['Lipid'] == 'FA(24:1)') & (df_before['Parent_Ion'] == 533.5))]

# # # Save the filtered DataFrame
# # filtered_df.to_parquet('Projects/STD/group/OFF/df_group_4_FAME_OFF_filtered24.parquet')

# # Display the filtered DataFrame
# filtered_df

print(df_before['Lipid'].unique())
print(df_before['Species'].unique())
df_before
# Out:
# [''
#  'FA(10:0) | FA(11:1)_<>_n-2 | FA(11:2)_<F>_n-2 | FA(12:1)_<>_n-3 | FA(12:2)_<F>_n-3 | FA(12:3)_<FF>_n-3 | FA(13:1)_<>_n-4 | FA(13:2)_<F>_n-4 | FA(13:3)_<FF>_n-4 | FA(13:4)_<FFF>_n-4 | FA(14:1)_<>_n-5 | FA(14:2)_<F>_n-5 | FA(14:3)_<FF>_n-5 | FA(14:4)_<FFF>_n-5 | FA(14:5)_<FFFF>_n-5 | FA(15:1)_<>_n-6 | FA(15:2)_<F>_n-6 | FA(15:3)_<FF>_n-6 | FA(15:4)_<FFF>_n-6 | FA(15:5)_<FFFF>_n-6 | FA(15:6)_<FFFFF>_n-6 | FA(16:1)_<>_n-7 | FA(16:2)_<F>_n-7 | FA(16:3)_<FF>_n-7 | FA(16:4)_<FFF>_n-7 | FA(16:5)_<FFFF>_n-7 | FA(16:6)_<FFFFF>_n-7 | FA(17:1)_<>_n-8 | FA(17:2)_<F>_n-8 | FA(17:3)_<FF>_n-8 | FA(17:4)_<FFF>_n-8 | FA(17:5)_<FFFF>_n-8 | FA(17:6)_<FFFFF>_n-8 | FA(18:1)_<>_n-9 | FA(18:2)_<F>_n-9 | FA(18:3)_<FF>_n-9 | FA(18:4)_<FFF>_n-9 | FA(18:5)_<FFFF>_n-9 | FA(18:6)_<FFFFF>_n-9 | FA(19:1)_<>_n-10 | FA(19:2)_<F>_n-10 | FA(19:3)_<FF>_n-10 | FA(19:4)_<FFF>_n-10 | FA(19:5)_<FFFF>_n-10 | FA(19:6)_<FFFFF>_n-10 | FA(20:1)_<>_n-11 | FA(20:2)_<F>_n-11 | FA(20:3)_<FF>_n-11 | FA(20:4)_<FFF>_n-11 | FA(20:5)_<FFFF>_n-11 | FA(20:6)_<FFFFF>_n-11 | FA(21:1)_<>_n-12 | FA(21:2)_<F>_n-12 | FA(21:3)_<FF>_n-12 | FA(21:4)_<FFF>_n-12 | FA(21:5)_<FFFF>_n-12 | FA(21:6)_<FFFFF>_n-12 | FA(22:1)_<>_n-13 | FA(22:2)_<F>_n-13 | FA(22:3)_<FF>_n-13 | FA(22:4)_<FFF>_n-13 | FA(22:5)_<FFFF>_n-13 | FA(22:6)_<FFFFF>_n-13 | FA(23:1)_<>_n-14 | FA(23:2)_<F>_n-14 | FA(23:3)_<FF>_n-14 | FA(23:4)_<FFF>_n-14 | FA(23:5)_<FFFF>_n-14 | FA(23:6)_<FFFFF>_n-14 | FA(24:1)_<>_n-15 | FA(24:2)_<F>_n-15 | FA(24:3)_<FF>_n-15 | FA(24:4)_<FFF>_n-15 | FA(24:5)_<FFFF>_n-15 | FA(24:6)_<FFFFF>_n-15 | FA(25:1)_<>_n-16 | FA(25:2)_<F>_n-16 | FA(25:3)_<FF>_n-16 | FA(25:4)_<FFF>_n-16 | FA(25:5)_<FFFF>_n-16 | FA(25:6)_<FFFFF>_n-16 | FA(26:1)_<>_n-17 | FA(26:2)_<F>_n-17 | FA(26:3)_<FF>_n-17 | FA(26:4)_<FFF>_n-17 | FA(26:5)_<FFFF>_n-17 | FA(26:6)_<FFFFF>_n-17 | FA(27:1)_<>_n-18 | FA(27:2)_<F>_n-18 | FA(27:3)_<FF>_n-18 | FA(27:4)_<FFF>_n-18 | FA(27:5)_<FFFF>_n-18 | FA(27:6)_<FFFFF>_n-18 | FA(28:1)_<>_n-19 | FA(28:2)_<F>_n-19 | FA(28:3)_<FF>_n-19 | FA(28:4)_<FFF>_n-19 | FA(28:5)_<FFFF>_n-19 | FA(28:6)_<FFFFF>_n-19 | FA(29:1)_<>_n-20 | FA(29:2)_<F>_n-20 | FA(29:3)_<FF>_n-20 | FA(29:4)_<FFF>_n-20 | FA(29:5)_<FFFF>_n-20 | FA(29:6)_<FFFFF>_n-20 | FA(30:1)_<>_n-21 | FA(30:2)_<F>_n-21 | FA(30:3)_<FF>_n-21 | FA(30:4)_<FFF>_n-21 | FA(30:5)_<FFFF>_n-21 | FA(30:6)_<FFFFF>_n-21'
#  'FA(10:2)_<B>_n-2 | FA(10:3)_<BF>_n-2 | FA(11:2)_<B>_n-3 | FA(11:3)_<BF>_n-3 | FA(11:4)_<BFF>_n-3 | FA(12:2)_<B>_n-4 | FA(12:3)_<BF>_n-4 | FA(12:4)_<BFF>_n-4 | FA(12:5)_<BFFF>_n-4 | FA(13:2)_<B>_n-5 | FA(13:3)_<BF>_n-5 | FA(13:4)_<BFF>_n-5 | FA(13:5)_<BFFF>_n-5 | FA(13:6)_<BFFFF>_n-5 | FA(14:2)_<B>_n-6 | FA(14:3)_<BF>_n-6 | FA(14:4)_<BFF>_n-6 | FA(14:5)_<BFFF>_n-6 | FA(14:6)_<BFFFF>_n-6 | FA(15:2)_<B>_n-7 | FA(15:3)_<BF>_n-7 | FA(15:4)_<BFF>_n-7 | FA(15:5)_<BFFF>_n-7 | FA(15:6)_<BFFFF>_n-7 | FA(16:2)_<B>_n-8 | FA(16:3)_<BF>_n-8 | FA(16:4)_<BFF>_n-8 | FA(16:5)_<BFFF>_n-8 | FA(16:6)_<BFFFF>_n-8 | FA(17:2)_<B>_n-9 | FA(17:3)_<BF>_n-9 | FA(17:4)_<BFF>_n-9 | FA(17:5)_<BFFF>_n-9 | FA(17:6)_<BFFFF>_n-9 | FA(18:2)_<B>_n-10 | FA(18:3)_<BF>_n-10 | FA(18:4)_<BFF>_n-10 | FA(18:5)_<BFFF>_n-10 | FA(18:6)_<BFFFF>_n-10 | FA(19:2)_<B>_n-11 | FA(19:3)_<BF>_n-11 | FA(19:4)_<BFF>_n-11 | FA(19:5)_<BFFF>_n-11 | FA(19:6)_<BFFFF>_n-11 | FA(20:2)_<B>_n-12 | FA(20:3)_<BF>_n-12 | FA(20:4)_<BFF>_n-12 | FA(20:5)_<BFFF>_n-12 | FA(20:6)_<BFFFF>_n-12 | FA(21:2)_<B>_n-13 | FA(21:3)_<BF>_n-13 | FA(21:4)_<BFF>_n-13 | FA(21:5)_<BFFF>_n-13 | FA(21:6)_<BFFFF>_n-13 | FA(22:2)_<B>_n-14 | FA(22:3)_<BF>_n-14 | FA(22:4)_<BFF>_n-14 | FA(22:5)_<BFFF>_n-14 | FA(22:6)_<BFFFF>_n-14 | FA(23:2)_<B>_n-15 | FA(23:3)_<BF>_n-15 | FA(23:4)_<BFF>_n-15 | FA(23:5)_<BFFF>_n-15 | FA(23:6)_<BFFFF>_n-15 | FA(24:2)_<B>_n-16 | FA(24:3)_<BF>_n-16 | FA(24:4)_<BFF>_n-16 | FA(24:5)_<BFFF>_n-16 | FA(24:6)_<BFFFF>_n-16 | FA(25:2)_<B>_n-17 | FA(25:3)_<BF>_n-17 | FA(25:4)_<BFF>_n-17 | FA(25:5)_<BFFF>_n-17 | FA(25:6)_<BFFFF>_n-17 | FA(26:2)_<B>_n-18 | FA(26:3)_<BF>_n-18 | FA(26:4)_<BFF>_n-18 | FA(26:5)_<BFFF>_n-18 | FA(26:6)_<BFFFF>_n-18 | FA(27:2)_<B>_n-19 | FA(27:3)_<BF>_n-19 | FA(27:4)_<BFF>_n-19 | FA(27:5)_<BFFF>_n-19 | FA(27:6)_<BFFFF>_n-19'
#  'FA(11:0) | FA(12:1)_<>_n-2 | FA(12:2)_<F>_n-2 | FA(13:1)_<>_n-3 | FA(13:2)_<F>_n-3 | FA(13:3)_<FF>_n-3 | FA(14:1)_<>_n-4 | FA(14:2)_<F>_n-4 | FA(14:3)_<FF>_n-4 | FA(14:4)_<FFF>_n-4 | FA(15:1)_<>_n-5 | FA(15:2)_<F>_n-5 | FA(15:3)_<FF>_n-5 | FA(15:4)_<FFF>_n-5 | FA(15:5)_<FFFF>_n-5 | FA(16:1)_<>_n-6 | FA(16:2)_<F>_n-6 | FA(16:3)_<FF>_n-6 | FA(16:4)_<FFF>_n-6 | FA(16:5)_<FFFF>_n-6 | FA(16:6)_<FFFFF>_n-6 | FA(17:1)_<>_n-7 | FA(17:2)_<F>_n-7 | FA(17:3)_<FF>_n-7 | FA(17:4)_<FFF>_n-7 | FA(17:5)_<FFFF>_n-7 | FA(17:6)_<FFFFF>_n-7 | FA(18:1)_<>_n-8 | FA(18:2)_<F>_n-8 | FA(18:3)_<FF>_n-8 | FA(18:4)_<FFF>_n-8 | FA(18:5)_<FFFF>_n-8 | FA(18:6)_<FFFFF>_n-8 | FA(19:1)_<>_n-9 | FA(19:2)_<F>_n-9 | FA(19:3)_<FF>_n-9 | FA(19:4)_<FFF>_n-9 | FA(19:5)_<FFFF>_n-9 | FA(19:6)_<FFFFF>_n-9 | FA(20:1)_<>_n-10 | FA(20:2)_<F>_n-10 | FA(20:3)_<FF>_n-10 | FA(20:4)_<FFF>_n-10 | FA(20:5)_<FFFF>_n-10 | FA(20:6)_<FFFFF>_n-10 | FA(21:1)_<>_n-11 | FA(21:2)_<F>_n-11 | FA(21:3)_<FF>_n-11 | FA(21:4)_<FFF>_n-11 | FA(21:5)_<FFFF>_n-11 | FA(21:6)_<FFFFF>_n-11 | FA(22:1)_<>_n-12 | FA(22:2)_<F>_n-12 | FA(22:3)_<FF>_n-12 | FA(22:4)_<FFF>_n-12 | FA(22:5)_<FFFF>_n-12 | FA(22:6)_<FFFFF>_n-12 | FA(23:1)_<>_n-13 | FA(23:2)_<F>_n-13 | FA(23:3)_<FF>_n-13 | FA(23:4)_<FFF>_n-13 | FA(23:5)_<FFFF>_n-13 | FA(23:6)_<FFFFF>_n-13 | FA(24:1)_<>_n-14 | FA(24:2)_<F>_n-14 | FA(24:3)_<FF>_n-14 | FA(24:4)_<FFF>_n-14 | FA(24:5)_<FFFF>_n-14 | FA(24:6)_<FFFFF>_n-14 | FA(25:1)_<>_n-15 | FA(25:2)_<F>_n-15 | FA(25:3)_<FF>_n-15 | FA(25:4)_<FFF>_n-15 | FA(25:5)_<FFFF>_n-15 | FA(25:6)_<FFFFF>_n-15 | FA(26:1)_<>_n-16 | FA(26:2)_<F>_n-16 | FA(26:3)_<FF>_n-16 | FA(26:4)_<FFF>_n-16 | FA(26:5)_<FFFF>_n-16 | FA(26:6)_<FFFFF>_n-16 | FA(27:1)_<>_n-17 | FA(27:2)_<F>_n-17 | FA(27:3)_<FF>_n-17 | FA(27:4)_<FFF>_n-17 | FA(27:5)_<FFFF>_n-17 | FA(27:6)_<FFFFF>_n-17 | FA(28:1)_<>_n-18 | FA(28:2)_<F>_n-18 | FA(28:3)_<FF>_n-18 | FA(28:4)_<FFF>_n-18 | FA(28:5)_<FFFF>_n-18 | FA(28:6)_<FFFFF>_n-18 | FA(29:1)_<>_n-19 | FA(29:2)_<F>_n-19 | FA(29:3)_<FF>_n-19 | FA(29:4)_<FFF>_n-19 | FA(29:5)_<FFFF>_n-19 | FA(29:6)_<FFFFF>_n-19 | FA(30:1)_<>_n-20 | FA(30:2)_<F>_n-20 | FA(30:3)_<FF>_n-20 | FA(30:4)_<FFF>_n-20 | FA(30:5)_<FFFF>_n-20 | FA(30:6)_<FFFFF>_n-20'
#  'FA(11:2)_<B>_n-2 | FA(11:3)_<BF>_n-2 | FA(12:2)_<B>_n-3 | FA(12:3)_<BF>_n-3 | FA(12:4)_<BFF>_n-3 | FA(13:2)_<B>_n-4 | FA(13:3)_<BF>_n-4 | FA(13:4)_<BFF>_n-4 | FA(13:5)_<BFFF>_n-4 | FA(14:2)_<B>_n-5 | FA(14:3)_<BF>_n-5 | FA(14:4)_<BFF>_n-5 | FA(14:5)_<BFFF>_n-5 | FA(14:6)_<BFFFF>_n-5 | FA(15:2)_<B>_n-6 | FA(15:3)_<BF>_n-6 | FA(15:4)_<BFF>_n-6 | FA(15:5)_<BFFF>_n-6 | FA(15:6)_<BFFFF>_n-6 | FA(16:2)_<B>_n-7 | FA(16:3)_<BF>_n-7 | FA(16:4)_<BFF>_n-7 | FA(16:5)_<BFFF>_n-7 | FA(16:6)_<BFFFF>_n-7 | FA(17:2)_<B>_n-8 | FA(17:3)_<BF>_n-8 | FA(17:4)_<BFF>_n-8 | FA(17:5)_<BFFF>_n-8 | FA(17:6)_<BFFFF>_n-8 | FA(18:2)_<B>_n-9 | FA(18:3)_<BF>_n-9 | FA(18:4)_<BFF>_n-9 | FA(18:5)_<BFFF>_n-9 | FA(18:6)_<BFFFF>_n-9 | FA(19:2)_<B>_n-10 | FA(19:3)_<BF>_n-10 | FA(19:4)_<BFF>_n-10 | FA(19:5)_<BFFF>_n-10 | FA(19:6)_<BFFFF>_n-10 | FA(20:2)_<B>_n-11 | FA(20:3)_<BF>_n-11 | FA(20:4)_<BFF>_n-11 | FA(20:5)_<BFFF>_n-11 | FA(20:6)_<BFFFF>_n-11 | FA(21:2)_<B>_n-12 | FA(21:3)_<BF>_n-12 | FA(21:4)_<BFF>_n-12 | FA(21:5)_<BFFF>_n-12 | FA(21:6)_<BFFFF>_n-12 | FA(22:2)_<B>_n-13 | FA(22:3)_<BF>_n-13 | FA(22:4)_<BFF>_n-13 | FA(22:5)_<BFFF>_n-13 | FA(22:6)_<BFFFF>_n-13 | FA(23:2)_<B>_n-14 | FA(23:3)_<BF>_n-14 | FA(23:4)_<BFF>_n-14 | FA(23:5)_<BFFF>_n-14 | FA(23:6)_<BFFFF>_n-14 | FA(24:2)_<B>_n-15 | FA(24:3)_<BF>_n-15 | FA(24:4)_<BFF>_n-15 | FA(24:5)_<BFFF>_n-15 | FA(24:6)_<BFFFF>_n-15 | FA(25:2)_<B>_n-16 | FA(25:3)_<BF>_n-16 | FA(25:4)_<BFF>_n-16 | FA(25:5)_<BFFF>_n-16 | FA(25:6)_<BFFFF>_n-16 | FA(26:2)_<B>_n-17 | FA(26:3)_<BF>_n-17 | FA(26:4)_<BFF>_n-17 | FA(26:5)_<BFFF>_n-17 | FA(26:6)_<BFFFF>_n-17 | FA(27:2)_<B>_n-18 | FA(27:3)_<BF>_n-18 | FA(27:4)_<BFF>_n-18 | FA(27:5)_<BFFF>_n-18 | FA(27:6)_<BFFFF>_n-18'
#  'FA(12:0) | FA(13:1)_<>_n-2 | FA(13:2)_<F>_n-2 | FA(14:1)_<>_n-3 | FA(14:2)_<F>_n-3 | FA(14:3)_<FF>_n-3 | FA(15:1)_<>_n-4 | FA(15:2)_<F>_n-4 | FA(15:3)_<FF>_n-4 | FA(15:4)_<FFF>_n-4 | FA(16:1)_<>_n-5 | FA(16:2)_<F>_n-5 | FA(16:3)_<FF>_n-5 | FA(16:4)_<FFF>_n-5 | FA(16:5)_<FFFF>_n-5 | FA(17:1)_<>_n-6 | FA(17:2)_<F>_n-6 | FA(17:3)_<FF>_n-6 | FA(17:4)_<FFF>_n-6 | FA(17:5)_<FFFF>_n-6 | FA(17:6)_<FFFFF>_n-6 | FA(18:1)_<>_n-7 | FA(18:2)_<F>_n-7 | FA(18:3)_<FF>_n-7 | FA(18:4)_<FFF>_n-7 | FA(18:5)_<FFFF>_n-7 | FA(18:6)_<FFFFF>_n-7 | FA(19:1)_<>_n-8 | FA(19:2)_<F>_n-8 | FA(19:3)_<FF>_n-8 | FA(19:4)_<FFF>_n-8 | FA(19:5)_<FFFF>_n-8 | FA(19:6)_<FFFFF>_n-8 | FA(20:1)_<>_n-9 | FA(20:2)_<F>_n-9 | FA(20:3)_<FF>_n-9 | FA(20:4)_<FFF>_n-9 | FA(20:5)_<FFFF>_n-9 | FA(20:6)_<FFFFF>_n-9 | FA(21:1)_<>_n-10 | FA(21:2)_<F>_n-10 | FA(21:3)_<FF>_n-10 | FA(21:4)_<FFF>_n-10 | FA(21:5)_<FFFF>_n-10 | FA(21:6)_<FFFFF>_n-10 | FA(22:1)_<>_n-11 | FA(22:2)_<F>_n-11 | FA(22:3)_<FF>_n-11 | FA(22:4)_<FFF>_n-11 | FA(22:5)_<FFFF>_n-11 | FA(22:6)_<FFFFF>_n-11 | FA(23:1)_<>_n-12 | FA(23:2)_<F>_n-12 | FA(23:3)_<FF>_n-12 | FA(23:4)_<FFF>_n-12 | FA(23:5)_<FFFF>_n-12 | FA(23:6)_<FFFFF>_n-12 | FA(24:1)_<>_n-13 | FA(24:2)_<F>_n-13 | FA(24:3)_<FF>_n-13 | FA(24:4)_<FFF>_n-13 | FA(24:5)_<FFFF>_n-13 | FA(24:6)_<FFFFF>_n-13 | FA(25:1)_<>_n-14 | FA(25:2)_<F>_n-14 | FA(25:3)_<FF>_n-14 | FA(25:4)_<FFF>_n-14 | FA(25:5)_<FFFF>_n-14 | FA(25:6)_<FFFFF>_n-14 | FA(26:1)_<>_n-15 | FA(26:2)_<F>_n-15 | FA(26:3)_<FF>_n-15 | FA(26:4)_<FFF>_n-15 | FA(26:5)_<FFFF>_n-15 | FA(26:6)_<FFFFF>_n-15 | FA(27:1)_<>_n-16 | FA(27:2)_<F>_n-16 | FA(27:3)_<FF>_n-16 | FA(27:4)_<FFF>_n-16 | FA(27:5)_<FFFF>_n-16 | FA(27:6)_<FFFFF>_n-16 | FA(28:1)_<>_n-17 | FA(28:2)_<F>_n-17 | FA(28:3)_<FF>_n-17 | FA(28:4)_<FFF>_n-17 | FA(28:5)_<FFFF>_n-17 | FA(28:6)_<FFFFF>_n-17 | FA(29:1)_<>_n-18 | FA(29:2)_<F>_n-18 | FA(29:3)_<FF>_n-18 | FA(29:4)_<FFF>_n-18 | FA(29:5)_<FFFF>_n-18 | FA(29:6)_<FFFFF>_n-18 | FA(30:1)_<>_n-19 | FA(30:2)_<F>_n-19 | FA(30:3)_<FF>_n-19 | FA(30:4)_<FFF>_n-19 | FA(30:5)_<FFFF>_n-19 | FA(30:6)_<FFFFF>_n-19'
#  'FA(12:3)_<BB>_n-2 | FA(12:4)_<BBF>_n-2 | FA(13:3)_<BB>_n-3 | FA(13:4)_<BBF>_n-3 | FA(13:5)_<BBFF>_n-3 | FA(14:3)_<BB>_n-4 | FA(14:4)_<BBF>_n-4 | FA(14:5)_<BBFF>_n-4 | FA(14:6)_<BBFFF>_n-4 | FA(15:3)_<BB>_n-5 | FA(15:4)_<BBF>_n-5 | FA(15:5)_<BBFF>_n-5 | FA(15:6)_<BBFFF>_n-5 | FA(16:3)_<BB>_n-6 | FA(16:4)_<BBF>_n-6 | FA(16:5)_<BBFF>_n-6 | FA(16:6)_<BBFFF>_n-6 | FA(17:3)_<BB>_n-7 | FA(17:4)_<BBF>_n-7 | FA(17:5)_<BBFF>_n-7 | FA(17:6)_<BBFFF>_n-7 | FA(18:3)_<BB>_n-8 | FA(18:4)_<BBF>_n-8 | FA(18:5)_<BBFF>_n-8 | FA(18:6)_<BBFFF>_n-8 | FA(19:3)_<BB>_n-9 | FA(19:4)_<BBF>_n-9 | FA(19:5)_<BBFF>_n-9 | FA(19:6)_<BBFFF>_n-9 | FA(20:3)_<BB>_n-10 | FA(20:4)_<BBF>_n-10 | FA(20:5)_<BBFF>_n-10 | FA(20:6)_<BBFFF>_n-10 | FA(21:3)_<BB>_n-11 | FA(21:4)_<BBF>_n-11 | FA(21:5)_<BBFF>_n-11 | FA(21:6)_<BBFFF>_n-11 | FA(22:3)_<BB>_n-12 | FA(22:4)_<BBF>_n-12 | FA(22:5)_<BBFF>_n-12 | FA(22:6)_<BBFFF>_n-12 | FA(23:3)_<BB>_n-13 | FA(23:4)_<BBF>_n-13 | FA(23:5)_<BBFF>_n-13 | FA(23:6)_<BBFFF>_n-13 | FA(24:3)_<BB>_n-14 | FA(24:4)_<BBF>_n-14 | FA(24:5)_<BBFF>_n-14 | FA(24:6)_<BBFFF>_n-14 | FA(25:3)_<BB>_n-15 | FA(25:4)_<BBF>_n-15 | FA(25:5)_<BBFF>_n-15 | FA(25:6)_<BBFFF>_n-15 | FA(26:3)_<BB>_n-16 | FA(26:4)_<BBF>_n-16 | FA(26:5)_<BBFF>_n-16 | FA(26:6)_<BBFFF>_n-16 | FA(27:3)_<BB>_n-17 | FA(27:4)_<BBF>_n-17 | FA(27:5)_<BBFF>_n-17 | FA(27:6)_<BBFFF>_n-17'
#  'FA(13:0) | FA(14:1)_<>_n-2 | FA(14:2)_<F>_n-2 | FA(15:1)_<>_n-3 | FA(15:2)_<F>_n-3 | FA(15:3)_<FF>_n-3 | FA(16:1)_<>_n-4 | FA(16:2)_<F>_n-4 | FA(16:3)_<FF>_n-4 | FA(16:4)_<FFF>_n-4 | FA(17:1)_<>_n-5 | FA(17:2)_<F>_n-5 | FA(17:3)_<FF>_n-5 | FA(17:4)_<FFF>_n-5 | FA(17:5)_<FFFF>_n-5 | FA(18:1)_<>_n-6 | FA(18:2)_<F>_n-6 | FA(18:3)_<FF>_n-6 | FA(18:4)_<FFF>_n-6 | FA(18:5)_<FFFF>_n-6 | FA(18:6)_<FFFFF>_n-6 | FA(19:1)_<>_n-7 | FA(19:2)_<F>_n-7 | FA(19:3)_<FF>_n-7 | FA(19:4)_<FFF>_n-7 | FA(19:5)_<FFFF>_n-7 | FA(19:6)_<FFFFF>_n-7 | FA(20:1)_<>_n-8 | FA(20:2)_<F>_n-8 | FA(20:3)_<FF>_n-8 | FA(20:4)_<FFF>_n-8 | FA(20:5)_<FFFF>_n-8 | FA(20:6)_<FFFFF>_n-8 | FA(21:1)_<>_n-9 | FA(21:2)_<F>_n-9 | FA(21:3)_<FF>_n-9 | FA(21:4)_<FFF>_n-9 | FA(21:5)_<FFFF>_n-9 | FA(21:6)_<FFFFF>_n-9 | FA(22:1)_<>_n-10 | FA(22:2)_<F>_n-10 | FA(22:3)_<FF>_n-10 | FA(22:4)_<FFF>_n-10 | FA(22:5)_<FFFF>_n-10 | FA(22:6)_<FFFFF>_n-10 | FA(23:1)_<>_n-11 | FA(23:2)_<F>_n-11 | FA(23:3)_<FF>_n-11 | FA(23:4)_<FFF>_n-11 | FA(23:5)_<FFFF>_n-11 | FA(23:6)_<FFFFF>_n-11 | FA(24:1)_<>_n-12 | FA(24:2)_<F>_n-12 | FA(24:3)_<FF>_n-12 | FA(24:4)_<FFF>_n-12 | FA(24:5)_<FFFF>_n-12 | FA(24:6)_<FFFFF>_n-12 | FA(25:1)_<>_n-13 | FA(25:2)_<F>_n-13 | FA(25:3)_<FF>_n-13 | FA(25:4)_<FFF>_n-13 | FA(25:5)_<FFFF>_n-13 | FA(25:6)_<FFFFF>_n-13 | FA(26:1)_<>_n-14 | FA(26:2)_<F>_n-14 | FA(26:3)_<FF>_n-14 | FA(26:4)_<FFF>_n-14 | FA(26:5)_<FFFF>_n-14 | FA(26:6)_<FFFFF>_n-14 | FA(27:1)_<>_n-15 | FA(27:2)_<F>_n-15 | FA(27:3)_<FF>_n-15 | FA(27:4)_<FFF>_n-15 | FA(27:5)_<FFFF>_n-15 | FA(27:6)_<FFFFF>_n-15 | FA(28:1)_<>_n-16 | FA(28:2)_<F>_n-16 | FA(28:3)_<FF>_n-16 | FA(28:4)_<FFF>_n-16 | FA(28:5)_<FFFF>_n-16 | FA(28:6)_<FFFFF>_n-16 | FA(29:1)_<>_n-17 | FA(29:2)_<F>_n-17 | FA(29:3)_<FF>_n-17 | FA(29:4)_<FFF>_n-17 | FA(29:5)_<FFFF>_n-17 | FA(29:6)_<FFFFF>_n-17 | FA(30:1)_<>_n-18 | FA(30:2)_<F>_n-18 | FA(30:3)_<FF>_n-18 | FA(30:4)_<FFF>_n-18 | FA(30:5)_<FFFF>_n-18 | FA(30:6)_<FFFFF>_n-18'
#  'FA(13:2)_<B>_n-2 | FA(13:3)_<BF>_n-2 | FA(14:2)_<B>_n-3 | FA(14:3)_<BF>_n-3 | FA(14:4)_<BFF>_n-3 | FA(15:2)_<B>_n-4 | FA(15:3)_<BF>_n-4 | FA(15:4)_<BFF>_n-4 | FA(15:5)_<BFFF>_n-4 | FA(16:2)_<B>_n-5 | FA(16:3)_<BF>_n-5 | FA(16:4)_<BFF>_n-5 | FA(16:5)_<BFFF>_n-5 | FA(16:6)_<BFFFF>_n-5 | FA(17:2)_<B>_n-6 | FA(17:3)_<BF>_n-6 | FA(17:4)_<BFF>_n-6 | FA(17:5)_<BFFF>_n-6 | FA(17:6)_<BFFFF>_n-6 | FA(18:2)_<B>_n-7 | FA(18:3)_<BF>_n-7 | FA(18:4)_<BFF>_n-7 | FA(18:5)_<BFFF>_n-7 | FA(18:6)_<BFFFF>_n-7 | FA(19:2)_<B>_n-8 | FA(19:3)_<BF>_n-8 | FA(19:4)_<BFF>_n-8 | FA(19:5)_<BFFF>_n-8 | FA(19:6)_<BFFFF>_n-8 | FA(20:2)_<B>_n-9 | FA(20:3)_<BF>_n-9 | FA(20:4)_<BFF>_n-9 | FA(20:5)_<BFFF>_n-9 | FA(20:6)_<BFFFF>_n-9 | FA(21:2)_<B>_n-10 | FA(21:3)_<BF>_n-10 | FA(21:4)_<BFF>_n-10 | FA(21:5)_<BFFF>_n-10 | FA(21:6)_<BFFFF>_n-10 | FA(22:2)_<B>_n-11 | FA(22:3)_<BF>_n-11 | FA(22:4)_<BFF>_n-11 | FA(22:5)_<BFFF>_n-11 | FA(22:6)_<BFFFF>_n-11 | FA(23:2)_<B>_n-12 | FA(23:3)_<BF>_n-12 | FA(23:4)_<BFF>_n-12 | FA(23:5)_<BFFF>_n-12 | FA(23:6)_<BFFFF>_n-12 | FA(24:2)_<B>_n-13 | FA(24:3)_<BF>_n-13 | FA(24:4)_<BFF>_n-13 | FA(24:5)_<BFFF>_n-13 | FA(24:6)_<BFFFF>_n-13 | FA(25:2)_<B>_n-14 | FA(25:3)_<BF>_n-14 | FA(25:4)_<BFF>_n-14 | FA(25:5)_<BFFF>_n-14 | FA(25:6)_<BFFFF>_n-14 | FA(26:2)_<B>_n-15 | FA(26:3)_<BF>_n-15 | FA(26:4)_<BFF>_n-15 | FA(26:5)_<BFFF>_n-15 | FA(26:6)_<BFFFF>_n-15 | FA(27:2)_<B>_n-16 | FA(27:3)_<BF>_n-16 | FA(27:4)_<BFF>_n-16 | FA(27:5)_<BFFF>_n-16 | FA(27:6)_<BFFFF>_n-16'
#  'FA(13:3)_<BB>_n-2 | FA(13:4)_<BBF>_n-2 | FA(14:3)_<BB>_n-3 | FA(14:4)_<BBF>_n-3 | FA(14:5)_<BBFF>_n-3 | FA(15:3)_<BB>_n-4 | FA(15:4)_<BBF>_n-4 | FA(15:5)_<BBFF>_n-4 | FA(15:6)_<BBFFF>_n-4 | FA(16:3)_<BB>_n-5 | FA(16:4)_<BBF>_n-5 | FA(16:5)_<BBFF>_n-5 | FA(16:6)_<BBFFF>_n-5 | FA(17:3)_<BB>_n-6 | FA(17:4)_<BBF>_n-6 | FA(17:5)_<BBFF>_n-6 | FA(17:6)_<BBFFF>_n-6 | FA(18:3)_<BB>_n-7 | FA(18:4)_<BBF>_n-7 | FA(18:5)_<BBFF>_n-7 | FA(18:6)_<BBFFF>_n-7 | FA(19:3)_<BB>_n-8 | FA(19:4)_<BBF>_n-8 | FA(19:5)_<BBFF>_n-8 | FA(19:6)_<BBFFF>_n-8 | FA(20:3)_<BB>_n-9 | FA(20:4)_<BBF>_n-9 | FA(20:5)_<BBFF>_n-9 | FA(20:6)_<BBFFF>_n-9 | FA(21:3)_<BB>_n-10 | FA(21:4)_<BBF>_n-10 | FA(21:5)_<BBFF>_n-10 | FA(21:6)_<BBFFF>_n-10 | FA(22:3)_<BB>_n-11 | FA(22:4)_<BBF>_n-11 | FA(22:5)_<BBFF>_n-11 | FA(22:6)_<BBFFF>_n-11 | FA(23:3)_<BB>_n-12 | FA(23:4)_<BBF>_n-12 | FA(23:5)_<BBFF>_n-12 | FA(23:6)_<BBFFF>_n-12 | FA(24:3)_<BB>_n-13 | FA(24:4)_<BBF>_n-13 | FA(24:5)_<BBFF>_n-13 | FA(24:6)_<BBFFF>_n-13 | FA(25:3)_<BB>_n-14 | FA(25:4)_<BBF>_n-14 | FA(25:5)_<BBFF>_n-14 | FA(25:6)_<BBFFF>_n-14 | FA(26:3)_<BB>_n-15 | FA(26:4)_<BBF>_n-15 | FA(26:5)_<BBFF>_n-15 | FA(26:6)_<BBFFF>_n-15 | FA(27:3)_<BB>_n-16 | FA(27:4)_<BBF>_n-16 | FA(27:5)_<BBFF>_n-16 | FA(27:6)_<BBFFF>_n-16 | FA(28:3)_<BB>_n-17 | FA(28:4)_<BBF>_n-17 | FA(28:5)_<BBFF>_n-17 | FA(28:6)_<BBFFF>_n-17 | FA(29:3)_<BB>_n-18 | FA(29:4)_<BBF>_n-18 | FA(29:5)_<BBFF>_n-18 | FA(29:6)_<BBFFF>_n-18 | FA(30:3)_<BB>_n-19 | FA(30:4)_<BBF>_n-19 | FA(30:5)_<BBFF>_n-19 | FA(30:6)_<BBFFF>_n-19'
#  'FA(14:0) | FA(15:1)_<>_n-2 | FA(15:2)_<F>_n-2 | FA(16:1)_<>_n-3 | FA(16:2)_<F>_n-3 | FA(16:3)_<FF>_n-3 | FA(17:1)_<>_n-4 | FA(17:2)_<F>_n-4 | FA(17:3)_<FF>_n-4 | FA(17:4)_<FFF>_n-4 | FA(18:1)_<>_n-5 | FA(18:2)_<F>_n-5 | FA(18:3)_<FF>_n-5 | FA(18:4)_<FFF>_n-5 | FA(18:5)_<FFFF>_n-5 | FA(19:1)_<>_n-6 | FA(19:2)_<F>_n-6 | FA(19:3)_<FF>_n-6 | FA(19:4)_<FFF>_n-6 | FA(19:5)_<FFFF>_n-6 | FA(19:6)_<FFFFF>_n-6 | FA(20:1)_<>_n-7 | FA(20:2)_<F>_n-7 | FA(20:3)_<FF>_n-7 | FA(20:4)_<FFF>_n-7 | FA(20:5)_<FFFF>_n-7 | FA(20:6)_<FFFFF>_n-7 | FA(21:1)_<>_n-8 | FA(21:2)_<F>_n-8 | FA(21:3)_<FF>_n-8 | FA(21:4)_<FFF>_n-8 | FA(21:5)_<FFFF>_n-8 | FA(21:6)_<FFFFF>_n-8 | FA(22:1)_<>_n-9 | FA(22:2)_<F>_n-9 | FA(22:3)_<FF>_n-9 | FA(22:4)_<FFF>_n-9 | FA(22:5)_<FFFF>_n-9 | FA(22:6)_<FFFFF>_n-9 | FA(23:1)_<>_n-10 | FA(23:2)_<F>_n-10 | FA(23:3)_<FF>_n-10 | FA(23:4)_<FFF>_n-10 | FA(23:5)_<FFFF>_n-10 | FA(23:6)_<FFFFF>_n-10 | FA(24:1)_<>_n-11 | FA(24:2)_<F>_n-11 | FA(24:3)_<FF>_n-11 | FA(24:4)_<FFF>_n-11 | FA(24:5)_<FFFF>_n-11 | FA(24:6)_<FFFFF>_n-11 | FA(25:1)_<>_n-12 | FA(25:2)_<F>_n-12 | FA(25:3)_<FF>_n-12 | FA(25:4)_<FFF>_n-12 | FA(25:5)_<FFFF>_n-12 | FA(25:6)_<FFFFF>_n-12 | FA(26:1)_<>_n-13 | FA(26:2)_<F>_n-13 | FA(26:3)_<FF>_n-13 | FA(26:4)_<FFF>_n-13 | FA(26:5)_<FFFF>_n-13 | FA(26:6)_<FFFFF>_n-13 | FA(27:1)_<>_n-14 | FA(27:2)_<F>_n-14 | FA(27:3)_<FF>_n-14 | FA(27:4)_<FFF>_n-14 | FA(27:5)_<FFFF>_n-14 | FA(27:6)_<FFFFF>_n-14 | FA(28:1)_<>_n-15 | FA(28:2)_<F>_n-15 | FA(28:3)_<FF>_n-15 | FA(28:4)_<FFF>_n-15 | FA(28:5)_<FFFF>_n-15 | FA(28:6)_<FFFFF>_n-15 | FA(29:1)_<>_n-16 | FA(29:2)_<F>_n-16 | FA(29:3)_<FF>_n-16 | FA(29:4)_<FFF>_n-16 | FA(29:5)_<FFFF>_n-16 | FA(29:6)_<FFFFF>_n-16 | FA(30:1)_<>_n-17 | FA(30:2)_<F>_n-17 | FA(30:3)_<FF>_n-17 | FA(30:4)_<FFF>_n-17 | FA(30:5)_<FFFF>_n-17 | FA(30:6)_<FFFFF>_n-17'
#  'FA(14:2)_<B>_n-2 | FA(14:3)_<BF>_n-2 | FA(15:2)_<B>_n-3 | FA(15:3)_<BF>_n-3 | FA(15:4)_<BFF>_n-3 | FA(16:2)_<B>_n-4 | FA(16:3)_<BF>_n-4 | FA(16:4)_<BFF>_n-4 | FA(16:5)_<BFFF>_n-4 | FA(17:2)_<B>_n-5 | FA(17:3)_<BF>_n-5 | FA(17:4)_<BFF>_n-5 | FA(17:5)_<BFFF>_n-5 | FA(17:6)_<BFFFF>_n-5 | FA(18:2)_<B>_n-6 | FA(18:3)_<BF>_n-6 | FA(18:4)_<BFF>_n-6 | FA(18:5)_<BFFF>_n-6 | FA(18:6)_<BFFFF>_n-6 | FA(19:2)_<B>_n-7 | FA(19:3)_<BF>_n-7 | FA(19:4)_<BFF>_n-7 | FA(19:5)_<BFFF>_n-7 | FA(19:6)_<BFFFF>_n-7 | FA(20:2)_<B>_n-8 | FA(20:3)_<BF>_n-8 | FA(20:4)_<BFF>_n-8 | FA(20:5)_<BFFF>_n-8 | FA(20:6)_<BFFFF>_n-8 | FA(21:2)_<B>_n-9 | FA(21:3)_<BF>_n-9 | FA(21:4)_<BFF>_n-9 | FA(21:5)_<BFFF>_n-9 | FA(21:6)_<BFFFF>_n-9 | FA(22:2)_<B>_n-10 | FA(22:3)_<BF>_n-10 | FA(22:4)_<BFF>_n-10 | FA(22:5)_<BFFF>_n-10 | FA(22:6)_<BFFFF>_n-10 | FA(23:2)_<B>_n-11 | FA(23:3)_<BF>_n-11 | FA(23:4)_<BFF>_n-11 | FA(23:5)_<BFFF>_n-11 | FA(23:6)_<BFFFF>_n-11 | FA(24:2)_<B>_n-12 | FA(24:3)_<BF>_n-12 | FA(24:4)_<BFF>_n-12 | FA(24:5)_<BFFF>_n-12 | FA(24:6)_<BFFFF>_n-12 | FA(25:2)_<B>_n-13 | FA(25:3)_<BF>_n-13 | FA(25:4)_<BFF>_n-13 | FA(25:5)_<BFFF>_n-13 | FA(25:6)_<BFFFF>_n-13 | FA(26:2)_<B>_n-14 | FA(26:3)_<BF>_n-14 | FA(26:4)_<BFF>_n-14 | FA(26:5)_<BFFF>_n-14 | FA(26:6)_<BFFFF>_n-14 | FA(27:2)_<B>_n-15 | FA(27:3)_<BF>_n-15 | FA(27:4)_<BFF>_n-15 | FA(27:5)_<BFFF>_n-15 | FA(27:6)_<BFFFF>_n-15 | FA(28:2)_<B>_n-16 | FA(28:3)_<BF>_n-16 | FA(28:4)_<BFF>_n-16 | FA(28:5)_<BFFF>_n-16 | FA(28:6)_<BFFFF>_n-16 | FA(29:2)_<B>_n-17 | FA(29:3)_<BF>_n-17 | FA(29:4)_<BFF>_n-17 | FA(29:5)_<BFFF>_n-17 | FA(29:6)_<BFFFF>_n-17 | FA(30:2)_<B>_n-18 | FA(30:3)_<BF>_n-18 | FA(30:4)_<BFF>_n-18 | FA(30:5)_<BFFF>_n-18 | FA(30:6)_<BFFFF>_n-18'
#  'FA(14:3)_<BB>_n-2 | FA(14:4)_<BBF>_n-2 | FA(15:3)_<BB>_n-3 | FA(15:4)_<BBF>_n-3 | FA(15:5)_<BBFF>_n-3 | FA(16:3)_<BB>_n-4 | FA(16:4)_<BBF>_n-4 | FA(16:5)_<BBFF>_n-4 | FA(16:6)_<BBFFF>_n-4 | FA(17:3)_<BB>_n-5 | FA(17:4)_<BBF>_n-5 | FA(17:5)_<BBFF>_n-5 | FA(17:6)_<BBFFF>_n-5 | FA(18:3)_<BB>_n-6 | FA(18:4)_<BBF>_n-6 | FA(18:5)_<BBFF>_n-6 | FA(18:6)_<BBFFF>_n-6 | FA(19:3)_<BB>_n-7 | FA(19:4)_<BBF>_n-7 | FA(19:5)_<BBFF>_n-7 | FA(19:6)_<BBFFF>_n-7 | FA(20:3)_<BB>_n-8 | FA(20:4)_<BBF>_n-8 | FA(20:5)_<BBFF>_n-8 | FA(20:6)_<BBFFF>_n-8 | FA(21:3)_<BB>_n-9 | FA(21:4)_<BBF>_n-9 | FA(21:5)_<BBFF>_n-9 | FA(21:6)_<BBFFF>_n-9 | FA(22:3)_<BB>_n-10 | FA(22:4)_<BBF>_n-10 | FA(22:5)_<BBFF>_n-10 | FA(22:6)_<BBFFF>_n-10 | FA(23:3)_<BB>_n-11 | FA(23:4)_<BBF>_n-11 | FA(23:5)_<BBFF>_n-11 | FA(23:6)_<BBFFF>_n-11 | FA(24:3)_<BB>_n-12 | FA(24:4)_<BBF>_n-12 | FA(24:5)_<BBFF>_n-12 | FA(24:6)_<BBFFF>_n-12 | FA(25:3)_<BB>_n-13 | FA(25:4)_<BBF>_n-13 | FA(25:5)_<BBFF>_n-13 | FA(25:6)_<BBFFF>_n-13 | FA(26:3)_<BB>_n-14 | FA(26:4)_<BBF>_n-14 | FA(26:5)_<BBFF>_n-14 | FA(26:6)_<BBFFF>_n-14 | FA(27:3)_<BB>_n-15 | FA(27:4)_<BBF>_n-15 | FA(27:5)_<BBFF>_n-15 | FA(27:6)_<BBFFF>_n-15'
#  'FA(15:0) | FA(16:1)_<>_n-2 | FA(16:2)_<F>_n-2 | FA(17:1)_<>_n-3 | FA(17:2)_<F>_n-3 | FA(17:3)_<FF>_n-3 | FA(18:1)_<>_n-4 | FA(18:2)_<F>_n-4 | FA(18:3)_<FF>_n-4 | FA(18:4)_<FFF>_n-4 | FA(19:1)_<>_n-5 | FA(19:2)_<F>_n-5 | FA(19:3)_<FF>_n-5 | FA(19:4)_<FFF>_n-5 | FA(19:5)_<FFFF>_n-5 | FA(20:1)_<>_n-6 | FA(20:2)_<F>_n-6 | FA(20:3)_<FF>_n-6 | FA(20:4)_<FFF>_n-6 | FA(20:5)_<FFFF>_n-6 | FA(20:6)_<FFFFF>_n-6 | FA(21:1)_<>_n-7 | FA(21:2)_<F>_n-7 | FA(21:3)_<FF>_n-7 | FA(21:4)_<FFF>_n-7 | FA(21:5)_<FFFF>_n-7 | FA(21:6)_<FFFFF>_n-7 | FA(22:1)_<>_n-8 | FA(22:2)_<F>_n-8 | FA(22:3)_<FF>_n-8 | FA(22:4)_<FFF>_n-8 | FA(22:5)_<FFFF>_n-8 | FA(22:6)_<FFFFF>_n-8 | FA(23:1)_<>_n-9 | FA(23:2)_<F>_n-9 | FA(23:3)_<FF>_n-9 | FA(23:4)_<FFF>_n-9 | FA(23:5)_<FFFF>_n-9 | FA(23:6)_<FFFFF>_n-9 | FA(24:1)_<>_n-10 | FA(24:2)_<F>_n-10 | FA(24:3)_<FF>_n-10 | FA(24:4)_<FFF>_n-10 | FA(24:5)_<FFFF>_n-10 | FA(24:6)_<FFFFF>_n-10 | FA(25:1)_<>_n-11 | FA(25:2)_<F>_n-11 | FA(25:3)_<FF>_n-11 | FA(25:4)_<FFF>_n-11 | FA(25:5)_<FFFF>_n-11 | FA(25:6)_<FFFFF>_n-11 | FA(26:1)_<>_n-12 | FA(26:2)_<F>_n-12 | FA(26:3)_<FF>_n-12 | FA(26:4)_<FFF>_n-12 | FA(26:5)_<FFFF>_n-12 | FA(26:6)_<FFFFF>_n-12 | FA(27:1)_<>_n-13 | FA(27:2)_<F>_n-13 | FA(27:3)_<FF>_n-13 | FA(27:4)_<FFF>_n-13 | FA(27:5)_<FFFF>_n-13 | FA(27:6)_<FFFFF>_n-13 | FA(28:1)_<>_n-14 | FA(28:2)_<F>_n-14 | FA(28:3)_<FF>_n-14 | FA(28:4)_<FFF>_n-14 | FA(28:5)_<FFFF>_n-14 | FA(28:6)_<FFFFF>_n-14 | FA(29:1)_<>_n-15 | FA(29:2)_<F>_n-15 | FA(29:3)_<FF>_n-15 | FA(29:4)_<FFF>_n-15 | FA(29:5)_<FFFF>_n-15 | FA(29:6)_<FFFFF>_n-15 | FA(30:1)_<>_n-16 | FA(30:2)_<F>_n-16 | FA(30:3)_<FF>_n-16 | FA(30:4)_<FFF>_n-16 | FA(30:5)_<FFFF>_n-16 | FA(30:6)_<FFFFF>_n-16'
#  'FA(15:2)_<B>_n-2 | FA(15:3)_<BF>_n-2 | FA(16:2)_<B>_n-3 | FA(16:3)_<BF>_n-3 | FA(16:4)_<BFF>_n-3 | FA(17:2)_<B>_n-4 | FA(17:3)_<BF>_n-4 | FA(17:4)_<BFF>_n-4 | FA(17:5)_<BFFF>_n-4 | FA(18:2)_<B>_n-5 | FA(18:3)_<BF>_n-5 | FA(18:4)_<BFF>_n-5 | FA(18:5)_<BFFF>_n-5 | FA(18:6)_<BFFFF>_n-5 | FA(19:2)_<B>_n-6 | FA(19:3)_<BF>_n-6 | FA(19:4)_<BFF>_n-6 | FA(19:5)_<BFFF>_n-6 | FA(19:6)_<BFFFF>_n-6 | FA(20:2)_<B>_n-7 | FA(20:3)_<BF>_n-7 | FA(20:4)_<BFF>_n-7 | FA(20:5)_<BFFF>_n-7 | FA(20:6)_<BFFFF>_n-7 | FA(21:2)_<B>_n-8 | FA(21:3)_<BF>_n-8 | FA(21:4)_<BFF>_n-8 | FA(21:5)_<BFFF>_n-8 | FA(21:6)_<BFFFF>_n-8 | FA(22:2)_<B>_n-9 | FA(22:3)_<BF>_n-9 | FA(22:4)_<BFF>_n-9 | FA(22:5)_<BFFF>_n-9 | FA(22:6)_<BFFFF>_n-9 | FA(23:2)_<B>_n-10 | FA(23:3)_<BF>_n-10 | FA(23:4)_<BFF>_n-10 | FA(23:5)_<BFFF>_n-10 | FA(23:6)_<BFFFF>_n-10 | FA(24:2)_<B>_n-11 | FA(24:3)_<BF>_n-11 | FA(24:4)_<BFF>_n-11 | FA(24:5)_<BFFF>_n-11 | FA(24:6)_<BFFFF>_n-11 | FA(25:2)_<B>_n-12 | FA(25:3)_<BF>_n-12 | FA(25:4)_<BFF>_n-12 | FA(25:5)_<BFFF>_n-12 | FA(25:6)_<BFFFF>_n-12 | FA(26:2)_<B>_n-13 | FA(26:3)_<BF>_n-13 | FA(26:4)_<BFF>_n-13 | FA(26:5)_<BFFF>_n-13 | FA(26:6)_<BFFFF>_n-13 | FA(27:2)_<B>_n-14 | FA(27:3)_<BF>_n-14 | FA(27:4)_<BFF>_n-14 | FA(27:5)_<BFFF>_n-14 | FA(27:6)_<BFFFF>_n-14 | FA(28:2)_<B>_n-15 | FA(28:3)_<BF>_n-15 | FA(28:4)_<BFF>_n-15 | FA(28:5)_<BFFF>_n-15 | FA(28:6)_<BFFFF>_n-15 | FA(29:2)_<B>_n-16 | FA(29:3)_<BF>_n-16 | FA(29:4)_<BFF>_n-16 | FA(29:5)_<BFFF>_n-16 | FA(29:6)_<BFFFF>_n-16 | FA(30:2)_<B>_n-17 | FA(30:3)_<BF>_n-17 | FA(30:4)_<BFF>_n-17 | FA(30:5)_<BFFF>_n-17 | FA(30:6)_<BFFFF>_n-17'
#  'FA(15:4)_<BBB>_n-2 | FA(15:5)_<BBBF>_n-2 | FA(16:4)_<BBB>_n-3 | FA(16:5)_<BBBF>_n-3 | FA(16:6)_<BBBFF>_n-3 | FA(17:4)_<BBB>_n-4 | FA(17:5)_<BBBF>_n-4 | FA(17:6)_<BBBFF>_n-4 | FA(18:4)_<BBB>_n-5 | FA(18:5)_<BBBF>_n-5 | FA(18:6)_<BBBFF>_n-5 | FA(19:4)_<BBB>_n-6 | FA(19:5)_<BBBF>_n-6 | FA(19:6)_<BBBFF>_n-6 | FA(20:4)_<BBB>_n-7 | FA(20:5)_<BBBF>_n-7 | FA(20:6)_<BBBFF>_n-7 | FA(21:4)_<BBB>_n-8 | FA(21:5)_<BBBF>_n-8 | FA(21:6)_<BBBFF>_n-8 | FA(22:4)_<BBB>_n-9 | FA(22:5)_<BBBF>_n-9 | FA(22:6)_<BBBFF>_n-9 | FA(23:4)_<BBB>_n-10 | FA(23:5)_<BBBF>_n-10 | FA(23:6)_<BBBFF>_n-10 | FA(24:4)_<BBB>_n-11 | FA(24:5)_<BBBF>_n-11 | FA(24:6)_<BBBFF>_n-11 | FA(25:4)_<BBB>_n-12 | FA(25:5)_<BBBF>_n-12 | FA(25:6)_<BBBFF>_n-12 | FA(26:4)_<BBB>_n-13 | FA(26:5)_<BBBF>_n-13 | FA(26:6)_<BBBFF>_n-13 | FA(27:4)_<BBB>_n-14 | FA(27:5)_<BBBF>_n-14 | FA(27:6)_<BBBFF>_n-14 | FA(28:4)_<BBB>_n-15 | FA(28:5)_<BBBF>_n-15 | FA(28:6)_<BBBFF>_n-15 | FA(29:4)_<BBB>_n-16 | FA(29:5)_<BBBF>_n-16 | FA(29:6)_<BBBFF>_n-16 | FA(30:4)_<BBB>_n-17 | FA(30:5)_<BBBF>_n-17 | FA(30:6)_<BBBFF>_n-17'
#  'FA(16:0) | FA(17:1)_<>_n-2 | FA(17:2)_<F>_n-2 | FA(18:1)_<>_n-3 | FA(18:2)_<F>_n-3 | FA(18:3)_<FF>_n-3 | FA(19:1)_<>_n-4 | FA(19:2)_<F>_n-4 | FA(19:3)_<FF>_n-4 | FA(19:4)_<FFF>_n-4 | FA(20:1)_<>_n-5 | FA(20:2)_<F>_n-5 | FA(20:3)_<FF>_n-5 | FA(20:4)_<FFF>_n-5 | FA(20:5)_<FFFF>_n-5 | FA(21:1)_<>_n-6 | FA(21:2)_<F>_n-6 | FA(21:3)_<FF>_n-6 | FA(21:4)_<FFF>_n-6 | FA(21:5)_<FFFF>_n-6 | FA(21:6)_<FFFFF>_n-6 | FA(22:1)_<>_n-7 | FA(22:2)_<F>_n-7 | FA(22:3)_<FF>_n-7 | FA(22:4)_<FFF>_n-7 | FA(22:5)_<FFFF>_n-7 | FA(22:6)_<FFFFF>_n-7 | FA(23:1)_<>_n-8 | FA(23:2)_<F>_n-8 | FA(23:3)_<FF>_n-8 | FA(23:4)_<FFF>_n-8 | FA(23:5)_<FFFF>_n-8 | FA(23:6)_<FFFFF>_n-8 | FA(24:1)_<>_n-9 | FA(24:2)_<F>_n-9 | FA(24:3)_<FF>_n-9 | FA(24:4)_<FFF>_n-9 | FA(24:5)_<FFFF>_n-9 | FA(24:6)_<FFFFF>_n-9 | FA(25:1)_<>_n-10 | FA(25:2)_<F>_n-10 | FA(25:3)_<FF>_n-10 | FA(25:4)_<FFF>_n-10 | FA(25:5)_<FFFF>_n-10 | FA(25:6)_<FFFFF>_n-10 | FA(26:1)_<>_n-11 | FA(26:2)_<F>_n-11 | FA(26:3)_<FF>_n-11 | FA(26:4)_<FFF>_n-11 | FA(26:5)_<FFFF>_n-11 | FA(26:6)_<FFFFF>_n-11 | FA(27:1)_<>_n-12 | FA(27:2)_<F>_n-12 | FA(27:3)_<FF>_n-12 | FA(27:4)_<FFF>_n-12 | FA(27:5)_<FFFF>_n-12 | FA(27:6)_<FFFFF>_n-12 | FA(28:1)_<>_n-13 | FA(28:2)_<F>_n-13 | FA(28:3)_<FF>_n-13 | FA(28:4)_<FFF>_n-13 | FA(28:5)_<FFFF>_n-13 | FA(28:6)_<FFFFF>_n-13 | FA(29:1)_<>_n-14 | FA(29:2)_<F>_n-14 | FA(29:3)_<FF>_n-14 | FA(29:4)_<FFF>_n-14 | FA(29:5)_<FFFF>_n-14 | FA(29:6)_<FFFFF>_n-14 | FA(30:1)_<>_n-15 | FA(30:2)_<F>_n-15 | FA(30:3)_<FF>_n-15 | FA(30:4)_<FFF>_n-15 | FA(30:5)_<FFFF>_n-15 | FA(30:6)_<FFFFF>_n-15'
#  'FA(16:2)_<B>_n-2 | FA(16:3)_<BF>_n-2 | FA(17:2)_<B>_n-3 | FA(17:3)_<BF>_n-3 | FA(17:4)_<BFF>_n-3 | FA(18:2)_<B>_n-4 | FA(18:3)_<BF>_n-4 | FA(18:4)_<BFF>_n-4 | FA(18:5)_<BFFF>_n-4 | FA(19:2)_<B>_n-5 | FA(19:3)_<BF>_n-5 | FA(19:4)_<BFF>_n-5 | FA(19:5)_<BFFF>_n-5 | FA(19:6)_<BFFFF>_n-5 | FA(20:2)_<B>_n-6 | FA(20:3)_<BF>_n-6 | FA(20:4)_<BFF>_n-6 | FA(20:5)_<BFFF>_n-6 | FA(20:6)_<BFFFF>_n-6 | FA(21:2)_<B>_n-7 | FA(21:3)_<BF>_n-7 | FA(21:4)_<BFF>_n-7 | FA(21:5)_<BFFF>_n-7 | FA(21:6)_<BFFFF>_n-7 | FA(22:2)_<B>_n-8 | FA(22:3)_<BF>_n-8 | FA(22:4)_<BFF>_n-8 | FA(22:5)_<BFFF>_n-8 | FA(22:6)_<BFFFF>_n-8 | FA(23:2)_<B>_n-9 | FA(23:3)_<BF>_n-9 | FA(23:4)_<BFF>_n-9 | FA(23:5)_<BFFF>_n-9 | FA(23:6)_<BFFFF>_n-9 | FA(24:2)_<B>_n-10 | FA(24:3)_<BF>_n-10 | FA(24:4)_<BFF>_n-10 | FA(24:5)_<BFFF>_n-10 | FA(24:6)_<BFFFF>_n-10 | FA(25:2)_<B>_n-11 | FA(25:3)_<BF>_n-11 | FA(25:4)_<BFF>_n-11 | FA(25:5)_<BFFF>_n-11 | FA(25:6)_<BFFFF>_n-11 | FA(26:2)_<B>_n-12 | FA(26:3)_<BF>_n-12 | FA(26:4)_<BFF>_n-12 | FA(26:5)_<BFFF>_n-12 | FA(26:6)_<BFFFF>_n-12 | FA(27:2)_<B>_n-13 | FA(27:3)_<BF>_n-13 | FA(27:4)_<BFF>_n-13 | FA(27:5)_<BFFF>_n-13 | FA(27:6)_<BFFFF>_n-13 | FA(28:2)_<B>_n-14 | FA(28:3)_<BF>_n-14 | FA(28:4)_<BFF>_n-14 | FA(28:5)_<BFFF>_n-14 | FA(28:6)_<BFFFF>_n-14 | FA(29:2)_<B>_n-15 | FA(29:3)_<BF>_n-15 | FA(29:4)_<BFF>_n-15 | FA(29:5)_<BFFF>_n-15 | FA(29:6)_<BFFFF>_n-15 | FA(30:2)_<B>_n-16 | FA(30:3)_<BF>_n-16 | FA(30:4)_<BFF>_n-16 | FA(30:5)_<BFFF>_n-16 | FA(30:6)_<BFFFF>_n-16'
#  'FA(16:3)_<BB>_n-2 | FA(16:4)_<BBF>_n-2 | FA(17:3)_<BB>_n-3 | FA(17:4)_<BBF>_n-3 | FA(17:5)_<BBFF>_n-3 | FA(18:3)_<BB>_n-4 | FA(18:4)_<BBF>_n-4 | FA(18:5)_<BBFF>_n-4 | FA(18:6)_<BBFFF>_n-4 | FA(19:3)_<BB>_n-5 | FA(19:4)_<BBF>_n-5 | FA(19:5)_<BBFF>_n-5 | FA(19:6)_<BBFFF>_n-5 | FA(20:3)_<BB>_n-6 | FA(20:4)_<BBF>_n-6 | FA(20:5)_<BBFF>_n-6 | FA(20:6)_<BBFFF>_n-6 | FA(21:3)_<BB>_n-7 | FA(21:4)_<BBF>_n-7 | FA(21:5)_<BBFF>_n-7 | FA(21:6)_<BBFFF>_n-7 | FA(22:3)_<BB>_n-8 | FA(22:4)_<BBF>_n-8 | FA(22:5)_<BBFF>_n-8 | FA(22:6)_<BBFFF>_n-8 | FA(23:3)_<BB>_n-9 | FA(23:4)_<BBF>_n-9 | FA(23:5)_<BBFF>_n-9 | FA(23:6)_<BBFFF>_n-9 | FA(24:3)_<BB>_n-10 | FA(24:4)_<BBF>_n-10 | FA(24:5)_<BBFF>_n-10 | FA(24:6)_<BBFFF>_n-10 | FA(25:3)_<BB>_n-11 | FA(25:4)_<BBF>_n-11 | FA(25:5)_<BBFF>_n-11 | FA(25:6)_<BBFFF>_n-11 | FA(26:3)_<BB>_n-12 | FA(26:4)_<BBF>_n-12 | FA(26:5)_<BBFF>_n-12 | FA(26:6)_<BBFFF>_n-12 | FA(27:3)_<BB>_n-13 | FA(27:4)_<BBF>_n-13 | FA(27:5)_<BBFF>_n-13 | FA(27:6)_<BBFFF>_n-13'
#  'FA(16:4)_<BBB>_n-2 | FA(16:5)_<BBBF>_n-2 | FA(17:4)_<BBB>_n-3 | FA(17:5)_<BBBF>_n-3 | FA(17:6)_<BBBFF>_n-3 | FA(18:4)_<BBB>_n-4 | FA(18:5)_<BBBF>_n-4 | FA(18:6)_<BBBFF>_n-4 | FA(19:4)_<BBB>_n-5 | FA(19:5)_<BBBF>_n-5 | FA(19:6)_<BBBFF>_n-5 | FA(20:4)_<BBB>_n-6 | FA(20:5)_<BBBF>_n-6 | FA(20:6)_<BBBFF>_n-6 | FA(21:4)_<BBB>_n-7 | FA(21:5)_<BBBF>_n-7 | FA(21:6)_<BBBFF>_n-7 | FA(22:4)_<BBB>_n-8 | FA(22:5)_<BBBF>_n-8 | FA(22:6)_<BBBFF>_n-8 | FA(23:4)_<BBB>_n-9 | FA(23:5)_<BBBF>_n-9 | FA(23:6)_<BBBFF>_n-9 | FA(24:4)_<BBB>_n-10 | FA(24:5)_<BBBF>_n-10 | FA(24:6)_<BBBFF>_n-10 | FA(25:4)_<BBB>_n-11 | FA(25:5)_<BBBF>_n-11 | FA(25:6)_<BBBFF>_n-11 | FA(26:4)_<BBB>_n-12 | FA(26:5)_<BBBF>_n-12 | FA(26:6)_<BBBFF>_n-12 | FA(27:4)_<BBB>_n-13 | FA(27:5)_<BBBF>_n-13 | FA(27:6)_<BBBFF>_n-13'
#  'FA(17:0) | FA(18:1)_<>_n-2 | FA(18:2)_<F>_n-2 | FA(19:1)_<>_n-3 | FA(19:2)_<F>_n-3 | FA(19:3)_<FF>_n-3 | FA(20:1)_<>_n-4 | FA(20:2)_<F>_n-4 | FA(20:3)_<FF>_n-4 | FA(20:4)_<FFF>_n-4 | FA(21:1)_<>_n-5 | FA(21:2)_<F>_n-5 | FA(21:3)_<FF>_n-5 | FA(21:4)_<FFF>_n-5 | FA(21:5)_<FFFF>_n-5 | FA(22:1)_<>_n-6 | FA(22:2)_<F>_n-6 | FA(22:3)_<FF>_n-6 | FA(22:4)_<FFF>_n-6 | FA(22:5)_<FFFF>_n-6 | FA(22:6)_<FFFFF>_n-6 | FA(23:1)_<>_n-7 | FA(23:2)_<F>_n-7 | FA(23:3)_<FF>_n-7 | FA(23:4)_<FFF>_n-7 | FA(23:5)_<FFFF>_n-7 | FA(23:6)_<FFFFF>_n-7 | FA(24:1)_<>_n-8 | FA(24:2)_<F>_n-8 | FA(24:3)_<FF>_n-8 | FA(24:4)_<FFF>_n-8 | FA(24:5)_<FFFF>_n-8 | FA(24:6)_<FFFFF>_n-8 | FA(25:1)_<>_n-9 | FA(25:2)_<F>_n-9 | FA(25:3)_<FF>_n-9 | FA(25:4)_<FFF>_n-9 | FA(25:5)_<FFFF>_n-9 | FA(25:6)_<FFFFF>_n-9 | FA(26:1)_<>_n-10 | FA(26:2)_<F>_n-10 | FA(26:3)_<FF>_n-10 | FA(26:4)_<FFF>_n-10 | FA(26:5)_<FFFF>_n-10 | FA(26:6)_<FFFFF>_n-10 | FA(27:1)_<>_n-11 | FA(27:2)_<F>_n-11 | FA(27:3)_<FF>_n-11 | FA(27:4)_<FFF>_n-11 | FA(27:5)_<FFFF>_n-11 | FA(27:6)_<FFFFF>_n-11 | FA(28:1)_<>_n-12 | FA(28:2)_<F>_n-12 | FA(28:3)_<FF>_n-12 | FA(28:4)_<FFF>_n-12 | FA(28:5)_<FFFF>_n-12 | FA(28:6)_<FFFFF>_n-12 | FA(29:1)_<>_n-13 | FA(29:2)_<F>_n-13 | FA(29:3)_<FF>_n-13 | FA(29:4)_<FFF>_n-13 | FA(29:5)_<FFFF>_n-13 | FA(29:6)_<FFFFF>_n-13 | FA(30:1)_<>_n-14 | FA(30:2)_<F>_n-14 | FA(30:3)_<FF>_n-14 | FA(30:4)_<FFF>_n-14 | FA(30:5)_<FFFF>_n-14 | FA(30:6)_<FFFFF>_n-14'
#  'FA(17:2)_<B>_n-2 | FA(17:3)_<BF>_n-2 | FA(18:2)_<B>_n-3 | FA(18:3)_<BF>_n-3 | FA(18:4)_<BFF>_n-3 | FA(19:2)_<B>_n-4 | FA(19:3)_<BF>_n-4 | FA(19:4)_<BFF>_n-4 | FA(19:5)_<BFFF>_n-4 | FA(20:2)_<B>_n-5 | FA(20:3)_<BF>_n-5 | FA(20:4)_<BFF>_n-5 | FA(20:5)_<BFFF>_n-5 | FA(20:6)_<BFFFF>_n-5 | FA(21:2)_<B>_n-6 | FA(21:3)_<BF>_n-6 | FA(21:4)_<BFF>_n-6 | FA(21:5)_<BFFF>_n-6 | FA(21:6)_<BFFFF>_n-6 | FA(22:2)_<B>_n-7 | FA(22:3)_<BF>_n-7 | FA(22:4)_<BFF>_n-7 | FA(22:5)_<BFFF>_n-7 | FA(22:6)_<BFFFF>_n-7 | FA(23:2)_<B>_n-8 | FA(23:3)_<BF>_n-8 | FA(23:4)_<BFF>_n-8 | FA(23:5)_<BFFF>_n-8 | FA(23:6)_<BFFFF>_n-8 | FA(24:2)_<B>_n-9 | FA(24:3)_<BF>_n-9 | FA(24:4)_<BFF>_n-9 | FA(24:5)_<BFFF>_n-9 | FA(24:6)_<BFFFF>_n-9 | FA(25:2)_<B>_n-10 | FA(25:3)_<BF>_n-10 | FA(25:4)_<BFF>_n-10 | FA(25:5)_<BFFF>_n-10 | FA(25:6)_<BFFFF>_n-10 | FA(26:2)_<B>_n-11 | FA(26:3)_<BF>_n-11 | FA(26:4)_<BFF>_n-11 | FA(26:5)_<BFFF>_n-11 | FA(26:6)_<BFFFF>_n-11 | FA(27:2)_<B>_n-12 | FA(27:3)_<BF>_n-12 | FA(27:4)_<BFF>_n-12 | FA(27:5)_<BFFF>_n-12 | FA(27:6)_<BFFFF>_n-12 | FA(28:2)_<B>_n-13 | FA(28:3)_<BF>_n-13 | FA(28:4)_<BFF>_n-13 | FA(28:5)_<BFFF>_n-13 | FA(28:6)_<BFFFF>_n-13 | FA(29:2)_<B>_n-14 | FA(29:3)_<BF>_n-14 | FA(29:4)_<BFF>_n-14 | FA(29:5)_<BFFF>_n-14 | FA(29:6)_<BFFFF>_n-14 | FA(30:2)_<B>_n-15 | FA(30:3)_<BF>_n-15 | FA(30:4)_<BFF>_n-15 | FA(30:5)_<BFFF>_n-15 | FA(30:6)_<BFFFF>_n-15'
#  'FA(17:3)_<BB>_n-2 | FA(17:4)_<BBF>_n-2 | FA(18:3)_<BB>_n-3 | FA(18:4)_<BBF>_n-3 | FA(18:5)_<BBFF>_n-3 | FA(19:3)_<BB>_n-4 | FA(19:4)_<BBF>_n-4 | FA(19:5)_<BBFF>_n-4 | FA(19:6)_<BBFFF>_n-4 | FA(20:3)_<BB>_n-5 | FA(20:4)_<BBF>_n-5 | FA(20:5)_<BBFF>_n-5 | FA(20:6)_<BBFFF>_n-5 | FA(21:3)_<BB>_n-6 | FA(21:4)_<BBF>_n-6 | FA(21:5)_<BBFF>_n-6 | FA(21:6)_<BBFFF>_n-6 | FA(22:3)_<BB>_n-7 | FA(22:4)_<BBF>_n-7 | FA(22:5)_<BBFF>_n-7 | FA(22:6)_<BBFFF>_n-7 | FA(23:3)_<BB>_n-8 | FA(23:4)_<BBF>_n-8 | FA(23:5)_<BBFF>_n-8 | FA(23:6)_<BBFFF>_n-8 | FA(24:3)_<BB>_n-9 | FA(24:4)_<BBF>_n-9 | FA(24:5)_<BBFF>_n-9 | FA(24:6)_<BBFFF>_n-9 | FA(25:3)_<BB>_n-10 | FA(25:4)_<BBF>_n-10 | FA(25:5)_<BBFF>_n-10 | FA(25:6)_<BBFFF>_n-10 | FA(26:3)_<BB>_n-11 | FA(26:4)_<BBF>_n-11 | FA(26:5)_<BBFF>_n-11 | FA(26:6)_<BBFFF>_n-11 | FA(27:3)_<BB>_n-12 | FA(27:4)_<BBF>_n-12 | FA(27:5)_<BBFF>_n-12 | FA(27:6)_<BBFFF>_n-12 | FA(28:3)_<BB>_n-13 | FA(28:4)_<BBF>_n-13 | FA(28:5)_<BBFF>_n-13 | FA(28:6)_<BBFFF>_n-13 | FA(29:3)_<BB>_n-14 | FA(29:4)_<BBF>_n-14 | FA(29:5)_<BBFF>_n-14 | FA(29:6)_<BBFFF>_n-14 | FA(30:3)_<BB>_n-15 | FA(30:4)_<BBF>_n-15 | FA(30:5)_<BBFF>_n-15 | FA(30:6)_<BBFFF>_n-15'
#  'FA(18:0) | FA(19:1)_<>_n-2 | FA(19:2)_<F>_n-2 | FA(20:1)_<>_n-3 | FA(20:2)_<F>_n-3 | FA(20:3)_<FF>_n-3 | FA(21:1)_<>_n-4 | FA(21:2)_<F>_n-4 | FA(21:3)_<FF>_n-4 | FA(21:4)_<FFF>_n-4 | FA(22:1)_<>_n-5 | FA(22:2)_<F>_n-5 | FA(22:3)_<FF>_n-5 | FA(22:4)_<FFF>_n-5 | FA(22:5)_<FFFF>_n-5 | FA(23:1)_<>_n-6 | FA(23:2)_<F>_n-6 | FA(23:3)_<FF>_n-6 | FA(23:4)_<FFF>_n-6 | FA(23:5)_<FFFF>_n-6 | FA(23:6)_<FFFFF>_n-6 | FA(24:1)_<>_n-7 | FA(24:2)_<F>_n-7 | FA(24:3)_<FF>_n-7 | FA(24:4)_<FFF>_n-7 | FA(24:5)_<FFFF>_n-7 | FA(24:6)_<FFFFF>_n-7 | FA(25:1)_<>_n-8 | FA(25:2)_<F>_n-8 | FA(25:3)_<FF>_n-8 | FA(25:4)_<FFF>_n-8 | FA(25:5)_<FFFF>_n-8 | FA(25:6)_<FFFFF>_n-8 | FA(26:1)_<>_n-9 | FA(26:2)_<F>_n-9 | FA(26:3)_<FF>_n-9 | FA(26:4)_<FFF>_n-9 | FA(26:5)_<FFFF>_n-9 | FA(26:6)_<FFFFF>_n-9 | FA(27:1)_<>_n-10 | FA(27:2)_<F>_n-10 | FA(27:3)_<FF>_n-10 | FA(27:4)_<FFF>_n-10 | FA(27:5)_<FFFF>_n-10 | FA(27:6)_<FFFFF>_n-10 | FA(28:1)_<>_n-11 | FA(28:2)_<F>_n-11 | FA(28:3)_<FF>_n-11 | FA(28:4)_<FFF>_n-11 | FA(28:5)_<FFFF>_n-11 | FA(28:6)_<FFFFF>_n-11 | FA(29:1)_<>_n-12 | FA(29:2)_<F>_n-12 | FA(29:3)_<FF>_n-12 | FA(29:4)_<FFF>_n-12 | FA(29:5)_<FFFF>_n-12 | FA(29:6)_<FFFFF>_n-12 | FA(30:1)_<>_n-13 | FA(30:2)_<F>_n-13 | FA(30:3)_<FF>_n-13 | FA(30:4)_<FFF>_n-13 | FA(30:5)_<FFFF>_n-13 | FA(30:6)_<FFFFF>_n-13'
#  'FA(18:2)_<B>_n-2 | FA(18:3)_<BF>_n-2 | FA(19:2)_<B>_n-3 | FA(19:3)_<BF>_n-3 | FA(19:4)_<BFF>_n-3 | FA(20:2)_<B>_n-4 | FA(20:3)_<BF>_n-4 | FA(20:4)_<BFF>_n-4 | FA(20:5)_<BFFF>_n-4 | FA(21:2)_<B>_n-5 | FA(21:3)_<BF>_n-5 | FA(21:4)_<BFF>_n-5 | FA(21:5)_<BFFF>_n-5 | FA(21:6)_<BFFFF>_n-5 | FA(22:2)_<B>_n-6 | FA(22:3)_<BF>_n-6 | FA(22:4)_<BFF>_n-6 | FA(22:5)_<BFFF>_n-6 | FA(22:6)_<BFFFF>_n-6 | FA(23:2)_<B>_n-7 | FA(23:3)_<BF>_n-7 | FA(23:4)_<BFF>_n-7 | FA(23:5)_<BFFF>_n-7 | FA(23:6)_<BFFFF>_n-7 | FA(24:2)_<B>_n-8 | FA(24:3)_<BF>_n-8 | FA(24:4)_<BFF>_n-8 | FA(24:5)_<BFFF>_n-8 | FA(24:6)_<BFFFF>_n-8 | FA(25:2)_<B>_n-9 | FA(25:3)_<BF>_n-9 | FA(25:4)_<BFF>_n-9 | FA(25:5)_<BFFF>_n-9 | FA(25:6)_<BFFFF>_n-9 | FA(26:2)_<B>_n-10 | FA(26:3)_<BF>_n-10 | FA(26:4)_<BFF>_n-10 | FA(26:5)_<BFFF>_n-10 | FA(26:6)_<BFFFF>_n-10 | FA(27:2)_<B>_n-11 | FA(27:3)_<BF>_n-11 | FA(27:4)_<BFF>_n-11 | FA(27:5)_<BFFF>_n-11 | FA(27:6)_<BFFFF>_n-11 | FA(28:2)_<B>_n-12 | FA(28:3)_<BF>_n-12 | FA(28:4)_<BFF>_n-12 | FA(28:5)_<BFFF>_n-12 | FA(28:6)_<BFFFF>_n-12 | FA(29:2)_<B>_n-13 | FA(29:3)_<BF>_n-13 | FA(29:4)_<BFF>_n-13 | FA(29:5)_<BFFF>_n-13 | FA(29:6)_<BFFFF>_n-13 | FA(30:2)_<B>_n-14 | FA(30:3)_<BF>_n-14 | FA(30:4)_<BFF>_n-14 | FA(30:5)_<BFFF>_n-14 | FA(30:6)_<BFFFF>_n-14'
#  'FA(18:5)_<BBBB>_n-2 | FA(18:6)_<BBBBF>_n-2 | FA(19:5)_<BBBB>_n-3 | FA(19:6)_<BBBBF>_n-3 | FA(20:5)_<BBBB>_n-4 | FA(20:6)_<BBBBF>_n-4 | FA(21:5)_<BBBB>_n-5 | FA(21:6)_<BBBBF>_n-5 | FA(22:5)_<BBBB>_n-6 | FA(22:6)_<BBBBF>_n-6 | FA(23:5)_<BBBB>_n-7 | FA(23:6)_<BBBBF>_n-7 | FA(24:5)_<BBBB>_n-8 | FA(24:6)_<BBBBF>_n-8 | FA(25:5)_<BBBB>_n-9 | FA(25:6)_<BBBBF>_n-9 | FA(26:5)_<BBBB>_n-10 | FA(26:6)_<BBBBF>_n-10 | FA(27:5)_<BBBB>_n-11 | FA(27:6)_<BBBBF>_n-11'
#  'FA(19:0) | FA(20:1)_<>_n-2 | FA(20:2)_<F>_n-2 | FA(21:1)_<>_n-3 | FA(21:2)_<F>_n-3 | FA(21:3)_<FF>_n-3 | FA(22:1)_<>_n-4 | FA(22:2)_<F>_n-4 | FA(22:3)_<FF>_n-4 | FA(22:4)_<FFF>_n-4 | FA(23:1)_<>_n-5 | FA(23:2)_<F>_n-5 | FA(23:3)_<FF>_n-5 | FA(23:4)_<FFF>_n-5 | FA(23:5)_<FFFF>_n-5 | FA(24:1)_<>_n-6 | FA(24:2)_<F>_n-6 | FA(24:3)_<FF>_n-6 | FA(24:4)_<FFF>_n-6 | FA(24:5)_<FFFF>_n-6 | FA(24:6)_<FFFFF>_n-6 | FA(25:1)_<>_n-7 | FA(25:2)_<F>_n-7 | FA(25:3)_<FF>_n-7 | FA(25:4)_<FFF>_n-7 | FA(25:5)_<FFFF>_n-7 | FA(25:6)_<FFFFF>_n-7 | FA(26:1)_<>_n-8 | FA(26:2)_<F>_n-8 | FA(26:3)_<FF>_n-8 | FA(26:4)_<FFF>_n-8 | FA(26:5)_<FFFF>_n-8 | FA(26:6)_<FFFFF>_n-8 | FA(27:1)_<>_n-9 | FA(27:2)_<F>_n-9 | FA(27:3)_<FF>_n-9 | FA(27:4)_<FFF>_n-9 | FA(27:5)_<FFFF>_n-9 | FA(27:6)_<FFFFF>_n-9 | FA(28:1)_<>_n-10 | FA(28:2)_<F>_n-10 | FA(28:3)_<FF>_n-10 | FA(28:4)_<FFF>_n-10 | FA(28:5)_<FFFF>_n-10 | FA(28:6)_<FFFFF>_n-10 | FA(29:1)_<>_n-11 | FA(29:2)_<F>_n-11 | FA(29:3)_<FF>_n-11 | FA(29:4)_<FFF>_n-11 | FA(29:5)_<FFFF>_n-11 | FA(29:6)_<FFFFF>_n-11 | FA(30:1)_<>_n-12 | FA(30:2)_<F>_n-12 | FA(30:3)_<FF>_n-12 | FA(30:4)_<FFF>_n-12 | FA(30:5)_<FFFF>_n-12 | FA(30:6)_<FFFFF>_n-12'
#  'FA(19:2)_<B>_n-2 | FA(19:3)_<BF>_n-2 | FA(20:2)_<B>_n-3 | FA(20:3)_<BF>_n-3 | FA(20:4)_<BFF>_n-3 | FA(21:2)_<B>_n-4 | FA(21:3)_<BF>_n-4 | FA(21:4)_<BFF>_n-4 | FA(21:5)_<BFFF>_n-4 | FA(22:2)_<B>_n-5 | FA(22:3)_<BF>_n-5 | FA(22:4)_<BFF>_n-5 | FA(22:5)_<BFFF>_n-5 | FA(22:6)_<BFFFF>_n-5 | FA(23:2)_<B>_n-6 | FA(23:3)_<BF>_n-6 | FA(23:4)_<BFF>_n-6 | FA(23:5)_<BFFF>_n-6 | FA(23:6)_<BFFFF>_n-6 | FA(24:2)_<B>_n-7 | FA(24:3)_<BF>_n-7 | FA(24:4)_<BFF>_n-7 | FA(24:5)_<BFFF>_n-7 | FA(24:6)_<BFFFF>_n-7 | FA(25:2)_<B>_n-8 | FA(25:3)_<BF>_n-8 | FA(25:4)_<BFF>_n-8 | FA(25:5)_<BFFF>_n-8 | FA(25:6)_<BFFFF>_n-8 | FA(26:2)_<B>_n-9 | FA(26:3)_<BF>_n-9 | FA(26:4)_<BFF>_n-9 | FA(26:5)_<BFFF>_n-9 | FA(26:6)_<BFFFF>_n-9 | FA(27:2)_<B>_n-10 | FA(27:3)_<BF>_n-10 | FA(27:4)_<BFF>_n-10 | FA(27:5)_<BFFF>_n-10 | FA(27:6)_<BFFFF>_n-10 | FA(28:2)_<B>_n-11 | FA(28:3)_<BF>_n-11 | FA(28:4)_<BFF>_n-11 | FA(28:5)_<BFFF>_n-11 | FA(28:6)_<BFFFF>_n-11 | FA(29:2)_<B>_n-12 | FA(29:3)_<BF>_n-12 | FA(29:4)_<BFF>_n-12 | FA(29:5)_<BFFF>_n-12 | FA(29:6)_<BFFFF>_n-12 | FA(30:2)_<B>_n-13 | FA(30:3)_<BF>_n-13 | FA(30:4)_<BFF>_n-13 | FA(30:5)_<BFFF>_n-13 | FA(30:6)_<BFFFF>_n-13'
#  'FA(19:3)_<BB>_n-2 | FA(19:4)_<BBF>_n-2 | FA(20:3)_<BB>_n-3 | FA(20:4)_<BBF>_n-3 | FA(20:5)_<BBFF>_n-3 | FA(21:3)_<BB>_n-4 | FA(21:4)_<BBF>_n-4 | FA(21:5)_<BBFF>_n-4 | FA(21:6)_<BBFFF>_n-4 | FA(22:3)_<BB>_n-5 | FA(22:4)_<BBF>_n-5 | FA(22:5)_<BBFF>_n-5 | FA(22:6)_<BBFFF>_n-5 | FA(23:3)_<BB>_n-6 | FA(23:4)_<BBF>_n-6 | FA(23:5)_<BBFF>_n-6 | FA(23:6)_<BBFFF>_n-6 | FA(24:3)_<BB>_n-7 | FA(24:4)_<BBF>_n-7 | FA(24:5)_<BBFF>_n-7 | FA(24:6)_<BBFFF>_n-7 | FA(25:3)_<BB>_n-8 | FA(25:4)_<BBF>_n-8 | FA(25:5)_<BBFF>_n-8 | FA(25:6)_<BBFFF>_n-8 | FA(26:3)_<BB>_n-9 | FA(26:4)_<BBF>_n-9 | FA(26:5)_<BBFF>_n-9 | FA(26:6)_<BBFFF>_n-9 | FA(27:3)_<BB>_n-10 | FA(27:4)_<BBF>_n-10 | FA(27:5)_<BBFF>_n-10 | FA(27:6)_<BBFFF>_n-10 | FA(28:3)_<BB>_n-11 | FA(28:4)_<BBF>_n-11 | FA(28:5)_<BBFF>_n-11 | FA(28:6)_<BBFFF>_n-11 | FA(29:3)_<BB>_n-12 | FA(29:4)_<BBF>_n-12 | FA(29:5)_<BBFF>_n-12 | FA(29:6)_<BBFFF>_n-12 | FA(30:3)_<BB>_n-13 | FA(30:4)_<BBF>_n-13 | FA(30:5)_<BBFF>_n-13 | FA(30:6)_<BBFFF>_n-13'
#  'FA(19:4)_<BBB>_n-2 | FA(19:5)_<BBBF>_n-2 | FA(20:4)_<BBB>_n-3 | FA(20:5)_<BBBF>_n-3 | FA(20:6)_<BBBFF>_n-3 | FA(21:4)_<BBB>_n-4 | FA(21:5)_<BBBF>_n-4 | FA(21:6)_<BBBFF>_n-4 | FA(22:4)_<BBB>_n-5 | FA(22:5)_<BBBF>_n-5 | FA(22:6)_<BBBFF>_n-5 | FA(23:4)_<BBB>_n-6 | FA(23:5)_<BBBF>_n-6 | FA(23:6)_<BBBFF>_n-6 | FA(24:4)_<BBB>_n-7 | FA(24:5)_<BBBF>_n-7 | FA(24:6)_<BBBFF>_n-7 | FA(25:4)_<BBB>_n-8 | FA(25:5)_<BBBF>_n-8 | FA(25:6)_<BBBFF>_n-8 | FA(26:4)_<BBB>_n-9 | FA(26:5)_<BBBF>_n-9 | FA(26:6)_<BBBFF>_n-9 | FA(27:4)_<BBB>_n-10 | FA(27:5)_<BBBF>_n-10 | FA(27:6)_<BBBFF>_n-10 | FA(28:4)_<BBB>_n-11 | FA(28:5)_<BBBF>_n-11 | FA(28:6)_<BBBFF>_n-11 | FA(29:4)_<BBB>_n-12 | FA(29:5)_<BBBF>_n-12 | FA(29:6)_<BBBFF>_n-12 | FA(30:4)_<BBB>_n-13 | FA(30:5)_<BBBF>_n-13 | FA(30:6)_<BBBFF>_n-13'
#  'FA(19:5)_<BBBB>_n-2 | FA(19:6)_<BBBBF>_n-2 | FA(20:5)_<BBBB>_n-3 | FA(20:6)_<BBBBF>_n-3 | FA(21:5)_<BBBB>_n-4 | FA(21:6)_<BBBBF>_n-4 | FA(22:5)_<BBBB>_n-5 | FA(22:6)_<BBBBF>_n-5 | FA(23:5)_<BBBB>_n-6 | FA(23:6)_<BBBBF>_n-6 | FA(24:5)_<BBBB>_n-7 | FA(24:6)_<BBBBF>_n-7 | FA(25:5)_<BBBB>_n-8 | FA(25:6)_<BBBBF>_n-8 | FA(26:5)_<BBBB>_n-9 | FA(26:6)_<BBBBF>_n-9 | FA(27:5)_<BBBB>_n-10 | FA(27:6)_<BBBBF>_n-10 | FA(28:5)_<BBBB>_n-11 | FA(28:6)_<BBBBF>_n-11 | FA(29:5)_<BBBB>_n-12 | FA(29:6)_<BBBBF>_n-12 | FA(30:5)_<BBBB>_n-13 | FA(30:6)_<BBBBF>_n-13'
#  'FA(20:0) | FA(21:1)_<>_n-2 | FA(21:2)_<F>_n-2 | FA(22:1)_<>_n-3 | FA(22:2)_<F>_n-3 | FA(22:3)_<FF>_n-3 | FA(23:1)_<>_n-4 | FA(23:2)_<F>_n-4 | FA(23:3)_<FF>_n-4 | FA(23:4)_<FFF>_n-4 | FA(24:1)_<>_n-5 | FA(24:2)_<F>_n-5 | FA(24:3)_<FF>_n-5 | FA(24:4)_<FFF>_n-5 | FA(24:5)_<FFFF>_n-5 | FA(25:1)_<>_n-6 | FA(25:2)_<F>_n-6 | FA(25:3)_<FF>_n-6 | FA(25:4)_<FFF>_n-6 | FA(25:5)_<FFFF>_n-6 | FA(25:6)_<FFFFF>_n-6 | FA(26:1)_<>_n-7 | FA(26:2)_<F>_n-7 | FA(26:3)_<FF>_n-7 | FA(26:4)_<FFF>_n-7 | FA(26:5)_<FFFF>_n-7 | FA(26:6)_<FFFFF>_n-7 | FA(27:1)_<>_n-8 | FA(27:2)_<F>_n-8 | FA(27:3)_<FF>_n-8 | FA(27:4)_<FFF>_n-8 | FA(27:5)_<FFFF>_n-8 | FA(27:6)_<FFFFF>_n-8 | FA(28:1)_<>_n-9 | FA(28:2)_<F>_n-9 | FA(28:3)_<FF>_n-9 | FA(28:4)_<FFF>_n-9 | FA(28:5)_<FFFF>_n-9 | FA(28:6)_<FFFFF>_n-9 | FA(29:1)_<>_n-10 | FA(29:2)_<F>_n-10 | FA(29:3)_<FF>_n-10 | FA(29:4)_<FFF>_n-10 | FA(29:5)_<FFFF>_n-10 | FA(29:6)_<FFFFF>_n-10 | FA(30:1)_<>_n-11 | FA(30:2)_<F>_n-11 | FA(30:3)_<FF>_n-11 | FA(30:4)_<FFF>_n-11 | FA(30:5)_<FFFF>_n-11 | FA(30:6)_<FFFFF>_n-11'
#  'FA(21:0) | FA(22:1)_<>_n-2 | FA(22:2)_<F>_n-2 | FA(23:1)_<>_n-3 | FA(23:2)_<F>_n-3 | FA(23:3)_<FF>_n-3 | FA(24:1)_<>_n-4 | FA(24:2)_<F>_n-4 | FA(24:3)_<FF>_n-4 | FA(24:4)_<FFF>_n-4 | FA(25:1)_<>_n-5 | FA(25:2)_<F>_n-5 | FA(25:3)_<FF>_n-5 | FA(25:4)_<FFF>_n-5 | FA(25:5)_<FFFF>_n-5 | FA(26:1)_<>_n-6 | FA(26:2)_<F>_n-6 | FA(26:3)_<FF>_n-6 | FA(26:4)_<FFF>_n-6 | FA(26:5)_<FFFF>_n-6 | FA(26:6)_<FFFFF>_n-6 | FA(27:1)_<>_n-7 | FA(27:2)_<F>_n-7 | FA(27:3)_<FF>_n-7 | FA(27:4)_<FFF>_n-7 | FA(27:5)_<FFFF>_n-7 | FA(27:6)_<FFFFF>_n-7 | FA(28:1)_<>_n-8 | FA(28:2)_<F>_n-8 | FA(28:3)_<FF>_n-8 | FA(28:4)_<FFF>_n-8 | FA(28:5)_<FFFF>_n-8 | FA(28:6)_<FFFFF>_n-8 | FA(29:1)_<>_n-9 | FA(29:2)_<F>_n-9 | FA(29:3)_<FF>_n-9 | FA(29:4)_<FFF>_n-9 | FA(29:5)_<FFFF>_n-9 | FA(29:6)_<FFFFF>_n-9 | FA(30:1)_<>_n-10 | FA(30:2)_<F>_n-10 | FA(30:3)_<FF>_n-10 | FA(30:4)_<FFF>_n-10 | FA(30:5)_<FFFF>_n-10 | FA(30:6)_<FFFFF>_n-10'
#  'FA(21:2)_<B>_n-2 | FA(21:3)_<BF>_n-2 | FA(22:2)_<B>_n-3 | FA(22:3)_<BF>_n-3 | FA(22:4)_<BFF>_n-3 | FA(23:2)_<B>_n-4 | FA(23:3)_<BF>_n-4 | FA(23:4)_<BFF>_n-4 | FA(23:5)_<BFFF>_n-4 | FA(24:2)_<B>_n-5 | FA(24:3)_<BF>_n-5 | FA(24:4)_<BFF>_n-5 | FA(24:5)_<BFFF>_n-5 | FA(24:6)_<BFFFF>_n-5 | FA(25:2)_<B>_n-6 | FA(25:3)_<BF>_n-6 | FA(25:4)_<BFF>_n-6 | FA(25:5)_<BFFF>_n-6 | FA(25:6)_<BFFFF>_n-6 | FA(26:2)_<B>_n-7 | FA(26:3)_<BF>_n-7 | FA(26:4)_<BFF>_n-7 | FA(26:5)_<BFFF>_n-7 | FA(26:6)_<BFFFF>_n-7 | FA(27:2)_<B>_n-8 | FA(27:3)_<BF>_n-8 | FA(27:4)_<BFF>_n-8 | FA(27:5)_<BFFF>_n-8 | FA(27:6)_<BFFFF>_n-8 | FA(28:2)_<B>_n-9 | FA(28:3)_<BF>_n-9 | FA(28:4)_<BFF>_n-9 | FA(28:5)_<BFFF>_n-9 | FA(28:6)_<BFFFF>_n-9 | FA(29:2)_<B>_n-10 | FA(29:3)_<BF>_n-10 | FA(29:4)_<BFF>_n-10 | FA(29:5)_<BFFF>_n-10 | FA(29:6)_<BFFFF>_n-10 | FA(30:2)_<B>_n-11 | FA(30:3)_<BF>_n-11 | FA(30:4)_<BFF>_n-11 | FA(30:5)_<BFFF>_n-11 | FA(30:6)_<BFFFF>_n-11'
#  'FA(21:3)_<BB>_n-2 | FA(21:4)_<BBF>_n-2 | FA(22:3)_<BB>_n-3 | FA(22:4)_<BBF>_n-3 | FA(22:5)_<BBFF>_n-3 | FA(23:3)_<BB>_n-4 | FA(23:4)_<BBF>_n-4 | FA(23:5)_<BBFF>_n-4 | FA(23:6)_<BBFFF>_n-4 | FA(24:3)_<BB>_n-5 | FA(24:4)_<BBF>_n-5 | FA(24:5)_<BBFF>_n-5 | FA(24:6)_<BBFFF>_n-5 | FA(25:3)_<BB>_n-6 | FA(25:4)_<BBF>_n-6 | FA(25:5)_<BBFF>_n-6 | FA(25:6)_<BBFFF>_n-6 | FA(26:3)_<BB>_n-7 | FA(26:4)_<BBF>_n-7 | FA(26:5)_<BBFF>_n-7 | FA(26:6)_<BBFFF>_n-7 | FA(27:3)_<BB>_n-8 | FA(27:4)_<BBF>_n-8 | FA(27:5)_<BBFF>_n-8 | FA(27:6)_<BBFFF>_n-8 | FA(28:3)_<BB>_n-9 | FA(28:4)_<BBF>_n-9 | FA(28:5)_<BBFF>_n-9 | FA(28:6)_<BBFFF>_n-9 | FA(29:3)_<BB>_n-10 | FA(29:4)_<BBF>_n-10 | FA(29:5)_<BBFF>_n-10 | FA(29:6)_<BBFFF>_n-10 | FA(30:3)_<BB>_n-11 | FA(30:4)_<BBF>_n-11 | FA(30:5)_<BBFF>_n-11 | FA(30:6)_<BBFFF>_n-11'
#  'FA(21:4)_<BBB>_n-2 | FA(21:5)_<BBBF>_n-2 | FA(22:4)_<BBB>_n-3 | FA(22:5)_<BBBF>_n-3 | FA(22:6)_<BBBFF>_n-3 | FA(23:4)_<BBB>_n-4 | FA(23:5)_<BBBF>_n-4 | FA(23:6)_<BBBFF>_n-4 | FA(24:4)_<BBB>_n-5 | FA(24:5)_<BBBF>_n-5 | FA(24:6)_<BBBFF>_n-5 | FA(25:4)_<BBB>_n-6 | FA(25:5)_<BBBF>_n-6 | FA(25:6)_<BBBFF>_n-6 | FA(26:4)_<BBB>_n-7 | FA(26:5)_<BBBF>_n-7 | FA(26:6)_<BBBFF>_n-7 | FA(27:4)_<BBB>_n-8 | FA(27:5)_<BBBF>_n-8 | FA(27:6)_<BBBFF>_n-8 | FA(28:4)_<BBB>_n-9 | FA(28:5)_<BBBF>_n-9 | FA(28:6)_<BBBFF>_n-9 | FA(29:4)_<BBB>_n-10 | FA(29:5)_<BBBF>_n-10 | FA(29:6)_<BBBFF>_n-10 | FA(30:4)_<BBB>_n-11 | FA(30:5)_<BBBF>_n-11 | FA(30:6)_<BBBFF>_n-11'
#  'FA(21:5)_<BBBB>_n-2 | FA(21:6)_<BBBBF>_n-2 | FA(22:5)_<BBBB>_n-3 | FA(22:6)_<BBBBF>_n-3 | FA(23:5)_<BBBB>_n-4 | FA(23:6)_<BBBBF>_n-4 | FA(24:5)_<BBBB>_n-5 | FA(24:6)_<BBBBF>_n-5 | FA(25:5)_<BBBB>_n-6 | FA(25:6)_<BBBBF>_n-6 | FA(26:5)_<BBBB>_n-7 | FA(26:6)_<BBBBF>_n-7 | FA(27:5)_<BBBB>_n-8 | FA(27:6)_<BBBBF>_n-8 | FA(28:5)_<BBBB>_n-9 | FA(28:6)_<BBBBF>_n-9 | FA(29:5)_<BBBB>_n-10 | FA(29:6)_<BBBBF>_n-10 | FA(30:5)_<BBBB>_n-11 | FA(30:6)_<BBBBF>_n-11'
#  'FA(21:6)_<BBBBB>_n-2 | FA(22:6)_<BBBBB>_n-3 | FA(23:6)_<BBBBB>_n-4 | FA(24:6)_<BBBBB>_n-5 | FA(25:6)_<BBBBB>_n-6 | FA(26:6)_<BBBBB>_n-7 | FA(27:6)_<BBBBB>_n-8 | FA(28:6)_<BBBBB>_n-9 | FA(29:6)_<BBBBB>_n-10 | FA(30:6)_<BBBBB>_n-11'
#  'FA(22:0) | FA(23:1)_<>_n-2 | FA(23:2)_<F>_n-2 | FA(24:1)_<>_n-3 | FA(24:2)_<F>_n-3 | FA(24:3)_<FF>_n-3 | FA(25:1)_<>_n-4 | FA(25:2)_<F>_n-4 | FA(25:3)_<FF>_n-4 | FA(25:4)_<FFF>_n-4 | FA(26:1)_<>_n-5 | FA(26:2)_<F>_n-5 | FA(26:3)_<FF>_n-5 | FA(26:4)_<FFF>_n-5 | FA(26:5)_<FFFF>_n-5 | FA(27:1)_<>_n-6 | FA(27:2)_<F>_n-6 | FA(27:3)_<FF>_n-6 | FA(27:4)_<FFF>_n-6 | FA(27:5)_<FFFF>_n-6 | FA(27:6)_<FFFFF>_n-6 | FA(28:1)_<>_n-7 | FA(28:2)_<F>_n-7 | FA(28:3)_<FF>_n-7 | FA(28:4)_<FFF>_n-7 | FA(28:5)_<FFFF>_n-7 | FA(28:6)_<FFFFF>_n-7 | FA(29:1)_<>_n-8 | FA(29:2)_<F>_n-8 | FA(29:3)_<FF>_n-8 | FA(29:4)_<FFF>_n-8 | FA(29:5)_<FFFF>_n-8 | FA(29:6)_<FFFFF>_n-8 | FA(30:1)_<>_n-9 | FA(30:2)_<F>_n-9 | FA(30:3)_<FF>_n-9 | FA(30:4)_<FFF>_n-9 | FA(30:5)_<FFFF>_n-9 | FA(30:6)_<FFFFF>_n-9'
# ...
#  '14:2|14:3|15:2|15:3|15:4|16:2|16:3|16:4|16:5|17:2|17:3|17:4|17:5|17:6|18:2|18:3|18:4|18:5|18:6|19:2|19:3|19:4|19:5|19:6|20:2|20:3|20:4|20:5|20:6|21:2|21:3|21:4|21:5|21:6|22:2|22:3|22:4|22:5|22:6|23:2|23:3|23:4|23:5|23:6|24:2|24:3|24:4|24:5|24:6|25:2|25:3|25:4|25:5|25:6|26:2|26:3|26:4|26:5|26:6|27:2|27:3|27:4|27:5|27:6|28:2|28:3|28:4|28:5|28:6|29:2|29:3|29:4|29:5|29:6|30:2|30:3|30:4|30:5|30:6'
#  '14:3|14:4|15:3|15:4|15:5|16:3|16:4|16:5|16:6|17:3|17:4|17:5|17:6|18:3|18:4|18:5|18:6|19:3|19:4|19:5|19:6|20:3|20:4|20:5|20:6|21:3|21:4|21:5|21:6|22:3|22:4|22:5|22:6|23:3|23:4|23:5|23:6|24:3|24:4|24:5|24:6|25:3|25:4|25:5|25:6|26:3|26:4|26:5|26:6|27:3|27:4|27:5|27:6'
#  '15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6'
#  '15:2|15:3|16:2|16:3|16:4|17:2|17:3|17:4|17:5|18:2|18:3|18:4|18:5|18:6|19:2|19:3|19:4|19:5|19:6|20:2|20:3|20:4|20:5|20:6|21:2|21:3|21:4|21:5|21:6|22:2|22:3|22:4|22:5|22:6|23:2|23:3|23:4|23:5|23:6|24:2|24:3|24:4|24:5|24:6|25:2|25:3|25:4|25:5|25:6|26:2|26:3|26:4|26:5|26:6|27:2|27:3|27:4|27:5|27:6|28:2|28:3|28:4|28:5|28:6|29:2|29:3|29:4|29:5|29:6|30:2|30:3|30:4|30:5|30:6'
#  '15:4|15:5|16:4|16:5|16:6|17:4|17:5|17:6|18:4|18:5|18:6|19:4|19:5|19:6|20:4|20:5|20:6|21:4|21:5|21:6|22:4|22:5|22:6|23:4|23:5|23:6|24:4|24:5|24:6|25:4|25:5|25:6|26:4|26:5|26:6|27:4|27:5|27:6|28:4|28:5|28:6|29:4|29:5|29:6|30:4|30:5|30:6'
#  '16:0|17:1|17:2|18:1|18:2|18:3|19:1|19:2|19:3|19:4|20:1|20:2|20:3|20:4|20:5|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6'
#  '16:2|16:3|17:2|17:3|17:4|18:2|18:3|18:4|18:5|19:2|19:3|19:4|19:5|19:6|20:2|20:3|20:4|20:5|20:6|21:2|21:3|21:4|21:5|21:6|22:2|22:3|22:4|22:5|22:6|23:2|23:3|23:4|23:5|23:6|24:2|24:3|24:4|24:5|24:6|25:2|25:3|25:4|25:5|25:6|26:2|26:3|26:4|26:5|26:6|27:2|27:3|27:4|27:5|27:6|28:2|28:3|28:4|28:5|28:6|29:2|29:3|29:4|29:5|29:6|30:2|30:3|30:4|30:5|30:6'
#  '16:3|16:4|17:3|17:4|17:5|18:3|18:4|18:5|18:6|19:3|19:4|19:5|19:6|20:3|20:4|20:5|20:6|21:3|21:4|21:5|21:6|22:3|22:4|22:5|22:6|23:3|23:4|23:5|23:6|24:3|24:4|24:5|24:6|25:3|25:4|25:5|25:6|26:3|26:4|26:5|26:6|27:3|27:4|27:5|27:6'
#  '16:4|16:5|17:4|17:5|17:6|18:4|18:5|18:6|19:4|19:5|19:6|20:4|20:5|20:6|21:4|21:5|21:6|22:4|22:5|22:6|23:4|23:5|23:6|24:4|24:5|24:6|25:4|25:5|25:6|26:4|26:5|26:6|27:4|27:5|27:6'
#  '17:0|18:1|18:2|19:1|19:2|19:3|20:1|20:2|20:3|20:4|21:1|21:2|21:3|21:4|21:5|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6'
#  '17:2|17:3|18:2|18:3|18:4|19:2|19:3|19:4|19:5|20:2|20:3|20:4|20:5|20:6|21:2|21:3|21:4|21:5|21:6|22:2|22:3|22:4|22:5|22:6|23:2|23:3|23:4|23:5|23:6|24:2|24:3|24:4|24:5|24:6|25:2|25:3|25:4|25:5|25:6|26:2|26:3|26:4|26:5|26:6|27:2|27:3|27:4|27:5|27:6|28:2|28:3|28:4|28:5|28:6|29:2|29:3|29:4|29:5|29:6|30:2|30:3|30:4|30:5|30:6'
#  '17:3|17:4|18:3|18:4|18:5|19:3|19:4|19:5|19:6|20:3|20:4|20:5|20:6|21:3|21:4|21:5|21:6|22:3|22:4|22:5|22:6|23:3|23:4|23:5|23:6|24:3|24:4|24:5|24:6|25:3|25:4|25:5|25:6|26:3|26:4|26:5|26:6|27:3|27:4|27:5|27:6|28:3|28:4|28:5|28:6|29:3|29:4|29:5|29:6|30:3|30:4|30:5|30:6'
#  '18:0|19:1|19:2|20:1|20:2|20:3|21:1|21:2|21:3|21:4|22:1|22:2|22:3|22:4|22:5|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6'
#  '18:2|18:3|19:2|19:3|19:4|20:2|20:3|20:4|20:5|21:2|21:3|21:4|21:5|21:6|22:2|22:3|22:4|22:5|22:6|23:2|23:3|23:4|23:5|23:6|24:2|24:3|24:4|24:5|24:6|25:2|25:3|25:4|25:5|25:6|26:2|26:3|26:4|26:5|26:6|27:2|27:3|27:4|27:5|27:6|28:2|28:3|28:4|28:5|28:6|29:2|29:3|29:4|29:5|29:6|30:2|30:3|30:4|30:5|30:6'
#  '18:5|18:6|19:5|19:6|20:5|20:6|21:5|21:6|22:5|22:6|23:5|23:6|24:5|24:6|25:5|25:6|26:5|26:6|27:5|27:6'
#  '19:0|20:1|20:2|21:1|21:2|21:3|22:1|22:2|22:3|22:4|23:1|23:2|23:3|23:4|23:5|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6'
#  '19:2|19:3|20:2|20:3|20:4|21:2|21:3|21:4|21:5|22:2|22:3|22:4|22:5|22:6|23:2|23:3|23:4|23:5|23:6|24:2|24:3|24:4|24:5|24:6|25:2|25:3|25:4|25:5|25:6|26:2|26:3|26:4|26:5|26:6|27:2|27:3|27:4|27:5|27:6|28:2|28:3|28:4|28:5|28:6|29:2|29:3|29:4|29:5|29:6|30:2|30:3|30:4|30:5|30:6'
#  '19:3|19:4|20:3|20:4|20:5|21:3|21:4|21:5|21:6|22:3|22:4|22:5|22:6|23:3|23:4|23:5|23:6|24:3|24:4|24:5|24:6|25:3|25:4|25:5|25:6|26:3|26:4|26:5|26:6|27:3|27:4|27:5|27:6|28:3|28:4|28:5|28:6|29:3|29:4|29:5|29:6|30:3|30:4|30:5|30:6'
#  '19:4|19:5|20:4|20:5|20:6|21:4|21:5|21:6|22:4|22:5|22:6|23:4|23:5|23:6|24:4|24:5|24:6|25:4|25:5|25:6|26:4|26:5|26:6|27:4|27:5|27:6|28:4|28:5|28:6|29:4|29:5|29:6|30:4|30:5|30:6'
#  '19:5|19:6|20:5|20:6|21:5|21:6|22:5|22:6|23:5|23:6|24:5|24:6|25:5|25:6|26:5|26:6|27:5|27:6|28:5|28:6|29:5|29:6|30:5|30:6'
#  '20:0|21:1|21:2|22:1|22:2|22:3|23:1|23:2|23:3|23:4|24:1|24:2|24:3|24:4|24:5|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6'
#  '21:0|22:1|22:2|23:1|23:2|23:3|24:1|24:2|24:3|24:4|25:1|25:2|25:3|25:4|25:5|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6'
#  '21:2|21:3|22:2|22:3|22:4|23:2|23:3|23:4|23:5|24:2|24:3|24:4|24:5|24:6|25:2|25:3|25:4|25:5|25:6|26:2|26:3|26:4|26:5|26:6|27:2|27:3|27:4|27:5|27:6|28:2|28:3|28:4|28:5|28:6|29:2|29:3|29:4|29:5|29:6|30:2|30:3|30:4|30:5|30:6'
#  '21:3|21:4|22:3|22:4|22:5|23:3|23:4|23:5|23:6|24:3|24:4|24:5|24:6|25:3|25:4|25:5|25:6|26:3|26:4|26:5|26:6|27:3|27:4|27:5|27:6|28:3|28:4|28:5|28:6|29:3|29:4|29:5|29:6|30:3|30:4|30:5|30:6'
#  '21:4|21:5|22:4|22:5|22:6|23:4|23:5|23:6|24:4|24:5|24:6|25:4|25:5|25:6|26:4|26:5|26:6|27:4|27:5|27:6|28:4|28:5|28:6|29:4|29:5|29:6|30:4|30:5|30:6'
#  '21:5|21:6|22:5|22:6|23:5|23:6|24:5|24:6|25:5|25:6|26:5|26:6|27:5|27:6|28:5|28:6|29:5|29:6|30:5|30:6'
#  '21:6|22:6|23:6|24:6|25:6|26:6|27:6|28:6|29:6|30:6'
#  '22:0|23:1|23:2|24:1|24:2|24:3|25:1|25:2|25:3|25:4|26:1|26:2|26:3|26:4|26:5|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6'
#  '23:0|24:1|24:2|25:1|25:2|25:3|26:1|26:2|26:3|26:4|27:1|27:2|27:3|27:4|27:5|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6'
#  '23:2|23:3|24:2|24:3|24:4|25:2|25:3|25:4|25:5|26:2|26:3|26:4|26:5|26:6|27:2|27:3|27:4|27:5|27:6|28:2|28:3|28:4|28:5|28:6|29:2|29:3|29:4|29:5|29:6|30:2|30:3|30:4|30:5|30:6'
#  '23:3|23:4|24:3|24:4|24:5|25:3|25:4|25:5|25:6|26:3|26:4|26:5|26:6|27:3|27:4|27:5|27:6|28:3|28:4|28:5|28:6|29:3|29:4|29:5|29:6|30:3|30:4|30:5|30:6'
#  '24:0|25:1|25:2|26:1|26:2|26:3|27:1|27:2|27:3|27:4|28:1|28:2|28:3|28:4|28:5|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6'
#  '25:2|25:3|26:2|26:3|26:4|27:2|27:3|27:4|27:5|28:2|28:3|28:4|28:5|28:6|29:2|29:3|29:4|29:5|29:6|30:2|30:3|30:4|30:5|30:6'
#  '5:0|6:1|6:2|7:1|7:2|7:3|8:1|8:2|8:3|8:4|9:1|9:2|9:3|9:4|9:5|10:1|10:2|10:3|10:4|10:5|10:6|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6'
#  '6:0|7:1|7:2|8:1|8:2|8:3|9:1|9:2|9:3|9:4|10:1|10:2|10:3|10:4|10:5|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6'
#  '6:1|6:2|6:3|7:1|7:2|7:3|7:4|8:1|8:2|8:3|8:4|8:5|9:1|9:2|9:3|9:4|9:5|9:6|10:1|10:2|10:3|10:4|10:5|10:6|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6'
#  '6:1|6:2|6:3|6:4|7:1|7:2|7:3|7:4|7:5|8:1|8:2|8:3|8:4|8:5|8:6|9:1|9:2|9:3|9:4|9:5|9:6|10:1|10:2|10:3|10:4|10:5|10:6|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6'
#  '7:0|8:1|8:2|9:1|9:2|9:3|10:1|10:2|10:3|10:4|11:1|11:2|11:3|11:4|11:5|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6'
#  '8:0|9:1|9:2|10:1|10:2|10:3|11:1|11:2|11:3|11:4|12:1|12:2|12:3|12:4|12:5|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6'
#  '9:0|10:1|10:2|11:1|11:2|11:3|12:1|12:2|12:3|12:4|13:1|13:2|13:3|13:4|13:5|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6'
#  '9:2|9:3|10:2|10:3|10:4|11:2|11:3|11:4|11:5|12:2|12:3|12:4|12:5|12:6|13:2|13:3|13:4|13:5|13:6|14:2|14:3|14:4|14:5|14:6|15:2|15:3|15:4|15:5|15:6|16:2|16:3|16:4|16:5|16:6|17:2|17:3|17:4|17:5|17:6|18:2|18:3|18:4|18:5|18:6|19:2|19:3|19:4|19:5|19:6|20:2|20:3|20:4|20:5|20:6|21:2|21:3|21:4|21:5|21:6|22:2|22:3|22:4|22:5|22:6|23:2|23:3|23:4|23:5|23:6|24:2|24:3|24:4|24:5|24:6|25:2|25:3|25:4|25:5|25:6|26:2|26:3|26:4|26:5|26:6|27:2|27:3|27:4|27:5|27:6'
#  '16:0']
#               Lipid  Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0                         495.4        183.0        0.001967             82.0
# 1                         227.1        183.0        0.011583             41.0
# 2                         495.4        183.0        0.014883             41.0
# 3                         227.1        183.0        0.024483             41.0
# 4                         495.4        183.0        0.027783             50.0
# ...             ...         ...          ...             ...              ...
# 127706  FA(d2-16:0)       425.4        183.0       29.941917             41.0
# 127707  FA(d2-16:0)       425.4        183.0       29.954833             41.0
# 127708  FA(d2-16:0)       425.4        183.0       29.967750             41.0
# 127709  FA(d2-16:0)       425.4        183.0       29.980667             42.0
# 127710  FA(d2-16:0)       425.4        183.0       29.993600             41.0
#
#                                                 Sample_ID      Transition  \
# 0       11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  495.4 -> 183.0
# 1       11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  227.1 -> 183.0
# 2       11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  495.4 -> 183.0
# 3       11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  227.1 -> 183.0
# 4       11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  495.4 -> 183.0
# ...                                                   ...             ...
# 127706  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  425.4 -> 183.0
# 127707  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  425.4 -> 183.0
# 127708  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  425.4 -> 183.0
# 127709  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  425.4 -> 183.0
# 127710  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  425.4 -> 183.0
#
#                     Sample   STD  STD_RT_OFF Class    Species Biology  \
# 0       hippo_WT_m1_FAD245  None    7.899783        Unknown_1   hippo
# 1       hippo_WT_m1_FAD245  None    7.899783        Unknown_1   hippo
# 2       hippo_WT_m1_FAD245  None    7.899783        Unknown_1   hippo
# 3       hippo_WT_m1_FAD245  None    7.899783        Unknown_1   hippo
# 4       hippo_WT_m1_FAD245  None    7.899783        Unknown_1   hippo
# ...                    ...   ...         ...   ...        ...     ...
# 127706  hippo_WT_m1_FAD245  None    7.899783    FA       16:0   hippo
# 127707  hippo_WT_m1_FAD245  None    7.899783    FA       16:0   hippo
# 127708  hippo_WT_m1_FAD245  None    7.899783    FA       16:0   hippo
# 127709  hippo_WT_m1_FAD245  None    7.899783    FA       16:0   hippo
# 127710  hippo_WT_m1_FAD245  None    7.899783    FA       16:0   hippo
#
#        Genotype    Cage Mouse  group_by_ion  group_by_lipid
# 0            WT  FAD245    m1            47               0
# 1            WT  FAD245    m1             0               0
# 2            WT  FAD245    m1            47               0
# 3            WT  FAD245    m1             0               0
# 4            WT  FAD245    m1            47               0
# ...         ...     ...   ...           ...             ...
# 127706       WT  FAD245    m1            30              52
# 127707       WT  FAD245    m1            30              52
# 127708       WT  FAD245    m1            30              52
# 127709       WT  FAD245    m1            30              52
# 127710       WT  FAD245    m1            30              52
#
# [127711 rows x 18 columns]

# %%
notpossible_lipids = df[df['Species'].str.contains('16:1', case=False, na=False)]
sorted_notpossible_lipids = notpossible_lipids.sort_values(by='OzESI_Intensity', ascending=False)
#print unique Lipid values
print(sorted_notpossible_lipids['Species'].unique())
sorted_notpossible_lipids
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1282923/330627786.py in <module>
# ----> 1 notpossible_lipids = df[df['Species'].str.contains('16:1', case=False, na=False)]
#       2 sorted_notpossible_lipids = notpossible_lipids.sort_values(by='OzESI_Intensity', ascending=False)
#       3 #print unique Lipid values
#       4 print(sorted_notpossible_lipids['Species'].unique())
#       5 sorted_notpossible_lipids
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt

# Function to plot chromatograms, with options to either display or save the plots
def plot_chromatograms(df, save_path=None, show_only=False, specific_group=None):
    if specific_group:
        # If a specific group is provided, filter the DataFrame for that group only
        group_data = df[df['group_by_lipid'] == specific_group]
        
        # Ensure the Retention_Time is sorted
        group_data = group_data.sort_values(by='Retention_Time')
        
        # Extract Lipid and Parent Ion values from the first row of the group
        lipid = group_data['Lipid'].iloc[0] if not group_data.empty else f"Unknown_Lipid_{specific_group}"
        parent_ion = group_data['Parent_Ion'].iloc[0] if not group_data.empty else "Unknown Parent Ion"
        
        plt.figure(figsize=(10, 6))
        plt.plot(group_data['Retention_Time'], group_data['OzESI_Intensity'], label=f'group_by_lipid: {specific_group}')
        plt.xlabel('Retention Time')
        plt.ylabel('OzESI Intensity')
        
        # Add Lipid and Parent Ion to the title
        plt.title(f'{specific_group} | Lipid: {lipid} | Parent Ion: {parent_ion}')
        
        plt.legend()
        plt.grid(True)
        
        if show_only:
            plt.show()  # Display the plot
        else:
            # Save the plot as a PNG with the lipid name followed by "_OFF"
            save_file = f"{save_path}/{lipid.replace(':', '_').replace('/', '_')}_OFF.png"  # Clean filename
            plt.savefig(save_file)
            print(f"Plot saved as {save_file}")
        plt.close()  # Close the figure after displaying or saving

    else:
        # Iterate through each unique group_by_lipid value if no specific group is provided
        for group_value in df['group_by_lipid'].unique():
            group_data = df[df['group_by_lipid'] == group_value]
            
            # Ensure the Retention_Time is sorted
            group_data = group_data.sort_values(by='Retention_Time')
            
            # Extract Lipid and Parent Ion values from the first row of the group
            lipid = group_data['Lipid'].iloc[0] if not group_data.empty else f"Unknown_Lipid_{group_value}"
            parent_ion = group_data['Parent_Ion'].iloc[0] if not group_data.empty else "Unknown Parent Ion"
            
            plt.figure(figsize=(10, 6))
            plt.plot(group_data['Retention_Time'], group_data['OzESI_Intensity'], label=f'group_by_lipid: {group_value}')
            plt.xlabel('Retention Time')
            plt.ylabel('OzESI Intensity')
            
            # Add Lipid and Parent Ion to the title
            plt.title(f'{group_value} | Lipid: {lipid} | Parent Ion: {parent_ion}')
            
            plt.legend()
            plt.grid(True)
            
            if show_only:
                plt.show()  # Display the plot
                break  # Exit after showing one plot if in "show only" mode
            else:
                # Save the plot as a PNG with the lipid name followed by "_OFF"
                save_file = f"{save_path}/{lipid.replace(':', '_').replace('/', '_')}_OFF.png"  # Clean filename
                plt.savefig(save_file)
                print(f"Plot saved as {save_file}")
            plt.close()  # Close the figure to avoid overlap in the next iteration

# Example usage:
# User-defined variable for the save path
save_path = 'Projects/AMP/plots/OFF_plots/'  # Replace with your desired save path

# # Call the function to either display or save chromatograms
# # For saving and iterating through all groups:
# plot_chromatograms(df, save_path=save_path)

# For showing only a specific group without saving:
plot_chromatograms(df_before, show_only=True, specific_group=25)

# %% [markdown]
# # 5 - Analysis

# %%
# !sbatch core/backend/not_possible/analysis_5_AMP_OFF_notpossible.sh
# Out:
# Submitted batch job 20384334

# %%
# import pandas as pd
# df = pd.read_parquet('Projects/STD/analysis/OFF/multiple_values/df_analysis_5_FAME_OFF.parquet')
#  #Projects/STD/analysis/OFF/df_analysis_5_FAME_OFF.parquet
# print(df['Lipid'].unique())
# df.head(10)
import pandas as pd
df = pd.read_parquet('Projects/AMP/analysis/OFF/notpossible/df_analysis_5_hippo_WT_m1_FAD245_OFF.parquet')
# pd.read_parquet('core/python/')
# df = df[(df['Retention_Time'] >= 6.4) & (df['Retention_Time'] <= 7.9)]
df
# Out:
#                                                  Lipid  Retention_Time  \
# 0                                          FA(d2-16:0)        3.558550
# 1                                          FA(d2-16:0)        4.075367
# 2                                          FA(d2-16:0)        4.269167
# 3                                          FA(d2-16:0)        7.899783
# 4                                          FA(d2-16:0)        8.558717
# ..                                                 ...             ...
# 478  FA(5:0) | FA(6:1)_<>_n-2 | FA(6:2)_<F>_n-2 | F...        2.310767
# 479  FA(5:0) | FA(6:1)_<>_n-2 | FA(6:2)_<F>_n-2 | F...        2.659617
# 480  FA(6:1)_<>_n-3 | FA(6:2)_<F>_n-3 | FA(6:3)_<FF...        0.670083
# 481  FA(6:1)_<>_n-3 | FA(6:2)_<F>_n-3 | FA(6:3)_<FF...        1.677867
# 482  FA(6:1)_<>_n-4 | FA(6:2)_<F>_n-4 | FA(6:3)_<FF...        1.135417
#
#      OzESI_Intensity  group_by_ion  group_by_lipid  \
# 0             2066.0            30              52
# 1             3753.0            30              52
# 2             1074.0            30              52
# 3          1019577.0            30              52
# 4             2783.0            30              52
# ..               ...           ...             ...
# 478           2330.0             3              44
# 479         136973.0             3              44
# 480           1765.0             2              46
# 481           5115.0             2              46
# 482           4669.0             1              47
#
#                                              Sample_ID      Transition  \
# 0    11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  425.4 -> 183.0
# 1    11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  425.4 -> 183.0
# 2    11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  425.4 -> 183.0
# 3    11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  425.4 -> 183.0
# 4    11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  425.4 -> 183.0
# ..                                                 ...             ...
# 478  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  269.1 -> 183.0
# 479  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  269.1 -> 183.0
# 480  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  255.2 -> 183.0
# 481  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  255.2 -> 183.0
# 482  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  241.1 -> 183.0
#
#                  Sample  Parent_Ion  Product_Ion  \
# 0    hippo_WT_m1_FAD245       425.4        183.0
# 1    hippo_WT_m1_FAD245       425.4        183.0
# 2    hippo_WT_m1_FAD245       425.4        183.0
# 3    hippo_WT_m1_FAD245       425.4        183.0
# 4    hippo_WT_m1_FAD245       425.4        183.0
# ..                  ...         ...          ...
# 478  hippo_WT_m1_FAD245       269.1        183.0
# 479  hippo_WT_m1_FAD245       269.1        183.0
# 480  hippo_WT_m1_FAD245       255.2        183.0
# 481  hippo_WT_m1_FAD245       255.2        183.0
# 482  hippo_WT_m1_FAD245       241.1        183.0
#
#                                                Species  \
# 0                                                 16:0
# 1                                                 16:0
# 2                                                 16:0
# 3                                                 16:0
# 4                                                 16:0
# ..                                                 ...
# 478  5:0|6:1|6:2|7:1|7:2|7:3|8:1|8:2|8:3|8:4|9:1|9:...
# 479  5:0|6:1|6:2|7:1|7:2|7:3|8:1|8:2|8:3|8:4|9:1|9:...
# 480  6:1|6:2|6:3|7:1|7:2|7:3|7:4|8:1|8:2|8:3|8:4|8:...
# 481  6:1|6:2|6:3|7:1|7:2|7:3|7:4|8:1|8:2|8:3|8:4|8:...
# 482  6:1|6:2|6:3|6:4|7:1|7:2|7:3|7:4|7:5|8:1|8:2|8:...
#
#                                                  Class   STD  STD_RT_OFF  \
# 0                                                   FA  None    7.899783
# 1                                                   FA  None    7.899783
# 2                                                   FA  None    7.899783
# 3                                                   FA  None    7.899783
# 4                                                   FA  None    7.899783
# ..                                                 ...   ...         ...
# 478  FA | FA | FA | FA | FA | FA | FA | FA | FA | F...  None    7.899783
# 479  FA | FA | FA | FA | FA | FA | FA | FA | FA | F...  None    7.899783
# 480  FA | FA | FA | FA | FA | FA | FA | FA | FA | F...  None    7.899783
# 481  FA | FA | FA | FA | FA | FA | FA | FA | FA | F...  None    7.899783
# 482  FA | FA | FA | FA | FA | FA | FA | FA | FA | F...  None    7.899783
#
#      Peak_Height      FWHM  Peak_Width      Peak_Area   Filter_Column
# 0         2066.0  0.061851    0.064600     133.463600  group_by_lipid
# 1         3753.0  0.171538    0.167967     630.378900  group_by_lipid
# 2         1074.0  0.051899    0.051667      55.490000  group_by_lipid
# 3      1019577.0  0.171566    0.180883  184424.486350  group_by_lipid
# 4         2783.0  0.041116    0.038750     107.841250  group_by_lipid
# ..           ...       ...         ...            ...             ...
# 478       2330.0  0.038104    0.038767      90.326333  group_by_lipid
# 479     136973.0  0.086414    0.090450   12389.207850  group_by_lipid
# 480       1765.0  0.089125    0.090433     159.614833  group_by_lipid
# 481       5115.0  0.210242    0.206717    1057.355750  group_by_lipid
# 482       4669.0  0.073865    0.077533     362.003133  group_by_lipid
#
# [483 rows x 19 columns]

# %% [markdown]
# # STD RT Adjustment

# %%
def STD_RT_Adjustment(ozon_df, fame_std):
    """
    Calculates the difference between STD_RT_OFF in ozon_df for each unique Sample_ID
    with the reference STD_RT_OFF from fame_std and applies the same difference to all rows for that Sample_ID.
    Creates a new column 'Adjusted_RT_FAME' which is the sum of 'Retention_Time' and 'STD_RT_Dif_FAME'.
    
    Assumes fame_std contains only one reference STD_RT_OFF value.
    """
    # Get the reference STD_RT_OFF value from fame_std
    reference_std_rt_off = fame_std['STD_RT_OFF'].iloc[0]
    print(f"Reference STD_RT_OFF: {reference_std_rt_off}")

    # Create a dictionary to store STD_RT_Dif_FAME for each unique Sample_ID
    std_rt_diff_dict = {}
    
    # Calculate the difference for each unique Sample_ID in ozon_df
    for sample_id in ozon_df['Sample_ID'].unique():
        sample_std_rt_off = ozon_df.loc[ozon_df['Sample_ID'] == sample_id, 'STD_RT_OFF'].iloc[0]
        std_rt_diff_dict[sample_id] = sample_std_rt_off - reference_std_rt_off
        print(f"Sample_ID: {sample_id}, STD_RT_OFF: {sample_std_rt_off}, "
              f"STD_RT_Dif_FAME: {std_rt_diff_dict[sample_id]}")
    
    # Apply the calculated difference to all rows based on Sample_ID
    ozon_df['STD_RT_Dif_FAME'] = ozon_df['Sample_ID'].map(std_rt_diff_dict)
    print("STD_RT_Dif_FAME column populated with RT differences per Sample_ID.")
    
    # Calculate Adjusted_RT_FAME as Retention_Time + STD_RT_Dif_FAME
    ozon_df['Adjusted_RT_FAME'] = ozon_df['Retention_Time'] + ozon_df['STD_RT_Dif_FAME']
    print("Adjusted_RT_FAME column created with adjusted retention times.")

# Example usage:
# STD_RT_Adjustment(ozon_df, fame_std)

# %%
fame_std = pd.read_parquet('Projects/STD/off_possible/FAME_off_possible_top2.parquet')
fame_std = fame_std[fame_std['Species'].str.contains('16:1', case=False, na=False)]
fame_std
# Out:
#       Lipid  Retention_Time  OzESI_Intensity  group_by_ion  group_by_lipid  \
# 4  FA(16:1)        6.910983        1813371.0            28              19
#
#   Sample_ID      Transition Sample  Parent_Ion  Product_Ion Species Class  \
# 4  FAME_off  421.4 -> 183.0   FAME       421.4        183.0    16:1    FA
#
#     STD  STD_RT_OFF  Peak_Height      FWHM  Peak_Width    Peak_Area  \
# 4  FAME    8.169267    1813371.0  0.104408    0.104933  190283.0636
#
#     Filter_Column  Isomer
# 4  group_by_lipid       1

# %%
STD_RT_Adjustment(df, fame_std)
df.to_parquet('Projects/AMP/notpossible/rt_adjustment_6/df_rt_adjustment_6_hippo_WT_m1_FAD245_OFF.parquet')
df
# Out:
# Reference STD_RT_OFF: 8.169266666666667
# Sample_ID: 11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-0_MRMs_O3off_01, STD_RT_OFF: 7.899783333333334, STD_RT_Dif_FAME: -0.2694833333333335
# STD_RT_Dif_FAME column populated with RT differences per Sample_ID.
# Adjusted_RT_FAME column created with adjusted retention times.
#                                                  Lipid  Retention_Time  \
# 0                                          FA(d2-16:0)        3.558550
# 1                                          FA(d2-16:0)        4.075367
# 2                                          FA(d2-16:0)        4.269167
# 3                                          FA(d2-16:0)        7.899783
# 4                                          FA(d2-16:0)        8.558717
# ..                                                 ...             ...
# 478  FA(5:0) | FA(6:1)_<>_n-2 | FA(6:2)_<F>_n-2 | F...        2.310767
# 479  FA(5:0) | FA(6:1)_<>_n-2 | FA(6:2)_<F>_n-2 | F...        2.659617
# 480  FA(6:1)_<>_n-3 | FA(6:2)_<F>_n-3 | FA(6:3)_<FF...        0.670083
# 481  FA(6:1)_<>_n-3 | FA(6:2)_<F>_n-3 | FA(6:3)_<FF...        1.677867
# 482  FA(6:1)_<>_n-4 | FA(6:2)_<F>_n-4 | FA(6:3)_<FF...        1.135417
#
#      OzESI_Intensity  group_by_ion  group_by_lipid  \
# 0             2066.0            30              52
# 1             3753.0            30              52
# 2             1074.0            30              52
# 3          1019577.0            30              52
# 4             2783.0            30              52
# ..               ...           ...             ...
# 478           2330.0             3              44
# 479         136973.0             3              44
# 480           1765.0             2              46
# 481           5115.0             2              46
# 482           4669.0             1              47
#
#                                              Sample_ID      Transition  \
# 0    11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  425.4 -> 183.0
# 1    11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  425.4 -> 183.0
# 2    11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  425.4 -> 183.0
# 3    11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  425.4 -> 183.0
# 4    11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  425.4 -> 183.0
# ..                                                 ...             ...
# 478  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  269.1 -> 183.0
# 479  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  269.1 -> 183.0
# 480  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  255.2 -> 183.0
# 481  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  255.2 -> 183.0
# 482  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  241.1 -> 183.0
#
#                  Sample  Parent_Ion  Product_Ion  ...  \
# 0    hippo_WT_m1_FAD245       425.4        183.0  ...
# 1    hippo_WT_m1_FAD245       425.4        183.0  ...
# 2    hippo_WT_m1_FAD245       425.4        183.0  ...
# 3    hippo_WT_m1_FAD245       425.4        183.0  ...
# 4    hippo_WT_m1_FAD245       425.4        183.0  ...
# ..                  ...         ...          ...  ...
# 478  hippo_WT_m1_FAD245       269.1        183.0  ...
# 479  hippo_WT_m1_FAD245       269.1        183.0  ...
# 480  hippo_WT_m1_FAD245       255.2        183.0  ...
# 481  hippo_WT_m1_FAD245       255.2        183.0  ...
# 482  hippo_WT_m1_FAD245       241.1        183.0  ...
#
#                                                  Class   STD STD_RT_OFF  \
# 0                                                   FA  None   7.899783
# 1                                                   FA  None   7.899783
# 2                                                   FA  None   7.899783
# 3                                                   FA  None   7.899783
# 4                                                   FA  None   7.899783
# ..                                                 ...   ...        ...
# 478  FA | FA | FA | FA | FA | FA | FA | FA | FA | F...  None   7.899783
# 479  FA | FA | FA | FA | FA | FA | FA | FA | FA | F...  None   7.899783
# 480  FA | FA | FA | FA | FA | FA | FA | FA | FA | F...  None   7.899783
# 481  FA | FA | FA | FA | FA | FA | FA | FA | FA | F...  None   7.899783
# 482  FA | FA | FA | FA | FA | FA | FA | FA | FA | F...  None   7.899783
#
#      Peak_Height      FWHM  Peak_Width      Peak_Area   Filter_Column  \
# 0         2066.0  0.061851    0.064600     133.463600  group_by_lipid
# 1         3753.0  0.171538    0.167967     630.378900  group_by_lipid
# 2         1074.0  0.051899    0.051667      55.490000  group_by_lipid
# 3      1019577.0  0.171566    0.180883  184424.486350  group_by_lipid
# 4         2783.0  0.041116    0.038750     107.841250  group_by_lipid
# ..           ...       ...         ...            ...             ...
# 478       2330.0  0.038104    0.038767      90.326333  group_by_lipid
# 479     136973.0  0.086414    0.090450   12389.207850  group_by_lipid
# 480       1765.0  0.089125    0.090433     159.614833  group_by_lipid
# 481       5115.0  0.210242    0.206717    1057.355750  group_by_lipid
# 482       4669.0  0.073865    0.077533     362.003133  group_by_lipid
#
#     STD_RT_Dif_FAME  Adjusted_RT_FAME
# 0         -0.269483          3.289067
# 1         -0.269483          3.805883
# 2         -0.269483          3.999683
# 3         -0.269483          7.630300
# 4         -0.269483          8.289233
# ..              ...               ...
# 478       -0.269483          2.041283
# 479       -0.269483          2.390133
# 480       -0.269483          0.400600
# 481       -0.269483          1.408383
# 482       -0.269483          0.865933
#
# [483 rows x 21 columns]

# %% [markdown]
# # 6 - FILTER BY FAME UPDATEING Nov6

# %% [markdown]
# # working for 16:1

# %%
import pandas as pd
import os
import re

def filter_OzOFF_by_fame_std(input_dir, fame_std, output_dir, fame_rt_window=0.5):
    """
    Filters parquet files in the input directory based on fame_std retention times and species,
    using Adjusted_RT_FAME from the input files to compare against fame_std Retention_Time.
    Updates Species to only contain the matched species and saves the filtered result as parquet files
    in the output directory. Logs and removed lipids CSVs are saved in a log directory inside the output directory.
    """
    
    def filter_fa_16_1(df):
        """
        Filters DataFrame rows where the Lipid column contains 'FA(16:1)'.
        Keeps only the 'FA(16:1)' entries along with any trailing details, removing other lipid types.
        """
        # Pattern to match 'FA(16:1)' along with any extra parts that follow it
        pattern = r'\bFA\(16:1\)(?:_[^|]*)?'

        # Filter rows where 'FA(16:1)' is present in the Lipid column
        filtered_df = df[df['Lipid'].str.contains(pattern, regex=True)]
        print(f"Number of rows matching FA(16:1): {len(filtered_df)}")

        # Update the Lipid column to keep only 'FA(16:1)' entries with any trailing details
        filtered_df['Lipid'] = filtered_df['Lipid'].apply(lambda x: '|'.join(re.findall(pattern, x)))
        print("Updated Lipid column to retain only 'FA(16:1)' values with details.")

        return filtered_df

    print("Starting filter_OzOFF_by_fame_std function")
    print(f"Input directory: {input_dir}")
    print(f"Output directory: {output_dir}")
    print(f"Retention time window: {fame_rt_window}")
    print(f"Fame standard DataFrame columns: {fame_std.columns.tolist()}")

    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Create a log subdirectory inside the output directory
    log_dir = os.path.join(output_dir, 'log')
    os.makedirs(log_dir, exist_ok=True)

    # Check if input directory has parquet files
    input_files = [f for f in os.listdir(input_dir) if f.endswith(".parquet")]
    print(f"Number of parquet files found in input directory: {len(input_files)}")
    if not input_files:
        print("No parquet files found in input directory. Exiting function.")
        return

    # Iterate over all parquet files in the input directory
    for parquet_file in input_files:
        print(f"Processing file: {parquet_file}")

        # Read the parquet file
        file_path = os.path.join(input_dir, parquet_file)
        filtered_ozON = pd.read_parquet(file_path)

        # Add Lipid_Possible column as a copy of Lipid
        filtered_ozON['Lipid_Possible'] = filtered_ozON['Lipid']
        print("Lipid_Possible column created")

        # Apply the FA(16:1) filter using the inner function
        filtered_ozON = filter_fa_16_1(filtered_ozON)

        # Check the initial data after applying the FA(16:1) filter
        print(f"Rows after FA(16:1) filter: {len(filtered_ozON)}")
        print(f"filtered_ozON columns: {filtered_ozON.columns.tolist()}")

        # Create a new DataFrame to store the filtered ozON data
        filtered_ozON_result = filtered_ozON.copy()

        # Prepare lists for logging
        drop_indices = []
        removed_lipids = []

        # Get sample name from Sample column
        sample_name = filtered_ozON_result['Sample'].unique()[0]
        log_filename = f"{sample_name}_fame_filter_log_debug.txt"
        log_file_path = os.path.join(log_dir, log_filename)

        # CSV filename for removed lipids
        csv_filename = f"{sample_name}_fame_filter_removed_lipids_debug.csv"
        csv_file_path = os.path.join(log_dir, csv_filename)

        # Iterate through each entry in fame_std to filter ozON entries
        for _, fame_entry in fame_std.iterrows():
            fame_std_rt = fame_entry['Retention_Time']
            fame_std_species = fame_entry['Species']
            print(f"Processing fame_std entry: Retention_Time={fame_std_rt}, Species={fame_std_species}")

            # Define bounds for Adjusted_RT_FAME comparison
            rt_lower_bound = fame_std_rt - fame_rt_window
            rt_upper_bound = fame_std_rt + fame_rt_window
            print(f"Adjusted RT bounds: {rt_lower_bound} to {rt_upper_bound}")

            # Filter entries within the defined Adjusted_RT_FAME window and matching Species
            for index, row in filtered_ozON_result.iterrows():
                adjusted_rt = row['Adjusted_RT_FAME']
                species_list = row['Species'].split('|')  # Split species by '|'

                print(f"Row {index}: Adjusted_RT_FAME={adjusted_rt}, Species={row['Species']}")
                print(f"Species list after split: {species_list}")

                # Check if fame_std_species is in the species_list and adjusted_rt is within bounds
                if fame_std_species in species_list and rt_lower_bound <= adjusted_rt <= rt_upper_bound:
                    print(f"Match found for row {index}: Adjusted_RT_FAME within bounds and Species match")
                    # Update Species column to contain only the matched fame_std_species
                    filtered_ozON_result.at[index, 'Species'] = fame_std_species
                    print(f"Updated Species for row {index} to: {fame_std_species}")
                else:
                    # If it doesn't match, log the row for removal
                    rt_diff = min(abs(adjusted_rt - rt_lower_bound), abs(adjusted_rt - rt_upper_bound))
                    print(f"No match for row {index}: RT difference={rt_diff}, Species mismatch or RT out of bounds")
                    drop_indices.append(index)
                    removed_lipids.append({
                        'Lipid': row['Lipid'],
                        'Adjusted_RT_FAME': adjusted_rt,
                        'Ground_Truth_RT': fame_std_rt,
                        'Species': row['Species'],
                        'Ground_Truth_Species': fame_std_species,
                        'RT_Difference': rt_diff
                    })

        # Drop all collected indices
        filtered_ozON_result = filtered_ozON_result.drop(drop_indices).reset_index(drop=True)
        print(f"Filtered rows in {sample_name}: {len(drop_indices)} removed")

        # Save filtered DataFrame and removed lipids log to CSV
        filtered_ozON_result.to_parquet(os.path.join(output_dir, f"{sample_name}_filtered.parquet"))
        pd.DataFrame(removed_lipids).to_csv(csv_file_path, index=False)

        # Write log entries to a text file
        with open(log_file_path, 'w') as log_file:
            for entry in removed_lipids:
                log_file.write(str(entry) + '\n')
            print(f"Log for removed lipids saved at: {log_file_path}")

    print("filter_OzOFF_by_fame_std function completed.")

# %% [markdown]
# # nov7 testing for all FA not just 16:1

# %%
import pandas as pd
import os
import re

def filter_OzOFF_by_fame_std(input_dir, fame_std, output_dir, fame_rt_window=0.5):
    """
    Filters parquet files in the input directory based on fame_std retention times and species,
    using Adjusted_RT_FAME from the input files to compare against fame_std Retention_Time.
    Updates Species and Lipid to only contain the matched species (including trailing details) and saves
    the filtered result as parquet files in the output directory. Logs and removed lipids CSVs are saved
    in a log directory inside the output directory.
    """
    
    print("Starting filter_OzOFF_by_fame_std function")
    print(f"Input directory: {input_dir}")
    print(f"Output directory: {output_dir}")
    print(f"Retention time window: {fame_rt_window}")
    print(f"Fame standard DataFrame columns: {fame_std.columns.tolist()}")

    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Create a log subdirectory inside the output directory
    log_dir = os.path.join(output_dir, 'log')
    os.makedirs(log_dir, exist_ok=True)

    # Check if input directory has parquet files
    input_files = [f for f in os.listdir(input_dir) if f.endswith(".parquet")]
    print(f"Number of parquet files found in input directory: {len(input_files)}")
    if not input_files:
        print("No parquet files found in input directory. Exiting function.")
        return

    # Iterate over all parquet files in the input directory
    for parquet_file in input_files:
        print(f"Processing file: {parquet_file}")

        # Read the parquet file
        file_path = os.path.join(input_dir, parquet_file)
        filtered_ozON = pd.read_parquet(file_path)

        # Add Lipid_Possible column as a copy of Lipid
        filtered_ozON['Lipid_Possible'] = filtered_ozON['Lipid']
        print("Lipid_Possible column created")

        # Create a new DataFrame to store the filtered ozON data
        filtered_ozON_result = filtered_ozON.copy()

        # Prepare lists for logging
        drop_indices = []
        removed_lipids = []

        # Get sample name from Sample column
        sample_name = filtered_ozON_result['Sample'].unique()[0]
        log_filename = f"{sample_name}_fame_filter_log_debug.txt"
        log_file_path = os.path.join(log_dir, log_filename)

        # CSV filename for removed lipids
        csv_filename = f"{sample_name}_fame_filter_removed_lipids_debug.csv"
        csv_file_path = os.path.join(log_dir, csv_filename)

        # Iterate through each entry in fame_std to filter ozON entries
        for _, fame_entry in fame_std.iterrows():
            fame_std_rt = fame_entry['Retention_Time']
            fame_std_species = fame_entry['Species']
            print(f"Processing fame_std entry: Retention_Time={fame_std_rt}, Species={fame_std_species}")

            # Define bounds for Adjusted_RT_FAME comparison
            rt_lower_bound = fame_std_rt - fame_rt_window
            rt_upper_bound = fame_std_rt + fame_rt_window
            print(f"Adjusted RT bounds: {rt_lower_bound} to {rt_upper_bound}")

            # Updated regex pattern to match the entire lipid entry with "FA()" and trailing details
            pattern = rf'\bFA\({re.escape(fame_std_species)}\)(?:_[^|]*)?'

            # Filter entries within the defined Adjusted_RT_FAME window and matching Species
            for index, row in filtered_ozON_result.iterrows():
                adjusted_rt = row['Adjusted_RT_FAME']
                species_list = row['Species'].split('|')  # Split species by '|'

                print(f"Row {index}: Adjusted_RT_FAME={adjusted_rt}, Species={row['Species']}")
                print(f"Species list after split: {species_list}")

                # Check if fame_std_species is in the species_list and adjusted_rt is within bounds
                if fame_std_species in species_list and rt_lower_bound <= adjusted_rt <= rt_upper_bound:
                    print(f"Match found for row {index}: Adjusted_RT_FAME within bounds and Species match")
                    
                    # Apply regex to capture the full matched lipid entry with details
                    matched_lipid = '|'.join(re.findall(pattern, row['Lipid']))
                    
                    # Debug statement to check the matched_lipid content before assignment
                    print(f"Original Lipid: {row['Lipid']}")
                    print(f"Pattern used: {pattern}")
                    print(f"Matched Lipid after regex: {matched_lipid}")
                    
                    # Update Species and Lipid columns to contain only the matched fame_std_species with details
                    filtered_ozON_result.at[index, 'Species'] = fame_std_species
                    filtered_ozON_result.at[index, 'Lipid'] = matched_lipid
                    
                    # Confirm the updated values
                    print(f"Updated Species for row {index} to: {fame_std_species}")
                    print(f"Updated Lipid for row {index} to: {matched_lipid}")
                else:
                    # If it doesn't match, log the row for removal
                    rt_diff = min(abs(adjusted_rt - rt_lower_bound), abs(adjusted_rt - rt_upper_bound))
                    print(f"No match for row {index}: RT difference={rt_diff}, Species mismatch or RT out of bounds")
                    drop_indices.append(index)
                    removed_lipids.append({
                        'Lipid': row['Lipid'],
                        'Adjusted_RT_FAME': adjusted_rt,
                        'Ground_Truth_RT': fame_std_rt,
                        'Species': row['Species'],
                        'Ground_Truth_Species': fame_std_species,
                        'RT_Difference': rt_diff
                    })

        # Drop all collected indices
        filtered_ozON_result = filtered_ozON_result.drop(drop_indices).reset_index(drop=True)
        print(f"Filtered rows in {sample_name}: {len(drop_indices)} removed")

        # Save filtered DataFrame and removed lipids log to CSV
        filtered_ozON_result.to_parquet(os.path.join(output_dir, f"{sample_name}_filtered.parquet"))
        pd.DataFrame(removed_lipids).to_csv(csv_file_path, index=False)

        # Write log entries to a text file
        with open(log_file_path, 'w') as log_file:
            for entry in removed_lipids:
                log_file.write(str(entry) + '\n')
            print(f"Log for removed lipids saved at: {log_file_path}")

    print("filter_OzOFF_by_fame_std function completed.")

# %%
# from core.python.fame_filter_AMP_7 import filter_ozon_by_fame_std
import pandas as pd

# Define input and output directories
#input_dir = 'Projects/AMP/analysis/OFF/notpossible/'
input_dir = 'Projects/AMP/notpossible/rt_adjustment_6/'
output_dir = 'Projects/AMP/fame_filter_7/notpossible_nov6/'


# Call the function with custom fame_rt_window and parent_ion_tolerance
filter_OzOFF_by_fame_std(input_dir, fame_std, output_dir, fame_rt_window=0.5)
# Out:
# Starting filter_OzOFF_by_fame_std function
# Input directory: Projects/AMP/notpossible/rt_adjustment_6/
# Output directory: Projects/AMP/fame_filter_7/notpossible_nov6/
# Retention time window: 0.5
# Fame standard DataFrame columns: ['Lipid', 'Retention_Time', 'OzESI_Intensity', 'group_by_ion', 'group_by_lipid', 'Sample_ID', 'Transition', 'Sample', 'Parent_Ion', 'Product_Ion', 'Species', 'Class', 'STD', 'STD_RT_OFF', 'Peak_Height', 'FWHM', 'Peak_Width', 'Peak_Area', 'Filter_Column', 'Isomer']
# Number of parquet files found in input directory: 1
# Processing file: df_rt_adjustment_6_hippo_WT_m1_FAD245_OFF.parquet
# Lipid_Possible column created
# Processing fame_std entry: Retention_Time=6.910983333333333, Species=16:1
# Adjusted RT bounds: 6.410983333333333 to 7.410983333333333
# Row 0: Adjusted_RT_FAME=3.289066666666667, Species=16:0
# Species list after split: ['16:0']
# No match for row 0: RT difference=3.1219166666666665, Species mismatch or RT out of bounds
# Row 1: Adjusted_RT_FAME=3.805883333333333, Species=16:0
# Species list after split: ['16:0']
# No match for row 1: RT difference=2.6051, Species mismatch or RT out of bounds
# Row 2: Adjusted_RT_FAME=3.9996833333333335, Species=16:0
# Species list after split: ['16:0']
# No match for row 2: RT difference=2.4112999999999998, Species mismatch or RT out of bounds
# Row 3: Adjusted_RT_FAME=7.6303, Species=16:0
# Species list after split: ['16:0']
# No match for row 3: RT difference=0.21931666666666683, Species mismatch or RT out of bounds
# Row 4: Adjusted_RT_FAME=8.289233333333334, Species=16:0
# Species list after split: ['16:0']
# No match for row 4: RT difference=0.8782500000000004, Species mismatch or RT out of bounds
# Row 5: Adjusted_RT_FAME=8.508883333333333, Species=16:0
# Species list after split: ['16:0']
# No match for row 5: RT difference=1.0979, Species mismatch or RT out of bounds
# Row 6: Adjusted_RT_FAME=15.804116666666665, Species=24:0|25:1|25:2|26:1|26:2|26:3|27:1|27:2|27:3|27:4|28:1|28:2|28:3|28:4|28:5|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['24:0', '25:1', '25:2', '26:1', '26:2', '26:3', '27:1', '27:2', '27:3', '27:4', '28:1', '28:2', '28:3', '28:4', '28:5', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 6: RT difference=8.393133333333331, Species mismatch or RT out of bounds
# Row 7: Adjusted_RT_FAME=15.933333333333334, Species=24:0|25:1|25:2|26:1|26:2|26:3|27:1|27:2|27:3|27:4|28:1|28:2|28:3|28:4|28:5|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['24:0', '25:1', '25:2', '26:1', '26:2', '26:3', '27:1', '27:2', '27:3', '27:4', '28:1', '28:2', '28:3', '28:4', '28:5', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 7: RT difference=8.52235, Species mismatch or RT out of bounds
# Row 8: Adjusted_RT_FAME=11.36015, Species=22:0|23:1|23:2|24:1|24:2|24:3|25:1|25:2|25:3|25:4|26:1|26:2|26:3|26:4|26:5|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['22:0', '23:1', '23:2', '24:1', '24:2', '24:3', '25:1', '25:2', '25:3', '25:4', '26:1', '26:2', '26:3', '26:4', '26:5', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 8: RT difference=3.9491666666666676, Species mismatch or RT out of bounds
# Row 9: Adjusted_RT_FAME=13.7375, Species=22:0|23:1|23:2|24:1|24:2|24:3|25:1|25:2|25:3|25:4|26:1|26:2|26:3|26:4|26:5|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['22:0', '23:1', '23:2', '24:1', '24:2', '24:3', '25:1', '25:2', '25:3', '25:4', '26:1', '26:2', '26:3', '26:4', '26:5', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 9: RT difference=6.3265166666666675, Species mismatch or RT out of bounds
# Row 10: Adjusted_RT_FAME=14.241383333333333, Species=22:0|23:1|23:2|24:1|24:2|24:3|25:1|25:2|25:3|25:4|26:1|26:2|26:3|26:4|26:5|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['22:0', '23:1', '23:2', '24:1', '24:2', '24:3', '25:1', '25:2', '25:3', '25:4', '26:1', '26:2', '26:3', '26:4', '26:5', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 10: RT difference=6.8304, Species mismatch or RT out of bounds
# Row 11: Adjusted_RT_FAME=14.525633333333333, Species=22:0|23:1|23:2|24:1|24:2|24:3|25:1|25:2|25:3|25:4|26:1|26:2|26:3|26:4|26:5|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['22:0', '23:1', '23:2', '24:1', '24:2', '24:3', '25:1', '25:2', '25:3', '25:4', '26:1', '26:2', '26:3', '26:4', '26:5', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 11: RT difference=7.11465, Species mismatch or RT out of bounds
# Row 12: Adjusted_RT_FAME=11.696283333333334, Species=23:2|23:3|24:2|24:3|24:4|25:2|25:3|25:4|25:5|26:2|26:3|26:4|26:5|26:6|27:2|27:3|27:4|27:5|27:6|28:2|28:3|28:4|28:5|28:6|29:2|29:3|29:4|29:5|29:6|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['23:2', '23:3', '24:2', '24:3', '24:4', '25:2', '25:3', '25:4', '25:5', '26:2', '26:3', '26:4', '26:5', '26:6', '27:2', '27:3', '27:4', '27:5', '27:6', '28:2', '28:3', '28:4', '28:5', '28:6', '29:2', '29:3', '29:4', '29:5', '29:6', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 12: RT difference=4.2853, Species mismatch or RT out of bounds
# Row 13: Adjusted_RT_FAME=12.135583333333333, Species=23:2|23:3|24:2|24:3|24:4|25:2|25:3|25:4|25:5|26:2|26:3|26:4|26:5|26:6|27:2|27:3|27:4|27:5|27:6|28:2|28:3|28:4|28:5|28:6|29:2|29:3|29:4|29:5|29:6|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['23:2', '23:3', '24:2', '24:3', '24:4', '25:2', '25:3', '25:4', '25:5', '26:2', '26:3', '26:4', '26:5', '26:6', '27:2', '27:3', '27:4', '27:5', '27:6', '28:2', '28:3', '28:4', '28:5', '28:6', '29:2', '29:3', '29:4', '29:5', '29:6', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 13: RT difference=4.7246, Species mismatch or RT out of bounds
# Row 14: Adjusted_RT_FAME=12.536116666666667, Species=23:2|23:3|24:2|24:3|24:4|25:2|25:3|25:4|25:5|26:2|26:3|26:4|26:5|26:6|27:2|27:3|27:4|27:5|27:6|28:2|28:3|28:4|28:5|28:6|29:2|29:3|29:4|29:5|29:6|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['23:2', '23:3', '24:2', '24:3', '24:4', '25:2', '25:3', '25:4', '25:5', '26:2', '26:3', '26:4', '26:5', '26:6', '27:2', '27:3', '27:4', '27:5', '27:6', '28:2', '28:3', '28:4', '28:5', '28:6', '29:2', '29:3', '29:4', '29:5', '29:6', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 14: RT difference=5.125133333333333, Species mismatch or RT out of bounds
# Row 15: Adjusted_RT_FAME=7.5624, Species=21:0|22:1|22:2|23:1|23:2|23:3|24:1|24:2|24:3|24:4|25:1|25:2|25:3|25:4|25:5|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['21:0', '22:1', '22:2', '23:1', '23:2', '23:3', '24:1', '24:2', '24:3', '24:4', '25:1', '25:2', '25:3', '25:4', '25:5', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 15: RT difference=0.15141666666666698, Species mismatch or RT out of bounds
# Row 16: Adjusted_RT_FAME=10.327350000000001, Species=21:0|22:1|22:2|23:1|23:2|23:3|24:1|24:2|24:3|24:4|25:1|25:2|25:3|25:4|25:5|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['21:0', '22:1', '22:2', '23:1', '23:2', '23:3', '24:1', '24:2', '24:3', '24:4', '25:1', '25:2', '25:3', '25:4', '25:5', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 16: RT difference=2.9163666666666677, Species mismatch or RT out of bounds
# Row 17: Adjusted_RT_FAME=11.580633333333333, Species=21:0|22:1|22:2|23:1|23:2|23:3|24:1|24:2|24:3|24:4|25:1|25:2|25:3|25:4|25:5|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['21:0', '22:1', '22:2', '23:1', '23:2', '23:3', '24:1', '24:2', '24:3', '24:4', '25:1', '25:2', '25:3', '25:4', '25:5', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 17: RT difference=4.16965, Species mismatch or RT out of bounds
# Row 18: Adjusted_RT_FAME=11.683983333333334, Species=21:0|22:1|22:2|23:1|23:2|23:3|24:1|24:2|24:3|24:4|25:1|25:2|25:3|25:4|25:5|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['21:0', '22:1', '22:2', '23:1', '23:2', '23:3', '24:1', '24:2', '24:3', '24:4', '25:1', '25:2', '25:3', '25:4', '25:5', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 18: RT difference=4.273000000000001, Species mismatch or RT out of bounds
# Row 19: Adjusted_RT_FAME=11.90365, Species=21:0|22:1|22:2|23:1|23:2|23:3|24:1|24:2|24:3|24:4|25:1|25:2|25:3|25:4|25:5|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['21:0', '22:1', '22:2', '23:1', '23:2', '23:3', '24:1', '24:2', '24:3', '24:4', '25:1', '25:2', '25:3', '25:4', '25:5', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 19: RT difference=4.4926666666666675, Species mismatch or RT out of bounds
# Row 20: Adjusted_RT_FAME=12.071616666666667, Species=21:0|22:1|22:2|23:1|23:2|23:3|24:1|24:2|24:3|24:4|25:1|25:2|25:3|25:4|25:5|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['21:0', '22:1', '22:2', '23:1', '23:2', '23:3', '24:1', '24:2', '24:3', '24:4', '25:1', '25:2', '25:3', '25:4', '25:5', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 20: RT difference=4.660633333333334, Species mismatch or RT out of bounds
# Row 21: Adjusted_RT_FAME=12.226650000000001, Species=21:0|22:1|22:2|23:1|23:2|23:3|24:1|24:2|24:3|24:4|25:1|25:2|25:3|25:4|25:5|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['21:0', '22:1', '22:2', '23:1', '23:2', '23:3', '24:1', '24:2', '24:3', '24:4', '25:1', '25:2', '25:3', '25:4', '25:5', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 21: RT difference=4.815666666666668, Species mismatch or RT out of bounds
# Row 22: Adjusted_RT_FAME=12.497983333333334, Species=21:0|22:1|22:2|23:1|23:2|23:3|24:1|24:2|24:3|24:4|25:1|25:2|25:3|25:4|25:5|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['21:0', '22:1', '22:2', '23:1', '23:2', '23:3', '24:1', '24:2', '24:3', '24:4', '25:1', '25:2', '25:3', '25:4', '25:5', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 22: RT difference=5.087000000000001, Species mismatch or RT out of bounds
# Row 23: Adjusted_RT_FAME=12.8339, Species=21:0|22:1|22:2|23:1|23:2|23:3|24:1|24:2|24:3|24:4|25:1|25:2|25:3|25:4|25:5|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['21:0', '22:1', '22:2', '23:1', '23:2', '23:3', '24:1', '24:2', '24:3', '24:4', '25:1', '25:2', '25:3', '25:4', '25:5', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 23: RT difference=5.422916666666667, Species mismatch or RT out of bounds
# Row 24: Adjusted_RT_FAME=13.001866666666666, Species=21:0|22:1|22:2|23:1|23:2|23:3|24:1|24:2|24:3|24:4|25:1|25:2|25:3|25:4|25:5|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['21:0', '22:1', '22:2', '23:1', '23:2', '23:3', '24:1', '24:2', '24:3', '24:4', '25:1', '25:2', '25:3', '25:4', '25:5', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 24: RT difference=5.590883333333333, Species mismatch or RT out of bounds
# Row 25: Adjusted_RT_FAME=3.9061500000000002, Species=20:0|21:1|21:2|22:1|22:2|22:3|23:1|23:2|23:3|23:4|24:1|24:2|24:3|24:4|24:5|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['20:0', '21:1', '21:2', '22:1', '22:2', '22:3', '23:1', '23:2', '23:3', '23:4', '24:1', '24:2', '24:3', '24:4', '24:5', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 25: RT difference=2.504833333333333, Species mismatch or RT out of bounds
# Row 26: Adjusted_RT_FAME=3.944916666666667, Species=20:0|21:1|21:2|22:1|22:2|22:3|23:1|23:2|23:3|23:4|24:1|24:2|24:3|24:4|24:5|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['20:0', '21:1', '21:2', '22:1', '22:2', '22:3', '23:1', '23:2', '23:3', '23:4', '24:1', '24:2', '24:3', '24:4', '24:5', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 26: RT difference=2.4660666666666664, Species mismatch or RT out of bounds
# Row 27: Adjusted_RT_FAME=4.074116666666667, Species=20:0|21:1|21:2|22:1|22:2|22:3|23:1|23:2|23:3|23:4|24:1|24:2|24:3|24:4|24:5|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['20:0', '21:1', '21:2', '22:1', '22:2', '22:3', '23:1', '23:2', '23:3', '23:4', '24:1', '24:2', '24:3', '24:4', '24:5', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 27: RT difference=2.3368666666666664, Species mismatch or RT out of bounds
# Row 28: Adjusted_RT_FAME=9.384366666666667, Species=20:0|21:1|21:2|22:1|22:2|22:3|23:1|23:2|23:3|23:4|24:1|24:2|24:3|24:4|24:5|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['20:0', '21:1', '21:2', '22:1', '22:2', '22:3', '23:1', '23:2', '23:3', '23:4', '24:1', '24:2', '24:3', '24:4', '24:5', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 28: RT difference=1.9733833333333335, Species mismatch or RT out of bounds
# Row 29: Adjusted_RT_FAME=10.430916666666667, Species=20:0|21:1|21:2|22:1|22:2|22:3|23:1|23:2|23:3|23:4|24:1|24:2|24:3|24:4|24:5|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['20:0', '21:1', '21:2', '22:1', '22:2', '22:3', '23:1', '23:2', '23:3', '23:4', '24:1', '24:2', '24:3', '24:4', '24:5', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 29: RT difference=3.0199333333333334, Species mismatch or RT out of bounds
# Row 30: Adjusted_RT_FAME=10.76685, Species=20:0|21:1|21:2|22:1|22:2|22:3|23:1|23:2|23:3|23:4|24:1|24:2|24:3|24:4|24:5|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['20:0', '21:1', '21:2', '22:1', '22:2', '22:3', '23:1', '23:2', '23:3', '23:4', '24:1', '24:2', '24:3', '24:4', '24:5', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 30: RT difference=3.3558666666666666, Species mismatch or RT out of bounds
# Row 31: Adjusted_RT_FAME=10.947750000000001, Species=20:0|21:1|21:2|22:1|22:2|22:3|23:1|23:2|23:3|23:4|24:1|24:2|24:3|24:4|24:5|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['20:0', '21:1', '21:2', '22:1', '22:2', '22:3', '23:1', '23:2', '23:3', '23:4', '24:1', '24:2', '24:3', '24:4', '24:5', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 31: RT difference=3.5367666666666677, Species mismatch or RT out of bounds
# Row 32: Adjusted_RT_FAME=11.206150000000001, Species=20:0|21:1|21:2|22:1|22:2|22:3|23:1|23:2|23:3|23:4|24:1|24:2|24:3|24:4|24:5|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['20:0', '21:1', '21:2', '22:1', '22:2', '22:3', '23:1', '23:2', '23:3', '23:4', '24:1', '24:2', '24:3', '24:4', '24:5', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 32: RT difference=3.7951666666666677, Species mismatch or RT out of bounds
# Row 33: Adjusted_RT_FAME=11.438716666666666, Species=20:0|21:1|21:2|22:1|22:2|22:3|23:1|23:2|23:3|23:4|24:1|24:2|24:3|24:4|24:5|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['20:0', '21:1', '21:2', '22:1', '22:2', '22:3', '23:1', '23:2', '23:3', '23:4', '24:1', '24:2', '24:3', '24:4', '24:5', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 33: RT difference=4.027733333333333, Species mismatch or RT out of bounds
# Row 34: Adjusted_RT_FAME=11.735883333333334, Species=20:0|21:1|21:2|22:1|22:2|22:3|23:1|23:2|23:3|23:4|24:1|24:2|24:3|24:4|24:5|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['20:0', '21:1', '21:2', '22:1', '22:2', '22:3', '23:1', '23:2', '23:3', '23:4', '24:1', '24:2', '24:3', '24:4', '24:5', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 34: RT difference=4.3249, Species mismatch or RT out of bounds
# Row 35: Adjusted_RT_FAME=12.743666666666668, Species=20:0|21:1|21:2|22:1|22:2|22:3|23:1|23:2|23:3|23:4|24:1|24:2|24:3|24:4|24:5|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['20:0', '21:1', '21:2', '22:1', '22:2', '22:3', '23:1', '23:2', '23:3', '23:4', '24:1', '24:2', '24:3', '24:4', '24:5', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 35: RT difference=5.3326833333333346, Species mismatch or RT out of bounds
# Row 36: Adjusted_RT_FAME=12.859950000000001, Species=20:0|21:1|21:2|22:1|22:2|22:3|23:1|23:2|23:3|23:4|24:1|24:2|24:3|24:4|24:5|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['20:0', '21:1', '21:2', '22:1', '22:2', '22:3', '23:1', '23:2', '23:3', '23:4', '24:1', '24:2', '24:3', '24:4', '24:5', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 36: RT difference=5.448966666666668, Species mismatch or RT out of bounds
# Row 37: Adjusted_RT_FAME=3.5058166666666666, Species=21:2|21:3|22:2|22:3|22:4|23:2|23:3|23:4|23:5|24:2|24:3|24:4|24:5|24:6|25:2|25:3|25:4|25:5|25:6|26:2|26:3|26:4|26:5|26:6|27:2|27:3|27:4|27:5|27:6|28:2|28:3|28:4|28:5|28:6|29:2|29:3|29:4|29:5|29:6|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['21:2', '21:3', '22:2', '22:3', '22:4', '23:2', '23:3', '23:4', '23:5', '24:2', '24:3', '24:4', '24:5', '24:6', '25:2', '25:3', '25:4', '25:5', '25:6', '26:2', '26:3', '26:4', '26:5', '26:6', '27:2', '27:3', '27:4', '27:5', '27:6', '28:2', '28:3', '28:4', '28:5', '28:6', '29:2', '29:3', '29:4', '29:5', '29:6', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 37: RT difference=2.9051666666666667, Species mismatch or RT out of bounds
# Row 38: Adjusted_RT_FAME=3.64795, Species=21:2|21:3|22:2|22:3|22:4|23:2|23:3|23:4|23:5|24:2|24:3|24:4|24:5|24:6|25:2|25:3|25:4|25:5|25:6|26:2|26:3|26:4|26:5|26:6|27:2|27:3|27:4|27:5|27:6|28:2|28:3|28:4|28:5|28:6|29:2|29:3|29:4|29:5|29:6|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['21:2', '21:3', '22:2', '22:3', '22:4', '23:2', '23:3', '23:4', '23:5', '24:2', '24:3', '24:4', '24:5', '24:6', '25:2', '25:3', '25:4', '25:5', '25:6', '26:2', '26:3', '26:4', '26:5', '26:6', '27:2', '27:3', '27:4', '27:5', '27:6', '28:2', '28:3', '28:4', '28:5', '28:6', '29:2', '29:3', '29:4', '29:5', '29:6', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 38: RT difference=2.7630333333333335, Species mismatch or RT out of bounds
# Row 39: Adjusted_RT_FAME=9.384583333333333, Species=21:2|21:3|22:2|22:3|22:4|23:2|23:3|23:4|23:5|24:2|24:3|24:4|24:5|24:6|25:2|25:3|25:4|25:5|25:6|26:2|26:3|26:4|26:5|26:6|27:2|27:3|27:4|27:5|27:6|28:2|28:3|28:4|28:5|28:6|29:2|29:3|29:4|29:5|29:6|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['21:2', '21:3', '22:2', '22:3', '22:4', '23:2', '23:3', '23:4', '23:5', '24:2', '24:3', '24:4', '24:5', '24:6', '25:2', '25:3', '25:4', '25:5', '25:6', '26:2', '26:3', '26:4', '26:5', '26:6', '27:2', '27:3', '27:4', '27:5', '27:6', '28:2', '28:3', '28:4', '28:5', '28:6', '29:2', '29:3', '29:4', '29:5', '29:6', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 39: RT difference=1.9736000000000002, Species mismatch or RT out of bounds
# Row 40: Adjusted_RT_FAME=10.056433333333334, Species=21:2|21:3|22:2|22:3|22:4|23:2|23:3|23:4|23:5|24:2|24:3|24:4|24:5|24:6|25:2|25:3|25:4|25:5|25:6|26:2|26:3|26:4|26:5|26:6|27:2|27:3|27:4|27:5|27:6|28:2|28:3|28:4|28:5|28:6|29:2|29:3|29:4|29:5|29:6|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['21:2', '21:3', '22:2', '22:3', '22:4', '23:2', '23:3', '23:4', '23:5', '24:2', '24:3', '24:4', '24:5', '24:6', '25:2', '25:3', '25:4', '25:5', '25:6', '26:2', '26:3', '26:4', '26:5', '26:6', '27:2', '27:3', '27:4', '27:5', '27:6', '28:2', '28:3', '28:4', '28:5', '28:6', '29:2', '29:3', '29:4', '29:5', '29:6', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 40: RT difference=2.645450000000001, Species mismatch or RT out of bounds
# Row 41: Adjusted_RT_FAME=10.26315, Species=21:2|21:3|22:2|22:3|22:4|23:2|23:3|23:4|23:5|24:2|24:3|24:4|24:5|24:6|25:2|25:3|25:4|25:5|25:6|26:2|26:3|26:4|26:5|26:6|27:2|27:3|27:4|27:5|27:6|28:2|28:3|28:4|28:5|28:6|29:2|29:3|29:4|29:5|29:6|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['21:2', '21:3', '22:2', '22:3', '22:4', '23:2', '23:3', '23:4', '23:5', '24:2', '24:3', '24:4', '24:5', '24:6', '25:2', '25:3', '25:4', '25:5', '25:6', '26:2', '26:3', '26:4', '26:5', '26:6', '27:2', '27:3', '27:4', '27:5', '27:6', '28:2', '28:3', '28:4', '28:5', '28:6', '29:2', '29:3', '29:4', '29:5', '29:6', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 41: RT difference=2.8521666666666663, Species mismatch or RT out of bounds
# Row 42: Adjusted_RT_FAME=10.57325, Species=21:2|21:3|22:2|22:3|22:4|23:2|23:3|23:4|23:5|24:2|24:3|24:4|24:5|24:6|25:2|25:3|25:4|25:5|25:6|26:2|26:3|26:4|26:5|26:6|27:2|27:3|27:4|27:5|27:6|28:2|28:3|28:4|28:5|28:6|29:2|29:3|29:4|29:5|29:6|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['21:2', '21:3', '22:2', '22:3', '22:4', '23:2', '23:3', '23:4', '23:5', '24:2', '24:3', '24:4', '24:5', '24:6', '25:2', '25:3', '25:4', '25:5', '25:6', '26:2', '26:3', '26:4', '26:5', '26:6', '27:2', '27:3', '27:4', '27:5', '27:6', '28:2', '28:3', '28:4', '28:5', '28:6', '29:2', '29:3', '29:4', '29:5', '29:6', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 42: RT difference=3.1622666666666666, Species mismatch or RT out of bounds
# Row 43: Adjusted_RT_FAME=10.94795, Species=21:2|21:3|22:2|22:3|22:4|23:2|23:3|23:4|23:5|24:2|24:3|24:4|24:5|24:6|25:2|25:3|25:4|25:5|25:6|26:2|26:3|26:4|26:5|26:6|27:2|27:3|27:4|27:5|27:6|28:2|28:3|28:4|28:5|28:6|29:2|29:3|29:4|29:5|29:6|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['21:2', '21:3', '22:2', '22:3', '22:4', '23:2', '23:3', '23:4', '23:5', '24:2', '24:3', '24:4', '24:5', '24:6', '25:2', '25:3', '25:4', '25:5', '25:6', '26:2', '26:3', '26:4', '26:5', '26:6', '27:2', '27:3', '27:4', '27:5', '27:6', '28:2', '28:3', '28:4', '28:5', '28:6', '29:2', '29:3', '29:4', '29:5', '29:6', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 43: RT difference=3.5369666666666673, Species mismatch or RT out of bounds
# Row 44: Adjusted_RT_FAME=8.72585, Species=21:3|21:4|22:3|22:4|22:5|23:3|23:4|23:5|23:6|24:3|24:4|24:5|24:6|25:3|25:4|25:5|25:6|26:3|26:4|26:5|26:6|27:3|27:4|27:5|27:6|28:3|28:4|28:5|28:6|29:3|29:4|29:5|29:6|30:3|30:4|30:5|30:6
# Species list after split: ['21:3', '21:4', '22:3', '22:4', '22:5', '23:3', '23:4', '23:5', '23:6', '24:3', '24:4', '24:5', '24:6', '25:3', '25:4', '25:5', '25:6', '26:3', '26:4', '26:5', '26:6', '27:3', '27:4', '27:5', '27:6', '28:3', '28:4', '28:5', '28:6', '29:3', '29:4', '29:5', '29:6', '30:3', '30:4', '30:5', '30:6']
# No match for row 44: RT difference=1.3148666666666662, Species mismatch or RT out of bounds
# Row 45: Adjusted_RT_FAME=8.98425, Species=21:3|21:4|22:3|22:4|22:5|23:3|23:4|23:5|23:6|24:3|24:4|24:5|24:6|25:3|25:4|25:5|25:6|26:3|26:4|26:5|26:6|27:3|27:4|27:5|27:6|28:3|28:4|28:5|28:6|29:3|29:4|29:5|29:6|30:3|30:4|30:5|30:6
# Species list after split: ['21:3', '21:4', '22:3', '22:4', '22:5', '23:3', '23:4', '23:5', '23:6', '24:3', '24:4', '24:5', '24:6', '25:3', '25:4', '25:5', '25:6', '26:3', '26:4', '26:5', '26:6', '27:3', '27:4', '27:5', '27:6', '28:3', '28:4', '28:5', '28:6', '29:3', '29:4', '29:5', '29:6', '30:3', '30:4', '30:5', '30:6']
# No match for row 45: RT difference=1.5732666666666661, Species mismatch or RT out of bounds
# Row 46: Adjusted_RT_FAME=9.190983333333334, Species=21:3|21:4|22:3|22:4|22:5|23:3|23:4|23:5|23:6|24:3|24:4|24:5|24:6|25:3|25:4|25:5|25:6|26:3|26:4|26:5|26:6|27:3|27:4|27:5|27:6|28:3|28:4|28:5|28:6|29:3|29:4|29:5|29:6|30:3|30:4|30:5|30:6
# Species list after split: ['21:3', '21:4', '22:3', '22:4', '22:5', '23:3', '23:4', '23:5', '23:6', '24:3', '24:4', '24:5', '24:6', '25:3', '25:4', '25:5', '25:6', '26:3', '26:4', '26:5', '26:6', '27:3', '27:4', '27:5', '27:6', '28:3', '28:4', '28:5', '28:6', '29:3', '29:4', '29:5', '29:6', '30:3', '30:4', '30:5', '30:6']
# No match for row 46: RT difference=1.7800000000000002, Species mismatch or RT out of bounds
# Row 47: Adjusted_RT_FAME=9.371866666666667, Species=21:3|21:4|22:3|22:4|22:5|23:3|23:4|23:5|23:6|24:3|24:4|24:5|24:6|25:3|25:4|25:5|25:6|26:3|26:4|26:5|26:6|27:3|27:4|27:5|27:6|28:3|28:4|28:5|28:6|29:3|29:4|29:5|29:6|30:3|30:4|30:5|30:6
# Species list after split: ['21:3', '21:4', '22:3', '22:4', '22:5', '23:3', '23:4', '23:5', '23:6', '24:3', '24:4', '24:5', '24:6', '25:3', '25:4', '25:5', '25:6', '26:3', '26:4', '26:5', '26:6', '27:3', '27:4', '27:5', '27:6', '28:3', '28:4', '28:5', '28:6', '29:3', '29:4', '29:5', '29:6', '30:3', '30:4', '30:5', '30:6']
# No match for row 47: RT difference=1.9608833333333342, Species mismatch or RT out of bounds
# Row 48: Adjusted_RT_FAME=8.364283333333333, Species=21:4|21:5|22:4|22:5|22:6|23:4|23:5|23:6|24:4|24:5|24:6|25:4|25:5|25:6|26:4|26:5|26:6|27:4|27:5|27:6|28:4|28:5|28:6|29:4|29:5|29:6|30:4|30:5|30:6
# Species list after split: ['21:4', '21:5', '22:4', '22:5', '22:6', '23:4', '23:5', '23:6', '24:4', '24:5', '24:6', '25:4', '25:5', '25:6', '26:4', '26:5', '26:6', '27:4', '27:5', '27:6', '28:4', '28:5', '28:6', '29:4', '29:5', '29:6', '30:4', '30:5', '30:6']
# No match for row 48: RT difference=0.9532999999999996, Species mismatch or RT out of bounds
# Row 49: Adjusted_RT_FAME=5.625383333333334, Species=21:5|21:6|22:5|22:6|23:5|23:6|24:5|24:6|25:5|25:6|26:5|26:6|27:5|27:6|28:5|28:6|29:5|29:6|30:5|30:6
# Species list after split: ['21:5', '21:6', '22:5', '22:6', '23:5', '23:6', '24:5', '24:6', '25:5', '25:6', '26:5', '26:6', '27:5', '27:6', '28:5', '28:6', '29:5', '29:6', '30:5', '30:6']
# No match for row 49: RT difference=0.7855999999999996, Species mismatch or RT out of bounds
# Row 50: Adjusted_RT_FAME=7.2921000000000005, Species=21:5|21:6|22:5|22:6|23:5|23:6|24:5|24:6|25:5|25:6|26:5|26:6|27:5|27:6|28:5|28:6|29:5|29:6|30:5|30:6
# Species list after split: ['21:5', '21:6', '22:5', '22:6', '23:5', '23:6', '24:5', '24:6', '25:5', '25:6', '26:5', '26:6', '27:5', '27:6', '28:5', '28:6', '29:5', '29:6', '30:5', '30:6']
# No match for row 50: RT difference=0.11888333333333279, Species mismatch or RT out of bounds
# Row 51: Adjusted_RT_FAME=7.5376, Species=21:5|21:6|22:5|22:6|23:5|23:6|24:5|24:6|25:5|25:6|26:5|26:6|27:5|27:6|28:5|28:6|29:5|29:6|30:5|30:6
# Species list after split: ['21:5', '21:6', '22:5', '22:6', '23:5', '23:6', '24:5', '24:6', '25:5', '25:6', '26:5', '26:6', '27:5', '27:6', '28:5', '28:6', '29:5', '29:6', '30:5', '30:6']
# No match for row 51: RT difference=0.12661666666666704, Species mismatch or RT out of bounds
# Row 52: Adjusted_RT_FAME=4.90205, Species=21:6|22:6|23:6|24:6|25:6|26:6|27:6|28:6|29:6|30:6
# Species list after split: ['21:6', '22:6', '23:6', '24:6', '25:6', '26:6', '27:6', '28:6', '29:6', '30:6']
# No match for row 52: RT difference=1.5089333333333332, Species mismatch or RT out of bounds
# Row 53: Adjusted_RT_FAME=5.108783333333333, Species=21:6|22:6|23:6|24:6|25:6|26:6|27:6|28:6|29:6|30:6
# Species list after split: ['21:6', '22:6', '23:6', '24:6', '25:6', '26:6', '27:6', '28:6', '29:6', '30:6']
# No match for row 53: RT difference=1.3022, Species mismatch or RT out of bounds
# Row 54: Adjusted_RT_FAME=5.212133333333333, Species=21:6|22:6|23:6|24:6|25:6|26:6|27:6|28:6|29:6|30:6
# Species list after split: ['21:6', '22:6', '23:6', '24:6', '25:6', '26:6', '27:6', '28:6', '29:6', '30:6']
# No match for row 54: RT difference=1.1988500000000002, Species mismatch or RT out of bounds
# Row 55: Adjusted_RT_FAME=5.3155, Species=21:6|22:6|23:6|24:6|25:6|26:6|27:6|28:6|29:6|30:6
# Species list after split: ['21:6', '22:6', '23:6', '24:6', '25:6', '26:6', '27:6', '28:6', '29:6', '30:6']
# No match for row 55: RT difference=1.0954833333333331, Species mismatch or RT out of bounds
# Row 56: Adjusted_RT_FAME=5.4447, Species=21:6|22:6|23:6|24:6|25:6|26:6|27:6|28:6|29:6|30:6
# Species list after split: ['21:6', '22:6', '23:6', '24:6', '25:6', '26:6', '27:6', '28:6', '29:6', '30:6']
# No match for row 56: RT difference=0.9662833333333332, Species mismatch or RT out of bounds
# Row 57: Adjusted_RT_FAME=5.625583333333333, Species=21:6|22:6|23:6|24:6|25:6|26:6|27:6|28:6|29:6|30:6
# Species list after split: ['21:6', '22:6', '23:6', '24:6', '25:6', '26:6', '27:6', '28:6', '29:6', '30:6']
# No match for row 57: RT difference=0.7854000000000001, Species mismatch or RT out of bounds
# Row 58: Adjusted_RT_FAME=5.832316666666666, Species=21:6|22:6|23:6|24:6|25:6|26:6|27:6|28:6|29:6|30:6
# Species list after split: ['21:6', '22:6', '23:6', '24:6', '25:6', '26:6', '27:6', '28:6', '29:6', '30:6']
# No match for row 58: RT difference=0.5786666666666669, Species mismatch or RT out of bounds
# Row 59: Adjusted_RT_FAME=4.295, Species=19:0|20:1|20:2|21:1|21:2|21:3|22:1|22:2|22:3|22:4|23:1|23:2|23:3|23:4|23:5|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['19:0', '20:1', '20:2', '21:1', '21:2', '21:3', '22:1', '22:2', '22:3', '22:4', '23:1', '23:2', '23:3', '23:4', '23:5', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 59: RT difference=2.1159833333333333, Species mismatch or RT out of bounds
# Row 60: Adjusted_RT_FAME=4.4629666666666665, Species=19:0|20:1|20:2|21:1|21:2|21:3|22:1|22:2|22:3|22:4|23:1|23:2|23:3|23:4|23:5|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['19:0', '20:1', '20:2', '21:1', '21:2', '21:3', '22:1', '22:2', '22:3', '22:4', '23:1', '23:2', '23:3', '23:4', '23:5', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 60: RT difference=1.9480166666666667, Species mismatch or RT out of bounds
# Row 61: Adjusted_RT_FAME=4.553416666666667, Species=19:0|20:1|20:2|21:1|21:2|21:3|22:1|22:2|22:3|22:4|23:1|23:2|23:3|23:4|23:5|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['19:0', '20:1', '20:2', '21:1', '21:2', '21:3', '22:1', '22:2', '22:3', '22:4', '23:1', '23:2', '23:3', '23:4', '23:5', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 61: RT difference=1.8575666666666661, Species mismatch or RT out of bounds
# Row 62: Adjusted_RT_FAME=4.747216666666667, Species=19:0|20:1|20:2|21:1|21:2|21:3|22:1|22:2|22:3|22:4|23:1|23:2|23:3|23:4|23:5|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['19:0', '20:1', '20:2', '21:1', '21:2', '21:3', '22:1', '22:2', '22:3', '22:4', '23:1', '23:2', '23:3', '23:4', '23:5', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 62: RT difference=1.6637666666666666, Species mismatch or RT out of bounds
# Row 63: Adjusted_RT_FAME=4.876416666666667, Species=19:0|20:1|20:2|21:1|21:2|21:3|22:1|22:2|22:3|22:4|23:1|23:2|23:3|23:4|23:5|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['19:0', '20:1', '20:2', '21:1', '21:2', '21:3', '22:1', '22:2', '22:3', '22:4', '23:1', '23:2', '23:3', '23:4', '23:5', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 63: RT difference=1.5345666666666666, Species mismatch or RT out of bounds
# Row 64: Adjusted_RT_FAME=5.0573, Species=19:0|20:1|20:2|21:1|21:2|21:3|22:1|22:2|22:3|22:4|23:1|23:2|23:3|23:4|23:5|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['19:0', '20:1', '20:2', '21:1', '21:2', '21:3', '22:1', '22:2', '22:3', '22:4', '23:1', '23:2', '23:3', '23:4', '23:5', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 64: RT difference=1.3536833333333336, Species mismatch or RT out of bounds
# Row 65: Adjusted_RT_FAME=5.199433333333333, Species=19:0|20:1|20:2|21:1|21:2|21:3|22:1|22:2|22:3|22:4|23:1|23:2|23:3|23:4|23:5|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['19:0', '20:1', '20:2', '21:1', '21:2', '21:3', '22:1', '22:2', '22:3', '22:4', '23:1', '23:2', '23:3', '23:4', '23:5', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 65: RT difference=1.21155, Species mismatch or RT out of bounds
# Row 66: Adjusted_RT_FAME=5.380316666666666, Species=19:0|20:1|20:2|21:1|21:2|21:3|22:1|22:2|22:3|22:4|23:1|23:2|23:3|23:4|23:5|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['19:0', '20:1', '20:2', '21:1', '21:2', '21:3', '22:1', '22:2', '22:3', '22:4', '23:1', '23:2', '23:3', '23:4', '23:5', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 66: RT difference=1.0306666666666668, Species mismatch or RT out of bounds
# Row 67: Adjusted_RT_FAME=5.47075, Species=19:0|20:1|20:2|21:1|21:2|21:3|22:1|22:2|22:3|22:4|23:1|23:2|23:3|23:4|23:5|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['19:0', '20:1', '20:2', '21:1', '21:2', '21:3', '22:1', '22:2', '22:3', '22:4', '23:1', '23:2', '23:3', '23:4', '23:5', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 67: RT difference=0.9402333333333335, Species mismatch or RT out of bounds
# Row 68: Adjusted_RT_FAME=5.638716666666666, Species=19:0|20:1|20:2|21:1|21:2|21:3|22:1|22:2|22:3|22:4|23:1|23:2|23:3|23:4|23:5|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['19:0', '20:1', '20:2', '21:1', '21:2', '21:3', '22:1', '22:2', '22:3', '22:4', '23:1', '23:2', '23:3', '23:4', '23:5', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 68: RT difference=0.7722666666666669, Species mismatch or RT out of bounds
# Row 69: Adjusted_RT_FAME=5.767916666666666, Species=19:0|20:1|20:2|21:1|21:2|21:3|22:1|22:2|22:3|22:4|23:1|23:2|23:3|23:4|23:5|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['19:0', '20:1', '20:2', '21:1', '21:2', '21:3', '22:1', '22:2', '22:3', '22:4', '23:1', '23:2', '23:3', '23:4', '23:5', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 69: RT difference=0.6430666666666669, Species mismatch or RT out of bounds
# Row 70: Adjusted_RT_FAME=5.91005, Species=19:0|20:1|20:2|21:1|21:2|21:3|22:1|22:2|22:3|22:4|23:1|23:2|23:3|23:4|23:5|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['19:0', '20:1', '20:2', '21:1', '21:2', '21:3', '22:1', '22:2', '22:3', '22:4', '23:1', '23:2', '23:3', '23:4', '23:5', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 70: RT difference=0.5009333333333332, Species mismatch or RT out of bounds
# Row 71: Adjusted_RT_FAME=6.116766666666667, Species=19:0|20:1|20:2|21:1|21:2|21:3|22:1|22:2|22:3|22:4|23:1|23:2|23:3|23:4|23:5|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# ...
# No match for row 473: RT difference=6.049533333333334, Species mismatch or RT out of bounds
# Row 474: Adjusted_RT_FAME=0.87825, Species=6:0|7:1|7:2|8:1|8:2|8:3|9:1|9:2|9:3|9:4|10:1|10:2|10:3|10:4|10:5|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6
# Species list after split: ['6:0', '7:1', '7:2', '8:1', '8:2', '8:3', '9:1', '9:2', '9:3', '9:4', '10:1', '10:2', '10:3', '10:4', '10:5', '11:1', '11:2', '11:3', '11:4', '11:5', '11:6', '12:1', '12:2', '12:3', '12:4', '12:5', '12:6', '13:1', '13:2', '13:3', '13:4', '13:5', '13:6', '14:1', '14:2', '14:3', '14:4', '14:5', '14:6', '15:1', '15:2', '15:3', '15:4', '15:5', '15:6', '16:1', '16:2', '16:3', '16:4', '16:5', '16:6', '17:1', '17:2', '17:3', '17:4', '17:5', '17:6', '18:1', '18:2', '18:3', '18:4', '18:5', '18:6', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6']
# No match for row 474: RT difference=5.532733333333333, Species mismatch or RT out of bounds
# Row 475: Adjusted_RT_FAME=2.002333333333333, Species=6:0|7:1|7:2|8:1|8:2|8:3|9:1|9:2|9:3|9:4|10:1|10:2|10:3|10:4|10:5|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6
# Species list after split: ['6:0', '7:1', '7:2', '8:1', '8:2', '8:3', '9:1', '9:2', '9:3', '9:4', '10:1', '10:2', '10:3', '10:4', '10:5', '11:1', '11:2', '11:3', '11:4', '11:5', '11:6', '12:1', '12:2', '12:3', '12:4', '12:5', '12:6', '13:1', '13:2', '13:3', '13:4', '13:5', '13:6', '14:1', '14:2', '14:3', '14:4', '14:5', '14:6', '15:1', '15:2', '15:3', '15:4', '15:5', '15:6', '16:1', '16:2', '16:3', '16:4', '16:5', '16:6', '17:1', '17:2', '17:3', '17:4', '17:5', '17:6', '18:1', '18:2', '18:3', '18:4', '18:5', '18:6', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6']
# No match for row 475: RT difference=4.40865, Species mismatch or RT out of bounds
# Row 476: Adjusted_RT_FAME=2.803383333333333, Species=6:0|7:1|7:2|8:1|8:2|8:3|9:1|9:2|9:3|9:4|10:1|10:2|10:3|10:4|10:5|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6
# Species list after split: ['6:0', '7:1', '7:2', '8:1', '8:2', '8:3', '9:1', '9:2', '9:3', '9:4', '10:1', '10:2', '10:3', '10:4', '10:5', '11:1', '11:2', '11:3', '11:4', '11:5', '11:6', '12:1', '12:2', '12:3', '12:4', '12:5', '12:6', '13:1', '13:2', '13:3', '13:4', '13:5', '13:6', '14:1', '14:2', '14:3', '14:4', '14:5', '14:6', '15:1', '15:2', '15:3', '15:4', '15:5', '15:6', '16:1', '16:2', '16:3', '16:4', '16:5', '16:6', '17:1', '17:2', '17:3', '17:4', '17:5', '17:6', '18:1', '18:2', '18:3', '18:4', '18:5', '18:6', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6']
# No match for row 476: RT difference=3.6076, Species mismatch or RT out of bounds
# Row 477: Adjusted_RT_FAME=0.5812833333333332, Species=5:0|6:1|6:2|7:1|7:2|7:3|8:1|8:2|8:3|8:4|9:1|9:2|9:3|9:4|9:5|10:1|10:2|10:3|10:4|10:5|10:6|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6
# Species list after split: ['5:0', '6:1', '6:2', '7:1', '7:2', '7:3', '8:1', '8:2', '8:3', '8:4', '9:1', '9:2', '9:3', '9:4', '9:5', '10:1', '10:2', '10:3', '10:4', '10:5', '10:6', '11:1', '11:2', '11:3', '11:4', '11:5', '11:6', '12:1', '12:2', '12:3', '12:4', '12:5', '12:6', '13:1', '13:2', '13:3', '13:4', '13:5', '13:6', '14:1', '14:2', '14:3', '14:4', '14:5', '14:6', '15:1', '15:2', '15:3', '15:4', '15:5', '15:6', '16:1', '16:2', '16:3', '16:4', '16:5', '16:6', '17:1', '17:2', '17:3', '17:4', '17:5', '17:6', '18:1', '18:2', '18:3', '18:4', '18:5', '18:6', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6']
# No match for row 477: RT difference=5.8297, Species mismatch or RT out of bounds
# Row 478: Adjusted_RT_FAME=2.0412833333333333, Species=5:0|6:1|6:2|7:1|7:2|7:3|8:1|8:2|8:3|8:4|9:1|9:2|9:3|9:4|9:5|10:1|10:2|10:3|10:4|10:5|10:6|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6
# Species list after split: ['5:0', '6:1', '6:2', '7:1', '7:2', '7:3', '8:1', '8:2', '8:3', '8:4', '9:1', '9:2', '9:3', '9:4', '9:5', '10:1', '10:2', '10:3', '10:4', '10:5', '10:6', '11:1', '11:2', '11:3', '11:4', '11:5', '11:6', '12:1', '12:2', '12:3', '12:4', '12:5', '12:6', '13:1', '13:2', '13:3', '13:4', '13:5', '13:6', '14:1', '14:2', '14:3', '14:4', '14:5', '14:6', '15:1', '15:2', '15:3', '15:4', '15:5', '15:6', '16:1', '16:2', '16:3', '16:4', '16:5', '16:6', '17:1', '17:2', '17:3', '17:4', '17:5', '17:6', '18:1', '18:2', '18:3', '18:4', '18:5', '18:6', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6']
# No match for row 478: RT difference=4.3697, Species mismatch or RT out of bounds
# Row 479: Adjusted_RT_FAME=2.3901333333333334, Species=5:0|6:1|6:2|7:1|7:2|7:3|8:1|8:2|8:3|8:4|9:1|9:2|9:3|9:4|9:5|10:1|10:2|10:3|10:4|10:5|10:6|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6
# Species list after split: ['5:0', '6:1', '6:2', '7:1', '7:2', '7:3', '8:1', '8:2', '8:3', '8:4', '9:1', '9:2', '9:3', '9:4', '9:5', '10:1', '10:2', '10:3', '10:4', '10:5', '10:6', '11:1', '11:2', '11:3', '11:4', '11:5', '11:6', '12:1', '12:2', '12:3', '12:4', '12:5', '12:6', '13:1', '13:2', '13:3', '13:4', '13:5', '13:6', '14:1', '14:2', '14:3', '14:4', '14:5', '14:6', '15:1', '15:2', '15:3', '15:4', '15:5', '15:6', '16:1', '16:2', '16:3', '16:4', '16:5', '16:6', '17:1', '17:2', '17:3', '17:4', '17:5', '17:6', '18:1', '18:2', '18:3', '18:4', '18:5', '18:6', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6']
# No match for row 479: RT difference=4.020849999999999, Species mismatch or RT out of bounds
# Row 480: Adjusted_RT_FAME=0.40059999999999985, Species=6:1|6:2|6:3|7:1|7:2|7:3|7:4|8:1|8:2|8:3|8:4|8:5|9:1|9:2|9:3|9:4|9:5|9:6|10:1|10:2|10:3|10:4|10:5|10:6|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6
# Species list after split: ['6:1', '6:2', '6:3', '7:1', '7:2', '7:3', '7:4', '8:1', '8:2', '8:3', '8:4', '8:5', '9:1', '9:2', '9:3', '9:4', '9:5', '9:6', '10:1', '10:2', '10:3', '10:4', '10:5', '10:6', '11:1', '11:2', '11:3', '11:4', '11:5', '11:6', '12:1', '12:2', '12:3', '12:4', '12:5', '12:6', '13:1', '13:2', '13:3', '13:4', '13:5', '13:6', '14:1', '14:2', '14:3', '14:4', '14:5', '14:6', '15:1', '15:2', '15:3', '15:4', '15:5', '15:6', '16:1', '16:2', '16:3', '16:4', '16:5', '16:6', '17:1', '17:2', '17:3', '17:4', '17:5', '17:6', '18:1', '18:2', '18:3', '18:4', '18:5', '18:6', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6']
# No match for row 480: RT difference=6.010383333333333, Species mismatch or RT out of bounds
# Row 481: Adjusted_RT_FAME=1.4083833333333333, Species=6:1|6:2|6:3|7:1|7:2|7:3|7:4|8:1|8:2|8:3|8:4|8:5|9:1|9:2|9:3|9:4|9:5|9:6|10:1|10:2|10:3|10:4|10:5|10:6|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6
# Species list after split: ['6:1', '6:2', '6:3', '7:1', '7:2', '7:3', '7:4', '8:1', '8:2', '8:3', '8:4', '8:5', '9:1', '9:2', '9:3', '9:4', '9:5', '9:6', '10:1', '10:2', '10:3', '10:4', '10:5', '10:6', '11:1', '11:2', '11:3', '11:4', '11:5', '11:6', '12:1', '12:2', '12:3', '12:4', '12:5', '12:6', '13:1', '13:2', '13:3', '13:4', '13:5', '13:6', '14:1', '14:2', '14:3', '14:4', '14:5', '14:6', '15:1', '15:2', '15:3', '15:4', '15:5', '15:6', '16:1', '16:2', '16:3', '16:4', '16:5', '16:6', '17:1', '17:2', '17:3', '17:4', '17:5', '17:6', '18:1', '18:2', '18:3', '18:4', '18:5', '18:6', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6']
# No match for row 481: RT difference=5.0026, Species mismatch or RT out of bounds
# Row 482: Adjusted_RT_FAME=0.8659333333333332, Species=6:1|6:2|6:3|6:4|7:1|7:2|7:3|7:4|7:5|8:1|8:2|8:3|8:4|8:5|8:6|9:1|9:2|9:3|9:4|9:5|9:6|10:1|10:2|10:3|10:4|10:5|10:6|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6
# Species list after split: ['6:1', '6:2', '6:3', '6:4', '7:1', '7:2', '7:3', '7:4', '7:5', '8:1', '8:2', '8:3', '8:4', '8:5', '8:6', '9:1', '9:2', '9:3', '9:4', '9:5', '9:6', '10:1', '10:2', '10:3', '10:4', '10:5', '10:6', '11:1', '11:2', '11:3', '11:4', '11:5', '11:6', '12:1', '12:2', '12:3', '12:4', '12:5', '12:6', '13:1', '13:2', '13:3', '13:4', '13:5', '13:6', '14:1', '14:2', '14:3', '14:4', '14:5', '14:6', '15:1', '15:2', '15:3', '15:4', '15:5', '15:6', '16:1', '16:2', '16:3', '16:4', '16:5', '16:6', '17:1', '17:2', '17:3', '17:4', '17:5', '17:6', '18:1', '18:2', '18:3', '18:4', '18:5', '18:6', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6']
# No match for row 482: RT difference=5.54505, Species mismatch or RT out of bounds
# Filtered rows in hippo_WT_m1_FAD245: 472 removed
# Log for removed lipids saved at: Projects/AMP/fame_filter_7/notpossible_nov6/log/hippo_WT_m1_FAD245_fame_filter_log_debug.txt
# filter_OzOFF_by_fame_std function completed.

# %%
step7 = pd.read_parquet('Projects/AMP/fame_filter_7/notpossible_nov6/hippo_WT_m1_FAD245_filtered.parquet')
step7
# Out:
#                Lipid  Retention_Time  OzESI_Intensity  group_by_ion  \
# 0   FA(16:1)_<>_n-2         6.724850           4029.0            26
# 1   FA(16:1)_<>_n-2         6.918667        1668488.0            26
# 2   FA(16:1)_<>_n-2         7.009100        1227931.0            26
# 3   FA(16:1)_<>_n-2         7.177067        2301793.0            26
# 4   FA(16:1)_<>_n-3         7.100367          10104.0            22
# 5   FA(16:1)_<>_n-3         7.307083           5942.0            22
# 6   FA(16:1)_<>_n-3         7.397533           5607.0            22
# 7   FA(16:1)_<>_n-3         7.643017           4473.0            22
# 8   FA(16:1)_<>_n-7         6.960483           3850.0            11
# 9   FA(16:1)_<>_n-7         7.257650           2460.0            11
# 10  FA(16:1)_<>_n-8         7.115933           1225.0             9
#
#     group_by_lipid                                          Sample_ID  \
# 0               13  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 1               13  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 2               13  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 3               13  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 4               10  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 5               10  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 6               10  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 7               10  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 8                1  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 9                1  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 10              50  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
#
#         Transition              Sample  Parent_Ion  Product_Ion  ...   STD  \
# 0   409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...  None
# 1   409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...  None
# 2   409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...  None
# 3   409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...  None
# 4   395.3 -> 183.0  hippo_WT_m1_FAD245       395.3        183.0  ...  None
# 5   395.3 -> 183.0  hippo_WT_m1_FAD245       395.3        183.0  ...  None
# 6   395.3 -> 183.0  hippo_WT_m1_FAD245       395.3        183.0  ...  None
# 7   395.3 -> 183.0  hippo_WT_m1_FAD245       395.3        183.0  ...  None
# 8   339.3 -> 183.0  hippo_WT_m1_FAD245       339.3        183.0  ...  None
# 9   339.3 -> 183.0  hippo_WT_m1_FAD245       339.3        183.0  ...  None
# 10  325.2 -> 183.0  hippo_WT_m1_FAD245       325.2        183.0  ...  None
#
#    STD_RT_OFF Peak_Height      FWHM  Peak_Width      Peak_Area  \
# 0    7.899783      4029.0  0.046318    0.051667     208.165000
# 1    7.899783   1668488.0  0.146934    0.142117  237119.952933
# 2    7.899783   1227931.0  0.035132    0.025833   31721.550833
# 3    7.899783   2301793.0  0.095411    0.103367  237928.669767
# 4    7.899783     10104.0  0.047203    0.038767     391.698400
# 5    7.899783      5942.0  0.055603    0.051683     307.102367
# 6    7.899783      5607.0  0.028146    0.025833     144.847500
# 7    7.899783      4473.0  0.112408    0.103350     462.284550
# 8    7.899783      3850.0  0.081412    0.077533     298.503333
# 9    7.899783      2460.0  0.072872    0.077533     190.732000
# 10   7.899783      1225.0  0.071837    0.077533      94.978333
#
#      Filter_Column  STD_RT_Dif_FAME Adjusted_RT_FAME  \
# 0   group_by_lipid        -0.269483         6.455367
# 1   group_by_lipid        -0.269483         6.649183
# 2   group_by_lipid        -0.269483         6.739617
# 3   group_by_lipid        -0.269483         6.907583
# 4   group_by_lipid        -0.269483         6.830883
# 5   group_by_lipid        -0.269483         7.037600
# 6   group_by_lipid        -0.269483         7.128050
# 7   group_by_lipid        -0.269483         7.373533
# 8   group_by_lipid        -0.269483         6.691000
# 9   group_by_lipid        -0.269483         6.988167
# 10  group_by_lipid        -0.269483         6.846450
#
#                                        Lipid_Possible
# 0   FA(15:0) | FA(16:1)_<>_n-2 | FA(16:2)_<F>_n-2 ...
# 1   FA(15:0) | FA(16:1)_<>_n-2 | FA(16:2)_<F>_n-2 ...
# 2   FA(15:0) | FA(16:1)_<>_n-2 | FA(16:2)_<F>_n-2 ...
# 3   FA(15:0) | FA(16:1)_<>_n-2 | FA(16:2)_<F>_n-2 ...
# 4   FA(14:0) | FA(15:1)_<>_n-2 | FA(15:2)_<F>_n-2 ...
# 5   FA(14:0) | FA(15:1)_<>_n-2 | FA(15:2)_<F>_n-2 ...
# 6   FA(14:0) | FA(15:1)_<>_n-2 | FA(15:2)_<F>_n-2 ...
# 7   FA(14:0) | FA(15:1)_<>_n-2 | FA(15:2)_<F>_n-2 ...
# 8   FA(10:0) | FA(11:1)_<>_n-2 | FA(11:2)_<F>_n-2 ...
# 9   FA(10:0) | FA(11:1)_<>_n-2 | FA(11:2)_<F>_n-2 ...
# 10  FA(9:0) | FA(10:1)_<>_n-2 | FA(10:2)_<F>_n-2 |...
#
# [11 rows x 22 columns]

# %% [markdown]
# # 161 and 181

# %%
import pandas as pd
import os
import re

def filter_OzOFF_by_fame_std(input_dir, fame_std, output_dir, fame_rt_window=0.5):
    """
    Filters parquet files in the input directory based on fame_std retention times and species,
    using Adjusted_RT_FAME from the input files to compare against fame_std Retention_Time.
    Updates Species to only contain the matched species and saves the filtered result as parquet files
    in the output directory. Logs and removed lipids CSVs are saved in a log directory inside the output directory.
    """
    
    def filter_fa_16_1_18_1(df):
        """
        Filters DataFrame rows where the Lipid column contains 'FA(16:1)' or 'FA(18:1)'.
        Keeps only the 'FA(16:1)' or 'FA(18:1)' entries along with any trailing details, removing other lipid types.
        """
        # Pattern to match 'FA(16:1)' or 'FA(18:1)' along with any extra parts that follow it
        pattern = r'\bFA\((?:16:1|18:1)\)(?:_[^|]*)?'

        # Filter rows where 'FA(16:1)' or 'FA(18:1)' is present in the Lipid column
        filtered_df = df[df['Lipid'].str.contains(pattern, regex=True)]
        print(f"Number of rows matching FA(16:1) or FA(18:1): {len(filtered_df)}")

        # Update the Lipid column to keep only 'FA(16:1)' or 'FA(18:1)' entries with any trailing details
        filtered_df['Lipid'] = filtered_df['Lipid'].apply(lambda x: '|'.join(re.findall(pattern, x)))
        print("Updated Lipid column to retain only 'FA(16:1)' or 'FA(18:1)' values with details.")

        return filtered_df

    print("Starting filter_OzOFF_by_fame_std function")
    print(f"Input directory: {input_dir}")
    print(f"Output directory: {output_dir}")
    print(f"Retention time window: {fame_rt_window}")
    print(f"Fame standard DataFrame columns: {fame_std.columns.tolist()}")

    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Create a log subdirectory inside the output directory
    log_dir = os.path.join(output_dir, 'log')
    os.makedirs(log_dir, exist_ok=True)

    # Check if input directory has parquet files
    input_files = [f for f in os.listdir(input_dir) if f.endswith(".parquet")]
    print(f"Number of parquet files found in input directory: {len(input_files)}")
    if not input_files:
        print("No parquet files found in input directory. Exiting function.")
        return

    # Iterate over all parquet files in the input directory
    for parquet_file in input_files:
        print(f"Processing file: {parquet_file}")

        # Read the parquet file
        file_path = os.path.join(input_dir, parquet_file)
        filtered_ozON = pd.read_parquet(file_path)

        # Add Lipid_Possible column as a copy of Lipid
        filtered_ozON['Lipid_Possible'] = filtered_ozON['Lipid']
        print("Lipid_Possible column created")

        # Apply the FA(16:1) and FA(18:1) filter using the inner function
        filtered_ozON = filter_fa_16_1_18_1(filtered_ozON)

        # Check the initial data after applying the FA(16:1) and FA(18:1) filter
        print(f"Rows after FA(16:1) and FA(18:1) filter: {len(filtered_ozON)}")
        print(f"filtered_ozON columns: {filtered_ozON.columns.tolist()}")

        # Create a new DataFrame to store the filtered ozON data
        filtered_ozON_result = filtered_ozON.copy()

        # Prepare lists for logging
        drop_indices = []
        removed_lipids = []

        # Get sample name from Sample column
        sample_name = filtered_ozON_result['Sample'].unique()[0]
        log_filename = f"{sample_name}_fame_filter_log_debug.txt"
        log_file_path = os.path.join(log_dir, log_filename)

        # CSV filename for removed lipids
        csv_filename = f"{sample_name}_fame_filter_removed_lipids_debug.csv"
        csv_file_path = os.path.join(log_dir, csv_filename)

        # Iterate through each entry in fame_std to filter ozON entries
        for _, fame_entry in fame_std.iterrows():
            fame_std_rt = fame_entry['Retention_Time']
            fame_std_species = fame_entry['Species']
            print(f"Processing fame_std entry: Retention_Time={fame_std_rt}, Species={fame_std_species}")

            # Define bounds for Adjusted_RT_FAME comparison
            rt_lower_bound = fame_std_rt - fame_rt_window
            rt_upper_bound = fame_std_rt + fame_rt_window
            print(f"Adjusted RT bounds: {rt_lower_bound} to {rt_upper_bound}")

            # Filter entries within the defined Adjusted_RT_FAME window and matching Species
            for index, row in filtered_ozON_result.iterrows():
                adjusted_rt = row['Adjusted_RT_FAME']
                species_list = row['Species'].split('|')  # Split species by '|'

                print(f"Row {index}: Adjusted_RT_FAME={adjusted_rt}, Species={row['Species']}")
                print(f"Species list after split: {species_list}")

                # Check if fame_std_species is in the species_list and adjusted_rt is within bounds
                if fame_std_species in species_list and rt_lower_bound <= adjusted_rt <= rt_upper_bound:
                    print(f"Match found for row {index}: Adjusted_RT_FAME within bounds and Species match")
                    # Update Species column to contain only the matched fame_std_species
                    filtered_ozON_result.at[index, 'Species'] = fame_std_species
                    print(f"Updated Species for row {index} to: {fame_std_species}")
                else:
                    # If it doesn't match, log the row for removal
                    rt_diff = min(abs(adjusted_rt - rt_lower_bound), abs(adjusted_rt - rt_upper_bound))
                    print(f"No match for row {index}: RT difference={rt_diff}, Species mismatch or RT out of bounds")
                    drop_indices.append(index)
                    removed_lipids.append({
                        'Lipid': row['Lipid'],
                        'Adjusted_RT_FAME': adjusted_rt,
                        'Ground_Truth_RT': fame_std_rt,
                        'Species': row['Species'],
                        'Ground_Truth_Species': fame_std_species,
                        'RT_Difference': rt_diff
                    })

        # Drop all collected indices
        filtered_ozON_result = filtered_ozON_result.drop(drop_indices).reset_index(drop=True)
        print(f"Filtered rows in {sample_name}: {len(drop_indices)} removed")

        # Save filtered DataFrame and removed lipids log to CSV
        filtered_ozON_result.to_parquet(os.path.join(output_dir, f"{sample_name}_filtered.parquet"))
        pd.DataFrame(removed_lipids).to_csv(csv_file_path, index=False)

        # Write log entries to a text file
        with open(log_file_path, 'w') as log_file:
            for entry in removed_lipids:
                log_file.write(str(entry) + '\n')
            print(f"Log for removed lipids saved at: {log_file_path}")

    print("filter_OzOFF_by_fame_std function completed.")

# %% [markdown]
# # nov7 update filtering step for FAME std

# %%
import pandas as pd
import os
import re

def filter_OzOFF_by_fame_std(input_dir, fame_std, output_dir, fame_rt_window=0.5):
    """
    Filters parquet files in the input directory based on fame_std retention times and species,
    using Adjusted_RT_FAME from the input files to compare against fame_std Retention_Time.
    Updates Species to only contain the matched species and saves the filtered result as parquet files
    in the output directory. Logs and removed lipids CSVs are saved in a log directory inside the output directory.
    """
    
    def filter_fa_species(df, species_pattern):
        """
        Filters DataFrame rows based on the provided fatty acid species pattern (e.g., 'FA(16:1)').
        Keeps only entries that match the pattern in the Lipid column.
        """
        # Pattern to match species with any trailing details
        pattern = rf'\b{species_pattern}(?:_[^|]*)?'

        # Filter rows where the specified species pattern is present in the Lipid column
        filtered_df = df[df['Lipid'].str.contains(pattern, regex=True)]
        print(f"Number of rows matching {species_pattern}: {len(filtered_df)}")

        # Update the Lipid column to keep only the matched species pattern entries
        filtered_df['Lipid'] = filtered_df['Lipid'].apply(lambda x: '|'.join(re.findall(pattern, x)))
        print(f"Updated Lipid column to retain only '{species_pattern}' values with details.")

        return filtered_df

    print("Starting filter_OzOFF_by_fame_std function")
    print(f"Input directory: {input_dir}")
    print(f"Output directory: {output_dir}")
    print(f"Retention time window: {fame_rt_window}")
    print(f"Fame standard DataFrame columns: {fame_std.columns.tolist()}")

    # Ensure the output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Create a log subdirectory inside the output directory
    log_dir = os.path.join(output_dir, 'log')
    os.makedirs(log_dir, exist_ok=True)

    # Check if input directory has parquet files
    input_files = [f for f in os.listdir(input_dir) if f.endswith(".parquet")]
    print(f"Number of parquet files found in input directory: {len(input_files)}")
    if not input_files:
        print("No parquet files found in input directory. Exiting function.")
        return

    # Iterate over all parquet files in the input directory
    for parquet_file in input_files:
        print(f"Processing file: {parquet_file}")

        # Read the parquet file
        file_path = os.path.join(input_dir, parquet_file)
        filtered_ozON = pd.read_parquet(file_path)

        # Add Lipid_Possible column as a copy of Lipid
        filtered_ozON['Lipid_Possible'] = filtered_ozON['Lipid']
        print("Lipid_Possible column created")

        # Filter based on all FA species patterns from fame_std
        all_filtered_dataframes = []
        for _, fame_entry in fame_std.iterrows():
            species_pattern = fame_entry['Species']
            # Apply species-specific filter
            filtered_species_df = filter_fa_species(filtered_ozON, species_pattern)
            all_filtered_dataframes.append(filtered_species_df)

        # Concatenate all filtered DataFrames
        filtered_ozON = pd.concat(all_filtered_dataframes).drop_duplicates().reset_index(drop=True)
        print(f"Total rows after applying all species filters: {len(filtered_ozON)}")
        
        # Prepare lists for logging
        drop_indices = []
        removed_lipids = []

        # Get sample name from Sample column
        sample_name = filtered_ozON['Sample'].unique()[0]
        log_filename = f"{sample_name}_fame_filter_log_debug.txt"
        log_file_path = os.path.join(log_dir, log_filename)

        # CSV filename for removed lipids
        csv_filename = f"{sample_name}_fame_filter_removed_lipids_debug.csv"
        csv_file_path = os.path.join(log_dir, csv_filename)

        # Iterate through each entry in fame_std to filter ozON entries
        for _, fame_entry in fame_std.iterrows():
            fame_std_rt = fame_entry['Retention_Time']
            fame_std_species = fame_entry['Species']
            print(f"Processing fame_std entry: Retention_Time={fame_std_rt}, Species={fame_std_species}")

            # Define bounds for Adjusted_RT_FAME comparison
            rt_lower_bound = fame_std_rt - fame_rt_window
            rt_upper_bound = fame_std_rt + fame_rt_window
            print(f"Adjusted RT bounds: {rt_lower_bound} to {rt_upper_bound}")

            # Filter entries within the defined Adjusted_RT_FAME window and matching Species
            for index, row in filtered_ozON.iterrows():
                adjusted_rt = row['Adjusted_RT_FAME']
                species_list = row['Species'].split('|')  # Split species by '|'

                print(f"Row {index}: Adjusted_RT_FAME={adjusted_rt}, Species={row['Species']}")
                print(f"Species list after split: {species_list}")

                # Check if fame_std_species is in the species_list and adjusted_rt is within bounds
                if fame_std_species in species_list and rt_lower_bound <= adjusted_rt <= rt_upper_bound:
                    print(f"Match found for row {index}: Adjusted_RT_FAME within bounds and Species match")
                    # Update Species column to contain only the matched fame_std_species
                    filtered_ozON.at[index, 'Species'] = fame_std_species
                    print(f"Updated Species for row {index} to: {fame_std_species}")
                else:
                    # If it doesn't match, log the row for removal
                    rt_diff = min(abs(adjusted_rt - rt_lower_bound), abs(adjusted_rt - rt_upper_bound))
                    print(f"No match for row {index}: RT difference={rt_diff}, Species mismatch or RT out of bounds")
                    drop_indices.append(index)
                    removed_lipids.append({
                        'Lipid': row['Lipid'],
                        'Adjusted_RT_FAME': adjusted_rt,
                        'Ground_Truth_RT': fame_std_rt,
                        'Species': row['Species'],
                        'Ground_Truth_Species': fame_std_species,
                        'RT_Difference': rt_diff
                    })

        # Drop all collected indices
        filtered_ozON = filtered_ozON.drop(drop_indices).reset_index(drop=True)
        print(f"Filtered rows in {sample_name}: {len(drop_indices)} removed")

        # Save filtered DataFrame and removed lipids log to CSV
        filtered_ozON.to_parquet(os.path.join(output_dir, f"{sample_name}_filtered.parquet"))
        pd.DataFrame(removed_lipids).to_csv(csv_file_path, index=False)

        # Write log entries to a text file
        with open(log_file_path, 'w') as log_file:
            for entry in removed_lipids:
                log_file.write(str(entry) + '\n')
            print(f"Log for removed lipids saved at: {log_file_path}")

    print("filter_OzOFF_by_fame_std function completed.")

# %%
# !sbatch core/backend/not_possible/FAME_filter_6_notpossible.sh
# Out:
# Submitted batch job 20451327

# %%
import pandas as pd
# from core.python.not_possible.FAME_filter_6_notpossible import filter_OzOFF_by_fame_std

# Define input and output directories
#input_dir = 'Projects/AMP/analysis/OFF/notpossible/'
input_dir = 'Projects/AMP/notpossible/rt_adjustment_6/'
output_dir = 'Projects/AMP/fame_filter_7/notpossible_nov6/'
fame_std = pd.read_parquet('Projects/STD/off_possible/FAME_off_possible_top2.parquet')


# Call the function with custom fame_rt_window and parent_ion_tolerance
filter_OzOFF_by_fame_std(input_dir, fame_std, output_dir, fame_rt_window=0.5)
# Out:
# Starting filter_OzOFF_by_fame_std function
# Input directory: Projects/AMP/notpossible/rt_adjustment_6/
# Output directory: Projects/AMP/fame_filter_7/notpossible_nov6/
# Retention time window: 0.5
# Fame standard DataFrame columns: ['Lipid', 'Retention_Time', 'OzESI_Intensity', 'group_by_ion', 'group_by_lipid', 'Sample_ID', 'Transition', 'Sample', 'Parent_Ion', 'Product_Ion', 'Species', 'Class', 'STD', 'STD_RT_OFF', 'Peak_Height', 'FWHM', 'Peak_Width', 'Peak_Area', 'Filter_Column', 'Isomer']
# Number of parquet files found in input directory: 1
# Processing file: df_rt_adjustment_6_hippo_WT_m1_FAD245_OFF.parquet
# Lipid_Possible column created
# Number of rows matching FA(16:1): 115
# Updated Lipid column to retain only 'FA(16:1)' values with details.
# Rows after FA(16:1) filter: 115
# filtered_ozON columns: ['Lipid', 'Retention_Time', 'OzESI_Intensity', 'group_by_ion', 'group_by_lipid', 'Sample_ID', 'Transition', 'Sample', 'Parent_Ion', 'Product_Ion', 'Species', 'Class', 'STD', 'STD_RT_OFF', 'Peak_Height', 'FWHM', 'Peak_Width', 'Peak_Area', 'Filter_Column', 'STD_RT_Dif_FAME', 'Adjusted_RT_FAME', 'Lipid_Possible']
# Processing fame_std entry: Retention_Time=5.3144, Species=14:1
# Adjusted RT bounds: 4.8144 to 5.8144
# Row 322: Adjusted_RT_FAME=3.1606833333333335, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 322: RT difference=1.6537166666666665, Species mismatch or RT out of bounds
# Row 323: Adjusted_RT_FAME=3.5612166666666667, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 323: RT difference=1.2531833333333333, Species mismatch or RT out of bounds
# Row 324: Adjusted_RT_FAME=3.6645833333333333, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 324: RT difference=1.1498166666666667, Species mismatch or RT out of bounds
# Row 325: Adjusted_RT_FAME=3.76795, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 325: RT difference=1.04645, Species mismatch or RT out of bounds
# Row 326: Adjusted_RT_FAME=3.89715, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 326: RT difference=0.9172500000000001, Species mismatch or RT out of bounds
# Row 327: Adjusted_RT_FAME=3.9875833333333333, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 327: RT difference=0.8268166666666668, Species mismatch or RT out of bounds
# Row 328: Adjusted_RT_FAME=4.168466666666666, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 328: RT difference=0.6459333333333337, Species mismatch or RT out of bounds
# Row 329: Adjusted_RT_FAME=4.5044, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 329: RT difference=0.3099999999999996, Species mismatch or RT out of bounds
# Row 330: Adjusted_RT_FAME=5.628466666666667, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 330: RT difference=0.18593333333333284, Species mismatch or RT out of bounds
# Row 331: Adjusted_RT_FAME=5.8998, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 331: RT difference=0.08539999999999992, Species mismatch or RT out of bounds
# Row 332: Adjusted_RT_FAME=6.0936, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 332: RT difference=0.27920000000000034, Species mismatch or RT out of bounds
# Row 333: Adjusted_RT_FAME=6.364933333333333, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 333: RT difference=0.5505333333333331, Species mismatch or RT out of bounds
# Row 334: Adjusted_RT_FAME=6.4553666666666665, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 334: RT difference=0.6409666666666665, Species mismatch or RT out of bounds
# Row 335: Adjusted_RT_FAME=6.649183333333333, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 335: RT difference=0.8347833333333332, Species mismatch or RT out of bounds
# Row 336: Adjusted_RT_FAME=6.739616666666667, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 336: RT difference=0.9252166666666666, Species mismatch or RT out of bounds
# Row 337: Adjusted_RT_FAME=6.907583333333333, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 337: RT difference=1.0931833333333332, Species mismatch or RT out of bounds
# Row 338: Adjusted_RT_FAME=7.721566666666667, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 338: RT difference=1.907166666666667, Species mismatch or RT out of bounds
# Row 339: Adjusted_RT_FAME=7.8637, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 339: RT difference=2.0492999999999997, Species mismatch or RT out of bounds
# Row 340: Adjusted_RT_FAME=7.9412166666666675, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 340: RT difference=2.1268166666666675, Species mismatch or RT out of bounds
# Row 341: Adjusted_RT_FAME=8.1221, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 341: RT difference=2.3076999999999996, Species mismatch or RT out of bounds
# Row 342: Adjusted_RT_FAME=8.199616666666667, Species=15:0|16:1|16:2|17:1|17:2|17:3|18:1|18:2|18:3|18:4|19:1|19:2|19:3|19:4|19:5|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['15:0', '16:1', '16:2', '17:1', '17:2', '17:3', '18:1', '18:2', '18:3', '18:4', '19:1', '19:2', '19:3', '19:4', '19:5', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 342: RT difference=2.3852166666666674, Species mismatch or RT out of bounds
# Row 353: Adjusted_RT_FAME=3.3553, Species=14:0|15:1|15:2|16:1|16:2|16:3|17:1|17:2|17:3|17:4|18:1|18:2|18:3|18:4|18:5|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['14:0', '15:1', '15:2', '16:1', '16:2', '16:3', '17:1', '17:2', '17:3', '17:4', '18:1', '18:2', '18:3', '18:4', '18:5', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 353: RT difference=1.4590999999999998, Species mismatch or RT out of bounds
# Row 354: Adjusted_RT_FAME=3.4715833333333332, Species=14:0|15:1|15:2|16:1|16:2|16:3|17:1|17:2|17:3|17:4|18:1|18:2|18:3|18:4|18:5|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['14:0', '15:1', '15:2', '16:1', '16:2', '16:3', '17:1', '17:2', '17:3', '17:4', '18:1', '18:2', '18:3', '18:4', '18:5', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 354: RT difference=1.3428166666666668, Species mismatch or RT out of bounds
# Row 355: Adjusted_RT_FAME=3.5878666666666668, Species=14:0|15:1|15:2|16:1|16:2|16:3|17:1|17:2|17:3|17:4|18:1|18:2|18:3|18:4|18:5|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['14:0', '15:1', '15:2', '16:1', '16:2', '16:3', '17:1', '17:2', '17:3', '17:4', '18:1', '18:2', '18:3', '18:4', '18:5', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 355: RT difference=1.2265333333333333, Species mismatch or RT out of bounds
# Row 356: Adjusted_RT_FAME=3.742916666666667, Species=14:0|15:1|15:2|16:1|16:2|16:3|17:1|17:2|17:3|17:4|18:1|18:2|18:3|18:4|18:5|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['14:0', '15:1', '15:2', '16:1', '16:2', '16:3', '17:1', '17:2', '17:3', '17:4', '18:1', '18:2', '18:3', '18:4', '18:5', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 356: RT difference=1.0714833333333331, Species mismatch or RT out of bounds
# Row 357: Adjusted_RT_FAME=3.846283333333333, Species=14:0|15:1|15:2|16:1|16:2|16:3|17:1|17:2|17:3|17:4|18:1|18:2|18:3|18:4|18:5|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['14:0', '15:1', '15:2', '16:1', '16:2', '16:3', '17:1', '17:2', '17:3', '17:4', '18:1', '18:2', '18:3', '18:4', '18:5', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 357: RT difference=0.968116666666667, Species mismatch or RT out of bounds
# Row 358: Adjusted_RT_FAME=4.892833333333334, Species=14:0|15:1|15:2|16:1|16:2|16:3|17:1|17:2|17:3|17:4|18:1|18:2|18:3|18:4|18:5|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['14:0', '15:1', '15:2', '16:1', '16:2', '16:3', '17:1', '17:2', '17:3', '17:4', '18:1', '18:2', '18:3', '18:4', '18:5', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 358: RT difference=0.0784333333333338, Species mismatch or RT out of bounds
# Row 359: Adjusted_RT_FAME=5.022033333333334, Species=14:0|15:1|15:2|16:1|16:2|16:3|17:1|17:2|17:3|17:4|18:1|18:2|18:3|18:4|18:5|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['14:0', '15:1', '15:2', '16:1', '16:2', '16:3', '17:1', '17:2', '17:3', '17:4', '18:1', '18:2', '18:3', '18:4', '18:5', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 359: RT difference=0.20763333333333378, Species mismatch or RT out of bounds
# Row 360: Adjusted_RT_FAME=5.21585, Species=14:0|15:1|15:2|16:1|16:2|16:3|17:1|17:2|17:3|17:4|18:1|18:2|18:3|18:4|18:5|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['14:0', '15:1', '15:2', '16:1', '16:2', '16:3', '17:1', '17:2', '17:3', '17:4', '18:1', '18:2', '18:3', '18:4', '18:5', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 360: RT difference=0.40144999999999964, Species mismatch or RT out of bounds
# Row 361: Adjusted_RT_FAME=5.5647, Species=14:0|15:1|15:2|16:1|16:2|16:3|17:1|17:2|17:3|17:4|18:1|18:2|18:3|18:4|18:5|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['14:0', '15:1', '15:2', '16:1', '16:2', '16:3', '17:1', '17:2', '17:3', '17:4', '18:1', '18:2', '18:3', '18:4', '18:5', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 361: RT difference=0.2496999999999998, Species mismatch or RT out of bounds
# Row 362: Adjusted_RT_FAME=5.642216666666667, Species=14:0|15:1|15:2|16:1|16:2|16:3|17:1|17:2|17:3|17:4|18:1|18:2|18:3|18:4|18:5|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['14:0', '15:1', '15:2', '16:1', '16:2', '16:3', '17:1', '17:2', '17:3', '17:4', '18:1', '18:2', '18:3', '18:4', '18:5', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 362: RT difference=0.1721833333333329, Species mismatch or RT out of bounds
# Row 363: Adjusted_RT_FAME=5.965216666666667, Species=14:0|15:1|15:2|16:1|16:2|16:3|17:1|17:2|17:3|17:4|18:1|18:2|18:3|18:4|18:5|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['14:0', '15:1', '15:2', '16:1', '16:2', '16:3', '17:1', '17:2', '17:3', '17:4', '18:1', '18:2', '18:3', '18:4', '18:5', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 363: RT difference=0.1508166666666666, Species mismatch or RT out of bounds
# Row 364: Adjusted_RT_FAME=6.830883333333333, Species=14:0|15:1|15:2|16:1|16:2|16:3|17:1|17:2|17:3|17:4|18:1|18:2|18:3|18:4|18:5|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['14:0', '15:1', '15:2', '16:1', '16:2', '16:3', '17:1', '17:2', '17:3', '17:4', '18:1', '18:2', '18:3', '18:4', '18:5', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 364: RT difference=1.0164833333333334, Species mismatch or RT out of bounds
# Row 365: Adjusted_RT_FAME=7.0376, Species=14:0|15:1|15:2|16:1|16:2|16:3|17:1|17:2|17:3|17:4|18:1|18:2|18:3|18:4|18:5|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['14:0', '15:1', '15:2', '16:1', '16:2', '16:3', '17:1', '17:2', '17:3', '17:4', '18:1', '18:2', '18:3', '18:4', '18:5', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 365: RT difference=1.2232000000000003, Species mismatch or RT out of bounds
# Row 366: Adjusted_RT_FAME=7.12805, Species=14:0|15:1|15:2|16:1|16:2|16:3|17:1|17:2|17:3|17:4|18:1|18:2|18:3|18:4|18:5|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['14:0', '15:1', '15:2', '16:1', '16:2', '16:3', '17:1', '17:2', '17:3', '17:4', '18:1', '18:2', '18:3', '18:4', '18:5', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 366: RT difference=1.31365, Species mismatch or RT out of bounds
# Row 367: Adjusted_RT_FAME=7.3735333333333335, Species=14:0|15:1|15:2|16:1|16:2|16:3|17:1|17:2|17:3|17:4|18:1|18:2|18:3|18:4|18:5|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['14:0', '15:1', '15:2', '16:1', '16:2', '16:3', '17:1', '17:2', '17:3', '17:4', '18:1', '18:2', '18:3', '18:4', '18:5', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 367: RT difference=1.5591333333333335, Species mismatch or RT out of bounds
# Row 368: Adjusted_RT_FAME=7.56735, Species=14:0|15:1|15:2|16:1|16:2|16:3|17:1|17:2|17:3|17:4|18:1|18:2|18:3|18:4|18:5|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6|28:1|28:2|28:3|28:4|28:5|28:6|29:1|29:2|29:3|29:4|29:5|29:6|30:1|30:2|30:3|30:4|30:5|30:6
# Species list after split: ['14:0', '15:1', '15:2', '16:1', '16:2', '16:3', '17:1', '17:2', '17:3', '17:4', '18:1', '18:2', '18:3', '18:4', '18:5', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6', '28:1', '28:2', '28:3', '28:4', '28:5', '28:6', '29:1', '29:2', '29:3', '29:4', '29:5', '29:6', '30:1', '30:2', '30:3', '30:4', '30:5', '30:6']
# No match for row 368: RT difference=1.7529500000000002, Species mismatch or RT out of bounds
# ...
# No match for row 473: RT difference=15.141933333333336, Species mismatch or RT out of bounds
# Row 474: Adjusted_RT_FAME=0.87825, Species=6:0|7:1|7:2|8:1|8:2|8:3|9:1|9:2|9:3|9:4|10:1|10:2|10:3|10:4|10:5|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6
# Species list after split: ['6:0', '7:1', '7:2', '8:1', '8:2', '8:3', '9:1', '9:2', '9:3', '9:4', '10:1', '10:2', '10:3', '10:4', '10:5', '11:1', '11:2', '11:3', '11:4', '11:5', '11:6', '12:1', '12:2', '12:3', '12:4', '12:5', '12:6', '13:1', '13:2', '13:3', '13:4', '13:5', '13:6', '14:1', '14:2', '14:3', '14:4', '14:5', '14:6', '15:1', '15:2', '15:3', '15:4', '15:5', '15:6', '16:1', '16:2', '16:3', '16:4', '16:5', '16:6', '17:1', '17:2', '17:3', '17:4', '17:5', '17:6', '18:1', '18:2', '18:3', '18:4', '18:5', '18:6', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6']
# No match for row 474: RT difference=14.625133333333336, Species mismatch or RT out of bounds
# Row 475: Adjusted_RT_FAME=2.002333333333333, Species=6:0|7:1|7:2|8:1|8:2|8:3|9:1|9:2|9:3|9:4|10:1|10:2|10:3|10:4|10:5|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6
# Species list after split: ['6:0', '7:1', '7:2', '8:1', '8:2', '8:3', '9:1', '9:2', '9:3', '9:4', '10:1', '10:2', '10:3', '10:4', '10:5', '11:1', '11:2', '11:3', '11:4', '11:5', '11:6', '12:1', '12:2', '12:3', '12:4', '12:5', '12:6', '13:1', '13:2', '13:3', '13:4', '13:5', '13:6', '14:1', '14:2', '14:3', '14:4', '14:5', '14:6', '15:1', '15:2', '15:3', '15:4', '15:5', '15:6', '16:1', '16:2', '16:3', '16:4', '16:5', '16:6', '17:1', '17:2', '17:3', '17:4', '17:5', '17:6', '18:1', '18:2', '18:3', '18:4', '18:5', '18:6', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6']
# No match for row 475: RT difference=13.501050000000003, Species mismatch or RT out of bounds
# Row 476: Adjusted_RT_FAME=2.803383333333333, Species=6:0|7:1|7:2|8:1|8:2|8:3|9:1|9:2|9:3|9:4|10:1|10:2|10:3|10:4|10:5|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6
# Species list after split: ['6:0', '7:1', '7:2', '8:1', '8:2', '8:3', '9:1', '9:2', '9:3', '9:4', '10:1', '10:2', '10:3', '10:4', '10:5', '11:1', '11:2', '11:3', '11:4', '11:5', '11:6', '12:1', '12:2', '12:3', '12:4', '12:5', '12:6', '13:1', '13:2', '13:3', '13:4', '13:5', '13:6', '14:1', '14:2', '14:3', '14:4', '14:5', '14:6', '15:1', '15:2', '15:3', '15:4', '15:5', '15:6', '16:1', '16:2', '16:3', '16:4', '16:5', '16:6', '17:1', '17:2', '17:3', '17:4', '17:5', '17:6', '18:1', '18:2', '18:3', '18:4', '18:5', '18:6', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6']
# No match for row 476: RT difference=12.700000000000003, Species mismatch or RT out of bounds
# Row 477: Adjusted_RT_FAME=0.5812833333333332, Species=5:0|6:1|6:2|7:1|7:2|7:3|8:1|8:2|8:3|8:4|9:1|9:2|9:3|9:4|9:5|10:1|10:2|10:3|10:4|10:5|10:6|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6
# Species list after split: ['5:0', '6:1', '6:2', '7:1', '7:2', '7:3', '8:1', '8:2', '8:3', '8:4', '9:1', '9:2', '9:3', '9:4', '9:5', '10:1', '10:2', '10:3', '10:4', '10:5', '10:6', '11:1', '11:2', '11:3', '11:4', '11:5', '11:6', '12:1', '12:2', '12:3', '12:4', '12:5', '12:6', '13:1', '13:2', '13:3', '13:4', '13:5', '13:6', '14:1', '14:2', '14:3', '14:4', '14:5', '14:6', '15:1', '15:2', '15:3', '15:4', '15:5', '15:6', '16:1', '16:2', '16:3', '16:4', '16:5', '16:6', '17:1', '17:2', '17:3', '17:4', '17:5', '17:6', '18:1', '18:2', '18:3', '18:4', '18:5', '18:6', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6']
# No match for row 477: RT difference=14.922100000000002, Species mismatch or RT out of bounds
# Row 478: Adjusted_RT_FAME=2.0412833333333333, Species=5:0|6:1|6:2|7:1|7:2|7:3|8:1|8:2|8:3|8:4|9:1|9:2|9:3|9:4|9:5|10:1|10:2|10:3|10:4|10:5|10:6|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6
# Species list after split: ['5:0', '6:1', '6:2', '7:1', '7:2', '7:3', '8:1', '8:2', '8:3', '8:4', '9:1', '9:2', '9:3', '9:4', '9:5', '10:1', '10:2', '10:3', '10:4', '10:5', '10:6', '11:1', '11:2', '11:3', '11:4', '11:5', '11:6', '12:1', '12:2', '12:3', '12:4', '12:5', '12:6', '13:1', '13:2', '13:3', '13:4', '13:5', '13:6', '14:1', '14:2', '14:3', '14:4', '14:5', '14:6', '15:1', '15:2', '15:3', '15:4', '15:5', '15:6', '16:1', '16:2', '16:3', '16:4', '16:5', '16:6', '17:1', '17:2', '17:3', '17:4', '17:5', '17:6', '18:1', '18:2', '18:3', '18:4', '18:5', '18:6', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6']
# No match for row 478: RT difference=13.462100000000003, Species mismatch or RT out of bounds
# Row 479: Adjusted_RT_FAME=2.3901333333333334, Species=5:0|6:1|6:2|7:1|7:2|7:3|8:1|8:2|8:3|8:4|9:1|9:2|9:3|9:4|9:5|10:1|10:2|10:3|10:4|10:5|10:6|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6
# Species list after split: ['5:0', '6:1', '6:2', '7:1', '7:2', '7:3', '8:1', '8:2', '8:3', '8:4', '9:1', '9:2', '9:3', '9:4', '9:5', '10:1', '10:2', '10:3', '10:4', '10:5', '10:6', '11:1', '11:2', '11:3', '11:4', '11:5', '11:6', '12:1', '12:2', '12:3', '12:4', '12:5', '12:6', '13:1', '13:2', '13:3', '13:4', '13:5', '13:6', '14:1', '14:2', '14:3', '14:4', '14:5', '14:6', '15:1', '15:2', '15:3', '15:4', '15:5', '15:6', '16:1', '16:2', '16:3', '16:4', '16:5', '16:6', '17:1', '17:2', '17:3', '17:4', '17:5', '17:6', '18:1', '18:2', '18:3', '18:4', '18:5', '18:6', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6']
# No match for row 479: RT difference=13.113250000000003, Species mismatch or RT out of bounds
# Row 480: Adjusted_RT_FAME=0.40059999999999985, Species=6:1|6:2|6:3|7:1|7:2|7:3|7:4|8:1|8:2|8:3|8:4|8:5|9:1|9:2|9:3|9:4|9:5|9:6|10:1|10:2|10:3|10:4|10:5|10:6|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6
# Species list after split: ['6:1', '6:2', '6:3', '7:1', '7:2', '7:3', '7:4', '8:1', '8:2', '8:3', '8:4', '8:5', '9:1', '9:2', '9:3', '9:4', '9:5', '9:6', '10:1', '10:2', '10:3', '10:4', '10:5', '10:6', '11:1', '11:2', '11:3', '11:4', '11:5', '11:6', '12:1', '12:2', '12:3', '12:4', '12:5', '12:6', '13:1', '13:2', '13:3', '13:4', '13:5', '13:6', '14:1', '14:2', '14:3', '14:4', '14:5', '14:6', '15:1', '15:2', '15:3', '15:4', '15:5', '15:6', '16:1', '16:2', '16:3', '16:4', '16:5', '16:6', '17:1', '17:2', '17:3', '17:4', '17:5', '17:6', '18:1', '18:2', '18:3', '18:4', '18:5', '18:6', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6']
# No match for row 480: RT difference=15.102783333333335, Species mismatch or RT out of bounds
# Row 481: Adjusted_RT_FAME=1.4083833333333333, Species=6:1|6:2|6:3|7:1|7:2|7:3|7:4|8:1|8:2|8:3|8:4|8:5|9:1|9:2|9:3|9:4|9:5|9:6|10:1|10:2|10:3|10:4|10:5|10:6|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6|21:1|21:2|21:3|21:4|21:5|21:6|22:1|22:2|22:3|22:4|22:5|22:6|23:1|23:2|23:3|23:4|23:5|23:6|24:1|24:2|24:3|24:4|24:5|24:6|25:1|25:2|25:3|25:4|25:5|25:6|26:1|26:2|26:3|26:4|26:5|26:6|27:1|27:2|27:3|27:4|27:5|27:6
# Species list after split: ['6:1', '6:2', '6:3', '7:1', '7:2', '7:3', '7:4', '8:1', '8:2', '8:3', '8:4', '8:5', '9:1', '9:2', '9:3', '9:4', '9:5', '9:6', '10:1', '10:2', '10:3', '10:4', '10:5', '10:6', '11:1', '11:2', '11:3', '11:4', '11:5', '11:6', '12:1', '12:2', '12:3', '12:4', '12:5', '12:6', '13:1', '13:2', '13:3', '13:4', '13:5', '13:6', '14:1', '14:2', '14:3', '14:4', '14:5', '14:6', '15:1', '15:2', '15:3', '15:4', '15:5', '15:6', '16:1', '16:2', '16:3', '16:4', '16:5', '16:6', '17:1', '17:2', '17:3', '17:4', '17:5', '17:6', '18:1', '18:2', '18:3', '18:4', '18:5', '18:6', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6', '21:1', '21:2', '21:3', '21:4', '21:5', '21:6', '22:1', '22:2', '22:3', '22:4', '22:5', '22:6', '23:1', '23:2', '23:3', '23:4', '23:5', '23:6', '24:1', '24:2', '24:3', '24:4', '24:5', '24:6', '25:1', '25:2', '25:3', '25:4', '25:5', '25:6', '26:1', '26:2', '26:3', '26:4', '26:5', '26:6', '27:1', '27:2', '27:3', '27:4', '27:5', '27:6']
# No match for row 481: RT difference=14.095000000000002, Species mismatch or RT out of bounds
# Row 482: Adjusted_RT_FAME=0.8659333333333332, Species=6:1|6:2|6:3|6:4|7:1|7:2|7:3|7:4|7:5|8:1|8:2|8:3|8:4|8:5|8:6|9:1|9:2|9:3|9:4|9:5|9:6|10:1|10:2|10:3|10:4|10:5|10:6|11:1|11:2|11:3|11:4|11:5|11:6|12:1|12:2|12:3|12:4|12:5|12:6|13:1|13:2|13:3|13:4|13:5|13:6|14:1|14:2|14:3|14:4|14:5|14:6|15:1|15:2|15:3|15:4|15:5|15:6|16:1|16:2|16:3|16:4|16:5|16:6|17:1|17:2|17:3|17:4|17:5|17:6|18:1|18:2|18:3|18:4|18:5|18:6|19:1|19:2|19:3|19:4|19:5|19:6|20:1|20:2|20:3|20:4|20:5|20:6
# Species list after split: ['6:1', '6:2', '6:3', '6:4', '7:1', '7:2', '7:3', '7:4', '7:5', '8:1', '8:2', '8:3', '8:4', '8:5', '8:6', '9:1', '9:2', '9:3', '9:4', '9:5', '9:6', '10:1', '10:2', '10:3', '10:4', '10:5', '10:6', '11:1', '11:2', '11:3', '11:4', '11:5', '11:6', '12:1', '12:2', '12:3', '12:4', '12:5', '12:6', '13:1', '13:2', '13:3', '13:4', '13:5', '13:6', '14:1', '14:2', '14:3', '14:4', '14:5', '14:6', '15:1', '15:2', '15:3', '15:4', '15:5', '15:6', '16:1', '16:2', '16:3', '16:4', '16:5', '16:6', '17:1', '17:2', '17:3', '17:4', '17:5', '17:6', '18:1', '18:2', '18:3', '18:4', '18:5', '18:6', '19:1', '19:2', '19:3', '19:4', '19:5', '19:6', '20:1', '20:2', '20:3', '20:4', '20:5', '20:6']
# No match for row 482: RT difference=14.637450000000003, Species mismatch or RT out of bounds
# Filtered rows in hippo_WT_m1_FAD245: 3528 removed
# Log for removed lipids saved at: Projects/AMP/fame_filter_7/notpossible_nov6/log/hippo_WT_m1_FAD245_fame_filter_log_debug.txt
# filter_OzOFF_by_fame_std function completed.

# %% [markdown]
# # Std RT adjustment

# %%
step7 = pd.read_parquet('Projects/AMP/fame_filter_7/notpossible_nov6/hippo_WT_m1_FAD245_filtered.parquet')
step7
# Out:
#                Lipid  Retention_Time  OzESI_Intensity  group_by_ion  \
# 0   FA(16:1)_<>_n-2         6.724850           4029.0            26
# 1   FA(16:1)_<>_n-2         6.918667        1668488.0            26
# 2   FA(16:1)_<>_n-2         7.009100        1227931.0            26
# 3   FA(16:1)_<>_n-2         7.177067        2301793.0            26
# 4   FA(16:1)_<>_n-3         7.100367          10104.0            22
# 5   FA(16:1)_<>_n-3         7.307083           5942.0            22
# 6   FA(16:1)_<>_n-3         7.397533           5607.0            22
# 7   FA(16:1)_<>_n-3         7.643017           4473.0            22
# 8   FA(16:1)_<>_n-7         6.960483           3850.0            11
# 9   FA(16:1)_<>_n-7         7.257650           2460.0            11
# 10  FA(16:1)_<>_n-8         7.115933           1225.0             9
#
#     group_by_lipid                                          Sample_ID  \
# 0               13  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 1               13  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 2               13  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 3               13  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 4               10  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 5               10  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 6               10  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 7               10  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 8                1  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 9                1  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 10              50  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
#
#         Transition              Sample  Parent_Ion  Product_Ion  ...   STD  \
# 0   409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...  None
# 1   409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...  None
# 2   409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...  None
# 3   409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...  None
# 4   395.3 -> 183.0  hippo_WT_m1_FAD245       395.3        183.0  ...  None
# 5   395.3 -> 183.0  hippo_WT_m1_FAD245       395.3        183.0  ...  None
# 6   395.3 -> 183.0  hippo_WT_m1_FAD245       395.3        183.0  ...  None
# 7   395.3 -> 183.0  hippo_WT_m1_FAD245       395.3        183.0  ...  None
# 8   339.3 -> 183.0  hippo_WT_m1_FAD245       339.3        183.0  ...  None
# 9   339.3 -> 183.0  hippo_WT_m1_FAD245       339.3        183.0  ...  None
# 10  325.2 -> 183.0  hippo_WT_m1_FAD245       325.2        183.0  ...  None
#
#    STD_RT_OFF Peak_Height      FWHM  Peak_Width      Peak_Area  \
# 0    7.899783      4029.0  0.046318    0.051667     208.165000
# 1    7.899783   1668488.0  0.146934    0.142117  237119.952933
# 2    7.899783   1227931.0  0.035132    0.025833   31721.550833
# 3    7.899783   2301793.0  0.095411    0.103367  237928.669767
# 4    7.899783     10104.0  0.047203    0.038767     391.698400
# 5    7.899783      5942.0  0.055603    0.051683     307.102367
# 6    7.899783      5607.0  0.028146    0.025833     144.847500
# 7    7.899783      4473.0  0.112408    0.103350     462.284550
# 8    7.899783      3850.0  0.081412    0.077533     298.503333
# 9    7.899783      2460.0  0.072872    0.077533     190.732000
# 10   7.899783      1225.0  0.071837    0.077533      94.978333
#
#      Filter_Column  STD_RT_Dif_FAME Adjusted_RT_FAME  \
# 0   group_by_lipid        -0.269483         6.455367
# 1   group_by_lipid        -0.269483         6.649183
# 2   group_by_lipid        -0.269483         6.739617
# 3   group_by_lipid        -0.269483         6.907583
# 4   group_by_lipid        -0.269483         6.830883
# 5   group_by_lipid        -0.269483         7.037600
# 6   group_by_lipid        -0.269483         7.128050
# 7   group_by_lipid        -0.269483         7.373533
# 8   group_by_lipid        -0.269483         6.691000
# 9   group_by_lipid        -0.269483         6.988167
# 10  group_by_lipid        -0.269483         6.846450
#
#                                        Lipid_Possible
# 0   FA(15:0) | FA(16:1)_<>_n-2 | FA(16:2)_<F>_n-2 ...
# 1   FA(15:0) | FA(16:1)_<>_n-2 | FA(16:2)_<F>_n-2 ...
# 2   FA(15:0) | FA(16:1)_<>_n-2 | FA(16:2)_<F>_n-2 ...
# 3   FA(15:0) | FA(16:1)_<>_n-2 | FA(16:2)_<F>_n-2 ...
# 4   FA(14:0) | FA(15:1)_<>_n-2 | FA(15:2)_<F>_n-2 ...
# 5   FA(14:0) | FA(15:1)_<>_n-2 | FA(15:2)_<F>_n-2 ...
# 6   FA(14:0) | FA(15:1)_<>_n-2 | FA(15:2)_<F>_n-2 ...
# 7   FA(14:0) | FA(15:1)_<>_n-2 | FA(15:2)_<F>_n-2 ...
# 8   FA(10:0) | FA(11:1)_<>_n-2 | FA(11:2)_<F>_n-2 ...
# 9   FA(10:0) | FA(11:1)_<>_n-2 | FA(11:2)_<F>_n-2 ...
# 10  FA(9:0) | FA(10:1)_<>_n-2 | FA(10:2)_<F>_n-2 |...
#
# [11 rows x 22 columns]

# %% [markdown]
# # plot

# %%
# import matplotlib.pyplot as plt

# # Function to plot the chromatogram for a specific group_by_lipid value, including analysis data (peaks)
# def plot_chromatogram(df_grouped, df_analysis, group_value):
#     """
#     Plot the chromatogram for a specific group_by_lipid value with a Retention_Time > 5 filter.

#     :param df_grouped: DataFrame containing the original grouped data.
#     :param df_analysis: DataFrame containing the analyzed data (peaks).
#     :param group_value: The specific group_by_lipid value to plot.
#     """
#     # Filter data for the specific group_by_lipid value and Retention_Time between 5 and 8
#     group_data = df_grouped[(df_grouped['group_by_lipid'] == group_value) & 
#                             (df_grouped['Retention_Time'] > 5) & 
#                             (df_grouped['Retention_Time'] < 8)]
    
#     analysis_data = df_analysis[(df_analysis['group_by_lipid'] == group_value) & 
#                                 (df_analysis['Retention_Time'] > 5) & 
#                                 (df_analysis['Retention_Time'] < 8)]
    
#     # Ensure the Retention_Time is sorted in both DataFrames
#     group_data = group_data.sort_values(by='Retention_Time')
#     analysis_data = analysis_data.sort_values(by='Retention_Time')

#     # Extract Lipid, Parent Ion, and Isomer values from the first row of the group
#     lipid = group_data['Lipid'].iloc[0] if not group_data.empty else "Unknown Lipid"
#     parent_ion = group_data['Parent_Ion'].iloc[0] if not group_data.empty else "Unknown Parent Ion"
    
#     # Plot the grouped data (original chromatogram)
#     plt.figure(figsize=(10, 6))
#     plt.plot(group_data['Retention_Time'], group_data['OzESI_Intensity'], label=f'Chromatogram - group_by_lipid: {group_value}', color='blue')
    
#     # Overlay the analysis data (peaks)
#     if not analysis_data.empty:
#         plt.scatter(analysis_data['Retention_Time'], analysis_data['OzESI_Intensity'], color='red', marker='x', label='Identified Peaks')

#     # Add labels and title
#     plt.xlabel('Retention Time')
#     plt.ylabel('OzESI Intensity')
    
#     # Add Lipid and Parent Ion to the title
#     plt.title(f'{group_value}   Parent Ion: {parent_ion}')
    
#     # Add a legend and grid
#     plt.legend()
#     plt.grid(True)
    
#     # Show the plot
#     plt.show()

# # Example: Define the specific group_by_lipid value you are interested in
# specific_group_by_lipid_value = 3 # Replace with the actual value you are interested in

# # Call the function to plot the chromatogram and analysis data with Retention_Time filter
# plot_chromatogram(df_before, df, specific_group_by_lipid_value)

# %%
# # Filter for Species containing '16:1', Retention_Time within the specified range, and OzESI_Intensity > 5000
# notpossible_lipids = df[(df['Species'].str.contains('18:1', case=False, na=False)) & 
#                         (df['Retention_Time'] >= 7.5) & 
#                         (df['Retention_Time'] <= 9.9) &
#                         (df['OzESI_Intensity'] > 500)]

# sorted_notpossible_lipids = notpossible_lipids.sort_values(by='OzESI_Intensity', ascending=False)
# #print unique Lipid values
# #print(sorted_notpossible_lipids['Lipid'].unique())
# sorted_notpossible_lipids = sorted_notpossible_lipids.nlargest(10, 'OzESI_Intensity')
# sorted_notpossible_lipids

# %% [markdown]
# # match notpossible OzOFF to regular OzOFF data - DONT ACTUALLY NEED THIS

# %%
# sorted_notpossible_lipids # not possible ozoff 16:1

# ozoff_df = pd.read_parquet('Projects/AMP/analysis/OFF/df_analysis_5_hippo_WT_m1_FAD245_OFF.parquet')
# ozoff_df = ozoff_df[ozoff_df['Species'].str.contains('16:1', case=False, na=False)]
# ozoff_df = ozoff_df.nlargest(2, 'OzESI_Intensity')
# ozoff_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1282923/886869083.py in <module>
# ----> 1 sorted_notpossible_lipids # not possible ozoff 16:1
#       2
#       3 ozoff_df = pd.read_parquet('Projects/AMP/analysis/OFF/df_analysis_5_hippo_WT_m1_FAD245_OFF.parquet')
#       4 ozoff_df = ozoff_df[ozoff_df['Species'].str.contains('16:1', case=False, na=False)]
#       5 ozoff_df = ozoff_df.nlargest(2, 'OzESI_Intensity')
#
# NameError: name 'sorted_notpossible_lipids' is not defined

# %%
# import pandas as pd
# import re
# from tqdm import tqdm

# def extract_core_lipid(lipid):
#     # Extract the core part of the lipid (e.g., "FA(16:1)" from "FA(16:1)_<>_n-3")
#     match = re.match(r'^(FA\(\d+:\d+\))', lipid)
#     return match.group(1) if match else lipid

# def notpossible_vs_ozoff_6(sorted_notpossible_lipids, ozoff_df):
#     # Define the retention time tolerance
#     tolerance = 0.1
    
#     # Create a new DataFrame to store matched rows
#     matched_df = pd.DataFrame()

#     # Iterate over rows in sorted_notpossible_lipids with tqdm
#     for _, not_possible_row in tqdm(sorted_notpossible_lipids.iterrows(), total=len(sorted_notpossible_lipids), desc="Processing not_possible_df rows"):
#         # Store the original Lipid values in the new column `all_possible_lipids`
#         all_possible_lipids = not_possible_row['Lipid']
        
#         # Split the Lipid values in sorted_notpossible_lipids based on '|'
#         lipid_values = all_possible_lipids.split('|')
#         species_values = not_possible_row['Species'].split('|')
        
#         # Loop through each lipid in the parsed list
#         for i, lipid in enumerate(lipid_values):
#             lipid = lipid.strip()  # Remove extra spaces
#             core_lipid = extract_core_lipid(lipid)  # Extract core lipid name
#             species = species_values[i].strip()  # Corresponding species for debugging
            
#             # Debug print for lipid and species being checked
#             # print(f"Checking Lipid: '{core_lipid}', Species: '{species}' from not_possible_row")

#             # Search for this lipid in ozoff_df within the retention time window with tqdm
#             for _, ozoff_row in tqdm(ozoff_df.iterrows(), total=len(ozoff_df), desc="Matching ozoff_df rows", leave=False):
#                 # Debug print for ozoff lipid and retention time
#                 # print(f"Comparing with ozoff Lipid: '{ozoff_row['Lipid']}', RT: {ozoff_row['Retention_Time']}, OzESI_Intensity: {ozoff_row['OzESI_Intensity']}")
                
#                 # Use direct string comparison for lipid and float comparison for retention time
#                 lipid_match = core_lipid == ozoff_row['Lipid']
#                 rt_match = abs(float(not_possible_row['Retention_Time']) - float(ozoff_row['Retention_Time'])) <= tolerance

#                 # Print match results for lipid and retention time
#                 # print(f"Lipid Match: {lipid_match}, RT Match: {rt_match}")
                
#                 if lipid_match and rt_match:
#                     # Create a new row with only matched lipid and species
#                     new_row = not_possible_row.copy()
#                     new_row['Lipid'] = lipid
#                     new_row['Species'] = species
#                     new_row['all_possible_lipids'] = all_possible_lipids  # Add original Lipid values
                    
#                     # Append to the matched DataFrame
#                     matched_df = pd.concat([matched_df, new_row.to_frame().T], ignore_index=True)
                    
#                     # Print debug statement showing match details
#                     # print(f"Match found and appended: Lipid = {lipid}, Species = {species}, Retention Time = {ozoff_row['Retention_Time']}, All Possible Lipids = {all_possible_lipids}")
#                     break  # Exit once a match is found for this lipid
#                 # else:
#                     # print("No match for this ozoff row.")
    
#     # Final debug output
#     # print("Matching complete.")
#     if matched_df.empty:
#         print("No matches were found.")
#     else:
#         print(f"Total matches found: {len(matched_df)}")
    
#     return matched_df

# # Call the function with your DataFrames
# matched_df = notpossible_vs_ozoff_6(sorted_notpossible_lipids, ozoff_df)

# # Display the resulting matched DataFrame
# matched_df
# Out:
# Processing not_possible_df rows: 100%|██████████| 5/5 [00:01<00:00,  3.70it/s]
# Total matches found: 2
#              Lipid Retention_Time OzESI_Intensity group_by_ion group_by_lipid  \
# 0  FA(18:1)_<>_n-2        9.03615       3224463.0           33             20
# 1  FA(18:1)_<>_n-3         8.9207         39933.0           29             16
#
#                                            Sample_ID      Transition  \
# 0  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  437.4 -> 183.0
# 1  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  423.3 -> 183.0
#
#                Sample Parent_Ion Product_Ion Species  \
# 0  hippo_WT_m1_FAD245      437.4       183.0    18:1
# 1  hippo_WT_m1_FAD245      423.3       183.0    18:1
#
#                                                Class   STD STD_RT_OFF  \
# 0  FA | FA | FA | FA | FA | FA | FA | FA | FA | F...  None   7.899783
# 1  FA | FA | FA | FA | FA | FA | FA | FA | FA | F...  None   7.899783
#
#   Peak_Height      FWHM Peak_Width    Peak_Area   Filter_Column  \
# 0   3224463.0  0.117766   0.116267  374897.5648  group_by_lipid
# 1     39933.0   0.05508   0.051667     2063.205  group_by_lipid
#
#                                  all_possible_lipids
# 0  FA(17:0) | FA(18:1)_<>_n-2 | FA(18:2)_<F>_n-2 ...
# 1  FA(16:0) | FA(17:1)_<>_n-2 | FA(17:2)_<F>_n-2 ...

# %%
# matched_df
# Out:
#              Lipid Retention_Time OzESI_Intensity group_by_ion group_by_lipid  \
# 0  FA(18:1)_<>_n-2        9.03615       3224463.0           33             20
# 1  FA(18:1)_<>_n-3         8.9207         39933.0           29             16
#
#                                            Sample_ID      Transition  \
# 0  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  437.4 -> 183.0
# 1  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  423.3 -> 183.0
#
#                Sample Parent_Ion Product_Ion Species  \
# 0  hippo_WT_m1_FAD245      437.4       183.0    18:1
# 1  hippo_WT_m1_FAD245      423.3       183.0    18:1
#
#                                                Class   STD STD_RT_OFF  \
# 0  FA | FA | FA | FA | FA | FA | FA | FA | FA | F...  None   7.899783
# 1  FA | FA | FA | FA | FA | FA | FA | FA | FA | F...  None   7.899783
#
#   Peak_Height      FWHM Peak_Width    Peak_Area   Filter_Column  \
# 0   3224463.0  0.117766   0.116267  374897.5648  group_by_lipid
# 1     39933.0   0.05508   0.051667     2063.205  group_by_lipid
#
#                                  all_possible_lipids
# 0  FA(17:0) | FA(18:1)_<>_n-2 | FA(18:2)_<F>_n-2 ...
# 1  FA(16:0) | FA(17:1)_<>_n-2 | FA(17:2)_<F>_n-2 ...

# %% [markdown]
# # DO MORE WORK HERE NEXT

# %% [markdown]
# # OzOFF notpossbile - Remove OzON not possible  | LOAD OZON HERE

# %%
import pandas as pd
ozon_test = pd.read_parquet('Projects/AMP/fame_filter_7/hippo_WT_m1_FAD245_fame_filter_7.parquet')
ozon_test = pd.read_parquet('Projects/AMP/isomer_filter_6/hippo_WT_m1_FAD245_isomer_filtered_6.parquet')

filtered_lipids = ozon_test[ozon_test['Lipid'].str.contains('16:1', case=False, na=False)]
sorted_filtered_lipids_OZON = filtered_lipids.sort_values(by='OzESI_Intensity', ascending=False)
print(sorted_filtered_lipids_OZON['Species'].unique())
sorted_filtered_lipids_OZON = sorted_filtered_lipids_OZON.sort_values(by='Lipid', ascending=True)
sorted_filtered_lipids_OZON


# ozon_test
# Out:
# ['16:1']
#                 Lipid  Retention_Time  OzESI_Intensity  group_by_ion  \
# 76  FA(16:1)_<>_n-10         7.039200           2658.0             4
# 68   FA(16:1)_<>_n-2         7.138283        1137226.0            25
# 66   FA(16:1)_<>_n-2         6.892800        1008466.0            25
# 77   FA(16:1)_<>_n-2         6.892800        1008466.0            25
# 67   FA(16:1)_<>_n-2         6.970317         608811.0            25
# 78   FA(16:1)_<>_n-2         6.970317         608811.0            25
# 79   FA(16:1)_<>_n-3         6.854850          10899.0            21
# 70   FA(16:1)_<>_n-5         7.101567            566.0            15
# 69   FA(16:1)_<>_n-5         7.062800            553.0            15
# 71   FA(16:1)_<>_n-6         7.063417            920.0            12
# 80   FA(16:1)_<>_n-7         6.831267           1788.0            10
# 73   FA(16:1)_<>_n-7         7.102583           1249.0            10
# 81   FA(16:1)_<>_n-7         6.921700           2359.0            10
# 72   FA(16:1)_<>_n-7         6.921700           2359.0            10
# 74   FA(16:1)_<>_n-8         7.103000           1655.0             8
# 82   FA(16:1)_<>_n-8         6.870433            820.0             8
# 75   FA(16:1)_<>_n-9         6.922517            672.0             6
# 83   FA(16:1)_<>_n-9         6.922517            672.0             6
#
#     group_by_lipid                                          Sample_ID  \
# 76              81  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 68              86  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 66              86  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 77              86  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 67              86  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 78              86  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 79              87  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 70              89  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 69              89  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 71              90  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 80              91  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 73              91  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 81              91  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 72              91  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 74              92  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 82              92  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 75              93  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 83              93  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
#
#         Transition              Sample  Parent_Ion  Product_Ion  ...  \
# 76  297.2 -> 183.0  hippo_WT_m1_FAD245       297.2        183.0  ...
# 68  409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...
# 66  409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...
# 77  409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...
# 67  409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...
# 78  409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...
# 79  395.3 -> 183.0  hippo_WT_m1_FAD245       395.3        183.0  ...
# 70  367.3 -> 183.0  hippo_WT_m1_FAD245       367.3        183.0  ...
# 69  367.3 -> 183.0  hippo_WT_m1_FAD245       367.3        183.0  ...
# 71  353.3 -> 183.0  hippo_WT_m1_FAD245       353.3        183.0  ...
# 80  339.3 -> 183.0  hippo_WT_m1_FAD245       339.3        183.0  ...
# 73  339.3 -> 183.0  hippo_WT_m1_FAD245       339.3        183.0  ...
# 81  339.3 -> 183.0  hippo_WT_m1_FAD245       339.3        183.0  ...
# 72  339.3 -> 183.0  hippo_WT_m1_FAD245       339.3        183.0  ...
# 74  325.2 -> 183.0  hippo_WT_m1_FAD245       325.2        183.0  ...
# 82  325.2 -> 183.0  hippo_WT_m1_FAD245       325.2        183.0  ...
# 75  311.3 -> 183.0  hippo_WT_m1_FAD245       311.3        183.0  ...
# 83  311.3 -> 183.0  hippo_WT_m1_FAD245       311.3        183.0  ...
#
#       Slope_Left   Slope_Right Biology  Genotype    Cage  Mouse  n_value  \
# 76  4.168539e+04 -2.796314e+04   hippo        WT  FAD245     m1       10
# 68  1.915522e+07 -6.663993e+06   hippo        WT  FAD245     m1        2
# 66  1.434060e+07 -1.149128e+07   hippo        WT  FAD245     m1        2
# 77  1.434060e+07 -1.149128e+07   hippo        WT  FAD245     m1        2
# 67 -3.180940e+05 -3.513944e+06   hippo        WT  FAD245     m1        2
# 78 -3.180940e+05 -3.513944e+06   hippo        WT  FAD245     m1        2
# 79  4.303410e+04 -1.137442e+04   hippo        WT  FAD245     m1        3
# 70 -6.089056e+02 -5.935323e+03   hippo        WT  FAD245     m1        5
# 69  5.905991e+03 -6.089056e+02   hippo        WT  FAD245     m1        5
# 71  1.059539e+04  6.735892e+01   hippo        WT  FAD245     m1        6
# 80  3.237235e+04 -1.998525e+04   hippo        WT  FAD245     m1        7
# 73  1.051797e+04 -1.141762e+04   hippo        WT  FAD245     m1        7
# 81  2.861198e+04 -2.362235e+04   hippo        WT  FAD245     m1        7
# 72  2.861198e+04 -2.362235e+04   hippo        WT  FAD245     m1        7
# 74  1.897880e+04 -1.060645e+04   hippo        WT  FAD245     m1        8
# 82  1.089401e+04 -1.089401e+04   hippo        WT  FAD245     m1        8
# 75  1.256527e+04 -8.571429e+03   hippo        WT  FAD245     m1        9
# 83  1.256527e+04 -8.571429e+03   hippo        WT  FAD245     m1        9
#
#     Adjusted_RT n_position  OzOFF_Isomer
# 76     7.077967         10           2.0
# 68     7.177050          2           2.0
# 66     6.931567          2           2.0
# 77     6.931567          2           1.0
# 67     7.009083          2           2.0
# 78     7.009083          2           1.0
# 79     6.893617          3           1.0
# 70     7.140333          5           2.0
# 69     7.101567          5           2.0
# 71     7.102183          6           2.0
# 80     6.870033          7           1.0
# 73     7.141350          7           2.0
# 81     6.960467          7           1.0
# 72     6.960467          7           2.0
# 74     7.141767          8           2.0
# 82     6.909200          8           1.0
# 75     6.961283          9           2.0
# 83     6.961283          9           1.0
#
# [18 rows x 32 columns]

# %%
# import pandas as pd

# def match_lipids(sorted_notpossible_lipids, ozon_test):
#     # Create a new column in the OFF data to store matched information
#     sorted_notpossible_lipids['Matched_Lipid_ON'] = None

#     # Iterate through each row in the ON data
#     for index_on, row_on in ozon_test.iterrows():
#         on_lipid = row_on['Lipid'].strip()  # Trim spaces for accurate matching
#         match_found = False

#         # Iterate through each row in the OFF data
#         for index_off, row_off in sorted_notpossible_lipids.iterrows():
#             # Split the OFF Lipid values by '|' and trim each part
#             off_lipids = [lipid.strip() for lipid in row_off['Lipid'].split('|')]

#             # Check if the ON lipid matches any of the possible OFF lipids
#             if any(on_lipid.lower() == off_lipid.lower() for off_lipid in off_lipids):
#                 # If a match is found, update the 'Matched_Lipid_ON' column in the OFF DataFrame
#                 sorted_notpossible_lipids.at[index_off, 'Matched_Lipid_ON'] = on_lipid
#                 match_found = True
#                 break  # Stop searching for this ON lipid once a match is found

#         # If no match is found, you can choose to log or handle this scenario
#         if not match_found:
#             print(f"No match found for ON lipid: {on_lipid}")

#     # Filter the OFF data to only keep rows with matched Lipids
#     matched_lipids = sorted_notpossible_lipids.dropna(subset=['Matched_Lipid_ON']).copy()

#     return matched_lipids

# # Example usage
# # Assuming sorted_notpossible_lipids and ozon_test are the input DataFrames
# matched_lipids_df = match_lipids(sorted_notpossible_lipids, ozon_test)

# # Display or save the result
# matched_lipids_df
# # matched_lipids_df.to_csv('matched_lipids.csv', index=False)

# %%
import pandas as pd

def match_lipids_with_adjusted_rt_to_rt(ozon_test, sorted_notpossible_lipids, rt_window=0.5):
    # Create new columns in the ON data to store matched information from OFF
    ozon_test['Matched_Lipid_OFF'] = None
    ozon_test['Intensity_OFF'] = None
    ozon_test['Retention_Time_OFF'] = None

    # Iterate through each row in the ON data
    for index_on, row_on in ozon_test.iterrows():
        on_lipid = row_on['Lipid'].strip()  # Trim spaces for accurate matching
        on_adjusted_rt = row_on['Adjusted_RT']  # Adjusted RT of the ON lipid
        match_found = False

        # Iterate through each row in the OFF data
        for index_off, row_off in sorted_notpossible_lipids.iterrows():
            # Split the OFF Lipid values by '|' and trim each part
            off_lipids = [lipid.strip() for lipid in row_off['Lipid'].split('|')]
            off_retention_time = row_off['Retention_Time']  # Retention time of the OFF lipid

            # Check if the ON lipid matches any of the possible OFF lipids
            # and if the Adjusted_RT is within the specified window of the Retention_Time
            if any(on_lipid.lower() == off_lipid.lower() for off_lipid in off_lipids) and abs(on_adjusted_rt - off_retention_time) <= rt_window:
                # If a match is found, update the 'Matched_Lipid_OFF', 'Intensity_OFF', and 'Retention_Time_OFF' columns in the ON DataFrame
                ozon_test.at[index_on, 'Matched_Lipid_OFF'] = row_off['Lipid']
                ozon_test.at[index_on, 'Intensity_OFF'] = row_off['OzESI_Intensity']
                ozon_test.at[index_on, 'Retention_Time_OFF'] = off_retention_time
                match_found = True
                break  # Stop searching for this ON lipid once a match is found

        # If no match is found, log or handle this scenario
        if not match_found:
            print(f"No match found for ON lipid: {on_lipid} within Adjusted_RT window {on_adjusted_rt} ± {rt_window}")

    # Filter the ON data to separate matched and unmatched lipids
    matched_lipids_df = ozon_test.dropna(subset=['Matched_Lipid_OFF']).copy()
    unmatched_lipids_df = ozon_test[ozon_test['Matched_Lipid_OFF'].isna()].copy()

    return matched_lipids_df, unmatched_lipids_df

# Example usage
# Assuming sorted_notpossible_lipids and ozon_test are the input DataFrames
matched_lipids_df, unmatched_lipids_df = match_lipids_with_adjusted_rt_to_rt(sorted_filtered_lipids_OZON, step7, rt_window=0.05)

# # Print values of Matched_Lipid_OFF in row 1 if exists
# if not matched_lipids_df.empty:
#     print(matched_lipids_df['Matched_Lipid_OFF'].iloc[1])

# Display or save the results
matched_lipids_df
unmatched_lipids_df
# matched_lipids_df.to_csv('matched_lipids.csv', index=False)
# unmatched_lipids_df.to_csv('unmatched_lipids.csv', index=False)
# Out:
# No match found for ON lipid: FA(16:1)_<>_n-10 within Adjusted_RT window 7.077966666666667 ± 0.05
# No match found for ON lipid: FA(16:1)_<>_n-3 within Adjusted_RT window 6.8936166666666665 ± 0.05
# No match found for ON lipid: FA(16:1)_<>_n-5 within Adjusted_RT window 7.140333333333333 ± 0.05
# No match found for ON lipid: FA(16:1)_<>_n-5 within Adjusted_RT window 7.101566666666667 ± 0.05
# No match found for ON lipid: FA(16:1)_<>_n-6 within Adjusted_RT window 7.1021833333333335 ± 0.05
# No match found for ON lipid: FA(16:1)_<>_n-7 within Adjusted_RT window 6.870033333333334 ± 0.05
# No match found for ON lipid: FA(16:1)_<>_n-7 within Adjusted_RT window 7.14135 ± 0.05
# No match found for ON lipid: FA(16:1)_<>_n-8 within Adjusted_RT window 6.9092 ± 0.05
# No match found for ON lipid: FA(16:1)_<>_n-9 within Adjusted_RT window 6.961283333333333 ± 0.05
# No match found for ON lipid: FA(16:1)_<>_n-9 within Adjusted_RT window 6.961283333333333 ± 0.05
#                 Lipid  Retention_Time  OzESI_Intensity  group_by_ion  \
# 76  FA(16:1)_<>_n-10         7.039200           2658.0             4
# 79   FA(16:1)_<>_n-3         6.854850          10899.0            21
# 70   FA(16:1)_<>_n-5         7.101567            566.0            15
# 69   FA(16:1)_<>_n-5         7.062800            553.0            15
# 71   FA(16:1)_<>_n-6         7.063417            920.0            12
# 80   FA(16:1)_<>_n-7         6.831267           1788.0            10
# 73   FA(16:1)_<>_n-7         7.102583           1249.0            10
# 82   FA(16:1)_<>_n-8         6.870433            820.0             8
# 75   FA(16:1)_<>_n-9         6.922517            672.0             6
# 83   FA(16:1)_<>_n-9         6.922517            672.0             6
#
#     group_by_lipid                                          Sample_ID  \
# 76              81  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 79              87  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 70              89  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 69              89  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 71              90  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 80              91  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 73              91  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 82              92  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 75              93  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 83              93  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
#
#         Transition              Sample  Parent_Ion  Product_Ion  ... Genotype  \
# 76  297.2 -> 183.0  hippo_WT_m1_FAD245       297.2        183.0  ...       WT
# 79  395.3 -> 183.0  hippo_WT_m1_FAD245       395.3        183.0  ...       WT
# 70  367.3 -> 183.0  hippo_WT_m1_FAD245       367.3        183.0  ...       WT
# 69  367.3 -> 183.0  hippo_WT_m1_FAD245       367.3        183.0  ...       WT
# 71  353.3 -> 183.0  hippo_WT_m1_FAD245       353.3        183.0  ...       WT
# 80  339.3 -> 183.0  hippo_WT_m1_FAD245       339.3        183.0  ...       WT
# 73  339.3 -> 183.0  hippo_WT_m1_FAD245       339.3        183.0  ...       WT
# 82  325.2 -> 183.0  hippo_WT_m1_FAD245       325.2        183.0  ...       WT
# 75  311.3 -> 183.0  hippo_WT_m1_FAD245       311.3        183.0  ...       WT
# 83  311.3 -> 183.0  hippo_WT_m1_FAD245       311.3        183.0  ...       WT
#
#       Cage Mouse  n_value  Adjusted_RT  n_position  OzOFF_Isomer  \
# 76  FAD245    m1       10     7.077967          10           2.0
# 79  FAD245    m1        3     6.893617           3           1.0
# 70  FAD245    m1        5     7.140333           5           2.0
# 69  FAD245    m1        5     7.101567           5           2.0
# 71  FAD245    m1        6     7.102183           6           2.0
# 80  FAD245    m1        7     6.870033           7           1.0
# 73  FAD245    m1        7     7.141350           7           2.0
# 82  FAD245    m1        8     6.909200           8           1.0
# 75  FAD245    m1        9     6.961283           9           2.0
# 83  FAD245    m1        9     6.961283           9           1.0
#
#     Matched_Lipid_OFF Intensity_OFF  Retention_Time_OFF
# 76               None          None                None
# 79               None          None                None
# 70               None          None                None
# 69               None          None                None
# 71               None          None                None
# 80               None          None                None
# 73               None          None                None
# 82               None          None                None
# 75               None          None                None
# 83               None          None                None
#
# [10 rows x 35 columns]

# %%
matched_lipids_df
# Out:
#                Lipid  Retention_Time  OzESI_Intensity  group_by_ion  \
# 68  FA(16:1)_<>_n-2         7.138283        1137226.0            25
# 66  FA(16:1)_<>_n-2         6.892800        1008466.0            25
# 77  FA(16:1)_<>_n-2         6.892800        1008466.0            25
# 67  FA(16:1)_<>_n-2         6.970317         608811.0            25
# 78  FA(16:1)_<>_n-2         6.970317         608811.0            25
# 81  FA(16:1)_<>_n-7         6.921700           2359.0            10
# 72  FA(16:1)_<>_n-7         6.921700           2359.0            10
# 74  FA(16:1)_<>_n-8         7.103000           1655.0             8
#
#     group_by_lipid                                          Sample_ID  \
# 68              86  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 66              86  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 77              86  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 67              86  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 78              86  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 81              91  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 72              91  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 74              92  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
#
#         Transition              Sample  Parent_Ion  Product_Ion  ... Genotype  \
# 68  409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...       WT
# 66  409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...       WT
# 77  409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...       WT
# 67  409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...       WT
# 78  409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...       WT
# 81  339.3 -> 183.0  hippo_WT_m1_FAD245       339.3        183.0  ...       WT
# 72  339.3 -> 183.0  hippo_WT_m1_FAD245       339.3        183.0  ...       WT
# 74  325.2 -> 183.0  hippo_WT_m1_FAD245       325.2        183.0  ...       WT
#
#       Cage Mouse  n_value  Adjusted_RT  n_position  OzOFF_Isomer  \
# 68  FAD245    m1        2     7.177050           2           2.0
# 66  FAD245    m1        2     6.931567           2           2.0
# 77  FAD245    m1        2     6.931567           2           1.0
# 67  FAD245    m1        2     7.009083           2           2.0
# 78  FAD245    m1        2     7.009083           2           1.0
# 81  FAD245    m1        7     6.960467           7           1.0
# 72  FAD245    m1        7     6.960467           7           2.0
# 74  FAD245    m1        8     7.141767           8           2.0
#
#     Matched_Lipid_OFF Intensity_OFF  Retention_Time_OFF
# 68   FA(16:1)_<>_n-2      2301793.0            7.177067
# 66   FA(16:1)_<>_n-2      1668488.0            6.918667
# 77   FA(16:1)_<>_n-2      1668488.0            6.918667
# 67   FA(16:1)_<>_n-2      1227931.0              7.0091
# 78   FA(16:1)_<>_n-2      1227931.0              7.0091
# 81   FA(16:1)_<>_n-7         3850.0            6.960483
# 72   FA(16:1)_<>_n-7         3850.0            6.960483
# 74   FA(16:1)_<>_n-8         1225.0            7.115933
#
# [8 rows x 35 columns]

# %% [markdown]
# # python function import same result?

# %%
# Jupyter Notebook Cell

# Import the function from the created Python file
from core.python.not_possible.notpossible_8_AMP import match_lipids_with_adjusted_rt_to_rt

# Define the paths to the directories containing the OzON and OzOFF DataFrames
ozon_test_path = 'Projects/AMP/fame_filter_7/'
off_data_path = 'Projects/AMP/analysis/OFF/notpossible/'

# Define the output directories for matched and unmatched results
notpossible_output_matched = 'Projects/AMP/notpossible_8/maybe/'
notpossible_output_nomatch = 'Projects/AMP/notpossible_8/yes/'

output_log_dir = 'Projects/AMP/notpossible_8/log/'

# Set the retention time window
rt_window = 0.2

# Call the function to match lipids
match_lipids_with_adjusted_rt_to_rt(
    input_dir=ozon_test_path,
    off_possible_dir=off_data_path,
    rt_window=rt_window,
    output_matched_dir=notpossible_output_matched,
    output_unmatched_dir=notpossible_output_nomatch,
    output_log_dir=output_log_dir
)
# Out:
# Output directory for matched files: Projects/AMP/notpossible_8/maybe/
# Output directory for unmatched files: Projects/AMP/notpossible_8/yes/
# Output directory for log files: Projects/AMP/notpossible_8/log/
#
# Files in Directory 1 (OzOFF):
# File: df_analysis_5_cortex_5xFAD_m2_FAD257_OFF.parquet, Key: cortex_5xFAD_m2_FAD257
# File: df_analysis_5_hippo_5xFAD_m1_FAD249_OFF.parquet, Key: hippo_5xFAD_m1_FAD249
# File: df_analysis_5_cortex_WT_m5_FAD263_OFF.parquet, Key: cortex_WT_m5_FAD263
# File: df_analysis_5_cereb_WT_m2_FAD246_OFF.parquet, Key: cereb_WT_m2_FAD246
# File: df_analysis_5_dienc_WT_m5_FAD263_OFF.parquet, Key: dienc_WT_m5_FAD263
# File: df_analysis_5_cereb_5xFAD_m2_FAD257_OFF.parquet, Key: cereb_5xFAD_m2_FAD257
# File: df_analysis_5_hippo_5xFAD_m2_FAD231_OFF.parquet, Key: hippo_5xFAD_m2_FAD231
# File: df_analysis_5_cereb_WT_m5_FAD259_OFF.parquet, Key: cereb_WT_m5_FAD259
# File: df_analysis_5_cereb_WT_m1_FAD245_OFF.parquet, Key: cereb_WT_m1_FAD245
# File: df_analysis_5_cereb_WT_m4_FAD263_OFF.parquet, Key: cereb_WT_m4_FAD263
# File: df_analysis_5_cortex_5xFAD_m2_FAD231_OFF.parquet, Key: cortex_5xFAD_m2_FAD231
# File: df_analysis_5_cereb_5xFAD_m1_FAD249_OFF.parquet, Key: cereb_5xFAD_m1_FAD249
# File: df_analysis_5_cereb_WT_m3_FAD263_OFF.parquet, Key: cereb_WT_m3_FAD263
# File: df_analysis_5_dienc_5xFAD_m1_FAD231_OFF.parquet, Key: dienc_5xFAD_m1_FAD231
# File: df_analysis_5_hippo_5xFAD_m2_FAD257_OFF.parquet, Key: hippo_5xFAD_m2_FAD257
# File: df_analysis_5_cereb_5xFAD_m2_FAD231_OFF.parquet, Key: cereb_5xFAD_m2_FAD231
# File: df_analysis_5_cortex_5xFAD_m1_FAD249_OFF.parquet, Key: cortex_5xFAD_m1_FAD249
# File: df_analysis_5_hippo_WT_m5_FAD263_OFF.parquet, Key: hippo_WT_m5_FAD263
# File: df_analysis_5_cortex_WT_m5_FAD259_OFF.parquet, Key: cortex_WT_m5_FAD259
# File: df_analysis_5_hippo_5xFAD_m1_FAD231_OFF.parquet, Key: hippo_5xFAD_m1_FAD231
# File: df_analysis_5_hippo_WT_m4_FAD263_OFF.parquet, Key: hippo_WT_m4_FAD263
# File: df_analysis_5_dienc_WT_m2_FAD249_OFF.parquet, Key: dienc_WT_m2_FAD249
# File: df_analysis_5_hippo_WT_m1_FAD245_OFF.parquet, Key: hippo_WT_m1_FAD245
# File: df_analysis_5_dienc_5xFAD_m2_FAD257_OFF.parquet, Key: dienc_5xFAD_m2_FAD257
# File: df_analysis_5_cortex_WT_m2_FAD249_OFF.parquet, Key: cortex_WT_m2_FAD249
# File: df_analysis_5_cereb_WT_m5_FAD263_OFF.parquet, Key: cereb_WT_m5_FAD263
# File: df_analysis_5_dienc_WT_m5_FAD259_OFF.parquet, Key: dienc_WT_m5_FAD259
# File: df_analysis_5_hippo_WT_m3_FAD263_OFF.parquet, Key: hippo_WT_m3_FAD263
# File: df_analysis_5_dienc_WT_m1_FAD245_OFF.parquet, Key: dienc_WT_m1_FAD245
# File: df_analysis_5_dienc_5xFAD_m2_FAD231_OFF.parquet, Key: dienc_5xFAD_m2_FAD231
# File: df_analysis_5_dienc_WT_m4_FAD263_OFF.parquet, Key: dienc_WT_m4_FAD263
# File: df_analysis_5_cereb_5xFAD_m1_FAD231_OFF.parquet, Key: cereb_5xFAD_m1_FAD231
# File: df_analysis_5_cortex_WT_m3_FAD263_OFF.parquet, Key: cortex_WT_m3_FAD263
# File: df_analysis_5_Unknown_OFF.parquet, Key: Unknown_OFF
# File: df_analysis_5_dienc_5xFAD_m1_FAD249_OFF.parquet, Key: dienc_5xFAD_m1_FAD249
# File: df_analysis_5_dienc_WT_m3_FAD263_OFF.parquet, Key: dienc_WT_m3_FAD263
# File: df_analysis_5_cortex_WT_m4_FAD263_OFF.parquet, Key: cortex_WT_m4_FAD263
# File: df_analysis_5_cortex_WT_m1_FAD245_OFF.parquet, Key: cortex_WT_m1_FAD245
# File: df_analysis_5_cortex_5xFAD_m1_FAD231_OFF.parquet, Key: cortex_5xFAD_m1_FAD231
#
# Files in Directory 2 (OzON):
# File: hippo_WT_m1_FAD245_fame_filter_7.parquet, Key: hippo_WT_m1_FAD245
# Total matched files: 1
#
# Unmatched Files:
# OzOFF file without match: df_analysis_5_cortex_5xFAD_m2_FAD257_OFF.parquet (Key: cortex_5xFAD_m2_FAD257)
# OzOFF file without match: df_analysis_5_hippo_5xFAD_m1_FAD249_OFF.parquet (Key: hippo_5xFAD_m1_FAD249)
# OzOFF file without match: df_analysis_5_cortex_WT_m5_FAD263_OFF.parquet (Key: cortex_WT_m5_FAD263)
# OzOFF file without match: df_analysis_5_cereb_WT_m2_FAD246_OFF.parquet (Key: cereb_WT_m2_FAD246)
# OzOFF file without match: df_analysis_5_dienc_WT_m5_FAD263_OFF.parquet (Key: dienc_WT_m5_FAD263)
# OzOFF file without match: df_analysis_5_cereb_5xFAD_m2_FAD257_OFF.parquet (Key: cereb_5xFAD_m2_FAD257)
# OzOFF file without match: df_analysis_5_hippo_5xFAD_m2_FAD231_OFF.parquet (Key: hippo_5xFAD_m2_FAD231)
# OzOFF file without match: df_analysis_5_cereb_WT_m5_FAD259_OFF.parquet (Key: cereb_WT_m5_FAD259)
# OzOFF file without match: df_analysis_5_cereb_WT_m1_FAD245_OFF.parquet (Key: cereb_WT_m1_FAD245)
# OzOFF file without match: df_analysis_5_cereb_WT_m4_FAD263_OFF.parquet (Key: cereb_WT_m4_FAD263)
# OzOFF file without match: df_analysis_5_cortex_5xFAD_m2_FAD231_OFF.parquet (Key: cortex_5xFAD_m2_FAD231)
# OzOFF file without match: df_analysis_5_cereb_5xFAD_m1_FAD249_OFF.parquet (Key: cereb_5xFAD_m1_FAD249)
# OzOFF file without match: df_analysis_5_cereb_WT_m3_FAD263_OFF.parquet (Key: cereb_WT_m3_FAD263)
# OzOFF file without match: df_analysis_5_dienc_5xFAD_m1_FAD231_OFF.parquet (Key: dienc_5xFAD_m1_FAD231)
# OzOFF file without match: df_analysis_5_hippo_5xFAD_m2_FAD257_OFF.parquet (Key: hippo_5xFAD_m2_FAD257)
# OzOFF file without match: df_analysis_5_cereb_5xFAD_m2_FAD231_OFF.parquet (Key: cereb_5xFAD_m2_FAD231)
# OzOFF file without match: df_analysis_5_cortex_5xFAD_m1_FAD249_OFF.parquet (Key: cortex_5xFAD_m1_FAD249)
# OzOFF file without match: df_analysis_5_hippo_WT_m5_FAD263_OFF.parquet (Key: hippo_WT_m5_FAD263)
# OzOFF file without match: df_analysis_5_cortex_WT_m5_FAD259_OFF.parquet (Key: cortex_WT_m5_FAD259)
# OzOFF file without match: df_analysis_5_hippo_5xFAD_m1_FAD231_OFF.parquet (Key: hippo_5xFAD_m1_FAD231)
# OzOFF file without match: df_analysis_5_hippo_WT_m4_FAD263_OFF.parquet (Key: hippo_WT_m4_FAD263)
# OzOFF file without match: df_analysis_5_dienc_WT_m2_FAD249_OFF.parquet (Key: dienc_WT_m2_FAD249)
# OzOFF file without match: df_analysis_5_dienc_5xFAD_m2_FAD257_OFF.parquet (Key: dienc_5xFAD_m2_FAD257)
# OzOFF file without match: df_analysis_5_cortex_WT_m2_FAD249_OFF.parquet (Key: cortex_WT_m2_FAD249)
# OzOFF file without match: df_analysis_5_cereb_WT_m5_FAD263_OFF.parquet (Key: cereb_WT_m5_FAD263)
# OzOFF file without match: df_analysis_5_dienc_WT_m5_FAD259_OFF.parquet (Key: dienc_WT_m5_FAD259)
# OzOFF file without match: df_analysis_5_hippo_WT_m3_FAD263_OFF.parquet (Key: hippo_WT_m3_FAD263)
# OzOFF file without match: df_analysis_5_dienc_WT_m1_FAD245_OFF.parquet (Key: dienc_WT_m1_FAD245)
# OzOFF file without match: df_analysis_5_dienc_5xFAD_m2_FAD231_OFF.parquet (Key: dienc_5xFAD_m2_FAD231)
# OzOFF file without match: df_analysis_5_dienc_WT_m4_FAD263_OFF.parquet (Key: dienc_WT_m4_FAD263)
# OzOFF file without match: df_analysis_5_cereb_5xFAD_m1_FAD231_OFF.parquet (Key: cereb_5xFAD_m1_FAD231)
# OzOFF file without match: df_analysis_5_cortex_WT_m3_FAD263_OFF.parquet (Key: cortex_WT_m3_FAD263)
# OzOFF file without match: df_analysis_5_Unknown_OFF.parquet (Key: Unknown_OFF)
# OzOFF file without match: df_analysis_5_dienc_5xFAD_m1_FAD249_OFF.parquet (Key: dienc_5xFAD_m1_FAD249)
# OzOFF file without match: df_analysis_5_dienc_WT_m3_FAD263_OFF.parquet (Key: dienc_WT_m3_FAD263)
# OzOFF file without match: df_analysis_5_cortex_WT_m4_FAD263_OFF.parquet (Key: cortex_WT_m4_FAD263)
# OzOFF file without match: df_analysis_5_cortex_WT_m1_FAD245_OFF.parquet (Key: cortex_WT_m1_FAD245)
# OzOFF file without match: df_analysis_5_cortex_5xFAD_m1_FAD231_OFF.parquet (Key: cortex_5xFAD_m1_FAD231)
# Log saved to: Projects/AMP/notpossible_8/log/hippo_WT_m1_FAD245_notpossibleLOG.txt

# %% [markdown]
# # NOT POSSIBLE

# %%
matched_lipids_df
# Out:
#                Lipid  Retention_Time  OzESI_Intensity  group_by_ion  \
# 51  FA(16:1)_<>_n-2         6.892800        1008466.0            25
# 58  FA(16:1)_<>_n-2         6.892800        1008466.0            25
# 52  FA(16:1)_<>_n-2         6.970317         608811.0            25
# 59  FA(16:1)_<>_n-2         6.970317         608811.0            25
#
#     group_by_lipid                                          Sample_ID  \
# 51              86  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 58              86  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 52              86  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 59              86  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
#
#         Transition              Sample  Parent_Ion  Product_Ion  ... Genotype  \
# 51  409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...       WT
# 58  409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...       WT
# 52  409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...       WT
# 59  409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...       WT
#
#       Cage Mouse  n_value  Adjusted_RT  n_position  OzOFF_Isomer  \
# 51  FAD245    m1        2     6.931567           2           2.0
# 58  FAD245    m1        2     6.931567           2           1.0
# 52  FAD245    m1        2     7.009083           2           2.0
# 59  FAD245    m1        2     7.009083           2           1.0
#
#     Matched_Lipid_OFF Intensity_OFF  Retention_Time_OFF
# 51    FA(16:1)_<>_n-2     1668488.0            6.918667
# 58    FA(16:1)_<>_n-2     1668488.0            6.918667
# 52    FA(16:1)_<>_n-2     1668488.0            6.918667
# 59    FA(16:1)_<>_n-2     1668488.0            6.918667
#
# [4 rows x 35 columns]

# %% [markdown]
# # POSSIBLE

# %%
unmatched_lipids_df
# Out:
#                 Lipid  Retention_Time  OzESI_Intensity  group_by_ion  \
# 57  FA(16:1)_<>_n-10         7.039200           2658.0             4
# 60   FA(16:1)_<>_n-3         6.854850          10899.0            21
# 53   FA(16:1)_<>_n-5         7.062800            553.0            15
# 54   FA(16:1)_<>_n-6         7.063417            920.0            12
# 55   FA(16:1)_<>_n-7         6.921700           2359.0            10
# 62   FA(16:1)_<>_n-7         6.921700           2359.0            10
# 61   FA(16:1)_<>_n-7         6.831267           1788.0            10
# 63   FA(16:1)_<>_n-8         6.870433            820.0             8
# 56   FA(16:1)_<>_n-9         6.922517            672.0             6
# 64   FA(16:1)_<>_n-9         6.922517            672.0             6
#
#     group_by_lipid                                          Sample_ID  \
# 57              81  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 60              87  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 53              89  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 54              90  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 55              91  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 62              91  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 61              91  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 63              92  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 56              93  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 64              93  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
#
#         Transition              Sample  Parent_Ion  Product_Ion  ... Genotype  \
# 57  297.2 -> 183.0  hippo_WT_m1_FAD245       297.2        183.0  ...       WT
# 60  395.3 -> 183.0  hippo_WT_m1_FAD245       395.3        183.0  ...       WT
# 53  367.3 -> 183.0  hippo_WT_m1_FAD245       367.3        183.0  ...       WT
# 54  353.3 -> 183.0  hippo_WT_m1_FAD245       353.3        183.0  ...       WT
# 55  339.3 -> 183.0  hippo_WT_m1_FAD245       339.3        183.0  ...       WT
# 62  339.3 -> 183.0  hippo_WT_m1_FAD245       339.3        183.0  ...       WT
# 61  339.3 -> 183.0  hippo_WT_m1_FAD245       339.3        183.0  ...       WT
# 63  325.2 -> 183.0  hippo_WT_m1_FAD245       325.2        183.0  ...       WT
# 56  311.3 -> 183.0  hippo_WT_m1_FAD245       311.3        183.0  ...       WT
# 64  311.3 -> 183.0  hippo_WT_m1_FAD245       311.3        183.0  ...       WT
#
#       Cage Mouse  n_value  Adjusted_RT  n_position  OzOFF_Isomer  \
# 57  FAD245    m1       10     7.077967          10           2.0
# 60  FAD245    m1        3     6.893617           3           1.0
# 53  FAD245    m1        5     7.101567           5           2.0
# 54  FAD245    m1        6     7.102183           6           2.0
# 55  FAD245    m1        7     6.960467           7           2.0
# 62  FAD245    m1        7     6.960467           7           1.0
# 61  FAD245    m1        7     6.870033           7           1.0
# 63  FAD245    m1        8     6.909200           8           1.0
# 56  FAD245    m1        9     6.961283           9           2.0
# 64  FAD245    m1        9     6.961283           9           1.0
#
#     Matched_Lipid_OFF Intensity_OFF  Retention_Time_OFF
# 57               None          None                None
# 60               None          None                None
# 53               None          None                None
# 54               None          None                None
# 55               None          None                None
# 62               None          None                None
# 61               None          None                None
# 63               None          None                None
# 56               None          None                None
# 64               None          None                None
#
# [10 rows x 35 columns]

# %%
import pandas as pd
yes = pd.read_parquet('Projects/AMP/notpossible_8/yes/hippo_WT_m1_FAD245_notpossible_yes.parquet')
yes
# Out:
#                    Lipid  Retention_Time  OzESI_Intensity  group_by_ion  \
# 0       FA(13:1)_<>_n-4         4.776933            631.0            10
# 1       FA(16:1)_<>_n-5         7.062800            553.0            15
# 2       FA(16:1)_<>_n-6         7.063417            920.0            12
# 3       FA(16:1)_<>_n-9         6.922517            672.0             6
# 4      FA(16:1)_<>_n-10         7.039200           2658.0             4
# 5       FA(16:1)_<>_n-3         6.854850          10899.0            21
# 6       FA(16:1)_<>_n-8         6.870433            820.0             8
# 7       FA(16:1)_<>_n-9         6.922517            672.0             6
# 8      FA(16:2)_<F>_n-5         5.822467            515.0            15
# 9     FA(16:2)_<F>_n-10         6.160617            604.0             4
# 10      FA(18:1)_<>_n-4         8.843783           1185.0            25
# 11      FA(18:1)_<>_n-6         8.819367           3424.0            18
# 12      FA(18:1)_<>_n-7         8.832900           6990.0            15
# 13      FA(18:1)_<>_n-8         8.872283          17293.0            12
# 14   FA(18:4)_<BFF>_n-3         6.026733            581.0            27
# 15   FA(18:4)_<BFF>_n-3         6.143017            638.0            27
# 16   FA(18:4)_<FFF>_n-6         6.222383            505.0            18
# 17   FA(18:4)_<FFF>_n-8         6.197767            540.0            12
# 18  FA(18:4)_<FFF>_n-10         6.185650            534.0             8
# 19  FA(18:4)_<FFF>_n-12         6.160617            604.0             4
# 20   FA(18:4)_<FFF>_n-4         5.639533            549.0            25
#
#     group_by_lipid                                          Sample_ID  \
# 0               32  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 1               89  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 2               90  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 3               93  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 4               81  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 5               87  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 6               92  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 7               93  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 8              109  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 9              101  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 10             137  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 11             139  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 12             140  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 13             141  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 14             204  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 15             204  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 16             219  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 17             221  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 18             210  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 19             212  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
# 20             217  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...
#
#         Transition              Sample  Parent_Ion  Product_Ion  ... Genotype  \
# 0   339.3 -> 183.0  hippo_WT_m1_FAD245       339.3        183.0  ...       WT
# 1   367.3 -> 183.0  hippo_WT_m1_FAD245       367.3        183.0  ...       WT
# 2   353.3 -> 183.0  hippo_WT_m1_FAD245       353.3        183.0  ...       WT
# 3   311.3 -> 183.0  hippo_WT_m1_FAD245       311.3        183.0  ...       WT
# 4   297.2 -> 183.0  hippo_WT_m1_FAD245       297.2        183.0  ...       WT
# 5   395.3 -> 183.0  hippo_WT_m1_FAD245       395.3        183.0  ...       WT
# 6   325.2 -> 183.0  hippo_WT_m1_FAD245       325.2        183.0  ...       WT
# 7   311.3 -> 183.0  hippo_WT_m1_FAD245       311.3        183.0  ...       WT
# 8   367.3 -> 183.0  hippo_WT_m1_FAD245       367.3        183.0  ...       WT
# 9   297.2 -> 183.0  hippo_WT_m1_FAD245       297.2        183.0  ...       WT
# 10  409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...       WT
# 11  381.3 -> 183.0  hippo_WT_m1_FAD245       381.3        183.0  ...       WT
# 12  367.3 -> 183.0  hippo_WT_m1_FAD245       367.3        183.0  ...       WT
# 13  353.3 -> 183.0  hippo_WT_m1_FAD245       353.3        183.0  ...       WT
# 14  421.4 -> 183.0  hippo_WT_m1_FAD245       421.4        183.0  ...       WT
# 15  421.4 -> 183.0  hippo_WT_m1_FAD245       421.4        183.0  ...       WT
# 16  381.3 -> 183.0  hippo_WT_m1_FAD245       381.3        183.0  ...       WT
# 17  353.3 -> 183.0  hippo_WT_m1_FAD245       353.3        183.0  ...       WT
# 18  325.2 -> 183.0  hippo_WT_m1_FAD245       325.2        183.0  ...       WT
# 19  297.2 -> 183.0  hippo_WT_m1_FAD245       297.2        183.0  ...       WT
# 20  409.3 -> 183.0  hippo_WT_m1_FAD245       409.3        183.0  ...       WT
#
#       Cage Mouse  n_value  Adjusted_RT  n_position  OzOFF_Isomer  \
# 0   FAD245    m1        4     4.815700           4           2.0
# 1   FAD245    m1        5     7.101567           5           2.0
# 2   FAD245    m1        6     7.102183           6           2.0
# 3   FAD245    m1        9     6.961283           9           2.0
# 4   FAD245    m1       10     7.077967          10           2.0
# 5   FAD245    m1        3     6.893617           3           1.0
# 6   FAD245    m1        8     6.909200           8           1.0
# 7   FAD245    m1        9     6.961283           9           1.0
# 8   FAD245    m1        5     5.861233           5           1.0
# 9   FAD245    m1       10     6.199383          10           2.0
# 10  FAD245    m1        4     8.882550           4           2.0
# 11  FAD245    m1        6     8.858133           6           2.0
# 12  FAD245    m1        7     8.871667           7           2.0
# 13  FAD245    m1        8     8.911050           8           2.0
# 14  FAD245    m1        3     6.065500           3           2.0
# 15  FAD245    m1        3     6.181783           3           2.0
# 16  FAD245    m1        6     6.261150           6           2.0
# 17  FAD245    m1        8     6.236533           8           2.0
# 18  FAD245    m1       10     6.224417          10           2.0
# 19  FAD245    m1       12     6.199383          12           2.0
# 20  FAD245    m1        4     5.678300           4           1.0
#
#     Matched_Lipid_OFF Intensity_OFF  Retention_Time_OFF
# 0                None          None                None
# 1                None          None                None
# 2                None          None                None
# 3                None          None                None
# 4                None          None                None
# 5                None          None                None
# 6                None          None                None
# 7                None          None                None
# 8                None          None                None
# 9                None          None                None
# 10               None          None                None
# 11               None          None                None
# 12               None          None                None
# 13               None          None                None
# 14               None          None                None
# 15               None          None                None
# 16               None          None                None
# 17               None          None                None
# 18               None          None                None
# 19               None          None                None
# 20               None          None                None
#
# [21 rows x 35 columns]

# %% [markdown]
# # max intensity OzOFf possible

# %%
# def get_highest_intensity_per_lipid(df):
#     """
#     This function returns the rows with the highest OzESI_Intensity for each unique Lipid.

#     Parameters:
#     df (pd.DataFrame): The DataFrame containing 'Lipid' and 'OzESI_Intensity' columns.

#     Returns:
#     pd.DataFrame: A DataFrame containing the rows with the highest intensity for each lipid.
#     """
#     # Group by 'Lipid' and get the row with the highest 'OzESI_Intensity' for each lipid
#     highest_intensity_df = df.loc[df.groupby('Lipid')['OzESI_Intensity'].idxmax()]

#     return highest_intensity_df

# # Assuming df is your DataFrame
# df_highest_intensity = get_highest_intensity_per_lipid(df)
# #df_highest_intensity.to_parquet('Projects/STD/analysis/OFF/df_analysis_5_FAME_OFF_max.parquet')

# df_highest_intensity.tail(10)

# %% [markdown]
# # get top 2 unsaturated lipids + add isomer column

# %%
# import pandas as pd
# import re

# def get_top_n_intensity_for_specific_fa(df, n=2):
#     """
#     This function returns the top N rows with the highest OzESI_Intensity for lipids that match the pattern FA(##:#) 
#     where the number after ':' is not 0 (e.g., FA(18:1), FA(16:2)). It also adds an 'Isomer' column to track the order
#     of lipids with the same name based on 'Retention_Time'. Additionally, it prints a list of lipids that have 2 or more isomers.

#     Parameters:
#     df (pd.DataFrame): The DataFrame containing 'Lipid', 'OzESI_Intensity', and 'Retention_Time' columns.
#     n (int): The number of top rows to return for each lipid based on intensity.

#     Returns:
#     pd.DataFrame: A DataFrame containing the top N rows with the highest intensity for each lipid matching the pattern,
#     and an additional 'Isomer' column that indicates the order based on 'Retention_Time'. It also prints a list of lipids
#     that have 2 or more isomers.
#     """
#     # Define the regex pattern for FA(##:#) where the number after ':' is not 0
#     pattern = r'FA\(\d+:(?!0)\d+\)'

#     # Filter the DataFrame to only include rows where the Lipid column matches the pattern
#     df_filtered = df[df['Lipid'].apply(lambda x: bool(re.match(pattern, x)))] 

#     # Sort by 'Lipid' and 'OzESI_Intensity' in descending order
#     df_sorted = df_filtered.sort_values(by=['Lipid', 'OzESI_Intensity'], ascending=[True, False])
    
#     # Select the top N entries for each 'Lipid'
#     top_n_intensity_df = df_sorted.groupby('Lipid').head(n).reset_index(drop=True)
    
#     # Sort by 'Lipid' and 'Retention_Time' to assign the Isomer number
#     top_n_intensity_df['Isomer'] = top_n_intensity_df.groupby('Lipid')['Retention_Time'].rank(method='first').astype(int)

#     # Find lipids that have 2 or more isomers
#     lipids_with_isomers = top_n_intensity_df.groupby('Lipid').filter(lambda x: x['Isomer'].nunique() >= 2)['Lipid'].unique().tolist()

#     # Print out the lipids with 2 or more isomers
#     print("Lipids with 2 or more isomers:", lipids_with_isomers)

#     return top_n_intensity_df

# off_dir = 'Projects/AMP/analysis/OFF/'
# sav_dir = 'Projects/AMP/analysis/OFF/off_possible/'

# # Assuming df is your DataFrame
# df_top_2_intensity_specific_fa = get_top_n_intensity_for_specific_fa(df, n=2)

# df_top_2_intensity_specific_fa

# %% [markdown]
# # OFF possible function

# %%
import pandas as pd
import re
import glob
import os

def get_top_n_intensity_for_specific_fa(df, n=2, intensity_threshold=1000, retention_time_window=(1, 20)):
    """
    This function returns the top N rows with the highest OzESI_Intensity for lipids that match the pattern FA(##:#) 
    where the number after ':' is not 0 (e.g., FA(18:1), FA(16:2)). It also adds an 'Isomer' column to track the order
    of lipids with the same name based on 'Retention_Time'. Additionally, it prints a list of lipids that have 2 or more isomers.

    The function also applies a threshold filter on OzESI_Intensity and filters Retention_Time within the specified window.

    Parameters:
    df (pd.DataFrame): The DataFrame containing 'Lipid', 'OzESI_Intensity', and 'Retention_Time' columns.
    n (int): The number of top rows to return for each lipid based on intensity.
    intensity_threshold (float): The minimum value for OzESI_Intensity to consider a row.
    retention_time_window (tuple): A tuple specifying the (min, max) range for Retention_Time.

    Returns:
    pd.DataFrame: A DataFrame containing the top N rows with the highest intensity for each lipid matching the pattern,
    and an additional 'Isomer' column that indicates the order based on 'Retention_Time'. It also prints a list of lipids
    that have 2 or more isomers.
    """
    # Define the regex pattern for FA(##:#) where the number after ':' is not 0
    pattern = r'FA\(\d+:(?!0)\d+\)'

    # Filter the DataFrame to only include rows where the Lipid column matches the pattern
    df_filtered = df[df['Lipid'].apply(lambda x: bool(re.match(pattern, x)))]

    # Apply the OzESI_Intensity threshold and the Retention_Time window filter
    df_filtered = df_filtered[
        (df_filtered['OzESI_Intensity'] >= intensity_threshold) &
        (df_filtered['Retention_Time'] >= retention_time_window[0]) &
        (df_filtered['Retention_Time'] <= retention_time_window[1])
    ]

    # Sort by 'Lipid' and 'OzESI_Intensity' in descending order
    df_sorted = df_filtered.sort_values(by=['Lipid', 'OzESI_Intensity'], ascending=[True, False])

    # Select the top N entries for each 'Lipid'
    top_n_intensity_df = df_sorted.groupby('Lipid').head(n).reset_index(drop=True)

    # Sort by 'Lipid' and 'Retention_Time' to assign the Isomer number
    top_n_intensity_df['Isomer'] = top_n_intensity_df.groupby('Lipid')['Retention_Time'].rank(method='first').astype(int)

    # Find lipids that have 2 or more isomers
    lipids_with_isomers = top_n_intensity_df.groupby('Lipid').filter(lambda x: x['Isomer'].nunique() >= 2)['Lipid'].unique().tolist()

    # Print out the lipids with 2 or more isomers
    print("Lipids with 2 or more isomers:", lipids_with_isomers)

    return top_n_intensity_df

def get_all_fa(df, intensity_threshold=1000, retention_time_window=(1, 20)):
    """
    This function returns all rows with OzESI_Intensity above a given threshold and within a specified Retention_Time window.

    Parameters:
    df (pd.DataFrame): The DataFrame containing 'Lipid', 'OzESI_Intensity', and 'Retention_Time' columns.
    intensity_threshold (float): The minimum value for OzESI_Intensity to consider a row.
    retention_time_window (tuple): A tuple specifying the (min, max) range for Retention_Time.

    Returns:
    pd.DataFrame: A DataFrame containing all rows with OzESI_Intensity above the threshold and within the Retention_Time window.
    """
    # Apply the OzESI_Intensity threshold and the Retention_Time window filter
    df_filtered = df[
        (df['OzESI_Intensity'] >= intensity_threshold) &
        (df['Retention_Time'] >= retention_time_window[0]) &
        (df['Retention_Time'] <= retention_time_window[1])
    ]
    return df_filtered

def get_top_n_intensity_for_all_fa(df, n=2, intensity_threshold=1000, retention_time_window=(1, 20)):
    """
    This function returns the top N rows with the highest OzESI_Intensity for all lipids, including those with FA(##:0).
    It also adds an 'Isomer' column to track the order of lipids with the same name based on 'Retention_Time'.

    Parameters:
    df (pd.DataFrame): The DataFrame containing 'Lipid', 'OzESI_Intensity', and 'Retention_Time' columns.
    n (int): The number of top rows to return for each lipid based on intensity.
    intensity_threshold (float): The minimum value for OzESI_Intensity to consider a row.
    retention_time_window (tuple): A tuple specifying the (min, max) range for Retention_Time.

    Returns:
    pd.DataFrame: A DataFrame containing the top N rows with the highest intensity for each lipid,
    and an additional 'Isomer' column that indicates the order based on 'Retention_Time'.
    """
    # Apply the OzESI_Intensity threshold and the Retention_Time window filter
    df_filtered = df[
        (df['OzESI_Intensity'] >= intensity_threshold) &
        (df['Retention_Time'] >= retention_time_window[0]) &
        (df['Retention_Time'] <= retention_time_window[1])
    ]

    # Sort by 'Lipid' and 'OzESI_Intensity' in descending order
    df_sorted = df_filtered.sort_values(by=['Lipid', 'OzESI_Intensity'], ascending=[True, False])

    # Select the top N entries for each 'Lipid'
    top_n_intensity_df = df_sorted.groupby('Lipid').head(n).reset_index(drop=True)

    # Sort by 'Lipid' and 'Retention_Time' to assign the Isomer number
    top_n_intensity_df['Isomer'] = top_n_intensity_df.groupby('Lipid')['Retention_Time'].rank(method='first').astype(int)

    return top_n_intensity_df

# Directories for input and output
off_dir = 'Projects/AMP/analysis/OFF/'
sav_dir = 'Projects/AMP/analysis/OFF/off_possible/'
sav_all_dir = 'Projects/AMP/analysis/OFF/all_lipids/all/'
sav_all_top2_dir = 'Projects/AMP/analysis/OFF/all_lipids/top2/'

# Ensure the save directories exist
os.makedirs(sav_dir, exist_ok=True)
os.makedirs(sav_all_dir, exist_ok=True)
os.makedirs(sav_all_top2_dir, exist_ok=True)

# Get a list of all parquet files in the off_dir
parquet_files = glob.glob(os.path.join(off_dir, '*.parquet'))

# Define thresholds for OzESI_Intensity and Retention_Time window
intensity_threshold = 1000  # Set the desired threshold for OzESI_Intensity
retention_time_window = (1, 20)  # Set the desired Retention_Time window (min, max)

# Iterate through each parquet file
for file_path in parquet_files:
    # Load the parquet file into a DataFrame
    df = pd.read_parquet(file_path)

    # Apply the function to get the top N intensity FA rows
    df_top_n = get_top_n_intensity_for_specific_fa(df, n=2, intensity_threshold=intensity_threshold, retention_time_window=retention_time_window)

    # Generate the new file name by appending '_offpossible' to the original file name
    base_name = os.path.basename(file_path).replace('.parquet', '_offpossible.parquet')
    save_path = os.path.join(sav_dir, base_name)

    # Save the updated DataFrame to a new parquet file
    df_top_n.to_parquet(save_path)

    print(f"Processed and saved: {save_path}")

    # Apply the function to get all FA rows
    df_all = get_all_fa(df, intensity_threshold=intensity_threshold, retention_time_window=retention_time_window)

    # Generate the new file name by appending '_alllipids' to the original file name
    base_name_all = os.path.basename(file_path).replace('.parquet', '_alllipids.csv')
    save_all_path = os.path.join(sav_all_dir, base_name_all)

    # Save the updated DataFrame to a new CSV file
    df_all.to_csv(save_all_path, index=False)

    print(f"Processed and saved: {save_all_path}")

    # Apply the function to get the top N intensity for all FA rows
    df_all_top_n = get_top_n_intensity_for_all_fa(df, n=2, intensity_threshold=intensity_threshold, retention_time_window=retention_time_window)

    # Generate the new file name by appending '_alllipids_top2' to the original file name
    base_name_all_top2 = os.path.basename(file_path).replace('.parquet', '_alllipids_top2.csv')
    save_all_top2_path = os.path.join(sav_all_top2_dir, base_name_all_top2)

    # Save the updated DataFrame to a new CSV file
    df_all_top_n.to_csv(save_all_top2_path, index=False)

    print(f"Processed and saved: {save_all_top2_path}")
# Out:
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:3)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_cereb_WT_m5_FAD259_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_cereb_WT_m5_FAD259_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_cereb_WT_m5_FAD259_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(14:3)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:3)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_cereb_5xFAD_m1_FAD249_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_cereb_5xFAD_m1_FAD249_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_cereb_5xFAD_m1_FAD249_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(15:2)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:3)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_cortex_5xFAD_m1_FAD231_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_cortex_5xFAD_m1_FAD231_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_cortex_5xFAD_m1_FAD231_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_cortex_WT_m5_FAD263_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_cortex_WT_m5_FAD263_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_cortex_WT_m5_FAD263_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:5)', 'FA(22:6)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_dienc_WT_m5_FAD263_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_dienc_WT_m5_FAD263_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_dienc_WT_m5_FAD263_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(20:1)', 'FA(20:5)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_cereb_WT_m2_FAD246_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_cereb_WT_m2_FAD246_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_cereb_WT_m2_FAD246_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:3)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_hippo_5xFAD_m2_FAD257_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_hippo_5xFAD_m2_FAD257_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_hippo_5xFAD_m2_FAD257_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(12:2)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_dienc_5xFAD_m1_FAD231_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_dienc_5xFAD_m1_FAD231_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_dienc_5xFAD_m1_FAD231_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:5)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_cereb_5xFAD_m2_FAD231_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_cereb_5xFAD_m2_FAD231_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_cereb_5xFAD_m2_FAD231_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:3)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_hippo_WT_m5_FAD263_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_hippo_WT_m5_FAD263_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_hippo_WT_m5_FAD263_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(20:1)', 'FA(20:5)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_Unknown_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_Unknown_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_Unknown_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_hippo_5xFAD_m1_FAD249_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_hippo_5xFAD_m1_FAD249_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_hippo_5xFAD_m1_FAD249_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(12:2)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(15:3)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:3)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_cereb_WT_m3_FAD263_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_cereb_WT_m3_FAD263_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_cereb_WT_m3_FAD263_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:3)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_cereb_5xFAD_m2_FAD257_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_cereb_5xFAD_m2_FAD257_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_cereb_5xFAD_m2_FAD257_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:3)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_hippo_5xFAD_m2_FAD231_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_hippo_5xFAD_m2_FAD231_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_hippo_5xFAD_m2_FAD231_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(15:3)', 'FA(16:1)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:3)', 'FA(22:1)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_cereb_WT_m4_FAD263_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_cereb_WT_m4_FAD263_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_cereb_WT_m4_FAD263_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:5)', 'FA(22:6)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_cereb_WT_m1_FAD245_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_cereb_WT_m1_FAD245_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_cereb_WT_m1_FAD245_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:3)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_dienc_WT_m5_FAD259_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_dienc_WT_m5_FAD259_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_dienc_WT_m5_FAD259_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:4)', 'FA(20:5)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_dienc_5xFAD_m2_FAD231_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_dienc_5xFAD_m2_FAD231_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_dienc_5xFAD_m2_FAD231_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:3)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_cortex_WT_m5_FAD259_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_cortex_WT_m5_FAD259_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_cortex_WT_m5_FAD259_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(11:2)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:3)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_hippo_WT_m3_FAD263_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_hippo_WT_m3_FAD263_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_hippo_WT_m3_FAD263_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(14:3)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:3)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_cortex_5xFAD_m1_FAD249_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_cortex_5xFAD_m1_FAD249_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_cortex_5xFAD_m1_FAD249_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:4)', 'FA(20:5)', 'FA(22:6)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_cereb_5xFAD_m1_FAD231_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_cereb_5xFAD_m1_FAD231_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_cereb_5xFAD_m1_FAD231_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(12:2)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(15:2)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:3)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_cereb_WT_m5_FAD263_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_cereb_WT_m5_FAD263_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_cereb_WT_m5_FAD263_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_cortex_WT_m2_FAD249_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_cortex_WT_m2_FAD249_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_cortex_WT_m2_FAD249_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:4)', 'FA(20:5)', 'FA(22:6)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_dienc_WT_m2_FAD249_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_dienc_WT_m2_FAD249_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_dienc_WT_m2_FAD249_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_hippo_WT_m1_FAD245_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_hippo_WT_m1_FAD245_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_hippo_WT_m1_FAD245_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:3)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_dienc_5xFAD_m1_FAD249_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_dienc_5xFAD_m1_FAD249_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_dienc_5xFAD_m1_FAD249_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_hippo_WT_m4_FAD263_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_hippo_WT_m4_FAD263_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_hippo_WT_m4_FAD263_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:4)', 'FA(20:5)', 'FA(22:6)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_cortex_5xFAD_m2_FAD231_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_cortex_5xFAD_m2_FAD231_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_cortex_5xFAD_m2_FAD231_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_dienc_5xFAD_m2_FAD257_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_dienc_5xFAD_m2_FAD257_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_dienc_5xFAD_m2_FAD257_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(17:4)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:3)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:2)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_cortex_WT_m3_FAD263_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_cortex_WT_m3_FAD263_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_cortex_WT_m3_FAD263_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:3)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:2)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_dienc_WT_m3_FAD263_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_dienc_WT_m3_FAD263_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_dienc_WT_m3_FAD263_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_hippo_WT_m5_FAD259_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_hippo_WT_m5_FAD259_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_hippo_WT_m5_FAD259_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(12:2)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_hippo_5xFAD_m1_FAD231_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_hippo_5xFAD_m1_FAD231_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_hippo_5xFAD_m1_FAD231_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_cortex_5xFAD_m2_FAD257_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_cortex_5xFAD_m2_FAD257_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_cortex_5xFAD_m2_FAD257_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:3)', 'FA(20:4)', 'FA(22:1)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_cortex_WT_m4_FAD263_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_cortex_WT_m4_FAD263_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_cortex_WT_m4_FAD263_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(12:2)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(15:3)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(17:4)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:3)', 'FA(20:5)', 'FA(22:1)', 'FA(22:2)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_dienc_WT_m4_FAD263_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_dienc_WT_m4_FAD263_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_dienc_WT_m4_FAD263_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:5)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_cortex_WT_m1_FAD245_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_cortex_WT_m1_FAD245_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_cortex_WT_m1_FAD245_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(20:1)', 'FA(20:4)', 'FA(20:5)', 'FA(22:6)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_hippo_WT_m2_FAD249_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_hippo_WT_m2_FAD249_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_hippo_WT_m2_FAD249_OFF_alllipids_top2.csv
# Lipids with 2 or more isomers: ['FA(10:1)', 'FA(12:1)', 'FA(13:1)', 'FA(14:1)', 'FA(15:1)', 'FA(16:1)', 'FA(16:2)', 'FA(17:1)', 'FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(18:4)', 'FA(20:1)', 'FA(20:2)', 'FA(20:4)', 'FA(20:5)', 'FA(22:1)', 'FA(22:6)', 'FA(8:1)', 'FA(9:1)']
# Processed and saved: Projects/AMP/analysis/OFF/off_possible/df_analysis_5_dienc_WT_m1_FAD245_OFF_offpossible.parquet
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/all/df_analysis_5_dienc_WT_m1_FAD245_OFF_alllipids.csv
# Processed and saved: Projects/AMP/analysis/OFF/all_lipids/top2/df_analysis_5_dienc_WT_m1_FAD245_OFF_alllipids_top2.csv

# %%
import pandas as pd
test_df = pd.read_parquet('Projects/AMP/analysis/OFF/off_possible/df_analysis_5_hippo_WT_m1_FAD245_OFF_offpossible.parquet')
test_df.to_csv('Projects/AMP/analysis/OFF/off_possible/csv/df_analysis_5_hippo_WT_m1_FAD245_OFF_offpossible.csv')
test_df
# Out:
#        Lipid  Retention_Time  OzESI_Intensity  group_by_ion  group_by_lipid  \
# 0   FA(10:1)        4.027767          11770.0            10               2
# 1   FA(10:1)        3.821050           8518.0            10               2
# 2   FA(12:1)        4.323917           8993.0            15               6
# 3   FA(12:1)        3.341967           6903.0            15               6
# 4   FA(12:2)        3.600583           1352.0            14               7
# 5   FA(13:1)        4.762600           6474.0            18               9
# 6   FA(13:1)        3.548083           6441.0            18               9
# 7   FA(14:1)        5.420933          36158.0            21              12
# 8   FA(14:1)        5.278800          18294.0            21              12
# 9   FA(15:1)        6.182417          30465.0            25              15
# 10  FA(15:1)        6.040283           7407.0            25              15
# 11  FA(15:3)        3.353250           5271.0            23              17
# 12  FA(16:1)        7.073300         350654.0            28              19
# 13  FA(16:1)        6.879483          79974.0            28              19
# 14  FA(16:2)        5.988200           1953.0            27              20
# 15  FA(16:2)        6.065717           1923.0            27              20
# 16  FA(17:1)        7.834783         115040.0            32              22
# 17  FA(17:1)        7.976900          65443.0            32              22
# 18  FA(18:1)        8.660650        1434622.0            37              25
# 19  FA(18:1)        8.957817         549631.0            37              25
# 20  FA(18:2)        7.510933         133767.0            36              26
# 21  FA(18:2)        7.833950          71565.0            36              26
# 22  FA(18:3)        4.126017          37741.0            35              27
# 23  FA(18:3)        6.567967           5892.0            35              27
# 24  FA(18:4)        6.115950           7939.0            34              28
# 25  FA(18:4)        5.702500           5727.0            34              28
# 26  FA(20:1)       10.842733          12856.0            44              31
# 27  FA(20:1)       10.532633          11239.0            44              31
# 28  FA(20:2)        9.641350           4741.0            43              32
# 29  FA(20:2)        9.460467           3182.0            43              32
# 30  FA(20:3)        8.633767           1301.0            42              33
# 31  FA(20:4)        7.561583          10954.0            41              34
# 32  FA(20:4)        7.807083           1446.0            41              34
# 33  FA(20:5)        5.895067          81363.0            40              35
# 34  FA(20:5)        6.101800          54076.0            40              35
# 35  FA(22:1)       12.405067           5463.0            49              38
# 36  FA(22:1)       12.805600           4194.0            49              38
# 37  FA(22:6)        7.521583          16442.0            47              40
# 38  FA(22:6)        6.074517           5730.0            47              40
# 39   FA(8:1)        3.576367          47449.0             6              48
# 40   FA(8:1)        3.369633           3364.0             6              48
# 41   FA(9:1)        3.563033          13749.0             8              50
# 42   FA(9:1)        3.705167          10479.0             8              50
#
#                                             Sample_ID      Transition  \
# 0   11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  337.2 -> 183.0
# 1   11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  337.2 -> 183.0
# 2   11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  365.2 -> 183.0
# 3   11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  365.2 -> 183.0
# 4   11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  363.3 -> 183.0
# 5   11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  379.3 -> 183.0
# 6   11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  379.3 -> 183.0
# 7   11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  393.4 -> 183.0
# 8   11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  393.4 -> 183.0
# 9   11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  407.3 -> 183.0
# 10  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  407.3 -> 183.0
# 11  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  403.2 -> 183.0
# 12  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  421.4 -> 183.0
# 13  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  421.4 -> 183.0
# 14  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  419.3 -> 183.0
# 15  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  419.3 -> 183.0
# 16  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  435.4 -> 183.0
# 17  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  435.4 -> 183.0
# 18  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  449.4 -> 183.0
# 19  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  449.4 -> 183.0
# 20  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  447.4 -> 183.0
# 21  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  447.4 -> 183.0
# 22  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  445.4 -> 183.0
# 23  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  445.4 -> 183.0
# 24  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  443.3 -> 183.0
# 25  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  443.3 -> 183.0
# 26  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  477.4 -> 183.0
# 27  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  477.4 -> 183.0
# 28  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  475.4 -> 183.0
# 29  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  475.4 -> 183.0
# 30  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  473.4 -> 183.0
# 31  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  471.4 -> 183.0
# 32  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  471.4 -> 183.0
# 33  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  469.4 -> 183.0
# 34  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  469.4 -> 183.0
# 35  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  505.4 -> 183.0
# 36  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  505.4 -> 183.0
# 37  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  495.4 -> 183.0
# 38  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  495.4 -> 183.0
# 39  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  309.1 -> 183.0
# 40  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  309.1 -> 183.0
# 41  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  323.2 -> 183.0
# 42  11162023_WT-m1-hippo-FAD245_AMP_2x_0.05uMd216-...  323.2 -> 183.0
#
#                 Sample  Parent_Ion  Product_Ion Species Class   STD  \
# 0   hippo_WT_m1_FAD245       337.2        183.0    10:1    FA  None
# 1   hippo_WT_m1_FAD245       337.2        183.0    10:1    FA  None
# 2   hippo_WT_m1_FAD245       365.2        183.0    12:1    FA  None
# 3   hippo_WT_m1_FAD245       365.2        183.0    12:1    FA  None
# 4   hippo_WT_m1_FAD245       363.3        183.0    12:2    FA  None
# 5   hippo_WT_m1_FAD245       379.3        183.0    13:1    FA  None
# 6   hippo_WT_m1_FAD245       379.3        183.0    13:1    FA  None
# 7   hippo_WT_m1_FAD245       393.4        183.0    14:1    FA  None
# 8   hippo_WT_m1_FAD245       393.4        183.0    14:1    FA  None
# 9   hippo_WT_m1_FAD245       407.3        183.0    15:1    FA  None
# 10  hippo_WT_m1_FAD245       407.3        183.0    15:1    FA  None
# 11  hippo_WT_m1_FAD245       403.2        183.0    15:3    FA  None
# 12  hippo_WT_m1_FAD245       421.4        183.0    16:1    FA  None
# 13  hippo_WT_m1_FAD245       421.4        183.0    16:1    FA  None
# 14  hippo_WT_m1_FAD245       419.3        183.0    16:2    FA  None
# 15  hippo_WT_m1_FAD245       419.3        183.0    16:2    FA  None
# 16  hippo_WT_m1_FAD245       435.4        183.0    17:1    FA  None
# 17  hippo_WT_m1_FAD245       435.4        183.0    17:1    FA  None
# 18  hippo_WT_m1_FAD245       449.4        183.0    18:1    FA  None
# 19  hippo_WT_m1_FAD245       449.4        183.0    18:1    FA  None
# 20  hippo_WT_m1_FAD245       447.4        183.0    18:2    FA  None
# 21  hippo_WT_m1_FAD245       447.4        183.0    18:2    FA  None
# 22  hippo_WT_m1_FAD245       445.4        183.0    18:3    FA  None
# 23  hippo_WT_m1_FAD245       445.4        183.0    18:3    FA  None
# 24  hippo_WT_m1_FAD245       443.3        183.0    18:4    FA  None
# 25  hippo_WT_m1_FAD245       443.3        183.0    18:4    FA  None
# 26  hippo_WT_m1_FAD245       477.4        183.0    20:1    FA  None
# 27  hippo_WT_m1_FAD245       477.4        183.0    20:1    FA  None
# 28  hippo_WT_m1_FAD245       475.4        183.0    20:2    FA  None
# 29  hippo_WT_m1_FAD245       475.4        183.0    20:2    FA  None
# 30  hippo_WT_m1_FAD245       473.4        183.0    20:3    FA  None
# 31  hippo_WT_m1_FAD245       471.4        183.0    20:4    FA  None
# 32  hippo_WT_m1_FAD245       471.4        183.0    20:4    FA  None
# 33  hippo_WT_m1_FAD245       469.4        183.0    20:5    FA  None
# 34  hippo_WT_m1_FAD245       469.4        183.0    20:5    FA  None
# 35  hippo_WT_m1_FAD245       505.4        183.0    22:1    FA  None
# 36  hippo_WT_m1_FAD245       505.4        183.0    22:1    FA  None
# 37  hippo_WT_m1_FAD245       495.4        183.0    22:6    FA  None
# 38  hippo_WT_m1_FAD245       495.4        183.0    22:6    FA  None
# 39  hippo_WT_m1_FAD245       309.1        183.0     8:1    FA  None
# 40  hippo_WT_m1_FAD245       309.1        183.0     8:1    FA  None
# 41  hippo_WT_m1_FAD245       323.2        183.0     9:1    FA  None
# 42  hippo_WT_m1_FAD245       323.2        183.0     9:1    FA  None
#
#     STD_RT_OFF  Peak_Height      FWHM  Peak_Width      Peak_Area  \
# 0     7.899783      11770.0  0.062611    0.064600     760.342000
# 1     7.899783       8518.0  0.071615    0.077517     660.286967
# 2     7.899783       8993.0  0.086871    0.090450     813.416850
# 3     7.899783       6903.0  0.074065    0.064600     445.933800
# 4     7.899783       1352.0  0.061586    0.064600      87.339200
# 5     7.899783       6474.0  0.091248    0.090450     585.573300
# 6     7.899783       6441.0  0.065524    0.064600     416.088600
# 7     7.899783      36158.0  0.109245    0.103367    3737.531933
# 8     7.899783      18294.0  0.054350    0.051683     945.494900
# 9     7.899783      30465.0  0.080497    0.077517    2361.545250
# 10    7.899783       7407.0  0.046173    0.038750     287.021250
# 11    7.899783       5271.0  0.097363    0.103367     544.845700
# 12    7.899783     350654.0  0.097199    0.103367   36245.935133
# 13    7.899783      79974.0  0.071640    0.064600    5166.320400
# 14    7.899783       1953.0  0.202071    0.193800     378.491400
# 15    7.899783       1923.0  0.034171    0.038750      74.516250
# 16    7.899783     115040.0  0.087041    0.090433   10403.450667
# 17    7.899783      65443.0  0.087596    0.077533    5074.013933
# 18    7.899783    1434622.0  0.110155    0.116283  166822.628233
# 19    7.899783     549631.0  0.127106    0.129200   71012.325200
# 20    7.899783     133767.0  0.085998    0.090450   12099.225150
# 21    7.899783      71565.0  0.060853    0.064617    4624.291750
# 22    7.899783      37741.0  0.060828    0.064617    2438.697617
# 23    7.899783       5892.0  0.074363    0.077517     456.728200
# 24    7.899783       7939.0  0.081898    0.077517     615.404817
# 25    7.899783       5727.0  0.078778    0.077517     443.937950
# 26    7.899783      12856.0  0.544520    0.542667    6976.522667
# 27    7.899783      11239.0  0.096048    0.090450    1016.567550
# 28    7.899783       4741.0  0.100325    0.103350     489.982350
# 29    7.899783       3182.0  0.072038    0.064600     205.557200
# 30    7.899783       1301.0  0.156400    0.155050     201.720050
# 31    7.899783      10954.0  0.096117    0.103367    1132.278467
# 32    7.899783       1446.0  0.032343    0.038767      56.056600
# 33    7.899783      81363.0  0.073080    0.077517    6306.988550
# 34    7.899783      54076.0  0.066729    0.064600    3493.309600
# 35    7.899783       5463.0  0.211311    0.219650    1199.947950
# 36    7.899783       4194.0  0.079347    0.077517     325.104900
# 37    7.899783      16442.0  0.075511    0.064600    1062.153200
# 38    7.899783       5730.0  0.162189    0.167950     962.353500
# 39    7.899783      47449.0  0.060582    0.064600    3065.205400
# 40    7.899783       3364.0  0.071556    0.064600     217.314400
# 41    7.899783      13749.0  0.091465    0.090433    1243.367900
# 42    7.899783      10479.0  0.051105    0.051683     541.589650
#
#      Filter_Column  Isomer
# 0   group_by_lipid       2
# 1   group_by_lipid       1
# 2   group_by_lipid       2
# 3   group_by_lipid       1
# 4   group_by_lipid       1
# 5   group_by_lipid       2
# 6   group_by_lipid       1
# 7   group_by_lipid       2
# 8   group_by_lipid       1
# 9   group_by_lipid       2
# 10  group_by_lipid       1
# 11  group_by_lipid       1
# 12  group_by_lipid       2
# 13  group_by_lipid       1
# 14  group_by_lipid       1
# 15  group_by_lipid       2
# 16  group_by_lipid       1
# 17  group_by_lipid       2
# 18  group_by_lipid       1
# 19  group_by_lipid       2
# 20  group_by_lipid       1
# 21  group_by_lipid       2
# 22  group_by_lipid       1
# 23  group_by_lipid       2
# 24  group_by_lipid       2
# 25  group_by_lipid       1
# 26  group_by_lipid       2
# 27  group_by_lipid       1
# 28  group_by_lipid       2
# 29  group_by_lipid       1
# 30  group_by_lipid       1
# 31  group_by_lipid       1
# 32  group_by_lipid       2
# 33  group_by_lipid       1
# 34  group_by_lipid       2
# 35  group_by_lipid       1
# 36  group_by_lipid       2
# 37  group_by_lipid       2
# 38  group_by_lipid       1
# 39  group_by_lipid       2
# 40  group_by_lipid       1
# 41  group_by_lipid       1
# 42  group_by_lipid       2

# %%
# import pandas as pd
# import re

# def filter_by_lipid_list(df, lipid_list):
#     """
#     This function filters the DataFrame to keep both isomers (Isomer 1 and 2) for lipids in the specified lipid_list.
#     For lipids not in the lipid_list, only the row with the maximum intensity is kept.
#     The resulting DataFrame is sorted by 'Lipid' and 'Retention_Time'.

#     Parameters:
#     df (pd.DataFrame): The DataFrame containing 'Lipid', 'OzESI_Intensity', 'Isomer', and other columns.
#     lipid_list (list): List of lipid names (e.g., ['FA(18:1)', 'FA(18:2)']) for which both isomers should be retained.

#     Returns:
#     pd.DataFrame: A DataFrame with the desired filtering applied and sorted by 'Lipid' and 'Retention_Time'.
#     """
#     # Split the DataFrame into two: one for lipids in the list and one for lipids not in the list
#     df_in_list = df[df['Lipid'].isin(lipid_list)]
#     df_not_in_list = df[~df['Lipid'].isin(lipid_list)]

#     # For lipids not in the list, keep only the row with the maximum OzESI_Intensity
#     df_not_in_list_max = df_not_in_list.loc[df_not_in_list.groupby('Lipid')['OzESI_Intensity'].idxmax()]

#     # Combine the two DataFrames
#     df_filtered = pd.concat([df_in_list, df_not_in_list_max], ignore_index=True)

#     # Sort the resulting DataFrame by 'Lipid' and 'Retention_Time'
#     df_filtered = df_filtered.sort_values(by=['Lipid', 'Retention_Time']).reset_index(drop=True)

#     return df_filtered


# # Define the list of FA lipids for which we want to keep both isomers
# lipid_list = ['FA(18:1)', 'FA(18:2)', 'FA(18:3)', 'FA(20:3)']

# # Apply the filtering function
# df_filtered = filter_by_lipid_list(df_top_2_intensity_specific_fa, lipid_list)

# # df_filtered.to_parquet('Projects/STD/analysis/OFF/df_analysis_5_FAME_OFF_twoisomers.parquet')

# df_filtered

# %%
# import pandas as pd
# test = pd.read_parquet('Projects/STD/analysis/OFF/df_analysis_5_FAME_OFF_twoisomers.parquet')
# test

# %%
# import pandas as pd
# test = pd.read_parquet('Projects/STD/analysis/OFF/df_analysis_5_FAME_OFF_twoisomers.parquet')
# test

# %%
# # pd.set_option('display.max_rows', None)
# database = pd.read_parquet('lipid_database/OzOFF_database/Database_OzOFF.parquet')
# database

# %%
# std = pd.read_parquet('lipid_database/OzOFF_database/Database_OzOFF.parquet')
# std

# %%
std = pd.read_csv('FAME.csv')
std
# Out:
#                                         Common Name  \
# 0                                      Butyric Acid
# 1                      Hexanoic Acid (Caproic Acid)
# 2                     Octanoic Acid (Caprylic Acid)
# 3                       Decanoic Acid (Capric Acid)
# 4                                   Undecanoic Acid
# 5                                       Lauric Acid
# 6                                  Tridecanoic Acid
# 7                                     Myristic Acid
# 8                                  Myristoleic Acid
# 9                                Pentadecanoic Acid
# 10                         10(Z)-Pentadecenoic Acid
# 11                                    Palmitic Acid
# 12                                 Palmitoleic Acid
# 13               Heptadecanoic Acid (Margaric Acid)
# 14                        cis-10-Heptadecenoic Acid
# 15                                     Stearic Acid
# 16                                     Elaidic Acid
# 17                                       Oleic Acid
# 18                                 Linoelaidic Acid
# 19                                    Linoleic Acid
# 20                                 α-Linolenic Acid
# 21                                   Arachidic Acid
# 22                                 γ-Linolenic Acid
# 23                               Heneicosanoic Acid
# 24             11(Z)-Eicosenoic Acid (Gondoic Acid)
# 25                   11(Z),14(Z)-Eicosadienoic Acid
# 26  homo-γ-Linolenic Acid (Dihomo-γ-linolenic acid)
# 27                   Docosanoic Acid (Behenic Acid)
# 28              13(Z)-Docosenoic Acid (Erucic Acid)
# 29            11(Z),14(Z),17(Z)-Eicosatrienoic Acid
# 30                                 Arachidonic Acid
# 31                                 Tricosanoic Acid
# 32                                  Lignoceric Acid
# 33                      Eicosapentaenoic Acid (EPA)
# 34                               Docosadienoic Acid
# 35                                    Nervonic Acid
# 36                       Docosahexaenoic Acid (DHA)
#
#        Shorthand Lipid Formula Species        FA
# 0                          4:0     4:0   FA(4:0)
# 1                          6:0     6:0   FA(6:0)
# 2                          8:0     8:0   FA(8:0)
# 3                         10:0    10:0  FA(10:0)
# 4                         11:0    11:0  FA(11:0)
# 5                         12:0    12:0  FA(12:0)
# 6                         13:0    13:0  FA(13:0)
# 7                         14:0    14:0  FA(14:0)
# 8                         14:1    14:1  FA(14:1)
# 9                         15:0    15:0  FA(15:0)
# 10                        15:1    15:1  FA(15:1)
# 11                        16:0    16:0  FA(16:0)
# 12                        16:1    16:1  FA(16:1)
# 13                        17:0    17:0  FA(17:0)
# 14                        17:1    17:1  FA(17:1)
# 15                        18:0    18:0  FA(18:0)
# 16              18:1 (trans-9)    18:1  FA(18:1)
# 17                18:1 (cis-9)    18:1  FA(18:1)
# 18           18:2 (trans-9,12)    18:2  FA(18:2)
# 19             18:2 (cis-9,12)    18:2  FA(18:2)
# 20          18:3 (cis-9,12,15)    18:3  FA(18:3)
# 21                        20:0    20:0  FA(20:0)
# 22           18:3 (cis-6,9,12)    18:3  FA(18:3)
# 23                        21:0    21:0  FA(21:0)
# 24               20:1 (cis-11)    20:1  FA(20:1)
# 25            20:2 (cis-11,14)    20:2  FA(20:2)
# 26          20:3 (cis-8,11,14)    20:3  FA(20:3)
# 27                        22:0    22:0  FA(22:0)
# 28               22:1 (cis-13)    22:1  FA(22:1)
# 29         20:3 (cis-11,14,17)    20:3  FA(20:3)
# 30        20:4 (cis-5,8,11,14)    20:4  FA(20:4)
# 31                        23:0    23:0  FA(23:0)
# 32                        24:0    24:0  FA(24:0)
# 33     20:5 (cis-5,8,11,14,17)    20:5  FA(20:5)
# 34                        22:2    22:2  FA(22:2)
# 35               24:1 (cis-15)    24:1  FA(24:1)
# 36  22:6 (cis-4,7,10,13,16,19)    22:6  FA(22:6)

# %%
import pandas as pd

def compare_lipids(df, std, intensity_threshold=0, top_n=1, sort_column='Sample_OzESI_Intensity', ascending=False):
    """
    Compares the sample lipid data (df) with the standard lipid data (std) and outputs a new DataFrame.
    The new DataFrame shows all STD Common Names, FA values, Retention Time (from df), OzESI_Intensity,
    Parent_Ion, and the matched unique sample lipids. The user can set an intensity threshold to filter the results
    based on Sample_OzESI_Intensity, select the top N OzESI_Intensity values for each Common Name, 
    and sort the results by a specified column in ascending or descending order.

    Parameters:
    df (pd.DataFrame): DataFrame containing sample lipid data.
    std (pd.DataFrame): DataFrame containing standard lipid data.
    intensity_threshold (float): Threshold to filter rows based on OzESI_Intensity. Default is 0.
    top_n (int): Number of top OzESI_Intensity values to select for each Common Name. Default is 1.
    sort_column (str): Column to sort the results by. Default is 'Sample_OzESI_Intensity'.
    ascending (bool): Whether to sort in ascending order. Default is False (descending).

    Returns:
    pd.DataFrame: DataFrame with common name, FA, sample retention time, OzESI_Intensity, 
                  Parent_Ion, and matched sample data, filtered by intensity threshold and sorted.
    """

    # Ensure 'Species' column exists in both DataFrames
    if 'Species' not in df.columns or 'Species' not in std.columns:
        raise ValueError("Both DataFrames must have a 'Species' column.")

    # Ensure 'Retention_Time', 'OzESI_Intensity', and 'Parent_Ion' columns exist in the df DataFrame
    if 'Retention_Time' not in df.columns:
        raise ValueError("The sample DataFrame (df) must have a 'Retention_Time' column.")
    
    if 'OzESI_Intensity' not in df.columns:
        raise ValueError("The sample DataFrame (df) must have an 'OzESI_Intensity' column.")
    
    if 'Parent_Ion' not in df.columns:
        raise ValueError("The sample DataFrame (df) must have a 'Parent_Ion' column.")

    # Merge based on the Species column to find matching lipids between df and std
    result_df = std.merge(df[['Lipid', 'Species', 'Retention_Time', 'OzESI_Intensity', 'Parent_Ion']].drop_duplicates(), 
                          on='Species', how='left')

    # Rename the 'Lipid' column from df to 'Sample_Data' for clarity
    result_df = result_df.rename(columns={'Lipid': 'Sample_Data'})

    # Add a 'Match' column: 'Yes' if there's a match (Sample_Data not NaN), otherwise 'No'
    result_df['Match'] = result_df['Sample_Data'].apply(lambda x: 'Yes' if pd.notna(x) else 'No')

    # Rename columns for clarity
    result_df = result_df.rename(columns={'Retention_Time': 'Sample_Retention_Time',
                                          'OzESI_Intensity': 'Sample_OzESI_Intensity',
                                          'Parent_Ion': 'Sample_Parent_Ion'})

    # Apply the intensity threshold filter
    result_df = result_df[result_df['Sample_OzESI_Intensity'] > intensity_threshold]

    # Check if the specified sort_column exists in the DataFrame
    if sort_column not in result_df.columns:
        raise ValueError(f"The specified sort_column '{sort_column}' does not exist in the DataFrame.")

    # Sort the DataFrame by the specified column and order
    result_df = result_df.sort_values(by=sort_column, ascending=ascending)

    # Group by Species (Common Name) and select the top N values for each group
    result_df = result_df.groupby('Species').head(top_n)

    return result_df

# Call the function with a user-defined intensity threshold, top N values, sorting column, and sort order (e.g., 1000, top 1, sort by 'Species', ascending=True)
comparison_result = compare_lipids(df_highest_intensity, std, intensity_threshold=1000, top_n=1, sort_column='Species', ascending=True)

# Save the result to a CSV file
comparison_result.to_csv('Projects/STD/off_possible/df_analysis_5_FAME_OFF_comparison.csv', index=False)
comparison_result.to_parquet('Projects/STD/off_possible/df_analysis_5_FAME_OFF_comparison.parquet')

# Set pandas option to display all rows
pd.set_option('display.max_rows', None)

# Display the result
comparison_result.head(None)
# Out:
#                                         Common Name  \
# 3                       Decanoic Acid (Capric Acid)
# 4                                   Undecanoic Acid
# 5                                       Lauric Acid
# 6                                  Tridecanoic Acid
# 7                                     Myristic Acid
# 8                                  Myristoleic Acid
# 9                                Pentadecanoic Acid
# 10                         10(Z)-Pentadecenoic Acid
# 11                                    Palmitic Acid
# 13                                 Palmitoleic Acid
# 14               Heptadecanoic Acid (Margaric Acid)
# 15                        cis-10-Heptadecenoic Acid
# 16                                     Stearic Acid
# 17                                     Elaidic Acid
# 20                                    Linoleic Acid
# 21                                 α-Linolenic Acid
# 22                                   Arachidic Acid
# 25             11(Z)-Eicosenoic Acid (Gondoic Acid)
# 26                   11(Z),14(Z)-Eicosadienoic Acid
# 27  homo-γ-Linolenic Acid (Dihomo-γ-linolenic acid)
# 31                                 Arachidonic Acid
# 34                      Eicosapentaenoic Acid (EPA)
# 24                               Heneicosanoic Acid
# 28                   Docosanoic Acid (Behenic Acid)
# 29              13(Z)-Docosenoic Acid (Erucic Acid)
# 35                               Docosadienoic Acid
# 37                       Docosahexaenoic Acid (DHA)
# 32                                 Tricosanoic Acid
# 33                                  Lignoceric Acid
# 36                                    Nervonic Acid
# 2                     Octanoic Acid (Caprylic Acid)
#
#        Shorthand Lipid Formula Species        FA Sample_Data  \
# 3                         10:0    10:0  FA(10:0)    FA(10:0)
# 4                         11:0    11:0  FA(11:0)    FA(11:0)
# 5                         12:0    12:0  FA(12:0)    FA(12:0)
# 6                         13:0    13:0  FA(13:0)    FA(13:0)
# 7                         14:0    14:0  FA(14:0)    FA(14:0)
# 8                         14:1    14:1  FA(14:1)    FA(14:1)
# 9                         15:0    15:0  FA(15:0)    FA(15:0)
# 10                        15:1    15:1  FA(15:1)    FA(15:1)
# 11                        16:0    16:0  FA(16:0)    FA(16:0)
# 13                        16:1    16:1  FA(16:1)    FA(16:1)
# 14                        17:0    17:0  FA(17:0)    FA(17:0)
# 15                        17:1    17:1  FA(17:1)    FA(17:1)
# 16                        18:0    18:0  FA(18:0)    FA(18:0)
# 17              18:1 (trans-9)    18:1  FA(18:1)    FA(18:1)
# 20             18:2 (cis-9,12)    18:2  FA(18:2)    FA(18:2)
# 21          18:3 (cis-9,12,15)    18:3  FA(18:3)    FA(18:3)
# 22                        20:0    20:0  FA(20:0)    FA(20:0)
# 25               20:1 (cis-11)    20:1  FA(20:1)    FA(20:1)
# 26            20:2 (cis-11,14)    20:2  FA(20:2)    FA(20:2)
# 27          20:3 (cis-8,11,14)    20:3  FA(20:3)    FA(20:3)
# 31        20:4 (cis-5,8,11,14)    20:4  FA(20:4)    FA(20:4)
# 34     20:5 (cis-5,8,11,14,17)    20:5  FA(20:5)    FA(20:5)
# 24                        21:0    21:0  FA(21:0)    FA(21:0)
# 28                        22:0    22:0  FA(22:0)    FA(22:0)
# 29               22:1 (cis-13)    22:1  FA(22:1)    FA(22:1)
# 35                        22:2    22:2  FA(22:2)    FA(22:2)
# 37  22:6 (cis-4,7,10,13,16,19)    22:6  FA(22:6)    FA(22:6)
# 32                        23:0    23:0  FA(23:0)    FA(23:0)
# 33                        24:0    24:0  FA(24:0)    FA(24:0)
# 36               24:1 (cis-15)    24:1  FA(24:1)    FA(24:1)
# 2                          8:0     8:0   FA(8:0)     FA(8:0)
#
#     Sample_Retention_Time  Sample_OzESI_Intensity  Sample_Parent_Ion Match
# 3                4.086000                 88307.0              339.3   Yes
# 4                4.373650                238663.0              353.3   Yes
# 5                4.818250                705102.0              367.3   Yes
# 6                5.525183                504149.0              381.3   Yes
# 7                6.337033               1573355.0              395.4   Yes
# 8                5.314400                834263.0              393.4   Yes
# 9                7.279150                857885.0              409.4   Yes
# 10               6.072883               1323773.0              407.4   Yes
# 11               8.195950               2398234.0              423.4   Yes
# 13               6.910983               1813371.0              421.4   Yes
# 14               9.217217                547385.0              437.4   Yes
# 15               7.801083               2232096.0              435.4   Yes
# 16              10.211783                659183.0              451.4   Yes
# 17               8.743200               4043347.0              449.4   Yes
# 20               8.035350               1831706.0              447.4   Yes
# 21               6.776617               2320712.0              445.4   Yes
# 22              12.255250                144205.0              479.4   Yes
# 25              10.629233               1023483.0              477.4   Yes
# 26               9.318033               1269626.0              475.4   Yes
# 27               8.269167               2384459.0              473.4   Yes
# 31               7.613800               2003592.0              471.4   Yes
# 34               6.669867               1621650.0              469.4   Yes
# 24              13.356583                 25096.0              493.4   Yes
# 28              14.377850                 20790.0              507.4   Yes
# 29              12.541983                274078.0              505.4   Yes
# 35              11.178317                436034.0              503.4   Yes
# 37               7.558583               2139168.0              495.4   Yes
# 32              15.479167                  2677.0              521.4   Yes
# 33              14.533867                  2242.0              535.4   Yes
# 36              14.534317                 55694.0              533.4   Yes
# 2                3.589383                 23194.0              311.3   Yes

# %%
import pandas as pd

# Load the parquet file
b = pd.read_parquet('Projects/STD/analysis/OFF/multiple_values/df_analysis_5_FAME_OFF.parquet')

# # Filter the DataFrame where the 'Lipid' column matches the pattern 'FA(24:#)' where # is any number
# filtered_lipids = b[b['Lipid'].str.contains(r'^FA\(24:\d+\)', regex=True)]

# Print each Lipid on a new line
for lipid in b['Lipid']:
    print(lipid)

# # Sort by OzESI_Intensity in descending order
# b_sorted = b.sort_values(by='OzESI_Intensity', ascending=False)

# # Keep only the first occurrence of each unique Lipid (which will have the highest OzESI_Intensity due to sorting)
# b_unique_lipids = b_sorted.drop_duplicates(subset='Lipid', keep='first')

# # Sort by the Lipid column in ascending order
# b_sorted_by_lipid = b_unique_lipids.sort_values(by='Lipid', ascending=True)

# b_sorted_by_lipid.to_parquet('Projects/STD/analysis/OFF/df_analysis_5_FAME_OFF_max.parquet')
# # Display the result
# b_sorted_by_lipid
# Out:
# FA(8:0)
# FA(9:0)
# FA(10:0)
# FA(10:0)
# FA(11:0)
# FA(12:0)
# FA(12:0)
# FA(13:0)
# FA(14:0)
# FA(14:0)
# FA(14:0)
# FA(14:0)
# FA(14:1)
# FA(14:1)
# FA(15:0)
# FA(15:0)
# FA(15:0)
# FA(15:0)
# FA(15:0)
# FA(15:1)
# FA(15:1)
# FA(d2-16:0)
# FA(16:0)
# FA(16:0)
# FA(16:0)
# FA(16:0)
# FA(16:0)
# FA(16:0)
# FA(16:0)
# FA(16:0)
# FA(16:1)
# FA(17:0)
# FA(17:0)
# FA(17:0)
# FA(17:0)
# FA(17:1)
# FA(17:1)
# FA(17:1)
# FA(17:1)
# FA(18:0)
# FA(18:0)
# FA(18:0)
# FA(18:0)
# FA(18:0)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:1)
# FA(18:2)
# FA(18:2)
# FA(18:2)
# FA(18:2)
# FA(18:2)
# FA(18:2)
# FA(18:2)
# FA(18:3)
# FA(18:3)
# FA(18:3)
# FA(18:3)
# FA(18:3)
# FA(20:0)
# FA(20:0)
# FA(20:0)
# FA(20:0)
# FA(20:0)
# FA(20:1)
# FA(20:1)
# FA(20:1)
# FA(20:1)
# FA(20:2)
# FA(20:2)
# FA(20:2)
# FA(20:3)
# FA(20:3)
# FA(20:3)
# FA(20:3)
# FA(20:3)
# FA(20:3)
# FA(20:4)
# FA(20:4)
# FA(20:4)
# FA(20:4)
# FA(20:5)
# FA(20:5)
# FA(21:0)
# FA(21:0)
# FA(22:0)
# FA(22:0)
# FA(22:1)
# FA(22:1)
# FA(22:1)
# FA(22:1)
# FA(22:1)
# FA(22:1)
# FA(22:2)
# FA(22:2)
# FA(22:6)
# FA(22:6)
# FA(22:6)
# FA(23:0)
# FA(24:0)
# FA(24:0)

# %%
# a = pd.read_parquet('Projects/STD/analysis/OFF/df_analysis_5_FAME_OFF.parquet')
import pandas as pd
a = pd.read_parquet('Projects/STD/analysis/OFF/df_analysis_5_FAME_OFF_max.parquet')
# make csv
a.to_csv('Projects/STD/analysis/OFF/df_analysis_5_FAME_OFF_max.csv', index=False)

a
# Out:
#            Lipid  Retention_Time  OzESI_Intensity  group_by_ion  \
# 3       FA(10:0)        4.086000          88307.0            10
# 4       FA(11:0)        4.373650         238663.0            12
# 5       FA(12:0)        4.818250         705102.0            15
# 7       FA(13:0)        5.525183         504149.0            18
# 9       FA(14:0)        6.337033        1573355.0            21
# 12      FA(14:1)        5.314400         834263.0            20
# 16      FA(15:0)        7.279150         857885.0            26
# 19      FA(15:1)        6.072883        1323773.0            25
# 23      FA(16:0)        8.195950        2398234.0            29
# 30      FA(16:1)        6.910983        1813371.0            28
# 33      FA(17:0)        9.217217         547385.0            33
# 35      FA(17:1)        7.801083        2232096.0            32
# 41      FA(18:0)       10.211783         659183.0            38
# 46      FA(18:1)        8.743200        4043347.0            37
# 89      FA(18:2)        8.035350        1831706.0            36
# 95      FA(18:3)        6.776617        2320712.0            35
# 100     FA(20:0)       12.255250         144205.0            44
# 104     FA(20:1)       10.629233        1023483.0            43
# 108     FA(20:2)        9.318033        1269626.0            42
# 111     FA(20:3)        8.269167        2384459.0            41
# 117     FA(20:4)        7.613800        2003592.0            40
# 120     FA(20:5)        6.669867        1621650.0            39
# 122     FA(21:0)       13.356583          25096.0            45
# 125     FA(22:0)       14.377850          20790.0            49
# 128     FA(22:1)       12.541983         274078.0            48
# 132     FA(22:2)       11.178317         436034.0            47
# 134     FA(22:6)        7.558583        2139168.0            46
# 137     FA(23:0)       15.479167           2677.0            50
# 138     FA(24:0)       14.533867           2242.0            53
# 140     FA(24:1)       14.534317          55694.0            51
# 0        FA(8:0)        3.589383          23194.0             6
# 1        FA(9:0)        3.824567           7033.0             8
# 21   FA(d2-16:0)        8.169267         208041.0            30
#
#      group_by_lipid Sample_ID      Transition Sample  Parent_Ion  Product_Ion  \
# 3                 1  FAME_off  339.3 -> 183.0   FAME       339.3        183.0
# 4                 3  FAME_off  353.3 -> 183.0   FAME       353.3        183.0
# 5                 5  FAME_off  367.3 -> 183.0   FAME       367.3        183.0
# 7                 8  FAME_off  381.3 -> 183.0   FAME       381.3        183.0
# 9                11  FAME_off  395.4 -> 183.0   FAME       395.4        183.0
# 12               12  FAME_off  393.4 -> 183.0   FAME       393.4        183.0
# 16               14  FAME_off  409.4 -> 183.0   FAME       409.4        183.0
# 19               15  FAME_off  407.4 -> 183.0   FAME       407.4        183.0
# 23               18  FAME_off  423.4 -> 183.0   FAME       423.4        183.0
# 30               19  FAME_off  421.4 -> 183.0   FAME       421.4        183.0
# 33               21  FAME_off  437.4 -> 183.0   FAME       437.4        183.0
# 35               22  FAME_off  435.4 -> 183.0   FAME       435.4        183.0
# 41               24  FAME_off  451.4 -> 183.0   FAME       451.4        183.0
# 46               25  FAME_off  449.4 -> 183.0   FAME       449.4        183.0
# 89               26  FAME_off  447.4 -> 183.0   FAME       447.4        183.0
# 95               27  FAME_off  445.4 -> 183.0   FAME       445.4        183.0
# 100              29  FAME_off  479.4 -> 183.0   FAME       479.4        183.0
# 104              30  FAME_off  477.4 -> 183.0   FAME       477.4        183.0
# 108              31  FAME_off  475.4 -> 183.0   FAME       475.4        183.0
# 111              32  FAME_off  473.4 -> 183.0   FAME       473.4        183.0
# 117              33  FAME_off  471.4 -> 183.0   FAME       471.4        183.0
# 120              34  FAME_off  469.4 -> 183.0   FAME       469.4        183.0
# 122              35  FAME_off  493.4 -> 183.0   FAME       493.4        183.0
# 125              36  FAME_off  507.4 -> 183.0   FAME       507.4        183.0
# 128              37  FAME_off  505.4 -> 183.0   FAME       505.4        183.0
# 132              38  FAME_off  503.4 -> 183.0   FAME       503.4        183.0
# 134              39  FAME_off  495.4 -> 183.0   FAME       495.4        183.0
# 137              40  FAME_off  521.4 -> 183.0   FAME       521.4        183.0
# 138              41  FAME_off  535.4 -> 183.0   FAME       535.4        183.0
# 140              42  FAME_off  533.4 -> 183.0   FAME       533.4        183.0
# 0                46  FAME_off  311.3 -> 183.0   FAME       311.3        183.0
# 1                48  FAME_off  325.2 -> 183.0   FAME       325.2        183.0
# 21               50  FAME_off  425.4 -> 183.0   FAME       425.4        183.0
#
#     Species Class   STD  STD_RT_OFF  Peak_Height      FWHM  Peak_Width  \
# 3      10:0    FA  FAME    8.169267      88307.0  0.079300    0.078700
# 4      11:0    FA  FAME    8.169267     238663.0  0.078274    0.078700
# 5      12:0    FA  FAME    8.169267     705102.0  0.091269    0.104933
# 7      13:0    FA  FAME    8.169267     504149.0  0.101116    0.104933
# 9      14:0    FA  FAME    8.169267    1573355.0  0.105889    0.104933
# 12     14:1    FA  FAME    8.169267     834263.0  0.097012    0.104933
# 16     15:0    FA  FAME    8.169267     857885.0  0.115178    0.131167
# 19     15:1    FA  FAME    8.169267    1323773.0  0.002610    0.078233
# 23     16:0    FA  FAME    8.169267    2398234.0  0.101095    0.104933
# 30     16:1    FA  FAME    8.169267    1813371.0  0.104408    0.104933
# 33     17:0    FA  FAME    8.169267     547385.0  0.135450    0.131167
# 35     17:1    FA  FAME    8.169267    2232096.0  0.112709    0.131167
# 41     18:0    FA  FAME    8.169267     659183.0  0.163508    0.183633
# 46     18:1    FA  FAME    8.169267    4043347.0  0.127516    0.131167
# 89     18:2    FA  FAME    8.169267    1831706.0  0.115203    0.104933
# 95     18:3    FA  FAME    8.169267    2320712.0  0.097786    0.078700
# 100    20:0    FA  FAME    8.169267     144205.0  0.203265    0.209867
# 104    20:1    FA  FAME    8.169267    1023483.0  0.144158    0.157400
# 108    20:2    FA  FAME    8.169267    1269626.0  0.107743    0.104933
# 111    20:3    FA  FAME    8.169267    2384459.0  0.130886    0.131167
# 117    20:4    FA  FAME    8.169267    2003592.0  0.100365    0.078700
# 120    20:5    FA  FAME    8.169267    1621650.0  0.090009    0.078700
# 122    21:0    FA  FAME    8.169267      25096.0  0.240523    0.236100
# 125    22:0    FA  FAME    8.169267      20790.0  0.200827    0.209850
# 128    22:1    FA  FAME    8.169267     274078.0  0.212511    0.209867
# 132    22:2    FA  FAME    8.169267     436034.0  0.158931    0.157400
# 134    22:6    FA  FAME    8.169267    2139168.0  0.091458    0.078700
# 137    23:0    FA  FAME    8.169267       2677.0  0.279536    0.262333
# 138    24:0    FA  FAME    8.169267       2242.0  0.211017    0.236100
# 140    24:1    FA  FAME    8.169267      55694.0  0.281332    0.262333
# 0       8:0    FA  FAME    8.169267      23194.0  0.072053    0.052467
# 1       9:0    FA  FAME    8.169267       7033.0  0.072858    0.052467
# 21     16:0    FA  FAME    8.169267     208041.0  0.097797    0.104933
#
#          Peak_Area   Filter_Column Isomer
# 3      6949.760900  group_by_lipid   None
# 4     18782.778100  group_by_lipid   None
# 5     73988.703200  group_by_lipid   None
# 7     52902.035067  group_by_lipid   None
# 9    165097.384667  group_by_lipid   None
# 12    87541.997467  group_by_lipid    cis
# 16   112525.915833  group_by_lipid   None
# 19   103563.174367  group_by_lipid    cis
# 23   251654.687733  group_by_lipid   None
# 30   190283.063600  group_by_lipid   None
# 33    71798.665833  group_by_lipid   None
# 35   292776.592000  group_by_lipid    cis
# 41   121047.971567  group_by_lipid   None
# 46   530352.348167  group_by_lipid    cis
# 89   192207.016267  group_by_lipid   None
# 95   182640.034400  group_by_lipid   None
# 100   30263.822667  group_by_lipid   None
# 104  161096.224200  group_by_lipid  trans
# 108  133226.088267  group_by_lipid   None
# 111  312761.538833  group_by_lipid   None
# 117  157682.690400  group_by_lipid   None
# 120  127623.855000  group_by_lipid   None
# 122    5925.165600  group_by_lipid   None
# 125    4362.781500  group_by_lipid   None
# 128   57519.836267  group_by_lipid  trans
# 132   68631.751600  group_by_lipid   None
# 134  168352.521600  group_by_lipid   None
# 137     702.266333  group_by_lipid   None
# 138     529.336200  group_by_lipid   None
# 140   14610.392667  group_by_lipid    cis
# 0      1216.911867  group_by_lipid   None
# 1       368.998067  group_by_lipid   None
# 21    21830.435600  group_by_lipid   None

# %%
def get_highest_intensity_per_lipid(df):
    """
    This function returns the rows with the highest OzESI_Intensity for each unique Lipid.

    Parameters:
    df (pd.DataFrame): The DataFrame containing 'Lipid' and 'OzESI_Intensity' columns.

    Returns:
    pd.DataFrame: A DataFrame containing the rows with the highest intensity for each lipid.
    """
    # Group by 'Lipid' and get the row with the highest 'OzESI_Intensity' for each lipid
    highest_intensity_df = df.loc[df.groupby('Lipid')['OzESI_Intensity'].idxmax()]

    return highest_intensity_df

# Assuming df is your DataFrame
df_highest_intensity = get_highest_intensity_per_lipid(a)
df_highest_intensity.to_parquet('Projects/STD/analysis/OFF/df_analysis_5_FAME_OFF_max.parquet')
df_highest_intensity.to_csv('Projects/STD/analysis/results_to_download/df_analysis_5_FAME_OFF_max.csv')

df_highest_intensity
# Out:
#            Lipid  Retention_Time  OzESI_Intensity  group_by_ion  \
# 3       FA(10:0)        4.086000          88307.0            10
# 4       FA(11:0)        4.373650         238663.0            12
# 5       FA(12:0)        4.818250         705102.0            15
# 7       FA(13:0)        5.525183         504149.0            18
# 9       FA(14:0)        6.337033        1573355.0            21
# 12      FA(14:1)        5.314400         834263.0            20
# 16      FA(15:0)        7.279150         857885.0            26
# 19      FA(15:1)        6.072883        1323773.0            25
# 23      FA(16:0)        8.195950        2398234.0            29
# 30      FA(16:1)        6.910983        1813371.0            28
# 33      FA(17:0)        9.217217         547385.0            33
# 35      FA(17:1)        7.801083        2232096.0            32
# 41      FA(18:0)       10.211783         659183.0            38
# 46      FA(18:1)        8.743200        4043347.0            37
# 89      FA(18:2)        8.035350        1831706.0            36
# 95      FA(18:3)        6.776617        2320712.0            35
# 100     FA(20:0)       12.255250         144205.0            44
# 104     FA(20:1)       10.629233        1023483.0            43
# 108     FA(20:2)        9.318033        1269626.0            42
# 111     FA(20:3)        8.269167        2384459.0            41
# 117     FA(20:4)        7.613800        2003592.0            40
# 120     FA(20:5)        6.669867        1621650.0            39
# 122     FA(21:0)       13.356583          25096.0            45
# 125     FA(22:0)       14.377850          20790.0            49
# 128     FA(22:1)       12.541983         274078.0            48
# 132     FA(22:2)       11.178317         436034.0            47
# 134     FA(22:6)        7.558583        2139168.0            46
# 137     FA(23:0)       15.479167           2677.0            50
# 138     FA(24:0)       14.533867           2242.0            53
# 140     FA(24:1)       14.534317          55694.0            51
# 0        FA(8:0)        3.589383          23194.0             6
# 1        FA(9:0)        3.824567           7033.0             8
# 21   FA(d2-16:0)        8.169267         208041.0            30
#
#      group_by_lipid Sample_ID      Transition Sample  Parent_Ion  Product_Ion  \
# 3                 1  FAME_off  339.3 -> 183.0   FAME       339.3        183.0
# 4                 3  FAME_off  353.3 -> 183.0   FAME       353.3        183.0
# 5                 5  FAME_off  367.3 -> 183.0   FAME       367.3        183.0
# 7                 8  FAME_off  381.3 -> 183.0   FAME       381.3        183.0
# 9                11  FAME_off  395.4 -> 183.0   FAME       395.4        183.0
# 12               12  FAME_off  393.4 -> 183.0   FAME       393.4        183.0
# 16               14  FAME_off  409.4 -> 183.0   FAME       409.4        183.0
# 19               15  FAME_off  407.4 -> 183.0   FAME       407.4        183.0
# 23               18  FAME_off  423.4 -> 183.0   FAME       423.4        183.0
# 30               19  FAME_off  421.4 -> 183.0   FAME       421.4        183.0
# 33               21  FAME_off  437.4 -> 183.0   FAME       437.4        183.0
# 35               22  FAME_off  435.4 -> 183.0   FAME       435.4        183.0
# 41               24  FAME_off  451.4 -> 183.0   FAME       451.4        183.0
# 46               25  FAME_off  449.4 -> 183.0   FAME       449.4        183.0
# 89               26  FAME_off  447.4 -> 183.0   FAME       447.4        183.0
# 95               27  FAME_off  445.4 -> 183.0   FAME       445.4        183.0
# 100              29  FAME_off  479.4 -> 183.0   FAME       479.4        183.0
# 104              30  FAME_off  477.4 -> 183.0   FAME       477.4        183.0
# 108              31  FAME_off  475.4 -> 183.0   FAME       475.4        183.0
# 111              32  FAME_off  473.4 -> 183.0   FAME       473.4        183.0
# 117              33  FAME_off  471.4 -> 183.0   FAME       471.4        183.0
# 120              34  FAME_off  469.4 -> 183.0   FAME       469.4        183.0
# 122              35  FAME_off  493.4 -> 183.0   FAME       493.4        183.0
# 125              36  FAME_off  507.4 -> 183.0   FAME       507.4        183.0
# 128              37  FAME_off  505.4 -> 183.0   FAME       505.4        183.0
# 132              38  FAME_off  503.4 -> 183.0   FAME       503.4        183.0
# 134              39  FAME_off  495.4 -> 183.0   FAME       495.4        183.0
# 137              40  FAME_off  521.4 -> 183.0   FAME       521.4        183.0
# 138              41  FAME_off  535.4 -> 183.0   FAME       535.4        183.0
# 140              42  FAME_off  533.4 -> 183.0   FAME       533.4        183.0
# 0                46  FAME_off  311.3 -> 183.0   FAME       311.3        183.0
# 1                48  FAME_off  325.2 -> 183.0   FAME       325.2        183.0
# 21               50  FAME_off  425.4 -> 183.0   FAME       425.4        183.0
#
#     Species Class   STD  STD_RT_OFF  Peak_Height      FWHM  Peak_Width  \
# 3      10:0    FA  FAME    8.169267      88307.0  0.079300    0.078700
# 4      11:0    FA  FAME    8.169267     238663.0  0.078274    0.078700
# 5      12:0    FA  FAME    8.169267     705102.0  0.091269    0.104933
# 7      13:0    FA  FAME    8.169267     504149.0  0.101116    0.104933
# 9      14:0    FA  FAME    8.169267    1573355.0  0.105889    0.104933
# 12     14:1    FA  FAME    8.169267     834263.0  0.097012    0.104933
# 16     15:0    FA  FAME    8.169267     857885.0  0.115178    0.131167
# 19     15:1    FA  FAME    8.169267    1323773.0  0.002610    0.078233
# 23     16:0    FA  FAME    8.169267    2398234.0  0.101095    0.104933
# 30     16:1    FA  FAME    8.169267    1813371.0  0.104408    0.104933
# 33     17:0    FA  FAME    8.169267     547385.0  0.135450    0.131167
# 35     17:1    FA  FAME    8.169267    2232096.0  0.112709    0.131167
# 41     18:0    FA  FAME    8.169267     659183.0  0.163508    0.183633
# 46     18:1    FA  FAME    8.169267    4043347.0  0.127516    0.131167
# 89     18:2    FA  FAME    8.169267    1831706.0  0.115203    0.104933
# 95     18:3    FA  FAME    8.169267    2320712.0  0.097786    0.078700
# 100    20:0    FA  FAME    8.169267     144205.0  0.203265    0.209867
# 104    20:1    FA  FAME    8.169267    1023483.0  0.144158    0.157400
# 108    20:2    FA  FAME    8.169267    1269626.0  0.107743    0.104933
# 111    20:3    FA  FAME    8.169267    2384459.0  0.130886    0.131167
# 117    20:4    FA  FAME    8.169267    2003592.0  0.100365    0.078700
# 120    20:5    FA  FAME    8.169267    1621650.0  0.090009    0.078700
# 122    21:0    FA  FAME    8.169267      25096.0  0.240523    0.236100
# 125    22:0    FA  FAME    8.169267      20790.0  0.200827    0.209850
# 128    22:1    FA  FAME    8.169267     274078.0  0.212511    0.209867
# 132    22:2    FA  FAME    8.169267     436034.0  0.158931    0.157400
# 134    22:6    FA  FAME    8.169267    2139168.0  0.091458    0.078700
# 137    23:0    FA  FAME    8.169267       2677.0  0.279536    0.262333
# 138    24:0    FA  FAME    8.169267       2242.0  0.211017    0.236100
# 140    24:1    FA  FAME    8.169267      55694.0  0.281332    0.262333
# 0       8:0    FA  FAME    8.169267      23194.0  0.072053    0.052467
# 1       9:0    FA  FAME    8.169267       7033.0  0.072858    0.052467
# 21     16:0    FA  FAME    8.169267     208041.0  0.097797    0.104933
#
#          Peak_Area   Filter_Column Isomer
# 3      6949.760900  group_by_lipid   None
# 4     18782.778100  group_by_lipid   None
# 5     73988.703200  group_by_lipid   None
# 7     52902.035067  group_by_lipid   None
# 9    165097.384667  group_by_lipid   None
# 12    87541.997467  group_by_lipid    cis
# 16   112525.915833  group_by_lipid   None
# 19   103563.174367  group_by_lipid    cis
# 23   251654.687733  group_by_lipid   None
# 30   190283.063600  group_by_lipid   None
# 33    71798.665833  group_by_lipid   None
# 35   292776.592000  group_by_lipid    cis
# 41   121047.971567  group_by_lipid   None
# 46   530352.348167  group_by_lipid    cis
# 89   192207.016267  group_by_lipid   None
# 95   182640.034400  group_by_lipid   None
# 100   30263.822667  group_by_lipid   None
# 104  161096.224200  group_by_lipid  trans
# 108  133226.088267  group_by_lipid   None
# 111  312761.538833  group_by_lipid   None
# 117  157682.690400  group_by_lipid   None
# 120  127623.855000  group_by_lipid   None
# 122    5925.165600  group_by_lipid   None
# 125    4362.781500  group_by_lipid   None
# 128   57519.836267  group_by_lipid  trans
# 132   68631.751600  group_by_lipid   None
# 134  168352.521600  group_by_lipid   None
# 137     702.266333  group_by_lipid   None
# 138     529.336200  group_by_lipid   None
# 140   14610.392667  group_by_lipid    cis
# 0      1216.911867  group_by_lipid   None
# 1       368.998067  group_by_lipid   None
# 21    21830.435600  group_by_lipid   None
