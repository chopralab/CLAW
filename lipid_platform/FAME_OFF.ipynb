# %% [markdown]
# # FAME OFF

# %%
import pandas as pd

# %%
# !sbatch core/backend/FAME/OFF/mzml_parser_1_CT_OFF.sh
# Out:
# Submitted batch job 22355568

# %%
df_mzml = pd.read_parquet('Projects/FAME/mzml_parsed/OFF/mzml_parser_1_OFF_intensity.parquet')
df_mzml
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            227.1        183.0        3.014900        40.880001
# 1            227.1        183.0        3.030717        41.000004
# 2            227.1        183.0        3.046567        40.920002
# 3            227.1        183.0        3.062417        42.420002
# 4            227.1        183.0        3.078267        41.960003
# ...            ...          ...             ...              ...
# 428103       533.5        183.0       31.928683        40.700005
# 428104       533.5        183.0       31.944533        40.680004
# 428105       533.5        183.0       31.960383        40.460003
# 428106       533.5        183.0       31.976233        40.360004
# 428107       533.5        183.0       31.992083        40.840004
#
#                           Sample_ID      Transition
# 0           02032025_FAME2_ozoneoff  227.1 -> 183.0
# 1           02032025_FAME2_ozoneoff  227.1 -> 183.0
# 2           02032025_FAME2_ozoneoff  227.1 -> 183.0
# 3           02032025_FAME2_ozoneoff  227.1 -> 183.0
# 4           02032025_FAME2_ozoneoff  227.1 -> 183.0
# ...                             ...             ...
# 428103  02032025_Blank_AMP_ozoneoff  533.5 -> 183.0
# 428104  02032025_Blank_AMP_ozoneoff  533.5 -> 183.0
# 428105  02032025_Blank_AMP_ozoneoff  533.5 -> 183.0
# 428106  02032025_Blank_AMP_ozoneoff  533.5 -> 183.0
# 428107  02032025_Blank_AMP_ozoneoff  533.5 -> 183.0
#
# [428108 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

# Plot the filtered data
plt.figure(figsize=(8, 6))
plt.scatter(df_mzml['Retention_Time'], df_mzml['OzESI_Intensity'], color='blue', label='OzESI Intensity')

# Add labels and title
plt.xlabel('Retention Time')
plt.ylabel('OzESI Intensity')
plt.title('Retention Time vs OzESI Intensity')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
# !sbatch core/backend/FAME/OFF/sample_2_CT_OFF.sh
# Out:
# Submitted batch job 22359644

# %%
import pandas as pd
df_sample = pd.read_parquet('Projects/FAME/samples/OFF/df_sample_2_FAME.parquet')
df_sample
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            227.1        183.0        3.014900        40.880001
# 1            227.1        183.0        3.030717        41.000004
# 2            227.1        183.0        3.046567        40.920002
# 3            227.1        183.0        3.062417        42.420002
# 4            227.1        183.0        3.078267        41.960003
# ...            ...          ...             ...              ...
# 214049       533.5        183.0       31.928667        40.860004
# 214050       533.5        183.0       31.944533        40.900002
# 214051       533.5        183.0       31.960383        40.960003
# 214052       533.5        183.0       31.976233        40.880001
# 214053       533.5        183.0       31.992083        41.160004
#
#                       Sample_ID      Transition Sample   STD  STD_RT_OFF  \
# 0       02032025_FAME2_ozoneoff  227.1 -> 183.0   FAME  None     10.8529
# 1       02032025_FAME2_ozoneoff  227.1 -> 183.0   FAME  None     10.8529
# 2       02032025_FAME2_ozoneoff  227.1 -> 183.0   FAME  None     10.8529
# 3       02032025_FAME2_ozoneoff  227.1 -> 183.0   FAME  None     10.8529
# 4       02032025_FAME2_ozoneoff  227.1 -> 183.0   FAME  None     10.8529
# ...                         ...             ...    ...   ...         ...
# 214049  02032025_FAME2_ozoneoff  533.5 -> 183.0   FAME  None     10.8529
# 214050  02032025_FAME2_ozoneoff  533.5 -> 183.0   FAME  None     10.8529
# 214051  02032025_FAME2_ozoneoff  533.5 -> 183.0   FAME  None     10.8529
# 214052  02032025_FAME2_ozoneoff  533.5 -> 183.0   FAME  None     10.8529
# 214053  02032025_FAME2_ozoneoff  533.5 -> 183.0   FAME  None     10.8529
#
#         STD_Peak_Intensity  STD_Peak_Area
# 0             30991.421875   19264.541874
# 1             30991.421875   19264.541874
# 2             30991.421875   19264.541874
# 3             30991.421875   19264.541874
# 4             30991.421875   19264.541874
# ...                    ...            ...
# 214049        30991.421875   19264.541874
# 214050        30991.421875   19264.541874
# 214051        30991.421875   19264.541874
# 214052        30991.421875   19264.541874
# 214053        30991.421875   19264.541874
#
# [214054 rows x 11 columns]

# %% [markdown]
# # Match

# %%
# !sbatch core/backend/FAME/OFF/match_3_CT_OFF.sh
# Out:
# Submitted batch job 22359704

# %%
import pandas as pd
df_match = pd.read_parquet('Projects/FAME/match/OFF/df_match_3_FAME.parquet')
df_match
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            227.1        183.0        3.014900             41.0
# 1            227.1        183.0        3.030717             41.0
# 2            227.1        183.0        3.046567             41.0
# 3            227.1        183.0        3.062417             42.0
# 4            227.1        183.0        3.078267             42.0
# ...            ...          ...             ...              ...
# 214049       533.5        183.0       31.928667             41.0
# 214050       533.5        183.0       31.944533             41.0
# 214051       533.5        183.0       31.960383             41.0
# 214052       533.5        183.0       31.976233             41.0
# 214053       533.5        183.0       31.992083             41.0
#
#                       Sample_ID      Transition Sample   STD  STD_RT_OFF  \
# 0       02032025_FAME2_ozoneoff  227.1 -> 183.0   FAME  None     10.8529
# 1       02032025_FAME2_ozoneoff  227.1 -> 183.0   FAME  None     10.8529
# 2       02032025_FAME2_ozoneoff  227.1 -> 183.0   FAME  None     10.8529
# 3       02032025_FAME2_ozoneoff  227.1 -> 183.0   FAME  None     10.8529
# 4       02032025_FAME2_ozoneoff  227.1 -> 183.0   FAME  None     10.8529
# ...                         ...             ...    ...   ...         ...
# 214049  02032025_FAME2_ozoneoff  533.5 -> 183.0   FAME  None     10.8529
# 214050  02032025_FAME2_ozoneoff  533.5 -> 183.0   FAME  None     10.8529
# 214051  02032025_FAME2_ozoneoff  533.5 -> 183.0   FAME  None     10.8529
# 214052  02032025_FAME2_ozoneoff  533.5 -> 183.0   FAME  None     10.8529
# 214053  02032025_FAME2_ozoneoff  533.5 -> 183.0   FAME  None     10.8529
#
#         STD_Peak_Intensity  STD_Peak_Area     Lipid Class
# 0             30991.421875   19264.541874
# 1             30991.421875   19264.541874
# 2             30991.421875   19264.541874
# 3             30991.421875   19264.541874
# 4             30991.421875   19264.541874
# ...                    ...            ...       ...   ...
# 214049        30991.421875   19264.541874  FA(24:1)    FA
# 214050        30991.421875   19264.541874  FA(24:1)    FA
# 214051        30991.421875   19264.541874  FA(24:1)    FA
# 214052        30991.421875   19264.541874  FA(24:1)    FA
# 214053        30991.421875   19264.541874  FA(24:1)    FA
#
# [214054 rows x 13 columns]

# %% [markdown]
# # Group

# %%
# !sbatch core/backend/FAME/OFF/group_4_CT_OFF.sh
# Out:
# Submitted batch job 22359706

# %%
import pandas as pd
df_group = pd.read_parquet('Projects/FAME/group/OFF/df_group_4_FAME_OFF.parquet')
df_group
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            255.2        183.0        3.014550             41.0
# 1            253.2        183.0        3.014667             41.0
# 2            241.1        183.0        3.014783             41.0
# 3            227.1        183.0        3.014900             41.0
# 4            255.2        183.0        3.030367            129.0
# ...            ...          ...             ...              ...
# 214049       425.4        183.0       31.935183             41.0
# 214050       425.4        183.0       31.951033             41.0
# 214051       425.4        183.0       31.966883             41.0
# 214052       425.4        183.0       31.982750             41.0
# 214053       425.4        183.0       31.998600             40.0
#
#                       Sample_ID      Transition Sample   STD  STD_RT_OFF  \
# 0       02032025_FAME2_ozoneoff  255.2 -> 183.0   FAME  None     10.8529
# 1       02032025_FAME2_ozoneoff  253.2 -> 183.0   FAME  None     10.8529
# 2       02032025_FAME2_ozoneoff  241.1 -> 183.0   FAME  None     10.8529
# 3       02032025_FAME2_ozoneoff  227.1 -> 183.0   FAME  None     10.8529
# 4       02032025_FAME2_ozoneoff  255.2 -> 183.0   FAME  None     10.8529
# ...                         ...             ...    ...   ...         ...
# 214049  02032025_FAME2_ozoneoff  425.4 -> 183.0   FAME  None     10.8529
# 214050  02032025_FAME2_ozoneoff  425.4 -> 183.0   FAME  None     10.8529
# 214051  02032025_FAME2_ozoneoff  425.4 -> 183.0   FAME  None     10.8529
# 214052  02032025_FAME2_ozoneoff  425.4 -> 183.0   FAME  None     10.8529
# 214053  02032025_FAME2_ozoneoff  425.4 -> 183.0   FAME  None     10.8529
#
#         STD_Peak_Intensity  STD_Peak_Area        Lipid Class    Species  \
# 0             30991.421875   19264.541874                     Unknown_1
# 1             30991.421875   19264.541874                     Unknown_1
# 2             30991.421875   19264.541874                     Unknown_1
# 3             30991.421875   19264.541874                     Unknown_1
# 4             30991.421875   19264.541874                     Unknown_1
# ...                    ...            ...          ...   ...        ...
# 214049        30991.421875   19264.541874  FA(d2-16:0)    FA       16:0
# 214050        30991.421875   19264.541874  FA(d2-16:0)    FA       16:0
# 214051        30991.421875   19264.541874  FA(d2-16:0)    FA       16:0
# 214052        30991.421875   19264.541874  FA(d2-16:0)    FA       16:0
# 214053        30991.421875   19264.541874  FA(d2-16:0)    FA       16:0
#
#        Biology Genotype Cage Mouse  group_by_ion  group_by_lipid
# 0                                              3               0
# 1                                              2               0
# 2                                              1               0
# 3                                              0               0
# 4                                              3               0
# ...        ...      ...  ...   ...           ...             ...
# 214049                                        70             112
# 214050                                        70             112
# 214051                                        70             112
# 214052                                        70             112
# 214053                                        70             112
#
# [214054 rows x 20 columns]

# %%
unique_lipids = df_group['Lipid'].unique()
print(unique_lipids)
# Out:
# ['' 'FA(10:0)' 'FA(10:1)' 'FA(10:2)' 'FA(10:3)' 'FA(10:4)' 'FA(10:5)'
#  'FA(11:0)' 'FA(11:1)' 'FA(11:2)' 'FA(11:3)' 'FA(11:4)' 'FA(11:5)'
#  'FA(12:0)' 'FA(12:1)' 'FA(12:2)' 'FA(12:3)' 'FA(12:4)' 'FA(12:5)'
#  'FA(13:0)' 'FA(13:1)' 'FA(13:2)' 'FA(13:3)' 'FA(13:4)' 'FA(13:5)'
#  'FA(14:0)' 'FA(14:1)' 'FA(14:2)' 'FA(14:3)' 'FA(14:4)' 'FA(14:5)'
#  'FA(15:0)' 'FA(15:1)' 'FA(15:2)' 'FA(15:3)' 'FA(15:4)' 'FA(15:5)'
#  'FA(16:0)' 'FA(16:1)' 'FA(16:2)' 'FA(16:3)' 'FA(16:4)' 'FA(16:5)'
#  'FA(17:0)' 'FA(17:1)' 'FA(17:2)' 'FA(17:3)' 'FA(17:4)' 'FA(17:5)'
#  'FA(18:0)' 'FA(18:1)' 'FA(18:2)' 'FA(18:3)' 'FA(18:4)' 'FA(18:5)'
#  'FA(19:0)' 'FA(19:1)' 'FA(19:2)' 'FA(19:3)' 'FA(19:4)' 'FA(19:5)'
#  'FA(20:0)' 'FA(20:1)' 'FA(20:2)' 'FA(20:3)' 'FA(20:4)' 'FA(20:5)'
#  'FA(21:0)' 'FA(21:1)' 'FA(21:2)' 'FA(21:3)' 'FA(21:4)' 'FA(21:5)'
#  'FA(22:0)' 'FA(22:1)' 'FA(22:2)' 'FA(22:3)' 'FA(22:4)' 'FA(22:5)'
#  'FA(22:6)' 'FA(23:0)' 'FA(23:1)' 'FA(23:2)' 'FA(23:3)' 'FA(23:4)'
#  'FA(23:5)' 'FA(24:0)' 'FA(24:1)' 'FA(5:0)' 'FA(5:1)' 'FA(5:2)' 'FA(6:0)'
#  'FA(6:1)' 'FA(6:2)' 'FA(6:3)' 'FA(7:0)' 'FA(7:1)' 'FA(7:2)' 'FA(7:3)'
#  'FA(7:4)' 'FA(8:0)' 'FA(8:1)' 'FA(8:2)' 'FA(8:3)' 'FA(8:4)' 'FA(8:5)'
#  'FA(9:0)' 'FA(9:1)' 'FA(9:2)' 'FA(9:3)' 'FA(9:4)' 'FA(9:5)' 'FA(d2-16:0)']

# %%
# print unique columns
unique_columns = df_group.columns
print(unique_columns)
# Out:
# Index(['Parent_Ion', 'Product_Ion', 'Retention_Time', 'OzESI_Intensity',
#        'Sample_ID', 'Transition', 'Sample', 'STD', 'STD_RT_OFF',
#        'STD_Peak_Intensity', 'STD_Peak_Area', 'Lipid', 'Class', 'Species',
#        'Biology', 'Genotype', 'Cage', 'Mouse', 'group_by_ion',
#        'group_by_lipid'],
#       dtype='object')

# %% [markdown]
# # analysis 5

# %%
# !sbatch core/backend/FAME/OFF/off_possible_6_FAME.sh
# Out:
# Submitted batch job 22366085

# %%
import pandas as pd
df_analysis = pd.read_parquet('Projects/FAME/analysis/OFF/df_analysis_CT_OFF_FAME.parquet')
df_analysis
# Out:
#         Lipid  Retention_Time  OzESI_Intensity  group_by_ion  group_by_lipid  \
# 0     FA(6:1)        8.878817           1388.0             9              92
# 1     FA(6:1)        9.718933           1150.0             9              92
# 2     FA(6:1)       10.463950           1050.0             9              92
# 3     FA(7:0)        3.282567           3840.0            15              95
# 4     FA(7:1)        7.721067           1375.0            14              96
# ..        ...             ...              ...           ...             ...
# 813  FA(23:1)        9.056500           3867.0           112              81
# 814  FA(23:1)        9.199167           5653.0           112              81
# 815  FA(23:1)        9.468633           1362.0           112              81
# 816  FA(23:1)        9.595450           1240.0           112              81
# 817  FA(24:0)       25.890250           1010.0           116              86
#
#                    Sample_ID      Transition Sample  Parent_Ion  Product_Ion  \
# 0    02032025_FAME2_ozoneoff  281.2 -> 183.0   FAME       281.2        183.0
# 1    02032025_FAME2_ozoneoff  281.2 -> 183.0   FAME       281.2        183.0
# 2    02032025_FAME2_ozoneoff  281.2 -> 183.0   FAME       281.2        183.0
# 3    02032025_FAME2_ozoneoff  297.2 -> 183.0   FAME       297.2        183.0
# 4    02032025_FAME2_ozoneoff  295.2 -> 183.0   FAME       295.2        183.0
# ..                       ...             ...    ...         ...          ...
# 813  02032025_FAME2_ozoneoff  519.4 -> 183.0   FAME       519.4        183.0
# 814  02032025_FAME2_ozoneoff  519.4 -> 183.0   FAME       519.4        183.0
# 815  02032025_FAME2_ozoneoff  519.4 -> 183.0   FAME       519.4        183.0
# 816  02032025_FAME2_ozoneoff  519.4 -> 183.0   FAME       519.4        183.0
# 817  02032025_FAME2_ozoneoff  535.4 -> 183.0   FAME       535.4        183.0
#
#      ...   STD STD_RT_OFF STD_Peak_Intensity  STD_Peak_Area  Peak_Height  \
# 0    ...  None    10.8529       30991.421875   19264.541874       1388.0
# 1    ...  None    10.8529       30991.421875   19264.541874       1150.0
# 2    ...  None    10.8529       30991.421875   19264.541874       1050.0
# 3    ...  None    10.8529       30991.421875   19264.541874       3840.0
# 4    ...  None    10.8529       30991.421875   19264.541874       1375.0
# ..   ...   ...        ...                ...            ...          ...
# 813  ...  None    10.8529       30991.421875   19264.541874       3867.0
# 814  ...  None    10.8529       30991.421875   19264.541874       5653.0
# 815  ...  None    10.8529       30991.421875   19264.541874       1362.0
# 816  ...  None    10.8529       30991.421875   19264.541874       1240.0
# 817  ...  None    10.8529       30991.421875   19264.541874       1010.0
#
#          FWHM  Peak_Width   Peak_Area   Filter_Column  Isomer
# 0    0.112651    0.126817  122.772733  group_by_lipid     cis
# 1    0.144271    0.142667  121.143983  group_by_lipid   trans
# 2    0.188396    0.190217  155.224283  group_by_lipid    None
# 3    0.094653    0.095117  295.446167  group_by_lipid    None
# 4    0.116168    0.110950  123.788500  group_by_lipid    None
# ..        ...         ...         ...             ...     ...
# 813  0.066180    0.063400  228.136975  group_by_lipid     cis
# 814  0.209946    0.206067  888.826042  group_by_lipid   trans
# 815  0.038687    0.031700   40.568075  group_by_lipid    None
# 816  0.043040    0.047567   52.490758  group_by_lipid    None
# 817  0.087503    0.079250   63.296975  group_by_lipid    None
#
# [818 rows x 22 columns]

# %% [markdown]
# # OFF Possible

# %%
# !sbatch core/backend/FAME/OFF/off_possible_6_FAME.sh
# Out:
# Submitted batch job 22366132

# %% [markdown]
# # off possible

# %%
import pandas as pd
off_possible_df = pd.read_parquet('Projects/FAME/analysis/OFF/off_possible/df_analysis_CT_OFF_FAME.parquet')
# filter for lipid species 18:1
# off_possible_df = off_possible_df[off_possible_df['Lipid'].str.contains('18:1')]
off_possible_df
# Out:
#       Lipid  Retention_Time  OzESI_Intensity  group_by_ion  group_by_lipid  \
# 0  FA(14:1)        6.780800        1357242.0            56              26
# 1  FA(15:1)        7.699450        2286310.0            62              32
# 2  FA(16:1)        8.840017        2275957.0            68              38
# 3  FA(17:1)       10.186517        1813559.0            75              44
# 4  FA(18:1)       11.739217        2146677.0            81              50
# 5  FA(18:1)       12.341567        1465008.0            81              50
# 6  FA(20:1)       15.193333         267482.0            93              62
# 7  FA(20:1)       15.462800         200099.0            93              62
# 8  FA(22:1)       18.346133          50478.0           106              74
# 9  FA(22:1)       18.599750          53744.0           106              74
#
#                  Sample_ID      Transition Sample  Parent_Ion  Product_Ion  \
# 0  02032025_FAME2_ozoneoff  393.4 -> 183.0   FAME       393.4        183.0
# 1  02032025_FAME2_ozoneoff  407.3 -> 183.0   FAME       407.3        183.0
# 2  02032025_FAME2_ozoneoff  421.4 -> 183.0   FAME       421.4        183.0
# 3  02032025_FAME2_ozoneoff  435.4 -> 183.0   FAME       435.4        183.0
# 4  02032025_FAME2_ozoneoff  449.4 -> 183.0   FAME       449.4        183.0
# 5  02032025_FAME2_ozoneoff  449.4 -> 183.0   FAME       449.4        183.0
# 6  02032025_FAME2_ozoneoff  477.4 -> 183.0   FAME       477.4        183.0
# 7  02032025_FAME2_ozoneoff  477.4 -> 183.0   FAME       477.4        183.0
# 8  02032025_FAME2_ozoneoff  505.4 -> 183.0   FAME       505.4        183.0
# 9  02032025_FAME2_ozoneoff  505.4 -> 183.0   FAME       505.4        183.0
#
#    ...   STD STD_RT_OFF STD_Peak_Intensity  STD_Peak_Area  Peak_Height  \
# 0  ...  None    10.8529       30991.421875   19264.541874    1357242.0
# 1  ...  None    10.8529       30991.421875   19264.541874    2286310.0
# 2  ...  None    10.8529       30991.421875   19264.541874    2275957.0
# 3  ...  None    10.8529       30991.421875   19264.541874    1813559.0
# 4  ...  None    10.8529       30991.421875   19264.541874    2146677.0
# 5  ...  None    10.8529       30991.421875   19264.541874    1465008.0
# 6  ...  None    10.8529       30991.421875   19264.541874     267482.0
# 7  ...  None    10.8529       30991.421875   19264.541874     200099.0
# 8  ...  None    10.8529       30991.421875   19264.541874      50478.0
# 9  ...  None    10.8529       30991.421875   19264.541874      53744.0
#
#        FWHM  Peak_Width      Peak_Area   Filter_Column  Isomer
# 0  0.191092    0.190217  201653.266692  group_by_lipid     cis
# 1  0.219561    0.221917  386365.901900  group_by_lipid     cis
# 2  0.229769    0.221917  393942.916992  group_by_lipid     cis
# 3  0.330647    0.332883  476715.988250  group_by_lipid     cis
# 4  0.410633    0.396283  653492.560858  group_by_lipid     cis
# 5  0.274177    0.269467  368145.777217  group_by_lipid   trans
# 6  0.857503    0.871833  180722.015742  group_by_lipid     cis
# 7  0.039548    0.031700    6283.114350  group_by_lipid   trans
# 8  0.050706    0.047550    2342.463575  group_by_lipid     cis
# 9  1.345168    1.347367   54912.845750  group_by_lipid   trans
#
# [10 rows x 22 columns]

# %% [markdown]
# # Plots

# %%
df_group = pd.read_parquet('Projects/FAME/group/OFF/df_group_4_FAME_OFF.parquet')
df_group
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            255.2        183.0        3.014550             41.0
# 1            253.2        183.0        3.014667             41.0
# 2            241.1        183.0        3.014783             41.0
# 3            227.1        183.0        3.014900             41.0
# 4            255.2        183.0        3.030367            129.0
# ...            ...          ...             ...              ...
# 214049       425.4        183.0       31.935183             41.0
# 214050       425.4        183.0       31.951033             41.0
# 214051       425.4        183.0       31.966883             41.0
# 214052       425.4        183.0       31.982750             41.0
# 214053       425.4        183.0       31.998600             40.0
#
#                       Sample_ID      Transition Sample   STD  STD_RT_OFF  \
# 0       02032025_FAME2_ozoneoff  255.2 -> 183.0   FAME  None     10.8529
# 1       02032025_FAME2_ozoneoff  253.2 -> 183.0   FAME  None     10.8529
# 2       02032025_FAME2_ozoneoff  241.1 -> 183.0   FAME  None     10.8529
# 3       02032025_FAME2_ozoneoff  227.1 -> 183.0   FAME  None     10.8529
# 4       02032025_FAME2_ozoneoff  255.2 -> 183.0   FAME  None     10.8529
# ...                         ...             ...    ...   ...         ...
# 214049  02032025_FAME2_ozoneoff  425.4 -> 183.0   FAME  None     10.8529
# 214050  02032025_FAME2_ozoneoff  425.4 -> 183.0   FAME  None     10.8529
# 214051  02032025_FAME2_ozoneoff  425.4 -> 183.0   FAME  None     10.8529
# 214052  02032025_FAME2_ozoneoff  425.4 -> 183.0   FAME  None     10.8529
# 214053  02032025_FAME2_ozoneoff  425.4 -> 183.0   FAME  None     10.8529
#
#         STD_Peak_Intensity  STD_Peak_Area        Lipid Class    Species  \
# 0             30991.421875   19264.541874                     Unknown_1
# 1             30991.421875   19264.541874                     Unknown_1
# 2             30991.421875   19264.541874                     Unknown_1
# 3             30991.421875   19264.541874                     Unknown_1
# 4             30991.421875   19264.541874                     Unknown_1
# ...                    ...            ...          ...   ...        ...
# 214049        30991.421875   19264.541874  FA(d2-16:0)    FA       16:0
# 214050        30991.421875   19264.541874  FA(d2-16:0)    FA       16:0
# 214051        30991.421875   19264.541874  FA(d2-16:0)    FA       16:0
# 214052        30991.421875   19264.541874  FA(d2-16:0)    FA       16:0
# 214053        30991.421875   19264.541874  FA(d2-16:0)    FA       16:0
#
#        Biology Genotype Cage Mouse  group_by_ion  group_by_lipid
# 0                                              3               0
# 1                                              2               0
# 2                                              1               0
# 3                                              0               0
# 4                                              3               0
# ...        ...      ...  ...   ...           ...             ...
# 214049                                        70             112
# 214050                                        70             112
# 214051                                        70             112
# 214052                                        70             112
# 214053                                        70             112
#
# [214054 rows x 20 columns]

# %%
import matplotlib.pyplot as plt

# Function to plot the chromatogram for a specific group_by_lipid value
def plot_chromatogram(df, group_value):
    group_data = df[df['group_by_lipid'] == group_value]
    
    # Ensure the Retention_Time is sorted
    group_data = group_data.sort_values(by='Retention_Time')
    
    # Extract Lipid, Parent Ion, and Isomer values from the first row of the group
    lipid = group_data['Lipid'].iloc[0] if not group_data.empty else "Unknown Lipid"
    parent_ion = group_data['Parent_Ion'].iloc[0] if not group_data.empty else "Unknown Parent Ion"
    # isomer = group_data['Isomer'].iloc[0] if not group_data.empty else "Unknown Isomer"
    
    plt.figure(figsize=(10, 6))
    plt.plot(group_data['Retention_Time'], group_data['OzESI_Intensity'], label=f'group_by_lipid: {group_value}')
    plt.xlabel('Retention Time')
    plt.ylabel('OzESI Intensity')
    
    # Add Lipid, Parent Ion, and Isomer to the title
    plt.title(f'{group_value} | Lipid: {lipid} | Parent Ion: {parent_ion} ')
    
    plt.legend()
    plt.grid(True)
    plt.show()

# Define the specific group_by_lipid value you are interested in
specific_group_by_lipid_value = 50 # Replace with the actual value you are interested in

# Call the function to plot the chromatogram
plot_chromatogram(df_group, specific_group_by_lipid_value)

# %% [markdown]
# # STD

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter the data for Parent_Ion within range 425.40 ± 0.3
mask = (df_mzml['Parent_Ion'] >= 425.10) & (df_mzml['Parent_Ion'] <= 425.70)
filtered_df = df_mzml[mask]

# Create the plot
plt.figure(figsize=(10, 6))
plt.scatter(filtered_df['Retention_Time'], filtered_df['OzESI_Intensity'], 
           color='blue', alpha=0.6, label='Parent Ion 425.40 ± 0.3')

# Add labels and title
plt.xlabel('Retention Time (min)')
plt.ylabel('Intensity')
plt.title('Retention Time vs Intensity for Parent Ion 425.40 ± 0.3')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3913390/2598971039.py in <module>
#       3
#       4 # Filter the data for Parent_Ion within range 425.40 ± 0.3
# ----> 5 mask = (df_mzml['Parent_Ion'] >= 425.10) & (df_mzml['Parent_Ion'] <= 425.70)
#       6 filtered_df = df_mzml[mask]
#       7
#
# NameError: name 'df_mzml' is not defined
