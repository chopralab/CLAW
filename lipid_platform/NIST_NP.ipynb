# %%
import pandas as pd

# %% [markdown]
# # 1 - mzml parse

# %%
# !sbatch core/backend/NIST/NP/mzml_parser_1_CT_NP.sh
# Out:
# Submitted batch job 22190140

# %% [markdown]
# # 2 Sample

# %% [markdown]
# # 3 NP Match NP

# %%
# !sbatch core/backend/NIST/NP/match_3_CT_NP.sh
# Out:
# Submitted batch job 22375222

# %%
df_match = pd.read_parquet('Projects/NIST/match/NP/df_match_3_df_sample_2_NIST_n1_ON.parquet')
df_match
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            227.1        183.0        3.014900             41.0
# 1            227.1        183.0        3.030717             41.0
# 2            227.1        183.0        3.046567             41.0
# 3            227.1        183.0        3.062417             41.0
# 4            227.1        183.0        3.078267             41.0
# ...            ...          ...             ...              ...
# 214050       533.5        183.0       31.928683             41.0
# 214051       533.5        183.0       31.944533             41.0
# 214052       533.5        183.0       31.960383             41.0
# 214053       533.5        183.0       31.976233             42.0
# 214054       533.5        183.0       31.992083             41.0
#
#                              Sample_ID      Transition   Sample   STD  \
# 0       02032025_n1Plasma_AMP_ozoneoff  227.1 -> 183.0  NIST_n1  NIST
# 1       02032025_n1Plasma_AMP_ozoneoff  227.1 -> 183.0  NIST_n1  NIST
# 2       02032025_n1Plasma_AMP_ozoneoff  227.1 -> 183.0  NIST_n1  NIST
# 3       02032025_n1Plasma_AMP_ozoneoff  227.1 -> 183.0  NIST_n1  NIST
# 4       02032025_n1Plasma_AMP_ozoneoff  227.1 -> 183.0  NIST_n1  NIST
# ...                                ...             ...      ...   ...
# 214050  02032025_n1Plasma_AMP_ozoneoff  533.5 -> 183.0  NIST_n1  NIST
# 214051  02032025_n1Plasma_AMP_ozoneoff  533.5 -> 183.0  NIST_n1  NIST
# 214052  02032025_n1Plasma_AMP_ozoneoff  533.5 -> 183.0  NIST_n1  NIST
# 214053  02032025_n1Plasma_AMP_ozoneoff  533.5 -> 183.0  NIST_n1  NIST
# 214054  02032025_n1Plasma_AMP_ozoneoff  533.5 -> 183.0  NIST_n1  NIST
#
#        Replicate  STD_RT_OFF  STD_Peak_Intensity  STD_Peak_Area     Lipid  \
# 0             n1     10.9163        194676.15625   41300.839204
# 1             n1     10.9163        194676.15625   41300.839204
# 2             n1     10.9163        194676.15625   41300.839204
# 3             n1     10.9163        194676.15625   41300.839204
# 4             n1     10.9163        194676.15625   41300.839204
# ...          ...         ...                 ...            ...       ...
# 214050        n1     10.9163        194676.15625   41300.839204  FA(24:1)
# 214051        n1     10.9163        194676.15625   41300.839204  FA(24:1)
# 214052        n1     10.9163        194676.15625   41300.839204  FA(24:1)
# 214053        n1     10.9163        194676.15625   41300.839204  FA(24:1)
# 214054        n1     10.9163        194676.15625   41300.839204  FA(24:1)
#
#        Class
# 0
# 1
# 2
# 3
# 4
# ...      ...
# 214050    FA
# 214051    FA
# 214052    FA
# 214053    FA
# 214054    FA
#
# [214055 rows x 14 columns]

# %% [markdown]
# # 4 - group

# %%
# !sbatch core/backend/NIST/NP/group_4_CT_NP.sh
# Out:
# Submitted batch job 22375232

# %%
df_group = pd.read_parquet('Projects/NIST/group/NP/df_grouped_NIST_n1_OFF.parquet')
df_group
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            255.2        183.0        3.014550             41.0
# 1            253.2        183.0        3.014667             40.0
# 2            241.1        183.0        3.014783             40.0
# 3            227.1        183.0        3.014900             41.0
# 4            255.2        183.0        3.030367             41.0
# ...            ...          ...             ...              ...
# 214050       425.4        183.0       31.935183             42.0
# 214051       425.4        183.0       31.951033             41.0
# 214052       425.4        183.0       31.966900             41.0
# 214053       425.4        183.0       31.982750             41.0
# 214054       425.4        183.0       31.998600             42.0
#
#                              Sample_ID      Transition   Sample   STD  \
# 0       02032025_n1Plasma_AMP_ozoneoff  255.2 -> 183.0  NIST_n1  NIST
# 1       02032025_n1Plasma_AMP_ozoneoff  253.2 -> 183.0  NIST_n1  NIST
# 2       02032025_n1Plasma_AMP_ozoneoff  241.1 -> 183.0  NIST_n1  NIST
# 3       02032025_n1Plasma_AMP_ozoneoff  227.1 -> 183.0  NIST_n1  NIST
# 4       02032025_n1Plasma_AMP_ozoneoff  255.2 -> 183.0  NIST_n1  NIST
# ...                                ...             ...      ...   ...
# 214050  02032025_n1Plasma_AMP_ozoneoff  425.4 -> 183.0  NIST_n1  NIST
# 214051  02032025_n1Plasma_AMP_ozoneoff  425.4 -> 183.0  NIST_n1  NIST
# 214052  02032025_n1Plasma_AMP_ozoneoff  425.4 -> 183.0  NIST_n1  NIST
# 214053  02032025_n1Plasma_AMP_ozoneoff  425.4 -> 183.0  NIST_n1  NIST
# 214054  02032025_n1Plasma_AMP_ozoneoff  425.4 -> 183.0  NIST_n1  NIST
#
#        Replicate  STD_RT_OFF  ...  STD_Peak_Area        Lipid Class  \
# 0             n1     10.9163  ...   41300.839204
# 1             n1     10.9163  ...   41300.839204
# 2             n1     10.9163  ...   41300.839204
# 3             n1     10.9163  ...   41300.839204
# 4             n1     10.9163  ...   41300.839204
# ...          ...         ...  ...            ...          ...   ...
# 214050        n1     10.9163  ...   41300.839204  FA(d2-16:0)    FA
# 214051        n1     10.9163  ...   41300.839204  FA(d2-16:0)    FA
# 214052        n1     10.9163  ...   41300.839204  FA(d2-16:0)    FA
# 214053        n1     10.9163  ...   41300.839204  FA(d2-16:0)    FA
# 214054        n1     10.9163  ...   41300.839204  FA(d2-16:0)    FA
#
#              Species  Biology Genotype     Cage    Mouse group_by_ion  \
# 0       Unknown_5488  Unknown  Unknown  Unknown  Unknown            3
# 1       Unknown_3659  Unknown  Unknown  Unknown  Unknown            2
# 2       Unknown_1830  Unknown  Unknown  Unknown  Unknown            1
# 3          Unknown_1  Unknown  Unknown  Unknown  Unknown            0
# 4       Unknown_5489  Unknown  Unknown  Unknown  Unknown            3
# ...              ...      ...      ...      ...      ...          ...
# 214050          16:0  Unknown  Unknown  Unknown  Unknown           70
# 214051          16:0  Unknown  Unknown  Unknown  Unknown           70
# 214052          16:0  Unknown  Unknown  Unknown  Unknown           70
# 214053          16:0  Unknown  Unknown  Unknown  Unknown           70
# 214054          16:0  Unknown  Unknown  Unknown  Unknown           70
#
#         group_by_lipid
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 214050             112
# 214051             112
# 214052             112
# 214053             112
# 214054             112
#
# [214055 rows x 21 columns]

# %% [markdown]
# # 5 - Analysis

# %%
# !sbatch core/backend/NIST/NP/analysis_5_CT_NP.sh
# Out:
# Submitted batch job 22375495

# %%
import pandas as pd
df_analysis = pd.read_parquet('Projects/NIST/analysis/NP/df_analysis_5_NIST_n1_OFF.parquet')
df_analysis
# Out:
#          Lipid  Retention_Time  OzESI_Intensity  group_by_ion  group_by_lipid  \
# 0      FA(5:1)        9.814517           1329.0             5              89
# 1      FA(5:1)        9.988883            664.0             5              89
# 2      FA(5:1)       11.827633           1207.0             5              89
# 3      FA(5:1)       11.906883            935.0             5              89
# 4      FA(5:1)       11.970300            942.0             5              89
# ...        ...             ...              ...           ...             ...
# 1316  FA(23:2)       13.304783            959.0           111              82
# 1317  FA(23:2)       13.479150            998.0           111              82
# 1318  FA(23:2)       13.653517            532.0           111              82
# 1319  FA(23:2)       14.097350            609.0           111              82
# 1320  FA(23:5)        9.659350            861.0           108              85
#
#                            Sample_ID      Transition   Sample  Parent_Ion  \
# 0     02032025_n1Plasma_AMP_ozoneoff  267.2 -> 183.0  NIST_n1       267.2
# 1     02032025_n1Plasma_AMP_ozoneoff  267.2 -> 183.0  NIST_n1       267.2
# 2     02032025_n1Plasma_AMP_ozoneoff  267.2 -> 183.0  NIST_n1       267.2
# 3     02032025_n1Plasma_AMP_ozoneoff  267.2 -> 183.0  NIST_n1       267.2
# 4     02032025_n1Plasma_AMP_ozoneoff  267.2 -> 183.0  NIST_n1       267.2
# ...                              ...             ...      ...         ...
# 1316  02032025_n1Plasma_AMP_ozoneoff  517.4 -> 183.0  NIST_n1       517.4
# 1317  02032025_n1Plasma_AMP_ozoneoff  517.4 -> 183.0  NIST_n1       517.4
# 1318  02032025_n1Plasma_AMP_ozoneoff  517.4 -> 183.0  NIST_n1       517.4
# 1319  02032025_n1Plasma_AMP_ozoneoff  517.4 -> 183.0  NIST_n1       517.4
# 1320  02032025_n1Plasma_AMP_ozoneoff  511.4 -> 183.0  NIST_n1       511.4
#
#       Product_Ion Species Class   STD  STD_RT_OFF  Peak_Height      FWHM  \
# 0           183.0     5:1    FA  NIST     10.9163       1329.0  0.063071
# 1           183.0     5:1    FA  NIST     10.9163        664.0  0.116436
# 2           183.0     5:1    FA  NIST     10.9163       1207.0  0.150753
# 3           183.0     5:1    FA  NIST     10.9163        935.0  0.033840
# 4           183.0     5:1    FA  NIST     10.9163        942.0  0.035066
# ...           ...     ...   ...   ...         ...          ...       ...
# 1316        183.0    23:2    FA  NIST     10.9163        959.0  0.050359
# 1317        183.0    23:2    FA  NIST     10.9163        998.0  0.081651
# 1318        183.0    23:2    FA  NIST     10.9163        532.0  0.032657
# 1319        183.0    23:2    FA  NIST     10.9163        609.0  0.065404
# 1320        183.0    23:5    FA  NIST     10.9163        861.0  0.079424
#
#       Peak_Width   Peak_Area   Filter_Column Isomer
# 0       0.063417   84.280750  group_by_lipid    cis
# 1       0.126817   84.206267  group_by_lipid   None
# 2       0.142667  172.198667  group_by_lipid  trans
# 3       0.031700   29.639500  group_by_lipid   None
# 4       0.031700   29.861400  group_by_lipid   None
# ...          ...         ...             ...    ...
# 1316    0.047550   45.600450  group_by_lipid   None
# 1317    0.095100   94.909800  group_by_lipid   None
# 1318    0.031700   16.864400  group_by_lipid   None
# 1319    0.063400   38.610600  group_by_lipid   None
# 1320    0.079250   68.234250  group_by_lipid   None
#
# [1321 rows x 20 columns]

# %% [markdown]
# # 6 - Not Possible

# %%
# !sbatch core/backend/NIST/NP/notpossible_9_CT_NP.sh
# Out:
# Submitted batch job 22375812

# %%
import pandas as pd
import os
import glob

def list_files_in_dirs(dir1, dir2, extension='*.parquet'):
    """
    Lists file names from two directories and creates keys for matching, explicitly handling "CisTrans" cases.

    Parameters:
    dir1 (str): Path to the first directory.
    dir2 (str): Path to the second directory.
    extension (str): File extension to match (default: '*.parquet').

    Returns:
    DataFrame: DataFrame containing file names from both directories and their keys.
    """
    # Get list of files in both directories
    files1 = glob.glob(os.path.join(dir1, extension))
    files2 = glob.glob(os.path.join(dir2, extension))

    # Debugging: Print file lists
    print(f"Files in {dir1}: {files1}")
    print(f"Files in {dir2}: {files2}")

    # Create separate DataFrames for each directory
    df1 = pd.DataFrame({
        'File': [os.path.basename(f) for f in files1],
        'Key': ["CisTrans" if "CisTrans" in os.path.basename(f) else os.path.basename(f).replace('.parquet', '') for f in files1]
    })
    df2 = pd.DataFrame({
        'File': [os.path.basename(f) for f in files2],
        'Key': ["CisTrans" if "CisTrans" in os.path.basename(f) else os.path.basename(f).replace('.parquet', '') for f in files2]
    })

    # Debugging: Print DataFrames before processing
    print(f"Initial DataFrame 1:\n{df1}")
    print(f"Initial DataFrame 2:\n{df2}")

    # Merge the DataFrames on the Key column
    merged_df = pd.merge(
        df1, 
        df2, 
        on='Key', 
        how='inner',  # Only keep pairs with matching keys
        suffixes=('_OzON', '_OzOFF')
    )

    # Debugging: Print merged DataFrame
    print(f"Merged DataFrame:\n{merged_df}")

    return merged_df

def match_lipids_with_adjusted_rt_to_rt_from_dirs(dir1, dir2, output_dir, rt_window=0.5):
    """
    Matches lipids between files in two directories using retention time and keys.

    Parameters:
    dir1 (str): Directory containing OzON files.
    dir2 (str): Directory containing OzOFF files.
    output_dir (str): Directory to save matched and unmatched results.
    rt_window (float): Retention time window for matching (default: 0.5).
    """
    # Get matched file pairs based on keys
    file_pairs = list_files_in_dirs(dir1, dir2)

    # Iterate through each matched pair of files
    for _, row in file_pairs.iterrows():
        ozon_file = os.path.join(dir1, row['File_OzON'])
        ozoff_file = os.path.join(dir2, row['File_OzOFF'])

        # Load the data from the matched files
        ozon_test = pd.read_parquet(ozon_file)
        sorted_notpossible_lipids = pd.read_parquet(ozoff_file)

        # Debugging: Print the first few rows of both DataFrames
        print(f"OzON DataFrame for {row['File_OzON']}:\n{ozon_test.head()}")
        print(f"OzOFF DataFrame for {row['File_OzOFF']}:\n{sorted_notpossible_lipids.head()}")

        # Create new columns in the ON data to store matched information from OFF
        ozon_test['Matched_Lipid_OFF'] = None
        ozon_test['Intensity_OFF'] = None
        ozon_test['Retention_Time_OFF'] = None

        # Perform lipid matching
        for index_on, row_on in ozon_test.iterrows():
            on_lipid = row_on['Lipid'].strip()  # Trim spaces for accurate matching
            on_adjusted_rt = row_on['Adjusted_RT']
            match_found = False

            for _, row_off in sorted_notpossible_lipids.iterrows():
                off_lipids = [lipid.strip() for lipid in row_off['Lipid'].split('|')]
                off_retention_time = row_off['Retention_Time']

                # Debugging: Print lipid comparison details
                print(f"Comparing ON lipid {on_lipid} (RT: {on_adjusted_rt}) with OFF lipids {off_lipids} (RT: {off_retention_time})")

                if any(on_lipid.lower() == off_lipid.lower() for off_lipid in off_lipids) and abs(on_adjusted_rt - off_retention_time) <= rt_window:
                    ozon_test.at[index_on, 'Matched_Lipid_OFF'] = row_off['Lipid']
                    ozon_test.at[index_on, 'Intensity_OFF'] = row_off['OzESI_Intensity']
                    ozon_test.at[index_on, 'Retention_Time_OFF'] = off_retention_time
                    match_found = True
                    break

            if not match_found:
                print(f"No match found for ON lipid {on_lipid} with Adjusted RT {on_adjusted_rt}")

        # Separate matched and unmatched lipids
        matched_lipids_df = ozon_test.dropna(subset=['Matched_Lipid_OFF']).copy()
        unmatched_lipids_df = ozon_test[ozon_test['Matched_Lipid_OFF'].isna()].copy()

        # Save results
        os.makedirs(output_dir, exist_ok=True)  # Ensure output directory exists
        matched_file = os.path.join(output_dir, f"matched_{row['Key']}.csv")
        unmatched_file = os.path.join(output_dir, f"unmatched_{row['Key']}.csv")

        matched_lipids_df.to_csv(matched_file, index=False)
        unmatched_lipids_df.to_csv(unmatched_file, index=False)

        print(f"Processed files: {row['File_OzON']} and {row['File_OzOFF']}")
        print(f"Saved matched lipids to {matched_file}")
        print(f"Saved unmatched lipids to {unmatched_file}")

# Example usage
ozon_dir = 'Projects/NIST/isomer_filter/'
ozoff_dir = 'Projects/NIST/analysis/NP/'
output_dir = 'Projects/NIST/not_possible/'

match_lipids_with_adjusted_rt_to_rt_from_dirs(ozon_dir, ozoff_dir, output_dir, rt_window=0.1)
# Out:
# Files in Projects/NIST/isomer_filter/: ['Projects/NIST/isomer_filter/NIST_n2_isomer_filtered.parquet', 'Projects/NIST/isomer_filter/Blank_isomer_filtered.parquet', 'Projects/NIST/isomer_filter/NIST_n1_isomer_filtered.parquet', 'Projects/NIST/isomer_filter/NIST_n3_isomer_filtered.parquet']
# Files in Projects/NIST/analysis/NP/: ['Projects/NIST/analysis/NP/df_analysis_5_Blank_OFF.parquet', 'Projects/NIST/analysis/NP/df_analysis_5_NIST_n2_OFF.parquet', 'Projects/NIST/analysis/NP/df_analysis_5_NIST_n3_OFF.parquet', 'Projects/NIST/analysis/NP/df_analysis_5_NIST_n1_OFF.parquet']
# Initial DataFrame 1:
#                               File                      Key
# 0  NIST_n2_isomer_filtered.parquet  NIST_n2_isomer_filtered
# 1    Blank_isomer_filtered.parquet    Blank_isomer_filtered
# 2  NIST_n1_isomer_filtered.parquet  NIST_n1_isomer_filtered
# 3  NIST_n3_isomer_filtered.parquet  NIST_n3_isomer_filtered
# Initial DataFrame 2:
#                                 File                        Key
# 0    df_analysis_5_Blank_OFF.parquet    df_analysis_5_Blank_OFF
# 1  df_analysis_5_NIST_n2_OFF.parquet  df_analysis_5_NIST_n2_OFF
# 2  df_analysis_5_NIST_n3_OFF.parquet  df_analysis_5_NIST_n3_OFF
# 3  df_analysis_5_NIST_n1_OFF.parquet  df_analysis_5_NIST_n1_OFF
# Merged DataFrame:
# Empty DataFrame
# Columns: [File_OzON, Key, File_OzOFF]
# Index: []

# %% [markdown]
# # 6 Not possible unmatched

# %%
NP_unmatched = pd.read_csv('Projects/NIST/not_possible/unmatched_NIST_n1.csv')
NP_unmatched
NP_unmatched[(NP_unmatched['Species'] == '18:1') & (NP_unmatched['n_value'] == 9)]
# Out:
#                 Lipid  Retention_Time  OzESI_Intensity  group_by_ion  \
# 380  FA(18:1)_<>_n-9        12.537617         198004.0            32
#
#      group_by_lipid                        Sample_ID      Transition   Sample  \
# 380             289  02032025_n1Plasma_AMP_ozoneonv2  339.3 -> 183.0  NIST_n1
#
#      Parent_Ion  Product_Ion  ... Genotype Cage Mouse  Normalized_Peak_Area  \
# 380       339.3        183.0  ...      NaN  NaN   NaN              0.158646
#
#      n_value  n_position  OzOFF_Isomer  Matched_Lipid_OFF Intensity_OFF  \
# 380        9         9.0         trans                NaN           NaN
#
#      Retention_Time_OFF
# 380                 NaN
#
# [1 rows x 41 columns]

# %% [markdown]
# # 6 Not possible Matched

# %%
NP_matched = pd.read_csv('Projects/NIST/not_possible/matched_NIST_n1.csv')
NP_matched
# filter for 18:1 Species
NP_matched[(NP_matched['Species'] == '18:1') & (NP_matched['n_value'] == 9)]
# Out:
#                 Lipid  Retention_Time  OzESI_Intensity  group_by_ion  \
# 931  FA(18:1)_<>_n-9        11.871867         531867.0            32
# 932  FA(18:1)_<>_n-9        11.935267         525052.0            32
#
#      group_by_lipid                        Sample_ID      Transition   Sample  \
# 931             289  02032025_n1Plasma_AMP_ozoneonv2  339.3 -> 183.0  NIST_n1
# 932             289  02032025_n1Plasma_AMP_ozoneonv2  339.3 -> 183.0  NIST_n1
#
#      Parent_Ion  Product_Ion  ... Genotype Cage Mouse  Normalized_Peak_Area  \
# 931       339.3        183.0  ...      NaN  NaN   NaN              4.627033
# 932       339.3        183.0  ...      NaN  NaN   NaN              0.420426
#
#      n_value  n_position  OzOFF_Isomer  Matched_Lipid_OFF Intensity_OFF  \
# 931        9         9.0           cis           FA(18:1)     6803927.0
# 932        9         9.0           cis           FA(18:1)     6803927.0
#
#      Retention_Time_OFF
# 931           11.802633
# 932           11.802633
#
# [2 rows x 41 columns]

# %% [markdown]
# # 7 - Combine Double Bonds

# %%
import pandas as pd
import numpy as np
import itertools

def n_value_combine_updated(df, retention_time_threshold=0.2):
    """
    Combines lipid n-values based on specified rules:
    - Combines n-values with the same Retention_Time within the threshold.
    - Groups n-values to meet the expected positions of FA(x:y).
    - Adds a 'Copy' column for each combination if necessary.
    - Includes 'Parent_Ion' and 'group_by_lipid' columns in the output, aggregating all relevant values separated by '| '.
    - Rounds Retention_Time to 1 decimal place in the output.

    Parameters:
    - df (DataFrame): Input DataFrame containing 'Lipid', 'Parent_Ion', 'group_by_lipid', and 'Retention_Time' columns.
    - retention_time_threshold (float): Maximum difference in retention time to consider lipids similar.

    Returns:
    - DataFrame: New DataFrame with combined lipid values, rounded Retention Times, 'Copy' column (if applicable),
                 'Parent_Ion' and 'group_by_lipid' columns with values separated by '| ', and 'total_n_values' column indicating the count of n_values per species.
    """
    required_columns = ['Parent_Ion', 'group_by_lipid', 'Lipid', 'Retention_Time']
    missing_columns = [col for col in required_columns if col not in df.columns]
    if missing_columns:
        raise ValueError(f"Input DataFrame is missing required columns: {', '.join(missing_columns)}")

    df['Parent_Ion'] = df['Parent_Ion'].astype(str)
    df['group_by_lipid'] = df['group_by_lipid'].astype(str)

    lipid_pattern = r'(FA\(\d+:\d+\))_<(.*?)>_n-(\d+)'
    extracted = df['Lipid'].str.extract(lipid_pattern, expand=True)
    if extracted.isnull().values.any():
        raise ValueError("Some entries in 'Lipid' column do not match the expected pattern 'FA(x:y)_<positions>_n-z'.")
    df[['FA', 'positions', 'n_value']] = extracted
    df['n_value'] = df['n_value'].astype(int)

    df['Retention_Time'] = pd.to_numeric(df['Retention_Time'], errors='coerce')
    if df['Retention_Time'].isnull().any():
        raise ValueError("Some 'Retention_Time' values could not be converted to float.")
    df['Retention_Time'] = df['Retention_Time'].round(1)

    total_positions_pattern = r'FA\(\d+:(\d+)\)'
    extracted_positions = df['FA'].str.extract(total_positions_pattern)
    if extracted_positions.isnull().values.any():
        raise ValueError("Some entries in 'FA' column do not match the expected pattern 'FA(x:y)'.")
    df['total_positions'] = extracted_positions[0].astype(int)

    df = df.sort_values(by=['FA', 'Retention_Time', 'n_value']).reset_index(drop=True)

    combined_results = []
    separator = '| '

    for fa, fa_group in df.groupby('FA'):
        expected_positions = fa_group['total_positions'].iloc[0]

        # Cluster by Retention_Time within threshold
        fa_group = fa_group.sort_values(by='Retention_Time').reset_index(drop=True)
        while not fa_group.empty:
            seed = fa_group.iloc[0]
            seed_retention_time = seed['Retention_Time']

            mask = abs(fa_group['Retention_Time'] - seed_retention_time) <= retention_time_threshold
            cluster = fa_group[mask]
            fa_group = fa_group[~mask]

            n_values = sorted(set(cluster['n_value'].tolist()))
            n_values_times = dict(zip(cluster['n_value'], cluster['Retention_Time']))
            n_values_parent_ions = dict(zip(cluster['n_value'], cluster['Parent_Ion']))
            n_values_group_by_lipid = dict(zip(cluster['n_value'], cluster['group_by_lipid']))

            num_n_values = len(n_values)

            if num_n_values > expected_positions:
                combinations_list = list(itertools.combinations(n_values, expected_positions))
                for idx, comb in enumerate(combinations_list, 1):
                    n_values_str = ' '.join([f"n-{n}" for n in comb])
                    retention_times = [str(n_values_times[n]) for n in comb]
                    retention_times_str = ','.join(retention_times)
                    parent_ions = [n_values_parent_ions[n] for n in comb]
                    parent_ions_str = separator.join(parent_ions)
                    group_by_lipids = [n_values_group_by_lipid[n] for n in comb]
                    group_by_lipids_str = separator.join(group_by_lipids)

                    combined_lipid = f"{fa} {n_values_str}"

                    combined_results.append({
                        'Lipid': combined_lipid,
                        'Parent_Ion': parent_ions_str,
                        'group_by_lipid': group_by_lipids_str,
                        'Retention_Time': retention_times_str,
                        'Copy': f"Copy{idx}",
                        'total_n_values': num_n_values
                    })
            else:
                n_values_str = ' '.join([f"n-{n}" for n in n_values])
                combined_lipid = f"{fa} {n_values_str}".strip()
                retention_times = [str(n_values_times[n]) for n in n_values]
                retention_times_str = ','.join(retention_times)
                parent_ions = [n_values_parent_ions[n] for n in n_values]
                parent_ions_str = separator.join(parent_ions)
                group_by_lipids = [n_values_group_by_lipid[n] for n in n_values]
                group_by_lipids_str = separator.join(group_by_lipids)

                combined_results.append({
                    'Lipid': combined_lipid,
                    'Parent_Ion': parent_ions_str,
                    'group_by_lipid': group_by_lipids_str,
                    'Retention_Time': retention_times_str,
                    'Copy': np.nan,
                    'total_n_values': num_n_values
                })

    df_combined_n_values = pd.DataFrame(combined_results)
    df_combined_n_values = df_combined_n_values[['Lipid', 'Parent_Ion', 'group_by_lipid', 'Retention_Time', 'Copy', 'total_n_values']]
    df_combined_n_values['Copy'] = df_combined_n_values['Copy'].replace('', np.nan)

    return df_combined_n_values


# Apply the function
df_combined_n_values = n_value_combine_updated(NP_unmatched)

# Display the first 60 rows
df_combined_n_values.head(60)
# Out:
#                    Lipid           Parent_Ion group_by_lipid Retention_Time  \
# 0           FA(18:1) n-4                409.3              9           11.3
# 1           FA(18:1) n-5                395.3             10           11.3
# 2           FA(18:1) n-6                381.3             11           11.3
# 3           FA(18:1) n-7                367.3             12           11.3
# 4           FA(18:1) n-8                353.3             13           11.3
# 5           FA(18:1) n-9                339.3             14           11.3
# 6          FA(18:1) n-10                325.2              0           11.5
# 7           FA(18:1) n-2                437.4              7           11.7
# 8           FA(18:1) n-3                423.3              8           11.7
# 9           FA(18:1) n-4                409.3              9           11.7
# 10          FA(18:1) n-5                395.3             10           11.7
# 11          FA(18:1) n-6                381.3             11           11.7
# 12          FA(18:1) n-7                367.3             12           11.7
# 13          FA(18:1) n-8                353.3             13           11.7
# 14          FA(18:1) n-9                339.3             14           11.7
# 15         FA(18:1) n-11                311.3              1           11.6
# 16          FA(18:1) n-5                395.3             10           11.8
# 17          FA(18:1) n-8                353.3             13           12.0
# 18          FA(18:1) n-9                339.3             14           12.0
# 19         FA(18:1) n-10                325.2              0           11.9
# 20         FA(18:1) n-12                297.2              2           11.8
# 21          FA(18:1) n-9                339.3             14           12.1
# 22         FA(18:1) n-10                325.2              0           12.1
# 23         FA(18:1) n-11                311.3              1           12.2
# 24         FA(18:1) n-12                297.2              2           12.2
# 25         FA(18:1) n-13                283.2              3           12.4
# 26      FA(18:2) n-6 n-9         379.3| 339.3         25| 43        9.6,9.6
# 27  FA(18:3) n-3 n-5 n-6  419.3| 395.3| 379.3     50| 80| 67    8.0,7.9,8.0
# 28  FA(18:3) n-3 n-5 n-9  419.3| 395.3| 339.3     50| 80| 84    8.0,7.9,8.0
# 29  FA(18:3) n-3 n-6 n-9  419.3| 379.3| 339.3     50| 67| 84    8.0,8.0,8.0
# 30  FA(18:3) n-5 n-6 n-9  395.3| 379.3| 339.3     80| 67| 84    7.9,8.0,8.0
#
#      Copy  total_n_values
# 0   Copy1               7
# 1   Copy2               7
# 2   Copy3               7
# 3   Copy4               7
# 4   Copy5               7
# 5   Copy6               7
# 6   Copy7               7
# 7   Copy1               9
# 8   Copy2               9
# 9   Copy3               9
# 10  Copy4               9
# 11  Copy5               9
# 12  Copy6               9
# 13  Copy7               9
# 14  Copy8               9
# 15  Copy9               9
# 16  Copy1               5
# 17  Copy2               5
# 18  Copy3               5
# 19  Copy4               5
# 20  Copy5               5
# 21  Copy1               4
# 22  Copy2               4
# 23  Copy3               4
# 24  Copy4               4
# 25    NaN               1
# 26    NaN               2
# 27  Copy1               4
# 28  Copy2               4
# 29  Copy3               4
# 30  Copy4               4
