# %%
import pandas as pd

# List of file names
file_names = [f'FF_OzMatched_{i}.csv' for i in range(1, 11)]

# Initialize an empty DataFrame
combined_df = pd.DataFrame()

# Loop through each file and append its contents to the combined DataFrame
for file in file_names:
    temp_df = pd.read_csv(file)
    combined_df = combined_df.append(temp_df, ignore_index=True)

# Save the combined DataFrame to a new CSV file
combined_df.to_csv('FF_OzMatched_full.csv', index=False)

# Display the combined DataFrame (optional)
combined_df.head(None)
# Out:
# /home/iyer95/.conda/envs/CLA/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3258: DtypeWarning: Columns (1,2) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          Unnamed: 0 Class                        Lipid  OzESI_Intensity  \
# 0                 0   NaN                          NaN        42.920002
# 1                 1   NaN                          NaN        42.540005
# 2                 2   NaN                          NaN        43.180004
# 3                 3   NaN                          NaN        42.780003
# 4                 4   NaN                          NaN        42.720001
# ...             ...   ...                          ...              ...
# 4137608      413759   TAG  [TG(59:11),TG(58:4)]_FA18:1        41.080002
# 4137609      413760   TAG  [TG(59:11),TG(58:4)]_FA18:1        40.980003
# ...
