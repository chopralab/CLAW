# %%
import pandas as pd
directory = 'Projects/AMP/results/fame_mix/'
file_name_ON = 'FAME_OzON.xlsx'
file_name_OFF = 'FAME_OzOFF.xlsx'

OzON_df = pd.read_excel(directory + file_name_ON)
OzOFF_df = pd.read_excel(directory + file_name_OFF)

# Drop 'Unnamed: 0' columns if they exist
OzON_df.drop(columns='Unnamed: 0', errors='ignore', inplace=True)
OzOFF_df.drop(columns='Unnamed: 0', errors='ignore', inplace=True)

# %%
OzOFF_df
# Out:
#        Lipid  Retention_Time  OzESI_Intensity  Match_Group  Group_Sample  \
# 0        NaN        4.086000     8.830661e+04           10            -1
# 1      11:0         4.373650     2.386627e+05           12             0
# 2       12:0        4.818250     7.051023e+05           15             1
# 3       13:0        5.525183     5.041493e+05           18             2
# 4   14:1(9Z)        5.314400     8.342626e+05           20             4
# 5       14:0        6.337033     1.573355e+06           21             3
# 6       15:1        6.073350     8.820002e+05           24             6
# 7       15:1        6.072883     1.323773e+06           25             6
# 8      15:0         7.279150     8.578846e+05           26             5
# 9       16:1        6.910983     1.813371e+06           28             8
# 10      16:0        8.195950     2.398234e+06           29             7
# 11   d2-16:0        8.169267     2.080406e+05           30            32
# 12      17:1        7.801083     2.232096e+06           32            10
# 13      17:0        9.217217     5.473852e+05           33             9
# 14      18:3        6.593000     1.362001e+06           35            14
# 15      18:3        6.776617     2.320712e+06           35            14
# 16      18:2        7.563167     1.625683e+06           36            13
# 17      18:2        8.035350     1.831706e+06           36            13
# 18      18:1        8.743200     4.043347e+06           37            12
# 19      18:1        9.057983     2.013433e+06           37            12
# 20      18:0        8.742733     6.815145e+04           38            11
# 21      18:0       10.211783     6.591829e+05           38            11
# 22      20:5        6.669867     1.621650e+06           39            20
# 23      20:4        7.613800     2.003592e+06           40            19
# 24      20:3        8.269167     2.384459e+06           41            18
# 25      20:2        9.318033     1.269626e+06           42            17
# 26      20:1       10.629233     1.023483e+06           43            16
# 27     20:0        12.255250     1.442046e+05           44            15
# 28      22:6        7.558583     2.139168e+06           46            25
# 29      22:2       11.178317     4.360343e+05           47            24
# 30      22:1       12.541983     2.740780e+05           48            23
# 31      24:1       14.534317     5.569380e+04           51            28
#
#                                             Sample_ID  Parent_Ion  \
# 0   11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       339.3
# 1   11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       353.3
# 2   11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       367.3
# 3   11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       381.3
# 4   11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       393.4
# 5   11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       395.4
# 6   11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       407.2
# 7   11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       407.4
# 8   11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       409.4
# 9   11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       421.4
# 10  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       423.4
# 11  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       425.4
# 12  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       435.4
# 13  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       437.4
# 14  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       445.4
# 15  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       445.4
# 16  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       447.4
# 17  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       447.4
# 18  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       449.4
# 19  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       449.4
# 20  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       451.4
# 21  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       451.4
# 22  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       469.4
# 23  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       471.4
# 24  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       473.4
# 25  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       475.4
# 26  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       477.4
# 27  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       479.4
# 28  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       495.4
# 29  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       503.4
# 30  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       505.4
# 31  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       533.4
#
#     Product_Ion       FAC  Biology  Genotype  Cage  Mouse   Peak_Height  \
# 0           183        []      NaN       NaN   NaN    NaN  8.830661e+04
# 1           183  ['11:0']      NaN       NaN   NaN    NaN  2.386627e+05
# 2           183  ['12:0']      NaN       NaN   NaN    NaN  7.051023e+05
# 3           183  ['13:0']      NaN       NaN   NaN    NaN  5.041493e+05
# 4           183  ['14:1']      NaN       NaN   NaN    NaN  8.342626e+05
# 5           183  ['14:0']      NaN       NaN   NaN    NaN  1.573355e+06
# 6           183  ['15:1']      NaN       NaN   NaN    NaN  8.820002e+05
# 7           183  ['15:1']      NaN       NaN   NaN    NaN  1.323773e+06
# 8           183  ['15:0']      NaN       NaN   NaN    NaN  8.578846e+05
# 9           183  ['16:1']      NaN       NaN   NaN    NaN  1.813371e+06
# 10          183  ['16:0']      NaN       NaN   NaN    NaN  2.398234e+06
# 11          183  ['16:0']      NaN       NaN   NaN    NaN  2.080406e+05
# 12          183  ['17:1']      NaN       NaN   NaN    NaN  2.232096e+06
# 13          183  ['17:0']      NaN       NaN   NaN    NaN  5.473852e+05
# 14          183  ['18:3']      NaN       NaN   NaN    NaN  1.362001e+06
# 15          183  ['18:3']      NaN       NaN   NaN    NaN  2.320712e+06
# 16          183  ['18:2']      NaN       NaN   NaN    NaN  1.625683e+06
# 17          183  ['18:2']      NaN       NaN   NaN    NaN  1.831706e+06
# 18          183  ['18:1']      NaN       NaN   NaN    NaN  4.043347e+06
# 19          183  ['18:1']      NaN       NaN   NaN    NaN  2.013433e+06
# 20          183  ['18:0']      NaN       NaN   NaN    NaN  6.815145e+04
# 21          183  ['18:0']      NaN       NaN   NaN    NaN  6.591829e+05
# 22          183  ['20:5']      NaN       NaN   NaN    NaN  1.621650e+06
# 23          183  ['20:4']      NaN       NaN   NaN    NaN  2.003592e+06
# 24          183  ['20:3']      NaN       NaN   NaN    NaN  2.384459e+06
# 25          183  ['20:2']      NaN       NaN   NaN    NaN  1.269626e+06
# 26          183  ['20:1']      NaN       NaN   NaN    NaN  1.023483e+06
# 27          183  ['20:0']      NaN       NaN   NaN    NaN  1.442046e+05
# 28          183  ['22:6']      NaN       NaN   NaN    NaN  2.139168e+06
# 29          183  ['22:2']      NaN       NaN   NaN    NaN  4.360343e+05
# 30          183  ['22:1']      NaN       NaN   NaN    NaN  2.740780e+05
# 31          183  ['24:1']      NaN       NaN   NaN    NaN  5.569380e+04
#
#             FWHM  Peak_Width     Peak_Area
# 0   4.417383e+04    3.024777  2.671078e+05
# 1   1.193519e+05    2.985645  7.125619e+05
# 2   3.525717e+05    3.481314  2.454683e+06
# 3   2.520953e+05    3.854480  1.943234e+06
# 4   4.171519e+05    3.700393  3.087099e+06
# 5   7.867077e+05    4.038937  6.354681e+06
# 6   4.410207e+05    3.952011  3.485674e+06
# 7   6.619096e+05    3.905462  5.169945e+06
# 8   4.289629e+05    4.393295  3.768940e+06
# 9   9.067083e+05    3.982506  7.221760e+06
# 10  1.199208e+06    3.855874  9.247287e+06
# 11  1.040409e+05    3.730332  7.760605e+05
# 12  1.116087e+06    4.299067  9.595929e+06
# 13  2.737281e+05    5.166337  2.827977e+06
# 14  8.455270e+05    2.832412  3.857749e+06
# 15  1.160392e+06    3.729877  8.655971e+06
# 16  8.320961e+05    3.560249  5.787837e+06
# 17  9.159314e+05    4.393906  8.048346e+06
# 18  2.022032e+06    4.862928  1.966250e+07
# 19  1.309715e+06    3.423079  6.892139e+06
# 20  3.424467e+04    4.843244  3.300741e+05
# 21  3.296834e+05    6.234862  4.109914e+06
# 22  8.108457e+05    3.433274  5.567570e+06
# 23  1.001817e+06    3.828277  7.670306e+06
# 24  1.192294e+06    4.992302  1.190394e+07
# 25  6.348484e+05    4.109634  5.217699e+06
# 26  5.118593e+05    5.497463  5.626558e+06
# 27  7.218223e+04    7.738091  1.115868e+06
# 28  1.069612e+06    3.488537  7.462566e+06
# 29  2.180709e+05    6.061085  2.642841e+06
# 30  1.372193e+05    8.096856  2.219170e+06
# 31  2.786751e+04   10.730996  5.976500e+05

# %%
OzON_df
# Out:
#                                                 Lipid  Retention_Time  \
# 0   22:6 (4Z,7Z,10Z,13Z,16Z,19Z)n-3,n-6,n-9,n-12,n...        7.579050
# 1   6:0 / 20:5 (5Z,8Z,11Z,14Z,17Z)n-3,n-6,n-9,n-12...        6.686683
# 2   6:0 / 20:5 (5Z,8Z,11Z,14Z,17Z)n-3,n-6,n-9,n-12...        7.631067
# 3   6:0 / 20:5 (5Z,8Z,11Z,14Z,17Z)n-3,n-6,n-9,n-12...        6.686233
# 4   6:0 / 20:5 (5Z,8Z,11Z,14Z,17Z)n-3,n-6,n-9,n-12...        7.630617
# ..                                                ...             ...
# 78                                               20:1       10.655467
# 79                           20:0 / 21:1n-2 / 22:1n-3       12.281450
# 80                                               22:6        7.584817
# 81                                               22:2       11.204517
# 82                                               22:1       12.568183
#
#     OzESI_Intensity  Match_Group  Group_Sample  \
# 0      64931.144531            1            43
# 1      64325.605469            2            48
# 2      91986.468750            2            48
# 3      70811.421875            3            48
# 4     105181.585938            3            48
# ..              ...          ...           ...
# 78    625269.312500           43            21
# 79    147127.203125           44            20
# 80    314451.750000           46            37
# 81    164623.828125           47            36
# 82    155917.515625           48            35
#
#                                             Sample_ID  Parent_Ion  \
# 0   11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       269.1
# 1   11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       283.1
# 2   11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       283.1
# 3   11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       283.3
# 4   11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       283.3
# ..                                                ...         ...
# 78  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       477.4
# 79  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       479.4
# 80  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       495.4
# 81  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       503.4
# 82  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       505.4
#
#     Product_Ion                                                FAC  Biology  \
# 0           183  ['22:6', '12:1', '13:1', '14:1', '15:1', '16:1...      NaN
# 1           183  ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1'...      NaN
# 2           183  ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1'...      NaN
# 3           183  ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1'...      NaN
# 4           183  ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1'...      NaN
# ..          ...                                                ...      ...
# 78          183                                           ['20:1']      NaN
# 79          183                           ['20:0', '21:1', '22:1']      NaN
# 80          183                                           ['22:6']      NaN
# 81          183                                           ['22:2']      NaN
# 82          183                                           ['22:1']      NaN
#
#     Genotype  Cage  Mouse    Peak_Height           FWHM  Peak_Width  \
# 0        NaN   NaN    NaN   64931.144531   32486.192266    3.429790
# 1        NaN   NaN    NaN   64325.605469   32196.472736    3.489308
# 2        NaN   NaN    NaN   91986.468750   46013.814377    3.721541
# 3        NaN   NaN    NaN   70811.421875   35462.490940    3.585388
# 4        NaN   NaN    NaN  105181.585938   52611.432970    3.799448
# ..       ...   ...    ...            ...            ...         ...
# 78       NaN   NaN    NaN  625269.312500  312673.366253    5.567599
# 79       NaN   NaN    NaN  147127.203125   73680.271568    8.632935
# 80       NaN   NaN    NaN  314451.750000  157246.545002    3.533352
# 81       NaN   NaN    NaN  164623.828125   82341.794065    6.204903
# 82       NaN   NaN    NaN  155917.515625   78019.937817    7.699657
#
#        Peak_Area
# 0   2.227002e+05
# 1   2.244519e+05
# 2   3.423315e+05
# 3   2.538864e+05
# 4   3.996319e+05
# ..           ...
# 78  3.481249e+06
# 79  1.270140e+06
# 80  1.111069e+06
# 81  1.021475e+06
# 82  1.200511e+06
#
# [83 rows x 17 columns]

# %%
# Assuming OzON_df and OzOFF_df are your existing DataFrame variables

# Print the data type of the FAC column in OzON_df
print("Data type of FAC column in OzON_df:", OzON_df['FAC'].dtype)

# Print the data type of the FAC column in OzOFF_df
print("Data type of FAC column in OzOFF_df:", OzOFF_df['FAC'].dtype)
# Out:
# Data type of FAC column in OzON_df: object
# Data type of FAC column in OzOFF_df: object

# %%
import pandas as pd
import ast

def match_dataframes(on_df, off_df):
    # Create a new empty DataFrame with the same columns as ON plus FAC_OFF and Retention_Time_OFF
    matched = pd.DataFrame(columns=on_df.columns.tolist() + ['FAC_OFF', 'Retention_Time_OFF'])

    # Iterate through each row of the ON DataFrame
    for _, on_row in on_df.iterrows():
        # Convert the string representation of the list in FAC to an actual list
        on_fac_list = ast.literal_eval(on_row['FAC'])

        # Iterate through each row of the OFF DataFrame
        for _, off_row in off_df.iterrows():
            # Convert the string representation of the list in FAC to an actual list
            off_fac_list = ast.literal_eval(off_row['FAC'])

            # Check if any of the FAC values in the ON row exactly match any FAC value in the OFF row
            for on_fac in on_fac_list:
                if on_fac in off_fac_list:
                    # Check if the absolute difference between Retention_Time is within 0.5
                    if abs(on_row['Retention_Time'] - off_row['Retention_Time']) <= 0.5:
                        # Append the ON row to the matched DataFrame with FAC_OFF and Retention_Time_OFF
                        new_row = on_row.copy()
                        new_row['FAC_OFF'] = on_fac
                        new_row['Retention_Time_OFF'] = off_row['Retention_Time']
                        matched = matched.append(new_row, ignore_index=True)

    return matched

# Example usage
matched_df = match_dataframes(OzON_df, OzOFF_df)

# %%
matched_df
# Out:
#                                                  Lipid  Retention_Time  \
# 0    22:6 (4Z,7Z,10Z,13Z,16Z,19Z)n-3,n-6,n-9,n-12,n...        7.579050
# 1    22:6 (4Z,7Z,10Z,13Z,16Z,19Z)n-3,n-6,n-9,n-12,n...        7.579050
# 2    6:0 / 20:5 (5Z,8Z,11Z,14Z,17Z)n-3,n-6,n-9,n-12...        6.686683
# 3    6:0 / 20:5 (5Z,8Z,11Z,14Z,17Z)n-3,n-6,n-9,n-12...        6.686683
# 4    6:0 / 20:5 (5Z,8Z,11Z,14Z,17Z)n-3,n-6,n-9,n-12...        7.631067
# ..                                                 ...             ...
# 112                           20:0 / 21:1n-2 / 22:1n-3       12.281450
# 113                           20:0 / 21:1n-2 / 22:1n-3       12.281450
# 114                                               22:6        7.584817
# 115                                               22:2       11.204517
# 116                                               22:1       12.568183
#
#      OzESI_Intensity Match_Group Group_Sample  \
# 0       64931.144531           1           43
# 1       64931.144531           1           43
# 2       64325.605469           2           48
# 3       64325.605469           2           48
# 4       91986.468750           2           48
# ..               ...         ...          ...
# 112    147127.203125          44           20
# 113    147127.203125          44           20
# 114    314451.750000          46           37
# 115    164623.828125          47           36
# 116    155917.515625          48           35
#
#                                              Sample_ID  Parent_Ion  \
# 0    11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       269.1
# 1    11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       269.1
# 2    11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       283.1
# 3    11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       283.1
# 4    11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       283.1
# ..                                                 ...         ...
# 112  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       479.4
# 113  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       479.4
# 114  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       495.4
# 115  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       503.4
# 116  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       505.4
#
#     Product_Ion                                                FAC  Biology  \
# 0           183  ['22:6', '12:1', '13:1', '14:1', '15:1', '16:1...      NaN
# 1           183  ['22:6', '12:1', '13:1', '14:1', '15:1', '16:1...      NaN
# 2           183  ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1'...      NaN
# 3           183  ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1'...      NaN
# 4           183  ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1'...      NaN
# ..          ...                                                ...      ...
# 112         183                           ['20:0', '21:1', '22:1']      NaN
# 113         183                           ['20:0', '21:1', '22:1']      NaN
# 114         183                                           ['22:6']      NaN
# 115         183                                           ['22:2']      NaN
# 116         183                                           ['22:1']      NaN
#
#      Genotype  Cage  Mouse    Peak_Height           FWHM  Peak_Width  \
# 0         NaN   NaN    NaN   64931.144531   32486.192266    3.429790
# 1         NaN   NaN    NaN   64931.144531   32486.192266    3.429790
# 2         NaN   NaN    NaN   64325.605469   32196.472736    3.489308
# 3         NaN   NaN    NaN   64325.605469   32196.472736    3.489308
# 4         NaN   NaN    NaN   91986.468750   46013.814377    3.721541
# ..        ...   ...    ...            ...            ...         ...
# 112       NaN   NaN    NaN  147127.203125   73680.271568    8.632935
# 113       NaN   NaN    NaN  147127.203125   73680.271568    8.632935
# 114       NaN   NaN    NaN  314451.750000  157246.545002    3.533352
# 115       NaN   NaN    NaN  164623.828125   82341.794065    6.204903
# 116       NaN   NaN    NaN  155917.515625   78019.937817    7.699657
#
#         Peak_Area FAC_OFF  Retention_Time_OFF
# 0    2.227002e+05    17:1            7.801083
# 1    2.227002e+05    22:6            7.558583
# 2    2.244519e+05    16:1            6.910983
# 3    2.244519e+05    20:5            6.669867
# 4    3.423315e+05    17:1            7.801083
# ..            ...     ...                 ...
# 112  1.270140e+06    20:0           12.255250
# 113  1.270140e+06    22:1           12.541983
# 114  1.111069e+06    22:6            7.558583
# 115  1.021475e+06    22:2           11.178317
# 116  1.200511e+06    22:1           12.541983
#
# [117 rows x 19 columns]

# %%
def print_fac_and_off_match(df, match_group):
    """
    Print the FAC and corresponding OzOFF_Match for a specified Match_Group.

    Parameters:
    - df: DataFrame containing matched data.
    - match_group: The specific Match_Group value to filter and print data for.
    """
    # Filter the DataFrame for the specified Match_Group
    group_data = df[df['Match_Group'] == match_group]

    # Check if there are entries for the specified Match_Group
    if group_data.empty:
        print(f"No entries found for Match Group {match_group}.")
    else:
        print(f"Entries for Match Group {match_group}:")
        for index, row in group_data.iterrows():
            print(f"Index {index}: FAC - {row['FAC']}, FAC_OFF - {row['FAC_OFF']}")

# Example usage
match_group_value = 2  # Set the Match_Group value you are interested in
print_fac_and_off_match(matched_df, match_group_value)
# Out:
# Entries for Match Group 2:
# Index 2: FAC - ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1', '15:1', '16:1', '17:1', '18:1'], FAC_OFF - 16:1
# Index 3: FAC - ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1', '15:1', '16:1', '17:1', '18:1'], FAC_OFF - 20:5
# Index 4: FAC - ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1', '15:1', '16:1', '17:1', '18:1'], FAC_OFF - 17:1
# Index 5: FAC - ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1', '15:1', '16:1', '17:1', '18:1'], FAC_OFF - 20:4

# %% [markdown]
# # Remove OzON with ##:0

# %%
def contains_colon_zero(fac_string):
    return ':0' not in fac_string  # Return True only if ':0' is not found

# Apply the filter to exclude strings containing ':0'
df_filtered = matched_df[matched_df['FAC_OFF'].apply(contains_colon_zero)]

df_filtered
# Out:
#                                                  Lipid  Retention_Time  \
# 0    22:6 (4Z,7Z,10Z,13Z,16Z,19Z)n-3,n-6,n-9,n-12,n...        7.579050
# 1    22:6 (4Z,7Z,10Z,13Z,16Z,19Z)n-3,n-6,n-9,n-12,n...        7.579050
# 2    6:0 / 20:5 (5Z,8Z,11Z,14Z,17Z)n-3,n-6,n-9,n-12...        6.686683
# 3    6:0 / 20:5 (5Z,8Z,11Z,14Z,17Z)n-3,n-6,n-9,n-12...        6.686683
# 4    6:0 / 20:5 (5Z,8Z,11Z,14Z,17Z)n-3,n-6,n-9,n-12...        7.631067
# ..                                                 ...             ...
# 111                                               20:1       10.655467
# 113                           20:0 / 21:1n-2 / 22:1n-3       12.281450
# 114                                               22:6        7.584817
# 115                                               22:2       11.204517
# 116                                               22:1       12.568183
#
#      OzESI_Intensity Match_Group Group_Sample  \
# 0       64931.144531           1           43
# 1       64931.144531           1           43
# 2       64325.605469           2           48
# 3       64325.605469           2           48
# 4       91986.468750           2           48
# ..               ...         ...          ...
# 111    625269.312500          43           21
# 113    147127.203125          44           20
# 114    314451.750000          46           37
# 115    164623.828125          47           36
# 116    155917.515625          48           35
#
#                                              Sample_ID  Parent_Ion  \
# 0    11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       269.1
# 1    11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       269.1
# 2    11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       283.1
# 3    11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       283.1
# 4    11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       283.1
# ..                                                 ...         ...
# 111  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       477.4
# 113  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       479.4
# 114  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       495.4
# 115  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       503.4
# 116  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       505.4
#
#     Product_Ion                                                FAC  Biology  \
# 0           183  ['22:6', '12:1', '13:1', '14:1', '15:1', '16:1...      NaN
# 1           183  ['22:6', '12:1', '13:1', '14:1', '15:1', '16:1...      NaN
# 2           183  ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1'...      NaN
# 3           183  ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1'...      NaN
# 4           183  ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1'...      NaN
# ..          ...                                                ...      ...
# 111         183                                           ['20:1']      NaN
# 113         183                           ['20:0', '21:1', '22:1']      NaN
# 114         183                                           ['22:6']      NaN
# 115         183                                           ['22:2']      NaN
# 116         183                                           ['22:1']      NaN
#
#      Genotype  Cage  Mouse    Peak_Height           FWHM  Peak_Width  \
# 0         NaN   NaN    NaN   64931.144531   32486.192266    3.429790
# 1         NaN   NaN    NaN   64931.144531   32486.192266    3.429790
# 2         NaN   NaN    NaN   64325.605469   32196.472736    3.489308
# 3         NaN   NaN    NaN   64325.605469   32196.472736    3.489308
# 4         NaN   NaN    NaN   91986.468750   46013.814377    3.721541
# ..        ...   ...    ...            ...            ...         ...
# 111       NaN   NaN    NaN  625269.312500  312673.366253    5.567599
# 113       NaN   NaN    NaN  147127.203125   73680.271568    8.632935
# 114       NaN   NaN    NaN  314451.750000  157246.545002    3.533352
# 115       NaN   NaN    NaN  164623.828125   82341.794065    6.204903
# 116       NaN   NaN    NaN  155917.515625   78019.937817    7.699657
#
#         Peak_Area FAC_OFF  Retention_Time_OFF
# 0    2.227002e+05    17:1            7.801083
# 1    2.227002e+05    22:6            7.558583
# 2    2.244519e+05    16:1            6.910983
# 3    2.244519e+05    20:5            6.669867
# 4    3.423315e+05    17:1            7.801083
# ..            ...     ...                 ...
# 111  3.481249e+06    20:1           10.629233
# 113  1.270140e+06    22:1           12.541983
# 114  1.111069e+06    22:6            7.558583
# 115  1.021475e+06    22:2           11.178317
# 116  1.200511e+06    22:1           12.541983
#
# [105 rows x 19 columns]

# %%
import pandas as pd
import ast

class OzoneCompare:
    def __init__(self, directory, file_name_on, file_name_off):
        self.directory = directory
        self.file_name_on = file_name_on
        self.file_name_off = file_name_off
        self.load_data()

    def load_data(self):
        # Load data from Excel files
        self.OzON_df = pd.read_excel(self.directory + self.file_name_on)
        self.OzOFF_df = pd.read_excel(self.directory + self.file_name_off)
        # Drop 'Unnamed: 0' columns if they exist
        self.OzON_df.drop(columns='Unnamed: 0', errors='ignore', inplace=True)
        self.OzOFF_df.drop(columns='Unnamed: 0', errors='ignore', inplace=True)

    def match_dataframes(self):
        matched = pd.DataFrame(columns=self.OzON_df.columns.tolist() + ['FAC_OFF', 'Retention_Time_OFF'])
        for _, on_row in self.OzON_df.iterrows():
            on_fac_list = ast.literal_eval(on_row['FAC'])
            for _, off_row in self.OzOFF_df.iterrows():
                off_fac_list = ast.literal_eval(off_row['FAC'])
                for on_fac in on_fac_list:
                    if on_fac in off_fac_list and abs(on_row['Retention_Time'] - off_row['Retention_Time']) <= 0.5:
                        new_row = on_row.copy()
                        new_row['FAC_OFF'] = on_fac
                        new_row['Retention_Time_OFF'] = off_row['Retention_Time']
                        matched = matched.append(new_row, ignore_index=True)
        return matched

    def print_fac_and_off_match(self, df, match_group):
        group_data = df[df['Match_Group'] == match_group]
        if group_data.empty:
            print(f"No entries found for Match Group {match_group}.")
        else:
            print(f"Entries for Match Group {match_group}:")
            for index, row in group_data.iterrows():
                print(f"Index {index}: FAC - {row['FAC']}, FAC_OFF - {row['FAC_OFF']}")

    def filter_contains_colon_zero(self, df):
        return df[df['FAC_OFF'].apply(lambda x: ':0' not in x)]

# Example of using the class
directory = 'Projects/AMP/results/fame_mix/'
file_name_on = 'FAME_OzON.xlsx'
file_name_off = 'FAME_OzOFF.xlsx'

# Create an instance of the class
ozone_compare = OzoneCompare(directory, file_name_on, file_name_off)

# Match dataframes
matched_df = ozone_compare.match_dataframes()

# Print matches for a specific match group
ozone_compare.print_fac_and_off_match(matched_df, 2)

# Filter and print DataFrame rows where FAC_OFF does not contain ':0'
filtered_df = ozone_compare.filter_contains_colon_zero(matched_df)
filtered_df
# Out:
# Entries for Match Group 2:
# Index 2: FAC - ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1', '15:1', '16:1', '17:1', '18:1'], FAC_OFF - 16:1
# Index 3: FAC - ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1', '15:1', '16:1', '17:1', '18:1'], FAC_OFF - 20:5
# Index 4: FAC - ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1', '15:1', '16:1', '17:1', '18:1'], FAC_OFF - 17:1
# Index 5: FAC - ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1', '15:1', '16:1', '17:1', '18:1'], FAC_OFF - 20:4
#                                                  Lipid  Retention_Time  \
# 0    22:6 (4Z,7Z,10Z,13Z,16Z,19Z)n-3,n-6,n-9,n-12,n...        7.579050
# 1    22:6 (4Z,7Z,10Z,13Z,16Z,19Z)n-3,n-6,n-9,n-12,n...        7.579050
# 2    6:0 / 20:5 (5Z,8Z,11Z,14Z,17Z)n-3,n-6,n-9,n-12...        6.686683
# 3    6:0 / 20:5 (5Z,8Z,11Z,14Z,17Z)n-3,n-6,n-9,n-12...        6.686683
# 4    6:0 / 20:5 (5Z,8Z,11Z,14Z,17Z)n-3,n-6,n-9,n-12...        7.631067
# ..                                                 ...             ...
# 111                                               20:1       10.655467
# 113                           20:0 / 21:1n-2 / 22:1n-3       12.281450
# 114                                               22:6        7.584817
# 115                                               22:2       11.204517
# 116                                               22:1       12.568183
#
#      OzESI_Intensity Match_Group Group_Sample  \
# 0       64931.144531           1           43
# 1       64931.144531           1           43
# 2       64325.605469           2           48
# 3       64325.605469           2           48
# 4       91986.468750           2           48
# ..               ...         ...          ...
# 111    625269.312500          43           21
# 113    147127.203125          44           20
# 114    314451.750000          46           37
# 115    164623.828125          47           36
# 116    155917.515625          48           35
#
#                                              Sample_ID  Parent_Ion  \
# 0    11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       269.1
# 1    11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       269.1
# 2    11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       283.1
# 3    11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       283.1
# 4    11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       283.1
# ..                                                 ...         ...
# 111  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       477.4
# 113  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       479.4
# 114  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       495.4
# 115  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       503.4
# 116  11152023_FAMEmix_AMP_1000x_0.1uMd216-0_MRMs_O3...       505.4
#
#     Product_Ion                                                FAC  Biology  \
# 0           183  ['22:6', '12:1', '13:1', '14:1', '15:1', '16:1...      NaN
# 1           183  ['22:6', '12:1', '13:1', '14:1', '15:1', '16:1...      NaN
# 2           183  ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1'...      NaN
# 3           183  ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1'...      NaN
# 4           183  ['6:0', '20:5', '20:4', '12:1', '13:1', '14:1'...      NaN
# ..          ...                                                ...      ...
# 111         183                                           ['20:1']      NaN
# 113         183                           ['20:0', '21:1', '22:1']      NaN
# 114         183                                           ['22:6']      NaN
# 115         183                                           ['22:2']      NaN
# 116         183                                           ['22:1']      NaN
#
#      Genotype  Cage  Mouse    Peak_Height           FWHM  Peak_Width  \
# 0         NaN   NaN    NaN   64931.144531   32486.192266    3.429790
# 1         NaN   NaN    NaN   64931.144531   32486.192266    3.429790
# 2         NaN   NaN    NaN   64325.605469   32196.472736    3.489308
# 3         NaN   NaN    NaN   64325.605469   32196.472736    3.489308
# 4         NaN   NaN    NaN   91986.468750   46013.814377    3.721541
# ..        ...   ...    ...            ...            ...         ...
# 111       NaN   NaN    NaN  625269.312500  312673.366253    5.567599
# 113       NaN   NaN    NaN  147127.203125   73680.271568    8.632935
# 114       NaN   NaN    NaN  314451.750000  157246.545002    3.533352
# 115       NaN   NaN    NaN  164623.828125   82341.794065    6.204903
# 116       NaN   NaN    NaN  155917.515625   78019.937817    7.699657
#
#         Peak_Area FAC_OFF  Retention_Time_OFF
# 0    2.227002e+05    17:1            7.801083
# 1    2.227002e+05    22:6            7.558583
# 2    2.244519e+05    16:1            6.910983
# 3    2.244519e+05    20:5            6.669867
# 4    3.423315e+05    17:1            7.801083
# ..            ...     ...                 ...
# 111  3.481249e+06    20:1           10.629233
# 113  1.270140e+06    22:1           12.541983
# 114  1.111069e+06    22:6            7.558583
# 115  1.021475e+06    22:2           11.178317
# 116  1.200511e+06    22:1           12.541983
#
# [105 rows x 19 columns]
