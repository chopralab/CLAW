# %% [markdown]
# # CT OFF

# %%
import pandas as pd

# %%
# !sbatch core/backend/CT/OFF/mzml_parser_1_CT_OFF.sh
# Out:
# Submitted batch job 22132912

# %%
df_mzml = pd.read_parquet('Projects/CT/mzml_parsed/OFF/mzml_parser_1_OFF_intensity.parquet')
df_mzml
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            227.1        183.0        3.019117        41.580002
# 1            227.1        183.0        3.034950        40.820004
# 2            227.1        183.0        3.050800        40.520004
# 3            227.1        183.0        3.066650        40.980003
# 4            227.1        183.0        3.082500        41.060001
# ...            ...          ...             ...              ...
# 428033       533.5        183.0       31.933100        41.220001
# 428034       533.5        183.0       31.948950        41.480003
# 428035       533.5        183.0       31.964800        41.380001
# 428036       533.5        183.0       31.980650        41.020004
# 428037       533.5        183.0       31.996500        40.660004
#
#                                    Sample_ID      Transition
# 0       01162025_CisTransMix_AMP_OzoneOff_01  227.1 -> 183.0
# 1       01162025_CisTransMix_AMP_OzoneOff_01  227.1 -> 183.0
# ...

# %%
# !sbatch core/backend/CT/OFF/sample_2_CT_OFF.sh
# Out:
# Submitted batch job 22133032

# %%
df_sample = pd.read_parquet('Projects/CT/samples/OFF/df_sample_2_CisTrans.parquet')
df_sample
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            227.1        183.0        3.019117        41.580002
# 1            227.1        183.0        3.034950        40.820004
# 2            227.1        183.0        3.050800        40.520004
# 3            227.1        183.0        3.066650        40.980003
# 4            227.1        183.0        3.082500        41.060001
# ...            ...          ...             ...              ...
# 214015       533.5        183.0       31.933133        41.120003
# 214016       533.5        183.0       31.948983        41.240002
# 214017       533.5        183.0       31.964833        41.260002
# 214018       533.5        183.0       31.980683        41.220001
# 214019       533.5        183.0       31.996550        41.720001
#
#                                    Sample_ID      Transition    Sample  \
# 0       01162025_CisTransMix_AMP_OzoneOff_01  227.1 -> 183.0  CisTrans
# ...

# %%
df_sample = pd.read_parquet('Projects/CT/samples/OFF/df_sample_2_Blank.parquet')
df_sample
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            227.1        183.0        3.019117        41.380001
# 1            227.1        183.0        3.034933        41.400002
# 2            227.1        183.0        3.050783        41.260002
# 3            227.1        183.0        3.066650        40.980003
# 4            227.1        183.0        3.082500        40.880001
# ...            ...          ...             ...              ...
# 214013       533.5        183.0       31.933100        41.220001
# 214014       533.5        183.0       31.948950        41.480003
# 214015       533.5        183.0       31.964800        41.380001
# 214016       533.5        183.0       31.980650        41.020004
# 214017       533.5        183.0       31.996500        40.660004
#
#                              Sample_ID      Transition Sample   STD  \
# 0       01162025_Blank_AMP_OzoneOff_01  227.1 -> 183.0  Blank  None
# ...

# %% [markdown]
# # Match

# %%
# !sbatch core/backend/CT/OFF/match_3_CT_OFF.sh
# Out:
# Submitted batch job 22133152

# %%
df_match = pd.read_parquet('Projects/CT/match/OFF/df_match_3_CisTrans.parquet')
df_match
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            227.1        183.0        3.019117             42.0
# 1            227.1        183.0        3.034950             41.0
# 2            227.1        183.0        3.050800             41.0
# 3            227.1        183.0        3.066650             41.0
# 4            227.1        183.0        3.082500             41.0
# ...            ...          ...             ...              ...
# 214015       533.5        183.0       31.933133             41.0
# 214016       533.5        183.0       31.948983             41.0
# 214017       533.5        183.0       31.964833             41.0
# 214018       533.5        183.0       31.980683             41.0
# 214019       533.5        183.0       31.996550             42.0
#
#                                    Sample_ID      Transition    Sample  \
# 0       01162025_CisTransMix_AMP_OzoneOff_01  227.1 -> 183.0  CisTrans
# ...

# %% [markdown]
# # Group

# %%
# !sbatch core/backend/CT/OFF/group_4_CT_OFF.sh
# Out:
# Submitted batch job 22133339

# %%
df_group = pd.read_parquet('Projects/CT/group/OFF/df_group_4_CisTrans_OFF.parquet')
df_group
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            255.2        183.0        3.018767             42.0
# 1            253.2        183.0        3.018883             41.0
# 2            241.1        183.0        3.019000             42.0
# 3            227.1        183.0        3.019117             42.0
# 4            255.2        183.0        3.034600             41.0
# ...            ...          ...             ...              ...
# 214015       425.4        183.0       31.923800             41.0
# 214016       425.4        183.0       31.939650             41.0
# 214017       425.4        183.0       31.955500             41.0
# 214018       425.4        183.0       31.971350             42.0
# 214019       425.4        183.0       31.987200             77.0
#
#                                    Sample_ID      Transition    Sample  \
# 0       01162025_CisTransMix_AMP_OzoneOff_01  255.2 -> 183.0  CisTrans
# ...

# %%
unique_lipids = df_group['Lipid'].unique()
print(unique_lipids)
# Out:
# ['' 'FA(10:0)' 'FA(10:1)' 'FA(10:2)' 'FA(10:3)' 'FA(10:4)' 'FA(10:5)'
#  'FA(11:0)' 'FA(11:1)' 'FA(11:2)' 'FA(11:3)' 'FA(11:4)' 'FA(11:5)'
#  'FA(12:0)' 'FA(12:1)' 'FA(12:2)' 'FA(12:3)' 'FA(12:4)' 'FA(12:5)'
#  'FA(13:0)' 'FA(13:1)' 'FA(13:2)' 'FA(13:3)' 'FA(13:4)' 'FA(13:5)'
#  'FA(14:0)' 'FA(14:1)' 'FA(14:2)' 'FA(14:3)' 'FA(14:4)' 'FA(14:5)'
#  'FA(15:0)' 'FA(15:1)' 'FA(15:2)' 'FA(15:3)' 'FA(15:4)' 'FA(15:5)'
#  'FA(16:0)' 'FA(16:1)' 'FA(16:2)' 'FA(16:3)' 'FA(16:4)' 'FA(16:5)'
#  'FA(17:0)' 'FA(17:1)' 'FA(17:2)' 'FA(17:3)' 'FA(17:4)' 'FA(17:5)'
#  'FA(18:0)' 'FA(18:1)' 'FA(18:2)' 'FA(18:3)' 'FA(18:4)' 'FA(18:5)'
#  'FA(19:0)' 'FA(19:1)' 'FA(19:2)' 'FA(19:3)' 'FA(19:4)' 'FA(19:5)'
#  'FA(20:0)' 'FA(20:1)' 'FA(20:2)' 'FA(20:3)' 'FA(20:4)' 'FA(20:5)'
#  'FA(21:0)' 'FA(21:1)' 'FA(21:2)' 'FA(21:3)' 'FA(21:4)' 'FA(21:5)'
#  'FA(22:0)' 'FA(22:1)' 'FA(22:2)' 'FA(22:3)' 'FA(22:4)' 'FA(22:5)'
#  'FA(22:6)' 'FA(23:0)' 'FA(23:1)' 'FA(23:2)' 'FA(23:3)' 'FA(23:4)'
# ...

# %%
# print unique columns
unique_columns = df_group.columns
print(unique_columns)
# Out:
# Index(['Parent_Ion', 'Product_Ion', 'Retention_Time', 'OzESI_Intensity',
#        'Sample_ID', 'Transition', 'Sample', 'STD', 'STD_RT_OFF',
#        'STD_Peak_Intensity', 'STD_Peak_Area', 'Lipid', 'Class', 'Species',
#        'Biology', 'Genotype', 'Cage', 'Mouse', 'group_by_ion',
#        'group_by_lipid'],
#       dtype='object')

# %% [markdown]
# # analysis 5

# %%
# !sbatch core/backend/CT/OFF/analysis_5_CT_OFF.sh
# Out:
# Submitted batch job 22133473

# %%
df_analysis = pd.read_parquet('Projects/CT/analysis/OFF/df_analysis_CT_OFF_CisTrans.parquet')
df_analysis
# Out:
#        Lipid  Retention_Time  OzESI_Intensity  group_by_ion  group_by_lipid  \
# 0    FA(6:2)        5.475117           1700.0             8              93
# 1    FA(6:3)       30.584000           1253.0             7              94
# 2    FA(7:2)        4.238117           1425.0            13              97
# 3    FA(7:2)        4.380783           1454.0            13              97
# 4   FA(16:0)       10.508567          39298.0            69              37
# 5   FA(18:0)       11.283683           2551.0            82              49
# 6   FA(18:0)       11.679983           2043.0            82              49
# 7   FA(18:0)       11.822650           1201.0            82              49
# 8   FA(18:0)       13.693133          24517.0            82              49
# 9   FA(18:1)       11.283817         122593.0            81              50
# 10  FA(18:1)       11.664250         107345.0            81              50
# ...

# %% [markdown]
# # OFF Possible

# %% [markdown]
# # off possible

# %%
fame_std = pd.read_parquet('Projects/STD/analysis/OFF/off_possible/df_analysis_5_FAME_OFF_offpossible.parquet')
fame_std
# Out:
#        Lipid  Retention_Time  OzESI_Intensity  group_by_ion  group_by_lipid  \
# 0   FA(10:1)        3.871267          20358.0            32               2
# 1   FA(10:1)        5.313750           5458.0            32               2
# 2   FA(10:3)        5.726133           1147.0            30               4
# 3   FA(10:3)        6.772333           1097.0            30               4
# 4   FA(10:4)        7.612567           1263.0            29               5
# ..       ...             ...              ...           ...             ...
# 71   FA(7:4)        5.316250           1251.0            11              99
# 72   FA(9:1)        4.537750           3880.0            26             107
# 73   FA(9:1)        4.807217           2653.0            26             107
# 74   FA(9:3)        5.251300           1566.0            24             109
# 75   FA(9:3)        6.693783           1208.0            24             109
#
# ...
