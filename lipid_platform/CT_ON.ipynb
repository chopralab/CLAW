# %% [markdown]
# # CT ON

# %%
import pandas as pd

# %% [markdown]
# # 1 mzml parse

# %%
# !sbatch core/backend/CT/ON/mzml_parser_1_CT_ON.sh
# Out:
# Submitted batch job 22133724

# %%
df_mzml = pd.read_parquet('Projects/CT/mzml_parsed/ON/mzml_parser_1_CT_ON.parquet')
df_mzml
# Out:
#        Lipid  Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0       None       227.1        183.0        3.019117        41.680004
# 1       None       227.1        183.0        3.034933        41.420002
# 2       None       227.1        183.0        3.050783        41.220001
# 3       None       227.1        183.0        3.066633        41.180004
# 4       None       227.1        183.0        3.082500        41.380001
# ...      ...         ...          ...             ...              ...
# 419662  None       533.5        183.0       31.933100        41.700005
# 419663  None       533.5        183.0       31.948950        41.660004
# 419664  None       533.5        183.0       31.964800        41.480003
# 419665  None       533.5        183.0       31.980650        41.200005
# 419666  None       533.5        183.0       31.996500        41.560001
#
#                                   Sample_ID      Transition
# ...

# %%
df_mzml = pd.read_parquet('Projects/CT/mzml_parsed/ON/transitions/mzml_transition_summed_1_CT_ON.parquet')
df_mzml
# Out:
#      Parent_Ion  Product_Ion     Intensity      Transition  \
# 0         227.1        183.0  73934.065178  227.1 -> 183.0
# 1         241.1        183.0  73392.765186  241.1 -> 183.0
# 2         253.2        183.0  73063.645134  253.2 -> 183.0
# 3         255.2        183.0  73782.185234  255.2 -> 183.0
# 4         265.2        183.0  72824.785095  265.2 -> 183.0
# ..          ...          ...           ...             ...
# 229       519.4        183.0  76653.565327  519.4 -> 183.0
# 230       521.4        183.0  77980.745449  521.4 -> 183.0
# 231       533.4        183.0  77182.145420  533.4 -> 183.0
# 232       535.4        183.0  77307.765453  535.4 -> 183.0
# 233       533.5        183.0  75748.665382  533.5 -> 183.0
#
#                                Sample_ID
# 0          01162025_Blank_AMP_OzoneOn_01
# 1          01162025_Blank_AMP_OzoneOn_01
# 2          01162025_Blank_AMP_OzoneOn_01
# 3          01162025_Blank_AMP_OzoneOn_01
# 4          01162025_Blank_AMP_OzoneOn_01
# ...

# %% [markdown]
# # 2 Sample

# %%
# !sbatch core/backend/CT/ON/sample_2_CT_ON.sh
# Out:
# Submitted batch job 22135332

# %%
df_sample = pd.read_parquet('Projects/CT/samples/ON/df_sample_2_CisTrans_ON.parquet')
df_sample
# Out:
#        Lipid  Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0       None       227.1        183.0        3.019117        41.560001
# 1       None       227.1        183.0        3.034933        63.960003
# 2       None       227.1        183.0        3.050783        67.240005
# 3       None       227.1        183.0        3.066633        63.960003
# 4       None       227.1        183.0        3.082500        41.420002
# ...      ...         ...          ...             ...              ...
# 214013  None       533.5        183.0       31.933100        41.700005
# 214014  None       533.5        183.0       31.948950        41.660004
# 214015  None       533.5        183.0       31.964800        41.480003
# 214016  None       533.5        183.0       31.980650        41.200005
# 214017  None       533.5        183.0       31.996500        41.560001
#
#                                   Sample_ID      Transition    Sample   STD  \
# ...

# %% [markdown]
# # 3 Match

# %%
# !sbatch core/backend/CT/ON/match_3_CT_ON.sh
# Out:
# Submitted batch job 22135546

# %%
df_match = pd.read_parquet('Projects/CT/match/ON/df_match_3_CisTrans.parquet')
df_match
# Out:
#        Lipid  Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0                  227.1        183.0        4.984683             42.0
# 1                  227.1        183.0        5.000533             42.0
# 2                  227.1        183.0        5.016383             42.0
# 3                  227.1        183.0        5.032233             42.0
# 4                  227.1        183.0        5.048083             41.0
# ...      ...         ...          ...             ...              ...
# 155031             533.5        183.0       20.424933             42.0
# 155032             533.5        183.0       20.440783             41.0
# 155033             533.5        183.0       20.456650             41.0
# 155034             533.5        183.0       20.472500             41.0
# 155035             533.5        183.0       20.488350             41.0
#
#                                   Sample_ID      Transition    Sample   STD  \
# ...

# %%
unique_lipids = df_match['Lipid'].unique()
print(unique_lipids)
# Out:
# [''
#  'FA(6:2)_<F>_n-4 | FA(6:3)_<FF>_n-4 | FA(7:2)_<F>_n-5 | FA(18:1)_<>_n-16 | FA(18:2)_<F>_n-16 | FA(18:3)_<FF>_n-16'
#  'FA(6:2)_<B>_n-3 | FA(6:3)_<BF>_n-3 | FA(7:2)_<B>_n-4 | FA(18:2)_<B>_n-15 | FA(18:3)_<BF>_n-15'
#  'FA(6:2)_<F>_n-3 | FA(6:3)_<FF>_n-3 | FA(7:2)_<F>_n-4 | FA(18:1)_<>_n-15 | FA(18:2)_<F>_n-15 | FA(18:3)_<FF>_n-15'
#  'FA(6:3)_<BB>_n-2 | FA(18:3)_<BB>_n-14'
#  'FA(6:2)_<B>_n-2 | FA(6:3)_<BF>_n-2 | FA(7:2)_<B>_n-3 | FA(18:2)_<B>_n-14 | FA(18:3)_<BF>_n-14'
#  'FA(6:2)_<F>_n-2 | FA(7:2)_<F>_n-3 | FA(18:1)_<>_n-14 | FA(18:2)_<F>_n-14 | FA(18:3)_<FF>_n-14'
#  'FA(18:3)_<BB>_n-13'
#  'FA(7:2)_<B>_n-2 | FA(18:2)_<B>_n-13 | FA(18:3)_<BF>_n-13'
#  'FA(7:2)_<F>_n-2 | FA(18:1)_<>_n-13 | FA(18:2)_<F>_n-13 | FA(18:3)_<FF>_n-13'
#  'FA(18:3)_<BB>_n-12' 'FA(18:2)_<B>_n-12 | FA(18:3)_<BF>_n-12'
#  'FA(18:1)_<>_n-12 | FA(18:2)_<F>_n-12 | FA(18:3)_<FF>_n-12'
#  'FA(18:3)_<BB>_n-11' 'FA(18:2)_<B>_n-11 | FA(18:3)_<BF>_n-11'
# ...

# %% [markdown]
# # 4 Group

# %%
# !sbatch core/backend/CT/ON/group_4_CT_ON.sh
# Out:
# Submitted batch job 22135554

# %%
df_group = pd.read_parquet('Projects/CT/group/ON/df_group_4_CisTrans.parquet')
df_group
# Out:
#                    Lipid  Parent_Ion  Product_Ion  Retention_Time  \
# 0      FA(18:1)_<>_n-10        325.2        183.0       10.798967
# 1      FA(18:1)_<>_n-10        325.2        183.0       10.814817
# 2      FA(18:1)_<>_n-10        325.2        183.0       10.830667
# 3      FA(18:1)_<>_n-10        325.2        183.0       10.846517
# 4      FA(18:1)_<>_n-10        325.2        183.0       10.862367
# ...                  ...         ...          ...             ...
# 16165   FA(7:2)_<F>_n-5        241.1        183.0        4.810200
# 16166   FA(7:2)_<F>_n-5        241.1        183.0        4.826050
# 16167   FA(7:2)_<F>_n-5        241.1        183.0        4.841900
# 16168   FA(7:2)_<F>_n-5        241.1        183.0        4.857750
# 16169   FA(7:2)_<F>_n-5        241.1        183.0        4.873600
#
#        OzESI_Intensity                            Sample_ID      Transition  \
# 0                 41.0  01162025_CisTransMix_AMP_OzoneOn_01  325.2 -> 183.0
# ...

# %%
# print all column names
print(df_group.columns)
# Out:
# Index(['Lipid', 'Parent_Ion', 'Product_Ion', 'Retention_Time',
#        'OzESI_Intensity', 'Sample_ID', 'Transition', 'Sample', 'STD',
#        'STD_RT_ON', 'STD_Peak_Intensity', 'STD_Peak_Area', 'STD_RT_Dif',
#        'Adjusted_RT', 'Species', 'Class', 'STD_RT_OFF', 'Possible_Lipids',
#        'Biology', 'Genotype', 'Cage', 'Mouse', 'group_by_ion',
#        'group_by_lipid'],
#       dtype='object')

# %% [markdown]
# # 5 analysis

# %%
# !sbatch core/backend/CT/ON/analysis_5_CT_ON.sh
# Out:
# Submitted batch job 22135571

# %%
df_analysis = pd.read_parquet('Projects/CT/analysis/ON/df_analysis_5_CisTrans.parquet')
df_analysis
# Out:
#                 Lipid  Retention_Time  OzESI_Intensity  group_by_ion  \
# 0    FA(18:1)_<>_n-2        11.664867            919.0            41
# 1    FA(18:1)_<>_n-2        11.696567            787.0            41
# 2    FA(18:1)_<>_n-3        11.665717           1452.0            38
# 3    FA(18:1)_<>_n-4        11.317717            885.0            35
# 4    FA(18:1)_<>_n-4        11.698150           2496.0            35
# 5    FA(18:1)_<>_n-5        11.255050           1352.0            32
# 6    FA(18:1)_<>_n-5        11.683033           7761.0            32
# 7    FA(18:1)_<>_n-5        11.825700            626.0            32
# 8    FA(18:1)_<>_n-6        11.255767           2105.0            29
# 9    FA(18:1)_<>_n-6        11.667900          10163.0            29
# 10   FA(18:1)_<>_n-7        11.256500           1450.0            26
# 11   FA(18:1)_<>_n-7        11.700333          15396.0            26
# 12   FA(18:1)_<>_n-8        11.273067           3767.0            23
# ...

# %%
df_analysis = pd.read_parquet('Projects/CT/analysis/ON/df_analysis_5_max_CisTrans.parquet')
df_analysis
# Out:
#                 Lipid  group_by_lipid    Sample  Retention_Time  \
# 0    FA(18:1)_<>_n-2                7  CisTrans       11.664867
# 1    FA(18:1)_<>_n-3                8  CisTrans       11.665717
# 2    FA(18:1)_<>_n-4                9  CisTrans       11.698150
# 3    FA(18:1)_<>_n-5               10  CisTrans       11.683033
# 4    FA(18:1)_<>_n-6               11  CisTrans       11.667900
# 5    FA(18:1)_<>_n-7               12  CisTrans       11.700333
# 6    FA(18:1)_<>_n-8               13  CisTrans       11.748617
# 7    FA(18:1)_<>_n-9               14  CisTrans       11.321350
# 8   FA(18:1)_<>_n-10                0  CisTrans       11.908567
# 9   FA(18:1)_<>_n-11                1  CisTrans       12.067783
# 10  FA(18:1)_<>_n-12                2  CisTrans       12.227017
# 11  FA(18:1)_<>_n-13                3  CisTrans       12.449533
# 12  FA(18:2)_<B>_n-6               25  CisTrans        9.417133
# 13  FA(18:2)_<F>_n-9               43  CisTrans        9.419167
# ...
