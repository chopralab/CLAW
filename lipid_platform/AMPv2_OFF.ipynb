# %% [markdown]
# # AMP_V2 OFF

# %%
import pandas as pd

# %%
# !sbatch core/backend/AMP_V2/OFF/mzml_parser_1_CT_OFF.sh
# Out:
# Submitted batch job 22200210

# %%
df_mzml = pd.read_parquet('Projects/AMP_V2/mzml_parsed/OFF/mzml_parser_1_OFF_intensity.parquet')
df_mzml
# Out:
#          Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0             227.1        183.0        0.011583        41.360004
# 1             227.1        183.0        0.024483        41.420002
# 2             227.1        183.0        0.037383        41.380001
# 3             227.1        183.0        0.050317        41.340004
# 4             227.1        183.0        0.063233        41.300003
# ...             ...          ...             ...              ...
# 4796605       533.5        183.0       29.949033        40.480003
# 4796606       533.5        183.0       29.961950        40.480003
# 4796607       533.5        183.0       29.974883        40.460003
# 4796608       533.5        183.0       29.987800        40.600002
# 4796609       533.5        183.0       30.000717        40.680004
#
#                                                  Sample_ID      Transition
# 0        11162023_WT-m5-dienc-FAD259_AMP_2x_0.05uMd216-...  227.1 -> 183.0
# 1        11162023_WT-m5-dienc-FAD259_AMP_2x_0.05uMd216-...  227.1 -> 183.0
# 2        11162023_WT-m5-dienc-FAD259_AMP_2x_0.05uMd216-...  227.1 -> 183.0
# 3        11162023_WT-m5-dienc-FAD259_AMP_2x_0.05uMd216-...  227.1 -> 183.0
# 4        11162023_WT-m5-dienc-FAD259_AMP_2x_0.05uMd216-...  227.1 -> 183.0
# ...                                                    ...             ...
# 4796605                11162023_Blank-AMP_2x_MRMs_O3off_01  533.5 -> 183.0
# 4796606                11162023_Blank-AMP_2x_MRMs_O3off_01  533.5 -> 183.0
# 4796607                11162023_Blank-AMP_2x_MRMs_O3off_01  533.5 -> 183.0
# 4796608                11162023_Blank-AMP_2x_MRMs_O3off_01  533.5 -> 183.0
# 4796609                11162023_Blank-AMP_2x_MRMs_O3off_01  533.5 -> 183.0
#
# [4796610 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

# Plot the filtered data
plt.figure(figsize=(8, 6))
plt.scatter(df_mzml['Retention_Time'], df_mzml['OzESI_Intensity'], color='blue', label='OzESI Intensity')

# Add labels and title
plt.xlabel('Retention Time')
plt.ylabel('OzESI Intensity')
plt.title('Retention Time vs OzESI Intensity')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
# !sbatch core/backend/AMP_V2/OFF/sample_2_CT_OFF.sh
# Out:
# Submitted batch job 22200261

# %%
import pandas as pd
df_sample = pd.read_parquet('Projects/AMP_V2/samples/OFF/df_sample_2_cereb_5xFAD_m1_FAD231.parquet')
df_sample
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            227.1        183.0        0.011583        41.600002
# 1            227.1        183.0        0.024483        41.460003
# 2            227.1        183.0        0.037383        41.440002
# 3            227.1        183.0        0.050317        41.500004
# 4            227.1        183.0        0.063233        41.480003
# ...            ...          ...             ...              ...
# 127706       533.5        183.0       29.949050        42.720001
# 127707       533.5        183.0       29.961983        41.120003
# 127708       533.5        183.0       29.974900        41.360004
# 127709       533.5        183.0       29.987817        40.860004
# 127710       533.5        183.0       30.000733        41.120003
#
#                                                 Sample_ID      Transition  \
# 0       11192023_5xFAD-m1-cereb-FAD231_AMP_2x_0.05uMd2...  227.1 -> 183.0
# 1       11192023_5xFAD-m1-cereb-FAD231_AMP_2x_0.05uMd2...  227.1 -> 183.0
# 2       11192023_5xFAD-m1-cereb-FAD231_AMP_2x_0.05uMd2...  227.1 -> 183.0
# 3       11192023_5xFAD-m1-cereb-FAD231_AMP_2x_0.05uMd2...  227.1 -> 183.0
# 4       11192023_5xFAD-m1-cereb-FAD231_AMP_2x_0.05uMd2...  227.1 -> 183.0
# ...                                                   ...             ...
# 127706  11192023_5xFAD-m1-cereb-FAD231_AMP_2x_0.05uMd2...  533.5 -> 183.0
# 127707  11192023_5xFAD-m1-cereb-FAD231_AMP_2x_0.05uMd2...  533.5 -> 183.0
# 127708  11192023_5xFAD-m1-cereb-FAD231_AMP_2x_0.05uMd2...  533.5 -> 183.0
# 127709  11192023_5xFAD-m1-cereb-FAD231_AMP_2x_0.05uMd2...  533.5 -> 183.0
# 127710  11192023_5xFAD-m1-cereb-FAD231_AMP_2x_0.05uMd2...  533.5 -> 183.0
#
#                        Sample   STD  STD_RT_OFF  STD_Peak_Intensity  \
# 0       cereb_5xFAD_m1_FAD231  None    8.016083         596862.3125
# 1       cereb_5xFAD_m1_FAD231  None    8.016083         596862.3125
# 2       cereb_5xFAD_m1_FAD231  None    8.016083         596862.3125
# 3       cereb_5xFAD_m1_FAD231  None    8.016083         596862.3125
# 4       cereb_5xFAD_m1_FAD231  None    8.016083         596862.3125
# ...                       ...   ...         ...                 ...
# 127706  cereb_5xFAD_m1_FAD231  None    8.016083         596862.3125
# 127707  cereb_5xFAD_m1_FAD231  None    8.016083         596862.3125
# 127708  cereb_5xFAD_m1_FAD231  None    8.016083         596862.3125
# 127709  cereb_5xFAD_m1_FAD231  None    8.016083         596862.3125
# 127710  cereb_5xFAD_m1_FAD231  None    8.016083         596862.3125
#
#         STD_Peak_Area
# 0       159883.703187
# 1       159883.703187
# 2       159883.703187
# 3       159883.703187
# 4       159883.703187
# ...               ...
# 127706  159883.703187
# 127707  159883.703187
# 127708  159883.703187
# 127709  159883.703187
# 127710  159883.703187
#
# [127711 rows x 11 columns]

# %% [markdown]
# # Match

# %%
import os
path = 'Projects/AMP_V2/samples/OFF/'
len(os.listdir(path))
# Out:
# 41

# %%
# !sbatch core/backend/AMP_V2/OFF/match_3_CT_OFF.sh
# Out:
# Submitted batch job 22200314

# %%
import pandas as pd
df_match = pd.read_parquet('Projects/AMP_V2/match/OFF/')
df_match
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            227.1        183.0        3.019117             41.0
# 1            227.1        183.0        3.034933             41.0
# 2            227.1        183.0        3.050783             41.0
# 3            227.1        183.0        3.066633             41.0
# 4            227.1        183.0        3.082500             41.0
# ...            ...          ...             ...              ...
# 192652       533.5        183.0       29.032317             40.0
# 192653       533.5        183.0       29.048167             40.0
# 192654       533.5        183.0       29.064017             40.0
# 192655       533.5        183.0       29.079867             40.0
# 192656       533.5        183.0       29.095717             41.0
#
#             Sample_ID      Transition Sample   STD  STD_RT_OFF  \
# 0       FAME_OzoneOff  227.1 -> 183.0   FAME  None   11.475367
# 1       FAME_OzoneOff  227.1 -> 183.0   FAME  None   11.475367
# 2       FAME_OzoneOff  227.1 -> 183.0   FAME  None   11.475367
# 3       FAME_OzoneOff  227.1 -> 183.0   FAME  None   11.475367
# 4       FAME_OzoneOff  227.1 -> 183.0   FAME  None   11.475367
# ...               ...             ...    ...   ...         ...
# 192652  FAME_OzoneOff  533.5 -> 183.0   FAME  None   11.475367
# 192653  FAME_OzoneOff  533.5 -> 183.0   FAME  None   11.475367
# 192654  FAME_OzoneOff  533.5 -> 183.0   FAME  None   11.475367
# 192655  FAME_OzoneOff  533.5 -> 183.0   FAME  None   11.475367
# 192656  FAME_OzoneOff  533.5 -> 183.0   FAME  None   11.475367
#
#         STD_Peak_Intensity  STD_Peak_Area     Lipid Class
# 0             34009.941406   13194.063558
# 1             34009.941406   13194.063558
# 2             34009.941406   13194.063558
# 3             34009.941406   13194.063558
# 4             34009.941406   13194.063558
# ...                    ...            ...       ...   ...
# 192652        34009.941406   13194.063558  FA(24:1)    FA
# 192653        34009.941406   13194.063558  FA(24:1)    FA
# 192654        34009.941406   13194.063558  FA(24:1)    FA
# 192655        34009.941406   13194.063558  FA(24:1)    FA
# 192656        34009.941406   13194.063558  FA(24:1)    FA
#
# [192657 rows x 13 columns]

# %% [markdown]
# # Group

# %%
# !sbatch core/backend/AMP_V2/OFF/group_4_CT_OFF.sh
# Out:
# Submitted batch job 22193996

# %%
df_group = pd.read_parquet('Projects/AMP_V2/group/OFF/df_group_4_FAME_OFF.parquet')
df_group
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            255.2        183.0        3.018767             41.0
# 1            253.2        183.0        3.018883             41.0
# 2            241.1        183.0        3.019000             41.0
# 3            227.1        183.0        3.019117             41.0
# 4            255.2        183.0        3.034583             63.0
# ...            ...          ...             ...              ...
# 192652       425.4        183.0       29.038833             41.0
# 192653       425.4        183.0       29.054683             41.0
# 192654       425.4        183.0       29.070533             40.0
# 192655       425.4        183.0       29.086383             40.0
# 192656       425.4        183.0       29.102233            221.0
#
#             Sample_ID      Transition Sample   STD  STD_RT_OFF  \
# 0       FAME_OzoneOff  255.2 -> 183.0   FAME  None   11.475367
# 1       FAME_OzoneOff  253.2 -> 183.0   FAME  None   11.475367
# 2       FAME_OzoneOff  241.1 -> 183.0   FAME  None   11.475367
# 3       FAME_OzoneOff  227.1 -> 183.0   FAME  None   11.475367
# 4       FAME_OzoneOff  255.2 -> 183.0   FAME  None   11.475367
# ...               ...             ...    ...   ...         ...
# 192652  FAME_OzoneOff  425.4 -> 183.0   FAME  None   11.475367
# 192653  FAME_OzoneOff  425.4 -> 183.0   FAME  None   11.475367
# 192654  FAME_OzoneOff  425.4 -> 183.0   FAME  None   11.475367
# 192655  FAME_OzoneOff  425.4 -> 183.0   FAME  None   11.475367
# 192656  FAME_OzoneOff  425.4 -> 183.0   FAME  None   11.475367
#
#         STD_Peak_Intensity  STD_Peak_Area        Lipid Class    Species  \
# 0             34009.941406   13194.063558                     Unknown_1
# 1             34009.941406   13194.063558                     Unknown_1
# 2             34009.941406   13194.063558                     Unknown_1
# 3             34009.941406   13194.063558                     Unknown_1
# 4             34009.941406   13194.063558                     Unknown_1
# ...                    ...            ...          ...   ...        ...
# 192652        34009.941406   13194.063558  FA(d2-16:0)    FA       16:0
# 192653        34009.941406   13194.063558  FA(d2-16:0)    FA       16:0
# 192654        34009.941406   13194.063558  FA(d2-16:0)    FA       16:0
# 192655        34009.941406   13194.063558  FA(d2-16:0)    FA       16:0
# 192656        34009.941406   13194.063558  FA(d2-16:0)    FA       16:0
#
#        Biology Genotype Cage Mouse  group_by_ion  group_by_lipid
# 0                                              3               0
# 1                                              2               0
# 2                                              1               0
# 3                                              0               0
# 4                                              3               0
# ...        ...      ...  ...   ...           ...             ...
# 192652                                        70             112
# 192653                                        70             112
# 192654                                        70             112
# 192655                                        70             112
# 192656                                        70             112
#
# [192657 rows x 20 columns]

# %%
unique_lipids = df_group['Lipid'].unique()
print(unique_lipids)
# Out:
# ['' 'FA(10:0)' 'FA(10:1)' 'FA(10:2)' 'FA(10:3)' 'FA(10:4)' 'FA(10:5)'
#  'FA(11:0)' 'FA(11:1)' 'FA(11:2)' 'FA(11:3)' 'FA(11:4)' 'FA(11:5)'
#  'FA(12:0)' 'FA(12:1)' 'FA(12:2)' 'FA(12:3)' 'FA(12:4)' 'FA(12:5)'
#  'FA(13:0)' 'FA(13:1)' 'FA(13:2)' 'FA(13:3)' 'FA(13:4)' 'FA(13:5)'
#  'FA(14:0)' 'FA(14:1)' 'FA(14:2)' 'FA(14:3)' 'FA(14:4)' 'FA(14:5)'
#  'FA(15:0)' 'FA(15:1)' 'FA(15:2)' 'FA(15:3)' 'FA(15:4)' 'FA(15:5)'
#  'FA(16:0)' 'FA(16:1)' 'FA(16:2)' 'FA(16:3)' 'FA(16:4)' 'FA(16:5)'
#  'FA(17:0)' 'FA(17:1)' 'FA(17:2)' 'FA(17:3)' 'FA(17:4)' 'FA(17:5)'
#  'FA(18:0)' 'FA(18:1)' 'FA(18:2)' 'FA(18:3)' 'FA(18:4)' 'FA(18:5)'
#  'FA(19:0)' 'FA(19:1)' 'FA(19:2)' 'FA(19:3)' 'FA(19:4)' 'FA(19:5)'
#  'FA(20:0)' 'FA(20:1)' 'FA(20:2)' 'FA(20:3)' 'FA(20:4)' 'FA(20:5)'
#  'FA(21:0)' 'FA(21:1)' 'FA(21:2)' 'FA(21:3)' 'FA(21:4)' 'FA(21:5)'
#  'FA(22:0)' 'FA(22:1)' 'FA(22:2)' 'FA(22:3)' 'FA(22:4)' 'FA(22:5)'
#  'FA(22:6)' 'FA(23:0)' 'FA(23:1)' 'FA(23:2)' 'FA(23:3)' 'FA(23:4)'
#  'FA(23:5)' 'FA(24:0)' 'FA(24:1)' 'FA(5:0)' 'FA(5:1)' 'FA(5:2)' 'FA(6:0)'
#  'FA(6:1)' 'FA(6:2)' 'FA(6:3)' 'FA(7:0)' 'FA(7:1)' 'FA(7:2)' 'FA(7:3)'
#  'FA(7:4)' 'FA(8:0)' 'FA(8:1)' 'FA(8:2)' 'FA(8:3)' 'FA(8:4)' 'FA(8:5)'
#  'FA(9:0)' 'FA(9:1)' 'FA(9:2)' 'FA(9:3)' 'FA(9:4)' 'FA(9:5)' 'FA(d2-16:0)']

# %%
# print unique columns
unique_columns = df_group.columns
print(unique_columns)
# Out:
# Index(['Parent_Ion', 'Product_Ion', 'Retention_Time', 'OzESI_Intensity',
#        'Sample_ID', 'Transition', 'Sample', 'STD', 'STD_RT_OFF',
#        'STD_Peak_Intensity', 'STD_Peak_Area', 'Lipid', 'Class', 'Species',
#        'Biology', 'Genotype', 'Cage', 'Mouse', 'group_by_ion',
#        'group_by_lipid'],
#       dtype='object')

# %% [markdown]
# # analysis 5

# %%
# !sbatch core/backend/AMP_V2/OFF/analysis_5_CT_OFF.sh
# Out:
# Submitted batch job 22194046

# %%
import pandas as pd
df_analysis = pd.read_parquet('Projects/AMP_V2/analysis/OFF/df_analysis_CT_OFF_FAME.parquet')
df_analysis
# Out:
#         Lipid  Retention_Time  OzESI_Intensity  group_by_ion  group_by_lipid  \
# 0     FA(5:1)        3.795217           1031.0             5              89
# 1     FA(5:1)        4.001283           1040.0             5              89
# 2     FA(6:2)        5.792150           3048.0             8              93
# 3     FA(6:2)       28.206167           1028.0             8              93
# 4     FA(6:2)       28.523183           1019.0             8              93
# ..        ...             ...              ...           ...             ...
# 363  FA(23:5)        5.399567           4498.0           108              85
# 364  FA(24:0)       24.594833           2982.0           116              86
# 365  FA(24:0)       24.689950           2417.0           116              86
# 366  FA(24:0)       24.785050           1962.0           116              86
# 367  FA(24:0)       24.927717           1013.0           116              86
#
#          Sample_ID      Transition Sample  Parent_Ion  Product_Ion  ...   STD  \
# 0    FAME_OzoneOff  267.2 -> 183.0   FAME       267.2        183.0  ...  None
# 1    FAME_OzoneOff  267.2 -> 183.0   FAME       267.2        183.0  ...  None
# 2    FAME_OzoneOff  279.2 -> 183.0   FAME       279.2        183.0  ...  None
# 3    FAME_OzoneOff  279.2 -> 183.0   FAME       279.2        183.0  ...  None
# 4    FAME_OzoneOff  279.2 -> 183.0   FAME       279.2        183.0  ...  None
# ..             ...             ...    ...         ...          ...  ...   ...
# 363  FAME_OzoneOff  511.4 -> 183.0   FAME       511.4        183.0  ...  None
# 364  FAME_OzoneOff  535.4 -> 183.0   FAME       535.4        183.0  ...  None
# 365  FAME_OzoneOff  535.4 -> 183.0   FAME       535.4        183.0  ...  None
# 366  FAME_OzoneOff  535.4 -> 183.0   FAME       535.4        183.0  ...  None
# 367  FAME_OzoneOff  535.4 -> 183.0   FAME       535.4        183.0  ...  None
#
#     STD_RT_OFF STD_Peak_Intensity  STD_Peak_Area  Peak_Height      FWHM  \
# 0    11.475367       34009.941406   13194.063558       1031.0  0.067124
# 1    11.475367       34009.941406   13194.063558       1040.0  0.315357
# 2    11.475367       34009.941406   13194.063558       3048.0  0.148223
# 3    11.475367       34009.941406   13194.063558       1028.0  0.094319
# 4    11.475367       34009.941406   13194.063558       1019.0  0.103924
# ..         ...                ...            ...          ...       ...
# 363  11.475367       34009.941406   13194.063558       4498.0  0.065207
# 364  11.475367       34009.941406   13194.063558       2982.0  0.241973
# 365  11.475367       34009.941406   13194.063558       2417.0  0.038222
# 366  11.475367       34009.941406   13194.063558       1962.0  0.032075
# 367  11.475367       34009.941406   13194.063558       1013.0  0.115945
#
#      Peak_Width   Peak_Area   Filter_Column  Isomer
# 0      0.079267   66.536717  group_by_lipid     cis
# 1      0.317017  250.612992  group_by_lipid   trans
# 2      0.142667  365.181892  group_by_lipid    None
# 3      0.095117   81.921175  group_by_lipid    None
# 4      0.095117   80.372658  group_by_lipid    None
# ..          ...         ...             ...     ...
# 363    0.063400  241.546075  group_by_lipid    None
# 364    0.237767  532.929025  group_by_lipid    None
# 365    0.047550  108.540800  group_by_lipid    None
# 366    0.031700   55.245175  group_by_lipid    None
# 367    0.126800  107.526400  group_by_lipid    None
#
# [368 rows x 22 columns]

# %% [markdown]
# # OFF Possible

# %%
import pandas as pd

# %% [markdown]
# # off possible

# %%
off_possible_df = pd.read_parquet('Projects/AMP_V2/analysis/OFF/df_analysis_CT_OFF_FAME.parquet')
# filter for lipid species 18:1
off_possible_df = off_possible_df[off_possible_df['Lipid'].str.contains('18:1')]
off_possible_df
# Out:
#         Lipid  Retention_Time  OzESI_Intensity  group_by_ion  group_by_lipid  \
# 239  FA(18:1)       10.269300           1100.0            81              50
# 240  FA(18:1)       11.030183           1055.0            81              50
# 241  FA(18:1)       12.330000         324899.0            81              50
# 242  FA(18:1)       12.884800          77485.0            81              50
# 243  FA(18:1)       13.138417           5609.0            81              50
# 244  FA(18:1)       13.582267           1161.0            81              50
# 245  FA(18:1)       13.661517           1040.0            81              50
#
#          Sample_ID      Transition Sample  Parent_Ion  Product_Ion  ...   STD  \
# 239  FAME_OzoneOff  449.4 -> 183.0   FAME       449.4        183.0  ...  None
# 240  FAME_OzoneOff  449.4 -> 183.0   FAME       449.4        183.0  ...  None
# 241  FAME_OzoneOff  449.4 -> 183.0   FAME       449.4        183.0  ...  None
# 242  FAME_OzoneOff  449.4 -> 183.0   FAME       449.4        183.0  ...  None
# 243  FAME_OzoneOff  449.4 -> 183.0   FAME       449.4        183.0  ...  None
# 244  FAME_OzoneOff  449.4 -> 183.0   FAME       449.4        183.0  ...  None
# 245  FAME_OzoneOff  449.4 -> 183.0   FAME       449.4        183.0  ...  None
#
#     STD_RT_OFF STD_Peak_Intensity  STD_Peak_Area  Peak_Height      FWHM  \
# 239  11.475367       34009.941406   13194.063558       1100.0  0.107470
# 240  11.475367       34009.941406   13194.063558       1055.0  0.083294
# 241  11.475367       34009.941406   13194.063558     324899.0  0.107350
# 242  11.475367       34009.941406   13194.063558      77485.0  0.107298
# 243  11.475367       34009.941406   13194.063558       5609.0  0.040537
# 244  11.475367       34009.941406   13194.063558       1161.0  0.046791
# 245  11.475367       34009.941406   13194.063558       1040.0  0.044791
#
#      Peak_Width     Peak_Area   Filter_Column  Isomer
# 239    0.110967     95.869742  group_by_lipid    None
# 240    0.095117     72.132842  group_by_lipid    None
# 241    0.110950  28488.203550  group_by_lipid     cis
# 242    0.110950   6892.110975  group_by_lipid   trans
# 243    0.047550    259.068250  group_by_lipid    None
# 244    0.047567     49.549700  group_by_lipid    None
# 245    0.047550     45.354775  group_by_lipid    None
#
# [7 rows x 22 columns]

# %% [markdown]
# # Plots

# %%
df_group = pd.read_parquet('Projects/AMP_V2/group/OFF/df_group_4_FAME_OFF.parquet')
df_group
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            255.2        183.0        3.018767             41.0
# 1            253.2        183.0        3.018883             41.0
# 2            241.1        183.0        3.019000             41.0
# 3            227.1        183.0        3.019117             41.0
# 4            255.2        183.0        3.034583             63.0
# ...            ...          ...             ...              ...
# 192652       425.4        183.0       29.038833             41.0
# 192653       425.4        183.0       29.054683             41.0
# 192654       425.4        183.0       29.070533             40.0
# 192655       425.4        183.0       29.086383             40.0
# 192656       425.4        183.0       29.102233            221.0
#
#             Sample_ID      Transition Sample   STD  STD_RT_OFF  \
# 0       FAME_OzoneOff  255.2 -> 183.0   FAME  None   11.475367
# 1       FAME_OzoneOff  253.2 -> 183.0   FAME  None   11.475367
# 2       FAME_OzoneOff  241.1 -> 183.0   FAME  None   11.475367
# 3       FAME_OzoneOff  227.1 -> 183.0   FAME  None   11.475367
# 4       FAME_OzoneOff  255.2 -> 183.0   FAME  None   11.475367
# ...               ...             ...    ...   ...         ...
# 192652  FAME_OzoneOff  425.4 -> 183.0   FAME  None   11.475367
# 192653  FAME_OzoneOff  425.4 -> 183.0   FAME  None   11.475367
# 192654  FAME_OzoneOff  425.4 -> 183.0   FAME  None   11.475367
# 192655  FAME_OzoneOff  425.4 -> 183.0   FAME  None   11.475367
# 192656  FAME_OzoneOff  425.4 -> 183.0   FAME  None   11.475367
#
#         STD_Peak_Intensity  STD_Peak_Area        Lipid Class    Species  \
# 0             34009.941406   13194.063558                     Unknown_1
# 1             34009.941406   13194.063558                     Unknown_1
# 2             34009.941406   13194.063558                     Unknown_1
# 3             34009.941406   13194.063558                     Unknown_1
# 4             34009.941406   13194.063558                     Unknown_1
# ...                    ...            ...          ...   ...        ...
# 192652        34009.941406   13194.063558  FA(d2-16:0)    FA       16:0
# 192653        34009.941406   13194.063558  FA(d2-16:0)    FA       16:0
# 192654        34009.941406   13194.063558  FA(d2-16:0)    FA       16:0
# 192655        34009.941406   13194.063558  FA(d2-16:0)    FA       16:0
# 192656        34009.941406   13194.063558  FA(d2-16:0)    FA       16:0
#
#        Biology Genotype Cage Mouse  group_by_ion  group_by_lipid
# 0                                              3               0
# 1                                              2               0
# 2                                              1               0
# 3                                              0               0
# 4                                              3               0
# ...        ...      ...  ...   ...           ...             ...
# 192652                                        70             112
# 192653                                        70             112
# 192654                                        70             112
# 192655                                        70             112
# 192656                                        70             112
#
# [192657 rows x 20 columns]

# %%
import matplotlib.pyplot as plt

# Function to plot the chromatogram for a specific group_by_lipid value
def plot_chromatogram(df, group_value):
    group_data = df[df['group_by_lipid'] == group_value]
    
    # Ensure the Retention_Time is sorted
    group_data = group_data.sort_values(by='Retention_Time')
    
    # Extract Lipid, Parent Ion, and Isomer values from the first row of the group
    lipid = group_data['Lipid'].iloc[0] if not group_data.empty else "Unknown Lipid"
    parent_ion = group_data['Parent_Ion'].iloc[0] if not group_data.empty else "Unknown Parent Ion"
    # isomer = group_data['Isomer'].iloc[0] if not group_data.empty else "Unknown Isomer"
    
    plt.figure(figsize=(10, 6))
    plt.plot(group_data['Retention_Time'], group_data['OzESI_Intensity'], label=f'group_by_lipid: {group_value}')
    plt.xlabel('Retention Time')
    plt.ylabel('OzESI Intensity')
    
    # Add Lipid, Parent Ion, and Isomer to the title
    plt.title(f'{group_value} | Lipid: {lipid} | Parent Ion: {parent_ion} ')
    
    plt.legend()
    plt.grid(True)
    plt.show()

# Define the specific group_by_lipid value you are interested in
specific_group_by_lipid_value = 50 # Replace with the actual value you are interested in

# Call the function to plot the chromatogram
plot_chromatogram(df_group, specific_group_by_lipid_value)

# %% [markdown]
# # STD

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter the data for Parent_Ion within range 425.40 ± 0.3
mask = (df_mzml['Parent_Ion'] >= 425.10) & (df_mzml['Parent_Ion'] <= 425.70)
filtered_df = df_mzml[mask]

# Create the plot
plt.figure(figsize=(10, 6))
plt.scatter(filtered_df['Retention_Time'], filtered_df['OzESI_Intensity'], 
           color='blue', alpha=0.6, label='Parent Ion 425.40 ± 0.3')

# Add labels and title
plt.xlabel('Retention Time (min)')
plt.ylabel('Intensity')
plt.title('Retention Time vs Intensity for Parent Ion 425.40 ± 0.3')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
