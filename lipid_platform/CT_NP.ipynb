# %%
import pandas as pd

# %% [markdown]
# # 1 - mzml parse

# %%
# !sbatch core/backend/CT/NP/mzml_parser_1_CT_NP.sh
# Out:
# Submitted batch job 22190140

# %% [markdown]
# # 2 Sample

# %% [markdown]
# # 3 NP Match NP

# %%
# !sbatch core/backend/CT/NP/match_3_CT_NP.sh
# Out:
# Submitted batch job 22190490

# %%
df_match = pd.read_parquet('Projects/CT/match/NP/df_match_3_df_sample_2_CisTrans.parquet')
df_match
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            227.1        183.0        3.019117             42.0
# 1            227.1        183.0        3.034950             41.0
# 2            227.1        183.0        3.050800             41.0
# 3            227.1        183.0        3.066650             41.0
# 4            227.1        183.0        3.082500             41.0
# ...            ...          ...             ...              ...
# 214015       533.5        183.0       31.933133             41.0
# 214016       533.5        183.0       31.948983             41.0
# 214017       533.5        183.0       31.964833             41.0
# 214018       533.5        183.0       31.980683             41.0
# 214019       533.5        183.0       31.996550             42.0
#
#                                    Sample_ID      Transition    Sample  \
# 0       01162025_CisTransMix_AMP_OzoneOff_01  227.1 -> 183.0  CisTrans
# 1       01162025_CisTransMix_AMP_OzoneOff_01  227.1 -> 183.0  CisTrans
# 2       01162025_CisTransMix_AMP_OzoneOff_01  227.1 -> 183.0  CisTrans
# 3       01162025_CisTransMix_AMP_OzoneOff_01  227.1 -> 183.0  CisTrans
# 4       01162025_CisTransMix_AMP_OzoneOff_01  227.1 -> 183.0  CisTrans
# ...                                      ...             ...       ...
# 214015  01162025_CisTransMix_AMP_OzoneOff_01  533.5 -> 183.0  CisTrans
# 214016  01162025_CisTransMix_AMP_OzoneOff_01  533.5 -> 183.0  CisTrans
# 214017  01162025_CisTransMix_AMP_OzoneOff_01  533.5 -> 183.0  CisTrans
# 214018  01162025_CisTransMix_AMP_OzoneOff_01  533.5 -> 183.0  CisTrans
# 214019  01162025_CisTransMix_AMP_OzoneOff_01  533.5 -> 183.0  CisTrans
#
#              STD  STD_RT_OFF  STD_Peak_Intensity  STD_Peak_Area     Lipid  \
# 0       CisTrans     10.5243          836.500061    1637.619204
# 1       CisTrans     10.5243          836.500061    1637.619204
# 2       CisTrans     10.5243          836.500061    1637.619204
# 3       CisTrans     10.5243          836.500061    1637.619204
# 4       CisTrans     10.5243          836.500061    1637.619204
# ...          ...         ...                 ...            ...       ...
# 214015  CisTrans     10.5243          836.500061    1637.619204  FA(24:1)
# 214016  CisTrans     10.5243          836.500061    1637.619204  FA(24:1)
# 214017  CisTrans     10.5243          836.500061    1637.619204  FA(24:1)
# 214018  CisTrans     10.5243          836.500061    1637.619204  FA(24:1)
# 214019  CisTrans     10.5243          836.500061    1637.619204  FA(24:1)
#
#        Class
# 0
# 1
# 2
# 3
# 4
# ...      ...
# 214015    FA
# 214016    FA
# 214017    FA
# 214018    FA
# 214019    FA
#
# [214020 rows x 13 columns]

# %% [markdown]
# # 4 - group

# %%
# !sbatch core/backend/CT/NP/group_4_CT_NP.sh
# Out:
# Submitted batch job 22190781

# %%
df_group = pd.read_parquet('Projects/CT/group/NP/df_grouped_CisTrans_OFF.parquet')
df_group
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            255.2        183.0        3.018767             42.0
# 1            253.2        183.0        3.018883             41.0
# 2            241.1        183.0        3.019000             42.0
# 3            227.1        183.0        3.019117             42.0
# 4            255.2        183.0        3.034600             41.0
# ...            ...          ...             ...              ...
# 214015       425.4        183.0       31.923800             41.0
# 214016       425.4        183.0       31.939650             41.0
# 214017       425.4        183.0       31.955500             41.0
# 214018       425.4        183.0       31.971350             42.0
# 214019       425.4        183.0       31.987200             77.0
#
#                                    Sample_ID      Transition    Sample  \
# 0       01162025_CisTransMix_AMP_OzoneOff_01  255.2 -> 183.0  CisTrans
# 1       01162025_CisTransMix_AMP_OzoneOff_01  253.2 -> 183.0  CisTrans
# 2       01162025_CisTransMix_AMP_OzoneOff_01  241.1 -> 183.0  CisTrans
# 3       01162025_CisTransMix_AMP_OzoneOff_01  227.1 -> 183.0  CisTrans
# 4       01162025_CisTransMix_AMP_OzoneOff_01  255.2 -> 183.0  CisTrans
# ...                                      ...             ...       ...
# 214015  01162025_CisTransMix_AMP_OzoneOff_01  425.4 -> 183.0  CisTrans
# 214016  01162025_CisTransMix_AMP_OzoneOff_01  425.4 -> 183.0  CisTrans
# 214017  01162025_CisTransMix_AMP_OzoneOff_01  425.4 -> 183.0  CisTrans
# 214018  01162025_CisTransMix_AMP_OzoneOff_01  425.4 -> 183.0  CisTrans
# 214019  01162025_CisTransMix_AMP_OzoneOff_01  425.4 -> 183.0  CisTrans
#
#              STD  STD_RT_OFF  STD_Peak_Intensity  STD_Peak_Area        Lipid  \
# 0       CisTrans     10.5243          836.500061    1637.619204
# 1       CisTrans     10.5243          836.500061    1637.619204
# 2       CisTrans     10.5243          836.500061    1637.619204
# 3       CisTrans     10.5243          836.500061    1637.619204
# 4       CisTrans     10.5243          836.500061    1637.619204
# ...          ...         ...                 ...            ...          ...
# 214015  CisTrans     10.5243          836.500061    1637.619204  FA(d2-16:0)
# 214016  CisTrans     10.5243          836.500061    1637.619204  FA(d2-16:0)
# 214017  CisTrans     10.5243          836.500061    1637.619204  FA(d2-16:0)
# 214018  CisTrans     10.5243          836.500061    1637.619204  FA(d2-16:0)
# 214019  CisTrans     10.5243          836.500061    1637.619204  FA(d2-16:0)
#
#        Class       Species  Biology Genotype     Cage    Mouse  group_by_ion  \
# 0             Unknown_5488  Unknown  Unknown  Unknown  Unknown             3
# 1             Unknown_3659  Unknown  Unknown  Unknown  Unknown             2
# 2             Unknown_1830  Unknown  Unknown  Unknown  Unknown             1
# 3                Unknown_1  Unknown  Unknown  Unknown  Unknown             0
# 4             Unknown_5489  Unknown  Unknown  Unknown  Unknown             3
# ...      ...           ...      ...      ...      ...      ...           ...
# 214015    FA          16:0  Unknown  Unknown  Unknown  Unknown            70
# 214016    FA          16:0  Unknown  Unknown  Unknown  Unknown            70
# 214017    FA          16:0  Unknown  Unknown  Unknown  Unknown            70
# 214018    FA          16:0  Unknown  Unknown  Unknown  Unknown            70
# 214019    FA          16:0  Unknown  Unknown  Unknown  Unknown            70
#
#         group_by_lipid
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# 214015             112
# 214016             112
# 214017             112
# 214018             112
# 214019             112
#
# [214020 rows x 20 columns]

# %% [markdown]
# # 5 - Analysis

# %%
# !sbatch core/backend/CT/NP/analysis_5_CT_NP.sh
# Out:
# Submitted batch job 22190794

# %%
import pandas as pd
df_analysis = pd.read_parquet('Projects/CT/analysis/NP/')
df_analysis

# %% [markdown]
# # 6 - Not Possible

# %%
import pandas as pd
import os
import glob

def list_files_in_dirs(dir1, dir2, extension='*.parquet'):
    """
    Lists file names from two directories and creates keys for matching, explicitly handling "CisTrans" cases.

    Parameters:
    dir1 (str): Path to the first directory.
    dir2 (str): Path to the second directory.
    extension (str): File extension to match (default: '*.parquet').

    Returns:
    DataFrame: DataFrame containing file names from both directories and their keys.
    """
    # Get list of files in both directories
    files1 = glob.glob(os.path.join(dir1, extension))
    files2 = glob.glob(os.path.join(dir2, extension))

    # Debugging: Print file lists
    print(f"Files in {dir1}: {files1}")
    print(f"Files in {dir2}: {files2}")

    # Create separate DataFrames for each directory
    df1 = pd.DataFrame({
        'File': [os.path.basename(f) for f in files1],
        'Key': ["CisTrans" if "CisTrans" in os.path.basename(f) else os.path.basename(f).replace('.parquet', '') for f in files1]
    })
    df2 = pd.DataFrame({
        'File': [os.path.basename(f) for f in files2],
        'Key': ["CisTrans" if "CisTrans" in os.path.basename(f) else os.path.basename(f).replace('.parquet', '') for f in files2]
    })

    # Debugging: Print DataFrames before processing
    print(f"Initial DataFrame 1:\n{df1}")
    print(f"Initial DataFrame 2:\n{df2}")

    # Merge the DataFrames on the Key column
    merged_df = pd.merge(
        df1, 
        df2, 
        on='Key', 
        how='inner',  # Only keep pairs with matching keys
        suffixes=('_OzON', '_OzOFF')
    )

    # Debugging: Print merged DataFrame
    print(f"Merged DataFrame:\n{merged_df}")

    return merged_df

def match_lipids_with_adjusted_rt_to_rt_from_dirs(dir1, dir2, output_dir, rt_window=0.5):
    """
    Matches lipids between files in two directories using retention time and keys.

    Parameters:
    dir1 (str): Directory containing OzON files.
    dir2 (str): Directory containing OzOFF files.
    output_dir (str): Directory to save matched and unmatched results.
    rt_window (float): Retention time window for matching (default: 0.5).
    """
    # Get matched file pairs based on keys
    file_pairs = list_files_in_dirs(dir1, dir2)

    # Iterate through each matched pair of files
    for _, row in file_pairs.iterrows():
        ozon_file = os.path.join(dir1, row['File_OzON'])
        ozoff_file = os.path.join(dir2, row['File_OzOFF'])

        # Load the data from the matched files
        ozon_test = pd.read_parquet(ozon_file)
        sorted_notpossible_lipids = pd.read_parquet(ozoff_file)

        # Debugging: Print the first few rows of both DataFrames
        print(f"OzON DataFrame for {row['File_OzON']}:\n{ozon_test.head()}")
        print(f"OzOFF DataFrame for {row['File_OzOFF']}:\n{sorted_notpossible_lipids.head()}")

        # Create new columns in the ON data to store matched information from OFF
        ozon_test['Matched_Lipid_OFF'] = None
        ozon_test['Intensity_OFF'] = None
        ozon_test['Retention_Time_OFF'] = None

        # Perform lipid matching
        for index_on, row_on in ozon_test.iterrows():
            on_lipid = row_on['Lipid'].strip()  # Trim spaces for accurate matching
            on_adjusted_rt = row_on['Adjusted_RT']
            match_found = False

            for _, row_off in sorted_notpossible_lipids.iterrows():
                off_lipids = [lipid.strip() for lipid in row_off['Lipid'].split('|')]
                off_retention_time = row_off['Retention_Time']

                # Debugging: Print lipid comparison details
                print(f"Comparing ON lipid {on_lipid} (RT: {on_adjusted_rt}) with OFF lipids {off_lipids} (RT: {off_retention_time})")

                if any(on_lipid.lower() == off_lipid.lower() for off_lipid in off_lipids) and abs(on_adjusted_rt - off_retention_time) <= rt_window:
                    ozon_test.at[index_on, 'Matched_Lipid_OFF'] = row_off['Lipid']
                    ozon_test.at[index_on, 'Intensity_OFF'] = row_off['OzESI_Intensity']
                    ozon_test.at[index_on, 'Retention_Time_OFF'] = off_retention_time
                    match_found = True
                    break

            if not match_found:
                print(f"No match found for ON lipid {on_lipid} with Adjusted RT {on_adjusted_rt}")

        # Separate matched and unmatched lipids
        matched_lipids_df = ozon_test.dropna(subset=['Matched_Lipid_OFF']).copy()
        unmatched_lipids_df = ozon_test[ozon_test['Matched_Lipid_OFF'].isna()].copy()

        # Save results
        os.makedirs(output_dir, exist_ok=True)  # Ensure output directory exists
        matched_file = os.path.join(output_dir, f"matched_{row['Key']}.csv")
        unmatched_file = os.path.join(output_dir, f"unmatched_{row['Key']}.csv")

        matched_lipids_df.to_csv(matched_file, index=False)
        unmatched_lipids_df.to_csv(unmatched_file, index=False)

        print(f"Processed files: {row['File_OzON']} and {row['File_OzOFF']}")
        print(f"Saved matched lipids to {matched_file}")
        print(f"Saved unmatched lipids to {unmatched_file}")

# Example usage
ozon_dir = 'Projects/CT/isomer_filter/'
ozoff_dir = 'Projects/CT/analysis/NP/'
output_dir = 'Projects/CT/not_possible/'

match_lipids_with_adjusted_rt_to_rt_from_dirs(ozon_dir, ozoff_dir, output_dir, rt_window=0.5)
# Out:
# Files in Projects/CT/isomer_filter/: ['Projects/CT/isomer_filter/CisTrans_isomer_filtered.parquet', 'Projects/CT/isomer_filter/Unknown_isomer_filtered.parquet']
# Files in Projects/CT/analysis/NP/: ['Projects/CT/analysis/NP/df_analysis_5_CisTrans_OFF.parquet', 'Projects/CT/analysis/NP/df_analysis_5_Blank_OFF.parquet', 'Projects/CT/analysis/NP/df_analysis_5_Unknown_OFF.parquet']
# Initial DataFrame 1:
#                                File                      Key
# 0  CisTrans_isomer_filtered.parquet                 CisTrans
# 1   Unknown_isomer_filtered.parquet  Unknown_isomer_filtered
# Initial DataFrame 2:
#                                  File                        Key
# 0  df_analysis_5_CisTrans_OFF.parquet                   CisTrans
# 1     df_analysis_5_Blank_OFF.parquet    df_analysis_5_Blank_OFF
# 2   df_analysis_5_Unknown_OFF.parquet  df_analysis_5_Unknown_OFF
# Merged DataFrame:
#                           File_OzON       Key  \
# 0  CisTrans_isomer_filtered.parquet  CisTrans
#
#                            File_OzOFF
# 0  df_analysis_5_CisTrans_OFF.parquet
# OzON DataFrame for CisTrans_isomer_filtered.parquet:
#               Lipid  Retention_Time  OzESI_Intensity  group_by_ion  \
# 0  FA(18:1)_<>_n-4        11.317717            885.0            35
# 1  FA(18:1)_<>_n-5        11.255050           1352.0            32
# 2  FA(18:1)_<>_n-6        11.255767           2105.0            29
# 3  FA(18:1)_<>_n-7        11.256500           1450.0            26
# 4  FA(18:1)_<>_n-8        11.273067           3767.0            23
#
#    group_by_lipid                            Sample_ID      Transition  \
# 0               9  01162025_CisTransMix_AMP_OzoneOn_01  409.3 -> 183.0
# 1              10  01162025_CisTransMix_AMP_OzoneOn_01  395.3 -> 183.0
# 2              11  01162025_CisTransMix_AMP_OzoneOn_01  381.3 -> 183.0
# 3              12  01162025_CisTransMix_AMP_OzoneOn_01  367.3 -> 183.0
# 4              13  01162025_CisTransMix_AMP_OzoneOn_01  353.3 -> 183.0
#
#      Sample  Parent_Ion  Product_Ion  ... Baseline_Drift Shoulder_Count  \
# 0  CisTrans       409.3        183.0  ...     796.987891              1
# 1  CisTrans       395.3        183.0  ...    1921.403178              1
# 2  CisTrans       381.3        183.0  ...    4182.619593              1
# 3  CisTrans       367.3        183.0  ...    2521.439076              1
# 4  CisTrans       353.3        183.0  ...   13275.669075              1
#
#   Biology  Genotype  Cage  Mouse  Normalized_Peak_Area  n_value n_position  \
# 0                                             0.289043        4        4.0
# 1                                             0.652568        5        5.0
# 2                                             1.095198        6        6.0
# 3                                             0.724706        7        7.0
# 4                                             1.144526        8        8.0
#
#    OzOFF_Isomer
# 0           cis
# 1           cis
# 2           cis
# 3           cis
# 4           cis
#
# [5 rows x 38 columns]
# OzOFF DataFrame for df_analysis_5_CisTrans_OFF.parquet:
#      Lipid  Retention_Time  OzESI_Intensity  group_by_ion  group_by_lipid  \
# 0  FA(6:2)        5.475117           1700.0             8              93
# 1  FA(6:2)       27.889133            547.0             8              93
# 2  FA(6:3)       30.584000           1253.0             7              94
# 3  FA(7:2)        4.238117           1425.0            13              97
# 4  FA(7:2)        4.380783           1454.0            13              97
#
#                               Sample_ID      Transition    Sample  Parent_Ion  \
# 0  01162025_CisTransMix_AMP_OzoneOff_01  279.2 -> 183.0  CisTrans       279.2
# 1  01162025_CisTransMix_AMP_OzoneOff_01  279.2 -> 183.0  CisTrans       279.2
# 2  01162025_CisTransMix_AMP_OzoneOff_01  277.2 -> 183.0  CisTrans       277.2
# 3  01162025_CisTransMix_AMP_OzoneOff_01  293.2 -> 183.0  CisTrans       293.2
# 4  01162025_CisTransMix_AMP_OzoneOff_01  293.2 -> 183.0  CisTrans       293.2
#
#    Product_Ion Species Class       STD  STD_RT_OFF  Peak_Height      FWHM  \
# 0        183.0     6:2    FA  CisTrans     10.5243       1700.0  0.067571
# 1        183.0     6:2    FA  CisTrans     10.5243        547.0  0.061782
# 2        183.0     6:3    FA  CisTrans     10.5243       1253.0  0.048243
# 3        183.0     7:2    FA  CisTrans     10.5243       1425.0  0.037122
# 4        183.0     7:2    FA  CisTrans     10.5243       1454.0  0.372422
#
#    Peak_Width   Peak_Area   Filter_Column Isomer
# 0    0.063400  107.780000  group_by_lipid   None
# 1    0.063400   34.679800  group_by_lipid   None
# 2    0.047550   59.580150  group_by_lipid   None
# 3    0.047550   67.758750  group_by_lipid   None
# 4    0.364583  530.104167  group_by_lipid   None
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(6:2)'] (RT: 5.475116666666667)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(6:2)'] (RT: 27.889133333333334)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(6:3)'] (RT: 30.584000000000003)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(7:2)'] (RT: 4.2381166666666665)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(7:2)'] (RT: 4.3807833333333335)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(7:2)'] (RT: 4.58685)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(7:2)'] (RT: 4.697816666666667)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(7:2)'] (RT: 4.792916666666667)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(7:2)'] (RT: 4.903883333333334)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(7:2)'] (RT: 5.014833333333334)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(7:2)'] (RT: 5.4745333333333335)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(7:2)'] (RT: 5.6964500000000005)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(7:2)'] (RT: 5.9183666666666666)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(7:2)'] (RT: 7.994916666666667)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(7:2)'] (RT: 8.597266666666668)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(7:2)'] (RT: 9.104533333333334)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(9:0)'] (RT: 4.426666666666667)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(9:0)'] (RT: 10.402683333333334)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(9:3)'] (RT: 30.581983333333334)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(10:5)'] (RT: 30.75586666666667)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(d2-16:0)'] (RT: 10.5243)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(16:0)'] (RT: 10.508566666666667)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:0)'] (RT: 11.283683333333334)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:0)'] (RT: 11.679983333333334)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:0)'] (RT: 11.822650000000001)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:0)'] (RT: 13.693133333333334)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:1)'] (RT: 9.38165)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:1)'] (RT: 11.283816666666667)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:1)'] (RT: 11.664250000000001)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:1)'] (RT: 12.012983333333334)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:1)'] (RT: 12.18735)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:1)'] (RT: 12.409283333333335)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:1)'] (RT: 12.5995)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:1)'] (RT: 12.71045)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:1)'] (RT: 12.805566666666667)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:1)'] (RT: 12.979933333333333)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:1)'] (RT: 13.106733333333334)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:2)'] (RT: 7.986816666666667)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:2)'] (RT: 9.381766666666667)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:2)'] (RT: 9.730500000000001)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:2)'] (RT: 9.952416666666668)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:2)'] (RT: 10.031683333333334)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:2)'] (RT: 10.285300000000001)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(18:3)'] (RT: 8.0028)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(20:0)'] (RT: 17.020466666666668)
# Comparing ON lipid FA(18:1)_<>_n-4 (RT: 11.317716666666668) with OFF lipids ['FA(22:0)'] (RT: 19.998933333333333)
# No match found for ON lipid FA(18:1)_<>_n-4 with Adjusted RT 11.317716666666668
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(6:2)'] (RT: 5.475116666666667)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(6:2)'] (RT: 27.889133333333334)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(6:3)'] (RT: 30.584000000000003)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(7:2)'] (RT: 4.2381166666666665)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(7:2)'] (RT: 4.3807833333333335)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(7:2)'] (RT: 4.58685)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(7:2)'] (RT: 4.697816666666667)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(7:2)'] (RT: 4.792916666666667)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(7:2)'] (RT: 4.903883333333334)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(7:2)'] (RT: 5.014833333333334)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(7:2)'] (RT: 5.4745333333333335)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(7:2)'] (RT: 5.6964500000000005)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(7:2)'] (RT: 5.9183666666666666)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(7:2)'] (RT: 7.994916666666667)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(7:2)'] (RT: 8.597266666666668)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(7:2)'] (RT: 9.104533333333334)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(9:0)'] (RT: 4.426666666666667)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(9:0)'] (RT: 10.402683333333334)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(9:3)'] (RT: 30.581983333333334)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(10:5)'] (RT: 30.75586666666667)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(d2-16:0)'] (RT: 10.5243)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(16:0)'] (RT: 10.508566666666667)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:0)'] (RT: 11.283683333333334)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:0)'] (RT: 11.679983333333334)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:0)'] (RT: 11.822650000000001)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:0)'] (RT: 13.693133333333334)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:1)'] (RT: 9.38165)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:1)'] (RT: 11.283816666666667)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:1)'] (RT: 11.664250000000001)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:1)'] (RT: 12.012983333333334)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:1)'] (RT: 12.18735)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:1)'] (RT: 12.409283333333335)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:1)'] (RT: 12.5995)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:1)'] (RT: 12.71045)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:1)'] (RT: 12.805566666666667)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:1)'] (RT: 12.979933333333333)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:1)'] (RT: 13.106733333333334)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:2)'] (RT: 7.986816666666667)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:2)'] (RT: 9.381766666666667)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:2)'] (RT: 9.730500000000001)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:2)'] (RT: 9.952416666666668)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:2)'] (RT: 10.031683333333334)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:2)'] (RT: 10.285300000000001)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(18:3)'] (RT: 8.0028)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(20:0)'] (RT: 17.020466666666668)
# Comparing ON lipid FA(18:1)_<>_n-5 (RT: 11.25505) with OFF lipids ['FA(22:0)'] (RT: 19.998933333333333)
# No match found for ON lipid FA(18:1)_<>_n-5 with Adjusted RT 11.25505
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(6:2)'] (RT: 5.475116666666667)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(6:2)'] (RT: 27.889133333333334)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(6:3)'] (RT: 30.584000000000003)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(7:2)'] (RT: 4.2381166666666665)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(7:2)'] (RT: 4.3807833333333335)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(7:2)'] (RT: 4.58685)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(7:2)'] (RT: 4.697816666666667)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(7:2)'] (RT: 4.792916666666667)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(7:2)'] (RT: 4.903883333333334)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(7:2)'] (RT: 5.014833333333334)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(7:2)'] (RT: 5.4745333333333335)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(7:2)'] (RT: 5.6964500000000005)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(7:2)'] (RT: 5.9183666666666666)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(7:2)'] (RT: 7.994916666666667)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(7:2)'] (RT: 8.597266666666668)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(7:2)'] (RT: 9.104533333333334)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(9:0)'] (RT: 4.426666666666667)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(9:0)'] (RT: 10.402683333333334)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(9:3)'] (RT: 30.581983333333334)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(10:5)'] (RT: 30.75586666666667)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(d2-16:0)'] (RT: 10.5243)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(16:0)'] (RT: 10.508566666666667)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:0)'] (RT: 11.283683333333334)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:0)'] (RT: 11.679983333333334)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:0)'] (RT: 11.822650000000001)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:0)'] (RT: 13.693133333333334)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:1)'] (RT: 9.38165)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:1)'] (RT: 11.283816666666667)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:1)'] (RT: 11.664250000000001)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:1)'] (RT: 12.012983333333334)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:1)'] (RT: 12.18735)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:1)'] (RT: 12.409283333333335)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:1)'] (RT: 12.5995)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:1)'] (RT: 12.71045)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:1)'] (RT: 12.805566666666667)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:1)'] (RT: 12.979933333333333)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:1)'] (RT: 13.106733333333334)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:2)'] (RT: 7.986816666666667)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:2)'] (RT: 9.381766666666667)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:2)'] (RT: 9.730500000000001)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:2)'] (RT: 9.952416666666668)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:2)'] (RT: 10.031683333333334)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:2)'] (RT: 10.285300000000001)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(18:3)'] (RT: 8.0028)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(20:0)'] (RT: 17.020466666666668)
# Comparing ON lipid FA(18:1)_<>_n-6 (RT: 11.255766666666668) with OFF lipids ['FA(22:0)'] (RT: 19.998933333333333)
# No match found for ON lipid FA(18:1)_<>_n-6 with Adjusted RT 11.255766666666668
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(6:2)'] (RT: 5.475116666666667)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(6:2)'] (RT: 27.889133333333334)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(6:3)'] (RT: 30.584000000000003)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(7:2)'] (RT: 4.2381166666666665)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(7:2)'] (RT: 4.3807833333333335)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(7:2)'] (RT: 4.58685)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(7:2)'] (RT: 4.697816666666667)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(7:2)'] (RT: 4.792916666666667)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(7:2)'] (RT: 4.903883333333334)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(7:2)'] (RT: 5.014833333333334)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(7:2)'] (RT: 5.4745333333333335)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(7:2)'] (RT: 5.6964500000000005)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(7:2)'] (RT: 5.9183666666666666)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(7:2)'] (RT: 7.994916666666667)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(7:2)'] (RT: 8.597266666666668)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(7:2)'] (RT: 9.104533333333334)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(9:0)'] (RT: 4.426666666666667)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(9:0)'] (RT: 10.402683333333334)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(9:3)'] (RT: 30.581983333333334)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(10:5)'] (RT: 30.75586666666667)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(d2-16:0)'] (RT: 10.5243)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(16:0)'] (RT: 10.508566666666667)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:0)'] (RT: 11.283683333333334)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:0)'] (RT: 11.679983333333334)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:0)'] (RT: 11.822650000000001)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:0)'] (RT: 13.693133333333334)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:1)'] (RT: 9.38165)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:1)'] (RT: 11.283816666666667)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:1)'] (RT: 11.664250000000001)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:1)'] (RT: 12.012983333333334)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:1)'] (RT: 12.18735)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:1)'] (RT: 12.409283333333335)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:1)'] (RT: 12.5995)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:1)'] (RT: 12.71045)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:1)'] (RT: 12.805566666666667)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:1)'] (RT: 12.979933333333333)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:1)'] (RT: 13.106733333333334)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:2)'] (RT: 7.986816666666667)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:2)'] (RT: 9.381766666666667)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:2)'] (RT: 9.730500000000001)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:2)'] (RT: 9.952416666666668)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:2)'] (RT: 10.031683333333334)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:2)'] (RT: 10.285300000000001)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(18:3)'] (RT: 8.0028)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(20:0)'] (RT: 17.020466666666668)
# Comparing ON lipid FA(18:1)_<>_n-7 (RT: 11.2565) with OFF lipids ['FA(22:0)'] (RT: 19.998933333333333)
# No match found for ON lipid FA(18:1)_<>_n-7 with Adjusted RT 11.2565
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(6:2)'] (RT: 5.475116666666667)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(6:2)'] (RT: 27.889133333333334)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(6:3)'] (RT: 30.584000000000003)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(7:2)'] (RT: 4.2381166666666665)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(7:2)'] (RT: 4.3807833333333335)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(7:2)'] (RT: 4.58685)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(7:2)'] (RT: 4.697816666666667)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(7:2)'] (RT: 4.792916666666667)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(7:2)'] (RT: 4.903883333333334)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(7:2)'] (RT: 5.014833333333334)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(7:2)'] (RT: 5.4745333333333335)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(7:2)'] (RT: 5.6964500000000005)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(7:2)'] (RT: 5.9183666666666666)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(7:2)'] (RT: 7.994916666666667)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(7:2)'] (RT: 8.597266666666668)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(7:2)'] (RT: 9.104533333333334)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(9:0)'] (RT: 4.426666666666667)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(9:0)'] (RT: 10.402683333333334)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(9:3)'] (RT: 30.581983333333334)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(10:5)'] (RT: 30.75586666666667)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(d2-16:0)'] (RT: 10.5243)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(16:0)'] (RT: 10.508566666666667)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:0)'] (RT: 11.283683333333334)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:0)'] (RT: 11.679983333333334)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:0)'] (RT: 11.822650000000001)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:0)'] (RT: 13.693133333333334)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:1)'] (RT: 9.38165)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:1)'] (RT: 11.283816666666667)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:1)'] (RT: 11.664250000000001)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:1)'] (RT: 12.012983333333334)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:1)'] (RT: 12.18735)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:1)'] (RT: 12.409283333333335)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:1)'] (RT: 12.5995)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:1)'] (RT: 12.71045)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:1)'] (RT: 12.805566666666667)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:1)'] (RT: 12.979933333333333)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:1)'] (RT: 13.106733333333334)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:2)'] (RT: 7.986816666666667)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:2)'] (RT: 9.381766666666667)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:2)'] (RT: 9.730500000000001)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:2)'] (RT: 9.952416666666668)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:2)'] (RT: 10.031683333333334)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:2)'] (RT: 10.285300000000001)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(18:3)'] (RT: 8.0028)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(20:0)'] (RT: 17.020466666666668)
# Comparing ON lipid FA(18:1)_<>_n-8 (RT: 11.273066666666667) with OFF lipids ['FA(22:0)'] (RT: 19.998933333333333)
# No match found for ON lipid FA(18:1)_<>_n-8 with Adjusted RT 11.273066666666667
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(6:2)'] (RT: 5.475116666666667)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(6:2)'] (RT: 27.889133333333334)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(6:3)'] (RT: 30.584000000000003)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(7:2)'] (RT: 4.2381166666666665)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(7:2)'] (RT: 4.3807833333333335)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(7:2)'] (RT: 4.58685)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(7:2)'] (RT: 4.697816666666667)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(7:2)'] (RT: 4.792916666666667)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(7:2)'] (RT: 4.903883333333334)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(7:2)'] (RT: 5.014833333333334)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(7:2)'] (RT: 5.4745333333333335)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(7:2)'] (RT: 5.6964500000000005)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(7:2)'] (RT: 5.9183666666666666)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(7:2)'] (RT: 7.994916666666667)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(7:2)'] (RT: 8.597266666666668)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(7:2)'] (RT: 9.104533333333334)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(9:0)'] (RT: 4.426666666666667)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(9:0)'] (RT: 10.402683333333334)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(9:3)'] (RT: 30.581983333333334)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(10:5)'] (RT: 30.75586666666667)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(d2-16:0)'] (RT: 10.5243)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(16:0)'] (RT: 10.508566666666667)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:0)'] (RT: 11.283683333333334)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:0)'] (RT: 11.679983333333334)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:0)'] (RT: 11.822650000000001)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:0)'] (RT: 13.693133333333334)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:1)'] (RT: 9.38165)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:1)'] (RT: 11.283816666666667)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:1)'] (RT: 11.664250000000001)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:1)'] (RT: 12.012983333333334)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:1)'] (RT: 12.18735)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:1)'] (RT: 12.409283333333335)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:1)'] (RT: 12.5995)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:1)'] (RT: 12.71045)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:1)'] (RT: 12.805566666666667)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:1)'] (RT: 12.979933333333333)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:1)'] (RT: 13.106733333333334)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:2)'] (RT: 7.986816666666667)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:2)'] (RT: 9.381766666666667)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:2)'] (RT: 9.730500000000001)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:2)'] (RT: 9.952416666666668)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:2)'] (RT: 10.031683333333334)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:2)'] (RT: 10.285300000000001)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(18:3)'] (RT: 8.0028)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(20:0)'] (RT: 17.020466666666668)
# Comparing ON lipid FA(18:1)_<>_n-9 (RT: 11.32135) with OFF lipids ['FA(22:0)'] (RT: 19.998933333333333)
# No match found for ON lipid FA(18:1)_<>_n-9 with Adjusted RT 11.32135
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(6:2)'] (RT: 5.475116666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(6:2)'] (RT: 27.889133333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(6:3)'] (RT: 30.584000000000003)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(7:2)'] (RT: 4.2381166666666665)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(7:2)'] (RT: 4.3807833333333335)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(7:2)'] (RT: 4.58685)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(7:2)'] (RT: 4.697816666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(7:2)'] (RT: 4.792916666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(7:2)'] (RT: 4.903883333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(7:2)'] (RT: 5.014833333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(7:2)'] (RT: 5.4745333333333335)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(7:2)'] (RT: 5.6964500000000005)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(7:2)'] (RT: 5.9183666666666666)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(7:2)'] (RT: 7.994916666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(7:2)'] (RT: 8.597266666666668)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(7:2)'] (RT: 9.104533333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(9:0)'] (RT: 4.426666666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(9:0)'] (RT: 10.402683333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(9:3)'] (RT: 30.581983333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(10:5)'] (RT: 30.75586666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(d2-16:0)'] (RT: 10.5243)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(16:0)'] (RT: 10.508566666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:0)'] (RT: 11.283683333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:0)'] (RT: 11.679983333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:0)'] (RT: 11.822650000000001)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:0)'] (RT: 13.693133333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:1)'] (RT: 9.38165)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:1)'] (RT: 11.283816666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:1)'] (RT: 11.664250000000001)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:1)'] (RT: 12.012983333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:1)'] (RT: 12.18735)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:1)'] (RT: 12.409283333333335)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:1)'] (RT: 12.5995)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:1)'] (RT: 12.71045)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:1)'] (RT: 12.805566666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:1)'] (RT: 12.979933333333333)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:1)'] (RT: 13.106733333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:2)'] (RT: 7.986816666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:2)'] (RT: 9.381766666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:2)'] (RT: 9.730500000000001)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:2)'] (RT: 9.952416666666668)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:2)'] (RT: 10.031683333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:2)'] (RT: 10.285300000000001)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(18:3)'] (RT: 8.0028)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(20:0)'] (RT: 17.020466666666668)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.448866666666667) with OFF lipids ['FA(22:0)'] (RT: 19.998933333333333)
# No match found for ON lipid FA(18:1)_<>_n-10 with Adjusted RT 11.448866666666667
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(6:2)'] (RT: 5.475116666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(6:2)'] (RT: 27.889133333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(6:3)'] (RT: 30.584000000000003)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(7:2)'] (RT: 4.2381166666666665)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(7:2)'] (RT: 4.3807833333333335)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(7:2)'] (RT: 4.58685)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(7:2)'] (RT: 4.697816666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(7:2)'] (RT: 4.792916666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(7:2)'] (RT: 4.903883333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(7:2)'] (RT: 5.014833333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(7:2)'] (RT: 5.4745333333333335)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(7:2)'] (RT: 5.6964500000000005)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(7:2)'] (RT: 5.9183666666666666)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(7:2)'] (RT: 7.994916666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(7:2)'] (RT: 8.597266666666668)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(7:2)'] (RT: 9.104533333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(9:0)'] (RT: 4.426666666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(9:0)'] (RT: 10.402683333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(9:3)'] (RT: 30.581983333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(10:5)'] (RT: 30.75586666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(d2-16:0)'] (RT: 10.5243)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(16:0)'] (RT: 10.508566666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:0)'] (RT: 11.283683333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:0)'] (RT: 11.679983333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:0)'] (RT: 11.822650000000001)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:0)'] (RT: 13.693133333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:1)'] (RT: 9.38165)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:1)'] (RT: 11.283816666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:1)'] (RT: 11.664250000000001)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:1)'] (RT: 12.012983333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:1)'] (RT: 12.18735)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:1)'] (RT: 12.409283333333335)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:1)'] (RT: 12.5995)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:1)'] (RT: 12.71045)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:1)'] (RT: 12.805566666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:1)'] (RT: 12.979933333333333)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:1)'] (RT: 13.106733333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:2)'] (RT: 7.986816666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:2)'] (RT: 9.381766666666667)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:2)'] (RT: 9.730500000000001)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:2)'] (RT: 9.952416666666668)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:2)'] (RT: 10.031683333333334)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:2)'] (RT: 10.285300000000001)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(18:3)'] (RT: 8.0028)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(20:0)'] (RT: 17.020466666666668)
# Comparing ON lipid FA(18:1)_<>_n-10 (RT: 11.528133333333335) with OFF lipids ['FA(22:0)'] (RT: 19.998933333333333)
# No match found for ON lipid FA(18:1)_<>_n-10 with Adjusted RT 11.528133333333335
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(6:2)'] (RT: 5.475116666666667)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(6:2)'] (RT: 27.889133333333334)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(6:3)'] (RT: 30.584000000000003)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(7:2)'] (RT: 4.2381166666666665)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(7:2)'] (RT: 4.3807833333333335)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(7:2)'] (RT: 4.58685)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(7:2)'] (RT: 4.697816666666667)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(7:2)'] (RT: 4.792916666666667)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(7:2)'] (RT: 4.903883333333334)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(7:2)'] (RT: 5.014833333333334)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(7:2)'] (RT: 5.4745333333333335)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(7:2)'] (RT: 5.6964500000000005)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(7:2)'] (RT: 5.9183666666666666)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(7:2)'] (RT: 7.994916666666667)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(7:2)'] (RT: 8.597266666666668)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(7:2)'] (RT: 9.104533333333334)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(9:0)'] (RT: 4.426666666666667)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(9:0)'] (RT: 10.402683333333334)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(9:3)'] (RT: 30.581983333333334)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(10:5)'] (RT: 30.75586666666667)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(d2-16:0)'] (RT: 10.5243)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(16:0)'] (RT: 10.508566666666667)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(18:0)'] (RT: 11.283683333333334)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(18:0)'] (RT: 11.679983333333334)
# Comparing ON lipid FA(18:1)_<>_n-2 (RT: 11.664866666666667) with OFF lipids ['FA(18:0)'] (RT: 11.822650000000001)
# ...
# Comparing ON lipid FA(18:3)_<BB>_n-3 (RT: 8.020133333333334) with OFF lipids ['FA(18:2)'] (RT: 9.730500000000001)
# Comparing ON lipid FA(18:3)_<BB>_n-3 (RT: 8.020133333333334) with OFF lipids ['FA(18:2)'] (RT: 9.952416666666668)
# Comparing ON lipid FA(18:3)_<BB>_n-3 (RT: 8.020133333333334) with OFF lipids ['FA(18:2)'] (RT: 10.031683333333334)
# Comparing ON lipid FA(18:3)_<BB>_n-3 (RT: 8.020133333333334) with OFF lipids ['FA(18:2)'] (RT: 10.285300000000001)
# Comparing ON lipid FA(18:3)_<BB>_n-3 (RT: 8.020133333333334) with OFF lipids ['FA(18:3)'] (RT: 8.0028)
# Comparing ON lipid FA(18:3)_<BB>_n-3 (RT: 8.020133333333334) with OFF lipids ['FA(20:0)'] (RT: 17.020466666666668)
# Comparing ON lipid FA(18:3)_<BB>_n-3 (RT: 8.020133333333334) with OFF lipids ['FA(22:0)'] (RT: 19.998933333333333)
# No match found for ON lipid FA(18:3)_<BB>_n-3 with Adjusted RT 8.020133333333334
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(6:2)'] (RT: 5.475116666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(6:2)'] (RT: 27.889133333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(6:3)'] (RT: 30.584000000000003)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(7:2)'] (RT: 4.2381166666666665)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(7:2)'] (RT: 4.3807833333333335)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(7:2)'] (RT: 4.58685)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(7:2)'] (RT: 4.697816666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(7:2)'] (RT: 4.792916666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(7:2)'] (RT: 4.903883333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(7:2)'] (RT: 5.014833333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(7:2)'] (RT: 5.4745333333333335)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(7:2)'] (RT: 5.6964500000000005)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(7:2)'] (RT: 5.9183666666666666)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(7:2)'] (RT: 7.994916666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(7:2)'] (RT: 8.597266666666668)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(7:2)'] (RT: 9.104533333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(9:0)'] (RT: 4.426666666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(9:0)'] (RT: 10.402683333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(9:3)'] (RT: 30.581983333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(10:5)'] (RT: 30.75586666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(d2-16:0)'] (RT: 10.5243)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(16:0)'] (RT: 10.508566666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:0)'] (RT: 11.283683333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:0)'] (RT: 11.679983333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:0)'] (RT: 11.822650000000001)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:0)'] (RT: 13.693133333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:1)'] (RT: 9.38165)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:1)'] (RT: 11.283816666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:1)'] (RT: 11.664250000000001)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:1)'] (RT: 12.012983333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:1)'] (RT: 12.18735)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:1)'] (RT: 12.409283333333335)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:1)'] (RT: 12.5995)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:1)'] (RT: 12.71045)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:1)'] (RT: 12.805566666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:1)'] (RT: 12.979933333333333)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:1)'] (RT: 13.106733333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:2)'] (RT: 7.986816666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:2)'] (RT: 9.381766666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:2)'] (RT: 9.730500000000001)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:2)'] (RT: 9.952416666666668)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:2)'] (RT: 10.031683333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:2)'] (RT: 10.285300000000001)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(18:3)'] (RT: 8.0028)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(20:0)'] (RT: 17.020466666666668)
# Comparing ON lipid FA(18:3)_<FF>_n-5 (RT: 7.862850000000001) with OFF lipids ['FA(22:0)'] (RT: 19.998933333333333)
# No match found for ON lipid FA(18:3)_<FF>_n-5 with Adjusted RT 7.862850000000001
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(6:2)'] (RT: 5.475116666666667)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(6:2)'] (RT: 27.889133333333334)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(6:3)'] (RT: 30.584000000000003)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(7:2)'] (RT: 4.2381166666666665)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(7:2)'] (RT: 4.3807833333333335)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(7:2)'] (RT: 4.58685)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(7:2)'] (RT: 4.697816666666667)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(7:2)'] (RT: 4.792916666666667)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(7:2)'] (RT: 4.903883333333334)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(7:2)'] (RT: 5.014833333333334)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(7:2)'] (RT: 5.4745333333333335)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(7:2)'] (RT: 5.6964500000000005)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(7:2)'] (RT: 5.9183666666666666)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(7:2)'] (RT: 7.994916666666667)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(7:2)'] (RT: 8.597266666666668)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(7:2)'] (RT: 9.104533333333334)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(9:0)'] (RT: 4.426666666666667)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(9:0)'] (RT: 10.402683333333334)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(9:3)'] (RT: 30.581983333333334)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(10:5)'] (RT: 30.75586666666667)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(d2-16:0)'] (RT: 10.5243)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(16:0)'] (RT: 10.508566666666667)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:0)'] (RT: 11.283683333333334)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:0)'] (RT: 11.679983333333334)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:0)'] (RT: 11.822650000000001)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:0)'] (RT: 13.693133333333334)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:1)'] (RT: 9.38165)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:1)'] (RT: 11.283816666666667)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:1)'] (RT: 11.664250000000001)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:1)'] (RT: 12.012983333333334)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:1)'] (RT: 12.18735)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:1)'] (RT: 12.409283333333335)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:1)'] (RT: 12.5995)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:1)'] (RT: 12.71045)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:1)'] (RT: 12.805566666666667)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:1)'] (RT: 12.979933333333333)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:1)'] (RT: 13.106733333333334)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:2)'] (RT: 7.986816666666667)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:2)'] (RT: 9.381766666666667)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:2)'] (RT: 9.730500000000001)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:2)'] (RT: 9.952416666666668)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:2)'] (RT: 10.031683333333334)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:2)'] (RT: 10.285300000000001)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(18:3)'] (RT: 8.0028)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(20:0)'] (RT: 17.020466666666668)
# Comparing ON lipid FA(18:3)_<BF>_n-6 (RT: 8.0222) with OFF lipids ['FA(22:0)'] (RT: 19.998933333333333)
# No match found for ON lipid FA(18:3)_<BF>_n-6 with Adjusted RT 8.0222
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(6:2)'] (RT: 5.475116666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(6:2)'] (RT: 27.889133333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(6:3)'] (RT: 30.584000000000003)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(7:2)'] (RT: 4.2381166666666665)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(7:2)'] (RT: 4.3807833333333335)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(7:2)'] (RT: 4.58685)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(7:2)'] (RT: 4.697816666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(7:2)'] (RT: 4.792916666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(7:2)'] (RT: 4.903883333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(7:2)'] (RT: 5.014833333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(7:2)'] (RT: 5.4745333333333335)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(7:2)'] (RT: 5.6964500000000005)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(7:2)'] (RT: 5.9183666666666666)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(7:2)'] (RT: 7.994916666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(7:2)'] (RT: 8.597266666666668)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(7:2)'] (RT: 9.104533333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(9:0)'] (RT: 4.426666666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(9:0)'] (RT: 10.402683333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(9:3)'] (RT: 30.581983333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(10:5)'] (RT: 30.75586666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(d2-16:0)'] (RT: 10.5243)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(16:0)'] (RT: 10.508566666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:0)'] (RT: 11.283683333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:0)'] (RT: 11.679983333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:0)'] (RT: 11.822650000000001)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:0)'] (RT: 13.693133333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:1)'] (RT: 9.38165)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:1)'] (RT: 11.283816666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:1)'] (RT: 11.664250000000001)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:1)'] (RT: 12.012983333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:1)'] (RT: 12.18735)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:1)'] (RT: 12.409283333333335)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:1)'] (RT: 12.5995)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:1)'] (RT: 12.71045)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:1)'] (RT: 12.805566666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:1)'] (RT: 12.979933333333333)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:1)'] (RT: 13.106733333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:2)'] (RT: 7.986816666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:2)'] (RT: 9.381766666666667)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:2)'] (RT: 9.730500000000001)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:2)'] (RT: 9.952416666666668)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:2)'] (RT: 10.031683333333334)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:2)'] (RT: 10.285300000000001)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(18:3)'] (RT: 8.0028)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(20:0)'] (RT: 17.020466666666668)
# Comparing ON lipid FA(18:3)_<FF>_n-9 (RT: 8.02425) with OFF lipids ['FA(22:0)'] (RT: 19.998933333333333)
# No match found for ON lipid FA(18:3)_<FF>_n-9 with Adjusted RT 8.02425
# Processed files: CisTrans_isomer_filtered.parquet and df_analysis_5_CisTrans_OFF.parquet
# Saved matched lipids to Projects/CT/not_possible/matched_CisTrans.csv
# Saved unmatched lipids to Projects/CT/not_possible/unmatched_CisTrans.csv

# %% [markdown]
# # 6 Not possible unmatched

# %%
NP_unmatched = pd.read_csv('Projects/CT/not_possible/unmatched_CisTrans.csv')
NP_unmatched
# Out:
#                 Lipid  Retention_Time  OzESI_Intensity  group_by_ion  \
# 0    FA(18:1)_<>_n-4        11.317717            885.0            35
# 1    FA(18:1)_<>_n-5        11.255050           1352.0            32
# 2    FA(18:1)_<>_n-6        11.255767           2105.0            29
# 3    FA(18:1)_<>_n-7        11.256500           1450.0            26
# 4    FA(18:1)_<>_n-8        11.273067           3767.0            23
# ..                ...             ...              ...           ...
# 56  FA(18:2)_<F>_n-9         9.641100            516.0            20
# 57  FA(18:3)_<BB>_n-3        8.020133           4849.0            36
# 58  FA(18:3)_<FF>_n-5        7.862850            673.0            32
# 59  FA(18:3)_<BF>_n-6        8.022200           5203.0            28
# 60  FA(18:3)_<FF>_n-9        8.024250           6440.0            20
#
#     group_by_lipid                            Sample_ID      Transition  \
# 0                9  01162025_CisTransMix_AMP_OzoneOn_01  409.3 -> 183.0
# 1               10  01162025_CisTransMix_AMP_OzoneOn_01  395.3 -> 183.0
# 2               11  01162025_CisTransMix_AMP_OzoneOn_01  381.3 -> 183.0
# 3               12  01162025_CisTransMix_AMP_OzoneOn_01  367.3 -> 183.0
# 4               13  01162025_CisTransMix_AMP_OzoneOn_01  353.3 -> 183.0
# ..             ...                                  ...             ...
# 56              43  01162025_CisTransMix_AMP_OzoneOn_01  339.3 -> 183.0
# 57              50  01162025_CisTransMix_AMP_OzoneOn_01  419.3 -> 183.0
# 58              80  01162025_CisTransMix_AMP_OzoneOn_01  395.3 -> 183.0
# 59              67  01162025_CisTransMix_AMP_OzoneOn_01  379.3 -> 183.0
# 60              84  01162025_CisTransMix_AMP_OzoneOn_01  339.3 -> 183.0
#
#       Sample  Parent_Ion  Product_Ion  ... Genotype Cage Mouse  \
# 0   CisTrans       409.3        183.0  ...      NaN  NaN   NaN
# 1   CisTrans       395.3        183.0  ...      NaN  NaN   NaN
# 2   CisTrans       381.3        183.0  ...      NaN  NaN   NaN
# 3   CisTrans       367.3        183.0  ...      NaN  NaN   NaN
# 4   CisTrans       353.3        183.0  ...      NaN  NaN   NaN
# ..       ...         ...          ...  ...      ...  ...   ...
# 56  CisTrans       339.3        183.0  ...      NaN  NaN   NaN
# 57  CisTrans       419.3        183.0  ...      NaN  NaN   NaN
# 58  CisTrans       395.3        183.0  ...      NaN  NaN   NaN
# 59  CisTrans       379.3        183.0  ...      NaN  NaN   NaN
# 60  CisTrans       339.3        183.0  ...      NaN  NaN   NaN
#
#     Normalized_Peak_Area  n_value  n_position  OzOFF_Isomer  \
# 0               0.289043        4         4.0           cis
# 1               0.652568        5         5.0           cis
# 2               1.095198        6         6.0           cis
# 3               0.724706        7         7.0           cis
# 4               1.144526        8         8.0           cis
# ..                   ...      ...         ...           ...
# 56              0.126673        9         9.0           NaN
# 57              1.588892        3         3.0           NaN
# 58              0.305910        5         5.0           NaN
# 59              1.132795        6         6.0           NaN
# 60              1.991653        9         9.0           NaN
#
#     Matched_Lipid_OFF Intensity_OFF  Retention_Time_OFF
# 0                 NaN           NaN                 NaN
# 1                 NaN           NaN                 NaN
# 2                 NaN           NaN                 NaN
# 3                 NaN           NaN                 NaN
# 4                 NaN           NaN                 NaN
# ..                ...           ...                 ...
# 56                NaN           NaN                 NaN
# 57                NaN           NaN                 NaN
# 58                NaN           NaN                 NaN
# 59                NaN           NaN                 NaN
# 60                NaN           NaN                 NaN
#
# [61 rows x 41 columns]

# %% [markdown]
# # 6 Not possible Matched

# %%
NP_matched = pd.read_csv('Projects/CT/not_possible/matched_CisTrans.csv')
NP_matched
# Out:
# Empty DataFrame
# Columns: [Lipid, Retention_Time, OzESI_Intensity, group_by_ion, group_by_lipid, Sample_ID, Transition, Sample, Parent_Ion, Product_Ion, Species, Class, Possible_Lipids, Peak_Height, Prominence, FWHM, Peak_Width, Peak_Area, Filter_Column, STD_RT_ON, STD_RT_OFF, STD_RT_Dif, STD_Peak_Intensity, STD_Peak_Area, Adjusted_RT, Slope_Left, Slope_Right, Asymmetry_Factor, Baseline_Drift, Shoulder_Count, Biology, Genotype, Cage, Mouse, Normalized_Peak_Area, n_value, n_position, OzOFF_Isomer, Matched_Lipid_OFF, Intensity_OFF, Retention_Time_OFF]
# Index: []
#
# [0 rows x 41 columns]

# %% [markdown]
# # 7 - Combine Double Bonds

# %%
import pandas as pd
import numpy as np
import itertools

def n_value_combine_updated(df, retention_time_threshold=0.2):
    """
    Combines lipid n-values based on specified rules:
    - Combines n-values with the same Retention_Time within the threshold.
    - Groups n-values to meet the expected positions of FA(x:y).
    - Adds a 'Copy' column for each combination if necessary.
    - Includes 'Parent_Ion' and 'group_by_lipid' columns in the output, aggregating all relevant values separated by '| '.
    - Rounds Retention_Time to 1 decimal place in the output.

    Parameters:
    - df (DataFrame): Input DataFrame containing 'Lipid', 'Parent_Ion', 'group_by_lipid', and 'Retention_Time' columns.
    - retention_time_threshold (float): Maximum difference in retention time to consider lipids similar.

    Returns:
    - DataFrame: New DataFrame with combined lipid values, rounded Retention Times, 'Copy' column (if applicable),
                 'Parent_Ion' and 'group_by_lipid' columns with values separated by '| ', and 'total_n_values' column indicating the count of n_values per species.
    """
    required_columns = ['Parent_Ion', 'group_by_lipid', 'Lipid', 'Retention_Time']
    missing_columns = [col for col in required_columns if col not in df.columns]
    if missing_columns:
        raise ValueError(f"Input DataFrame is missing required columns: {', '.join(missing_columns)}")

    df['Parent_Ion'] = df['Parent_Ion'].astype(str)
    df['group_by_lipid'] = df['group_by_lipid'].astype(str)

    lipid_pattern = r'(FA\(\d+:\d+\))_<(.*?)>_n-(\d+)'
    extracted = df['Lipid'].str.extract(lipid_pattern, expand=True)
    if extracted.isnull().values.any():
        raise ValueError("Some entries in 'Lipid' column do not match the expected pattern 'FA(x:y)_<positions>_n-z'.")
    df[['FA', 'positions', 'n_value']] = extracted
    df['n_value'] = df['n_value'].astype(int)

    df['Retention_Time'] = pd.to_numeric(df['Retention_Time'], errors='coerce')
    if df['Retention_Time'].isnull().any():
        raise ValueError("Some 'Retention_Time' values could not be converted to float.")
    df['Retention_Time'] = df['Retention_Time'].round(1)

    total_positions_pattern = r'FA\(\d+:(\d+)\)'
    extracted_positions = df['FA'].str.extract(total_positions_pattern)
    if extracted_positions.isnull().values.any():
        raise ValueError("Some entries in 'FA' column do not match the expected pattern 'FA(x:y)'.")
    df['total_positions'] = extracted_positions[0].astype(int)

    df = df.sort_values(by=['FA', 'Retention_Time', 'n_value']).reset_index(drop=True)

    combined_results = []
    separator = '| '

    for fa, fa_group in df.groupby('FA'):
        expected_positions = fa_group['total_positions'].iloc[0]

        # Cluster by Retention_Time within threshold
        fa_group = fa_group.sort_values(by='Retention_Time').reset_index(drop=True)
        while not fa_group.empty:
            seed = fa_group.iloc[0]
            seed_retention_time = seed['Retention_Time']

            mask = abs(fa_group['Retention_Time'] - seed_retention_time) <= retention_time_threshold
            cluster = fa_group[mask]
            fa_group = fa_group[~mask]

            n_values = sorted(set(cluster['n_value'].tolist()))
            n_values_times = dict(zip(cluster['n_value'], cluster['Retention_Time']))
            n_values_parent_ions = dict(zip(cluster['n_value'], cluster['Parent_Ion']))
            n_values_group_by_lipid = dict(zip(cluster['n_value'], cluster['group_by_lipid']))

            num_n_values = len(n_values)

            if num_n_values > expected_positions:
                combinations_list = list(itertools.combinations(n_values, expected_positions))
                for idx, comb in enumerate(combinations_list, 1):
                    n_values_str = ' '.join([f"n-{n}" for n in comb])
                    retention_times = [str(n_values_times[n]) for n in comb]
                    retention_times_str = ','.join(retention_times)
                    parent_ions = [n_values_parent_ions[n] for n in comb]
                    parent_ions_str = separator.join(parent_ions)
                    group_by_lipids = [n_values_group_by_lipid[n] for n in comb]
                    group_by_lipids_str = separator.join(group_by_lipids)

                    combined_lipid = f"{fa} {n_values_str}"

                    combined_results.append({
                        'Lipid': combined_lipid,
                        'Parent_Ion': parent_ions_str,
                        'group_by_lipid': group_by_lipids_str,
                        'Retention_Time': retention_times_str,
                        'Copy': f"Copy{idx}",
                        'total_n_values': num_n_values
                    })
            else:
                n_values_str = ' '.join([f"n-{n}" for n in n_values])
                combined_lipid = f"{fa} {n_values_str}".strip()
                retention_times = [str(n_values_times[n]) for n in n_values]
                retention_times_str = ','.join(retention_times)
                parent_ions = [n_values_parent_ions[n] for n in n_values]
                parent_ions_str = separator.join(parent_ions)
                group_by_lipids = [n_values_group_by_lipid[n] for n in n_values]
                group_by_lipids_str = separator.join(group_by_lipids)

                combined_results.append({
                    'Lipid': combined_lipid,
                    'Parent_Ion': parent_ions_str,
                    'group_by_lipid': group_by_lipids_str,
                    'Retention_Time': retention_times_str,
                    'Copy': np.nan,
                    'total_n_values': num_n_values
                })

    df_combined_n_values = pd.DataFrame(combined_results)
    df_combined_n_values = df_combined_n_values[['Lipid', 'Parent_Ion', 'group_by_lipid', 'Retention_Time', 'Copy', 'total_n_values']]
    df_combined_n_values['Copy'] = df_combined_n_values['Copy'].replace('', np.nan)

    return df_combined_n_values


# Apply the function
df_combined_n_values = n_value_combine_updated(NP_unmatched)

# Display the first 60 rows
df_combined_n_values.head(60)
# Out:
#                    Lipid           Parent_Ion group_by_lipid Retention_Time  \
# 0           FA(18:1) n-4                409.3              9           11.3
# 1           FA(18:1) n-5                395.3             10           11.3
# 2           FA(18:1) n-6                381.3             11           11.3
# 3           FA(18:1) n-7                367.3             12           11.3
# 4           FA(18:1) n-8                353.3             13           11.3
# 5           FA(18:1) n-9                339.3             14           11.3
# 6          FA(18:1) n-10                325.2              0           11.5
# 7           FA(18:1) n-2                437.4              7           11.7
# 8           FA(18:1) n-3                423.3              8           11.7
# 9           FA(18:1) n-4                409.3              9           11.7
# 10          FA(18:1) n-5                395.3             10           11.7
# 11          FA(18:1) n-6                381.3             11           11.7
# 12          FA(18:1) n-7                367.3             12           11.7
# 13          FA(18:1) n-8                353.3             13           11.7
# 14          FA(18:1) n-9                339.3             14           11.7
# 15         FA(18:1) n-11                311.3              1           11.6
# 16          FA(18:1) n-5                395.3             10           11.8
# 17          FA(18:1) n-8                353.3             13           12.0
# 18          FA(18:1) n-9                339.3             14           12.0
# 19         FA(18:1) n-10                325.2              0           11.9
# 20         FA(18:1) n-12                297.2              2           11.8
# 21          FA(18:1) n-9                339.3             14           12.1
# 22         FA(18:1) n-10                325.2              0           12.1
# 23         FA(18:1) n-11                311.3              1           12.2
# 24         FA(18:1) n-12                297.2              2           12.2
# 25         FA(18:1) n-13                283.2              3           12.4
# 26      FA(18:2) n-6 n-9         379.3| 339.3         25| 43        9.6,9.6
# 27  FA(18:3) n-3 n-5 n-6  419.3| 395.3| 379.3     50| 80| 67    8.0,7.9,8.0
# 28  FA(18:3) n-3 n-5 n-9  419.3| 395.3| 339.3     50| 80| 84    8.0,7.9,8.0
# 29  FA(18:3) n-3 n-6 n-9  419.3| 379.3| 339.3     50| 67| 84    8.0,8.0,8.0
# 30  FA(18:3) n-5 n-6 n-9  395.3| 379.3| 339.3     80| 67| 84    7.9,8.0,8.0
#
#      Copy  total_n_values
# 0   Copy1               7
# 1   Copy2               7
# 2   Copy3               7
# 3   Copy4               7
# 4   Copy5               7
# 5   Copy6               7
# 6   Copy7               7
# 7   Copy1               9
# 8   Copy2               9
# 9   Copy3               9
# 10  Copy4               9
# 11  Copy5               9
# 12  Copy6               9
# 13  Copy7               9
# 14  Copy8               9
# 15  Copy9               9
# 16  Copy1               5
# 17  Copy2               5
# 18  Copy3               5
# 19  Copy4               5
# 20  Copy5               5
# 21  Copy1               4
# 22  Copy2               4
# 23  Copy3               4
# 24  Copy4               4
# 25    NaN               1
# 26    NaN               2
# 27  Copy1               4
# 28  Copy2               4
# 29  Copy3               4
# 30  Copy4               4
