# %% [markdown]
# # NIST HUMAN PLASMA OFF

# %%
import pandas as pd

# %%
# !sbatch core/backend/NIST/OFF/mzml_parser_1_CT_OFF.sh
# Out:
# Submitted batch job 22362214

# %%
df_mzml = pd.read_parquet('Projects/NIST/mzml_parsed/OFF/mzml_parser_1_OFF_intensity.parquet')
# new df with just Rentention_Time 10 to 13
df_rt = df_mzml[(df_mzml['Retention_Time'] >= 10.8) & (df_mzml['Retention_Time'] <= 11.4)]
# df_rt.to_parquet('Projects/NIST/mzml_parsed/OFF/mzml_parser_1_OFF_intensity_RT_10_13.parquet')
df_mzml
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            227.1        183.0        3.014900        42.220001
# 1            227.1        183.0        3.030717        42.160004
# 2            227.1        183.0        3.046567        42.120003
# 3            227.1        183.0        3.062417        42.020004
# 4            227.1        183.0        3.078267        41.880001
# ...            ...          ...             ...              ...
# 856213       533.5        183.0       31.928683        41.000004
# 856214       533.5        183.0       31.944533        41.080002
# 856215       533.5        183.0       31.960383        41.000004
# 856216       533.5        183.0       31.976233        40.740002
# 856217       533.5        183.0       31.992083        40.640003
#
#                                 Sample_ID      Transition
# 0          02032025_n3Plasma_AMP_ozoneoff  227.1 -> 183.0
# 1          02032025_n3Plasma_AMP_ozoneoff  227.1 -> 183.0
# 2          02032025_n3Plasma_AMP_ozoneoff  227.1 -> 183.0
# 3          02032025_n3Plasma_AMP_ozoneoff  227.1 -> 183.0
# 4          02032025_n3Plasma_AMP_ozoneoff  227.1 -> 183.0
# ...                                   ...             ...
# 856213  02032025_BlankPlasma_AMP_ozoneoff  533.5 -> 183.0
# 856214  02032025_BlankPlasma_AMP_ozoneoff  533.5 -> 183.0
# 856215  02032025_BlankPlasma_AMP_ozoneoff  533.5 -> 183.0
# 856216  02032025_BlankPlasma_AMP_ozoneoff  533.5 -> 183.0
# 856217  02032025_BlankPlasma_AMP_ozoneoff  533.5 -> 183.0
#
# [856218 rows x 6 columns]

# %%
df_rt
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 492          227.1        183.0       10.813733        41.520004
# 493          227.1        183.0       10.829583        41.600002
# 494          227.1        183.0       10.845433        41.380001
# 495          227.1        183.0       10.861283        41.640003
# 496          227.1        183.0       10.877133        41.760002
# ...            ...          ...             ...              ...
# 854913       533.5        183.0       11.321917        41.400002
# 854914       533.5        183.0       11.337767        41.360004
# 854915       533.5        183.0       11.353617        41.300003
# 854916       533.5        183.0       11.369467        41.320004
# 854917       533.5        183.0       11.385333        41.360004
#
#                                 Sample_ID      Transition
# 492        02032025_n3Plasma_AMP_ozoneoff  227.1 -> 183.0
# 493        02032025_n3Plasma_AMP_ozoneoff  227.1 -> 183.0
# 494        02032025_n3Plasma_AMP_ozoneoff  227.1 -> 183.0
# 495        02032025_n3Plasma_AMP_ozoneoff  227.1 -> 183.0
# 496        02032025_n3Plasma_AMP_ozoneoff  227.1 -> 183.0
# ...                                   ...             ...
# 854913  02032025_BlankPlasma_AMP_ozoneoff  533.5 -> 183.0
# 854914  02032025_BlankPlasma_AMP_ozoneoff  533.5 -> 183.0
# 854915  02032025_BlankPlasma_AMP_ozoneoff  533.5 -> 183.0
# 854916  02032025_BlankPlasma_AMP_ozoneoff  533.5 -> 183.0
# 854917  02032025_BlankPlasma_AMP_ozoneoff  533.5 -> 183.0
#
# [17764 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

# Plot the filtered data
plt.figure(figsize=(8, 6))
plt.scatter(df_mzml['Retention_Time'], df_mzml['OzESI_Intensity'], color='blue', label='OzESI Intensity')

# Add labels and title
plt.xlabel('Retention Time')
plt.ylabel('OzESI Intensity')
plt.title('Retention Time vs OzESI Intensity')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
# !sbatch core/backend/NIST/OFF/sample_2_NIST_OFF.sh
# Out:
# Submitted batch job 22362210

# %%
df_sample = pd.read_parquet('Projects/NIST/samples/OFF/df_sample_2_NIST_n1_ON.parquet')
df_sample
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            227.1        183.0        3.014900        41.180004
# 1            227.1        183.0        3.030717        40.860004
# 2            227.1        183.0        3.046567        40.800003
# 3            227.1        183.0        3.062417        40.500004
# 4            227.1        183.0        3.078267        40.720001
# ...            ...          ...             ...              ...
# 214050       533.5        183.0       31.928683        40.820004
# 214051       533.5        183.0       31.944533        40.880001
# 214052       533.5        183.0       31.960383        41.220001
# 214053       533.5        183.0       31.976233        42.200005
# 214054       533.5        183.0       31.992083        41.460003
#
#                              Sample_ID      Transition   Sample   STD  \
# 0       02032025_n1Plasma_AMP_ozoneoff  227.1 -> 183.0  NIST_n1  NIST
# 1       02032025_n1Plasma_AMP_ozoneoff  227.1 -> 183.0  NIST_n1  NIST
# 2       02032025_n1Plasma_AMP_ozoneoff  227.1 -> 183.0  NIST_n1  NIST
# 3       02032025_n1Plasma_AMP_ozoneoff  227.1 -> 183.0  NIST_n1  NIST
# 4       02032025_n1Plasma_AMP_ozoneoff  227.1 -> 183.0  NIST_n1  NIST
# ...                                ...             ...      ...   ...
# 214050  02032025_n1Plasma_AMP_ozoneoff  533.5 -> 183.0  NIST_n1  NIST
# 214051  02032025_n1Plasma_AMP_ozoneoff  533.5 -> 183.0  NIST_n1  NIST
# 214052  02032025_n1Plasma_AMP_ozoneoff  533.5 -> 183.0  NIST_n1  NIST
# 214053  02032025_n1Plasma_AMP_ozoneoff  533.5 -> 183.0  NIST_n1  NIST
# 214054  02032025_n1Plasma_AMP_ozoneoff  533.5 -> 183.0  NIST_n1  NIST
#
#        Replicate  STD_RT_OFF  STD_Peak_Intensity  STD_Peak_Area
# 0             n1     10.9163        194676.15625   41300.839204
# 1             n1     10.9163        194676.15625   41300.839204
# 2             n1     10.9163        194676.15625   41300.839204
# 3             n1     10.9163        194676.15625   41300.839204
# 4             n1     10.9163        194676.15625   41300.839204
# ...          ...         ...                 ...            ...
# 214050        n1     10.9163        194676.15625   41300.839204
# 214051        n1     10.9163        194676.15625   41300.839204
# 214052        n1     10.9163        194676.15625   41300.839204
# 214053        n1     10.9163        194676.15625   41300.839204
# 214054        n1     10.9163        194676.15625   41300.839204
#
# [214055 rows x 12 columns]

# %% [markdown]
# # Match

# %%
# !sbatch core/backend/NIST/OFF/match_3_CT_OFF.sh
# Out:
# Submitted batch job 22362217

# %%
df_match = pd.read_parquet('Projects/NIST/match/OFF/df_match_3_NIST_n1.parquet')
df_match
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            227.1        183.0        3.014900             41.0
# 1            227.1        183.0        3.030717             41.0
# 2            227.1        183.0        3.046567             41.0
# 3            227.1        183.0        3.062417             41.0
# 4            227.1        183.0        3.078267             41.0
# ...            ...          ...             ...              ...
# 214050       533.5        183.0       31.928683             41.0
# 214051       533.5        183.0       31.944533             41.0
# 214052       533.5        183.0       31.960383             41.0
# 214053       533.5        183.0       31.976233             42.0
# 214054       533.5        183.0       31.992083             41.0
#
#                              Sample_ID      Transition   Sample   STD  \
# 0       02032025_n1Plasma_AMP_ozoneoff  227.1 -> 183.0  NIST_n1  NIST
# 1       02032025_n1Plasma_AMP_ozoneoff  227.1 -> 183.0  NIST_n1  NIST
# 2       02032025_n1Plasma_AMP_ozoneoff  227.1 -> 183.0  NIST_n1  NIST
# 3       02032025_n1Plasma_AMP_ozoneoff  227.1 -> 183.0  NIST_n1  NIST
# 4       02032025_n1Plasma_AMP_ozoneoff  227.1 -> 183.0  NIST_n1  NIST
# ...                                ...             ...      ...   ...
# 214050  02032025_n1Plasma_AMP_ozoneoff  533.5 -> 183.0  NIST_n1  NIST
# 214051  02032025_n1Plasma_AMP_ozoneoff  533.5 -> 183.0  NIST_n1  NIST
# 214052  02032025_n1Plasma_AMP_ozoneoff  533.5 -> 183.0  NIST_n1  NIST
# 214053  02032025_n1Plasma_AMP_ozoneoff  533.5 -> 183.0  NIST_n1  NIST
# 214054  02032025_n1Plasma_AMP_ozoneoff  533.5 -> 183.0  NIST_n1  NIST
#
#        Replicate  STD_RT_OFF  STD_Peak_Intensity  STD_Peak_Area     Lipid  \
# 0             n1     10.9163        194676.15625   41300.839204
# 1             n1     10.9163        194676.15625   41300.839204
# 2             n1     10.9163        194676.15625   41300.839204
# 3             n1     10.9163        194676.15625   41300.839204
# 4             n1     10.9163        194676.15625   41300.839204
# ...          ...         ...                 ...            ...       ...
# 214050        n1     10.9163        194676.15625   41300.839204  FA(24:1)
# 214051        n1     10.9163        194676.15625   41300.839204  FA(24:1)
# 214052        n1     10.9163        194676.15625   41300.839204  FA(24:1)
# 214053        n1     10.9163        194676.15625   41300.839204  FA(24:1)
# 214054        n1     10.9163        194676.15625   41300.839204  FA(24:1)
#
#        Class
# 0
# 1
# 2
# 3
# 4
# ...      ...
# 214050    FA
# 214051    FA
# 214052    FA
# 214053    FA
# 214054    FA
#
# [214055 rows x 14 columns]

# %% [markdown]
# # Group

# %%
# !sbatch core/backend/NIST/OFF/group_4_CT_OFF.sh
# Out:
# Submitted batch job 22362222

# %%
df_group = pd.read_parquet('Projects/NIST/group/OFF/df_group_4_NIST_n1_OFF.parquet')
df_group
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            255.2        183.0        3.014550             41.0
# 1            253.2        183.0        3.014667             40.0
# 2            241.1        183.0        3.014783             40.0
# 3            227.1        183.0        3.014900             41.0
# 4            255.2        183.0        3.030367             41.0
# ...            ...          ...             ...              ...
# 214050       425.4        183.0       31.935183             42.0
# 214051       425.4        183.0       31.951033             41.0
# 214052       425.4        183.0       31.966900             41.0
# 214053       425.4        183.0       31.982750             41.0
# 214054       425.4        183.0       31.998600             42.0
#
#                              Sample_ID      Transition   Sample   STD  \
# 0       02032025_n1Plasma_AMP_ozoneoff  255.2 -> 183.0  NIST_n1  NIST
# 1       02032025_n1Plasma_AMP_ozoneoff  253.2 -> 183.0  NIST_n1  NIST
# 2       02032025_n1Plasma_AMP_ozoneoff  241.1 -> 183.0  NIST_n1  NIST
# 3       02032025_n1Plasma_AMP_ozoneoff  227.1 -> 183.0  NIST_n1  NIST
# 4       02032025_n1Plasma_AMP_ozoneoff  255.2 -> 183.0  NIST_n1  NIST
# ...                                ...             ...      ...   ...
# 214050  02032025_n1Plasma_AMP_ozoneoff  425.4 -> 183.0  NIST_n1  NIST
# 214051  02032025_n1Plasma_AMP_ozoneoff  425.4 -> 183.0  NIST_n1  NIST
# 214052  02032025_n1Plasma_AMP_ozoneoff  425.4 -> 183.0  NIST_n1  NIST
# 214053  02032025_n1Plasma_AMP_ozoneoff  425.4 -> 183.0  NIST_n1  NIST
# 214054  02032025_n1Plasma_AMP_ozoneoff  425.4 -> 183.0  NIST_n1  NIST
#
#        Replicate  STD_RT_OFF  ...  STD_Peak_Area        Lipid Class  \
# 0             n1     10.9163  ...   41300.839204
# 1             n1     10.9163  ...   41300.839204
# 2             n1     10.9163  ...   41300.839204
# 3             n1     10.9163  ...   41300.839204
# 4             n1     10.9163  ...   41300.839204
# ...          ...         ...  ...            ...          ...   ...
# 214050        n1     10.9163  ...   41300.839204  FA(d2-16:0)    FA
# 214051        n1     10.9163  ...   41300.839204  FA(d2-16:0)    FA
# 214052        n1     10.9163  ...   41300.839204  FA(d2-16:0)    FA
# 214053        n1     10.9163  ...   41300.839204  FA(d2-16:0)    FA
# 214054        n1     10.9163  ...   41300.839204  FA(d2-16:0)    FA
#
#           Species Biology Genotype Cage Mouse group_by_ion  group_by_lipid
# 0       Unknown_1                                        3               0
# 1       Unknown_1                                        2               0
# 2       Unknown_1                                        1               0
# 3       Unknown_1                                        0               0
# 4       Unknown_1                                        3               0
# ...           ...     ...      ...  ...   ...          ...             ...
# 214050       16:0                                       70             112
# 214051       16:0                                       70             112
# 214052       16:0                                       70             112
# 214053       16:0                                       70             112
# 214054       16:0                                       70             112
#
# [214055 rows x 21 columns]

# %%
unique_lipids = df_group['Lipid'].unique()
print(unique_lipids)
# Out:
# ['' 'FA(10:0)' 'FA(10:1)' 'FA(10:2)' 'FA(10:3)' 'FA(10:4)' 'FA(10:5)'
#  'FA(11:0)' 'FA(11:1)' 'FA(11:2)' 'FA(11:3)' 'FA(11:4)' 'FA(11:5)'
#  'FA(12:0)' 'FA(12:1)' 'FA(12:2)' 'FA(12:3)' 'FA(12:4)' 'FA(12:5)'
#  'FA(13:0)' 'FA(13:1)' 'FA(13:2)' 'FA(13:3)' 'FA(13:4)' 'FA(13:5)'
#  'FA(14:0)' 'FA(14:1)' 'FA(14:2)' 'FA(14:3)' 'FA(14:4)' 'FA(14:5)'
#  'FA(15:0)' 'FA(15:1)' 'FA(15:2)' 'FA(15:3)' 'FA(15:4)' 'FA(15:5)'
#  'FA(16:0)' 'FA(16:1)' 'FA(16:2)' 'FA(16:3)' 'FA(16:4)' 'FA(16:5)'
#  'FA(17:0)' 'FA(17:1)' 'FA(17:2)' 'FA(17:3)' 'FA(17:4)' 'FA(17:5)'
#  'FA(18:0)' 'FA(18:1)' 'FA(18:2)' 'FA(18:3)' 'FA(18:4)' 'FA(18:5)'
#  'FA(19:0)' 'FA(19:1)' 'FA(19:2)' 'FA(19:3)' 'FA(19:4)' 'FA(19:5)'
#  'FA(20:0)' 'FA(20:1)' 'FA(20:2)' 'FA(20:3)' 'FA(20:4)' 'FA(20:5)'
#  'FA(21:0)' 'FA(21:1)' 'FA(21:2)' 'FA(21:3)' 'FA(21:4)' 'FA(21:5)'
#  'FA(22:0)' 'FA(22:1)' 'FA(22:2)' 'FA(22:3)' 'FA(22:4)' 'FA(22:5)'
#  'FA(22:6)' 'FA(23:0)' 'FA(23:1)' 'FA(23:2)' 'FA(23:3)' 'FA(23:4)'
#  'FA(23:5)' 'FA(24:0)' 'FA(24:1)' 'FA(5:0)' 'FA(5:1)' 'FA(5:2)' 'FA(6:0)'
#  'FA(6:1)' 'FA(6:2)' 'FA(6:3)' 'FA(7:0)' 'FA(7:1)' 'FA(7:2)' 'FA(7:3)'
#  'FA(7:4)' 'FA(8:0)' 'FA(8:1)' 'FA(8:2)' 'FA(8:3)' 'FA(8:4)' 'FA(8:5)'
#  'FA(9:0)' 'FA(9:1)' 'FA(9:2)' 'FA(9:3)' 'FA(9:4)' 'FA(9:5)' 'FA(d2-16:0)']

# %%
# print unique columns
unique_columns = df_group.columns
print(unique_columns)
# Out:
# Index(['Parent_Ion', 'Product_Ion', 'Retention_Time', 'OzESI_Intensity',
#        'Sample_ID', 'Transition', 'Sample', 'STD', 'Replicate', 'STD_RT_ON',
#        'STD_Peak_Intensity', 'STD_Peak_Area', 'Lipid', 'Class', 'Species',
#        'Biology', 'Genotype', 'Cage', 'Mouse', 'group_by_ion',
#        'group_by_lipid'],
#       dtype='object')

# %% [markdown]
# # analysis 5

# %%
# !sbatch core/backend/NIST/OFF/analysis_5_CT_OFF.sh
# Out:
# Submitted batch job 22364519

# %%
import pandas as pd
df_analysis = pd.read_parquet('Projects/NIST/analysis/OFF/df_analysis_CT_OFF_NIST_n1.parquet')
df_analysis
# Out:
#         Lipid  Retention_Time  OzESI_Intensity  group_by_ion  group_by_lipid  \
# 0     FA(5:1)        9.814517           1329.0             5              89
# 1     FA(5:1)       11.827633           1207.0             5              89
# 2     FA(6:1)        9.829883           1568.0             9              92
# 3     FA(6:1)        9.940850           1013.0             9              92
# 4     FA(6:1)       11.795450           2385.0             9              92
# ..        ...             ...              ...           ...             ...
# 751  FA(22:6)        9.707767         801549.0           101              79
# 752  FA(22:6)       10.738117          12375.0           101              79
# 753  FA(22:6)       11.134400           1698.0           101              79
# 754  FA(23:2)       13.146267           1335.0           111              82
# 755  FA(23:2)       13.209683           1502.0           111              82
#
#                           Sample_ID      Transition   Sample  Parent_Ion  \
# 0    02032025_n1Plasma_AMP_ozoneoff  267.2 -> 183.0  NIST_n1       267.2
# 1    02032025_n1Plasma_AMP_ozoneoff  267.2 -> 183.0  NIST_n1       267.2
# 2    02032025_n1Plasma_AMP_ozoneoff  281.2 -> 183.0  NIST_n1       281.2
# 3    02032025_n1Plasma_AMP_ozoneoff  281.2 -> 183.0  NIST_n1       281.2
# 4    02032025_n1Plasma_AMP_ozoneoff  281.2 -> 183.0  NIST_n1       281.2
# ..                              ...             ...      ...         ...
# 751  02032025_n1Plasma_AMP_ozoneoff  495.4 -> 183.0  NIST_n1       495.4
# 752  02032025_n1Plasma_AMP_ozoneoff  495.4 -> 183.0  NIST_n1       495.4
# 753  02032025_n1Plasma_AMP_ozoneoff  495.4 -> 183.0  NIST_n1       495.4
# 754  02032025_n1Plasma_AMP_ozoneoff  517.4 -> 183.0  NIST_n1       517.4
# 755  02032025_n1Plasma_AMP_ozoneoff  517.4 -> 183.0  NIST_n1       517.4
#
#      Product_Ion  ...   STD STD_RT_OFF STD_Peak_Intensity  STD_Peak_Area  \
# 0          183.0  ...  NIST    10.9163       194676.15625   41300.839204
# 1          183.0  ...  NIST    10.9163       194676.15625   41300.839204
# 2          183.0  ...  NIST    10.9163       194676.15625   41300.839204
# 3          183.0  ...  NIST    10.9163       194676.15625   41300.839204
# 4          183.0  ...  NIST    10.9163       194676.15625   41300.839204
# ..           ...  ...   ...        ...                ...            ...
# 751        183.0  ...  NIST    10.9163       194676.15625   41300.839204
# 752        183.0  ...  NIST    10.9163       194676.15625   41300.839204
# 753        183.0  ...  NIST    10.9163       194676.15625   41300.839204
# 754        183.0  ...  NIST    10.9163       194676.15625   41300.839204
# 755        183.0  ...  NIST    10.9163       194676.15625   41300.839204
#
#      Peak_Height      FWHM  Peak_Width     Peak_Area   Filter_Column  Isomer
# 0         1329.0  0.063071    0.063417     63.923250  group_by_lipid     cis
# 1         1207.0  0.150753    0.142667    153.420458  group_by_lipid   trans
# 2         1568.0  0.163518    0.158517    180.825533  group_by_lipid     cis
# 3         1013.0  0.048130    0.047550     45.663850  group_by_lipid    None
# 4         2385.0  0.136502    0.126817    232.430092  group_by_lipid   trans
# ..           ...       ...         ...           ...             ...     ...
# 751     801549.0  0.139911    0.142667  87016.341650  group_by_lipid    None
# 752      12375.0  0.031641    0.031700    378.498000  group_by_lipid    None
# 753       1698.0  0.068802    0.063400     89.560425  group_by_lipid    None
# 754       1335.0  0.032434    0.031700     40.045025  group_by_lipid    None
# 755       1502.0  0.160272    0.158517    181.417533  group_by_lipid    None
#
# [756 rows x 22 columns]

# %% [markdown]
# # OFF Possible

# %%
# !sbatch core/backend/NIST/OFF/off_possible_6_NIST.sh
# Out:
# Submitted batch job 22366288

# %% [markdown]
# # off possible

# %%
off_possible_df = pd.read_parquet('Projects/NIST/analysis/OFF/off_possible/df_analysis_CT_OFF_NIST_n1.parquet')
# filter for lipid species 18:1
# off_possible_df = off_possible_df[off_possible_df['Lipid'].str.contains('18:1')]
off_possible_df
# Out:
#        Lipid  Retention_Time  OzESI_Intensity  group_by_ion  group_by_lipid  \
# 0   FA(12:1)       11.807133          11352.0            44              14
# 1   FA(13:1)       11.806400          11007.0            50              20
# 2   FA(16:1)        9.109483         377712.0            68              38
# 3   FA(16:1)        9.363117         345628.0            68              38
# 4   FA(17:1)       10.487700          51288.0            75              44
# 5   FA(17:1)       10.773017          40602.0            75              44
# 6   FA(18:1)       11.802633        6803927.0            81              50
# 7   FA(18:1)       12.294017        2306772.0            81              50
# 8   FA(19:1)       13.989367          14692.0            87              56
# 9   FA(19:1)       14.116183          17208.0            87              56
# 10  FA(20:1)       15.399400          58424.0            93              62
# 11  FA(20:1)       15.827383          37811.0            93              62
#
#                          Sample_ID      Transition   Sample  Parent_Ion  \
# 0   02032025_n1Plasma_AMP_ozoneoff  365.2 -> 183.0  NIST_n1       365.2
# 1   02032025_n1Plasma_AMP_ozoneoff  379.3 -> 183.0  NIST_n1       379.3
# 2   02032025_n1Plasma_AMP_ozoneoff  421.4 -> 183.0  NIST_n1       421.4
# 3   02032025_n1Plasma_AMP_ozoneoff  421.4 -> 183.0  NIST_n1       421.4
# 4   02032025_n1Plasma_AMP_ozoneoff  435.4 -> 183.0  NIST_n1       435.4
# 5   02032025_n1Plasma_AMP_ozoneoff  435.4 -> 183.0  NIST_n1       435.4
# 6   02032025_n1Plasma_AMP_ozoneoff  449.4 -> 183.0  NIST_n1       449.4
# 7   02032025_n1Plasma_AMP_ozoneoff  449.4 -> 183.0  NIST_n1       449.4
# 8   02032025_n1Plasma_AMP_ozoneoff  463.3 -> 183.0  NIST_n1       463.3
# 9   02032025_n1Plasma_AMP_ozoneoff  463.3 -> 183.0  NIST_n1       463.3
# 10  02032025_n1Plasma_AMP_ozoneoff  477.4 -> 183.0  NIST_n1       477.4
# 11  02032025_n1Plasma_AMP_ozoneoff  477.4 -> 183.0  NIST_n1       477.4
#
#     Product_Ion  ...   STD STD_RT_OFF STD_Peak_Intensity  STD_Peak_Area  \
# 0         183.0  ...  NIST    10.9163       194676.15625   41300.839204
# 1         183.0  ...  NIST    10.9163       194676.15625   41300.839204
# 2         183.0  ...  NIST    10.9163       194676.15625   41300.839204
# 3         183.0  ...  NIST    10.9163       194676.15625   41300.839204
# 4         183.0  ...  NIST    10.9163       194676.15625   41300.839204
# 5         183.0  ...  NIST    10.9163       194676.15625   41300.839204
# 6         183.0  ...  NIST    10.9163       194676.15625   41300.839204
# 7         183.0  ...  NIST    10.9163       194676.15625   41300.839204
# 8         183.0  ...  NIST    10.9163       194676.15625   41300.839204
# 9         183.0  ...  NIST    10.9163       194676.15625   41300.839204
# 10        183.0  ...  NIST    10.9163       194676.15625   41300.839204
# 11        183.0  ...  NIST    10.9163       194676.15625   41300.839204
#
#     Peak_Height      FWHM  Peak_Width     Peak_Area   Filter_Column  Isomer
# 0       11352.0  0.303187    0.301183  2.416498e+03  group_by_lipid     cis
# 1       11007.0  0.336664    0.332883  2.916630e+03  group_by_lipid     cis
# 2      377712.0  0.775032    0.776717  2.428561e+05  group_by_lipid     cis
# 3      345628.0  0.057371    0.047567  1.618954e+04  group_by_lipid   trans
# 4       51288.0  0.537292    0.538950  2.063279e+04  group_by_lipid     cis
# 5       40602.0  0.099822    0.110967  4.294068e+03  group_by_lipid   trans
# 6     6803927.0  0.355920    0.348733  1.880467e+06  group_by_lipid     cis
# 7     2306772.0  0.052011    0.047550  1.086590e+05  group_by_lipid   trans
# 8       14692.0  0.082415    0.095117  1.351784e+03  group_by_lipid     cis
# 9       17208.0  0.612050    0.618200  7.978047e+03  group_by_lipid   trans
# 10      58424.0  0.777482    0.776717  3.320831e+04  group_by_lipid     cis
# 11      37811.0  0.044945    0.047550  1.708567e+03  group_by_lipid   trans
#
# [12 rows x 22 columns]

# %% [markdown]
# # Plots

# %%
import matplotlib.pyplot as plt

# Function to plot the chromatogram for a specific group_by_lipid value
def plot_chromatogram(df, group_value):
    group_data = df[df['group_by_lipid'] == group_value]
    
    # Ensure the Retention_Time is sorted
    group_data = group_data.sort_values(by='Retention_Time')
    
    # Extract Lipid, Parent Ion, and Isomer values from the first row of the group
    lipid = group_data['Lipid'].iloc[0] if not group_data.empty else "Unknown Lipid"
    parent_ion = group_data['Parent_Ion'].iloc[0] if not group_data.empty else "Unknown Parent Ion"
    # isomer = group_data['Isomer'].iloc[0] if not group_data.empty else "Unknown Isomer"
    
    plt.figure(figsize=(10, 6))
    plt.plot(group_data['Retention_Time'], group_data['OzESI_Intensity'], label=f'group_by_lipid: {group_value}')
    plt.xlabel('Retention Time')
    plt.ylabel('OzESI Intensity')
    
    # Add Lipid, Parent Ion, and Isomer to the title
    plt.title(f'{group_value} | Lipid: {lipid} | Parent Ion: {parent_ion} ')
    
    plt.legend()
    plt.grid(True)
    plt.show()

# Define the specific group_by_lipid value you are interested in
specific_group_by_lipid_value = 50 # Replace with the actual value you are interested in

# Call the function to plot the chromatogram
plot_chromatogram(df_group, specific_group_by_lipid_value)

# %% [markdown]
# # STD

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter the data for Parent_Ion within range 425.40 ± 0.3
mask = (df_mzml['Parent_Ion'] >= 425.10) & (df_mzml['Parent_Ion'] <= 425.70)
filtered_df = df_mzml[mask]

# Create the plot
plt.figure(figsize=(10, 6))
plt.scatter(filtered_df['Retention_Time'], filtered_df['OzESI_Intensity'], 
           color='blue', alpha=0.6, label='Parent Ion 425.40 ± 0.3')

# Add labels and title
plt.xlabel('Retention Time (min)')
plt.ylabel('Intensity')
plt.title('Retention Time vs Intensity for Parent Ion 425.40 ± 0.3')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
