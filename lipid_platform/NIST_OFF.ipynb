# %% [markdown]
# # NIST HUMAN PLASMA OFF

# %%
import pandas as pd

# %%
# !sbatch core/backend/NIST/OFF/mzml_parser_1_CT_OFF.sh
# Out:
# Submitted batch job 22362214

# %%
df_mzml = pd.read_parquet('Projects/NIST/mzml_parsed/OFF/mzml_parser_1_OFF_intensity.parquet')
# new df with just Rentention_Time 10 to 13
df_rt = df_mzml[(df_mzml['Retention_Time'] >= 10.8) & (df_mzml['Retention_Time'] <= 11.4)]
# df_rt.to_parquet('Projects/NIST/mzml_parsed/OFF/mzml_parser_1_OFF_intensity_RT_10_13.parquet')
df_mzml
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            227.1        183.0        3.014900        42.220001
# 1            227.1        183.0        3.030717        42.160004
# 2            227.1        183.0        3.046567        42.120003
# 3            227.1        183.0        3.062417        42.020004
# 4            227.1        183.0        3.078267        41.880001
# ...            ...          ...             ...              ...
# 856213       533.5        183.0       31.928683        41.000004
# 856214       533.5        183.0       31.944533        41.080002
# 856215       533.5        183.0       31.960383        41.000004
# 856216       533.5        183.0       31.976233        40.740002
# 856217       533.5        183.0       31.992083        40.640003
#
#                                 Sample_ID      Transition
# 0          02032025_n3Plasma_AMP_ozoneoff  227.1 -> 183.0
# 1          02032025_n3Plasma_AMP_ozoneoff  227.1 -> 183.0
# ...

# %%
df_rt
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 492          227.1        183.0       10.813733        41.520004
# 493          227.1        183.0       10.829583        41.600002
# 494          227.1        183.0       10.845433        41.380001
# 495          227.1        183.0       10.861283        41.640003
# 496          227.1        183.0       10.877133        41.760002
# ...            ...          ...             ...              ...
# 854913       533.5        183.0       11.321917        41.400002
# 854914       533.5        183.0       11.337767        41.360004
# 854915       533.5        183.0       11.353617        41.300003
# 854916       533.5        183.0       11.369467        41.320004
# 854917       533.5        183.0       11.385333        41.360004
#
#                                 Sample_ID      Transition
# 492        02032025_n3Plasma_AMP_ozoneoff  227.1 -> 183.0
# 493        02032025_n3Plasma_AMP_ozoneoff  227.1 -> 183.0
# ...

# %%
import matplotlib.pyplot as plt

# Plot the filtered data
plt.figure(figsize=(8, 6))
plt.scatter(df_mzml['Retention_Time'], df_mzml['OzESI_Intensity'], color='blue', label='OzESI Intensity')

# Add labels and title
plt.xlabel('Retention Time')
plt.ylabel('OzESI Intensity')
plt.title('Retention Time vs OzESI Intensity')
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
# !sbatch core/backend/NIST/OFF/sample_2_NIST_OFF.sh
# Out:
# Submitted batch job 22362210

# %%
df_sample = pd.read_parquet('Projects/NIST/samples/OFF/df_sample_2_NIST_n1_ON.parquet')
df_sample
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            227.1        183.0        3.014900        41.180004
# 1            227.1        183.0        3.030717        40.860004
# 2            227.1        183.0        3.046567        40.800003
# 3            227.1        183.0        3.062417        40.500004
# 4            227.1        183.0        3.078267        40.720001
# ...            ...          ...             ...              ...
# 214050       533.5        183.0       31.928683        40.820004
# 214051       533.5        183.0       31.944533        40.880001
# 214052       533.5        183.0       31.960383        41.220001
# 214053       533.5        183.0       31.976233        42.200005
# 214054       533.5        183.0       31.992083        41.460003
#
#                              Sample_ID      Transition   Sample   STD  \
# 0       02032025_n1Plasma_AMP_ozoneoff  227.1 -> 183.0  NIST_n1  NIST
# ...

# %% [markdown]
# # Match

# %%
# !sbatch core/backend/NIST/OFF/match_3_CT_OFF.sh
# Out:
# Submitted batch job 22362217

# %%
df_match = pd.read_parquet('Projects/NIST/match/OFF/df_match_3_NIST_n3.parquet')
df_match
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            227.1        183.0        3.014900             42.0
# 1            227.1        183.0        3.030717             42.0
# 2            227.1        183.0        3.046567             42.0
# 3            227.1        183.0        3.062417             42.0
# 4            227.1        183.0        3.078267             42.0
# ...            ...          ...             ...              ...
# 214049       533.5        183.0       31.928683             42.0
# 214050       533.5        183.0       31.944533             42.0
# 214051       533.5        183.0       31.960383             42.0
# 214052       533.5        183.0       31.976233             42.0
# 214053       533.5        183.0       31.992083             42.0
#
#                              Sample_ID      Transition   Sample   STD  \
# 0       02032025_n3Plasma_AMP_ozoneoff  227.1 -> 183.0  NIST_n3  NIST
# ...

# %% [markdown]
# # Group

# %%
# !sbatch core/backend/NIST/OFF/group_4_CT_OFF.sh
# Out:
# Submitted batch job 22370723

# %%
df_group = pd.read_parquet('Projects/NIST/group/OFF/df_group_4_NIST_n3_OFF.parquet')
df_group
# Out:
#         Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0            255.2        183.0        3.014550             40.0
# 1            253.2        183.0        3.014667             42.0
# 2            241.1        183.0        3.014783             41.0
# 3            227.1        183.0        3.014900             42.0
# 4            255.2        183.0        3.030367            170.0
# ...            ...          ...             ...              ...
# 214049       425.4        183.0       31.935183             42.0
# 214050       425.4        183.0       31.951050             42.0
# 214051       425.4        183.0       31.966900             42.0
# 214052       425.4        183.0       31.982750             41.0
# 214053       425.4        183.0       31.998600             42.0
#
#                              Sample_ID      Transition   Sample   STD  \
# 0       02032025_n3Plasma_AMP_ozoneoff  255.2 -> 183.0  NIST_n3  NIST
# ...

# %%
unique_lipids = df_group['Lipid'].unique()
print(unique_lipids)
# Out:
# ['' 'FA(10:0)' 'FA(10:1)' 'FA(10:2)' 'FA(10:3)' 'FA(10:4)' 'FA(10:5)'
#  'FA(11:0)' 'FA(11:1)' 'FA(11:2)' 'FA(11:3)' 'FA(11:4)' 'FA(11:5)'
#  'FA(12:0)' 'FA(12:1)' 'FA(12:2)' 'FA(12:3)' 'FA(12:4)' 'FA(12:5)'
#  'FA(13:0)' 'FA(13:1)' 'FA(13:2)' 'FA(13:3)' 'FA(13:4)' 'FA(13:5)'
#  'FA(14:0)' 'FA(14:1)' 'FA(14:2)' 'FA(14:3)' 'FA(14:4)' 'FA(14:5)'
#  'FA(15:0)' 'FA(15:1)' 'FA(15:2)' 'FA(15:3)' 'FA(15:4)' 'FA(15:5)'
#  'FA(16:0)' 'FA(16:1)' 'FA(16:2)' 'FA(16:3)' 'FA(16:4)' 'FA(16:5)'
#  'FA(17:0)' 'FA(17:1)' 'FA(17:2)' 'FA(17:3)' 'FA(17:4)' 'FA(17:5)'
#  'FA(18:0)' 'FA(18:1)' 'FA(18:2)' 'FA(18:3)' 'FA(18:4)' 'FA(18:5)'
#  'FA(19:0)' 'FA(19:1)' 'FA(19:2)' 'FA(19:3)' 'FA(19:4)' 'FA(19:5)'
#  'FA(20:0)' 'FA(20:1)' 'FA(20:2)' 'FA(20:3)' 'FA(20:4)' 'FA(20:5)'
#  'FA(21:0)' 'FA(21:1)' 'FA(21:2)' 'FA(21:3)' 'FA(21:4)' 'FA(21:5)'
#  'FA(22:0)' 'FA(22:1)' 'FA(22:2)' 'FA(22:3)' 'FA(22:4)' 'FA(22:5)'
#  'FA(22:6)' 'FA(23:0)' 'FA(23:1)' 'FA(23:2)' 'FA(23:3)' 'FA(23:4)'
# ...

# %%
# print unique columns
unique_columns = df_group.columns
print(unique_columns)
# Out:
# Index(['Parent_Ion', 'Product_Ion', 'Retention_Time', 'OzESI_Intensity',
#        'Sample_ID', 'Transition', 'Sample', 'STD', 'Replicate', 'STD_RT_ON',
#        'STD_Peak_Intensity', 'STD_Peak_Area', 'Lipid', 'Class', 'Species',
#        'Biology', 'Genotype', 'Cage', 'Mouse', 'group_by_ion',
#        'group_by_lipid'],
#       dtype='object')

# %% [markdown]
# # analysis 5

# %%
# !sbatch core/backend/NIST/OFF/analysis_5_CT_OFF.sh
# Out:
# Submitted batch job 22370736

# %%
import pandas as pd
df_analysis = pd.read_parquet('Projects/NIST/analysis/OFF/df_analysis_CT_OFF_NIST_n1.parquet')
df_analysis
# Out:
#         Lipid  Retention_Time  OzESI_Intensity  group_by_ion  group_by_lipid  \
# 0     FA(5:1)        9.814517           1329.0             5              89
# 1     FA(5:1)       11.827633           1207.0             5              89
# 2     FA(6:1)        9.829883           1568.0             9              92
# 3     FA(6:1)        9.940850           1013.0             9              92
# 4     FA(6:1)       11.795450           2385.0             9              92
# ..        ...             ...              ...           ...             ...
# 751  FA(22:6)        9.707767         801549.0           101              79
# 752  FA(22:6)       10.738117          12375.0           101              79
# 753  FA(22:6)       11.134400           1698.0           101              79
# 754  FA(23:2)       13.146267           1335.0           111              82
# 755  FA(23:2)       13.209683           1502.0           111              82
#
# ...

# %%
unique_lipids = df_analysis['Lipid'].unique()
print(unique_lipids)

# look at FA(22:0)
df_analysis[df_analysis['Lipid'] == 'FA(20:0)']
# Out:
# ['FA(5:1)' 'FA(6:1)' 'FA(6:3)' 'FA(7:0)' 'FA(7:1)' 'FA(7:3)' 'FA(8:0)'
#  'FA(8:1)' 'FA(9:0)' 'FA(9:1)' 'FA(10:0)' 'FA(10:1)' 'FA(10:2)' 'FA(11:0)'
#  'FA(11:1)' 'FA(11:2)' 'FA(12:0)' 'FA(12:1)' 'FA(12:2)' 'FA(13:0)'
#  'FA(13:1)' 'FA(13:2)' 'FA(14:0)' 'FA(14:1)' 'FA(14:2)' 'FA(15:0)'
#  'FA(15:1)' 'FA(d2-16:0)' 'FA(16:0)' 'FA(16:1)' 'FA(16:2)' 'FA(17:0)'
#  'FA(17:1)' 'FA(17:2)' 'FA(17:5)' 'FA(18:0)' 'FA(18:1)' 'FA(18:2)'
#  'FA(18:3)' 'FA(18:4)' 'FA(19:0)' 'FA(19:1)' 'FA(19:2)' 'FA(19:3)'
#  'FA(20:0)' 'FA(20:1)' 'FA(20:2)' 'FA(20:3)' 'FA(20:4)' 'FA(20:5)'
#  'FA(21:0)' 'FA(21:1)' 'FA(22:0)' 'FA(22:1)' 'FA(22:2)' 'FA(22:3)'
#  'FA(22:4)' 'FA(22:5)' 'FA(22:6)' 'FA(23:2)']
#         Lipid  Retention_Time  OzESI_Intensity  group_by_ion  group_by_lipid  \
# 556  FA(20:0)       15.193217           1204.0            94              61
# 557  FA(20:0)       15.399283           1987.0            94              61
# ...

# %% [markdown]
# # OFF Possible

# %%
# !sbatch core/backend/NIST/OFF/off_possible_6_NIST.sh
# Out:
# Submitted batch job 22372142

# %% [markdown]
# # off possible

# %%
off_possible_df = pd.read_parquet('Projects/NIST/analysis/OFF/off_possible/df_analysis_CT_OFF_NIST_n3.parquet')
# filter for lipid species 18:1
# off_possible_df = off_possible_df[off_possible_df['Lipid'].str.contains('18:1')]
# show all rows
pd.set_option('display.max_rows', None)
off_possible_df
# Out:
#           Lipid  Retention_Time  OzESI_Intensity  group_by_ion  \
# 0       FA(5:1)       11.764233           2442.0             5
# 1       FA(5:1)        9.782817           2304.0             5
# 2       FA(6:1)       11.700350           4390.0             9
# 3       FA(6:1)       11.795467           2954.0             9
# 4       FA(6:2)        5.613550           1174.0             8
# 5       FA(6:3)       30.674650           1094.0             7
# 6       FA(7:1)       11.810717           6565.0            14
# 7       FA(7:1)       11.683900           6202.0            14
# 8       FA(8:1)       11.683200           9219.0            20
# 9       FA(8:1)       11.920967           6463.0            20
# 10      FA(9:1)       11.761733          11674.0            26
# 11      FA(9:1)        9.796167           9045.0            26
# 12      FA(9:2)        9.732883           1017.0            25
# 13     FA(10:1)       11.713467          14253.0            32
# ...

# %%
import pandas as pd
# look at species 18:1 in off possible
off_possible_df[off_possible_df['Lipid'] == 'FA(18:1)']
# Out:
#        Lipid  Retention_Time  OzESI_Intensity  group_by_ion  group_by_lipid  \
# 47  FA(18:1)       12.309867        4391440.0            81              50
# 48  FA(18:1)       11.739217       10387532.0            81              50
#
#                          Sample_ID      Transition   Sample  Parent_Ion  \
# 47  02032025_n3Plasma_AMP_ozoneoff  449.4 -> 183.0  NIST_n3       449.4
# 48  02032025_n3Plasma_AMP_ozoneoff  449.4 -> 183.0  NIST_n3       449.4
#
#     Product_Ion  ...   STD STD_RT_OFF STD_Peak_Intensity  STD_Peak_Area  \
# 47        183.0  ...  NIST    10.8529         298454.875   72918.039967
# 48        183.0  ...  NIST    10.8529         298454.875   72918.039967
#
#     Peak_Height      FWHM  Peak_Width     Peak_Area   Filter_Column  Isomer
# 47    4391440.0  0.032694    0.031700  1.385682e+05  group_by_lipid   trans
# 48   10387532.0  0.479680    0.475533  3.928742e+06  group_by_lipid     cis
#
# [2 rows x 22 columns]

# %%
unique_lipids = off_possible_df['Lipid'].unique()
print(unique_lipids)
# Out:
# ['FA(5:1)' 'FA(6:1)' 'FA(6:2)' 'FA(6:3)' 'FA(7:1)' 'FA(8:1)' 'FA(9:1)'
#  'FA(9:2)' 'FA(10:1)' 'FA(10:2)' 'FA(11:1)' 'FA(11:2)' 'FA(12:1)'
#  'FA(12:2)' 'FA(13:1)' 'FA(13:2)' 'FA(14:1)' 'FA(14:2)' 'FA(15:1)'
#  'FA(16:1)' 'FA(16:2)' 'FA(16:3)' 'FA(17:1)' 'FA(17:2)' 'FA(17:5)'
#  'FA(18:1)' 'FA(18:2)' 'FA(18:3)' 'FA(18:4)' 'FA(19:1)' 'FA(19:2)'
#  'FA(19:3)' 'FA(20:1)' 'FA(20:2)' 'FA(20:3)' 'FA(20:4)' 'FA(20:5)'
#  'FA(21:5)' 'FA(22:1)' 'FA(22:2)' 'FA(22:3)' 'FA(22:4)' 'FA(22:5)'
#  'FA(22:6)' 'FA(23:2)' 'FA(d2-16:0)']

# %% [markdown]
# # ZERO VALUES

# %%
zero_value_df = pd.read_parquet('Projects/NIST/analysis/OFF/off_possible/zero/df_analysis_CT_OFF_NIST_n1.parquet')
# filter for lipid species 18:1
# zero_value_df = zero_value_df[zero_value_df['Lipid'].str.contains('18:1')]
zero_value_df
# Out:
#        Lipid  Retention_Time  OzESI_Intensity  group_by_ion  group_by_lipid  \
# 0    FA(7:0)        3.298417           4488.0            15              95
# 1    FA(8:0)        4.011017           6143.0            21             100
# 2    FA(9:0)        4.612667         144060.0            27             106
# 3   FA(10:0)        5.198433          16806.0            33               1
# 4   FA(11:0)        5.736667           4497.0            39               7
# 5   FA(12:0)        6.338300         211361.0            45              13
# 6   FA(13:0)        7.225250           4189.0            51              19
# 7   FA(14:0)        8.381667         224411.0            57              25
# 8   FA(15:0)        9.696600          41887.0            63              31
# 9   FA(16:0)       10.932267        5478866.0            69              37
# 10  FA(17:0)       12.849433          61617.0            76              43
# ...

# %% [markdown]
# # BLANK SUBTRACTED

# %%
blank_subtracted_zero_df = pd.read_csv('Projects/NIST/analysis/OFF/off_possible/zero/csv_dir/df_analysis_CT_OFF_NIST_n1.csv')
# filter for lipid species 18:1

blank_subtracted_zero_df
# Out:
#        Lipid  Retention_Time  OzESI_Intensity  group_by_ion  group_by_lipid  \
# 0    FA(7:0)        3.298417         340349.0            15              95
# 1    FA(8:0)        3.979317          95808.0            21             100
# 2    FA(9:0)        4.596800        2202392.0            27             106
# 3   FA(10:0)        5.198433          58658.0            33               1
# 4   FA(11:0)        5.704967           9767.0            39               7
# 5   FA(12:0)        6.370000         123252.0            45              13
# 6   FA(13:0)        6.892367           4428.0            51              19
# 7   FA(14:0)        8.381667          71732.0            57              25
# 8   FA(15:0)        9.807567          10287.0            63              31
# 9   FA(16:0)       11.106633         865578.0            69              37
# 10  FA(17:0)       12.944533           9484.0            76              43
# ...

# %%
import os
import glob
import pandas as pd

# Define the directory that contains the CSV files
csv_dir = 'Projects/NIST/analysis/OFF/off_possible/zero/csv_dir'
# Define the output directory for blank-subtracted files
output_dir = os.path.join(csv_dir, 'blank_subtracted')
os.makedirs(output_dir, exist_ok=True)

# Get a list of all CSV files in the directory
csv_files = glob.glob(os.path.join(csv_dir, '*.csv'))

# Identify the blank file (assume the filename contains 'Blank')
blank_files = [f for f in csv_files if 'Blank' in os.path.basename(f)]
if not blank_files:
    raise ValueError("No file with 'Blank' in its name found!")
elif len(blank_files) > 1:
    print("Warning: More than one 'Blank' file found. Using the first one.")

# Read the blank file into a DataFrame
blank_file = blank_files[0]
print(f"Using blank file: {os.path.basename(blank_file)}")
blank_df = pd.read_csv(blank_file)

# Create a lookup for blank intensities by Lipid.
# Assumes one row per unique Lipid.
blank_lookup = blank_df.set_index('Lipid')['OzESI_Intensity']

# Debug: show the first few items in the blank lookup
print("First few entries in the blank lookup:")
print(blank_lookup.head())

# Now iterate through all CSV files (skipping the blank file)
for file in csv_files:
    if file == blank_file:
        continue  # Skip the blank file

    print(f"\nProcessing file: {os.path.basename(file)}")
    df = pd.read_csv(file)

    # Optionally, if you want to filter to a specific lipid (e.g. containing '18:1'):
    # df = df[df['Lipid'].str.contains('18:1')]

    # Map the blank intensity to the current file's lipids.
    df['Blank_Intensity'] = df['Lipid'].map(blank_lookup)

    # Debug: count how many lipids got a matching blank intensity
    num_matched = df['Blank_Intensity'].notna().sum()
    total_lipids = len(df)
    print(f"Matched blank intensity for {num_matched} out of {total_lipids} lipids.")

    # Optionally, show some of the mapping details for the first few lipids
    print("Sample mapping (first 5 rows):")
    print(df[['Lipid', 'OzESI_Intensity', 'Blank_Intensity']].head())

    # Replace missing blank values with 0 if that's appropriate
    df['Blank_Intensity'] = df['Blank_Intensity'].fillna(0)

    # Subtract the blank intensity from the original intensity
    df['OzESI_Intensity_BlankSubtracted'] = df['OzESI_Intensity'] - df['Blank_Intensity']

    # Debug: display the result of subtraction for the first few rows
    print("After subtraction (first 5 rows):")
    print(df[['Lipid', 'OzESI_Intensity', 'Blank_Intensity', 'OzESI_Intensity_BlankSubtracted']].head())

    # Reorder columns so that OzESI_Intensity_BlankSubtracted is right after OzESI_Intensity
    cols = list(df.columns)
    # Remove the new column from the list (if it exists) so we can reinsert it
    if 'OzESI_Intensity_BlankSubtracted' in cols:
        cols.remove('OzESI_Intensity_BlankSubtracted')
    # Find the index of OzESI_Intensity and insert the new column right after it
    try:
        idx = cols.index('OzESI_Intensity')
    except ValueError:
        raise ValueError("Column 'OzESI_Intensity' not found in the DataFrame!")
    cols.insert(idx + 1, 'OzESI_Intensity_BlankSubtracted')
    # Reorder the dataframe columns
    df = df[cols]

    # Optionally drop the extra Blank_Intensity column if you don't need it
    # df.drop(columns=['Blank_Intensity'], inplace=True)

    # Save the new dataframe to the output directory.
    output_file = os.path.join(output_dir, os.path.basename(file))
    df.to_csv(output_file, index=False)
    print(f"Processed and saved: {output_file}")
# Out:
# Using blank file: df_analysis_CT_OFF_Blank.csv
# First few entries in the blank lookup:
# Lipid
# FA(7:0)      340349.0
# FA(8:0)       95808.0
# FA(9:0)     2202392.0
# FA(10:0)      58658.0
# FA(11:0)       9767.0
# Name: OzESI_Intensity, dtype: float64
#
# Processing file: df_analysis_CT_OFF_NIST_n2.csv
# Matched blank intensity for 14 out of 15 lipids.
# Sample mapping (first 5 rows):
#       Lipid  OzESI_Intensity  Blank_Intensity
# 0   FA(7:0)           3181.0         340349.0
# 1   FA(8:0)           6161.0          95808.0
# 2   FA(9:0)         100981.0        2202392.0
# 3  FA(10:0)          10688.0          58658.0
# 4  FA(11:0)           3383.0           9767.0
# After subtraction (first 5 rows):
#       Lipid  OzESI_Intensity  Blank_Intensity  OzESI_Intensity_BlankSubtracted
# 0   FA(7:0)           3181.0         340349.0                        -337168.0
# 1   FA(8:0)           6161.0          95808.0                         -89647.0
# ...

# %%
# load this Processed and saved: Projects/NIST/analysis/OFF/off_possible/zero/csv_dir/blank_subtracted/df_analysis_CT_OFF_NIST_n2.csv
blank_subtracted_df = pd.read_csv('Projects/NIST/analysis/OFF/off_possible/zero/csv_dir/blank_subtracted/df_analysis_CT_OFF_NIST_n1.csv')
blank_subtracted_df
# Out:
#        Lipid  Retention_Time  OzESI_Intensity  \
# 0    FA(7:0)        3.298417           4488.0
# 1    FA(8:0)        4.011017           6143.0
# 2    FA(9:0)        4.612667         144060.0
# 3   FA(10:0)        5.198433          16806.0
# 4   FA(11:0)        5.736667           4497.0
# 5   FA(12:0)        6.338300         211361.0
# 6   FA(13:0)        7.225250           4189.0
# 7   FA(14:0)        8.381667         224411.0
# 8   FA(15:0)        9.696600          41887.0
# 9   FA(16:0)       10.932267        5478866.0
# 10  FA(17:0)       12.849433          61617.0
# 11  FA(18:0)       14.307017        2514614.0
# 12  FA(19:0)       17.365583           2504.0
# 13  FA(20:0)       19.171900           7254.0
# 14  FA(21:0)        8.725117           1008.0
# 15  FA(22:0)       23.957383           1431.0
#
#     OzESI_Intensity_BlankSubtracted  group_by_ion  group_by_lipid  \
# 0                         -335861.0            15              95
# ...

# %% [markdown]
# # Plots

# %%
import matplotlib.pyplot as plt

# Function to plot the chromatogram for a specific group_by_lipid value
def plot_chromatogram(df, group_value):
    group_data = df[df['group_by_lipid'] == group_value]
    
    # Ensure the Retention_Time is sorted
    group_data = group_data.sort_values(by='Retention_Time')
    
    # Extract Lipid, Parent Ion, and Isomer values from the first row of the group
    lipid = group_data['Lipid'].iloc[0] if not group_data.empty else "Unknown Lipid"
    parent_ion = group_data['Parent_Ion'].iloc[0] if not group_data.empty else "Unknown Parent Ion"
    # isomer = group_data['Isomer'].iloc[0] if not group_data.empty else "Unknown Isomer"
    
    plt.figure(figsize=(10, 6))
    plt.plot(group_data['Retention_Time'], group_data['OzESI_Intensity'], label=f'group_by_lipid: {group_value}')
    plt.xlabel('Retention Time')
    plt.ylabel('OzESI Intensity')
    
    # Add Lipid, Parent Ion, and Isomer to the title
    plt.title(f'{group_value} | Lipid: {lipid} | Parent Ion: {parent_ion} ')
    
    plt.legend()
    plt.grid(True)
    plt.show()

# Define the specific group_by_lipid value you are interested in
specific_group_by_lipid_value = 26 # Replace with the actual value you are interested in

# Call the function to plot the chromatogram
plot_chromatogram(df_group, specific_group_by_lipid_value)

# %% [markdown]
# # STD

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter the data for Parent_Ion within range 425.40 ± 0.3
mask = (df_mzml['Parent_Ion'] >= 425.10) & (df_mzml['Parent_Ion'] <= 425.70)
filtered_df = df_mzml[mask]

# Create the plot
plt.figure(figsize=(10, 6))
plt.scatter(filtered_df['Retention_Time'], filtered_df['OzESI_Intensity'], 
           color='blue', alpha=0.6, label='Parent Ion 425.40 ± 0.3')

# Add labels and title
plt.xlabel('Retention Time (min)')
plt.ylabel('Intensity')
plt.title('Retention Time vs Intensity for Parent Ion 425.40 ± 0.3')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
