# %%
import pandas as pd

# %% [markdown]
# # 1 - parser ON

# %%
# Submit the SLURM job for mzml_parser_1.sh
# !sbatch core/backend/mzml_parser_1_test.sh
# Out:
# Submitted batch job 19346821

# %%
# sum = pd.read_parquet('Projects/STD/mzml_parsed/ON/sum/df_transition_summed_1_test.parquet')
# sum

# %%
df = pd.read_parquet('Projects/STD/mzml_parsed/ON/df_mzml_parser_1_ON_test.parquet')
df
# Out:
#       Lipid  Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0      None       255.2        183.0        0.024400        41.320004
# 1      None       255.2        183.0        0.050617        41.300003
# 2      None       255.2        183.0        0.076850        41.300003
# 3      None       255.2        183.0        0.103083        41.320004
# 4      None       255.2        183.0        0.129317        54.620003
# ...     ...         ...          ...             ...              ...
# 50900  None       533.5        183.0       24.606100        41.800003
# 50901  None       533.5        183.0       24.632333        41.280003
# 50902  None       533.5        183.0       24.658567        41.280003
# 50903  None       533.5        183.0       24.684800        41.220001
# 50904  None       533.5        183.0       24.711033        41.280003
#
#       Sample_ID      Transition
# 0       FAME_on  255.2 -> 183.0
# 1       FAME_on  255.2 -> 183.0
# 2       FAME_on  255.2 -> 183.0
# 3       FAME_on  255.2 -> 183.0
# 4       FAME_on  255.2 -> 183.0
# ...         ...             ...
# 50900   FAME_on  533.5 -> 183.0
# 50901   FAME_on  533.5 -> 183.0
# 50902   FAME_on  533.5 -> 183.0
# 50903   FAME_on  533.5 -> 183.0
# 50904   FAME_on  533.5 -> 183.0
#
# [50905 rows x 7 columns]

# %% [markdown]
# # 2 - Sample

# %%
# Submit the SLURM job for !sbatch core/backend/sample_2.sh
# !sbatch core/backend/sample_2_test.sh
# Out:
# Submitted batch job 19347022

# %%
import pandas as pd
df = pd.read_parquet('Projects/STD/samples/ON/df_sample_2_FAME_ON.parquet')
df
# Out:
#       Lipid  Parent_Ion  Product_Ion  Retention_Time  OzESI_Intensity  \
# 0      None       255.2        183.0        0.024400        41.320004
# 1      None       255.2        183.0        0.050617        41.300003
# 2      None       255.2        183.0        0.076850        41.300003
# 3      None       255.2        183.0        0.103083        41.320004
# 4      None       255.2        183.0        0.129317        54.620003
# ...     ...         ...          ...             ...              ...
# 50900  None       533.5        183.0       24.606100        41.800003
# 50901  None       533.5        183.0       24.632333        41.280003
# 50902  None       533.5        183.0       24.658567        41.280003
# 50903  None       533.5        183.0       24.684800        41.220001
# 50904  None       533.5        183.0       24.711033        41.280003
#
#       Sample_ID      Transition Sample   STD  STD_RT_ON
# 0       FAME_on  255.2 -> 183.0   FAME  FAME   8.195483
# 1       FAME_on  255.2 -> 183.0   FAME  FAME   8.195483
# 2       FAME_on  255.2 -> 183.0   FAME  FAME   8.195483
# 3       FAME_on  255.2 -> 183.0   FAME  FAME   8.195483
# 4       FAME_on  255.2 -> 183.0   FAME  FAME   8.195483
# ...         ...             ...    ...   ...        ...
# 50900   FAME_on  533.5 -> 183.0   FAME  FAME   8.195483
# 50901   FAME_on  533.5 -> 183.0   FAME  FAME   8.195483
# 50902   FAME_on  533.5 -> 183.0   FAME  FAME   8.195483
# 50903   FAME_on  533.5 -> 183.0   FAME  FAME   8.195483
# 50904   FAME_on  533.5 -> 183.0   FAME  FAME   8.195483
#
# [50905 rows x 10 columns]

# %% [markdown]
# # 3 - Match

# %%
# Submit the SLURM job for !sbatch core/backend/match_3.sh
# !sbatch core/backend/match_3_test.sh
# Out:
# Submitted batch job 19352584

# %%
import pandas as pd
df = pd.read_parquet('Projects/STD/match/ON/df_match_3_FAME.parquet')
#print unqiue vlaues of Lipid in df
print(df['Lipid'].unique())
df
# Out:
# ['FA(14:1)_<>_n-11 | FA(15:1)_<>_n-12 | FA(16:1)_<>_n-13 | FA(17:1)_<>_n-14 | FA(18:1)_<>_n-15 | FA(18:2)_<F>_n-15 | FA(18:3)_<FF>_n-15 | FA(20:1)_<>_n-17 | FA(20:2)_<F>_n-17 | FA(20:3)_<FF>_n-17 | FA(20:4)_<FFF>_n-17 | FA(20:5)_<FFFF>_n-17 | FA(22:1)_<>_n-19 | FA(22:2)_<F>_n-19 | FA(22:6)_<FFFFF>_n-19'
#  'FA(14:1)_<>_n-10 | FA(15:1)_<>_n-11 | FA(16:1)_<>_n-12 | FA(17:1)_<>_n-13 | FA(18:1)_<>_n-14 | FA(18:2)_<F>_n-14 | FA(18:3)_<FF>_n-14 | FA(20:1)_<>_n-16 | FA(20:2)_<F>_n-16 | FA(20:3)_<FF>_n-16 | FA(20:4)_<FFF>_n-16 | FA(20:5)_<FFFF>_n-16 | FA(22:1)_<>_n-18 | FA(22:2)_<F>_n-18 | FA(22:6)_<FFFFF>_n-18'
#  'FA(14:1)_<>_n-9 | FA(15:1)_<>_n-10 | FA(16:1)_<>_n-11 | FA(17:1)_<>_n-12 | FA(18:1)_<>_n-13 | FA(18:2)_<F>_n-13 | FA(18:3)_<FF>_n-13 | FA(20:1)_<>_n-15 | FA(20:2)_<F>_n-15 | FA(20:3)_<FF>_n-15 | FA(20:4)_<FFF>_n-15 | FA(20:5)_<FFFF>_n-15 | FA(22:1)_<>_n-17 | FA(22:2)_<F>_n-17 | FA(22:6)_<FFFFF>_n-17'
#  'FA(14:1)_<>_n-8 | FA(15:1)_<>_n-9 | FA(16:1)_<>_n-10 | FA(17:1)_<>_n-11 | FA(18:1)_<>_n-12 | FA(18:2)_<F>_n-12 | FA(18:3)_<FF>_n-12 | FA(20:1)_<>_n-14 | FA(20:2)_<F>_n-14 | FA(20:3)_<FF>_n-14 | FA(20:4)_<FFF>_n-14 | FA(20:5)_<FFFF>_n-14 | FA(22:1)_<>_n-16 | FA(22:2)_<F>_n-16 | FA(22:6)_<FFFFF>_n-16'
#  'FA(18:2)_<B>_n-11 | FA(18:3)_<BF>_n-11 | FA(20:2)_<B>_n-13 | FA(20:3)_<BF>_n-13 | FA(20:4)_<BFF>_n-13 | FA(20:5)_<BFFF>_n-13 | FA(22:2)_<B>_n-15 | FA(22:6)_<BFFFF>_n-15'
#  'FA(8:0) | FA(14:1)_<>_n-7 | FA(15:1)_<>_n-8 | FA(16:1)_<>_n-9 | FA(17:1)_<>_n-10 | FA(18:1)_<>_n-11 | FA(18:2)_<F>_n-11 | FA(18:3)_<FF>_n-11 | FA(20:1)_<>_n-13 | FA(20:2)_<F>_n-13 | FA(20:3)_<FF>_n-13 | FA(20:4)_<FFF>_n-13 | FA(20:5)_<FFFF>_n-13 | FA(22:1)_<>_n-15 | FA(22:2)_<F>_n-15 | FA(22:6)_<FFFFF>_n-15'
#  'FA(18:2)_<B>_n-10 | FA(18:3)_<BF>_n-10 | FA(20:2)_<B>_n-12 | FA(20:3)_<BF>_n-12 | FA(20:4)_<BFF>_n-12 | FA(20:5)_<BFFF>_n-12 | FA(22:2)_<B>_n-14 | FA(22:6)_<BFFFF>_n-14'
#  'FA(9:0) | FA(14:1)_<>_n-6 | FA(15:1)_<>_n-7 | FA(16:1)_<>_n-8 | FA(17:1)_<>_n-9 | FA(18:1)_<>_n-10 | FA(18:2)_<F>_n-10 | FA(18:3)_<FF>_n-10 | FA(20:1)_<>_n-12 | FA(20:2)_<F>_n-12 | FA(20:3)_<FF>_n-12 | FA(20:4)_<FFF>_n-12 | FA(20:5)_<FFFF>_n-12 | FA(22:1)_<>_n-14 | FA(22:2)_<F>_n-14 | FA(22:6)_<FFFFF>_n-14'
#  'FA(18:2)_<B>_n-9 | FA(18:3)_<BF>_n-9 | FA(20:2)_<B>_n-11 | FA(20:3)_<BF>_n-11 | FA(20:4)_<BFF>_n-11 | FA(20:5)_<BFFF>_n-11 | FA(22:2)_<B>_n-13 | FA(22:6)_<BFFFF>_n-13'
#  'FA(10:0) | FA(14:1)_<>_n-5 | FA(15:1)_<>_n-6 | FA(16:1)_<>_n-7 | FA(17:1)_<>_n-8 | FA(18:1)_<>_n-9 | FA(18:2)_<F>_n-9 | FA(18:3)_<FF>_n-9 | FA(20:1)_<>_n-11 | FA(20:2)_<F>_n-11 | FA(20:3)_<FF>_n-11 | FA(20:4)_<FFF>_n-11 | FA(20:5)_<FFFF>_n-11 | FA(22:1)_<>_n-13 | FA(22:2)_<F>_n-13 | FA(22:6)_<FFFFF>_n-13'
#  'FA(18:3)_<BB>_n-8 | FA(20:3)_<BB>_n-10 | FA(20:4)_<BBF>_n-10 | FA(20:5)_<BBFF>_n-10 | FA(22:6)_<BBFFF>_n-12'
#  'FA(11:0) | FA(14:1)_<>_n-4 | FA(15:1)_<>_n-5 | FA(16:1)_<>_n-6 | FA(17:1)_<>_n-7 | FA(18:1)_<>_n-8 | FA(18:2)_<F>_n-8 | FA(18:3)_<FF>_n-8 | FA(20:1)_<>_n-10 | FA(20:2)_<F>_n-10 | FA(20:3)_<FF>_n-10 | FA(20:4)_<FFF>_n-10 | FA(20:5)_<FFFF>_n-10 | FA(22:1)_<>_n-12 | FA(22:2)_<F>_n-12 | FA(22:6)_<FFFFF>_n-12'
#  'FA(18:3)_<BB>_n-7 | FA(20:3)_<BB>_n-9 | FA(20:4)_<BBF>_n-9 | FA(20:5)_<BBFF>_n-9 | FA(22:6)_<BBFFF>_n-11'
#  'FA(18:2)_<B>_n-7 | FA(18:3)_<BF>_n-7 | FA(20:2)_<B>_n-9 | FA(20:3)_<BF>_n-9 | FA(20:4)_<BFF>_n-9 | FA(20:5)_<BFFF>_n-9 | FA(22:2)_<B>_n-11 | FA(22:6)_<BFFFF>_n-11'
#  'FA(12:0) | FA(14:1)_<>_n-3 | FA(15:1)_<>_n-4 | FA(16:1)_<>_n-5 | FA(17:1)_<>_n-6 | FA(18:1)_<>_n-7 | FA(18:2)_<F>_n-7 | FA(18:3)_<FF>_n-7 | FA(20:1)_<>_n-9 | FA(20:2)_<F>_n-9 | FA(20:3)_<FF>_n-9 | FA(20:4)_<FFF>_n-9 | FA(20:5)_<FFFF>_n-9 | FA(22:1)_<>_n-11 | FA(22:2)_<F>_n-11 | FA(22:6)_<FFFFF>_n-11'
#  'FA(18:3)_<BB>_n-6 | FA(20:3)_<BB>_n-8 | FA(20:4)_<BBF>_n-8 | FA(20:5)_<BBFF>_n-8 | FA(22:6)_<BBFFF>_n-10'
#  'FA(18:2)_<B>_n-6 | FA(18:3)_<BF>_n-6 | FA(20:2)_<B>_n-8 | FA(20:3)_<BF>_n-8 | FA(20:4)_<BFF>_n-8 | FA(20:5)_<BFFF>_n-8 | FA(22:2)_<B>_n-10 | FA(22:6)_<BFFFF>_n-10'
#  'FA(13:0) | FA(14:1)_<>_n-2 | FA(15:1)_<>_n-3 | FA(16:1)_<>_n-4 | FA(17:1)_<>_n-5 | FA(18:1)_<>_n-6 | FA(18:2)_<F>_n-6 | FA(18:3)_<FF>_n-6 | FA(20:1)_<>_n-8 | FA(20:2)_<F>_n-8 | FA(20:3)_<FF>_n-8 | FA(20:4)_<FFF>_n-8 | FA(20:5)_<FFFF>_n-8 | FA(22:1)_<>_n-10 | FA(22:2)_<F>_n-10 | FA(22:6)_<FFFFF>_n-10'
#  'FA(20:4)_<BBB>_n-7 | FA(20:5)_<BBBF>_n-7 | FA(22:6)_<BBBFF>_n-9'
#  'FA(18:2)_<B>_n-5 | FA(18:3)_<BF>_n-5 | FA(20:2)_<B>_n-7 | FA(20:3)_<BF>_n-7 | FA(20:4)_<BFF>_n-7 | FA(20:5)_<BFFF>_n-7 | FA(22:2)_<B>_n-9 | FA(22:6)_<BFFFF>_n-9'
#  'FA(14:0) | FA(15:1)_<>_n-2 | FA(16:1)_<>_n-3 | FA(17:1)_<>_n-4 | FA(18:1)_<>_n-5 | FA(18:2)_<F>_n-5 | FA(18:3)_<FF>_n-5 | FA(20:1)_<>_n-7 | FA(20:2)_<F>_n-7 | FA(20:3)_<FF>_n-7 | FA(20:4)_<FFF>_n-7 | FA(20:5)_<FFFF>_n-7 | FA(22:1)_<>_n-9 | FA(22:2)_<F>_n-9 | FA(22:6)_<FFFFF>_n-9'
#  'FA(20:4)_<BBB>_n-6 | FA(20:5)_<BBBF>_n-6 | FA(22:6)_<BBBFF>_n-8'
#  'FA(18:3)_<BB>_n-4 | FA(20:3)_<BB>_n-6 | FA(20:4)_<BBF>_n-6 | FA(20:5)_<BBFF>_n-6 | FA(22:6)_<BBFFF>_n-8'
#  'FA(18:2)_<B>_n-4 | FA(18:3)_<BF>_n-4 | FA(20:2)_<B>_n-6 | FA(20:3)_<BF>_n-6 | FA(20:4)_<BFF>_n-6 | FA(20:5)_<BFFF>_n-6 | FA(22:2)_<B>_n-8 | FA(22:6)_<BFFFF>_n-8'
#  'FA(15:0) | FA(16:1)_<>_n-2 | FA(17:1)_<>_n-3 | FA(18:1)_<>_n-4 | FA(18:2)_<F>_n-4 | FA(18:3)_<FF>_n-4 | FA(20:1)_<>_n-6 | FA(20:2)_<F>_n-6 | FA(20:3)_<FF>_n-6 | FA(20:4)_<FFF>_n-6 | FA(20:5)_<FFFF>_n-6 | FA(22:1)_<>_n-8 | FA(22:2)_<F>_n-8 | FA(22:6)_<FFFFF>_n-8'
#  'FA(18:3)_<BB>_n-3 | FA(20:3)_<BB>_n-5 | FA(20:4)_<BBF>_n-5 | FA(20:5)_<BBFF>_n-5 | FA(22:6)_<BBFFF>_n-7'
#  'FA(18:2)_<B>_n-3 | FA(18:3)_<BF>_n-3 | FA(20:2)_<B>_n-5 | FA(20:3)_<BF>_n-5 | FA(20:4)_<BFF>_n-5 | FA(20:5)_<BFFF>_n-5 | FA(22:2)_<B>_n-7 | FA(22:6)_<BFFFF>_n-7'
#  'FA(16:0) | FA(17:1)_<>_n-2 | FA(18:1)_<>_n-3 | FA(18:2)_<F>_n-3 | FA(18:3)_<FF>_n-3 | FA(20:1)_<>_n-5 | FA(20:2)_<F>_n-5 | FA(20:3)_<FF>_n-5 | FA(20:4)_<FFF>_n-5 | FA(20:5)_<FFFF>_n-5 | FA(22:1)_<>_n-7 | FA(22:2)_<F>_n-7 | FA(22:6)_<FFFFF>_n-7'
#  '' 'FA(20:5)_<BBBB>_n-4 | FA(22:6)_<BBBBF>_n-6'
#  'FA(18:2)_<B>_n-2 | FA(18:3)_<BF>_n-2 | FA(20:2)_<B>_n-4 | FA(20:3)_<BF>_n-4 | FA(20:4)_<BFF>_n-4 | FA(20:5)_<BFFF>_n-4 | FA(22:2)_<B>_n-6 | FA(22:6)_<BFFFF>_n-6'
#  'FA(17:0) | FA(18:1)_<>_n-2 | FA(18:2)_<F>_n-2 | FA(20:1)_<>_n-4 | FA(20:2)_<F>_n-4 | FA(20:3)_<FF>_n-4 | FA(20:4)_<FFF>_n-4 | FA(22:1)_<>_n-6 | FA(22:2)_<F>_n-6 | FA(22:6)_<FFFFF>_n-6'
#  'FA(20:5)_<BBBB>_n-3 | FA(22:6)_<BBBBF>_n-5'
#  'FA(20:4)_<BBB>_n-3 | FA(20:5)_<BBBF>_n-3 | FA(22:6)_<BBBFF>_n-5'
#  'FA(20:3)_<BB>_n-3 | FA(20:4)_<BBF>_n-3 | FA(20:5)_<BBFF>_n-3 | FA(22:6)_<BBFFF>_n-5'
#  'FA(20:2)_<B>_n-3 | FA(20:3)_<BF>_n-3 | FA(20:4)_<BFF>_n-3 | FA(22:2)_<B>_n-5 | FA(22:6)_<BFFFF>_n-5'
#  'FA(18:0) | FA(20:1)_<>_n-3 | FA(20:2)_<F>_n-3 | FA(20:3)_<FF>_n-3 | FA(22:1)_<>_n-5 | FA(22:2)_<F>_n-5'
#  'FA(22:6)_<BBBBB>_n-3' 'FA(22:6)_<BBBBF>_n-3' 'FA(22:6)_<BBBFF>_n-3'
#  'FA(22:2)_<B>_n-3' 'FA(20:0) | FA(22:1)_<>_n-3 | FA(22:2)_<F>_n-3'
#  'FA(21:0) | FA(22:1)_<>_n-2 | FA(22:2)_<F>_n-2' 'FA(22:0)' 'FA(23:0)'
#  'FA(24:0)']
#                                                     Lipid  Parent_Ion  \
# 0       FA(14:1)_<>_n-11 | FA(15:1)_<>_n-12 | FA(16:1)...       255.2
# 1       FA(14:1)_<>_n-11 | FA(15:1)_<>_n-12 | FA(16:1)...       255.2
# 2       FA(14:1)_<>_n-11 | FA(15:1)_<>_n-12 | FA(16:1)...       255.2
# 3       FA(14:1)_<>_n-11 | FA(15:1)_<>_n-12 | FA(16:1)...       255.2
# 4       FA(14:1)_<>_n-11 | FA(15:1)_<>_n-12 | FA(16:1)...       255.2
# ...                                                   ...         ...
# 288250                                                          533.5
# 288251                                                          533.5
# 288252                                                          533.5
# 288253                                                          533.5
# 288254                                                          533.5
#
#         Product_Ion  Retention_Time  OzESI_Intensity Sample_ID  \
# 0             183.0        3.067417             60.0   FAME_on
# 1             183.0        3.093650             41.0   FAME_on
# 2             183.0        3.119883             41.0   FAME_on
# 3             183.0        3.146117             49.0   FAME_on
# 4             183.0        3.172350             53.0   FAME_on
# ...             ...             ...              ...       ...
# 288250        183.0       17.024717             43.0   FAME_on
# 288251        183.0       17.050950             43.0   FAME_on
# 288252        183.0       17.077183             43.0   FAME_on
# 288253        183.0       17.103417             41.0   FAME_on
# 288254        183.0       17.129650             41.0   FAME_on
#
#             Transition Sample   STD  STD_RT_ON  STD_RT_Dif Species  \
# 0       255.2 -> 183.0   FAME  FAME   8.195483   -0.026217     8:0
# 1       255.2 -> 183.0   FAME  FAME   8.195483   -0.026217     8:0
# 2       255.2 -> 183.0   FAME  FAME   8.195483   -0.026217     8:0
# 3       255.2 -> 183.0   FAME  FAME   8.195483   -0.026217     8:0
# 4       255.2 -> 183.0   FAME  FAME   8.195483   -0.026217     8:0
# ...                ...    ...   ...        ...         ...     ...
# 288250  533.5 -> 183.0   FAME  FAME   8.195483   -0.026217    24:0
# 288251  533.5 -> 183.0   FAME  FAME   8.195483   -0.026217    24:0
# 288252  533.5 -> 183.0   FAME  FAME   8.195483   -0.026217    24:0
# 288253  533.5 -> 183.0   FAME  FAME   8.195483   -0.026217    24:0
# 288254  533.5 -> 183.0   FAME  FAME   8.195483   -0.026217    24:0
#
#                                                     Class  STD_RT_OFF
# 0       FA | FA | FA | FA | FA | FA | FA | FA | FA | F...    8.169267
# 1       FA | FA | FA | FA | FA | FA | FA | FA | FA | F...    8.169267
# 2       FA | FA | FA | FA | FA | FA | FA | FA | FA | F...    8.169267
# 3       FA | FA | FA | FA | FA | FA | FA | FA | FA | F...    8.169267
# 4       FA | FA | FA | FA | FA | FA | FA | FA | FA | F...    8.169267
# ...                                                   ...         ...
# 288250                                                       8.169267
# 288251                                                       8.169267
# 288252                                                       8.169267
# 288253                                                       8.169267
# 288254                                                       8.169267
#
# [288255 rows x 14 columns]

# %% [markdown]
# # 4 - group

# %%
# !sbatch core/backend/group_4_test.sh
# Out:
# Submitted batch job 19352611

# %%
import pandas as pd
df = pd.read_parquet('Projects/STD/group/ON/df_group_4_FAME.parquet')
#print unqiue vlaues of Lipid in df
print(df['Lipid'].unique())
df
# Out:
# ['FA(14:1)_<>_n-10 ' 'FA(14:1)_<>_n-11 ' 'FA(14:1)_<>_n-2 '
#  'FA(14:1)_<>_n-3 ' 'FA(14:1)_<>_n-4 ' 'FA(14:1)_<>_n-5 '
#  'FA(14:1)_<>_n-6 ' 'FA(14:1)_<>_n-7 ' 'FA(14:1)_<>_n-8 '
#  'FA(14:1)_<>_n-9 ' 'FA(15:1)_<>_n-10 ' 'FA(15:1)_<>_n-11 '
#  'FA(15:1)_<>_n-12 ' 'FA(15:1)_<>_n-2 ' 'FA(15:1)_<>_n-3 '
#  'FA(15:1)_<>_n-4 ' 'FA(15:1)_<>_n-5 ' 'FA(15:1)_<>_n-6 '
#  'FA(15:1)_<>_n-7 ' 'FA(15:1)_<>_n-8 ' 'FA(15:1)_<>_n-9 '
#  'FA(16:1)_<>_n-10 ' 'FA(16:1)_<>_n-11 ' 'FA(16:1)_<>_n-12 '
#  'FA(16:1)_<>_n-13 ' 'FA(16:1)_<>_n-2 ' 'FA(16:1)_<>_n-3 '
#  'FA(16:1)_<>_n-4 ' 'FA(16:1)_<>_n-5 ' 'FA(16:1)_<>_n-6 '
#  'FA(16:1)_<>_n-7 ' 'FA(16:1)_<>_n-8 ' 'FA(16:1)_<>_n-9 '
#  'FA(17:1)_<>_n-10 ' 'FA(17:1)_<>_n-11 ' 'FA(17:1)_<>_n-12 '
#  'FA(17:1)_<>_n-13 ' 'FA(17:1)_<>_n-14 ' 'FA(17:1)_<>_n-2 '
#  'FA(17:1)_<>_n-3 ' 'FA(17:1)_<>_n-4 ' 'FA(17:1)_<>_n-5 '
#  'FA(17:1)_<>_n-6 ' 'FA(17:1)_<>_n-7 ' 'FA(17:1)_<>_n-8 '
#  'FA(17:1)_<>_n-9 ' 'FA(18:1)_<>_n-10 ' 'FA(18:1)_<>_n-11 '
#  'FA(18:1)_<>_n-12 ' 'FA(18:1)_<>_n-13 ' 'FA(18:1)_<>_n-14 '
#  'FA(18:1)_<>_n-15 ' 'FA(18:1)_<>_n-2 ' 'FA(18:1)_<>_n-3 '
#  'FA(18:1)_<>_n-4 ' 'FA(18:1)_<>_n-5 ' 'FA(18:1)_<>_n-6 '
#  'FA(18:1)_<>_n-7 ' 'FA(18:1)_<>_n-8 ' 'FA(18:1)_<>_n-9 '
#  'FA(18:2)_<B>_n-10 ' 'FA(18:2)_<B>_n-11 ' 'FA(18:2)_<B>_n-2 '
#  'FA(18:2)_<B>_n-3 ' 'FA(18:2)_<B>_n-4 ' 'FA(18:2)_<B>_n-5 '
#  'FA(18:2)_<B>_n-6 ' 'FA(18:2)_<B>_n-7 ' 'FA(18:2)_<B>_n-9 '
#  'FA(18:2)_<F>_n-10 ' 'FA(18:2)_<F>_n-11 ' 'FA(18:2)_<F>_n-12 '
#  'FA(18:2)_<F>_n-13 ' 'FA(18:2)_<F>_n-14 ' 'FA(18:2)_<F>_n-15 '
#  'FA(18:2)_<F>_n-2 ' 'FA(18:2)_<F>_n-3 ' 'FA(18:2)_<F>_n-4 '
#  'FA(18:2)_<F>_n-5 ' 'FA(18:2)_<F>_n-6 ' 'FA(18:2)_<F>_n-7 '
#  'FA(18:2)_<F>_n-8 ' 'FA(18:2)_<F>_n-9 ' 'FA(18:3)_<BB>_n-3 '
#  'FA(18:3)_<BB>_n-4 ' 'FA(18:3)_<BB>_n-6 ' 'FA(18:3)_<BB>_n-7 '
#  'FA(18:3)_<BB>_n-8 ' 'FA(18:3)_<BF>_n-10 ' 'FA(18:3)_<BF>_n-11 '
#  'FA(18:3)_<BF>_n-2 ' 'FA(18:3)_<BF>_n-3 ' 'FA(18:3)_<BF>_n-4 '
#  'FA(18:3)_<BF>_n-5 ' 'FA(18:3)_<BF>_n-6 ' 'FA(18:3)_<BF>_n-7 '
#  'FA(18:3)_<BF>_n-9 ' 'FA(18:3)_<FF>_n-10 ' 'FA(18:3)_<FF>_n-11 '
#  'FA(18:3)_<FF>_n-12 ' 'FA(18:3)_<FF>_n-13 ' 'FA(18:3)_<FF>_n-14 '
#  'FA(18:3)_<FF>_n-15 ' 'FA(18:3)_<FF>_n-3 ' 'FA(18:3)_<FF>_n-4 '
#  'FA(18:3)_<FF>_n-5 ' 'FA(18:3)_<FF>_n-6 ' 'FA(18:3)_<FF>_n-7 '
#  'FA(18:3)_<FF>_n-8 ' 'FA(18:3)_<FF>_n-9 ' 'FA(20:1)_<>_n-10 '
#  'FA(20:1)_<>_n-11 ' 'FA(20:1)_<>_n-12 ' 'FA(20:1)_<>_n-13 '
#  'FA(20:1)_<>_n-14 ' 'FA(20:1)_<>_n-15 ' 'FA(20:1)_<>_n-16 '
#  'FA(20:1)_<>_n-17 ' 'FA(20:1)_<>_n-3 ' 'FA(20:1)_<>_n-4 '
#  'FA(20:1)_<>_n-5 ' 'FA(20:1)_<>_n-6 ' 'FA(20:1)_<>_n-7 '
#  'FA(20:1)_<>_n-8 ' 'FA(20:1)_<>_n-9 ' 'FA(20:2)_<B>_n-11 '
#  'FA(20:2)_<B>_n-12 ' 'FA(20:2)_<B>_n-13 ' 'FA(20:2)_<B>_n-3 '
#  'FA(20:2)_<B>_n-4 ' 'FA(20:2)_<B>_n-5 ' 'FA(20:2)_<B>_n-6 '
#  'FA(20:2)_<B>_n-7 ' 'FA(20:2)_<B>_n-8 ' 'FA(20:2)_<B>_n-9 '
#  'FA(20:2)_<F>_n-10 ' 'FA(20:2)_<F>_n-11 ' 'FA(20:2)_<F>_n-12 '
#  'FA(20:2)_<F>_n-13 ' 'FA(20:2)_<F>_n-14 ' 'FA(20:2)_<F>_n-15 '
#  'FA(20:2)_<F>_n-16 ' 'FA(20:2)_<F>_n-17 ' 'FA(20:2)_<F>_n-3 '
#  'FA(20:2)_<F>_n-4 ' 'FA(20:2)_<F>_n-5 ' 'FA(20:2)_<F>_n-6 '
#  'FA(20:2)_<F>_n-7 ' 'FA(20:2)_<F>_n-8 ' 'FA(20:2)_<F>_n-9 '
#  'FA(20:3)_<BB>_n-10 ' 'FA(20:3)_<BB>_n-3 ' 'FA(20:3)_<BB>_n-5 '
#  'FA(20:3)_<BB>_n-6 ' 'FA(20:3)_<BB>_n-8 ' 'FA(20:3)_<BB>_n-9 '
#  'FA(20:3)_<BF>_n-11 ' 'FA(20:3)_<BF>_n-12 ' 'FA(20:3)_<BF>_n-13 '
#  'FA(20:3)_<BF>_n-3 ' 'FA(20:3)_<BF>_n-4 ' 'FA(20:3)_<BF>_n-5 '
#  'FA(20:3)_<BF>_n-6 ' 'FA(20:3)_<BF>_n-7 ' 'FA(20:3)_<BF>_n-8 '
#  'FA(20:3)_<BF>_n-9 ' 'FA(20:3)_<FF>_n-10 ' 'FA(20:3)_<FF>_n-11 '
#  'FA(20:3)_<FF>_n-12 ' 'FA(20:3)_<FF>_n-13 ' 'FA(20:3)_<FF>_n-14 '
#  'FA(20:3)_<FF>_n-15 ' 'FA(20:3)_<FF>_n-16 ' 'FA(20:3)_<FF>_n-17 '
#  'FA(20:3)_<FF>_n-3 ' 'FA(20:3)_<FF>_n-4 ' 'FA(20:3)_<FF>_n-5 '
#  'FA(20:3)_<FF>_n-6 ' 'FA(20:3)_<FF>_n-7 ' 'FA(20:3)_<FF>_n-8 '
#  'FA(20:3)_<FF>_n-9 ' 'FA(20:4)_<BBB>_n-3 ' 'FA(20:4)_<BBB>_n-6 '
#  'FA(20:4)_<BBB>_n-7 ' 'FA(20:4)_<BBF>_n-10 ' 'FA(20:4)_<BBF>_n-3 '
#  'FA(20:4)_<BBF>_n-5 ' 'FA(20:4)_<BBF>_n-6 ' 'FA(20:4)_<BBF>_n-8 '
#  'FA(20:4)_<BBF>_n-9 ' 'FA(20:4)_<BFF>_n-11 ' 'FA(20:4)_<BFF>_n-12 '
#  'FA(20:4)_<BFF>_n-13 ' 'FA(20:4)_<BFF>_n-3 ' 'FA(20:4)_<BFF>_n-4 '
#  'FA(20:4)_<BFF>_n-5 ' 'FA(20:4)_<BFF>_n-6 ' 'FA(20:4)_<BFF>_n-7 '
#  'FA(20:4)_<BFF>_n-8 ' 'FA(20:4)_<BFF>_n-9 ' 'FA(20:4)_<FFF>_n-10 '
#  'FA(20:4)_<FFF>_n-11 ' 'FA(20:4)_<FFF>_n-12 ' 'FA(20:4)_<FFF>_n-13 '
#  'FA(20:4)_<FFF>_n-14 ' 'FA(20:4)_<FFF>_n-15 ' 'FA(20:4)_<FFF>_n-16 '
#  'FA(20:4)_<FFF>_n-17 ' 'FA(20:4)_<FFF>_n-4 ' 'FA(20:4)_<FFF>_n-5 '
#  'FA(20:4)_<FFF>_n-6 ' 'FA(20:4)_<FFF>_n-7 ' 'FA(20:4)_<FFF>_n-8 '
#  'FA(20:4)_<FFF>_n-9 ' 'FA(20:5)_<BBBB>_n-3 ' 'FA(20:5)_<BBBB>_n-4 '
#  'FA(20:5)_<BBBF>_n-3 ' 'FA(20:5)_<BBBF>_n-6 ' 'FA(20:5)_<BBBF>_n-7 '
#  'FA(20:5)_<BBFF>_n-10 ' 'FA(20:5)_<BBFF>_n-3 ' 'FA(20:5)_<BBFF>_n-5 '
#  'FA(20:5)_<BBFF>_n-6 ' 'FA(20:5)_<BBFF>_n-8 ' 'FA(20:5)_<BBFF>_n-9 '
#  'FA(20:5)_<BFFF>_n-11 ' 'FA(20:5)_<BFFF>_n-12 ' 'FA(20:5)_<BFFF>_n-13 '
#  'FA(20:5)_<BFFF>_n-4 ' 'FA(20:5)_<BFFF>_n-5 ' 'FA(20:5)_<BFFF>_n-6 '
#  'FA(20:5)_<BFFF>_n-7 ' 'FA(20:5)_<BFFF>_n-8 ' 'FA(20:5)_<BFFF>_n-9 '
#  'FA(20:5)_<FFFF>_n-10 ' 'FA(20:5)_<FFFF>_n-11 ' 'FA(20:5)_<FFFF>_n-12 '
#  'FA(20:5)_<FFFF>_n-13 ' 'FA(20:5)_<FFFF>_n-14 ' 'FA(20:5)_<FFFF>_n-15 '
#  'FA(20:5)_<FFFF>_n-16 ' 'FA(20:5)_<FFFF>_n-17 ' 'FA(20:5)_<FFFF>_n-5 '
#  'FA(20:5)_<FFFF>_n-6 ' 'FA(20:5)_<FFFF>_n-7 ' 'FA(20:5)_<FFFF>_n-8 '
#  'FA(20:5)_<FFFF>_n-9 ' 'FA(22:1)_<>_n-10 ' 'FA(22:1)_<>_n-11 '
#  'FA(22:1)_<>_n-12 ' 'FA(22:1)_<>_n-13 ' 'FA(22:1)_<>_n-14 '
#  'FA(22:1)_<>_n-15 ' 'FA(22:1)_<>_n-16 ' 'FA(22:1)_<>_n-17 '
#  'FA(22:1)_<>_n-18 ' 'FA(22:1)_<>_n-19 ' 'FA(22:1)_<>_n-2 '
#  'FA(22:1)_<>_n-3 ' 'FA(22:1)_<>_n-5 ' 'FA(22:1)_<>_n-6 '
#  'FA(22:1)_<>_n-7 ' 'FA(22:1)_<>_n-8 ' 'FA(22:1)_<>_n-9 '
#  'FA(22:2)_<B>_n-10 ' 'FA(22:2)_<B>_n-11 ' 'FA(22:2)_<B>_n-13 '
#  'FA(22:2)_<B>_n-14 ' 'FA(22:2)_<B>_n-15 ' 'FA(22:2)_<B>_n-3'
#  'FA(22:2)_<B>_n-5 ' 'FA(22:2)_<B>_n-6 ' 'FA(22:2)_<B>_n-7 '
#  'FA(22:2)_<B>_n-8 ' 'FA(22:2)_<B>_n-9 ' 'FA(22:2)_<F>_n-10 '
#  'FA(22:2)_<F>_n-11 ' 'FA(22:2)_<F>_n-12 ' 'FA(22:2)_<F>_n-13 '
#  'FA(22:2)_<F>_n-14 ' 'FA(22:2)_<F>_n-15 ' 'FA(22:2)_<F>_n-16 '
#  'FA(22:2)_<F>_n-17 ' 'FA(22:2)_<F>_n-18 ' 'FA(22:2)_<F>_n-19 '
#  'FA(22:2)_<F>_n-2' 'FA(22:2)_<F>_n-3' 'FA(22:2)_<F>_n-5'
#  'FA(22:2)_<F>_n-6 ' 'FA(22:2)_<F>_n-7 ' 'FA(22:2)_<F>_n-8 '
#  'FA(22:2)_<F>_n-9 ' 'FA(22:6)_<BBBBB>_n-3' 'FA(22:6)_<BBBBF>_n-3'
#  'FA(22:6)_<BBBBF>_n-5' 'FA(22:6)_<BBBBF>_n-6' 'FA(22:6)_<BBBFF>_n-3'
#  'FA(22:6)_<BBBFF>_n-5' 'FA(22:6)_<BBBFF>_n-8' 'FA(22:6)_<BBBFF>_n-9'
#  'FA(22:6)_<BBFFF>_n-10' 'FA(22:6)_<BBFFF>_n-11' 'FA(22:6)_<BBFFF>_n-12'
#  'FA(22:6)_<BBFFF>_n-5' 'FA(22:6)_<BBFFF>_n-7' 'FA(22:6)_<BBFFF>_n-8'
#  'FA(22:6)_<BFFFF>_n-10' 'FA(22:6)_<BFFFF>_n-11' 'FA(22:6)_<BFFFF>_n-13'
#  'FA(22:6)_<BFFFF>_n-14' 'FA(22:6)_<BFFFF>_n-15' 'FA(22:6)_<BFFFF>_n-5'
#  'FA(22:6)_<BFFFF>_n-6' 'FA(22:6)_<BFFFF>_n-7' 'FA(22:6)_<BFFFF>_n-8'
#  'FA(22:6)_<BFFFF>_n-9' 'FA(22:6)_<FFFFF>_n-10' 'FA(22:6)_<FFFFF>_n-11'
#  'FA(22:6)_<FFFFF>_n-12' 'FA(22:6)_<FFFFF>_n-13' 'FA(22:6)_<FFFFF>_n-14'
#  'FA(22:6)_<FFFFF>_n-15' 'FA(22:6)_<FFFFF>_n-16' 'FA(22:6)_<FFFFF>_n-17'
#  'FA(22:6)_<FFFFF>_n-18' 'FA(22:6)_<FFFFF>_n-19' 'FA(22:6)_<FFFFF>_n-6'
#  'FA(22:6)_<FFFFF>_n-7' 'FA(22:6)_<FFFFF>_n-8' 'FA(22:6)_<FFFFF>_n-9']
#                       Lipid  Parent_Ion  Product_Ion  Retention_Time  \
# 0         FA(14:1)_<>_n-10        269.1        183.0        4.798350
# 1         FA(14:1)_<>_n-10        269.1        183.0        4.824583
# 2         FA(14:1)_<>_n-10        269.1        183.0        4.850817
# 3         FA(14:1)_<>_n-10        269.1        183.0        4.877050
# 4         FA(14:1)_<>_n-10        269.1        183.0        4.903283
# ...                     ...         ...          ...             ...
# 72464  FA(22:6)_<FFFFF>_n-9       395.4        183.0        9.589933
# 72465  FA(22:6)_<FFFFF>_n-9       395.4        183.0        9.616167
# 72466  FA(22:6)_<FFFFF>_n-9       395.4        183.0        9.642400
# 72467  FA(22:6)_<FFFFF>_n-9       395.4        183.0        9.668633
# 72468  FA(22:6)_<FFFFF>_n-9       395.4        183.0        9.694867
#
#        OzESI_Intensity Sample_ID      Transition Sample   STD  STD_RT_ON  \
# 0                 74.0   FAME_on  269.1 -> 183.0   FAME  FAME   8.195483
# 1                 76.0   FAME_on  269.1 -> 183.0   FAME  FAME   8.195483
# 2                 57.0   FAME_on  269.1 -> 183.0   FAME  FAME   8.195483
# 3                 41.0   FAME_on  269.1 -> 183.0   FAME  FAME   8.195483
# 4                 41.0   FAME_on  269.1 -> 183.0   FAME  FAME   8.195483
# ...                ...       ...             ...    ...   ...        ...
# 72464            874.0   FAME_on  395.4 -> 183.0   FAME  FAME   8.195483
# 72465            786.0   FAME_on  395.4 -> 183.0   FAME  FAME   8.195483
# 72466            706.0   FAME_on  395.4 -> 183.0   FAME  FAME   8.195483
# 72467            600.0   FAME_on  395.4 -> 183.0   FAME  FAME   8.195483
# 72468            514.0   FAME_on  395.4 -> 183.0   FAME  FAME   8.195483
#
#        STD_RT_Dif Species Class  STD_RT_OFF  \
# 0       -0.026217    14:1    FA    8.169267
# 1       -0.026217    14:1    FA    8.169267
# 2       -0.026217    14:1    FA    8.169267
# 3       -0.026217    14:1    FA    8.169267
# 4       -0.026217    14:1    FA    8.169267
# ...           ...     ...   ...         ...
# 72464   -0.026217    22:6    FA    8.169267
# 72465   -0.026217    22:6    FA    8.169267
# 72466   -0.026217    22:6    FA    8.169267
# 72467   -0.026217    22:6    FA    8.169267
# 72468   -0.026217    22:6    FA    8.169267
#
#                                          Possible_Lipids  group_by_ion  \
# 0      FA(14:1)_<>_n-10 | FA(15:1)_<>_n-11 | FA(16:1)...             1
# 1      FA(14:1)_<>_n-10 | FA(15:1)_<>_n-11 | FA(16:1)...             1
# 2      FA(14:1)_<>_n-10 | FA(15:1)_<>_n-11 | FA(16:1)...             1
# 3      FA(14:1)_<>_n-10 | FA(15:1)_<>_n-11 | FA(16:1)...             1
# 4      FA(14:1)_<>_n-10 | FA(15:1)_<>_n-11 | FA(16:1)...             1
# ...                                                  ...           ...
# 72464  FA(14:0) | FA(15:1)_<>_n-2 | FA(16:1)_<>_n-3 |...            21
# 72465  FA(14:0) | FA(15:1)_<>_n-2 | FA(16:1)_<>_n-3 |...            21
# 72466  FA(14:0) | FA(15:1)_<>_n-2 | FA(16:1)_<>_n-3 |...            21
# 72467  FA(14:0) | FA(15:1)_<>_n-2 | FA(16:1)_<>_n-3 |...            21
# 72468  FA(14:0) | FA(15:1)_<>_n-2 | FA(16:1)_<>_n-3 |...            21
#
#        group_by_lipid
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 72464             329
# 72465             329
# 72466             329
# 72467             329
# 72468             329
#
# [72469 rows x 17 columns]

# %%
import matplotlib.pyplot as plt

# Function to plot the chromatogram for a specific group_by_lipid value
def plot_chromatogram(df, group_value):
    group_data = df[df['group_by_lipid'] == group_value]
    
    # Ensure the Retention_Time is sorted
    group_data = group_data.sort_values(by='Retention_Time')
    
    # Extract Lipid and Parent Ion values from the first row of the group
    lipid = group_data['Lipid'].iloc[0] if not group_data.empty else "Unknown Lipid"
    parent_ion = group_data['Parent_Ion'].iloc[0] if not group_data.empty else "Unknown Parent Ion"
    
    plt.figure(figsize=(10, 6))
    plt.plot(group_data['Retention_Time'], group_data['OzESI_Intensity'], label=f'group_by_lipid: {group_value}')
    plt.xlabel('Retention Time')
    plt.ylabel('OzESI Intensity')
    
    # Add Lipid and Parent Ion to the title
    plt.title(f'{group_value} | Lipid: {lipid} | Parent Ion: {parent_ion}')
    
    plt.legend()
    plt.grid(True)
    plt.show()

# Define the specific group_by_lipid value you are interested in
specific_group_by_lipid_value = 10  # Replace with the actual value you are interested in

# Call the function to plot the chromatogram
plot_chromatogram(df, specific_group_by_lipid_value)

# %% [markdown]
# # 5 - Analysis

# %%
# !sbatch core/backend/analysis_5_test.sh
# Out:
# Submitted batch job 19352649

# %%
import pandas as pd
df_analysis = pd.read_parquet('Projects/STD/analysis/ON/df_analysis_5_FAME.parquet')
#print number of unqiue values
print(df_analysis['Lipid'].unique())
df_analysis
# Out:
# ['FA(14:1)_<>_n-2 ' 'FA(14:1)_<>_n-3 ' 'FA(14:1)_<>_n-4 '
#  'FA(14:1)_<>_n-5 ' 'FA(14:1)_<>_n-6 ' 'FA(14:1)_<>_n-9 '
#  'FA(15:1)_<>_n-2 ' 'FA(15:1)_<>_n-3 ' 'FA(15:1)_<>_n-4 '
#  'FA(15:1)_<>_n-5 ' 'FA(15:1)_<>_n-6 ' 'FA(15:1)_<>_n-7 '
#  'FA(15:1)_<>_n-8 ' 'FA(15:1)_<>_n-9 ' 'FA(15:1)_<>_n-10 '
#  'FA(15:1)_<>_n-11 ' 'FA(16:1)_<>_n-2 ' 'FA(16:1)_<>_n-4 '
#  'FA(16:1)_<>_n-5 ' 'FA(16:1)_<>_n-6 ' 'FA(16:1)_<>_n-7 '
#  'FA(16:1)_<>_n-8 ' 'FA(16:1)_<>_n-9 ' 'FA(16:1)_<>_n-10 '
#  'FA(16:1)_<>_n-11 ' 'FA(16:1)_<>_n-12 ' 'FA(17:1)_<>_n-2 '
#  'FA(17:1)_<>_n-3 ' 'FA(17:1)_<>_n-4 ' 'FA(17:1)_<>_n-5 '
#  'FA(17:1)_<>_n-6 ' 'FA(17:1)_<>_n-7 ' 'FA(17:1)_<>_n-8 '
#  'FA(17:1)_<>_n-9 ' 'FA(17:1)_<>_n-10 ' 'FA(17:1)_<>_n-11 '
#  'FA(17:1)_<>_n-12 ' 'FA(17:1)_<>_n-13 ' 'FA(18:1)_<>_n-2 '
#  'FA(18:1)_<>_n-3 ' 'FA(18:1)_<>_n-4 ' 'FA(18:1)_<>_n-5 '
#  'FA(18:1)_<>_n-6 ' 'FA(18:1)_<>_n-7 ' 'FA(18:1)_<>_n-8 '
#  'FA(18:1)_<>_n-9 ' 'FA(18:1)_<>_n-10 ' 'FA(18:1)_<>_n-11 '
#  'FA(18:1)_<>_n-12 ' 'FA(18:1)_<>_n-13 ' 'FA(18:1)_<>_n-14 '
#  'FA(18:2)_<F>_n-2 ' 'FA(18:2)_<B>_n-2 ' 'FA(18:2)_<F>_n-3 '
#  'FA(18:2)_<B>_n-3 ' 'FA(18:2)_<F>_n-4 ' 'FA(18:2)_<B>_n-4 '
#  'FA(18:2)_<F>_n-5 ' 'FA(18:2)_<B>_n-5 ' 'FA(18:2)_<F>_n-6 '
#  'FA(18:2)_<B>_n-6 ' 'FA(18:2)_<F>_n-7 ' 'FA(18:2)_<B>_n-7 '
#  'FA(18:2)_<F>_n-8 ' 'FA(18:2)_<F>_n-9 ' 'FA(18:2)_<B>_n-9 '
#  'FA(18:2)_<F>_n-10 ' 'FA(18:2)_<B>_n-10 ' 'FA(18:2)_<F>_n-11 '
#  'FA(18:2)_<B>_n-11 ' 'FA(18:2)_<F>_n-12 ' 'FA(18:2)_<F>_n-13 '
#  'FA(18:2)_<F>_n-14 ' 'FA(18:3)_<BF>_n-2 ' 'FA(18:3)_<FF>_n-3 '
#  'FA(18:3)_<BF>_n-3 ' 'FA(18:3)_<BB>_n-3 ' 'FA(18:3)_<FF>_n-4 '
#  'FA(18:3)_<BF>_n-4 ' 'FA(18:3)_<BB>_n-4 ' 'FA(18:3)_<FF>_n-5 '
#  'FA(18:3)_<BF>_n-5 ' 'FA(18:3)_<FF>_n-6 ' 'FA(18:3)_<BF>_n-6 '
#  'FA(18:3)_<BB>_n-6 ' 'FA(18:3)_<FF>_n-7 ' 'FA(18:3)_<BF>_n-7 '
#  'FA(18:3)_<BB>_n-7 ' 'FA(18:3)_<FF>_n-8 ' 'FA(18:3)_<BB>_n-8 '
#  'FA(18:3)_<FF>_n-9 ' 'FA(18:3)_<BF>_n-9 ' 'FA(18:3)_<FF>_n-10 '
#  'FA(18:3)_<BF>_n-10 ' 'FA(18:3)_<FF>_n-11 ' 'FA(18:3)_<BF>_n-11 '
#  'FA(18:3)_<FF>_n-12 ' 'FA(18:3)_<FF>_n-13 ' 'FA(18:3)_<FF>_n-14 '
#  'FA(20:1)_<>_n-3 ' 'FA(20:1)_<>_n-4 ' 'FA(20:1)_<>_n-5 '
#  'FA(20:1)_<>_n-6 ' 'FA(20:1)_<>_n-7 ' 'FA(20:1)_<>_n-9 '
#  'FA(20:1)_<>_n-10 ' 'FA(20:1)_<>_n-11 ' 'FA(20:1)_<>_n-12 '
#  'FA(20:1)_<>_n-13 ' 'FA(20:2)_<F>_n-3 ' 'FA(20:2)_<B>_n-3 '
#  'FA(20:2)_<F>_n-4 ' 'FA(20:2)_<B>_n-4 ' 'FA(20:2)_<F>_n-5 '
#  'FA(20:2)_<B>_n-5 ' 'FA(20:2)_<F>_n-6 ' 'FA(20:2)_<B>_n-6 '
#  'FA(20:2)_<F>_n-7 ' 'FA(20:2)_<B>_n-7 ' 'FA(20:2)_<F>_n-8 '
#  'FA(20:2)_<B>_n-8 ' 'FA(20:2)_<F>_n-9 ' 'FA(20:2)_<B>_n-9 '
#  'FA(20:2)_<F>_n-10 ' 'FA(20:2)_<F>_n-11 ' 'FA(20:2)_<B>_n-11 '
#  'FA(20:2)_<F>_n-12 ' 'FA(20:2)_<B>_n-12 ' 'FA(20:2)_<F>_n-13 '
#  'FA(20:2)_<B>_n-13 ' 'FA(20:3)_<FF>_n-3 ' 'FA(20:3)_<BF>_n-3 '
#  'FA(20:3)_<BB>_n-3 ' 'FA(20:3)_<FF>_n-4 ' 'FA(20:3)_<BF>_n-4 '
#  'FA(20:3)_<FF>_n-5 ' 'FA(20:3)_<BF>_n-5 ' 'FA(20:3)_<BB>_n-5 '
#  'FA(20:3)_<FF>_n-6 ' 'FA(20:3)_<BF>_n-6 ' 'FA(20:3)_<BB>_n-6 '
#  'FA(20:3)_<FF>_n-7 ' 'FA(20:3)_<BF>_n-7 ' 'FA(20:3)_<FF>_n-8 '
#  'FA(20:3)_<BF>_n-8 ' 'FA(20:3)_<BB>_n-8 ' 'FA(20:3)_<FF>_n-9 '
#  'FA(20:3)_<BF>_n-9 ' 'FA(20:3)_<BB>_n-9 ' 'FA(20:3)_<FF>_n-10 '
#  'FA(20:3)_<BB>_n-10 ' 'FA(20:3)_<FF>_n-11 ' 'FA(20:3)_<BF>_n-11 '
#  'FA(20:3)_<FF>_n-12 ' 'FA(20:3)_<BF>_n-12 ' 'FA(20:3)_<FF>_n-13 '
#  'FA(20:3)_<BF>_n-13 ' 'FA(20:3)_<FF>_n-14 ' 'FA(20:3)_<FF>_n-15 '
#  'FA(20:3)_<FF>_n-16 ' 'FA(20:4)_<BFF>_n-3 ' 'FA(20:4)_<BBF>_n-3 '
#  'FA(20:4)_<BBB>_n-3 ' 'FA(20:4)_<FFF>_n-4 ' 'FA(20:4)_<BFF>_n-4 '
#  'FA(20:4)_<FFF>_n-5 ' 'FA(20:4)_<BFF>_n-5 ' 'FA(20:4)_<BBF>_n-5 '
#  'FA(20:4)_<FFF>_n-6 ' 'FA(20:4)_<BFF>_n-6 ' 'FA(20:4)_<BBF>_n-6 '
#  'FA(20:4)_<BBB>_n-6 ' 'FA(20:4)_<FFF>_n-7 ' 'FA(20:4)_<BFF>_n-7 '
#  'FA(20:4)_<BBB>_n-7 ' 'FA(20:4)_<FFF>_n-8 ' 'FA(20:4)_<BFF>_n-8 '
#  'FA(20:4)_<BBF>_n-8 ' 'FA(20:4)_<FFF>_n-9 ' 'FA(20:4)_<BFF>_n-9 '
#  'FA(20:4)_<BBF>_n-9 ' 'FA(20:4)_<FFF>_n-10 ' 'FA(20:4)_<BBF>_n-10 '
#  'FA(20:4)_<FFF>_n-11 ' 'FA(20:4)_<BFF>_n-11 ' 'FA(20:4)_<FFF>_n-12 '
#  'FA(20:4)_<BFF>_n-12 ' 'FA(20:4)_<FFF>_n-13 ' 'FA(20:4)_<BFF>_n-13 '
#  'FA(20:4)_<FFF>_n-14 ' 'FA(20:4)_<FFF>_n-15 ' 'FA(20:4)_<FFF>_n-16 '
#  'FA(20:5)_<BBFF>_n-3 ' 'FA(20:5)_<BBBF>_n-3 ' 'FA(20:5)_<BBBB>_n-3 '
#  'FA(20:5)_<BFFF>_n-4 ' 'FA(20:5)_<BBBB>_n-4 ' 'FA(20:5)_<FFFF>_n-5 '
#  'FA(20:5)_<BFFF>_n-5 ' 'FA(20:5)_<BBFF>_n-5 ' 'FA(20:5)_<FFFF>_n-6 '
#  'FA(20:5)_<BFFF>_n-6 ' 'FA(20:5)_<BBFF>_n-6 ' 'FA(20:5)_<BBBF>_n-6 '
#  'FA(20:5)_<FFFF>_n-7 ' 'FA(20:5)_<BFFF>_n-7 ' 'FA(20:5)_<BBBF>_n-7 '
#  'FA(20:5)_<FFFF>_n-8 ' 'FA(20:5)_<BFFF>_n-8 ' 'FA(20:5)_<BBFF>_n-8 '
#  'FA(20:5)_<FFFF>_n-9 ' 'FA(20:5)_<BFFF>_n-9 ' 'FA(20:5)_<BBFF>_n-9 '
#  'FA(20:5)_<FFFF>_n-10 ' 'FA(20:5)_<BBFF>_n-10 ' 'FA(20:5)_<FFFF>_n-11 '
#  'FA(20:5)_<BFFF>_n-11 ' 'FA(20:5)_<FFFF>_n-12 ' 'FA(20:5)_<BFFF>_n-12 '
#  'FA(20:5)_<FFFF>_n-13 ' 'FA(20:5)_<BFFF>_n-13 ' 'FA(20:5)_<FFFF>_n-14 '
#  'FA(20:5)_<FFFF>_n-15 ' 'FA(20:5)_<FFFF>_n-16 ' 'FA(22:1)_<>_n-2 '
#  'FA(22:1)_<>_n-3 ' 'FA(22:1)_<>_n-5 ' 'FA(22:1)_<>_n-6 '
#  'FA(22:1)_<>_n-7 ' 'FA(22:1)_<>_n-9 ' 'FA(22:1)_<>_n-10 '
#  'FA(22:1)_<>_n-11 ' 'FA(22:1)_<>_n-13 ' 'FA(22:2)_<F>_n-3'
#  'FA(22:2)_<B>_n-3' 'FA(22:2)_<F>_n-5' 'FA(22:2)_<B>_n-5 '
#  'FA(22:2)_<F>_n-6 ' 'FA(22:2)_<B>_n-6 ' 'FA(22:2)_<F>_n-7 '
#  'FA(22:2)_<B>_n-7 ' 'FA(22:2)_<F>_n-9 ' 'FA(22:2)_<F>_n-10 '
#  'FA(22:2)_<F>_n-11 ' 'FA(22:2)_<F>_n-13 ' 'FA(22:6)_<BBBFF>_n-3'
#  'FA(22:6)_<BBBBF>_n-3' 'FA(22:6)_<BBBBB>_n-3' 'FA(22:6)_<BFFFF>_n-5'
#  'FA(22:6)_<BBFFF>_n-5' 'FA(22:6)_<BBBFF>_n-5' 'FA(22:6)_<BBBBF>_n-5'
#  'FA(22:6)_<FFFFF>_n-6' 'FA(22:6)_<BFFFF>_n-6' 'FA(22:6)_<BBBBF>_n-6'
#  'FA(22:6)_<FFFFF>_n-7' 'FA(22:6)_<BFFFF>_n-7' 'FA(22:6)_<BBFFF>_n-7'
#  'FA(22:6)_<FFFFF>_n-8' 'FA(22:6)_<BFFFF>_n-8' 'FA(22:6)_<BBFFF>_n-8'
#  'FA(22:6)_<BBBFF>_n-8' 'FA(22:6)_<FFFFF>_n-9' 'FA(22:6)_<BFFFF>_n-9'
#  'FA(22:6)_<BBBFF>_n-9' 'FA(22:6)_<FFFFF>_n-10' 'FA(22:6)_<BFFFF>_n-10'
#  'FA(22:6)_<BBFFF>_n-10' 'FA(22:6)_<FFFFF>_n-11' 'FA(22:6)_<BFFFF>_n-11'
#  'FA(22:6)_<BBFFF>_n-11' 'FA(22:6)_<FFFFF>_n-12' 'FA(22:6)_<BBFFF>_n-12'
#  'FA(22:6)_<FFFFF>_n-13' 'FA(22:6)_<BFFFF>_n-13' 'FA(22:6)_<FFFFF>_n-14'
#  'FA(22:6)_<BFFFF>_n-14' 'FA(22:6)_<FFFFF>_n-15' 'FA(22:6)_<BFFFF>_n-15'
#  'FA(22:6)_<FFFFF>_n-16' 'FA(22:6)_<FFFFF>_n-17' 'FA(22:6)_<FFFFF>_n-18']
#                       Lipid  Retention_Time  OzESI_Intensity  group_by_ion  \
# 0          FA(14:1)_<>_n-2         5.551400         532130.0            18
# 1          FA(14:1)_<>_n-3         4.844483         756968.0            15
# 2          FA(14:1)_<>_n-3         5.710167           1105.0            15
# 3          FA(14:1)_<>_n-4         6.078800         189818.0            12
# 4          FA(14:1)_<>_n-5         5.318933         116090.0            10
# ...                     ...             ...              ...           ...
# 1061  FA(22:6)_<BFFFF>_n-15        7.577250         165002.0             5
# 1062  FA(22:6)_<BFFFF>_n-15        8.757733           1307.0             5
# 1063  FA(22:6)_<FFFFF>_n-16        7.577700           1929.0             4
# 1064  FA(22:6)_<FFFFF>_n-17        7.630617         105182.0             3
# 1065  FA(22:6)_<FFFFF>_n-18        7.579050          64931.0             1
#
#       group_by_lipid Sample_ID      Transition Sample  Parent_Ion  \
# 0                  2   FAME_on  381.3 -> 183.0   FAME       381.3
# 1                  3   FAME_on  367.3 -> 183.0   FAME       367.3
# 2                  3   FAME_on  367.3 -> 183.0   FAME       367.3
# 3                  4   FAME_on  353.3 -> 183.0   FAME       353.3
# 4                  5   FAME_on  339.3 -> 183.0   FAME       339.3
# ...              ...       ...             ...    ...         ...
# 1061             310   FAME_on  309.1 -> 183.0   FAME       309.1
# 1062             310   FAME_on  309.1 -> 183.0   FAME       309.1
# 1063             322   FAME_on  297.2 -> 183.0   FAME       297.2
# 1064             323   FAME_on  283.3 -> 183.0   FAME       283.3
# 1065             324   FAME_on  269.1 -> 183.0   FAME       269.1
#
#       Product_Ion Species Class  \
# 0           183.0    14:1    FA
# 1           183.0    14:1    FA
# 2           183.0    14:1    FA
# 3           183.0    14:1    FA
# 4           183.0    14:1    FA
# ...           ...     ...   ...
# 1061        183.0    22:6    FA
# 1062        183.0    22:6    FA
# 1063        183.0    22:6    FA
# 1064        183.0    22:6    FA
# 1065        183.0    22:6    FA
#
#                                         Possible_Lipids  Peak_Height  \
# 0     FA(13:0) | FA(14:1)_<>_n-2 | FA(15:1)_<>_n-3 |...     532130.0
# 1     FA(12:0) | FA(14:1)_<>_n-3 | FA(15:1)_<>_n-4 |...     756968.0
# 2     FA(12:0) | FA(14:1)_<>_n-3 | FA(15:1)_<>_n-4 |...       1105.0
# 3     FA(11:0) | FA(14:1)_<>_n-4 | FA(15:1)_<>_n-5 |...     189818.0
# 4     FA(10:0) | FA(14:1)_<>_n-5 | FA(15:1)_<>_n-6 |...     116090.0
# ...                                                 ...          ...
# 1061  FA(18:2)_<B>_n-11 | FA(18:3)_<BF>_n-11 | FA(20...     165002.0
# 1062  FA(18:2)_<B>_n-11 | FA(18:3)_<BF>_n-11 | FA(20...       1307.0
# 1063  FA(14:1)_<>_n-8 | FA(15:1)_<>_n-9 | FA(16:1)_<...       1929.0
# 1064  FA(14:1)_<>_n-9 | FA(15:1)_<>_n-10 | FA(16:1)_...     105182.0
# 1065  FA(14:1)_<>_n-10 | FA(15:1)_<>_n-11 | FA(16:1)...      64931.0
#
#           FWHM  Peak_Width     Peak_Area   Filter_Column  n_value
# 0     0.099008    0.104933  55838.174667  group_by_lipid        2
# 1     0.063411    0.078683  59560.765467  group_by_lipid        3
# 2     0.083444    0.052467     57.975667  group_by_lipid        3
# 3     0.100073    0.104917  19915.071833  group_by_lipid        4
# 4     0.091635    0.078700   9136.283000  group_by_lipid        5
# ...        ...         ...           ...             ...      ...
# 1061  0.092584    0.104933  17314.209867  group_by_lipid       15
# 1062  0.178197    0.078717    102.882683  group_by_lipid       15
# 1063  0.145926    0.131167    253.020500  group_by_lipid       16
# 1064  0.003156    0.104483  10989.765967  group_by_lipid       17
# 1065  0.089976    0.104933   6813.426267  group_by_lipid       18
#
# [1066 rows x 19 columns]

# %%
import matplotlib.pyplot as plt

# Function to plot the chromatogram for a specific group_by_lipid value, including analysis data (peaks)
def plot_chromatogram(df_grouped, df_analysis, group_value):
    """
    Plot the chromatogram for a specific group_by_lipid value.

    :param df_grouped: DataFrame containing the original grouped data.
    :param df_analysis: DataFrame containing the analyzed data (peaks).
    :param group_value: The specific group_by_lipid value to plot.
    """
    # Filter data for the specific group_by_lipid value
    group_data = df_grouped[df_grouped['group_by_lipid'] == group_value]
    analysis_data = df_analysis[df_analysis['group_by_lipid'] == group_value]
    
    # Ensure the Retention_Time is sorted in both DataFrames
    group_data = group_data.sort_values(by='Retention_Time')
    analysis_data = analysis_data.sort_values(by='Retention_Time')

    # Extract Lipid and Parent Ion values from the first row of the group
    lipid = group_data['Lipid'].iloc[0] if not group_data.empty else "Unknown Lipid"
    parent_ion = group_data['Parent_Ion'].iloc[0] if not group_data.empty else "Unknown Parent Ion"
    
    # Plot the grouped data (original chromatogram)
    plt.figure(figsize=(10, 6))
    plt.plot(group_data['Retention_Time'], group_data['OzESI_Intensity'], label=f'Chromatogram - group_by_lipid: {group_value}', color='blue')
    
    # Overlay the analysis data (peaks)
    if not analysis_data.empty:
        plt.scatter(analysis_data['Retention_Time'], analysis_data['OzESI_Intensity'], color='red', marker='x', label='Identified Peaks')

    # Add labels and title
    plt.xlabel('Retention Time')
    plt.ylabel('OzESI Intensity')
    
    # Add Lipid and Parent Ion to the title
    plt.title(f'{group_value} | Lipid: {lipid} | Parent Ion: {parent_ion}')
    
    # Add a legend and grid
    plt.legend()
    plt.grid(True)
    
    # Show the plot
    plt.show()

# Example: Define the specific group_by_lipid value you are interested in
specific_group_by_lipid_value = 10  # Replace with the actual value you are interested in

# Call the function to plot the chromatogram and analysis data
plot_chromatogram(df, df_analysis, specific_group_by_lipid_value)

# %% [markdown]
# # PLOT

# %%
import matplotlib.pyplot as plt

# Function to create a bar plot of Lipid vs Max OzESI_Intensity, separated by Species
def plot_max_lipid_intensity_by_species(df):
    """
    Create separate bar plots of Lipid vs Max OzESI_Intensity for each unique Species.

    :param df: DataFrame containing Lipid, OzESI_Intensity, and Species columns.
    """
    unique_species = df['Species'].unique()

    for species in unique_species:
        # Filter the DataFrame by the current Species
        species_data = df[df['Species'] == species]
        
        # Group by Lipid and get the maximum OzESI_Intensity for each Lipid within the current Species
        max_lipid_intensity = species_data.groupby('Lipid')['OzESI_Intensity'].max().reset_index()
        
        # Sort the lipids by intensity for better visualization
        max_lipid_intensity = max_lipid_intensity.sort_values(by='OzESI_Intensity', ascending=False)
        
        # Create a bar plot for the current Species
        plt.figure(figsize=(12, 6))
        plt.bar(max_lipid_intensity['Lipid'], max_lipid_intensity['OzESI_Intensity'], color='skyblue')
        
        # Add labels and title
        plt.xlabel('Lipid')
        plt.ylabel('Max OzESI Intensity')
        plt.title(f'Lipid vs Max OzESI Intensity | Species: {species}')
        
        # Rotate x-axis labels for better readability
        plt.xticks(rotation=90)
        
        plt.tight_layout()
        plt.show()

# Call the function with df_grouped or df_analysis
plot_max_lipid_intensity_by_species(df_analysis)
